# %% [markdown]
# Następujący notes został wygenerowany automatycznie przez GitHub Copilot Chat i służy wyłącznie do początkowej konfiguracji

# %% [markdown]
# # Wprowadzenie do inżynierii promptów
# Inżynieria promptów to proces projektowania i optymalizacji promptów dla zadań przetwarzania języka naturalnego. Obejmuje wybór odpowiednich promptów, dostrajanie ich parametrów oraz ocenę ich wydajności. Inżynieria promptów jest kluczowa dla osiągnięcia wysokiej dokładności i efektywności w modelach NLP. W tej sekcji zbadamy podstawy inżynierii promptów, korzystając z modeli OpenAI do eksploracji.

# %% [markdown]
# ### Ćwiczenie 1: Tokenizacja
# Poznaj tokenizację za pomocą tiktoken, otwartoźródłowego szybkiego tokenizera od OpenAI
# Zobacz [OpenAI Cookbook](https://github.com/openai/openai-cookbook/blob/main/examples/How_to_count_tokens_with_tiktoken.ipynb?WT.mc_id=academic-105485-koreyst) aby zobaczyć więcej przykładów.

# %%
# EXERCISE:
# 1. Run the exercise as is first
# 2. Change the text to any prompt input you want to use & re-run to see tokens

import tiktoken

# Define the prompt you want tokenized
text = f"""
Jupiter is the fifth planet from the Sun and the \
largest in the Solar System. It is a gas giant with \
a mass one-thousandth that of the Sun, but two-and-a-half \
times that of all the other planets in the Solar System combined. \
Jupiter is one of the brightest objects visible to the naked eye \
in the night sky, and has been known to ancient civilizations since \
before recorded history. It is named after the Roman god Jupiter.[19] \
When viewed from Earth, Jupiter can be bright enough for its reflected \
light to cast visible shadows,[20] and is on average the third-brightest \
natural object in the night sky after the Moon and Venus.
"""

# Set the model you want encoding for
encoding = tiktoken.encoding_for_model("gpt-4o")

# Encode the text - gives you the tokens in integer form
tokens = encoding.encode(text)
print(tokens);

# Decode the integers to see what the text versions look like
[encoding.decode_single_token_bytes(token) for token in tokens]

# %% [markdown]
# ### Ćwiczenie 2: Sprawdź poprawność konfiguracji klucza API OpenAI
#
# Uruchom poniższy kod, aby zweryfikować, czy Twój punkt końcowy OpenAI jest poprawnie skonfigurowany. Kod próbuje wykonać prostą podstawową komendę i sprawdza poprawność odpowiedzi. Wprowadzenie `oh say can you see` powinno zakończyć się mniej więcej tekstem `by the dawn's early light..`

# %%
# Uses the OpenAI client against the Azure OpenAI (Microsoft Foundry) v1 endpoint
# with the Responses API. See https://aka.ms/openai/start

import os
from openai import OpenAI
from dotenv import load_dotenv
load_dotenv()

client = OpenAI(
  api_key=os.environ['AZURE_OPENAI_API_KEY'],
  base_url=f"{os.environ['AZURE_OPENAI_ENDPOINT'].rstrip('/')}/openai/v1/",
  )

deployment=os.environ['AZURE_OPENAI_DEPLOYMENT']

def get_completion(prompt):
    response = client.responses.create(
        model=deployment,
        input=prompt,
        temperature=0, # this is the degree of randomness of the model's output
        max_output_tokens=1024,
        store=False,
    )
    return response.output_text

## ---------- Call the helper method

### 1. Set primary content or prompt text
text = f"""
oh say can you see
"""

### 2. Use that in the prompt template below
prompt = f"""
```{text}```
"""

## 3. Run the prompt
response = get_completion(prompt)
print(response)

# %% [markdown]
# ### Ćwiczenie 3: Wymyślone treści
# Zbadaj, co się stanie, gdy poprosisz LLM o wygenerowanie odpowiedzi na temat, który może nie istnieć, lub na tematy, o których może nie wiedzieć, ponieważ były poza jego wstępnie wytrenowanym zbiorem danych (bardziej aktualne). Zobacz, jak zmienia się odpowiedź, jeśli spróbujesz innego zapytania lub innego modelu.

# %%
## Set the text for simple prompt or primary content
## Prompt shows a template format with text in it - add cues, commands etc if needed
## Run the completion 
text = f"""
generate a lesson plan on the Martian War of 2076.
"""

prompt = f"""
```{text}```
"""

response = get_completion(prompt)
print(response)

# %% [markdown]
# ### Ćwiczenie 4: Oparte na instrukcji
# Użyj zmiennej "text", aby ustawić główną treść
# oraz zmiennej "prompt", aby podać instrukcję związaną z tą główną treścią.
#
# Tutaj prosimy model o streszczenie tekstu dla ucznia drugiej klasy

# %%
# Test Example
# https://platform.openai.com/playground/p/default-summarize

## Example text
text = f"""
Jupiter is the fifth planet from the Sun and the \
largest in the Solar System. It is a gas giant with \
a mass one-thousandth that of the Sun, but two-and-a-half \
times that of all the other planets in the Solar System combined. \
Jupiter is one of the brightest objects visible to the naked eye \
in the night sky, and has been known to ancient civilizations since \
before recorded history. It is named after the Roman god Jupiter.[19] \
When viewed from Earth, Jupiter can be bright enough for its reflected \
light to cast visible shadows,[20] and is on average the third-brightest \
natural object in the night sky after the Moon and Venus.
"""

## Set the prompt
prompt = f"""
Summarize content you are provided with for a second-grade student.
```{text}```
"""

## Run the prompt
response = get_completion(prompt)
print(response)

# %% [markdown]
# ### Ćwiczenie 5: Złożona prośba
# Wypróbuj prośbę, która zawiera wiadomości systemowe, użytkownika i asystenta
# System ustawia kontekst asystenta
# Wiadomości użytkownika i asystenta dostarczają kontekst rozmowy wieloetapowej
#
# Zwróć uwagę, jak osobowość asystenta jest ustawiona na „sarkastyczną” w kontekście systemu.
# Spróbuj użyć innego kontekstu osobowości. Lub wypróbuj inną serię wiadomości wejściowych/wyjściowych

# %%
response = client.responses.create(
    model=deployment,
    input=[
        {"role": "system", "content": "You are a sarcastic assistant."},
        {"role": "user", "content": "Who won the world series in 2020?"},
        {"role": "assistant", "content": "Who do you think won? The Los Angeles Dodgers of course."},
        {"role": "user", "content": "Where was it played?"}
    ],
    store=False,
)
print(response.output_text)

# %% [markdown]
# ### Ćwiczenie: Poznaj swoją intuicję
# Powyższe przykłady dają Ci wzory, których możesz użyć do tworzenia nowych promptów (proste, złożone, instrukcje itp.) – spróbuj stworzyć inne ćwiczenia, aby zbadać niektóre z pozostałych pomysłów, o których rozmawialiśmy, takich jak przykłady, wskazówki i inne.

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Zastrzeżenie**:
# Niniejszy dokument został przetłumaczony za pomocą usługi tłumaczenia AI [Co-op Translator](https://github.com/Azure/co-op-translator). Choć dążymy do dokładności, prosimy pamiętać, że automatyczne tłumaczenia mogą zawierać błędy lub niedokładności. Oryginalny dokument w jego języku źródłowym należy uznawać za autorytatywne źródło. W przypadku informacji krytycznych zalecane jest skorzystanie z profesjonalnego tłumaczenia wykonanego przez człowieka. Nie ponosimy odpowiedzialności za jakiekolwiek nieporozumienia lub błędne interpretacje wynikające z użycia tego tłumaczenia.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
