# %% [markdown]
# Daftari lifuatalo lilizalishwa moja kwa moja na GitHub Copilot Chat na limetengenezwa kwa ajili ya usanidi wa awali pekee

# %% [markdown]
# # Utangulizi kwa Uhandisi wa Amri
# Uhandisi wa amri ni mchakato wa kubuni na kuboresha amri kwa kazi za usindikaji wa lugha asilia. Inahusisha kuchagua amri sahihi, kurekebisha vigezo vyake, na kutathmini utendaji wake. Uhandisi wa amri ni muhimu kwa kufikia usahihi mkubwa na ufanisi katika mifano ya NLP. Katika sehemu hii, tutachunguza misingi ya uhandisi wa amri kwa kutumia mifano ya OpenAI kwa ajili ya uchunguzi.

# %% [markdown]
# ### Zozo la 1: Ukitishaji
# Chunguza Ukitishaji ukitumia tiktoken, kidokezo cha haraka kinachopatikana wazi kutoka OpenAI
# Tazama [OpenAI Cookbook](https://github.com/openai/openai-cookbook/blob/main/examples/How_to_count_tokens_with_tiktoken.ipynb?WT.mc_id=academic-105485-koreyst) kwa mifano zaidi.

# %%
# EXERCISE:
# 1. Run the exercise as is first
# 2. Change the text to any prompt input you want to use & re-run to see tokens

import tiktoken

# Define the prompt you want tokenized
text = f"""
Jupiter is the fifth planet from the Sun and the \
largest in the Solar System. It is a gas giant with \
a mass one-thousandth that of the Sun, but two-and-a-half \
times that of all the other planets in the Solar System combined. \
Jupiter is one of the brightest objects visible to the naked eye \
in the night sky, and has been known to ancient civilizations since \
before recorded history. It is named after the Roman god Jupiter.[19] \
When viewed from Earth, Jupiter can be bright enough for its reflected \
light to cast visible shadows,[20] and is on average the third-brightest \
natural object in the night sky after the Moon and Venus.
"""

# Set the model you want encoding for
encoding = tiktoken.encoding_for_model("gpt-4o")

# Encode the text - gives you the tokens in integer form
tokens = encoding.encode(text)
print(tokens);

# Decode the integers to see what the text versions look like
[encoding.decode_single_token_bytes(token) for token in tokens]

# %% [markdown]
# ### Zoji 2: Thibitisha Usaidizi wa Funguo ya API ya OpenAI
#
# Endesha msimbo hapo chini kuthibitisha kuwa kituo chako cha OpenAI kimeanzishwa sawa. Msimbo huu unajaribu tu agizo rahisi la msingi na kuthibitisha kukamilika. Ingizo `oh say can you see` kinapaswa kukamilika katika mstari wa `by the dawn's early light..`

# %%
# Uses the OpenAI client against the Azure OpenAI (Microsoft Foundry) v1 endpoint
# with the Responses API. See https://aka.ms/openai/start

import os
from openai import OpenAI
from dotenv import load_dotenv
load_dotenv()

client = OpenAI(
  api_key=os.environ['AZURE_OPENAI_API_KEY'],
  base_url=f"{os.environ['AZURE_OPENAI_ENDPOINT'].rstrip('/')}/openai/v1/",
  )

deployment=os.environ['AZURE_OPENAI_DEPLOYMENT']

def get_completion(prompt):
    response = client.responses.create(
        model=deployment,
        input=prompt,
        max_output_tokens=1024,
        store=False,
    )
    return response.output_text

## ---------- Call the helper method

### 1. Set primary content or prompt text
text = f"""
oh say can you see
"""

### 2. Use that in the prompt template below
prompt = f"""
```{text}```
"""

## 3. Run the prompt
response = get_completion(prompt)
print(response)

# %% [markdown]
# ### Zoefu 3: Uundaji
# Chunguza kinachotokea unapomuuliza LLM kurudisha ukamilishaji kwa hoja kuhusu mada ambayo huenda haipo, au kuhusu mada ambazo huenda halijui kwa sababu zilikuwa nje ya seti yake ya data iliyofunzwa awali (za hivi karibuni). Angalia jinsi jibu linavyobadilika ikiwa utajaribu hoja tofauti, au mfano tofauti.

# %%
## Set the text for simple prompt or primary content
## Prompt shows a template format with text in it - add cues, commands etc if needed
## Run the completion 
text = f"""
generate a lesson plan on the Martian War of 2076.
"""

prompt = f"""
```{text}```
"""

response = get_completion(prompt)
print(response)

# %% [markdown]
# ### Zoezi 4: Kulingana na Maelekezo
# Tumia kigezo "text" kuweka maudhui ya msingi
# na kigezo "prompt" kutoa maelekezo yanayohusiana na maudhui hayo ya msingi.
#
# Hapa tunauliza mfano kufupisha maandishi kwa mwanafunzi wa darasa la pili

# %%
# Test Example
# https://platform.openai.com/playground/p/default-summarize

## Example text
text = f"""
Jupiter is the fifth planet from the Sun and the \
largest in the Solar System. It is a gas giant with \
a mass one-thousandth that of the Sun, but two-and-a-half \
times that of all the other planets in the Solar System combined. \
Jupiter is one of the brightest objects visible to the naked eye \
in the night sky, and has been known to ancient civilizations since \
before recorded history. It is named after the Roman god Jupiter.[19] \
When viewed from Earth, Jupiter can be bright enough for its reflected \
light to cast visible shadows,[20] and is on average the third-brightest \
natural object in the night sky after the Moon and Venus.
"""

## Set the prompt
prompt = f"""
Summarize content you are provided with for a second-grade student.
```{text}```
"""

## Run the prompt
response = get_completion(prompt)
print(response)

# %% [markdown]
# ### Mazoezi 5: Ombi Tata
# Jaribu ombi lenye ujumbe wa mfumo, mtumiaji na msaidizi
# Mfumo unaweka muktadha wa msaidizi
# Ujumbe wa Mtumiaji & Msaidizi hutoa muktadha wa mazungumzo ya mizunguko mingi
#
# Angalia jinsi tabia ya msaidizi imewekwa kuwa "udhalimu" katika muktadha wa mfumo.
# Jaribu kutumia muktadha tofauti wa tabia. Au jaribu mfululizo tofauti wa ujumbe wa ingizo/maingizo

# %%
response = client.responses.create(
    model=deployment,
    input=[
        {"role": "system", "content": "You are a sarcastic assistant."},
        {"role": "user", "content": "Who won the world series in 2020?"},
        {"role": "assistant", "content": "Who do you think won? The Los Angeles Dodgers of course."},
        {"role": "user", "content": "Where was it played?"}
    ],
    store=False,
)
print(response.output_text)

# %% [markdown]
# ### Mazoezi: Chunguza Hisia Zako za Ndani
# Mifano hapo juu inakupa mifumo ambayo unaweza kutumia kuunda maelekezo mapya (rahisi, changamano, maelekezo n.k.) - jaribu kuunda mazoezi mengine kuchunguza baadhi ya mawazo mengine tuliyozungumzia kama vile mifano, ishara na zaidi.

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Kionyozo**:
# Hati hii imetafsiriwa kwa kutumia huduma ya tafsiri ya AI [Co-op Translator](https://github.com/Azure/co-op-translator). Ingawa tunajitahidi kupata usahihi, tafadhali fahamu kwamba tafsiri za kiotomatiki zinaweza kuwa na makosa au upungufu wa usahihi. Hati ya asili katika lugha yake halisi inapaswa kuchukuliwa kama chanzo cha mamlaka. Kwa taarifa muhimu, tafsiri ya kitaalamu inayofanywa na binadamu inapendekezwa. Hatutojibu kwa kuelewa vibaya au tafsiri potofu zinazotokea kutokana na matumizi ya tafsiri hii.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
