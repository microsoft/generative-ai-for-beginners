# %% [markdown]
# # Sura ya 7: Kujenga Programu za Mazungumzo
# ## Mwanzo wa Haraka wa API ya OpenAI
#
# Daftari hii imetengenezwa kutoka kwenye [Hazina ya Sampuli za Azure OpenAI](https://github.com/Azure/azure-openai-samples?WT.mc_id=academic-105485-koreyst) ambayo inajumuisha daftari zinazopata huduma za [Azure OpenAI](notebook-azure-openai.ipynb).
#
# API ya Python ya OpenAI pia hufanya kazi na Modeli za Azure OpenAI, kwa mabadiliko machache. Jifunze zaidi kuhusu tofauti hapa: [Jinsi ya kubadilisha kati ya OpenAI na Azure OpenAI endpoints kwa Python](https://learn.microsoft.com/azure/ai-services/openai/how-to/switching-endpoints?WT.mc_id=academic-109527-jasmineg)

# %% [markdown]
# # Muhtasari
# "Mifumo mikubwa ya lugha ni kazi zinazobadilisha maandishi kuwa maandishi. Ikiwa na mfuatiliaji wa maandishi kama ingizo, mfumo mkubwa wa lugha hujaribu kutabiri maandishi yatakayofuata"(1). Daftari hili la "kuanza haraka" litaanzisha watumiaji kwa dhana za juu za LLM, mahitaji ya kifurushi cha msingi kwa kuanza na AML, utangulizi mpole wa muundo wa prompt, na mifano kadhaa fupi ya matumizi tofauti.

# %% [markdown]
# ## Jedwali la Yaliyomo
#
# [Muhtasari](#overview)
# [Jinsi ya kutumia Huduma ya OpenAI](#how-to-use-openai-service)
# [1. Kuunda Huduma yako ya OpenAI](#1.-creating-your-openai-service)
# [2. Ufungaji](#2.-installation)
# [3. Vyeti](#3.-credentials)
#
# [Matumizi](#use-cases)
# [1. Fupisha Maandishi](#1.-summarize-text)
# [2. Panga Maandishi](#2.-classify-text)
# [3. Tengeneza Majina Mapya ya Bidhaa](#3.-generate-new-product-names)
# [4. Boresha Kipangaji](#4.fine-tune-a-classifier)
#
# [Marejeleo](#references)

# %% [markdown]
# ### Jenga ombi lako la kwanza
# Mazoezi haya mafupi yatatoa utangulizi wa msingi wa kuwasilisha maombi kwa mfano wa OpenAI kwa kazi rahisi ya "muhtasari".
#
#
# **Hatua**:
# 1. Sakinisha maktaba ya OpenAI katika mazingira yako ya python
# 2. Pakia maktaba za msaada za kawaida na weka cheti chako cha usalama cha OpenAI kwa Huduma ya OpenAI ambayo umeunda
# 3. Chagua mfano kwa ajili ya kazi yako
# 4. Tengeneza ombi rahisi kwa mfano
# 5. Wasilisha ombi lako kwa API ya mfano!

# %% [markdown]
# ### 1. Sakinisha OpenAI

# %%
# %pip install openai python-dotenv

# %% [markdown]
# ### 2. Ingiza maktaba za msaada na tengeneza leseni

# %%
import os
from openai import OpenAI
from dotenv import load_dotenv

load_dotenv()

API_KEY = os.getenv("OPENAI_API_KEY","")
assert API_KEY, "ERROR: OpenAI Key is missing"

client = OpenAI(
    api_key=API_KEY
    )

# %% [markdown]
# ### 3. Kupata mfano sahihi
# Miundo kama GPT-4o na GPT-4o mini zinaweza kuelewa na kuzalisha lugha ya asili, na zinapatikana kwenye jukwaa la OpenAI kwa viwango tofauti vya nguvu na kasi vinavyofaa kwa kazi mbalimbali.

# %%
# Select a general purpose chat model
model = "gpt-4o-mini"

# %% [markdown]
# ## 4. Ubunifu wa Mwitikio
#
# "Siri ya mifano mikubwa ya lugha ni kwamba kwa kufunzwa kupunguza hitilafu hii ya utabiri juu ya maandishi mengi sana, mifano husoma dhana zinazotumika kwa ajili ya utabiri huu. Kwa mfano, hujifunza dhana kama"(1):
#
# * jinsi ya stavisha
# * jinsi sarufi inavyofanya kazi
# * jinsi ya kubadilisha maneno (paraphrase)
# * jinsi ya kujibu maswali
# * jinsi ya kuendesha mazungumzo
# * jinsi ya kuandika katika lugha nyingi
# * jinsi ya kuandika nambari za kompyuta (code)
# * n.k.
#
# #### Jinsi ya kudhibiti mfano mkubwa wa lugha
# "Kutoka kwa ingizo zote katika mfano mkubwa wa lugha, kwa mbali kabisa kivutio kikubwa ni mwitikio wa maandishi(1).
#
# Mifano mikubwa ya lugha inaweza kupewa mwitikio kwa njia chache:
#
# Maagizo: Mwambie mfano unachotaka
# Umaliziaji: Himiza mfano kumalizia mwanzo wa kile unachotaka
# Maonyesho: Muwonye mfano unachotaka, kwa:
# Mifano michache ndani ya mwitikio
# Mamia au maelfu ya mifano katika seti ya data ya mafunzo ya urekebishaji"
#
#
#
# #### Kuna miongozo mitatu ya msingi ya kuunda mwitikio:
#
# **Onyesha na sema**. Fanya kuwa wazi unachotaka kupitia maagizo, mifano, au mchanganyiko wa yote mawili. Ikiwa unataka mfano kupanga orodha ya vitu kwa mpangilio wa alfabeti au kuainisha aya kwa hisia, mwonyeshe kuwa ndicho unachotaka.
#
# **Toa data bora**. Ukijaribu kujenga aina ya kupanga au kupata mfano kufuata muundo, hakikisha kuna mifano ya kutosha. Hakikisha kusoma mifano yako kwa makini — mfano kawaida huwa na akili ya kuona makosa ya stavisha ya msingi na kukupa jibu, lakini pia unaweza kudhani kuwa ni makusudi na inaweza kuathiri jibu.
#
# **Kagua mipangilio yako.** Joto na mipangilio ya top_p hudhibiti jinsi mfano unavyokuwa na uhakika katika kutoa jibu. Ikiwa unajiuliza jibu ni moja tu sahihi, basi ungependa kuweka hizi chini. Ikiwa unatafuta majibu yenye utofauti zaidi, basi ungependa kuweka juu. Kosa nambari moja watu hufanya na mipangilio hii ni kudhani kuwa ni udhibiti wa "werevu" au "ubunifu."
#
#
# Chanzo: https://learn.microsoft.com/azure/ai-services/openai/overview

# %% [markdown]
# ### 5. Tuma!

# %%
# Create your first prompt
text_prompt = "Should oxford commas always be used?"

response = client.responses.create(
  model=model,
  input = [{"role":"system", "content":"You are a helpful assistant."},
               {"role":"user","content":text_prompt},],
  store=False,)

response.output_text

# %% [markdown]
# ### Rudia wito ule ule, matokeo yanalinganishaje?

# %%
response = client.responses.create(
  model=model,
  input = [{"role":"system", "content":"You are a helpful assistant."},
               {"role":"user","content":text_prompt},],
  store=False,)

response.output_text

# %% [markdown]
# ## Fupisha Maandishi
# #### Changamoto
# Fupisha maandishi kwa kuongeza 'tl;dr:' mwishoni mwa kipande cha maandishi. Tambua jinsi mfano unavyofahamu jinsi ya kufanya majukumu kadhaa bila maagizo ya ziada. Unaweza kujaribu maelekezo ya kina zaidi kuliko tl;dr kubadilisha tabia ya mfano na kubinafsisha muhtasari unaoupata(3).
#
# Kazi za hivi karibuni zimeonyesha mafanikio makubwa katika kazi nyingi za NLP na viwango vya rufaa kwa mafunzo ya awali kwenye mkusanyiko mkubwa wa maandishi ikifuatiwa na ufundishaji maalum kwa kazi fulani. Ingawa kawaida muundo haujali kazi fulani, njia hii bado inahitaji seti za data za ufundishaji maalum za kazi zenye maelfu au maelfu kumi ya mifano. Kwa upande mwingine, binadamu kwa ujumla wanaweza kufanya kazi mpya ya lugha kwa kutumia mifano michache tu au maagizo rahisi - jambo ambalo mifumo ya NLP ya sasa bado inakumbwa na tatizo kubwa la kufanya. Hapa tunaonyesha kuwa kuongeza ukubwa wa mifano ya lugha huboresha sana utendakazi wa kidogo-kipimo usioguswa na kazi, wakati mwingine hiki kinapofikia ushindani na mbinu za ufundishaji maalum za hali ya juu zilizopita.
#
#
#
# Tl;dr

# %% [markdown]
# # Mazoezi kwa matumizi mbalimbali
# 1. Fupisha Maandishi
# 2. Panga Maandishi
# 3. Tengeneza Majina Mapya ya Bidhaa

# %%
prompt = "Recent work has demonstrated substantial gains on many NLP tasks and benchmarks by pre-training on a large corpus of text followed by fine-tuning on a specific task. While typically task-agnostic in architecture, this method still requires task-specific fine-tuning datasets of thousands or tens of thousands of examples. By contrast, humans can generally perform a new language task from only a few examples or from simple instructions - something that current NLP systems still largely struggle to do. Here we show that scaling up language models greatly improves task-agnostic, few-shot performance, sometimes even reaching competitiveness with prior state-of-the-art fine-tuning approaches.\n\nTl;dr"

# %%
#Setting a few additional, typical parameters during API Call

response = client.responses.create(
  model=model,
  input = [{"role":"system", "content":"You are a helpful assistant."},
               {"role":"user","content":prompt},],
  store=False,)

response.output_text

# %% [markdown]
# ## Flasha Maandishi
# #### Changamoto
# Flasha vitu katika makundi yaliyotolewa wakati wa uthibitisho. Katika mfano ufuatao, tunatoa makundi pamoja na maandishi ya kuflasha katika ombi (*playground_reference).
#
# Utafiti wa Mteja: Habari, moja ya funguo kwenye kibodi ya kompyuta yangu kibebea hivi karibuni na nitahitaji mbadala:
#
# Kundi lililoflashiwa:

# %%
prompt = "Classify the following inquiry into one of the following: categories: [Pricing, Hardware Support, Software Support]\n\ninquiry: Hello, one of the keys on my laptop keyboard broke recently and I'll need a replacement:\n\nClassified category:"
print(prompt)

# %%
#Setting a few additional, typical parameters during API Call

response = client.responses.create(
  model=model,
  input = [{"role":"system", "content":"You are a helpful assistant."},
               {"role":"user","content":prompt},],
  store=False,)

response.output_text

# %% [markdown]
# ## Tengeneza Majina Mpya ya Bidhaa
# #### Changamoto
# Tengeneza majina ya bidhaa kutoka kwa maneno ya mifano. Hapa tunajumuisha katika maagizo taarifa kuhusu bidhaa tunayotaka kutengeneza majina yake. Pia tunatoa mfano unaofanana kuonyesha muundo tunaotaka kupokea. Tumeweka thamani ya joto juu kuongeza bahati nasibu na majibu ya ubunifu zaidi.
#
# Maelezo ya bidhaa: Kifaa cha kutengenezea milkshake cha nyumbani
# Maneno ya msingi: haraka, kiafya, kidogo.
# Majina ya bidhaa: HomeShaker, Fit Shaker, QuickShake, Shake Maker
#
# Maelezo ya bidhaa: Viatu vinavyoweza kufaa kwa ukubwa wowote wa mguu.
# Maneno ya msingi: yanayobadilika, yanayofaa, omni-fit.

# %%
prompt = "Product description: A home milkshake maker\nSeed words: fast, healthy, compact.\nProduct names: HomeShaker, Fit Shaker, QuickShake, Shake Maker\n\nProduct description: A pair of shoes that can fit any foot size.\nSeed words: adaptable, fit, omni-fit."

print(prompt)

# %%
#Setting a few additional, typical parameters during API Call

response = client.responses.create(
  model=model,
  input = [{"role":"system", "content":"You are a helpful assistant."},
               {"role":"user","content":prompt}],
  store=False,)

response.output_text

# %% [markdown]
# # Marejeleo
# - [Kitabu cha Mapishi cha Openai](https://github.com/openai/openai-cookbook?WT.mc_id=academic-105485-koreyst)
# - [Lango la Microsoft Foundry](https://ai.azure.com?WT.mc_id=academic-105485-koreyst)
# - [Mila bora za kufinyanga modeli za GPT kwa ajili ya kuainisha maandishi](https://platform.openai.com/docs/guides/fine-tuning?WT.mc_id=academic-105485-koreyst)

# %% [markdown]
# # Kwa Msaada Zaidi
# [Timu ya Ukomesheni ya OpenAI](AzureOpenAITeam@microsoft.com)

# %% [markdown]
# # Wachangiaji
# * Louis Li

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Kionyozo**:
# Hati hii imetafsiriwa kwa kutumia huduma ya tafsiri ya AI [Co-op Translator](https://github.com/Azure/co-op-translator). Ingawa tunajitahidi kupata usahihi, tafadhali fahamu kwamba tafsiri za kiotomatiki zinaweza kuwa na makosa au upungufu wa usahihi. Hati ya asili katika lugha yake halisi inapaswa kuchukuliwa kama chanzo cha mamlaka. Kwa taarifa muhimu, tafsiri ya kitaalamu inayofanywa na binadamu inapendekezwa. Hatutojibu kwa kuelewa vibaya au tafsiri potofu zinazotokea kutokana na matumizi ya tafsiri hii.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
