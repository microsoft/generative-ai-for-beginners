# %% [markdown]
# # Sura ya 7: Kujenga Programu za Gumzo
# ## Anza Haraka na API ya OpenAI
#
# Kitabu hiki cha kumbukumbu kimebuniwa kutoka kwa [Azure OpenAI Samples Repository](https://github.com/Azure/azure-openai-samples?WT.mc_id=academic-105485-koreyst) ambacho kina vitabu vya kumbukumbu vinavyopata huduma za [Azure OpenAI](notebook-azure-openai.ipynb).
#
# API ya OpenAI kwa Python inafanya kazi pia na Modeli za Azure OpenAI, kwa marekebisho machache. Jifunze zaidi kuhusu tofauti hapa: [Jinsi ya kubadili kati ya OpenAI na Azure OpenAI endpoints kwa Python](https://learn.microsoft.com/azure/ai-foundry/openai/how-to/switching-endpoints?WT.mc_id=academic-109527-jasmineg)

# %% [markdown]
# # Muhtasari
# "Mifano mikubwa ya lugha ni kazi zinazotumia maandishi kuelekea maandishi. Ukipewa mfululizo wa maandishi kama ingizo, mfano mkubwa wa lugha hujaribu kutabiri maandishi yatakayofuata"(1). Daftari hili la "kuanza haraka" litaanzisha watumiaji kwa dhana za juu za LLM, mahitaji muhimu ya kifurushi cha kuanza na AML, utangulizi laini kwa usanifu wa maelekezo, na mifano kadhaa fupi ya matumizi mbalimbali.

# %% [markdown]
# ## Jedwali la Yaliyomo
#
# [Muhtasari](#overview)
# [Jinsi ya kutumia Huduma ya OpenAI](#how-to-use-openai-service)
# [1. Kuunda Huduma yako ya OpenAI](#1.-creating-your-openai-service)
# [2. Ufungaji](#2.-installation)
# [3. Vyeti](#3.-credentials)
#
# [Matumizi](#use-cases)
# [1. Fupisha Maandishi](#1.-summarize-text)
# [2. Panga Maandishi Kiwango](#2.-classify-text)
# [3. Tengeneza Majina Mapya ya Bidhaa](#3.-generate-new-product-names)
# [4. Boresha Kipimo cha Uainishaji](#4.fine-tune-a-classifier)
#
# [Marejeleo](#references)

# %% [markdown]
# ### Jenga ombi lako la kwanza
# Zoebisho hili fupi litatia moyo msingi wa kuwasilisha maombi kwa mfano wa OpenAI kwa kazi rahisi ya "muhtasari".
#
#
# **Hatua**:
# 1. Sanidi maktaba ya OpenAI katika mazingira yako ya python
# 2. Pakia maktaba za msaada za kawaida na weka nyaraka zako za usalama za kawaida kwa Huduma ya OpenAI uliyotengeneza
# 3. Chagua mfano kwa ajili ya kazi yako
# 4. Unda ombi rahisi kwa mfano
# 5. Wasilisha ombi lako kwa API ya mfano!

# %% [markdown]
# ### 1. Sakinisha OpenAI

# %%
# %pip install openai python-dotenv

# %% [markdown]
# ### 2. Ingiza maktaba za msaada na unda vyeti vya ufikiaji

# %%
import os
from openai import OpenAI
from dotenv import load_dotenv

load_dotenv()

API_KEY = os.getenv("OPENAI_API_KEY","")
assert API_KEY, "ERROR: OpenAI Key is missing"

client = OpenAI(
    api_key=API_KEY
    )

# %% [markdown]
# ### 3. Kupata mfano sahihi
# Mifano kama GPT-4o na GPT-4o mini wanaweza kuelewa na kuzalisha lugha ya asili, na inapatikana kwenye jukwaa la OpenAI kwa viwango tofauti vya nguvu na kasi vinavyofaa kwa kazi tofauti.

# %%
# Select a general purpose chat model
model = "gpt-5-mini"

# %% [markdown]
# ## 4. Ubunifu wa Maagizo
#
# "Macho ya miundo mikubwa ya lugha ni kwamba kwa kufunzwa kupunguza kosa hili la utabiri juu ya kiasi kikubwa cha maandishi, miundo hujifunza dhana zinazofaa kwa ajili ya utabiri huu. Kwa mfano, hujifunza dhana kama"(1):
#
# * jinsi ya kuandika kwa herufi sahihi
# * jinsi sarufi inavyofanya kazi
# * jinsi ya kufasiri kwa maneno mengine
# * jinsi ya kujibu maswali
# * jinsi ya kuendesha mazungumzo
# * jinsi ya kuandika kwa lugha nyingi
# * jinsi ya kuandika msimbo
# * n.k.
#
# #### Jinsi ya kudhibiti mfano mkubwa wa lugha
# "Kati ya pembejeo zote kwa mfano mkubwa wa lugha, kwa mbali sehemu yenye ushawishi mkubwa zaidi ni maagizo ya maandishi(1).
#
# Mifano mikubwa ya lugha inaweza kuamshwa kutoa matokeo kwa njia chache:
#
# Maagizo: Waambie mfano unachotaka
# Ukomeshaji: Shinikiza mfano kumalizia mwanzo wa unachotaka
# Onyesho: Mwonyeshe mfano unachotaka, kwa:
# Mfano kadhaa ndani ya agizo
# Mamia au maelfu ya mifano katika seti ya mafunzo ya kufinya tena"
#
#
#
# #### Kuna miongozo mitatu ya msingi ya kuunda maagizo:
#
# **Onyesha na eleza**. Fanya iwe wazi unachotaka kupitia maagizo, mifano, au mchanganyiko wa yote mawili. Ikiwa unataka mfano upange orodha ya vitu kwa mpangilio wa alfabeti au kuainisha aya kwa hisia, muuoneshe ni hayo unayotaka.
#
# **Toa data bora**. Ikiwa unajaribu kujenga kigezo au kumfanya mfano afuate muundo, hakikisha kuna mifano ya kutosha. Hakikisha kuhariri mifano yako — mfano kwa kawaida ni smart ya kutosha kuona makosa ya tahajia ya msingi na kukupa jibu, lakini pia inaweza kudhani hili ni makusudi na inaweza kuathiri jibu.
#
# **Kagua mipangilio yako.** Mipangilio ya joto (temperature) na top_p hudhibiti jinsi mfano anavyokuwa na utabiriki katika kutoa jibu. Ikiwa unamwomba jibu ambapo kuna jibu moja tu sahihi, basi ungependa kuweka mipangilio hii chini. Ikiwa unatafuta majibu yenye utofauti zaidi, basi ungependa kuiweka juu. Kosa nambari moja watu hufanya na mipangilio hii ni kudhani kwamba ni udhibiti wa "werevu" au "ubunifu".
#
#
# Chanzo: https://learn.microsoft.com/azure/ai-foundry/openai/overview

# %% [markdown]
# ### 5. Wasilisha!

# %%
# Create your first prompt
text_prompt = "Should oxford commas always be used?"

response = client.responses.create(
  model=model,
  input = [{"role":"system", "content":"You are a helpful assistant."},
               {"role":"user","content":text_prompt},],
  store=False,)

response.output_text

# %% [markdown]
# ### Rudia wito ule ule, matokeo yanalinganishwaje?

# %%
response = client.responses.create(
  model=model,
  input = [{"role":"system", "content":"You are a helpful assistant."},
               {"role":"user","content":text_prompt},],
  store=False,)

response.output_text

# %% [markdown]
# ## Fupisha Maandishi
# #### Changamoto
# Fupisha maandishi kwa kuongeza 'tl;dr:' mwishoni mwa kipande cha maandishi. Angalia jinsi mfano unavyoelewa jinsi ya kufanya kazi nyingi bila maagizo ya ziada. Unaweza kujaribu maagizo yenye maelezo zaidi kuliko tl;dr kubadilisha tabia ya mfano na kubinafsisha muhtasari unaoupata(3).
#
# Kazi za hivi karibuni zimeonyesha ongezeko kubwa katika kazi na viwango vya NLP kwa mafunzo ya awali kwenye mkusanyiko mkubwa wa maandishi ikifuatiwa na urekebishaji maalum wa kazi. Ingawa mara nyingi usanifu hauzingatii kazi, njia hii bado inahitaji seti za data za mafunzo maalum za maelfu au kumi ya maelfu ya mifano. Kwa upande mwingine, watu kwa kawaida wanaweza kufanya kazi mpya ya lugha kutoka kwa mifano michache au kutoka kwa maagizo rahisi - jambo ambalo mifumo ya sasa ya NLP bado inapata ugumu mkubwa kufanya. Hapa tunaonyesha kuwa kuongeza ukubwa wa modeli za lugha kunaboreshwa kwa kiasi kikubwa utendaji wa kazi zisizo za kazi, kwa mifano michache, wakati mwingine hata kufikia ushindani na mbinu za urekebishaji za hali ya juu zilizotangulia.
#
#
#
# Tl;dr

# %% [markdown]
# # Mazoezi kwa matumizi kadhaa
# 1. Fupisha Maandishi
# 2. Panga Maandishi
# 3. Tengeneza Majina Mapya ya Bidhaa

# %%
prompt = "Recent work has demonstrated substantial gains on many NLP tasks and benchmarks by pre-training on a large corpus of text followed by fine-tuning on a specific task. While typically task-agnostic in architecture, this method still requires task-specific fine-tuning datasets of thousands or tens of thousands of examples. By contrast, humans can generally perform a new language task from only a few examples or from simple instructions - something that current NLP systems still largely struggle to do. Here we show that scaling up language models greatly improves task-agnostic, few-shot performance, sometimes even reaching competitiveness with prior state-of-the-art fine-tuning approaches.\n\nTl;dr"

# %%
#Setting a few additional, typical parameters during API Call

response = client.responses.create(
  model=model,
  input = [{"role":"system", "content":"You are a helpful assistant."},
               {"role":"user","content":prompt},],
  store=False,)

response.output_text

# %% [markdown]
# ## Panga Maandishi
# #### Changamoto
# Pangilia vitu katika makundi yaliyotolewa wakati wa ugunduzi. Katika mfano ufuatao, tunatoa makundi pamoja na maandishi ya kupangilia kwenye tahadhari (*playground_reference).
#
# Ujumbe wa Mteja: Hujambo, moja ya funguo kwenye kibodi ya kompyuta yangu ya mkononi imevunjika hivi karibuni na nitahitaji mbadala:
#
# Kundi lililogawanywa:

# %%
prompt = "Classify the following inquiry into one of the following: categories: [Pricing, Hardware Support, Software Support]\n\ninquiry: Hello, one of the keys on my laptop keyboard broke recently and I'll need a replacement:\n\nClassified category:"
print(prompt)

# %%
#Setting a few additional, typical parameters during API Call

response = client.responses.create(
  model=model,
  input = [{"role":"system", "content":"You are a helpful assistant."},
               {"role":"user","content":prompt},],
  store=False,)

response.output_text

# %% [markdown]
# ## Tengenezaji Majina Mapya ya Bidhaa
# #### Changamoto
# Tengeneza majina ya bidhaa kutoka kwa maneno ya mifano. Hapa tunajumuisha katika maelezo habari kuhusu bidhaa tunayotaka kutengeneza majina yake. Pia tunatoa mfano unaofanana kuonyesha muundo tunayotaka kupokea. Pia tumeweka thamani ya joto kuwa juu ili kuongeza mseto na majibu ya ubunifu zaidi.
#
# Maelezo ya bidhaa: Mtengenezaji wa mchanganyiko wa maziwa wa nyumbani
# Maneno ya msingi: haraka, afya, kompakt
# Majina ya bidhaa: HomeShaker, Fit Shaker, QuickShake, Shake Maker
#
# Maelezo ya bidhaa: Viatu vinavyoweza kufaa kwa ukubwa wowote wa mguu.
# Maneno ya msingi: kubadilika, kufaa, omni-fit.

# %%
prompt = "Product description: A home milkshake maker\nSeed words: fast, healthy, compact.\nProduct names: HomeShaker, Fit Shaker, QuickShake, Shake Maker\n\nProduct description: A pair of shoes that can fit any foot size.\nSeed words: adaptable, fit, omni-fit."

print(prompt)

# %%
#Setting a few additional, typical parameters during API Call

response = client.responses.create(
  model=model,
  input = [{"role":"system", "content":"You are a helpful assistant."},
               {"role":"user","content":prompt}],
  store=False,)

response.output_text

# %% [markdown]
# # Marejeleo
# - [Openai Cookbook](https://github.com/openai/openai-cookbook?WT.mc_id=academic-105485-koreyst)
# - [Microsoft Foundry portal](https://ai.azure.com?WT.mc_id=academic-105485-koreyst)
# - [Mazoezi bora ya kurekebisha modeli za GPT kwa ajili ya kutambua maandishi](https://platform.openai.com/docs/guides/fine-tuning?WT.mc_id=academic-105485-koreyst)

# %% [markdown]
# # Kwa Msaada Zaidi
# [Timu ya Uuzaji ya OpenAI](AzureOpenAITeam@microsoft.com)

# %% [markdown]
# # Wachangiaji
# * Louis Li

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Kionyozo**:
# Hati hii imetafsiriwa kwa kutumia huduma ya tafsiri ya AI [Co-op Translator](https://github.com/Azure/co-op-translator). Ingawa tunajitahidi kupata usahihi, tafadhali fahamu kwamba tafsiri za kiotomatiki zinaweza kuwa na makosa au upungufu wa usahihi. Hati ya asili katika lugha yake halisi inapaswa kuchukuliwa kama chanzo cha mamlaka. Kwa taarifa muhimu, tafsiri ya kitaalamu inayofanywa na binadamu inapendekezwa. Hatutojibu kwa kuelewa vibaya au tafsiri potofu zinazotokea kutokana na matumizi ya tafsiri hii.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
