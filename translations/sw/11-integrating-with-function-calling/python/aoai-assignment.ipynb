# %% [markdown]
# ## Utangulizi
#
# Somo hili litajumuisha:
# - Nini maana ya kuita kazi na matumizi yake
# - Jinsi ya kuunda wito wa kazi kwa kutumia Azure OpenAI
# - Jinsi ya kuingiza wito wa kazi katika programu
#
# ## Malengo ya Kujifunza
#
# Baada ya kumaliza somo hili utajua jinsi ya na kuelewa:
#
# - Kusudi la kutumia wito wa kazi
# - Kutayarisha Wito wa Kazi kwa kutumia Huduma ya Azure Open AI
# - Kubuni wito wa kazi wenye ufanisi kwa matumizi ya programu zako

# %% [markdown]
# ## Kuelewa Miito ya Kazi
#
# Kwa somo hili, tunataka kujenga kipengele kwa ajili ya kampuni yetu ya elimu kinachowawezesha watumiaji kutumia chatbot kutafuta kozi za kiufundi. Tutapendekeza kozi zinazolingana na kiwango chao cha ujuzi, nafasi yao ya sasa na teknolojia wanayopenda.
#
# Ili kumaliza hili tutatumia mchanganyiko wa:
#  - `Azure Open AI` kuunda uzoefu wa mazungumzo kwa mtumiaji
#  - `Microsoft Learn Catalog API` kuwasaidia watumiaji kupata kozi kulingana na ombi la mtumiaji
#  - `Function Calling` kuchukua swali la mtumiaji na kulituma kwa kazi kufanya ombi la API.
#
# Ili kuanza, tutaangalia kwa nini tungependa kutumia miito ya kazi hapo mwanzo:

# %% [markdown]
# ### Kwa Nini Kupiga Kazi
#
# Ikiwa umemaliza somo lolote katika kozi hii, huenda unaelewa nguvu ya kutumia Mifano Mikubwa ya Lugha (LLMs). Tunatumai pia unaweza kuona baadhi ya vikwazo vyake pia.
#
# Kupiga Kazi ni kipengele cha Huduma ya Azure Open AI kushinda vikwazo vifuatavyo:
# 1) Muundo thabiti wa jibu
# 2) Uwezo wa kutumia data kutoka vyanzo vingine vya programu katika muktadha wa mazungumzo
#
# Kabla ya kupiga kazi, majibu kutoka kwa LLM yalikuwa yasiyo na muundo na hayakuwa thabiti. Waendelezaji walilazimika kuandika nambari ngumu za uthibitishaji kuhakikisha wanaweza kushughulikia kila tofauti ya jibu.
#
# Watumiaji hawakuweza kupata majibu kama "Hali ya hewa ya sasa jijini Stockholm ni nini?". Hii ni kwa sababu mifano ilikuwa na kikomo kwa wakati data ilipofundishwa.
#
# Tuchukulie mfano hapa chini unaoonyesha tatizo hili:
#
# Tuseme tunataka kuunda hifadhidata ya data za wanafunzi ili tuweze kupendekeza kozi sahihi kwao. Hapa chini tuna maelezo mawili ya wanafunzi yanayofanana sana katika data wanayo nayo.

# %%
student_1_description="Emily Johnson is a sophomore majoring in computer science at Duke University. She has a 3.7 GPA. Emily is an active member of the university's Chess Club and Debate Team. She hopes to pursue a career in software engineering after graduating."
 
student_2_description = "Michael Lee is a sophomore majoring in computer science at Stanford University. He has a 3.8 GPA. Michael is known for his programming skills and is an active member of the university's Robotics Club. He hopes to pursue a career in artificial intelligence after finishing his studies."

# %% [markdown]
# Tunataka kutuma hii kwa LLM ili kuchambua data. Hii baadaye inaweza kutumika katika programu yetu kutuma hii kwa API au kuihifadhi katika hifadhidata.
#
# Hebu tengeneze maelekezo mawili yaliyofanana ambayo tutamwelekeza LLM juu ya taarifa ambayo tunavutiwa nayo:

# %% [markdown]
# Tunataka kutuma hii kwa LLM ili kuchambua sehemu muhimu kwa bidhaa yetu. Hivyo tunaweza kuunda maagizo mawili sawa kumwelekeza LLM:

# %%
prompt1 = f'''
Please extract the following information from the given text and return it as a JSON object:

name
major
school
grades
club

This is the body of text to extract the information from:
{student_1_description}
'''


prompt2 = f'''
Please extract the following information from the given text and return it as a JSON object:

name
major
school
grades
club

This is the body of text to extract the information from:
{student_2_description}
'''

# %% [markdown]
# Baada ya kuunda vihimizo hivi viwili, tutavituma kwa LLM kwa kutumia `client.responses.create`. Tunahifadhi kihimizo katika kigezo `input` na kuipa jukumu la `user`. Hii ni kuiga ujumbe kutoka kwa mtumiaji unaoandikwa kwa chatbot.

# %%
import os
import json
from openai import OpenAI
from dotenv import load_dotenv
load_dotenv()

# The OpenAI client points at the Azure OpenAI (Microsoft Foundry) /openai/v1/ endpoint
client = OpenAI(
  api_key=os.environ['AZURE_OPENAI_API_KEY'],
  base_url=f"{os.environ['AZURE_OPENAI_ENDPOINT'].rstrip('/')}/openai/v1/",
  )

deployment=os.environ['AZURE_OPENAI_DEPLOYMENT']
# Out:
# Running cells with '/opt/homebrew/bin/python3' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# Sasa tunaweza kutuma maombi yote mawili kwa LLM na kuchunguza jibu tunalopokea.

# %%
openai_response1 = client.responses.create(
 model=deployment,    
 input = [{'role': 'user', 'content': prompt1}],
 store=False,
)
openai_response1.output_text

# %%
openai_response2 = client.responses.create(
 model=deployment,    
 input = [{'role': 'user', 'content': prompt2}],
 store=False,
)
openai_response2.output_text

# %%
# Loading the response as a JSON object
json_response1 = json.loads(openai_response1.output_text)
json_response1

# %%
# Loading the response as a JSON object
json_response2 = json.loads(openai_response2.output_text)
json_response2

# %% [markdown]
# Ingawa maagizo ni yale yale na maelezo ni yanayofanana, tunaweza kupata miundo tofauti ya mali ya `Grades`.
#
# Ikiwa utaendesha seli iliyo hapo juu mara nyingi, muundo unaweza kuwa `3.7` au `3.7 GPA`.
#
# Hii ni kwa sababu LLM hupokea data isiyo na muundo katika fomu ya agizo lililoandikwa na hurudisha pia data isiyo na muundo. Tunahitaji kuwa na muundo uliopangwa ili tuweze kujua nini cha kutarajia tunapohifadhi au kutumia data hii.
#
# Kwa kutumia upigaji simu wa kazi, tunaweza kuhakikisha tunapokea data zilizopangwa kurudi. Tunapotumia upigaji simu wa kazi, LLM halifanyi kwa kweli kupiga simu au kuendesha kazi zozote. Badala yake, tunaunda muundo ambao LLM itafuata kwa majibu yake. Kisha tunatumia majibu hayo yaliyo na muundo kujua kazi gani yaendeshe katika programu zetu.

# %% [markdown]
# ![Mchoro wa Mtiririko wa Kuitwa kwa Kazi](../../../../translated_images/sw/Function-Flow.083875364af4f4bb.webp)

# %% [markdown]
# Kisha tunaweza kuchukua kile kinachorejeshwa kutoka kwa kazi na kurudisha hii kwa LLM. LLM kisha itajibu kwa kutumia lugha ya asili kujibu swali la mtumiaji.

# %% [markdown]
# ### Matumizi ya Kupiga Simu za Kazi
#
# **Kupigia Simu Vifaa vya Nje**
# Chatbots ni nzuri kutoa majibu kwa maswali kutoka kwa watumiaji. Kwa kutumia kupiga simu za kazi, chatbots zinaweza kutumia jumbe kutoka kwa watumiaji kukamilisha baadhi ya kazi. Kwa mfano, mwanafunzi anaweza kumuomba chatbot "Tuma barua pepe kwa mwalimu wangu akisema nahitaji msaada zaidi na somo hili". Hii inaweza kufanya simu ya kazi ya `send_email(to: string, body: string)`
#
#
# **Kuunda Maswali ya API au Hifadhidata**
# Watumiaji wanaweza kupata taarifa kwa kutumia lugha ya asili ambayo hubadilishwa kuwa swali lililo pangwa au ombi la API. Mfano wa hii inaweza kuwa mwalimu anayemuomba "Nani ni wanafunzi waliomaliza kazi ya nyumbani ya mwisho" ambayo inaweza kupiga simu ya kazi inayoitwa `get_completed(student_name: string, assignment: int, current_status: string)`
#
#
# **Kuunda Data Iliyo Pangwa**
# Watumiaji wanaweza kuchukua kipande cha maandishi au CSV na kutumia LLM kutoa taarifa muhimu kutoka kwake. Kwa mfano, mwanafunzi anaweza kubadilisha makala ya Wikipedia kuhusu makubaliano ya amani kuunda kadi za kumbukumbu za AI. Hii inaweza kufanywa kwa kutumia kazi iitwayo `get_important_facts(agreement_name: string, date_signed: string, parties_involved: list)`

# %% [markdown]
# ## 2. Kutengeneza Simu Yako ya Kwanza ya Kifunctioni
#
# Mchakato wa kutengeneza simu ya kifunctioni unajumuisha hatua kuu 3:
# 1. Kupiga wito kwa API ya Kukamilisha Gumzo na orodha ya falsafa zako na ujumbe wa mtumiaji
# 2. Kusoma jibu la modeli ili kufanya kitendo yaani kutekeleza functioni au Wito wa API
# 3. Kufanya wito mwingine kwa API ya Kukamilisha Gumzo ukiwa na jibu kutoka kwa functioni yako ili kutumia taarifa hiyo kutengeneza jibu kwa mtumiaji.

# %% [markdown]
# ![Mtiririko wa Wito wa Kazi](../../../../translated_images/sw/LLM-Flow.3285ed8caf4796d7.webp)

# %% [markdown]
# ### Vipengele vya mwito wa kazi
#
# #### Ingizo la Watumiaji
#
# Hatua ya kwanza ni kuunda ujumbe wa mtumiaji. Huu unaweza kugawanywa kwa nguvu kwa kuchukua thamani ya ingizo la maandishi au unaweza kuweka thamani hapa. Ikiwa huu ni mara yako ya kwanza kufanya kazi na Chat Completions API, tunahitaji kufafanua `role` na `content` ya ujumbe.
#
# `role` inaweza kuwa `system` (kutengeneza sheria), `assistant` (mfano) au `user` (mtumiaji wa mwisho). Kwa mwito wa kazi, tutaweka hii kama `user` na swali la mfano.

# %%
messages= [ {"role": "user", "content": "Find me a good course for a beginner student to learn Azure."} ]

# %% [markdown]
# ### Kuunda kazi.
#
# Ifuatayo tutajifunza jinsi ya kufafanua kazi na vigezo vya kazi hiyo. Tutatumia kazi moja tu hapa inayoitwa `search_courses` lakini unaweza kuunda kazi nyingi.
#
# **Muhimu** : Kazi hujumuishwa kwenye ujumbe wa mfumo kwa LLM na zitahesabiwa katika idadi ya tokens ulizonazo.

# %%
# The Responses API uses a flat tool format: name/description/parameters at the top level
functions = [
   {
      "type":"function",
      "name":"search_courses",
      "description":"Retrieves courses from the search index based on the parameters provided",
      "parameters":{
         "type":"object",
         "properties":{
            "role":{
               "type":"string",
               "description":"The role of the learner (i.e. developer, data scientist, student, etc.)"
            },
            "product":{
               "type":"string",
               "description":"The product that the lesson is covering (i.e. Azure, Power BI, etc.)"
            },
            "level":{
               "type":"string",
               "description":"The level of experience the learner has prior to taking the course (i.e. beginner, intermediate, advanced)"
            }
         },
         "required":[
            "role"
         ]
      }
   }
]

# %% [markdown]
# **Maelezo**
#
# `name` - Jina la kazi tunayotaka iitwe.
#
# `description` - Hii ni maelezo ya jinsi kazi inavyofanya kazi. Hapa ni muhimu kuwa maalum na wazi
#
# `parameters` - Orodha ya thamani na muundo unaotaka mfano uzalishe katika jibu lake
#
#
# `type` - Aina ya data ambayo mali zitahifadhiwa ndani yake
#
# `properties` - Orodha ya thamani maalum ambazo mfano utatumia kwa ajili ya jibu lake
#
#
# `name` - jina la mali ambayo mfano utatumia katika jibu lililopangwa
#
# `type` - Aina ya data ya mali hii
#
# `description` - Maelezo ya mali maalum
#
#
# **Hiari**
#
# `required` - mali muhimu kwa ajili ya kukamilisha wito wa kazi

# %% [markdown]
# ### Kufanya wito la kazi
# Baada ya kufafanua kazi, sasa tunahitaji kuiingiza katika wito kwa API ya Kukamilisha Chat. Tunafanya hivyo kwa kuongeza `functions` kwenye ombi. Katika kesi hii `functions=functions`.
#
# Pia kuna chaguo la kuweka `function_call` kuwa `auto`. Hii inamaanisha tutamruhusu LLM kuamua ni kazi gani inapaswa kuitwa kulingana na ujumbe wa mtumiaji badala ya kuiteua wenyewe.

# %%
response = client.responses.create(model=deployment, 
                                        input=messages,
                                        tools=functions, 
                                        tool_choice="auto",
                                        store=False) 

print(response.output)

# %% [markdown]
# Sasa tuchukulie jibu na tuone jinsi lilivyopangwa:
#
# {
#   "role": "msaidizi",
#   "function_call": {
#     "name": "search_courses",
#     "arguments": "{\n  \"role\": \"mwanafunzi\",\n  \"product\": \"Azure\",\n  \"level\": \"mwanzo\"\n}"
#   }
# }
#
# Unaweza kuona kuwa jina la kazi liliitwa na kutoka kwa ujumbe wa mtumiaji, LLM ilikuwa na uwezo wa kupata data inayofaa hoja za kazi hiyo.

# %% [markdown]
# ## 3.Kuunganisha Miito ya Kazi kwenye Programu.
#
#
# Baada ya kujaribu jibu lililopangwa kutoka LLM, sasa tunaweza kuingiza hii katika programu.
#
# ### Kusimamia mzunguko
#
# Ili kuingiza hii kwenye programu yetu, tuchukue hatua zifuatazo:
#
# Kwanza, tufanye simu kwa huduma za Open AI na kuhifadhi ujumbe katika kigezo kinachoitwa `response_message`.

# %%
# Extract the function call items from the response output
tool_calls = [item for item in response.output if item.type == "function_call"]

# %% [markdown]
# Sasa tutaelezea kazi ambayo itaitisha Microsoft Learn API kupata orodha ya kozi:

# %%
import requests

def search_courses(role, product, level):
    url = "https://learn.microsoft.com/api/catalog/"
    params = {
        "role": role,
        "product": product,
        "level": level
    }
    response = requests.get(url, params=params)
    modules = response.json()["modules"]
    results = []
    for module in modules[:5]:
        title = module["title"]
        url = module["url"]
        results.append({"title": title, "url": url})
    return str(results)

# %% [markdown]
# Kama desturi bora, kisha tutaona ikiwa mfano unataka kuita kazi. Baada ya hapo, tutaunda moja ya kazi zilizopo na kuihifadhi kwa kazi inayoitwa.
# Kisha tutachukua hoja za kazi na kuzipangilia kwa hoja kutoka kwa LLM.
#
# Mwishowe, tutaongeza ujumbe wa wito wa kazi na maadili yaliyorudishwa na ujumbe wa `search_courses`. Hii hutoa LLM taarifa zote zinazohitajika
# kujibu mtumiaji kwa kutumia lugha ya asili.

# %%
# Check if the model wants to call a function
if tool_calls:
    tool_call = tool_calls[0]
    print("Recommended Function call:")
    print(tool_call.name)
    print()

    # Call the function. 
    function_name = tool_call.name

    available_functions = {
            "search_courses": search_courses,
    }
    function_to_call = available_functions[function_name] 

    function_args = json.loads(tool_call.arguments)
    function_response = function_to_call(**function_args)

    print("Output of function call:")
    print(function_response)
    print(type(function_response))


    # Add the model's function call item(s) and our function result to the conversation.
    # The Responses API represents tool results as `function_call_output` items.
    messages.extend(response.output)  # adding the model's function_call item(s)
    messages.append( # adding function response to messages
        {
            "type": "function_call_output",
            "call_id": tool_call.call_id,
            "output": function_response,
        }
    )

# %% [markdown]
# Sasa tutatuma ujumbe uliosasishwa kwa LLM ili tuweze kupokea jibu la lugha ya asili badala ya jibu la API lililotengenezwa kwa muundo wa JSON.

# %%
print("Messages in next request:")
print(messages)
print()

second_response = client.responses.create(
    input=messages,
    model=deployment,
    tools=functions,
    tool_choice="auto",
    store=False,
        )  # get a new response from the model where it can see the function response


print(second_response.output_text)

# %% [markdown]
# ## Changamoto ya Msimbo
#
# Kazi nzuri! Ili kuendelea kujifunza kwako kuhusu Kupiga Simu ya Azure Open AI Function unaweza kujenga: https://learn.microsoft.com/training/support/catalog-api-developer-reference?WT.mc_id=academic-105485-koreyst
#  - Vigezo zaidi vya kazi ambavyo vinaweza kusaidia wanafunzi kupata kozi zaidi. Unaweza kupata vigezo vya API vinavyopatikana hapa:
#  - Tengeneza simu nyingine ya kazi ambayo inachukua taarifa zaidi kutoka kwa mwanafunzi kama lugha yao asili
#  - Tengeneza utambuzi wa makosa wakati simu ya kazi na/au simu ya API haitoi kozi zinazofaa

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Kionyozo**:
# Hati hii imetafsiriwa kwa kutumia huduma ya tafsiri ya AI [Co-op Translator](https://github.com/Azure/co-op-translator). Ingawa tunajitahidi kupata usahihi, tafadhali fahamu kwamba tafsiri za kiotomatiki zinaweza kuwa na makosa au upungufu wa usahihi. Hati ya asili katika lugha yake halisi inapaswa kuchukuliwa kama chanzo cha mamlaka. Kwa taarifa muhimu, tafsiri ya kitaalamu inayofanywa na binadamu inapendekezwa. Hatutojibu kwa kuelewa vibaya au tafsiri potofu zinazotokea kutokana na matumizi ya tafsiri hii.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
