# %% [markdown]
# # അധ്യായം 7: ചെറ്റ് ആപ്ലിക്കേഷൻ മാർ സൃഷ്ടിക്കൽ
# ## OpenAI API ക്വിക്ക്‌സ്റ്റാർട്ട്
#
# ഈ നോട്ട്‌బുക്ക് [Azure OpenAI സാമ്പിൾ റിപോസിറ്ററി](https://github.com/Azure/azure-openai-samples?WT.mc_id=academic-105485-koreyst) ൽ നിന്ന് സ്വീകരിച്ചതാണ്, അതിൽ [Azure OpenAI](notebook-azure-openai.ipynb) സർവീസുകൾ ആക്സസ് ചെയ്യുന്നതിനുള്ള നോട്ട്‌ബുക്കുകൾ ഉൾക്കൊള്ളുന്നു.
#
# Python OpenAI API, കുറച്ച് മാറ്റങ്ങളോടെ Azure OpenAI മോഡലുകളുമായി കൂടി പ്രവർത്തിക്കുന്നു. വ്യത്യാസങ്ങളെ കുറിച്ച് കൂടുതൽ അറിയാൻ ഇവിടെ കാണുക: [Python ഉപയോഗിച്ച് OpenAIയും Azure OpenAI എന്റുപോയിന്റുകളും എങ്ങനെ മാറാം](https://learn.microsoft.com/azure/ai-foundry/openai/how-to/switching-endpoints?WT.mc_id=academic-109527-jasmineg)

# %% [markdown]
# # അവലോകനം
# "വലുതായ ഭാഷ മോഡലുകൾ എന്നത് ടെക്സ്റ്റിനെ ടെക്സ്റ്റായി മാറിക്കുന്ന ഫംഗ്ഷനുകളാണ്. ഒരു എൻപുട്ട് ടെക്സ്റ്റ് സ്ട്രിംഗ് നൽകിയാൽ, വലുതായ ഭാഷ മോഡൽ അടുത്തത് വരുന്ന ടെക്സ്റ്റ് പ്രവചിക്കാൻ ശ്രമിക്കുന്നു"(1). ഈ "ക്വിക്‌സ്റ്റാർട്ട്" നോട്ട്‌ബുക്ക് ഉപയോക്താക്കൾക്ക് ഉയർന്നതലത്തിലുള്ള LLM ആശയങ്ങൾ, AML ഉപയോഗിച്ച് ആരംഭിക്കുന്നതിന് വേണ്ട കോർ പാക്കേജ് ആവശ്യകതകൾ, പ്രോംപ്റ്റ് ഡിസൈൻ ഒരു സോഫ്റ്റ് പരിചയം, കൂടാതെ വിവിധ ഉപയോഗകേസുകളുടെ ചെറിയ ഉദാഹരണങ്ങൾ പരിചയപ്പെടുത്തും.

# %% [markdown]
# ## ഉള്ളടക്ക പട്ടിക
#
# [അവലോകനം](#overview)
# [OpenAI സേവനം എങ്ങനെ ഉപയോഗിക്കാം](#how-to-use-openai-service)
# [1. നിങ്ങളുടെ OpenAI സേവനം സൃഷ്ടിക്കൽ](#1.-creating-your-openai-service)
# [2. ഇൻസ്റ്റലേഷൻ](#2.-installation)
# [3. ക്രെഡൻഷ്യലുകൾ](#3.-credentials)
#
# [ഉപയോഗ കേസ്‌കൾ](#use-cases)
# [1. വാചകം സംഗ്രഹിക്കുക](#1.-summarize-text)
# [2. വാചകം വർഗ്ഗീകരിക്കുക](#2.-classify-text)
# [3. പുതിയ ഉൽപ്പന്ന നാമങ്ങൾ സൃഷ്ടിക്കുക](#3.-generate-new-product-names)
# [4. ഒരു ക്ലാസിഫയർ ഫൈൻ ട്യൂൺ ചെയ്യുക](#4.fine-tune-a-classifier)
#
# [അഭിപ്രായങ്ങൾ](#references)

# %% [markdown]
# ### നിങ്ങളുടെ ആദ്യ പ്രോംപ്റ്റ് നിർമ്മിക്കുക
# ഈ ചെറുനടപടി "സംക്ഷേപണം" എന്ന ലളിതമായ പ്രവര്‍ത്തനത്തിനു OpenAI മോഡലിലേക്ക് പ്രോംപ്റ്റുകൾ സമര്‍പ്പിക്കുന്നതിന് അടിസ്ഥാന പരിചയം നൽകും.
#
#
# **പടികൾ**:
# 1. നിങ്ങളുടെ പൈതൺ പരിസ്ഥിതിയിൽ OpenAI ലൈബ്രറി ഇൻസ്റ്റാൾ ചെയ്യുക
# 2. സ്റ്റാൻഡർഡ് സഹായക ലൈബ്രറികൾ ലോഡ് ചെയ്ത് നിങ്ങൾ സൃഷ്ടിച്ച OpenAI സേവനത്തിനുള്ള സാധാരണ OpenAI സുരക്ഷാ ക്രെഡൻഷ്യലുകൾ സജ്ജമാക്കുക
# 3. നിങ്ങളുടെ പ്രവർത്തനത്തിനു ഒരു മോഡൽ തെരയുക
# 4. മോഡലിന് ഒരു ലളിതമായ പ്രോംപ്റ്റ് സൃഷ്ടിക്കുക
# 5. നിങ്ങളുടെ അഭ്യർത്ഥന മോഡൽ API-യിലേക്ക് സമർപ്പിക്കുക!

# %% [markdown]
# ### 1. ഓപ്പണ്‍എഐ ഇന്‍സ്റ്റാള്‍ ചെയ്യുക

# %%
# %pip install openai python-dotenv

# %% [markdown]
# ### 2. സഹായക ലൈബ്രറികള്‍ ഇറക്കുമതി ചെയ്യാനും ക്രെഡന്‍ഷ്യല്‍സ് സൃഷ്ടിക്കാനും

# %%
import os
from openai import OpenAI
from dotenv import load_dotenv

load_dotenv()

API_KEY = os.getenv("OPENAI_API_KEY","")
assert API_KEY, "ERROR: OpenAI Key is missing"

client = OpenAI(
    api_key=API_KEY
    )

# %% [markdown]
# ### 3. ശരിയായ മോഡൽ കണ്ടെത്തൽ
# GPT-4o, GPT-4o മിനി പോലുള്ള മോഡലുകൾ സ്വാഭാവിക ഭാഷ മനസിലാക്കി സൃഷ്ടികരിക്കാനും കഴിയും, വിവിധതരം പ്രവൃത്തികൾക്ക് അനുയോജ്യമായ വ്യത്യസ്ത ശక్తി, വേഗത മോഡലുകളും ഓപ്പൺഎഐ പ്ലാറ്റ്ഫോംലിൽ ലഭ്യമാണ്.

# %%
# Select a general purpose chat model
model = "gpt-5-mini"

# %% [markdown]
# ## 4. പ്രോംപ്റ്റ് ഡിസൈൻ
#
# "വലുതായ ഭാഷാ മോഡലുകളുടെ മായാജാലം ഇതാണ്: വൻമൊരു വാക്കുകൾക്കിടയിലെ മുൻകൂറുപിഴവ് കുറയ്ക്കാൻ പരിശീലിപ്പിക്കപ്പെടുന്നതിനാൽ, ഈ മോഡലുകൾ ആ മുൻകൂറുകൾക്കായി സഹായകമായ ആശയങ്ങൾ പഠിക്കുന്നു. ഉദാഹരണത്തിന്, അവർ പഠിക്കും"(1):
#
# * എങ്ങിനെ എഴുതാം
# * എങ്ങിനെ വ്യാകരം പ്രവർത്തിക്കുന്നു
# * എങ്ങിനെ പാരാഫ്രേസ് ചെയ്യാം
# * എങ്ങിനെ ചോദ്യങ്ങൾക്ക് മറുപടി നൽകാം
# * എങ്ങിനെ ഒരു സംവാദം നടത്താം
# * എങ്ങിനെ പല ഭാഷകളിൽ എഴുതാം
# * എങ്ങിനെ കോഡിങ്ങ് ചെയ്യാം
# * മുതലായവ.
#
# #### ഒരു വലിയ ഭാഷാ മോഡലിനെ എങ്ങിനെ നിയന്ത്രിക്കാം
# "ഒരു വലിയ ഭാഷാ മോഡലിലേക്ക് വരുന്ന എല്ലാ ഇൻപുട്ടുകളിൽ, ഏറ്റവും കൂടുതൽ സ്വാധീനം വഹിക്കുന്നത് ടെക്സ്റ്റ് പ്രോംപ്റ്റാണ്(1).
#
# വലിയ ഭാഷാ മോഡലുകൾ ഓരോ രീതിയിലും ഔട്ട്‌പുട്ട് നൽകാൻ പ്രോംപ്റ്റ് ചെയ്യാവുന്നതാണ്:
#
# നിർദേശം: നിങ്ങൾ എന്ത് വേണമെന്ന് മോഡലിന് പറയുക
# പൂരണം: നിങ്ങൾ വേണ്ടതിന്റെ തുടക്കമെടുത്ത് മോഡലിനെ പൂരിപ്പിക്കാൻ പ്രേരിപ്പിക്കുക
# ഉദാഹരണം: മോഡലിന് നിങ്ങൾ എന്തു വേണമെന്ന് കാണിക്കുക, അതിന്:
# പ്രോംപ്റ്റിൽ കുറച്ചു ഉദാഹരണങ്ങൾ
# ഫൈൻ-ട്യൂണിംഗ് പരിശീലന ഡാറ്റാസെറ്റിൽ നിരവധി നിലത്തോ ആയിരക്കണക്കിന് ഉദാഹരണങ്ങൾ"
#
#
#
# #### പ്രോംപ്റ്റുകൾ സൃഷ്ടിക്കാൻ മൂന്ന് അടിസ്ഥാന നിർദ്ദേശങ്ങൾ ഉണ്ട്:
#
# **കാണിക്കുകയും പറയുകയും ചെയ്യുക**. നിങ്ങൾ എന്ത് വേണമെന്ന് നിർദേശങ്ങളിലൂടെ, ഉദാഹരണങ്ങളിലൂടെ, അല്ലെങ്കിൽ രണ്ടിന്റേയും സംയോജനം കൊണ്ട് വ്യക്തമായാക്കുക. മോഡലിന് ഒരു പട്ടിക ആല്ഫബറ്റിക്കൽ ഓർഡറിൽ റാങ്ക് ചെയ്യാൻ വേണമെങ്കിൽ, അല്ലെങ്കിൽ ഒരു പാരഗ്രാഫ് വികാരാനുസൃതമായി വർഗ്ഗീകരിക്കാൻ വേണമെങ്കിൽ, അത് നിങ്ങൾക്കാണ് എന്ന് അത് കാണിക്കൂ.
#
# **ഗുണമേൻമയുള്ള ഡാറ്റ നൽകുക**. നിങ്ങൾ ക്ലാസിഫയർ നിർമ്മിക്കാൻ ശ്രമിക്കുന്നെങ്കിൽ അല്ലെങ്കിൽ മോഡലിനെ ഒരു മാതൃക പിന്തുടരാൻ വേണമെന്ന് ആഗ്രഹിക്കുന്നെങ്കിൽ, ഉദാഹരണങ്ങൾ മതിയാകണം. നിങ്ങളുടെ ഉദാഹരണങ്ങൾ പിഴവുകൾക്കായി നോക്കിയാളുക — മോഡൽ സാധാരണയായി അടിസ്ഥാന ഉച്ചാരണം പിഴവുകൾ തിരിച്ചറിയാനും മറുപടി നൽകാനും കൃത്യമായിത്തന്നെ ഉള്ളതാണ്, എന്നാൽ ഇത് ഉദ്ദേശിച്ച പിഴവാണെന്ന് കരുതുകയും ഈ മറുപടിയിൽ സ്വാധീനിക്കാം.
#
# **സജ്ജീകരണങ്ങൾ പരിശോധിക്കുക.** ടെംപറേച്ചറും top_p സജ്ജീകരണങ്ങളും മോഡൽ എത്രത്തോളം നിശ്ചിതത്വത്തോടെ മറുപടി നൽകാനുള്ളത് എന്നിവ നിയന്ത്രിക്കുന്നു. ഒരേ ശരിയായ ഉത്തരം ഒറ്റത്തവണയാണ് എന്ന് നിങ്ങൾ ചോദിക്കുന്നുവെങ്കിൽ, ഇവ കുറയ്ക്കുന്നുവെന്ന് നിങ്ങൾ ആഗ്രഹിക്കും. കൂടുതൽ വ്യത്യസ്തമായ മറുപടികൾക്കായി, ഇവ ഉയർത്താം. ഈ സജ്ജീകരണങ്ങളുമായി ആളുകൾ ചെയ്യുന്നത് ഏറ്റവും വലിയ തെറ്റ് അവയെ "ബുദ്ധിമുട്ട്" അല്ലെങ്കിൽ "സൃഷ്ടിപരമായ" നിയന്ത്രണങ്ങളായി കാണുന്നത് ആണ്.
#
#
# മൂലം: https://learn.microsoft.com/azure/ai-foundry/openai/overview

# %% [markdown]
# ### 5. സമർപ്പിക്കുക!

# %%
# Create your first prompt
text_prompt = "Should oxford commas always be used?"

response = client.responses.create(
  model=model,
  input = [{"role":"system", "content":"You are a helpful assistant."},
               {"role":"user","content":text_prompt},],
  store=False,)

response.output_text

# %% [markdown]
# ### അന്നു ഒറ്റ ഫോൺ വീണ്ടും ചെയ്യുമ്പോൾ, ഫലങ്ങൾ എങ്ങിനെയാണ് താരതമ്യം ചെയ്യുന്നത്?

# %%
response = client.responses.create(
  model=model,
  input = [{"role":"system", "content":"You are a helpful assistant."},
               {"role":"user","content":text_prompt},],
  store=False,)

response.output_text

# %% [markdown]
# ## രൂപരേഖ തയ്യാറാക്കുക
# #### ചലഞ്ച്
# ഒരു വാചകഭാഗത്തിന്റെ അവസാനം 'tl;dr:' ചേർക്കുന്നതിനാൽ വാചകത്തിന്റെ സംഗ്രഹം തയ്യാറാക്കുക. മോഡൽ എങ്ങനെ കൂടാതെ അധിക നിർദ്ദേശങ്ങളില്ലാതെ പല ജോലികളും ചെയ്യാൻ അറിയുന്നുവെന്ന് ശ്രദ്ധിക്കുക. മോഡലിന്റെ പെരുമാറ്റം മാറ്റാനും നിങ്ങൾക്ക് ലഭിക്കുന്ന സംഗ്രഹവുമെന്തെന്നു വ്യക്തിഗതമാക്കാനും tl;dr-നേക്കാൾ കൂടുതൽ വിവരണാത്മകമായ പ്രേരണകൾ പരീക്ഷിക്കാം(3).
#
# ഏറ്റവും പുതിയ ഗവേഷണങ്ങൾ ദൈർഘ്യമേറിയ എഴുത്തിന്റെ ഒരു വലിയ കോർപ്പസിൽ പ്രീ-ട്രെയിനിങ്ങ് ചെയ്ത ശേഷം ഒരു പ്രത്യേക ജോലിയിൽ ഫൈൻ-ട്യൂണിങ്ങ് നടത്തുന്നതിനുവഴി അനേകം NLP ജോലികളിലും ബെഞ്ച്മാർക്കുകളിലും വലിയ പുരോഗതി കാണിച്ചിരുന്നു. സാധാരണയായി ജോലിയുമായി ബന്ധപ്പെട്ടുകൊണ്ടുള്ള ഘടനയില്ലാതെ ഉണ്ടാകുമ്പോഴും, ഈ രീതി ഇപ്പോഴും സംശുദ്ധമായ ജോലിയുമായി ബന്ധപ്പെട്ട ഫൈൻ-ട്യൂണിങ് ഡാറ്റാസെറ്റുകൾ ആയിരക്കണക്കിന് ഉദാഹരണങ്ങൾ ആവശ്യമാണ്. എതിരാളികൾ പോലെ, മനുഷ്യർ സാധാരണയായി കുറച്ച് ഉദാഹരണങ്ങളിലെനിൽ മാത്രം അല്ലെങ്കിൽ ലളിതമായ നിർദ്ദേശങ്ങളിൽ നിന്നുമാണ് ഒരു പുതിയ ഭാഷാ ജോലി ചെയ്യുന്നത് - അത് ഇപ്പോഴും പലപ്പോഴും നിലവിലെ NLP സിസ്റ്റങ്ങൾ ചെയ്യാൻ വളരെ ബുദ്ധിമുട്ടുള്ളതാണ്. ഇവിടെ കാണിക്കുന്നത് ഭാഷാ മോഡലുകൾ വലുതാക്കുന്നത് ജോലിയുമായി ബന്ധപ്പെട്ടില്ലാത്ത കുറച്ച് ഉദാഹരണങ്ങളിലുള്ള പ്രകടനം വളരെ മെച്ചപ്പെടുത്തുന്നു, ചിലപ്പോൾ മുൻപ് അതിനുശേഷം ഫൈൻ-ട്യൂണിങ് രീതി സ്വീകരിച്ച സ്റ്റേറ്റ്-ഓഫ്-ദി-ആർട്ട് പ്രകടനത്തെ മത്സരാധിഷ്ഠിതമാക്കുന്നവയിലേക്ക് എത്തിക്കുന്നതിനും.
#
#
#
# Tl;dr

# %% [markdown]
# # നിരവധി ഉപയോഗ സാഹചര്യങ്ങൾക്ക് വ്യായാമങ്ങൾ
# 1. വാചകസംഗ്രഹം
# 2. വാചകം വർഗ്ഗീകരിക്കുക
# 3. പുതിയ ഉൽപ്പന്ന നാമങ്ങൾ സൃഷ്ടിക്കുക

# %%
prompt = "Recent work has demonstrated substantial gains on many NLP tasks and benchmarks by pre-training on a large corpus of text followed by fine-tuning on a specific task. While typically task-agnostic in architecture, this method still requires task-specific fine-tuning datasets of thousands or tens of thousands of examples. By contrast, humans can generally perform a new language task from only a few examples or from simple instructions - something that current NLP systems still largely struggle to do. Here we show that scaling up language models greatly improves task-agnostic, few-shot performance, sometimes even reaching competitiveness with prior state-of-the-art fine-tuning approaches.\n\nTl;dr"

# %%
#Setting a few additional, typical parameters during API Call

response = client.responses.create(
  model=model,
  input = [{"role":"system", "content":"You are a helpful assistant."},
               {"role":"user","content":prompt},],
  store=False,)

response.output_text

# %% [markdown]
# ## പാഠം വർഗ്ഗീകരിക്കുക
# #### വെല്ലുവിളി
# ഇൻഫറൻസ് സമയത്ത് നൽകിയ വിഭാഗങ്ങളിലേക്കായി വസ്തുക്കൾ വർഗ്ഗീകരിക്കുക. താഴെ കൊടുത്തിരിക്കുന്ന ഉദാഹരണത്തിൽ, വിഭാഗങ്ങളും വർഗ്ഗീകരിക്കാനുള്ള എഴുത്തും_prompt(*playground_reference) നൽകുന്നു.
#
# ഉപഭോക്തൃ ചോദിക്കുന്നത്: ഹെലോ, എന്റെ ലാപ്‌ടോപ്പിന്റെ കീബോർഡിലെ ഒരു കീ തകർന്നുപോയി, അതിന് പകരം ഒരു കീ എനിക്ക് വേണം:
#
# വർഗ്ഗീകരിച്ച വിഭാഗം:

# %%
prompt = "Classify the following inquiry into one of the following: categories: [Pricing, Hardware Support, Software Support]\n\ninquiry: Hello, one of the keys on my laptop keyboard broke recently and I'll need a replacement:\n\nClassified category:"
print(prompt)

# %%
#Setting a few additional, typical parameters during API Call

response = client.responses.create(
  model=model,
  input = [{"role":"system", "content":"You are a helpful assistant."},
               {"role":"user","content":prompt},],
  store=False,)

response.output_text

# %% [markdown]
# ## പുതിയ ഉൽപ്പന്ന നാമങ്ങൾ സൃഷ്ടിക്കുക
# #### വെല്ലുവിളി
# ഉദാഹരണ വാക്കുകളിൽ നിന്ന് ഉൽപ്പന്ന നാമങ്ങൾ സൃഷ്ടിക്കുക. നാമങ്ങൾ സൃഷ്ടിക്കാനായി ഞങ്ങൾ ഉൽപ്പന്നത്തെ കുറിച്ചുള്ള വിവരങ്ങൾ പ്രോംപ്റ്റിൽ ഉൾപ്പെടുത്തുന്നു. ഞങ്ങൾ ലഭിക്കാൻ ആഗ്രഹിക്കുന്ന മാതൃക കാണിക്കുന്ന സമാന ഉദാഹരണം കൂടി നൽകുന്നു. ഒന്നിച്ച് കൂടുതൽ വ്യത്യസ്തതയും നവീനതയും വർദ്ധിപ്പിക്കാൻ താപനില മൂല്യം ഉയർത്തിയിട്ടുണ്ട്.
#
# ഉൽപ്പന്ന വിവരണം: ഒരു വീടിനുള്ളിൽ ഉപയോഗിക്കാവുന്ന മിൽക്ക്‌ഷേക്ക് നിർമാതാവ്
# വിത്ത് വാക്കുകൾ: വേഗം, ആരോഗ്യകരം, ചുരുങ്ങിയ ആകാരം.
# ഉൽപ്പന്ന നാമങ്ങൾ: HomeShaker, Fit Shaker, QuickShake, Shake Maker
#
# ഉൽപ്പന്ന വിവരണം: ഏതൊരു പാദ വലിപ്പത്തിലും സുഖമായി പൊരുത്തപ്പെടുന്ന ചെരുപ്പിന്റെ ഒരു ജോഡി.
# വിത്ത് വാക്കുകൾ: ഒത്തുചേരുന്ന, പൊരുത്തമുള്ള, ഒമ്നി-ഫിറ്റ്.

# %%
prompt = "Product description: A home milkshake maker\nSeed words: fast, healthy, compact.\nProduct names: HomeShaker, Fit Shaker, QuickShake, Shake Maker\n\nProduct description: A pair of shoes that can fit any foot size.\nSeed words: adaptable, fit, omni-fit."

print(prompt)

# %%
#Setting a few additional, typical parameters during API Call

response = client.responses.create(
  model=model,
  input = [{"role":"system", "content":"You are a helpful assistant."},
               {"role":"user","content":prompt}],
  store=False,)

response.output_text

# %% [markdown]
# # റഫറൻസുകൾ
# - [Openai Cookbook](https://github.com/openai/openai-cookbook?WT.mc_id=academic-105485-koreyst)
# - [Microsoft Foundry portal](https://ai.azure.com?WT.mc_id=academic-105485-koreyst)
# - [വാചകങ്ങൾ വർഗ്ഗീകരിക്കാൻ GPT മോഡലുകൾ ഫൈൻ-ട്യൂൺ ചെയ്യുന്നതിനുള്ള മികച്ച രീതികൾ](https://platform.openai.com/docs/guides/fine-tuning?WT.mc_id=academic-105485-koreyst)

# %% [markdown]
# # കൂടുതല്‍ സഹായത്തിനായി
# [OpenAI Commercialization Team](AzureOpenAITeam@microsoft.com)

# %% [markdown]
# # സംഭാവകർ
# * ലൂയിസ് ലി

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **അറിയിപ്പ്**:
# ഈ രേഖ AI പരിഭാഷാ സേവനം [Co-op Translator](https://github.com/Azure/co-op-translator) ഉപയോഗിച്ച് പരിഭാഷപ്പെടുത്തിയതാണ്. ഞങ്ങൾ കൃത്യതയ്ക്കായി ശ്രമിക്കുന്നുവെങ്കിലും, ഓട്ടോമേറ്റഡ് പരിഭാഷകളിൽ പിഴവുകൾ അല്ലെങ്കിൽ തെറ്റായ വിവരങ്ങൾ ഉണ്ടാകാൻ സാധ്യതയുണ്ട്. അതിന്റെ സ്വാഭാവിക ഭാഷയിലുള്ള അസൽ രേഖയാണ് പ്രാമാണികമായ ഉറവിടമായി പരിഗണിക്കേണ്ടത്. നിർണായകമായ വിവരങ്ങൾക്ക്, പ്രൊഫഷണൽ മനുഷ്യ പരിഭാഷ ശുപാർശ ചെയ്യുന്നു. ഈ പരിഭാഷ ഉപയോഗിച്ച് ഉണ്ടാകുന്ന തെറ്റിദ്ധാരണകൾ അല്ലെങ്കിൽ തെറ്റായ വ്യാഖ്യാനങ്ങൾക്കായി ഞങ്ങൾ ഉത്തരവാദികളല്ല.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
