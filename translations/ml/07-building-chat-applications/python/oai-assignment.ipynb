# %% [markdown]
# # പ്രബന്ധം 7: ചാറ്റ് അപ്ലിക്കേഷനുകൾ നിർമ്മിക്കൽ
# ## OpenAI API ക്വിക്ക്സ്റ്റാർട്ട്
#
# ഈ നോട്ട്ബുക്ക് [Azure OpenAI സാംപിള്‌സ് റിപ്പോസിറ്ററി](https://github.com/Azure/azure-openai-samples?WT.mc_id=academic-105485-koreyst) നിന്നാണ് എടുത്തത്, അതിൽ [Azure OpenAI](notebook-azure-openai.ipynb) സേവനങ്ങളിലേക്ക് പ്രവേശിക്കുന്ന നോട്ട്ബുക്കുകളും ഉൾപ്പെടുന്നു.
#
# Python OpenAI API, ആസൂർ OpenAI മോഡലുകളുമായി أيضًا കുറച്ച് മാറ്റങ്ങൾക്ക് നേരെ പ്രവർത്തിക്കുന്നു. വ്യത്യാസങ്ങളെക്കുറിച്ച് കൂടുതലറിയാൻ ഇവിടെ കാണുക: [Python ഉപയോഗിച്ച് OpenAI-നും Azure OpenAI അവസാനപ്പോന്റ്‌മാരും എങ്ങനെ മാറാം](https://learn.microsoft.com/azure/ai-services/openai/how-to/switching-endpoints?WT.mc_id=academic-109527-jasmineg)

# %% [markdown]
# # അവലോകനം
# "വലുതായ ഭാഷാ മാതൃകകൾ ടെക്സ്റ്റ് നിന്ന് ടെക്സ്റ്റിലേക്ക് മാപ്പ് ചെയ്യുന്ന ഫംഗ്ഷനുകളാണ്. ഒരു ഇൻപുട്ട് ടെക്സ്റ്റ് സ്ട്രിംഗ് നൽകിയാൽ, ഒരു വലിയ ഭാഷാ മാതൃക അടുത്തിറങ്ങാനുള്ള ടെക്സ്റ്റ് പ്രവചിക്കാൻ ശ്രമിക്കുന്നു"(1). ഈ "ക്വിക്‌സ്റ്റാർട്ട്" നോട്ട്‌ബുക്ക് ഉപഭോക്താക്കളെ ഉയർന്ന തലത്തിലുള്ള LLM ആശയങ്ങളിലേയ്ക്ക്, AML ആരംഭിക്കാനുള്ള അത്യാവശ്യ കോർ പാക്കേജുകൾ, പ്രോംപ്റ്റ് ഡിസൈനിലേക്കുള്ള ഒരു മൃദുവായ പരിചയം, കൂടാതെ വ്യത്യസ്ത ഉപയോഗകേസുകളുടെ ചില ചുരുങ്ങിയ ഉദാഹരണങ്ങൾ പരിചയപ്പെടുത്തും.

# %% [markdown]
# ## ഉള്ളടക്ക പട്ടിക
#
# [അവലോകനം](#overview)
# [OpenAI സർവീസ് ഉപയോഗിക്കുന്ന വിധം](#how-to-use-openai-service)
# [1. നിങ്ങളുടെ OpenAI സർവീസ് സൃഷ്ടിക്കാം](#1.-creating-your-openai-service)
# [2. ഇൻസ്റ്റളേഷൻ](#2.-installation)
# [3. ക്രെഡൻഷ്യൽസ്](#3.-credentials)
#
# [ഉപയോഗ കാല്ഗൾ](#use-cases)
# [1. വാചകം സംക്ഷേപിക്കുക](#1.-summarize-text)
# [2. വാചകം വർഗീകരിക്കുക](#2.-classify-text)
# [3. പുതിയ ഉൽപ്പന്ന നാമങ്ങൾ സൃഷ്ടിക്കുക](#3.-generate-new-product-names)
# [4. ക്ലാസിഫയർ ഫൈൻ ട്യൂൺ ചെയ്യുക](#4.fine-tune-a-classifier)
#
# [റഫറൻസുകൾ](#references)

# %% [markdown]
# ### നിങ്ങളുടെ ആദ്യത്തെ പ്രോമ്പ്റ്റ് നിർമ്മിക്കുക
# ഈ ചെറിയ പരിശീലനം ഒരു ലളിതമായ ടാസ്‌ക്കായ "സംക്ഷേപണം" എന്നതിനായി OpenAI മോഡലിലേക്ക് പ്രോമ്പ്റ്റുകൾ സമർപ്പിക്കുന്നതിനുള്ള അടിസ്ഥാന പരിചയം നൽകും.
#
#
# **പടിപാടികൾ**:
# 1. നിങ്ങളുടെ പൈതോൺ പാരിസ്ഥിതികത്തിൽ OpenAI ലൈബ്രറി ഇൻസ്റ്റാൾ ചെയ്യുക
# 2. സാന്ദർഭിക സഹായക ലൈബ്രറികളും നിങ്ങളുടെ സാധാരണ OpenAI സുരക്ഷാ ക്രെഡൻഷ്യലുകളും സെറ്റ് ചെയ്യുക, നിങ്ങൾ സൃഷ്ടിച്ച OpenAI സർവീസിനായി
# 3. നിങ്ങളുടെ ടാസ്‌കിനായി ഒരു മോഡൽ തിരഞ്ഞെടുക്കുക
# 4. മോഡലിനായി ലളിതമായ ഒരു പ്രോമ്പ്റ്റ് സൃഷ്ടിക്കുക
# 5. മോഡൽ API-യിലേക്ക് നിങ്ങളുടെ അഭ്യർത്ഥനം സമർപ്പിക്കുക!

# %% [markdown]
# ### 1. ഒപൺഎഐ ഇൻസ്റ്റാൾ ചെയ്യുക

# %%
# %pip install openai python-dotenv

# %% [markdown]
# ### 2. സഹായക ലൈബ്രറികൾ ഇമ്പോർട്ട് ചെയ്ത് ക്രെഡൻഷിയലുകൾ സൃഷ്‌ടിക്കുക

# %%
import os
from openai import OpenAI
from dotenv import load_dotenv

load_dotenv()

API_KEY = os.getenv("OPENAI_API_KEY","")
assert API_KEY, "ERROR: OpenAI Key is missing"

client = OpenAI(
    api_key=API_KEY
    )

# %% [markdown]
# ### 3. യോജിച്ച മോഡൽ കണ്ടെത്തൽ
# GPT-4o, GPT-4o മിനി പോലുള്ള മോഡലുകൾ സ്വാഭാവിക ഭാഷ മനസിലാക്കി സൃഷ്‌ടിക്കാൻ സാധിക്കുകയും, വിവിധ ജോലികൾക്ക് അനുയോജ്യമായ ശക്തിയും വേഗതയും ഉള്ള വിവിധതരം മോഡലുകൾ ആധാരമാക്കി OpenAI പ്ലാറ്റ്‌ഫോമിൽ ലഭ്യമാണ്.

# %%
# Select a general purpose chat model
model = "gpt-4o-mini"

# %% [markdown]
# ## 4. പ്രോംപ്റ്റ് ഡിസൈൻ
#
# "വമ്പൻ ഭാഷാ മോഡലുകളുടെ മായാജാലം ഇതാണ്—അതിവലിപ്പത്തിലുള്ള ടെക്സ്റ്റുകളുടെ പ്രവചന പിശകു കുറഞ്ഞുകൊണ്ടു പഠിപ്പിച്ചതിലൂടെ, മോഡലുകൾ ഇവ പ്രവചിക്കാൻ ഉപയോഗപ്രദമായ ആശയങ്ങൾ പഠിക്കുകയും ചെയ്യുന്നു. ഉദാഹരണത്തിന്, അവർ ഈ ആശയങ്ങൾ പഠിക്കുന്നു"(1):
#
# * എങ്ങനെ വാക്യംവരുത്തണം
# * വ്യാകരണം എങ്ങനെ പ്രവര്‍ത്തിക്കുന്നു
# * എങ്ങനെ പദവി മാറ്റണം
# * എങ്ങനെ ചോദ്യങ്ങൾക്ക് ഉത്തരം നൽകണം
# * എങ്ങനെ സംഭാഷണം നടത്തണം
# * എങ്ങനെ പല ഭാഷകളിലുമായി എഴുതണം
# * എങ്ങനെ കോഡ് ചെയ്യണം
# * തുടങ്ങിയവ.
#
# #### വലുപ്പമുള്ള ഭാഷാ മോഡൽ നിയന്ത്രിക്കാനുള്ള മാർഗങ്ങൾ
# "വലിപ്പമുള്ള ഭാഷാ മോഡലിലേക്കുള്ള എണ്ണമറ്റ ഇൻപുട്ടുകളുടെ തൊട്ടിൽ, ഏറ്റവും ശക്തമായ സ്വാധീനകരമായത് ടെക്സ്റ്റ് പ്രോംപ്റ്റ് ആണ്(1).
#
# വലിപ്പമുള്ള ഭാഷാ മോഡലുകൾ പ്രോംപ്റ്റ് ചെയ്ത് പുറപ്പെടുവിക്കാനാകുന്ന ചില മാർഗങ്ങൾ:
#
# നിർദ്ദേശം: മോഡലിനോട് നിങ്ങൾക്കാവശ്യം എന്താണെന്ന് പറയുക
# പൂർത്തീകരണം: നിങ്ങൾക്കാവശ്യം തുടക്കത്തിലായി പൂർത്തീകരിക്കാൻ മോഡലിനെ പ്രേരിപ്പിക്കുക
# പ്രത്യക്ഷീകരണം: നിങ്ങൾക്കാവശ്യം ഉള്ളത് മോഡലിന് കാണിക്കുക, ഒരു തരം:
# പ്രോംപ്റ്റിൽ കുറച്ച് ഉദാഹരണങ്ങൾ
# നൂറുകളോ ആയിരത്തിലധികമോ ഉദാഹരണങ്ങളുള്ള ഫൈൻ-ട്യൂണിംഗ് പരിശീലന ഡാറ്റാസെറ്റ്"
#
#
#
# #### പ്രോംപ്റ്റുകൾ സൃഷ്ടിക്കാനുള്ള മൂന്ന് മൗലിക മാർഗനിർദ്ദേശങ്ങൾ:
#
# **കാണിക്കുകയും പറയുകയും**. നിർദേശങ്ങൾ, ഉദാഹരണങ്ങൾ, അല്ലെങ്കിൽ ഇരണ്ടിന്റെ സംയോജനം വഴി നിങ്ങൾക്കാവശ്യം എന്താണെന്ന് വ്യക്തമായി കാണിക്കുക. മോഡൽ ഒരു പട്ടികയുടെ ഇനങ്ങളെ അക്ഷരമാലാ ക്രമത്തിലോ ഒരു പാരഗ്രാഫിനെ ഭാവനാനുസൃതമായി ക്ലാസിഫൈ ചെയ്യാനോ ആഗ്രഹിച്ചാൽ, അത് നിങ്ങൾക്കാവശ്യമാണെന്ന് കാണിച്ച് തരുക.
#
# **ഗുണമേമായ ഡാറ്റ നൽകുക**. നിങ്ങൾ ക്ലാസിഫയറോ മാതൃക പിന്തുടരാനോ ശ്രമിക്കുന്നുവെങ്കിൽ, സാധാരണയായി മതിയായ ഉദാഹരണങ്ങൾ ഉണ്ടെന്നു ഉറപ്പാക്കുക. നിങ്ങളുടെ ഉദാഹരണങ്ങൾ തിരുത്തുന്നതിൽ ശ്രദ്ധിക്കുക — മോഡൽ സാധാരണയായി അടിസ്ഥാന വാക്കുപിഴച്ചുകൾ കണ്ടുപിടിക്കുകയും ഉത്തരം നൽകുകയും ചെയ്യുന്നു, പക്ഷെ ഇത് ഉദ്ദേശിച്ചതാണെന്ന് കരുതി പ്രതികരണത്തെ ബാധിക്കാം.
#
# **നിങ്ങളുടെ ക്രമീകരണങ്ങൾ പരിശോധിക്കുക.** താപനിലയും top_p ക്രമീകരണങ്ങളും മോഡൽ എത്ര നിശ്ചിതമായി പ്രതികരിക്കുന്നുവെന്ന് നിയന്ത്രിക്കുന്നു. ഒരൊറ്റ ശരിയായ ഉത്തരം ഉള്ളപ്പോൾ ഈ ക്രമീകരണങ്ങൾ കുറയ്ക്കുന്നത് ഉചിതമാണ്. കൂടുതൽ വൈവിധ്യമാർന്ന പ്രതികരണങ്ങൾ ആശിക്കുന്നത് എന്നാൽ ഉയർത്തിയാകാം. ഈ ക്രമീകരണങ്ങളെ "ബുദ്ധിമുട്ട്" അല്ലെങ്കിൽ "സൃഷ്ടിപരമായ" നിയന്ത്രണങ്ങൾ എന്നു കരുതുന്നതിൽ ആളുകൾ ചെയ്യുന്ന പ്രധാന പിശക് ആണ്.
#
#
# ഉറവിടം: https://learn.microsoft.com/azure/ai-services/openai/overview

# %% [markdown]
# ### 5. സമർപ്പിക്കുക!

# %%
# Create your first prompt
text_prompt = "Should oxford commas always be used?"

response = client.responses.create(
  model=model,
  input = [{"role":"system", "content":"You are a helpful assistant."},
               {"role":"user","content":text_prompt},],
  store=False,)

response.output_text

# %% [markdown]
# ### ഒരേ കോൾ വീണ്ടും വീണ്ടും ചെയ്യുമ്പോൾ ഫലങ്ങൾ എങ്ങനെ താരതമ്യപ്പെടുത്താം?

# %%
response = client.responses.create(
  model=model,
  input = [{"role":"system", "content":"You are a helpful assistant."},
               {"role":"user","content":text_prompt},],
  store=False,)

response.output_text

# %% [markdown]
# ## ടെക്സ്റ്റ് സംഗ്രഹിക്കുക
# #### ചലഞ്ച്
# ഒരു ടെക്സ്റ്റ് പാസ്ജിന്റെ അവസാനം 'tl;dr:' ചേർത്ത് ടെക്സ്റ്റ് സംഗ്രഹിക്കുക. ഒരു മോഡലിന് എങ്ങനെ അധിക പാലനങ്ങളില്ലാതെ പല ജോലികളും ചെയ്യാമെന്ന് മനസ്സിലാക്കുന്നുവെന്ന് ശ്രദ്ധിക്കുക. tl;dr-ക്കു പകരം കൂടുതൽ വിവരണാത്മകമായ പ്രംപ്റ്റുകളുമായി പരീക്ഷണങ്ങൾ നടത്താം, ഇത് മോഡലിന്റെ പെരുമാറ്റം തികച്ചും മാറ്റുകയും നിങ്ങൾക്ക് ലഭിക്കുന്ന സംഗ്രഹണം വ്യക്തിഗതമാക്കാൻ സഹായിക്കുകയും ചെയ്യും(3).
#
# പുതിയ പഠനങ്ങൾ വലിയ ടെക്സ്റ്റ് കൊറപ്പസ് ഉപയോഗിച്ച് മുന്‍ പരിശീലനം നടത്തുകയും തുടർന്ന് ഒരു പ്രത്യേക ജോലിയ്ക്ക് ഫൈന്‍-ട്യൂണിംഗ് നടത്തുകയും ചെയ്താൽ അനേകം NLP ജോലികളിലും ബെഞ്ച്മാർക്കുകളിലും വലിയ പുരോഗതി ഉണ്ടാക്കുമെന്ന് തെളിയിച്ചിട്ടുണ്ട്. സാധാരണയായി ജോലി-അഗ്നോസ്റ്റെക്ക്ചറിൽ ഉള്ളപ്പോഴും, ഈ രീതിക്ക് തുലനാത്മകമായി ലക്ഷണക്കണക്കിന് ജോലിക്ക് അനുയോജ്യമായ ഫൈന്‍-ട്യൂണിംഗ് ഡേറ്റാസെറ്റുകൾ ആവശ്യമുണ്ട്. അതിന് വിപരീതമായി, മനുഷ്യര്‌ സാധാരണയായി കുറച്ച് ഉദാഹരണങ്ങളോ ലളിതമായ നിർദേശങ്ങളോ നിന്നും പുതിയ ഭാഷാനിർദ്ദേശം ചെയ്യുന്ന ജോലികൾ ചെയ്യാൻ കഴിയും - ഇത് ഇന്നത്തെ NLP സിസ്റ്റങ്ങൾ സാധാരണയായി ബുദ്ധിമുട്ടുന്ന കാര്യമാണിത്. ഇവിടെ കാണിക്കുന്നത്, ഭാഷ മോഡലുകൾ വലുതാക്കി ഉയർത്തിയാൽ ജോലി-അഗ്നോസ്റ്റെ, കുറച്ചു ഉദാഹരണങ്ങൾ ഉള്ള പ്രകടനം വലിയ തോതിൽ മെച്ചപ്പെടുകയും, പാർവ്വതകാലം സൃഷ്ടിച്ച മുൻനിര ഫൈന്‍-ട്യൂണിംഗ് സമീപനങ്ങളുടെ തുല്യമായതോ അതിൽ മേൽപറഞ്ഞതോ വരുന്ന പ്രകടനം പോലും ഉണ്ടാകുകയും ചെയ്യുന്നു.
#
#
#
# Tl;dr

# %% [markdown]
# # വിവിധ ഉപയോഗങ്ങളിൽ പരീക്ഷണങ്ങൾ
# 1. വാചകം സംക്ഷേപിക്കുക
# 2. വാചകം വർഗ്ഗീകരിക്കുക
# 3. പുതിയ ഉൽപ്പന്ന നാമങ്ങൾ സൃഷ്ടിക്കുക

# %%
prompt = "Recent work has demonstrated substantial gains on many NLP tasks and benchmarks by pre-training on a large corpus of text followed by fine-tuning on a specific task. While typically task-agnostic in architecture, this method still requires task-specific fine-tuning datasets of thousands or tens of thousands of examples. By contrast, humans can generally perform a new language task from only a few examples or from simple instructions - something that current NLP systems still largely struggle to do. Here we show that scaling up language models greatly improves task-agnostic, few-shot performance, sometimes even reaching competitiveness with prior state-of-the-art fine-tuning approaches.\n\nTl;dr"

# %%
#Setting a few additional, typical parameters during API Call

response = client.responses.create(
  model=model,
  input = [{"role":"system", "content":"You are a helpful assistant."},
               {"role":"user","content":prompt},],
  store=False,)

response.output_text

# %% [markdown]
# ## ടെക്‌സ്റ്റ് വർഗ്ഗീകരിക്കുക
# #### വെല്ലുവിളി
# ഇൻഫറൻസ് സമയത്ത് നൽകുന്ന വിഭാഗങ്ങളിലേക്ക് ഇനങ്ങൾ വർഗ്ഗീകരിക്കുക. താഴെ കാണുന്ന ഉദാഹരണത്തിൽ, ഞങ്ങൾ prompt(*playground_reference)ൽ വർഗ്ഗങ്ങളും വർഗ്ഗീകരിക്കാനുള്ള ടെക്‌സ്റ്റും നൽകുന്നു.
#
# ഉപഭോക്തൃ അന്വേഷണo: ഹലോ, എന്റെ ലാപ്ടോപ്പ് കീബോർഡിലെ ഒരു കീ അടുത്തിടെ തകർന്നു, അതിനുള്ള പകരം ഒരു കീ എനിക്ക് വേണമെങ്കിൽ:
#
# വർഗ്ഗീകരിച്ച വിഭാഗം:

# %%
prompt = "Classify the following inquiry into one of the following: categories: [Pricing, Hardware Support, Software Support]\n\ninquiry: Hello, one of the keys on my laptop keyboard broke recently and I'll need a replacement:\n\nClassified category:"
print(prompt)

# %%
#Setting a few additional, typical parameters during API Call

response = client.responses.create(
  model=model,
  input = [{"role":"system", "content":"You are a helpful assistant."},
               {"role":"user","content":prompt},],
  store=False,)

response.output_text

# %% [markdown]
# ## പുതിയ ഉൽപ്പന്ന പേരുകൾ സൃഷ്ടിക്കുക
# #### വെല്ലുവിളി
# ഉദാഹരണ വാക്കുകളിൽ നിന്നാണ് ഉൽപ്പന്ന പേരുകൾ സൃഷ്ടിക്കുക. ഇവിടെ ആ പേരുകൾ സൃഷ്ടിക്കാനായി ഉൽപ്പന്നത്തിന്റെ വിവരങ്ങൾ പ്രോമ്പ്റ്റിൽ ഉൾപ്പെടുത്തുന്നു. എങ്ങനെ പേരുകൾ ഉണ്ടാകണമെന്ന് കാണിക്കാൻ സമാനമായ ഒരു ഉദാഹരണം കൂടി നൽകുന്നു. അന്യോന്യം കൂടിയ മറുപടികൾക്ക് ഏറെ സാധ്യതയുള്ളതായതിനാൽ ടേംപറേച്ചർ മൂല്യം ഉയർത്തിയിട്ടുണ്ട്.
#
# ഉൽപ്പന്നം വിശദീകരണം: ഒരു ഹോം മിൽക്‌ഷേക്ക് മേക്കർ
# വിത്ത് വാക്കുകൾ: വേഗം, ആരോഗ്യകാരി, സംക്ഷിപ്തം.
# ഉൽപ്പന്ന പേരുകൾ: ഹോംഷേക്കർ, ഫിറ്റ് ഷേക്കർ, ക്വിക്ക്‌ഷേക്ക്, ഷേക്ക് മേക്കർ
#
# ഉൽപ്പന്നം വിശദീകരണം: ഏതൊരു കാൽവലുപ്പത്തിനും പൊരുത്തം ചെയ്യുന്ന ഷൂകൾ
# വിത്ത് വാക്കുകൾ: അനുയോജ്യമായ, പൊരുത്തം, ഒമ്നി-ഫിറ്റ്.

# %%
prompt = "Product description: A home milkshake maker\nSeed words: fast, healthy, compact.\nProduct names: HomeShaker, Fit Shaker, QuickShake, Shake Maker\n\nProduct description: A pair of shoes that can fit any foot size.\nSeed words: adaptable, fit, omni-fit."

print(prompt)

# %%
#Setting a few additional, typical parameters during API Call

response = client.responses.create(
  model=model,
  input = [{"role":"system", "content":"You are a helpful assistant."},
               {"role":"user","content":prompt}],
  store=False,)

response.output_text

# %% [markdown]
# # റഫറൻസുകൾ
# - [Openai Cookbook](https://github.com/openai/openai-cookbook?WT.mc_id=academic-105485-koreyst)
# - [Microsoft Foundry portal](https://ai.azure.com?WT.mc_id=academic-105485-koreyst)
# - [വാചകങ്ങൾ ക്ലാസിഫൈ ചെയ്യുന്നതിനായുള്ള GPT മോഡലുകൾ ഫൈൻ ട്യൂണിങ്ങ് ചെയ്യാനുള്ള മികച്ച രീതികൾ](https://platform.openai.com/docs/guides/fine-tuning?WT.mc_id=academic-105485-koreyst)

# %% [markdown]
# # കൂടുതൽ സഹായത്തിനായി
# [OpenAI വ്യാപാരവൽക്കരണ ടീം](AzureOpenAITeam@microsoft.com)

# %% [markdown]
# # സംഭാവകർ
# * ലൂയിസ് ലി

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **അറിയിപ്പ്**:
# ഈ രേഖ AI പരിഭാഷാ സേവനം [Co-op Translator](https://github.com/Azure/co-op-translator) ഉപയോഗിച്ച് പരിഭാഷപ്പെടുത്തിയതാണ്. ഞങ്ങൾ കൃത്യതയ്ക്കായി ശ്രമിക്കുന്നുവെങ്കിലും, ഓട്ടോമേറ്റഡ് പരിഭാഷകളിൽ പിഴവുകൾ അല്ലെങ്കിൽ തെറ്റായ വിവരങ്ങൾ ഉണ്ടാകാൻ സാധ്യതയുണ്ട്. അതിന്റെ സ്വാഭാവിക ഭാഷയിലുള്ള അസൽ രേഖയാണ് പ്രാമാണികമായ ഉറവിടമായി പരിഗണിക്കേണ്ടത്. നിർണായകമായ വിവരങ്ങൾക്ക്, പ്രൊഫഷണൽ മനുഷ്യ പരിഭാഷ ശുപാർശ ചെയ്യുന്നു. ഈ പരിഭാഷ ഉപയോഗിച്ച് ഉണ്ടാകുന്ന തെറ്റിദ്ധാരണകൾ അല്ലെങ്കിൽ തെറ്റായ വ്യാഖ്യാനങ്ങൾക്കായി ഞങ്ങൾ ഉത്തരവാദികളല്ല.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
