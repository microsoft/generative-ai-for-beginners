# %% [markdown]
# ## പരിചയം
#
# ഈ പാഠം ഉൾക്കൊള്ളുന്നതാണ്:
# - ഫംഗ്ഷൻ കോൾ ചെയ്യുന്നത് എന്താണെന്നും അതിന്റെ ഉപയോഗ കേസുകൾ
# - Azure OpenAI ഉപയോഗിച്ച് ഫംഗ്ഷൻ കോൾ എങ്ങനെ സൃഷ്ടിക്കാമെന്ന്
# - ഒരു ആപ്ലിക്കേഷനിൽ ഫംഗ്ഷൻ കോൾ എങ്ങനെ സംയോജിപ്പിക്കാമെന്ന്
#
# ## പഠന ലക്ഷ്യങ്ങൾ
#
# ഈ പാഠം പൂർത്തിയാക്കിയ ശേഷം നിങ്ങൾ അറിയുകയും മനസ്സിലാക്കുകയും ചെയ്യുക:
#
# - ഫംഗ്ഷൻ കോൾ ചെയ്യുന്നതിന്റെ ഉദ്ദേശ്യം
# - Azure Open AI സർവീസ് ഉപയോഗിച്ച് ഫംഗ്ഷൻ കോൾ സജ്ജമാക്കൽ
# - നിങ്ങളുടെ ആപ്ലിക്കേഷന്റെ ഉപയോഗ കേസിനായി ഫംഗ്ഷൻ കോൾ ഫലപ്രദമായി രൂപകൽപ്പന ചെയ്യുക

# %% [markdown]
# ## ഫംഗ്ഷൻ കോൾസ് മനസ്സിലാക്കൽ
#
# ഈ പാഠത്തിനായി, ഞങ്ങൾ ഒരു എഡ്യൂക്കേഷൻ സ്റ്റാർട്ടപ്പിനായി ഒരു ഫീച്ചർ നിർമ്മിക്കാൻ ആഗ്രഹിക്കുന്നു, ഇത് ഉപയോക്താക്കൾക്ക് ടെക്നിക്കൽ കോഴ്സുകൾ കണ്ടെത്താൻ ഒരു ചാറ്റ്ബോട്ട് ഉപയോഗിക്കാൻ അനുവദിക്കും. അവരുടെ കഴിവ് നില, നിലവിലെ റോളും താൽപ്പര്യമുള്ള സാങ്കേതികവിദ്യയും അനുസരിച്ച് കോഴ്സുകൾ ഞങ്ങൾ ശിപാർശ ചെയ്യും.
#
# ഇത് പൂർത്തിയാക്കാൻ ഞങ്ങൾ ഉപയോഗിക്കുന്ന സംയോജനം:
#  - ഉപയോക്താവിന് ഒരു ചാറ്റ് അനുഭവം സൃഷ്ടിക്കാൻ `Azure Open AI`
#  - ഉപയോക്താവിന്റെ അഭ്യർത്ഥനയുടെ അടിസ്ഥാനത്തിൽ കോഴ്സുകൾ കണ്ടെത്താൻ സഹായിക്കുന്ന `Microsoft Learn Catalog API`
#  - ഉപയോക്താവിന്റെ ചോദ്യം എടുത്ത് API അഭ്യർത്ഥന നടത്താൻ ഒരു ഫംഗ്ഷനിലേക്ക് അയയ്ക്കാൻ `Function Calling`
#
# ആരംഭിക്കാൻ, ആദ്യം ഫംഗ്ഷൻ കോൾ ഉപയോഗിക്കേണ്ടതിന്റെ കാരണം നോക്കാം:
#
# print("അടുത്ത അഭ്യർത്ഥനയിലെ സന്ദേശങ്ങൾ:")
# print(messages)
# print()
#
# second_response = client.chat.completions.create(
#     messages=messages,
#     model=deployment,
#     function_call="auto",
#     functions=functions,
#     temperature=0
#         )  # ഫംഗ്ഷൻ പ്രതികരണം കാണാൻ GPT-യിൽ നിന്ന് പുതിയ പ്രതികരണം നേടുക
#
#
# print(second_response.choices[0].message)

# %% [markdown]
# ### ഫംഗ്ഷൻ കോൾ ചെയ്യാനുള്ള കാരണം
#
# നിങ്ങൾ ഈ കോഴ്സിലെ മറ്റേതെങ്കിലും പാഠം പൂർത്തിയാക്കിയിട്ടുണ്ടെങ്കിൽ, വലിയ ഭാഷാ മോഡലുകൾ (LLMs) ഉപയോഗിക്കുന്നതിന്റെ ശക്തി നിങ്ങൾക്ക് മനസ്സിലായിരിക്കാം. അതുപോലെ, അവയുടെ ചില പരിമിതികളും നിങ്ങൾക്ക് കാണാനാകാം.
#
# ഫംഗ്ഷൻ കോൾ ചെയ്യൽ Azure Open AI സർവീസിന്റെ ഒരു സവിശേഷതയാണ്, താഴെപ്പറയുന്ന പരിമിതികൾ മറികടക്കാൻ:
# 1) സ്ഥിരമായ പ്രതികരണ ഫോർമാറ്റ്
# 2) ചാറ്റ് സാഹചര്യത്തിൽ ഒരു ആപ്ലിക്കേഷന്റെ മറ്റ് ഉറവിടങ്ങളിൽ നിന്നുള്ള ഡാറ്റ ഉപയോഗിക്കാൻ കഴിവ്
#
# ഫംഗ്ഷൻ കോൾ ചെയ്യുന്നതിന് മുമ്പ്, LLM-കളിൽ നിന്നുള്ള പ്രതികരണങ്ങൾ അസംഘടിതവും അനിയമിതവുമായിരുന്നു. ഓരോ പ്രതികരണ വ്യത്യാസവും കൈകാര്യം ചെയ്യാൻ ഡെവലപ്പർമാർക്ക് സങ്കീർണ്ണമായ പരിശോധന കോഡ് എഴുതേണ്ടിവന്നു.
#
# ഉപയോക്താക്കൾക്ക് "സ്റ്റോക്ക്ഹോംയിലെ നിലവിലെ കാലാവസ്ഥ എന്താണ്?" പോലുള്ള ചോദ്യങ്ങൾക്ക് ഉത്തരം ലഭിക്കാനായിരുന്നില്ല. കാരണം മോഡലുകൾ പരിശീലിപ്പിച്ച ഡാറ്റയുടെ സമയപരിധിയിലായിരുന്നു പരിമിതമായിരുന്നത്.
#
# ഈ പ്രശ്നം വിശദീകരിക്കുന്ന താഴെ കാണുന്ന ഉദാഹരണം നോക്കാം:
#
# നമുക്ക് വിദ്യാർത്ഥികളുടെ ഡാറ്റാബേസ് സൃഷ്ടിച്ച് അവർക്കു ശരിയായ കോഴ്സ് നിർദ്ദേശിക്കാൻ ആഗ്രഹിക്കാം. താഴെ രണ്ട് വിദ്യാർത്ഥികളുടെ വിവരങ്ങൾ കാണാം, അവ തമ്മിൽ ഡാറ്റയിൽ വളരെ സമാനമാണ്.

# %%
student_1_description="Emily Johnson is a sophomore majoring in computer science at Duke University. She has a 3.7 GPA. Emily is an active member of the university's Chess Club and Debate Team. She hopes to pursue a career in software engineering after graduating."
 
student_2_description = "Michael Lee is a sophomore majoring in computer science at Stanford University. He has a 3.8 GPA. Michael is known for his programming skills and is an active member of the university's Robotics Club. He hopes to pursue a career in artificial intelligence after finishing his studies."

# %% [markdown]
# നാം ഈ ഡാറ്റ പാഴ്‌സ് ചെയ്യാൻ ഒരു LLM-ലേക്ക് അയയ്ക്കാൻ ആഗ്രഹിക്കുന്നു. ഇത് പിന്നീട് നമ്മുടെ ആപ്ലിക്കേഷനിൽ API-യിലേക്ക് അയയ്ക്കാനോ ഡാറ്റാബേസിൽ സൂക്ഷിക്കാനോ ഉപയോഗിക്കാം.
#
# നാം LLM-നെ ഞങ്ങൾക്കു വേണ്ട വിവരങ്ങൾ എന്തെല്ലാമാണെന്ന് നിർദ്ദേശിക്കുന്ന രണ്ട് സമാനമായ പ്രോംപ്റ്റുകൾ സൃഷ്ടിക്കാം:

# %% [markdown]
# നാം ഇത് ഒരു LLM-ന് അയച്ച് നമ്മുടെ ഉൽപ്പന്നത്തിന് പ്രധാനപ്പെട്ട ഭാഗങ്ങൾ പാഴ്‌സ് ചെയ്യാൻ ആഗ്രഹിക്കുന്നു. അതിനാൽ നാം LLM-നെ നിർദ്ദേശിക്കാൻ രണ്ട് സമാനമായ പ്രോംപ്റ്റുകൾ സൃഷ്ടിക്കാം:

# %%
prompt1 = f'''
Please extract the following information from the given text and return it as a JSON object:

name
major
school
grades
club

This is the body of text to extract the information from:
{student_1_description}
'''


prompt2 = f'''
Please extract the following information from the given text and return it as a JSON object:

name
major
school
grades
club

This is the body of text to extract the information from:
{student_2_description}
'''

# %% [markdown]
# ഈ രണ്ട് പ്രോംപ്റ്റുകളും സൃഷ്ടിച്ചതിന് ശേഷം, അവയെ `openai.ChatCompletion` ഉപയോഗിച്ച് LLM-ലേക്ക് അയയ്ക്കും. പ്രോംപ്റ്റ് `messages` എന്ന വേരിയബിളിൽ സൂക്ഷിക്കുകയും റോളായി `user` നിശ്ചയിക്കുകയും ചെയ്യുന്നു. ഇത് ഒരു ഉപയോക്താവിന്റെ സന്ദേശം ചാറ്റ്ബോട്ടിലേക്ക് എഴുതുന്നതിനെ അനുകരിക്കാൻ ആണ്.

# %%
import os
import json
from openai import AzureOpenAI
from dotenv import load_dotenv
load_dotenv()

client = AzureOpenAI(
  api_key=os.environ['AZURE_OPENAI_API_KEY'],  # this is also the default, it can be omitted
  api_version = "2023-07-01-preview"
  )

deployment=os.environ['AZURE_OPENAI_DEPLOYMENT']
# Out:
# Running cells with '/opt/homebrew/bin/python3' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ഇപ്പോൾ നാം രണ്ട് അഭ്യർത്ഥനകളും LLM-ലേക്ക് അയച്ച് ലഭിക്കുന്ന പ്രതികരണം പരിശോധിക്കാം.

# %%
openai_response1 = client.chat.completions.create(
 model=deployment,    
 messages = [{'role': 'user', 'content': prompt1}]
)
openai_response1.choices[0].message.content

# %%
openai_response2 = client.chat.completions.create(
 model=deployment,    
 messages = [{'role': 'user', 'content': prompt2}]
)
openai_response2.choices[0].message.content

# %%
# Loading the response as a JSON object
json_response1 = json.loads(openai_response1.choices[0].message.content)
json_response1

# %%
# Loading the response as a JSON object
json_response2 = json.loads(openai_response2.choices[0].message.content )
json_response2

# %% [markdown]
# പ്രോംപ്റ്റുകൾ ഒരേതാണെങ്കിലും, വിവരണങ്ങൾ സമാനമായിരുന്നാലും, `Grades` പ്രോപ്പർട്ടി വ്യത്യസ്ത ഫോർമാറ്റുകളിൽ ലഭിക്കാം.
#
# മുകളിൽ കൊടുത്ത സെൽ പലതവണ ഓടിച്ചാൽ, ഫോർമാറ്റ് `3.7` അല്ലെങ്കിൽ `3.7 GPA` ആകാം.
#
# ഇത് സംഭവിക്കുന്നത് LLM എഴുതിയ പ്രോംപ്റ്റിന്റെ രൂപത്തിൽ അനിയന്ത്രിത ഡാറ്റ സ്വീകരിച്ച് അനിയന്ത്രിത ഡാറ്റയായി തിരികെ നൽകുന്നതിനാൽ ആണ്. ഈ ഡാറ്റ സംഭരിക്കുമ്പോഴും ഉപയോഗിക്കുമ്പോഴും എന്ത് പ്രതീക്ഷിക്കാമെന്ന് അറിയാൻ നമുക്ക് ഘടനാപരമായ ഫോർമാറ്റ് വേണം.
#
# ഫംഗ്ഷണൽ കോളിംഗ് ഉപയോഗിച്ച്, നമുക്ക് ഘടനാപരമായ ഡാറ്റ തിരികെ ലഭിക്കുന്നതായി ഉറപ്പാക്കാം. ഫംഗ്ഷൻ കോളിംഗ് ഉപയോഗിക്കുമ്പോൾ, LLM യഥാർത്ഥത്തിൽ ഫംഗ്ഷനുകൾ വിളിക്കുകയോ ഓടിക്കുകയോ ചെയ്യില്ല. പകരം, LLM അതിന്റെ പ്രതികരണങ്ങൾക്ക് പിന്തുടരാനുള്ള ഘടന നാം സൃഷ്ടിക്കുന്നു. പിന്നീട് ആ ഘടനാപരമായ പ്രതികരണങ്ങൾ ഉപയോഗിച്ച് നമ്മുടെ ആപ്ലിക്കേഷനുകളിൽ ഏത് ഫംഗ്ഷൻ ഓടിക്കണമെന്ന് നമുക്ക് അറിയാം.

# %% [markdown]
# ![ഫംഗ്ഷൻ കോളിംഗ് ഫ്ലോ ഡയഗ്രാം](../../../../translated_images/ml/Function-Flow.083875364af4f4bb.png)

# %% [markdown]
# അപ്പോൾ നാം ഫംഗ്ഷനിൽ നിന്നു ലഭിക്കുന്നതെടുത്ത് LLM-ലേക്ക് തിരിച്ച് അയക്കാം. LLM പിന്നീട് സ്വാഭാവിക ഭാഷ ഉപയോഗിച്ച് ഉപയോക്താവിന്റെ ചോദ്യം മറുപടി നൽകും.

# %% [markdown]
# ### ഫംഗ്ഷൻ കോൾസ് ഉപയോഗിക്കുന്നതിന് ഉപയോഗകേസുകൾ
#
# **ബാഹ്യ ടൂളുകൾ കോൾ ചെയ്യൽ**
# ചാറ്റ്ബോട്ടുകൾ ഉപയോക്താക്കളുടെ ചോദ്യങ്ങൾക്ക് ഉത്തരം നൽകുന്നതിൽ മികച്ചവയാണ്. ഫംഗ്ഷൻ കോൾ ഉപയോഗിച്ച്, ചാറ്റ്ബോട്ടുകൾ ഉപയോക്താക്കളുടെ സന്ദേശങ്ങൾ ഉപയോഗിച്ച് ചില പ്രവർത്തനങ്ങൾ പൂർത്തിയാക്കാൻ കഴിയും. ഉദാഹരണത്തിന്, ഒരു വിദ്യാർത്ഥി ചാറ്റ്ബോട്ടിനോട് "ഈ വിഷയത്തിൽ കൂടുതൽ സഹായം വേണമെന്ന് എന്റെ ഇൻസ്ട്രക്ടറിന് ഇമെയിൽ അയയ്ക്കൂ" എന്ന് ചോദിക്കാം. ഇത് `send_email(to: string, body: string)` എന്ന ഫംഗ്ഷൻ കോൾ ചെയ്യാൻ കഴിയും.
#
# **API അല്ലെങ്കിൽ ഡാറ്റാബേസ് ക്വറികൾ സൃഷ്ടിക്കൽ**
# ഉപയോക്താക്കൾ സ്വാഭാവിക ഭാഷ ഉപയോഗിച്ച് വിവരങ്ങൾ കണ്ടെത്താം, അത് ഫോർമാറ്റ് ചെയ്ത ക്വറി അല്ലെങ്കിൽ API അഭ്യർത്ഥനയാക്കി മാറ്റപ്പെടുന്നു. ഉദാഹരണത്തിന്, ഒരു അധ്യാപകൻ "അവസാന അസൈൻമെന്റ് പൂർത്തിയാക്കിയ വിദ്യാർത്ഥികൾ ആരെല്ലാം?" എന്ന് ചോദിക്കുമ്പോൾ, `get_completed(student_name: string, assignment: int, current_status: string)` എന്ന ഫംഗ്ഷൻ കോൾ ചെയ്യാം.
#
# **സംഘടിത ഡാറ്റ സൃഷ്ടിക്കൽ**
# ഉപയോക്താക്കൾ ഒരു ടെക്സ്റ്റ് ബ്ലോക്ക് അല്ലെങ്കിൽ CSV എടുത്ത് അതിൽ നിന്നുള്ള പ്രധാന വിവരങ്ങൾ LLM ഉപയോഗിച്ച് എടുക്കാം. ഉദാഹരണത്തിന്, ഒരു വിദ്യാർത്ഥി സമാധാന കരാറുകളെക്കുറിച്ചുള്ള വിക്കിപീഡിയ ലേഖനം എഐ ഫ്ലാഷ് കാർഡുകൾ സൃഷ്ടിക്കാൻ മാറ്റാം. ഇത് `get_important_facts(agreement_name: string, date_signed: string, parties_involved: list)` എന്ന ഫംഗ്ഷൻ ഉപയോഗിച്ച് ചെയ്യാം.

# %% [markdown]
# ## 2. നിങ്ങളുടെ ആദ്യ ഫംഗ്ഷൻ കോൾ സൃഷ്ടിക്കൽ
#
# ഒരു ഫംഗ്ഷൻ കോൾ സൃഷ്ടിക്കുന്ന പ്രക്രിയയിൽ 3 പ്രധാന ഘട്ടങ്ങൾ ഉൾപ്പെടുന്നു:
# 1. നിങ്ങളുടെ ഫംഗ്ഷനുകളുടെ പട്ടികയും ഒരു ഉപയോക്തൃ സന്ദേശവും ഉപയോഗിച്ച് Chat Completions API കോൾ ചെയ്യുക
# 2. ഒരു പ്രവർത്തനം നിർവഹിക്കാൻ മോഡലിന്റെ പ്രതികരണം വായിക്കുക, ഉദാ: ഒരു ഫംഗ്ഷൻ അല്ലെങ്കിൽ API കോൾ നിർവഹിക്കുക
# 3. നിങ്ങളുടെ ഫംഗ്ഷനിൽ നിന്നുള്ള പ്രതികരണം ഉപയോഗിച്ച് ഉപയോക്താവിന് മറുപടി സൃഷ്ടിക്കാൻ Chat Completions API വീണ്ടും കോൾ ചെയ്യുക.

# %% [markdown]
# ![ഫംഗ്ഷൻ കോൾ ഫ്ലോ](../../../../translated_images/ml/LLM-Flow.3285ed8caf4796d7.png)

# %% [markdown]
# ### ഫംഗ്ഷൻ കോൾ എലമെന്റുകൾ
#
# #### ഉപയോക്തൃ ഇൻപുട്ട്
#
# ആദ്യ ഘട്ടം ഒരു ഉപയോക്തൃ സന്ദേശം സൃഷ്ടിക്കുകയാണ്. ഇത് ഒരു ടെക്സ്റ്റ് ഇൻപുട്ടിന്റെ മൂല്യം എടുത്ത് ഡൈനാമിക്കായി നിയോഗിക്കാമോ അല്ലെങ്കിൽ നിങ്ങൾക്ക് ഇവിടെ ഒരു മൂല്യം നിയോഗിക്കാമോ. ഇത് Chat Completions API-യുമായി ആദ്യമായി പ്രവർത്തിക്കുന്നുവെങ്കിൽ, സന്ദേശത്തിന്റെ `role`യും `content`ഉം നിർവചിക്കേണ്ടതുണ്ട്.
#
# `role` ആയിരിക്കും `system` (നിയമങ്ങൾ സൃഷ്ടിക്കുന്നത്), `assistant` (മോഡൽ) അല്ലെങ്കിൽ `user` (അവസാന ഉപയോക്താവ്). ഫംഗ്ഷൻ കോൾ ചെയ്യുന്നതിനായി, ഇത് `user` ആയി നിയോഗിക്കുകയും ഒരു ഉദാഹരണ ചോദ്യവും നൽകുകയും ചെയ്യും.

# %%
messages= [ {"role": "user", "content": "Find me a good course for a beginner student to learn Azure."} ]

# %% [markdown]
# ### ഫംഗ്ഷനുകൾ സൃഷ്ടിക്കൽ.
#
# അടുത്തതായി നാം ഒരു ഫംഗ്ഷനും ആ ഫംഗ്ഷന്റെ പാരാമീറ്ററുകളും നിർവചിക്കും. ഇവിടെ നാം `search_courses` എന്ന ഒരു ഫംഗ്ഷൻ മാത്രം ഉപയോഗിക്കും, പക്ഷേ നിങ്ങൾക്ക് നിരവധി ഫംഗ്ഷനുകൾ സൃഷ്ടിക്കാം.
#
# **പ്രധാനമാണ്** : ഫംഗ്ഷനുകൾ LLM-ന് സിസ്റ്റം സന്ദേശത്തിൽ ഉൾപ്പെടുകയും നിങ്ങൾക്ക് ലഭ്യമായ ടോക്കണുകളുടെ അളവിൽ ഉൾപ്പെടുകയും ചെയ്യും.

# %%
functions = [
   {
      "name":"search_courses",
      "description":"Retrieves courses from the search index based on the parameters provided",
      "parameters":{
         "type":"object",
         "properties":{
            "role":{
               "type":"string",
               "description":"The role of the learner (i.e. developer, data scientist, student, etc.)"
            },
            "product":{
               "type":"string",
               "description":"The product that the lesson is covering (i.e. Azure, Power BI, etc.)"
            },
            "level":{
               "type":"string",
               "description":"The level of experience the learner has prior to taking the course (i.e. beginner, intermediate, advanced)"
            }
         },
         "required":[
            "role"
         ]
      }
   }
]

# %% [markdown]
# **നിർവചനങ്ങൾ**
#
# `name` - ഞങ്ങൾ വിളിക്കണമെന്ന് ആഗ്രഹിക്കുന്ന ഫംഗ്ഷന്റെ പേര്.
#
# `description` - ഫംഗ്ഷൻ എങ്ങനെ പ്രവർത്തിക്കുന്നു എന്നതിന്റെ വിവരണം. ഇവിടെ വ്യക്തവും വ്യക്തമുമായിരിക്കേണ്ടത് പ്രധാനമാണ്.
#
# `parameters` - മോഡൽ അതിന്റെ പ്രതികരണത്തിൽ ഉത്പാദിപ്പിക്കേണ്ട മൂല്യങ്ങളും ഫോർമാറ്റും ഉള്ള പട്ടിക.
#
#
# `type` - പ്രോപ്പർട്ടികൾ സൂക്ഷിക്കപ്പെടുന്ന ഡാറ്റാ തരം.
#
# `properties` - മോഡൽ അതിന്റെ പ്രതികരണത്തിനായി ഉപയോഗിക്കുന്ന പ്രത്യേക മൂല്യങ്ങളുടെ പട്ടിക.
#
#
# `name` - മോഡൽ അതിന്റെ ഫോർമാറ്റ് ചെയ്ത പ്രതികരണത്തിൽ ഉപയോഗിക്കുന്ന പ്രോപ്പർട്ടി നാമം.
#
# `type` - ഈ പ്രോപ്പർട്ടിയുടെ ഡാറ്റാ തരം.
#
# `description` - പ്രത്യേക പ്രോപ്പർട്ടിയുടെ വിവരണം.
#
#
# **ഐച്ഛികം**
#
# `required` - ഫംഗ്ഷൻ കോൾ പൂർത്തിയാക്കാൻ ആവശ്യമായ പ്രോപ്പർട്ടി.

# %% [markdown]
# ### ഫംഗ്ഷൻ കോൾ ചെയ്യൽ
# ഒരു ഫംഗ്ഷൻ നിർവചിച്ചതിന് ശേഷം, ഇപ്പോൾ അത് Chat Completion API-യിലേക്ക് കോൾ ചെയ്യുന്നതിൽ ഉൾപ്പെടുത്തേണ്ടതുണ്ട്. ഇത് ചെയ്യാൻ, അഭ്യർത്ഥനയിൽ `functions` ചേർക്കുന്നു. ഈ കേസിൽ `functions=functions` ആണ്.
#
# `function_call` നെ `auto` ആയി സജ്ജീകരിക്കുന്ന ഒരു ഓപ്ഷനും ഉണ്ട്. ഇതിന്റെ അർത്ഥം, ഉപയോക്തൃ സന്ദേശത്തിന്റെ അടിസ്ഥാനത്തിൽ ഏത് ഫംഗ്ഷൻ കോൾ ചെയ്യണമെന്ന് LLM-ന് തീരുമാനിക്കാൻ അനുവദിക്കുന്നതാണ്, നമുക്ക് തന്നെ അത് നിശ്ചയിക്കാതെ.

# %%
response = client.chat.completions.create(model=deployment, 
                                        messages=messages,
                                        functions=functions, 
                                        function_call="auto") 

print(response.choices[0].message)

# %% [markdown]
# ഇപ്പോൾ നമുക്ക് പ്രതികരണം നോക്കാം, അത് എങ്ങനെ ഫോർമാറ്റ് ചെയ്തിട്ടുള്ളതെന്ന് കാണാം:
#
# {
#   "role": "assistant",
#   "function_call": {
#     "name": "search_courses",
#     "arguments": "{\n  \"role\": \"student\",\n  \"product\": \"Azure\",\n  \"level\": \"beginner\"\n}"
#   }
# }
#
# ഫംഗ്ഷന്റെ പേര് വിളിക്കപ്പെട്ടിരിക്കുന്നതും, ഉപയോക്തൃ സന്ദേശത്തിൽ നിന്നുള്ള ഡാറ്റ ഫംഗ്ഷന്റെ arguments-നു അനുയോജ്യമായി കണ്ടെത്തിയതും നിങ്ങൾക്ക് കാണാം.

# %% [markdown]
# ## 3.ഒരു അപ്ലിക്കേഷനിൽ ഫംഗ്ഷൻ കോൾസ് സംയോജിപ്പിക്കൽ.
#
#
# LLM-ൽ നിന്നുള്ള ഫോർമാറ്റ് ചെയ്ത പ്രതികരണം ഞങ്ങൾ പരിശോധിച്ചതിന് ശേഷം, ഇപ്പോൾ ഇത് ഒരു അപ്ലിക്കേഷനിൽ സംയോജിപ്പിക്കാം.
#
# ### പ്രവാഹം നിയന്ത്രിക്കൽ
#
# ഇത് നമ്മുടെ അപ്ലിക്കേഷനിൽ സംയോജിപ്പിക്കാൻ, താഴെ പറയുന്ന ഘട്ടങ്ങൾ സ്വീകരിക്കാം:
#
# ആദ്യം, Open AI സേവനങ്ങളിലേക്ക് കോൾ ചെയ്യുകയും സന്ദേശം `response_message` എന്ന വേരിയബിളിൽ സൂക്ഷിക്കുകയും ചെയ്യാം.

# %%
response_message = response.choices[0].message

# %% [markdown]
# ഇപ്പോൾ നാം കോഴ്സുകളുടെ പട്ടിക ലഭിക്കാൻ Microsoft Learn API വിളിക്കുന്ന ഫംഗ്ഷൻ നിർവചിക്കും:

# %%
import requests

def search_courses(role, product, level):
    url = "https://learn.microsoft.com/api/catalog/"
    params = {
        "role": role,
        "product": product,
        "level": level
    }
    response = requests.get(url, params=params)
    modules = response.json()["modules"]
    results = []
    for module in modules[:5]:
        title = module["title"]
        url = module["url"]
        results.append({"title": title, "url": url})
    return str(results)

# %% [markdown]
# ഒരു മികച്ച പ്രാക്ടീസായി, മോഡൽ ഒരു ഫംഗ്ഷൻ വിളിക്കണമെന്ന് ആഗ്രഹിക്കുന്നുണ്ടോ എന്ന് നാം പിന്നീട് കാണും. അതിനുശേഷം, ലഭ്യമായ ഫംഗ്ഷനുകളിൽ ഒന്നിനെ നാം സൃഷ്ടിച്ച് വിളിക്കപ്പെടുന്ന ഫംഗ്ഷനുമായി പൊരുത്തപ്പെടുത്തും.
# അതിനുശേഷം, ഫംഗ്ഷന്റെ arguments എടുത്ത് അവ LLM-ന്റെ arguments-നോട് മാപ്പ് ചെയ്യും.
#
# അവസാനമായി, ഫംഗ്ഷൻ കോൾ സന്ദേശവും `search_courses` സന്ദേശം വഴി തിരികെ ലഭിച്ച മൂല്യങ്ങളും നാം ചേർക്കും. ഇത് LLM-ന് ഉപയോക്താവിനോട് സ്വാഭാവിക ഭാഷ ഉപയോഗിച്ച് പ്രതികരിക്കാൻ ആവശ്യമായ എല്ലാ വിവരങ്ങളും നൽകുന്നു.

# %%
# Check if the model wants to call a function
if response_message.function_call.name:
    print("Recommended Function call:")
    print(response_message.function_call.name)
    print()

    # Call the function. 
    function_name = response_message.function_call.name

    available_functions = {
            "search_courses": search_courses,
    }
    function_to_call = available_functions[function_name] 

    function_args = json.loads(response_message.function_call.arguments)
    function_response = function_to_call(**function_args)

    print("Output of function call:")
    print(function_response)
    print(type(function_response))


    # Add the assistant response and function response to the messages
    messages.append( # adding assistant response to messages
        {
            "role": response_message.role,
            "function_call": {
                "name": function_name,
                "arguments": response_message.function_call.arguments,
            },
            "content": None
        }
    )
    messages.append( # adding function response to messages
        {
            "role": "function",
            "name": function_name,
            "content":function_response,
        }
    )

# %% [markdown]
# ഇപ്പോൾ നാം അപ്ഡേറ്റ് ചെയ്ത സന്ദേശം LLM-ലേക്ക് അയയ്ക്കും, അതിലൂടെ API JSON ഫോർമാറ്റിലുള്ള മറുപടി പകരം സ്വാഭാവിക ഭാഷാ മറുപടി ലഭിക്കും.

# %%
print("Messages in next request:")
print(messages)
print()

second_response = client.chat.completions.create(
    messages=messages,
    model=deployment,
    function_call="auto",
    functions=functions,
    temperature=0
        )  # get a new response from GPT where it can see the function response


print(second_response.choices[0].message)

# %% [markdown]
# ## കോഡ് ചലഞ്ച്
#
# ശ്രേഷ്ഠമായ ജോലി! Azure Open AI Function Calling പഠനം തുടരാൻ നിങ്ങൾക്ക് നിർമ്മിക്കാം: https://learn.microsoft.com/training/support/catalog-api-developer-reference?WT.mc_id=academic-105485-koreyst
#  - പഠനാർത്ഥികൾക്ക് കൂടുതൽ കോഴ്സുകൾ കണ്ടെത്താൻ സഹായിക്കുന്ന ഫംഗ്ഷന്റെ കൂടുതൽ പാരാമീറ്ററുകൾ. ലഭ്യമായ API പാരാമീറ്ററുകൾ ഇവിടെ കണ്ടെത്താം:
#  - പഠനാർത്ഥിയുടെ മാതൃഭാഷ പോലുള്ള കൂടുതൽ വിവരങ്ങൾ സ്വീകരിക്കുന്ന മറ്റൊരു ഫംഗ്ഷൻ കോൾ സൃഷ്ടിക്കുക
#  - ഫംഗ്ഷൻ കോൾ അല്ലെങ്കിൽ API കോൾ യോജിച്ച കോഴ്സുകൾ തിരികെ നൽകാത്തപ്പോൾ പിശക് കൈകാര്യം ചെയ്യൽ സൃഷ്ടിക്കുക

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **അസൂയാ**:
# ഈ രേഖ AI വിവർത്തന സേവനം [Co-op Translator](https://github.com/Azure/co-op-translator) ഉപയോഗിച്ച് വിവർത്തനം ചെയ്തതാണ്. നാം കൃത്യതയ്ക്ക് ശ്രമിച്ചെങ്കിലും, സ്വയം പ്രവർത്തിക്കുന്ന വിവർത്തനങ്ങളിൽ പിശകുകൾ അല്ലെങ്കിൽ തെറ്റുകൾ ഉണ്ടാകാമെന്ന് ദയവായി ശ്രദ്ധിക്കുക. അതിന്റെ മാതൃഭാഷയിലുള്ള യഥാർത്ഥ രേഖയാണ് പ്രാമാണികമായ ഉറവിടം എന്ന് കരുതേണ്ടതാണ്. നിർണായക വിവരങ്ങൾക്ക്, പ്രൊഫഷണൽ മനുഷ്യ വിവർത്തനം ശുപാർശ ചെയ്യപ്പെടുന്നു. ഈ വിവർത്തനം ഉപയോഗിക്കുന്നതിൽ നിന്നുണ്ടാകുന്ന ഏതെങ്കിലും തെറ്റിദ്ധാരണകൾക്കോ തെറ്റായ വ്യാഖ്യാനങ്ങൾക്കോ ഞങ്ങൾ ഉത്തരവാദികളല്ല.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
