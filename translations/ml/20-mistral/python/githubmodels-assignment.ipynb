# %% [markdown]
# # മിസ്ട്രാൽ മോഡലുകളുമായി നിർമ്മിക്കുന്നത്
#
# ## പരിചയം
#
# ഈ പാഠം ഉൾക്കൊള്ളുന്നതാണ്:
# - വ്യത്യസ്ത മിസ്ട്രാൽ മോഡലുകൾ പരിചയപ്പെടുന്നു
# - ഓരോ മോഡലിന്റെയും ഉപയോ​ഗ-​കേസ്​കളും ദൃശ്യമന്‍‌ഥങ്ങളും യാഥാർത്ഥ്യപ്പെടുത്തുന്നു
# - ഓരോ മോഡലിന്റെയും പ്രത്യേകതകൾ കാണിക്കുന്ന കോഡ് സാമ്പിളുകൾ.

# %% [markdown]
# ## മിസ്ട്രൽ മോഡലുകൾ
#
# ഈ പാഠത്തിൽ, നാം 3 വിഭിന്ന മിസ്ട്രൽ മോഡലുകൾ പരിശോധിക്കാം:
# **മിസ്ട്രൽ വലിയവ**, **മിസ്ട്രൽ ചെറിയവ** மற்றும் **മിസ്ട്രൽ നീമോ**.
#
# ഈ മോഡലുകളിൽ ഓരോതും [Microsoft Foundry Models](https://ai.azure.com/catalog/models?WT.mc_id=academic-105485-koreyst) ൽ സൗജന്യമായി ലഭ്യമാണ്. ഈ നോട്ട്ബുക്കിലുണ്ടാകുന്ന കോഡ് ഈ മോഡലുകൾ ഉപയോഗിച്ച് പ്രവർത്തിക്കും.
#
# > **കുറിപ്പ്:** GitHub മോഡലുകൾ ജൂലൈ 2026 അവസാനം വിരമിക്കുന്നു. AI മോഡലുകളോടെ പ്രോട്ടോടൈപ്പ് ചെയ്യാൻ [Microsoft Foundry Models](https://learn.microsoft.com/azure/ai-foundry/model-inference/overview?WT.mc_id=academic-105485-koreyst) ഉപയോഗിക്കുന്നതിനെ കുറിച്ച് കൂടുതൽ വിശദാംശങ്ങൾ ഇവിടെ ഉണ്ട്.

# %% [markdown]
# ## മിസ്ട്രൽ ലാർജ് 2 (2407)
# മിസ്ട്രൽ ലാർജ് 2 ഇപ്പോള്‍ മിസ്ട്രലിന്റെ ഫ്ലാഗ്‌ഷിപ്പ് മോഡലാണ്, ഇത് സംരംഭ ഉപയോക്താക്കൾക്കുള്ളതാണ്.
#
# ഈ മോഡൽ ഓറിജിനൽ മിസ്ട്രൽ ലാർജിന്റെ അപ്ഗ്രേഡ് ആണു്, അതിൽ നൽകുന്നത്
# -  വലുതgent Context Window - 128k vs 32k
# -  ഗണിതവും കോഡിങ്ങും സംബന്ധിച്ച ജോലികളിൽ മികച്ച പ്രകടനം - ശരാശരി കൃത്യത 76.9% vs 60.4%
# -  വർദ്ധിച്ച ബഹു ഭാഷാപരമായ പ്രകടനം - ഭാഷകൾ: ഇംഗ്ലീഷ്, ഫ്രഞ്ച്, ജർമൻ, സ്പാനിഷ്, ഇറ്റാലിയൻ, പോർച്ചുഗീസ്, ഡച്ച്, റഷ്യൻ, ചൈനീസ്, ജാപ്പനീസ്, കൊറിയൻ, അറബി, ഹിന്ദി.
#
# ഈ സവിശേഷതകളോട് കൂടി, മിസ്ട്രൽ ലാർജ് മികച്ചതാണ്
# - *റിട്രീവൽ ഓഗ്മെന്റഡ് ജനറേഷൻ (RAG)* - വലിയ കോൺടെക്സ്റ്റ് വിൻഡോയുടെ കാരണം
# - *ഫംഗ്ഷൻ കോളിംഗ്* - പുറമെൻറെ ടൂളുകൾക്കും API-കൾക്കും ഇന്റഗ്രേഷൻ അനുവദിക്കുന്ന നാട്ടീവ് ഫംഗ്ഷൻ കോളിംഗ് ഈ മോഡലിന് ഉണ്ട്. ഈ കോളുകൾ ഒരുപോലെ അല്ലെങ്കിൽ ഒരു തുടർ ക്രമത്തിൽ നടത്താവുന്നതാണ്.
# - *കോഡ് ജനറേഷൻ* - പൈഥൺ, ജാവ, ടൈപ്പ്സ്ക്രിപ്റ്റും C++ ജനറേഷനിൽ മോഡൽ മികച്ച പ്രകടനം കാഴ്ചവെക്കുന്നു.

# %% [markdown]
# ### മിസ്ട്രൽ ലാർജ് 2 ഉപയോഗിച്ചുള്ള RAG ഉദാഹരണം

# %% [markdown]
# ഈ ഉദാഹരണത്തിൽ, നാം ടെക്സ്റ്റ് ഡോക്യുമെന്റിൽ RAG മാതൃക നടത്താൻ Mistral Large 2 ഉപയോഗിക്കുന്നു. ചോദ്യം കൊറിയൻ ഭാഷയിൽ എഴുതപ്പെട്ടതാണ്, അതിൽ എഴുത്തുകാരൻ കോളേജിനു മുമ്പ് നടത്തിയ പ്രവർത്തികള hakkında ചോദിക്കുന്നു.
#
# ഇത് ടെക്സ്റ്റ് ഡോക്യുമെന്റിന്റെയും ചോദ്യത്തിന്റെയും എംബെഡിങ്സ് സൃഷ്ടിക്കാൻ Cohere Embeddings Model ഉപയോഗിക്കുന്നു. ഈ മാതൃകയ്ക്കായി faiss Python പാക്കേജ് വെക്ടർ സ്റ്റോർ ആയി ഉപയോഗിക്കുന്നു.
#
# Mistral മോഡലിന് അയയ്ക്കുന്ന പ്രോമ്പ്റ്റ് ചോദ്യങ്ങളും ചോദ്യത്തിന് സമാനമായ കണ്ടെത്തിയ ചങ്കുകളും ഉൾക്കൊള്ളുന്നു. മോഡൽ പിന്നീട് സ്വാഭാവികഭാഷാ പ്രതികരണം നൽകുന്നു.

# %%
pip install faiss-cpu
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
import numpy as np
import faiss
import os

from azure.ai.inference import ChatCompletionsClient
from azure.ai.inference.models import SystemMessage, UserMessage
from azure.core.credentials import AzureKeyCredential
from azure.ai.inference import EmbeddingsClient

# Get these from your Microsoft Foundry project's "Overview" page
endpoint = os.environ["AZURE_INFERENCE_ENDPOINT"]
model_name = "Mistral-large"
token = os.environ["AZURE_INFERENCE_CREDENTIAL"]

client = ChatCompletionsClient(
    endpoint=endpoint,
    credential=AzureKeyCredential(token),
)

response = requests.get('https://raw.githubusercontent.com/run-llama/llama_index/main/docs/docs/examples/data/paul_graham/paul_graham_essay.txt')
text = response.text

chunk_size = 2048
chunks = [text[i:i + chunk_size] for i in range(0, len(text), chunk_size)]
len(chunks)

embed_model_name = "cohere-embed-v3-multilingual" 

embed_client = EmbeddingsClient(
        endpoint=endpoint,
        credential=AzureKeyCredential(token)
)

embed_response = embed_client.embed(
    input=chunks,
    model=embed_model_name
)



text_embeddings = []
for item in embed_response.data:
    length = len(item.embedding)
    text_embeddings.append(item.embedding)
text_embeddings = np.array(text_embeddings)


d = text_embeddings.shape[1]
index = faiss.IndexFlatL2(d)
index.add(text_embeddings)

question = "저자가 대학에 오기 전에 주로 했던 두 가지 일은 무엇이었나요?？"

question_embedding = embed_client.embed(
    input=[question],
    model=embed_model_name
)

question_embeddings = np.array(question_embedding.data[0].embedding)


D, I = index.search(question_embeddings.reshape(1, -1), k=2) # distance, index
retrieved_chunks = [chunks[i] for i in I.tolist()[0]]

prompt = f"""
Context information is below.
---------------------
{retrieved_chunks}
---------------------
Given the context information and not prior knowledge, answer the query.
Query: {question}
Answer:
"""


chat_response = client.complete(
    messages=[
        SystemMessage(content="You are a helpful assistant."),
        UserMessage(content=prompt),
    ],
    temperature=1.0,
    top_p=1.0,
    max_tokens=1000,
    model=model_name
)

print(chat_response.choices[0].message.content)
# Out:
# The author primarily engaged in two activities before college: writing and programming. In terms of writing, they wrote short stories, albeit not very good ones, with minimal plot and characters expressing strong feelings. For programming, they started writing programs on the IBM 1401 used for data processing during their 9th grade, at the age of 13 or 14. They used an early version of Fortran and typed programs on punch cards, later loading them into the card reader to run the program.

# %% [markdown]
# ## മിസ്‌ട്രാൽ സ്‌മാൾ
# മിസ്‌ട്രാൽ സ്‌മാൾ പ്രീമിയർ/എന്റർപ്രൈസ് വിഭാഗത്ത്ിനുള്ള മിസ്‌ട്രാലിന്റെ മറ്റൊരു മോഡലാണ്. പേരുകേട്ട് തന്നെ, ഈ മോഡൽ ഒരു സ്മാൾ ലാംഗ്വേജ് മോഡൽ (SLM) ആണ്. മിസ്‌ട്രാൽ സ്‌മാൾ ഉപയോഗിക്കുന്നതിനുള്ള ലാഭങ്ങൾ:
# - മിസ്ട്രാൽ ലാർജ്, NeMo പോലെയുള്ള മിസ്ട്രാൽ LLMകളെക്കാൾ ചെലവ് കുറഞ്ഞു - 80% വിലക്കുറവ്
# - കുറഞ്ഞ താപോവേഗം - മിസ്ട്രാൽ LLMകളെ അപേക്ഷിച്ച് വേഗത്തിലുള്ള പ്രതികരണം
# - സാന്ദ്രത - ആവശ്യമായ വിഭവങ്ങളിൽ കുറവ് നിയന്ത്രണങ്ങളോടെ വ്യത്യസ്ത പരിസരങ്ങളിൽ വിന്യസിക്കാൻ കഴിയും.
#
#
# മിസ്‌ട്രാൽ സ്‌മാൾ ഉപയോഗിക്കാൻ ഉത്തമം:
# - സംഗ്രഹീകരണം, സെൻമന്റ് വിശകലനം, ഭാഷാന്തരണം പോലുള്ള ടെക്സ്റ്റ് അടിസ്ഥാന പ്രവർത്തനങ്ങൾ
# - ചിലവു കാര്യക്ഷമത മൂലം പതിവായി അഭ്യർത്ഥനകളുള്ള ആപ്ലിക്കേഷനുകൾ
# - റിവ്യൂ, കോഡ് നിർദ്ദേശങ്ങൾ പോലുള്ള താഴ്ന്ന തടവിലുള്ള കോഡ് പ്രവർത്തനങ്ങൾ

# %% [markdown]
# ## മിസ്ട്രൽ സ്മാൾയും മിസ്ട്രൽ ലാർജും തമ്മിലുള്ള താരതമ്യം
#
# മിസ്ട്രൽ സ്മാൾയും ലാർജും തമ്മിലുള്ള വൈകിയ സമയം വ്യത്യാസം കാണിക്കാൻ, താഴെ കൊടുത്ത സെല്ലുകൾ ഓടിക്കുക.
#
# 3-5 സെക്കൻഡ് വരെ പ്രതികരണ സമയങ്ങളിൽ വ്യത്യാസം കാണാൻ സാധിക്കും. ഒരേ പ്രൊംപ്റ്റിനായി പ്രതികരണത്തിന്റെ നീളവും ശൈലിയും ശ്രദ്ധിക്കുക.

# %%
import os 
endpoint = os.environ["AZURE_INFERENCE_ENDPOINT"]
model_name = "Mistral-small"
token = os.environ["AZURE_INFERENCE_CREDENTIAL"]

client = ChatCompletionsClient(
    endpoint=endpoint,
    credential=AzureKeyCredential(token),
)

response = client.complete(
    messages=[
        SystemMessage(content="You are a helpful coding assistant."),
        UserMessage(content="Can you write a Python function to the fizz buzz test?"),
    ],
    temperature=1.0,
    top_p=1.0,
    max_tokens=1000,
    model=model_name
)

print(response.choices[0].message.content)

# %%
import os
from azure.ai.inference import ChatCompletionsClient
from azure.ai.inference.models import SystemMessage, UserMessage
from azure.core.credentials import AzureKeyCredential

endpoint = os.environ["AZURE_INFERENCE_ENDPOINT"]
model_name = "Mistral-large"
token = os.environ["AZURE_INFERENCE_CREDENTIAL"]

client = ChatCompletionsClient(
    endpoint=endpoint,
    credential=AzureKeyCredential(token),
)

response = client.complete(
    messages=[
        SystemMessage(content="You are a helpful coding assistant."),
        UserMessage(content="Can you write a Python function to the fizz buzz test?"),
    ],
    temperature=1.0,
    top_p=1.0,
    max_tokens=1000,
    model=model_name
)

print(response.choices[0].message.content)

# %% [markdown]
# ## മിസ്റ്റ്രാൽ നീമോ
#
# ഈ പാഠത്തിൽ ചർച്ചചെയ്ത മറ്റ് രണ്ടു മാതൃകകളോട് താരതമ്യപ്പെടുത്തുമ്പോൾ, മിസ്റ്റ്രാൽ നീമോ ആണ് ഒരു അപാച്ചെ2 ലൈസൻസോടെയുള്ള ഏക സൗജന്യ മാതൃക.
#
# ഇത് മിസ്റ്റ്രാലിൽ നിന്നുള്ള പഴയ ഓപ്പൺ സോഴ്‌സ് LLM ആയ മിസ്റ്റ്രാൽ 7B-നേക്കാൾ അപ്ഗ്രേഡ് ആയി കണക്കാക്കപ്പെടുന്നു.
#
# നീമോ മാതൃകയുടെ മറ്റൊരു ചില പ്രത്യേകതകൾ:
#
# - *കൂടുതൽ കാര്യക്ഷമമായ ടോക്കൺ ചെയ്യലിൽ:* ഈ മോഡൽ സാധാരണയായി ഉപയോഗിക്കുന്ന ടിക്ടോക്കന്റെ മ yerine ടേക്കൻ ടോക്കനൈസർ ഉപയോഗിക്കുന്നു. ഇത് കൂടുതൽ ഭാഷകളിലും കോഡിലും മെച്ചപ്പെട്ട പ്രവർത്തനം അനുവദിക്കുന്നു.
#
# - *ഫൈൻട്യൂണിംഗ്:* അടിസ്ഥാന മോഡൽ ഫൈൻട്യൂണിംഗിന് ലഭ്യമാണ്. ഇത് ഫൈൻട്യൂണിംഗ് ആവശ്യമായ ഉപയോഗരീതികൾക്കായി കൂടുതൽ സൗകര്യം നൽകുന്നു.
#
# - *നേറ്റീവ് ഫംഗ്ഷൻ കോളിംഗ്* - മിസ്റ്റ്രാൽ ലാർജ് പോലെ, ഈ മോഡലും ഫംഗ്ഷൻ കോളിംഗിൽ പരിശീലനം ലഭിച്ചിട്ടുണ്ട്. ഇത് ഓപ്പൺ സോഴ്‌സ് മോഡലുകളിൽ ആദ്യമായുള്ളവരിൽ ഒന്നായി അതിനെ പ്രത്യേകം വിഭിന്നമാക്കുന്നു.

# %% [markdown]
# ## മിസ്‌ട്രാൽ നീമോ
#
# ഈ പാഠத்தில் ചർച്ചചെയ്ത മറ്റു രണ്ട് മോഡൽകളുമായി താരതമ്യം ചെയ്താൽ, മിസ്‌ട്രാൽ നീമോ ആപാച്ചെ2 ലൈസൻസോടെ ലഭ്യമായ ഏക സൗജന്യ മോഡലാണ്.
#
# ഇത് മിസ്‌ട്രാലിന്റെ മുമ്പത്തെ ഓപ്പൺ സോഴ്‌സ് LLM ആയ മിസ്‌ട്രാൽ 7B-നേക്ക് ഒരു അപ്ഗ്രേഡായി കണക്കാക്കപ്പെടുന്നു.
#
# നീമോ മോഡലിന്റെ മറ്റു ചില സവിശേഷതകൾ:
#
# - *കൂടുതൽ കാര്യക്ഷമമായ ടോക്കണൈസേഷൻ:* ഈ മോഡൽ സാധാരണയായി ഉപയോഗിക്കുന്ന ടിക്കറ്റ് ടോക്കണറിന്റെ പകരം ടെക്കൻ ടോക്കണൈസർ ഉപയോഗിക്കുന്നു. ഇത് കൂടുതൽ ഭാഷകളിലും കോഡിലും മികച്ച പ്രകടനം അനുമതുനൽകുന്നു.
#
# - *ഫൈൻട്യൂണിംഗ്:* ഫൈൻട്യൂണിംഗിന് അടിസ്ഥാന മോഡൽ ലഭ്യമാണ്. ഇത് ഫൈൻട്യൂണിംഗിന് ആവശ്യമുള്ള ഉപയോഗങ്ങൾക്ക് കൂടുതൽ നൈപുണ്യം നൽകുന്നു.
#
# - *നേറ്റീവ് ഫംഗ്ഷൻ കോളിംഗ്* - മിസ്‌ട്രാൽ ലാർജിൻപോലെ, ഈ മോഡൽ ഫംഗ്ഷൻ കോളിങ്ങിൽ പരിശീലിപ്പിച്ചിട്ടുണ്ട്. ഇത് ഓപ്പൺ സോഴ്‌സ് മോഡലുകളിൽ ഒന്നാമതായി ഇത്തരം കഴിവുള്ളതാക്കുന്നു.

# %% [markdown]
# ### ടോക്കൺൈസർമാരെ താരതമ്യം ചെയ്യുക
#
# ഈ സാമ്പിളിൽ, Mistral NeMo ടോക്കൺൈസേഷൻ എങ്ങനെ കൈകാര്യം ചെയ്യുന്നു എന്ന് Mistral Large-നൊപ്പം താരതമ്യം ചെയ്ത് നോക്കാം.
#
# രണ്ട് സാമ്പിളുകളും ഒരേ പ്രോംപ്റ്റ് ഉപയോഗിക്കുന്നു, എന്നാൽ NeMoൽ നിന്ന് Mistral Large-നേക്കാൾ കുറവ് ടോക്കണുകൾ ലഭിക്കുന്നതായി നിങ്ങൾ കാണേണ്ടതാണ്.

# %%
pip install mistral-common
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 63.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 19.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 16.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 797.0/797.0 kB 15.1 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import needed packages:
from mistral_common.protocol.instruct.messages import (
    UserMessage,
)
from mistral_common.protocol.instruct.request import ChatCompletionRequest
from mistral_common.protocol.instruct.tool_calls import (
    Function,
    Tool,
)
from mistral_common.tokens.tokenizers.mistral import MistralTokenizer

# Load Mistral tokenizer

model_name = "open-mistral-nemo	"

tokenizer = MistralTokenizer.from_model(model_name)

# Tokenize a list of messages
tokenized = tokenizer.encode_chat_completion(
    ChatCompletionRequest(
        tools=[
            Tool(
                function=Function(
                    name="get_current_weather",
                    description="Get the current weather",
                    parameters={
                        "type": "object",
                        "properties": {
                            "location": {
                                "type": "string",
                                "description": "The city and state, e.g. San Francisco, CA",
                            },
                            "format": {
                                "type": "string",
                                "enum": ["celsius", "fahrenheit"],
                                "description": "The temperature unit to use. Infer this from the users location.",
                            },
                        },
                        "required": ["location", "format"],
                    },
                )
            )
        ],
        messages=[
            UserMessage(content="What's the weather like today in Paris"),
        ],
        model=model_name,
    )
)
tokens, text = tokenized.tokens, tokenized.text

# Count the number of tokens
print(len(tokens))
# Out:
# 128

# %%
# Import needed packages:
from mistral_common.protocol.instruct.messages import (
    UserMessage,
)
from mistral_common.protocol.instruct.request import ChatCompletionRequest
from mistral_common.protocol.instruct.tool_calls import (
    Function,
    Tool,
)
from mistral_common.tokens.tokenizers.mistral import MistralTokenizer

# Load Mistral tokenizer

model_name = "mistral-large-latest"

tokenizer = MistralTokenizer.from_model(model_name)

# Tokenize a list of messages
tokenized = tokenizer.encode_chat_completion(
    ChatCompletionRequest(
        tools=[
            Tool(
                function=Function(
                    name="get_current_weather",
                    description="Get the current weather",
                    parameters={
                        "type": "object",
                        "properties": {
                            "location": {
                                "type": "string",
                                "description": "The city and state, e.g. San Francisco, CA",
                            },
                            "format": {
                                "type": "string",
                                "enum": ["celsius", "fahrenheit"],
                                "description": "The temperature unit to use. Infer this from the users location.",
                            },
                        },
                        "required": ["location", "format"],
                    },
                )
            )
        ],
        messages=[
            UserMessage(content="What's the weather like today in Paris"),
        ],
        model=model_name,
    )
)
tokens, text = tokenized.tokens, tokenized.text

# Count the number of tokens
print(len(tokens))
# Out:
# 135

# %% [markdown]
# ## പഠനം ഇതിൽ അവസാനിക്കുന്നില്ല, യാത്ര തുടരുക
#
# ഈ പാഠം പൂർത്തിയാക്കിയശേഷം, നിങ്ങളുടെ ജനറേറ്റീവ് AI ജ്ഞാനം മെച്ചപ്പെടുത്താൻ ഞങ്ങളുടെ [ജനറേറ്റീവ് AI പഠന ശേഖരം](https://aka.ms/genai-collection?WT.mc_id=academic-105485-koreyst) പരിശോധിക്കുക!

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **അറിയിപ്പ്**:
# ഈ രേഖ AI പരിഭാഷാ സേവനം [Co-op Translator](https://github.com/Azure/co-op-translator) ഉപയോഗിച്ച് പരിഭാഷപ്പെടുത്തിയതാണ്. ഞങ്ങൾ കൃത്യതയ്ക്കായി ശ്രമിക്കുന്നുവെങ്കിലും, ഓട്ടോമേറ്റഡ് പരിഭാഷകളിൽ പിഴവുകൾ അല്ലെങ്കിൽ തെറ്റായ വിവരങ്ങൾ ഉണ്ടാകാൻ സാധ്യതയുണ്ട്. അതിന്റെ സ്വാഭാവിക ഭാഷയിലുള്ള അസൽ രേഖയാണ് പ്രാമാണികമായ ഉറവിടമായി പരിഗണിക്കേണ്ടത്. നിർണായകമായ വിവരങ്ങൾക്ക്, പ്രൊഫഷണൽ മനുഷ്യ പരിഭാഷ ശുപാർശ ചെയ്യുന്നു. ഈ പരിഭാഷ ഉപയോഗിച്ച് ഉണ്ടാകുന്ന തെറ്റിദ്ധാരണകൾ അല്ലെങ്കിൽ തെറ്റായ വ്യാഖ്യാനങ്ങൾക്കായി ഞങ്ങൾ ഉത്തരവാദികളല്ല.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
