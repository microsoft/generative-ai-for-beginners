# %% [markdown]
# # മിസ്ട്രൽ മോഡലുകളുമായി നിർമ്മാണം
#
# ## പരിചയം
#
# ഈ പാഠത്തിൽ ഉൾപ്പെടുന്നത്:
# - വിവിധ മിസ്ട്രൽ മോഡലുകളെ അന്വേഷിക്കൽ
# - ഓരോ മോഡലിനും അനുയോജ്യമായ ഉപയോഗ-кേസുകളും സന്നിവേശങ്ങളും മനസിലാക്കൽ
# - ഓരോ മോഡലിന്റെയും പ്രത്യേക സവിശേഷതകളെ കാണിക്കുന്ന കോഡ് ഉദാഹരണങ്ങൾ.

# %% [markdown]
# ## മിസ്ട്രൽ മോഡലുകൾ
#
# ഈ പാഠത്തിൽ, നാം മൂന്ന് വ്യത്യസ്ത മിസ്ട്രൽ മോഡലുകൾ പരിശോധിക്കും:
# **മിസ്ട്രൽ ലാർജ്**, **മിസ്ട്രൽ സ്‌മോൾ**, һәм **മിസ്ട്രൽ നിമോ**.
#
# ഈ മോഡലുകൾ ഓരോന്നും [Microsoft Foundry Models](https://ai.azure.com/catalog/models?WT.mc_id=academic-105485-koreyst)ലിൽ സൗജന്യമായി ലഭ്യമാണ്. ഈ നോട്ട്‌ബുക്കിലെ കോഡ് ഈ മോഡലുകൾ ഉപയോഗിച്ച് പ്രവർത്തിക്കും.
#
# > **കുറിപ്പ്:** GitHub മോഡലുകൾ 2026 ജൂലൈ അവസാനം വിരമിക്കുന്നു. AI മോഡലുകളുമായി പ്രോട്ടോടൈപ്പ് ചെയ്യുന്നതിന് [Microsoft Foundry Models](https://learn.microsoft.com/en-us/azure/ai-foundry/model-inference/overview?WT.mc_id=academic-105485-koreyst) ഉപയോഗിക്കുന്നതിന്റെ കൂടുതൽ വിവരങ്ങൾ ഇവിടെ ഉണ്ട്.

# %% [markdown]
# ## Mistral Large 2 (2407)
# Mistral Large 2 ഇപ്പോൾ Mistral കമ്പനിയുടേയും ഫ്‌ളാഗ്ഷിപ്പ് മോഡലും എന്റർപ്രൈസുകൾക്ക് രൂപകല്‍പ്പന ചെയ്‌തിരിക്കുന്നു.
#
# ഈ മോഡൽ, യഥാർത്ഥ Mistral Large നുള്ള അപ്ഗ്രേഡ് ആണു്, കൂടാതെ
# -  വലുതായ കോൺടെക്സ്‌റ്റ് വിൻഡോ - 128k എതിരിൽ 32k
# -  ഗണിതം, കോഡിംഗ് ടാസ്കുകളിൽ മെച്ചപ്പെട്ട പ്രകടനം - ശരാശരി കൃത്യത 76.9% എതിരിൽ 60.4%
# -  ബഹുഭാഷ വിദഗ്ധത ഉയർന്നിട്ടുണ്ട് - ഉൾക്കൊള്ളുന്ന ഭാഷകൾ: ഇംഗ്ലീഷ്, ഫ്രഞ്ച്, ജർമ്മൻ, സ്‌പാനീഷ്, ഇറ്റാലീയൻ, പോർച്ചുഗീസ്, ഡച്ച്, റഷ്യൻ, ചൈനീസ്, ജാപ്പനീസ്, കൊറിയൻ, അറബിക്, ഹിന്ദി.
#
# ഈ സവിശേഷതകളോടെ, Mistral Large ചാർച്ച ചെയ്യുന്നതിൽ ബഹുമുഖവത്കരണത്തിലുണ്ട്
# - *രിറ്റ്രീവൽ ഓഗ്മെൻറഡ് ജനറേഷൻ (RAG)* - വലുതായ കോൺടെക്സ്‌റ്റ് വിൻഡോയിലുണ്ടായതുകൊണ്ടു്
# - *ഫങ്ക്ഷൻ കോൾ* - ഈ മോഡലിന് നേറ്റീവ് ഫംഗ്ഷൻ കോൾ ഉണ്ട്; ഇത് ബാഹ്യ ഉപകരണങ്ങളും API കളുമായി ഇന്റഗ്രേഷൻ ചെയ്യാൻ അനുവദിക്കുന്നു. ഈ കോൾകൾ സാന്ത്വനത്തിലും തുടർച്ചയായി ഒരിനെങ്കിലും ക്രമത്തിൽ നടത്താവുന്നതാണ്.
# - *കോഡ് ജനറേഷൻ* - ഈ മോഡൽ പൈതൺ, ജാവ, ടൈപ്പ്സ്ക്രിപ്റ്റ്, സി++ ജനറേഷനിൽ മികച്ച പ്രകടനം കാഴ്ചവെക്കുന്നു.

# %% [markdown]
# ### മിസ്ട്രാൽ ലാർജ് 2 ഉപയോഗിച്ച് RAG ഉദാഹരണം

# %% [markdown]
# ഈ ഉദാഹരണത്തിൽ, ഒരു എഴുത്ത് ഡോക്യുമെന്റിന്മേൽ RAG പാറ്റേൺ നടപ്പിലാക്കാൻ Mistral Large 2 ഉപയോഗിക്കുന്നു. ചോദ്യം കൊറിയൻ ഭാഷയിൽ എഴുതിയതാണ്, അത് കോളേജിന് മുമ്പത്തെ എഴുത്തുകാരന്റെ പ്രവർത്തനങ്ങളെക്കുറിച്ച് ചോദിക്കുന്നു.
#
# Cocohere Embeddings മോഡൽ ഉപയോഗിച്ച് എഴുത്ത് ഡോക്യുമെന്റിന്റെയും ചോദ്യത്തിന്റെയും എംബഡിംഗുകൾ സൃഷ്ടിക്കുന്നു. ഈ മാതൃകയിൽ, faiss Python പാക്കേജ് വെക്ടർ സ്റ്റോറായി ഉപയോഗിക്കുന്നു.
#
# Mistral മോഡലിലേക്ക് സമർപ്പിക്കുന്ന പ്രോമ്പ്റ്റിൽ ചോദ്യങ്ങളും ചോദ്യവുമായി സമാനമായ തിരിഞ്ഞെടുത്ത ചങ്കുകളും ഉൾപ്പെടുത്തുന്നു. മോഡൽ പിന്നീട് സ്വാഭാവിക ഭാഷാ പ്രതികരണമ നൽകുന്നു.

# %%
pip install faiss-cpu
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
import numpy as np
import faiss
import os

from azure.ai.inference import ChatCompletionsClient
from azure.ai.inference.models import SystemMessage, UserMessage
from azure.core.credentials import AzureKeyCredential
from azure.ai.inference import EmbeddingsClient

# Get these from your Microsoft Foundry project's "Overview" page
endpoint = os.environ["AZURE_INFERENCE_ENDPOINT"]
model_name = "Mistral-large"
token = os.environ["AZURE_INFERENCE_CREDENTIAL"]

client = ChatCompletionsClient(
    endpoint=endpoint,
    credential=AzureKeyCredential(token),
)

response = requests.get('https://raw.githubusercontent.com/run-llama/llama_index/main/docs/docs/examples/data/paul_graham/paul_graham_essay.txt')
text = response.text

chunk_size = 2048
chunks = [text[i:i + chunk_size] for i in range(0, len(text), chunk_size)]
len(chunks)

embed_model_name = "cohere-embed-v3-multilingual" 

embed_client = EmbeddingsClient(
        endpoint=endpoint,
        credential=AzureKeyCredential(token)
)

embed_response = embed_client.embed(
    input=chunks,
    model=embed_model_name
)



text_embeddings = []
for item in embed_response.data:
    length = len(item.embedding)
    text_embeddings.append(item.embedding)
text_embeddings = np.array(text_embeddings)


d = text_embeddings.shape[1]
index = faiss.IndexFlatL2(d)
index.add(text_embeddings)

question = "저자가 대학에 오기 전에 주로 했던 두 가지 일은 무엇이었나요?？"

question_embedding = embed_client.embed(
    input=[question],
    model=embed_model_name
)

question_embeddings = np.array(question_embedding.data[0].embedding)


D, I = index.search(question_embeddings.reshape(1, -1), k=2) # distance, index
retrieved_chunks = [chunks[i] for i in I.tolist()[0]]

prompt = f"""
Context information is below.
---------------------
{retrieved_chunks}
---------------------
Given the context information and not prior knowledge, answer the query.
Query: {question}
Answer:
"""


chat_response = client.complete(
    messages=[
        SystemMessage(content="You are a helpful assistant."),
        UserMessage(content=prompt),
    ],
    temperature=1.0,
    top_p=1.0,
    max_tokens=1000,
    model=model_name
)

print(chat_response.choices[0].message.content)
# Out:
# The author primarily engaged in two activities before college: writing and programming. In terms of writing, they wrote short stories, albeit not very good ones, with minimal plot and characters expressing strong feelings. For programming, they started writing programs on the IBM 1401 used for data processing during their 9th grade, at the age of 13 or 14. They used an early version of Fortran and typed programs on punch cards, later loading them into the card reader to run the program.

# %% [markdown]
# ## മിസ്ട്രാൽ স্মാൾ
# മിസ്ട്രാൽ স্মാൾ പ്രീമിയർ/എന്റർപ്രൈസ് വിഭാഗത്തിൽപ്പെട്ട മിസ്ട്രാൽ കുടുംബത്തിലെ മറ്റൊരു മോഡലാണ്. പേരും സൂചിപ്പിച്ചതുപോലെ, ഈ മോഡൽ ഒരു സ്മാൾ ഭാഷാ മോഡലാണ് (SLM). മിസ്ട്രാൽ স্মാൾ ഉപയോഗിക്കുന്നതിനുള്ള ലാഭങ്ങൾ താഴെപ്പറയുന്നതുപോലെയാണ്:
# - മിസ്ട്രാൽ LLMകൾ പോലുള്ള മിസ്ട്രാൾ ലാർജും നീമോയുടെ ഉപരീതമായി ചിലവ് ലഘൂകരിക്കൽ - 80% വില കുറവ്
# - കുറവ് വൈകല്യം - മിസ്ട്രാലിന്റെ LLMകൾക്കു സമാന്തരമായി വേഗതയുള്ള പ്രതികരണം
# - ഫ്ലെക്സിബിൾ - ആവശ്യമായ വിഭവങ്ങളിൽ കുറവുള്ള നിയന്ത്രണത്തോടെ വ്യത്യസ്ത പരിതസ്ഥിതികൾക്ക് അനുസരിച്ച് വിനിയോഗിക്കാനാകുന്നു.
#
#
# മിസ്ട്രാൽ স্মാൾ ഈ തരം ഉപയോഗങ്ങൾക്ക് അനുയോജ്യമാണ്:
# - സംഗ്രഹിക്കൽ, മനോഭാവ വിശകലനം, വിവർത്തനങ്ങളുടെ പോലെ എഴുത്ത് അടിസ്ഥാനത്തിലുള്ള പ്രവർത്തനങ്ങൾ
# - കുറഞ്ഞ ചിലവിന്റെ ഫലമായി പലപ്പോഴും അഭ്യർത്ഥനകൾ വരിക ചെയ്യുന്ന അപ്ലിക്കേഷനുകൾ
# - അവലോകനം, കോഡ് നിർദ്ദേശങ്ങൾ പോലുള്ള വേഗതാപരമായ കോഡ് പ്രവർത്തനങ്ങൾ

# %% [markdown]
# ## മിസ്ട്രാൽ സ്മോൾയും മിസ്ട്രാൽ ലാർജും തമ്മിൽ താരതമ്യം
#
# മിസ്ട്രാൽ സ്മോൾക്കും ലാർജിനും ഇടയിലുള്ള ലാറ്റൻസി വ്യത്യാസങ്ങൾ കാണിക്കാൻ താഴെ കൊടുത്തിരിക്കുന്ന സെല്ലുകൾ പ്രവർത്തിപ്പിക്കുക.
#
# 3-5 സെക്കൻഡ്സ് വരെ പ്രതികരണ സമയങ്ങളിൽ മാറ്റം കാണാൻ സാധിക്കും. ഒരേ പ്രമ്പ്റ്റിലൂടെ പ്രതികരണ ദൈർഘ്യവും ശൈലിയും ശ്രദ്ധിക്കുക.

# %%
import os 
endpoint = os.environ["AZURE_INFERENCE_ENDPOINT"]
model_name = "Mistral-small"
token = os.environ["AZURE_INFERENCE_CREDENTIAL"]

client = ChatCompletionsClient(
    endpoint=endpoint,
    credential=AzureKeyCredential(token),
)

response = client.complete(
    messages=[
        SystemMessage(content="You are a helpful coding assistant."),
        UserMessage(content="Can you write a Python function to the fizz buzz test?"),
    ],
    temperature=1.0,
    top_p=1.0,
    max_tokens=1000,
    model=model_name
)

print(response.choices[0].message.content)

# %%
import os
from azure.ai.inference import ChatCompletionsClient
from azure.ai.inference.models import SystemMessage, UserMessage
from azure.core.credentials import AzureKeyCredential

endpoint = os.environ["AZURE_INFERENCE_ENDPOINT"]
model_name = "Mistral-large"
token = os.environ["AZURE_INFERENCE_CREDENTIAL"]

client = ChatCompletionsClient(
    endpoint=endpoint,
    credential=AzureKeyCredential(token),
)

response = client.complete(
    messages=[
        SystemMessage(content="You are a helpful coding assistant."),
        UserMessage(content="Can you write a Python function to the fizz buzz test?"),
    ],
    temperature=1.0,
    top_p=1.0,
    max_tokens=1000,
    model=model_name
)

print(response.choices[0].message.content)

# %% [markdown]
# ## മിസ്ട്രൽ നിയോ
#
# ഈ പാഠത്തിൽ ചർച്ച ചെയ്ത മറ്റ് രണ്ട് മാതൃകകളെ അപേക്ഷിച്ച്, മിസ്ട്രൽ നിയോ അപാച്ചി2 ലൈസൻസ് ഉള്ള ഏക இலവസമാറ്റ മോഡലാണ്.
#
# ഇത് മിസ്ട്രലിന്റെ മുമ്പത്തെ ഓപ്പൺ സോഴ്‌സ് LLM ആയ മിസ്ട്രൽ 7B യുടെ അപ്ഗ്രേഡ് ആയി കാണപ്പെടുന്നു.
#
# നീയോ മോഡലിന്റെ മറ്റെന്താനും ചില പ്രത്യേകതകൾ ഇവയാണ്:
#
# - *കൂടുതൽ കാര്യക്ഷമമായ ടോക്കൺവൽക്കൽ:* ഈ മോഡൽ സാധാരണയായി ഉപയോഗിക്കുന്ന ടിക്ടോക്കനിനെ അപേക്ഷിച്ച് ടെക്കൻ ടോക്കനെർ ഉപയോഗിക്കുന്നു. ഇത് കൂടുതൽ ഭാഷകളിലും കോഡിലും മെച്ചപ്പെട്ട പ്രകടനം നൽകുന്നു.
#
# - *ഫൈൻട്യൂണിംഗ്:* ബേസ് മോഡൽ ഫൈൻട്യൂണിംഗിനായി ലഭ്യമാണ്. ഇത് ഫൈൻട്യൂണിംഗ് ആവശ്യമുള്ള ഉപയോഗകേസുകൾക്ക് കൂടുതൽ സൗകര്യം നൽകുന്നു.
#
# - *നേറ്റീവ് ഫംഗ്ഷൻ കോളിംഗ്* - മിസ്‌ട്രൽ ലാർജിനുപോലെ, ഈ മോഡൽ ഫംഗ്ഷൻ കോളിംഗിൽ പരിശീലിപ്പിച്ചിരിക്കുന്നു. ഇത് ഓപ്പൺ സോഴ്‌സ് മോഡലുകളിൽ ആദ്യ പടിയിലൊന്നായി ഇതിനെ ഉപയോഗപ്രദമാക്കുന്നു.

# %% [markdown]
# ## മിസ്ട്രാൽ നീമോ
#
# ഈ പാഠത്തിൽ ചർച്ചചെയ്‌ത മുകളിലുള്ള രണ്ട് മോഡലുകളുമായി താരതമ്യപ്പെടുത്തുമ്പോൾ, മിസ്ട്രാൽ നീമോ മാത്രം Apache2 ലൈസൻസുള്ള സൗജന്യ മോഡലാണ്.
#
# ഇത് മുമ്പത്തെ തുറസ്സായ സ്രോതസ്സുള്ള LLM ആയ മിസ്ട്രാൽ 7B-ന്റെ അപ്ഗ്രേഡായി കാണപ്പെടുന്നു.
#
# നീമോ മോഡലിന്റെ ചില മറ്റ് സവിശേഷതകൾ:
#
# - *കൂടുതൽ കാര്യക്ഷമമായ ടോക്കിനൈസേഷൻ:* ഈ മോഡൽ പൊതുവായി ഉപയോഗിക്കുന്ന tiktoken-നേക്കാൾ TekkenTokenizer ഉപയോഗിക്കുന്നു. ഇത് കൂടുതൽ ഭാഷകളിലും കോഡിലും മികച്ച പ്രകടനം നൽകുന്നു.
#
# - *ഫൈന്റ്റ്യൂണിംഗ്:* അടിസ്ഥാന മോഡൽ ഫൈന്റ്റ്യൂണിംഗിനായി ലഭ്യമാണ്. ഫൈന്റ്റ്യൂണിംഗ് ആവശ്യമായ ഉപയോഗകേസുകൾക്ക് കൂടുതൽ സൗകര്യമാർത്തിക്കുന്നു.
#
# - *പുരാതന ഫംഗ്ഷൻ കോളിംഗ്* - മിസ്ട്രാൽ ലാർജിനെ പോലെ, ഈ മോഡലും ഫംഗ്ഷൻ കോളിംഗിൽ പരിശീലിപ്പിച്ചിട്ടുണ്ട്. ഇത് ഇത് ആദ്യത്തെ തുറന്ന സ്രോതസ്സ് മോഡലുകളിൽ ഒന്നായി അതിനെ പ്രത്യേകമാക്കുന്നു.

# %% [markdown]
# ### ടോക്കനൈസർമാരുടെ താരതമ്യം
#
# ഈ സാമ്പിളിൽ, Mistral Large നെ പകരം Mistral NeMo ടോക്കനൈസേഷൻ എങ്ങനെ കൈകാര്യം ചെയ്യുന്നു എന്നതിനെക്കുറിച്ച് നോക്കാം.
#
# ഇരുപാടുകളും ഒരേസമയം പ്രൊംപ്റ്റ് സ്വീകരിക്കുന്നുവെങ്കിലും NeMo മടക്കമായി കുറവ് ടോക്കണുകൾ നൽകുമെന്ന് നിങ്ങൾ കാണും, Mistral Large നെപ്പറ്റി.

# %%
pip install mistral-common
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 63.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 19.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 16.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 797.0/797.0 kB 15.1 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import needed packages:
from mistral_common.protocol.instruct.messages import (
    UserMessage,
)
from mistral_common.protocol.instruct.request import ChatCompletionRequest
from mistral_common.protocol.instruct.tool_calls import (
    Function,
    Tool,
)
from mistral_common.tokens.tokenizers.mistral import MistralTokenizer

# Load Mistral tokenizer

model_name = "open-mistral-nemo	"

tokenizer = MistralTokenizer.from_model(model_name)

# Tokenize a list of messages
tokenized = tokenizer.encode_chat_completion(
    ChatCompletionRequest(
        tools=[
            Tool(
                function=Function(
                    name="get_current_weather",
                    description="Get the current weather",
                    parameters={
                        "type": "object",
                        "properties": {
                            "location": {
                                "type": "string",
                                "description": "The city and state, e.g. San Francisco, CA",
                            },
                            "format": {
                                "type": "string",
                                "enum": ["celsius", "fahrenheit"],
                                "description": "The temperature unit to use. Infer this from the users location.",
                            },
                        },
                        "required": ["location", "format"],
                    },
                )
            )
        ],
        messages=[
            UserMessage(content="What's the weather like today in Paris"),
        ],
        model=model_name,
    )
)
tokens, text = tokenized.tokens, tokenized.text

# Count the number of tokens
print(len(tokens))
# Out:
# 128

# %%
# Import needed packages:
from mistral_common.protocol.instruct.messages import (
    UserMessage,
)
from mistral_common.protocol.instruct.request import ChatCompletionRequest
from mistral_common.protocol.instruct.tool_calls import (
    Function,
    Tool,
)
from mistral_common.tokens.tokenizers.mistral import MistralTokenizer

# Load Mistral tokenizer

model_name = "mistral-large-latest"

tokenizer = MistralTokenizer.from_model(model_name)

# Tokenize a list of messages
tokenized = tokenizer.encode_chat_completion(
    ChatCompletionRequest(
        tools=[
            Tool(
                function=Function(
                    name="get_current_weather",
                    description="Get the current weather",
                    parameters={
                        "type": "object",
                        "properties": {
                            "location": {
                                "type": "string",
                                "description": "The city and state, e.g. San Francisco, CA",
                            },
                            "format": {
                                "type": "string",
                                "enum": ["celsius", "fahrenheit"],
                                "description": "The temperature unit to use. Infer this from the users location.",
                            },
                        },
                        "required": ["location", "format"],
                    },
                )
            )
        ],
        messages=[
            UserMessage(content="What's the weather like today in Paris"),
        ],
        model=model_name,
    )
)
tokens, text = tokenized.tokens, tokenized.text

# Count the number of tokens
print(len(tokens))
# Out:
# 135

# %% [markdown]
# ## പഠനം ഇവിടെ നിർത്തരുത്, യാത്ര തുടരുക
#
# ഈ പാഠം പൂർത്തിയാക്കിയ ശേഷം, നിങ്ങളുടെ ജനറേറ്റീവ് AI അറിവ് കൂടുതല്‍ മെച്ചപ്പെടുത്താൻ ഞങ്ങളുടെ [Generative AI Learning collection](https://aka.ms/genai-collection?WT.mc_id=academic-105485-koreyst) പരിശോധിച്ച് കാണൂ!

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **അറിയിപ്പ്**:
# ഈ രേഖ AI പരിഭാഷാ സേവനം [Co-op Translator](https://github.com/Azure/co-op-translator) ഉപയോഗിച്ച് പരിഭാഷപ്പെടുത്തിയതാണ്. ഞങ്ങൾ കൃത്യതയ്ക്കായി ശ്രമിക്കുന്നുവെങ്കിലും, ഓട്ടോമേറ്റഡ് പരിഭാഷകളിൽ പിഴവുകൾ അല്ലെങ്കിൽ തെറ്റായ വിവരങ്ങൾ ഉണ്ടാകാൻ സാധ്യതയുണ്ട്. അതിന്റെ സ്വാഭാവിക ഭാഷയിലുള്ള അസൽ രേഖയാണ് പ്രാമാണികമായ ഉറവിടമായി പരിഗണിക്കേണ്ടത്. നിർണായകമായ വിവരങ്ങൾക്ക്, പ്രൊഫഷണൽ മനുഷ്യ പരിഭാഷ ശുപാർശ ചെയ്യുന്നു. ഈ പരിഭാഷ ഉപയോഗിച്ച് ഉണ്ടാകുന്ന തെറ്റിദ്ധാരണകൾ അല്ലെങ്കിൽ തെറ്റായ വ്യാഖ്യാനങ്ങൾക്കായി ഞങ്ങൾ ഉത്തരവാദികളല്ല.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
