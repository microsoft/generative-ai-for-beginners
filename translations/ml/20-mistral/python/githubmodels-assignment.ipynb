# %% [markdown]
# # Mistral മോഡലുകളുമായി നിർമ്മാണം
#
# ## പരിചയം
#
# ഈ പാഠം ഉൾക്കൊള്ളുന്നതാണ്:
# - വ്യത്യസ്ത Mistral മോഡലുകൾ പരിശോധിക്കൽ
# - ഓരോ മോഡലിന്റെയും ഉപയോഗ കേസുകളും സാഹചര്യങ്ങളും മനസിലാക്കൽ
# - ഓരോ മോഡലിന്റെയും പ്രത്യേകതകൾ കാണിക്കുന്ന കോഡ് സാമ്പിളുകൾ.

# %% [markdown]
# ## ദ മിസ്ട്രാൽ മോഡലുകൾ
#
# ഈ പാഠത്തിൽ, നാം 3 വ്യത്യസ്ത മിസ്ട്രാൽ മോഡലുകൾ പരിശോധിക്കും:
# **മിസ്ട്രാൽ ലാർജ്**, **മിസ്ട്രാൽ സ്മോൾ** және **മിസ്ട്രാൽ നിമോ**.
#
# ഈ മോഡലുകൾ ഓരോന്നും ഗിത്തബ് മോഡൽ മാർക്കറ്റ്പ്ലേസിൽ സൗജന്യമായി ലഭ്യമാണ്. ഈ നോട്ട്‌ബുക്കിലെ കോഡ് ഈ മോഡലുകൾ ഉപയോഗിച്ച് പ്രവർത്തിക്കും. ഗിത്തബ് മോഡലുകൾ ഉപയോഗിച്ച് [AI മോഡലുകളുമായി പ്രോട്ടോടൈപ്പ് ചെയ്യുന്നതിനെക്കുറിച്ച്](https://docs.github.com/en/github-models/prototyping-with-ai-models?WT.mc_id=academic-105485-koreyst) കൂടുതൽ വിവരങ്ങൾ ഇവിടെ ലഭ്യമാണ്.

# %% [markdown]
# ## Mistral Large 2 (2407)
# Mistral Large 2 നിലവിൽ Mistral-ന്റെ ഫ്ലാഗ്ഷിപ്പ് മോഡലാണ്, ഇത് എന്റർപ്രൈസ് ഉപയോഗത്തിനായി രൂപകൽപ്പന ചെയ്തതാണ്.
#
# മോഡൽ ഒറിജിനൽ Mistral Large-ന്റെ അപ്ഗ്രേഡാണ്, ഇത് നൽകുന്നു
# -  വലുതായ കോൺടെക്സ്റ്റ് വിൻഡോ - 128k vs 32k
# -  ഗണിതവും കോഡിങ്ങ് ടാസ്കുകളിലും മെച്ചപ്പെട്ട പ്രകടനം - ശരാശരി കൃത്യത 76.9% vs 60.4%
# -  വർദ്ധിച്ച ബഹുഭാഷാ പ്രകടനം - ഭാഷകൾ ഉൾപ്പെടുന്നു: ഇംഗ്ലീഷ്, ഫ്രഞ്ച്, ജർമ്മൻ, സ്പാനിഷ്, ഇറ്റാലിയൻ, പോർച്ചുഗീസ്, ഡച്ച്, റഷ്യൻ, ചൈനീസ്, ജാപ്പനീസ്, കൊറിയൻ, അറബിക്, ഹിന്ദി.
#
# ഈ സവിശേഷതകളോടെ, Mistral Large മികച്ചത്
# - *Retrieval Augmented Generation (RAG)* - വലുതായ കോൺടെക്സ്റ്റ് വിൻഡോ കാരണം
# - *Function Calling* - ഈ മോഡലിന് നേറ്റീവ് ഫംഗ്ഷൻ കോളിംഗ് ഉണ്ട്, ഇത് ബാഹ്യ ടൂളുകളും API-കളും ഇന്റഗ്രേറ്റ് ചെയ്യാൻ അനുവദിക്കുന്നു. ഈ കോളുകൾ പരലൽ ആയി അല്ലെങ്കിൽ പരമ്പരാഗത ക്രമത്തിൽ ഒരുമിച്ച് നടത്താം.
# - *Code Generation* - Python, Java, TypeScript, C++ ജനറേഷനിൽ ഈ മോഡൽ മികച്ച പ്രകടനം കാണിക്കുന്നു.

# %% [markdown]
# ### മിസ്ട്രൽ ലാർജ് 2 ഉപയോഗിച്ച് RAG ഉദാഹരണം

# %% [markdown]
# ഈ ഉദാഹരണത്തിൽ, ഒരു ടെക്സ്റ്റ് ഡോക്യുമെന്റിൽ RAG പാറ്റേൺ പ്രവർത്തിപ്പിക്കാൻ Mistral Large 2 ഉപയോഗിക്കുന്നു. ചോദ്യം കൊറിയൻ ഭാഷയിൽ എഴുതപ്പെട്ടതാണ്, കോളേജിന് മുമ്പ് എഴുത്തുകാരൻ നടത്തിയ പ്രവർത്തനങ്ങളെക്കുറിച്ചാണ്.
#
# ടെക്സ്റ്റ് ഡോക്യുമെന്റിന്റെയും ചോദ്യത്തിന്റെയും എംബെഡിംഗുകൾ സൃഷ്ടിക്കാൻ Cohere Embeddings Model ഉപയോഗിക്കുന്നു. ഈ സാമ്പിളിനായി, വെക്ടർ സ്റ്റോറായി faiss Python പാക്കേജ് ഉപയോഗിക്കുന്നു.
#
# Mistral മോഡലിലേക്ക് അയക്കുന്ന പ്രോംപ്റ്റിൽ ചോദ്യങ്ങളും ചോദ്യത്തിന് സമാനമായ തിരികെ ലഭിച്ച ഭാഗങ്ങളും ഉൾപ്പെടുന്നു. മോഡൽ പിന്നീട് സ്വാഭാവിക ഭാഷാ പ്രതികരണം നൽകുന്നു.

# %%
pip install faiss-cpu
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
import numpy as np
import faiss
import os

from azure.ai.inference import ChatCompletionsClient
from azure.ai.inference.models import SystemMessage, UserMessage
from azure.core.credentials import AzureKeyCredential
from azure.ai.inference import EmbeddingsClient

endpoint = "https://models.inference.ai.azure.com"
model_name = "Mistral-large"
token = os.environ["GITHUB_TOKEN"]

client = ChatCompletionsClient(
    endpoint=endpoint,
    credential=AzureKeyCredential(token),
)

response = requests.get('https://raw.githubusercontent.com/run-llama/llama_index/main/docs/docs/examples/data/paul_graham/paul_graham_essay.txt')
text = response.text

chunk_size = 2048
chunks = [text[i:i + chunk_size] for i in range(0, len(text), chunk_size)]
len(chunks)

embed_model_name = "cohere-embed-v3-multilingual" 

embed_client = EmbeddingsClient(
        endpoint=endpoint,
        credential=AzureKeyCredential(token)
)

embed_response = embed_client.embed(
    input=chunks,
    model=embed_model_name
)



text_embeddings = []
for item in embed_response.data:
    length = len(item.embedding)
    text_embeddings.append(item.embedding)
text_embeddings = np.array(text_embeddings)


d = text_embeddings.shape[1]
index = faiss.IndexFlatL2(d)
index.add(text_embeddings)

question = "저자가 대학에 오기 전에 주로 했던 두 가지 일은 무엇이었나요?？"

question_embedding = embed_client.embed(
    input=[question],
    model=embed_model_name
)

question_embeddings = np.array(question_embedding.data[0].embedding)


D, I = index.search(question_embeddings.reshape(1, -1), k=2) # distance, index
retrieved_chunks = [chunks[i] for i in I.tolist()[0]]

prompt = f"""
Context information is below.
---------------------
{retrieved_chunks}
---------------------
Given the context information and not prior knowledge, answer the query.
Query: {question}
Answer:
"""


chat_response = client.complete(
    messages=[
        SystemMessage(content="You are a helpful assistant."),
        UserMessage(content=prompt),
    ],
    temperature=1.0,
    top_p=1.0,
    max_tokens=1000,
    model=model_name
)

print(chat_response.choices[0].message.content)
# Out:
# The author primarily engaged in two activities before college: writing and programming. In terms of writing, they wrote short stories, albeit not very good ones, with minimal plot and characters expressing strong feelings. For programming, they started writing programs on the IBM 1401 used for data processing during their 9th grade, at the age of 13 or 14. They used an early version of Fortran and typed programs on punch cards, later loading them into the card reader to run the program.

# %% [markdown]
# ## Mistral Small
# Mistral Small Mistral കുടുംബത്തിലെ premier/enterprise വിഭാഗത്തിലുള്ള മറ്റൊരു മോഡലാണ്. പേരുപോലെ, ഈ മോഡൽ ഒരു ചെറിയ ഭാഷാ മോഡലാണ് (SLM). Mistral Small ഉപയോഗിക്കുന്നതിന്റെ ഗുണങ്ങൾ:
# - Mistral Large, NeMo പോലുള്ള Mistral LLMs-നേക്കാൾ ചെലവ് കുറവ് - 80% വില കുറവ്
# - കുറഞ്ഞ ലാറ്റൻസി - Mistral LLMs-നേക്കാൾ വേഗത്തിലുള്ള പ്രതികരണം
# - ലളിതം - ആവശ്യമായ വിഭവങ്ങളിൽ കുറവ് നിയന്ത്രണങ്ങളോടെ വ്യത്യസ്ത പരിസ്ഥിതികളിൽ വിന്യസിക്കാവുന്നതാണ്.
#
# Mistral Small ഉത്തമമാണ്:
# - സംഗ്രഹം, മനോഭാവ വിശകലനം, വിവർത്തനം പോലുള്ള ടെക്സ്റ്റ് അടിസ്ഥാനത്തിലുള്ള ജോലികൾക്ക്
# - ചെലവ് കാര്യക്ഷമത കാരണം ആവർത്തിച്ച് അഭ്യർത്ഥനകൾ ഉണ്ടാകുന്ന ആപ്ലിക്കേഷനുകൾക്ക്
# - റിവ്യൂ, കോഡ് നിർദ്ദേശങ്ങൾ പോലുള്ള കുറഞ്ഞ ലാറ്റൻസി കോഡ് ജോലികൾക്ക്

# %% [markdown]
# ## Mistral Small ഉം Mistral Large ഉം താരതമ്യം ചെയ്യുന്നു
#
# Mistral Small ഉം Large ഉം തമ്മിലുള്ള വൈകിയ സമയം വ്യത്യാസം കാണിക്കാൻ, താഴെ കൊടുത്ത സെല്ലുകൾ പ്രവർത്തിപ്പിക്കുക.
#
# 3-5 സെക്കൻഡ് വരെ പ്രതികരണ സമയങ്ങളിൽ വ്യത്യാസം കാണാൻ സാധിക്കും. അതുപോലെ തന്നെ ഒരേ പ്രോംപ്റ്റിൽ പ്രതികരണത്തിന്റെ നീളം, ശൈലി എന്നിവ ശ്രദ്ധിക്കുക.

# %%
import os 
endpoint = "https://models.inference.ai.azure.com"
model_name = "Mistral-small"
token = os.environ["GITHUB_TOKEN"]

client = ChatCompletionsClient(
    endpoint=endpoint,
    credential=AzureKeyCredential(token),
)

response = client.complete(
    messages=[
        SystemMessage(content="You are a helpful coding assistant."),
        UserMessage(content="Can you write a Python function to the fizz buzz test?"),
    ],
    temperature=1.0,
    top_p=1.0,
    max_tokens=1000,
    model=model_name
)

print(response.choices[0].message.content)

# %%
import os
from azure.ai.inference import ChatCompletionsClient
from azure.ai.inference.models import SystemMessage, UserMessage
from azure.core.credentials import AzureKeyCredential

endpoint = "https://models.inference.ai.azure.com"
model_name = "Mistral-large"
token = os.environ["GITHUB_TOKEN"]

client = ChatCompletionsClient(
    endpoint=endpoint,
    credential=AzureKeyCredential(token),
)

response = client.complete(
    messages=[
        SystemMessage(content="You are a helpful coding assistant."),
        UserMessage(content="Can you write a Python function to the fizz buzz test?"),
    ],
    temperature=1.0,
    top_p=1.0,
    max_tokens=1000,
    model=model_name
)

print(response.choices[0].message.content)

# %% [markdown]
# ## Mistral NeMo
#
# ഈ പാഠത്തിൽ ചർച്ച ചെയ്ത മറ്റ് രണ്ട് മോഡലുകളുമായി താരതമ്യപ്പെടുത്തുമ്പോൾ, Mistral NeMo മാത്രമാണ് Apache2 ലൈസൻസുള്ള സൗജന്യ മോഡൽ.
#
# Mistral-ന്റെ മുൻപ് പുറത്തിറങ്ങിയ ഓപ്പൺ സോഴ്‌സ് LLM ആയ Mistral 7B-യുടെ അപ്ഗ്രേഡായി ഇത് കണക്കാക്കപ്പെടുന്നു.
#
# NeMo മോഡലിന്റെ മറ്റ് ചില സവിശേഷതകൾ:
#
# - *കൂടുതൽ കാര്യക്ഷമമായ ടോക്കനൈസേഷൻ:* ഈ മോഡൽ സാധാരണയായി ഉപയോഗിക്കുന്ന tiktoken-നേക്കാൾ Tekken ടോക്കനൈസർ ഉപയോഗിക്കുന്നു. ഇത് കൂടുതൽ ഭാഷകളിലും കോഡിലും മികച്ച പ്രകടനം നൽകുന്നു.
#
# - *ഫൈൻട്യൂണിംഗ്:* അടിസ്ഥാന മോഡൽ ഫൈൻട്യൂണിംഗിനായി ലഭ്യമാണ്. ഇത് ഫൈൻട്യൂണിംഗ് ആവശ്യമായ ഉപയോഗകേസുകൾക്കായി കൂടുതൽ സൗകര്യം നൽകുന്നു.
#
# - *നേറ്റീവ് ഫംഗ്ഷൻ കോളിംഗ്* - Mistral Large പോലെ, ഈ മോഡലും ഫംഗ്ഷൻ കോളിംഗിൽ പരിശീലിപ്പിച്ചിരിക്കുന്നു. ഇത് ആദ്യ ഓപ്പൺ സോഴ്‌സ് മോഡലുകളിൽ ഒന്നായി അതിനെ വ്യത്യസ്തമാക്കുന്നു.

# %% [markdown]
# ## Mistral NeMo
#
# ഈ പാഠത്തിൽ ചർച്ച ചെയ്ത മറ്റ് രണ്ട് മോഡലുകളുമായി താരതമ്യപ്പെടുത്തുമ്പോൾ, Mistral NeMo മാത്രമാണ് Apache2 ലൈസൻസുള്ള സൗജന്യ മോഡൽ.
#
# Mistral-ന്റെ മുൻകാല ഓപ്പൺ സോഴ്‌സ് LLM ആയ Mistral 7B-യുടെ അപ്ഗ്രേഡായി ഇത് കണക്കാക്കപ്പെടുന്നു.
#
# NeMo മോഡലിന്റെ മറ്റ് ചില സവിശേഷതകൾ:
#
# - *കൂടുതൽ കാര്യക്ഷമമായ ടോക്കനൈസേഷൻ:* ഈ മോഡൽ സാധാരണയായി ഉപയോഗിക്കുന്ന tiktoken-നേക്കാൾ Tekken ടോക്കനൈസർ ഉപയോഗിക്കുന്നു. ഇത് കൂടുതൽ ഭാഷകളിലും കോഡിലും മികച്ച പ്രകടനം നൽകുന്നു.
#
# - *ഫൈൻട്യൂണിംഗ്:* അടിസ്ഥാന മോഡൽ ഫൈൻട്യൂണിംഗിനായി ലഭ്യമാണ്. ഫൈൻട്യൂണിംഗ് ആവശ്യമായ ഉപയോഗകേസുകൾക്കായി ഇത് കൂടുതൽ സൗകര്യം നൽകുന്നു.
#
# - *നേറ്റീവ് ഫംഗ്ഷൻ കോളിംഗ്* - Mistral Large പോലെ, ഈ മോഡലും ഫംഗ്ഷൻ കോളിംഗിൽ പരിശീലനം നേടിയതാണ്. ഇത് ആദ്യ ഓപ്പൺ സോഴ്‌സ് മോഡലുകളിൽ ഒന്നായി അതിനെ വ്യത്യസ്തമാക്കുന്നു.

# %% [markdown]
# ### ടോക്കനൈസറുകൾ താരതമ്യം ചെയ്യുന്നു
#
# ഈ സാമ്പിളിൽ, Mistral NeMo ടോക്കനൈസേഷൻ എങ്ങനെ കൈകാര്യം ചെയ്യുന്നു എന്ന് Mistral Large-നൊപ്പം താരതമ്യം ചെയ്യാം.
#
# രണ്ടു സാമ്പിളുകളും ഒരേ പ്രോംപ്റ്റ് ഉപയോഗിക്കുന്നു, പക്ഷേ NeMo Mistral Large-നേക്കാൾ കുറവ് ടോക്കനുകൾ തിരികെ നൽകുന്നുവെന്ന് നിങ്ങൾ കാണണം.

# %%
pip install mistral-common
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 63.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 19.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 16.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 797.0/797.0 kB 15.1 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import needed packages:
from mistral_common.protocol.instruct.messages import (
    UserMessage,
)
from mistral_common.protocol.instruct.request import ChatCompletionRequest
from mistral_common.protocol.instruct.tool_calls import (
    Function,
    Tool,
)
from mistral_common.tokens.tokenizers.mistral import MistralTokenizer

# Load Mistral tokenizer

model_name = "open-mistral-nemo	"

tokenizer = MistralTokenizer.from_model(model_name)

# Tokenize a list of messages
tokenized = tokenizer.encode_chat_completion(
    ChatCompletionRequest(
        tools=[
            Tool(
                function=Function(
                    name="get_current_weather",
                    description="Get the current weather",
                    parameters={
                        "type": "object",
                        "properties": {
                            "location": {
                                "type": "string",
                                "description": "The city and state, e.g. San Francisco, CA",
                            },
                            "format": {
                                "type": "string",
                                "enum": ["celsius", "fahrenheit"],
                                "description": "The temperature unit to use. Infer this from the users location.",
                            },
                        },
                        "required": ["location", "format"],
                    },
                )
            )
        ],
        messages=[
            UserMessage(content="What's the weather like today in Paris"),
        ],
        model=model_name,
    )
)
tokens, text = tokenized.tokens, tokenized.text

# Count the number of tokens
print(len(tokens))
# Out:
# 128

# %%
# Import needed packages:
from mistral_common.protocol.instruct.messages import (
    UserMessage,
)
from mistral_common.protocol.instruct.request import ChatCompletionRequest
from mistral_common.protocol.instruct.tool_calls import (
    Function,
    Tool,
)
from mistral_common.tokens.tokenizers.mistral import MistralTokenizer

# Load Mistral tokenizer

model_name = "mistral-large-latest"

tokenizer = MistralTokenizer.from_model(model_name)

# Tokenize a list of messages
tokenized = tokenizer.encode_chat_completion(
    ChatCompletionRequest(
        tools=[
            Tool(
                function=Function(
                    name="get_current_weather",
                    description="Get the current weather",
                    parameters={
                        "type": "object",
                        "properties": {
                            "location": {
                                "type": "string",
                                "description": "The city and state, e.g. San Francisco, CA",
                            },
                            "format": {
                                "type": "string",
                                "enum": ["celsius", "fahrenheit"],
                                "description": "The temperature unit to use. Infer this from the users location.",
                            },
                        },
                        "required": ["location", "format"],
                    },
                )
            )
        ],
        messages=[
            UserMessage(content="What's the weather like today in Paris"),
        ],
        model=model_name,
    )
)
tokens, text = tokenized.tokens, tokenized.text

# Count the number of tokens
print(len(tokens))
# Out:
# 135

# %% [markdown]
# ## പഠനം ഇവിടെ അവസാനിക്കുന്നില്ല, യാത്ര തുടരുക
#
# ഈ പാഠം പൂർത്തിയാക്കിയ ശേഷം, നിങ്ങളുടെ ജനറേറ്റീവ് AI അറിവ് മെച്ചപ്പെടുത്താൻ ഞങ്ങളുടെ [Generative AI Learning collection](https://aka.ms/genai-collection?WT.mc_id=academic-105485-koreyst) പരിശോധിക്കുക!

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **അസൂയാ**:
# ഈ രേഖ AI വിവർത്തന സേവനം [Co-op Translator](https://github.com/Azure/co-op-translator) ഉപയോഗിച്ച് വിവർത്തനം ചെയ്തതാണ്. നാം കൃത്യതയ്ക്ക് ശ്രമിച്ചിട്ടുണ്ടെങ്കിലും, സ്വയം പ്രവർത്തിക്കുന്ന വിവർത്തനങ്ങളിൽ പിശകുകൾ അല്ലെങ്കിൽ തെറ്റുകൾ ഉണ്ടാകാമെന്ന് ദയവായി ശ്രദ്ധിക്കുക. അതിന്റെ മാതൃഭാഷയിലുള്ള യഥാർത്ഥ രേഖ അധികാരപരമായ ഉറവിടമായി കണക്കാക്കപ്പെടണം. നിർണായക വിവരങ്ങൾക്ക്, പ്രൊഫഷണൽ മനുഷ്യ വിവർത്തനം ശുപാർശ ചെയ്യപ്പെടുന്നു. ഈ വിവർത്തനം ഉപയോഗിക്കുന്നതിൽ നിന്നുണ്ടാകുന്ന ഏതെങ്കിലും തെറ്റിദ്ധാരണകൾക്കോ തെറ്റായ വ്യാഖ്യാനങ്ങൾക്കോ ഞങ്ങൾ ഉത്തരവാദികളല്ല.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
