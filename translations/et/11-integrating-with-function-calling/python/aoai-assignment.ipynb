# %% [markdown]
# ## Sissejuhatus
#
# See õppetükk käsitleb:
# - Mis on funktsiooni kutsumine ja selle kasutusjuhud
# - Kuidas luua funktsiooni kutsumine kasutades Azure OpenAI
# - Kuidas integreerida funktsiooni kutsumist rakendusse
#
# ## Õpieesmärgid
#
# Pärast selle õppetüki lõpetamist tead ja mõistad, kuidas:
#
# - Funktsiooni kutsumise kasutamise eesmärk
# - Funktsiooni kutsumise seadistamine Azure Open AI teenuse kasutamisel
# - Kujundada tõhusaid funktsiooni kutsumisi oma rakenduse kasutusjuhu jaoks

# %% [markdown]
# ## Funktsioonikõnede mõistmine
#
# Selle õppetüki jaoks tahame ehitada funktsiooni meie haridusettevõttele, mis võimaldab kasutajatel kasutada chatbot'i tehniliste kursuste leidmiseks. Soovitame kursusi, mis sobivad nende oskustasemele, praegusele ametikohale ja huvipakkuvale tehnoloogiale.
#
# Selle lõpetamiseks kasutame kombinatsiooni:
#  - `Azure Open AI`, et luua kasutajale vestluskogemus
#  - `Microsoft Learn Catalog API`, et aidata kasutajatel leida kursusi vastavalt kasutaja päringule
#  - `Function Calling`, et võtta kasutaja päring ja saata see funktsioonile API-päringu tegemiseks.
#
# Alustamiseks vaatame, miks me üldse tahaksime kasutada funktsioonikõnet:

# %% [markdown]
# ### Miks Funktsioonikõnet Kasutada
#
# Kui oled selle kursuse mõne muu õppetüki läbinud, siis sa tõenäoliselt mõistad Suurte Keelemudelite (LLM-ide) kasutamise võimsust. Loodetavasti näed ka mõningaid nende piiranguid.
#
# Funktsioonikõne on Azure Open AI Teenuse funktsioon, mis ületab järgmisi piiranguid:
# 1) Ühtlane vastuse formaat
# 2) Võimalus kasutada vestluse kontekstis rakenduse teistest allikatest pärinevaid andmeid
#
# Enne funktsioonikõnet olid LLM-i vastused struktureerimata ja ebajärjekindlad. Arendajad pidid kirjutama keeruka valideerimiskoodi, et olla suuteline iga vastuse variatsiooniga toime tulema.
#
# Kasutajad ei saanud vastuseid näiteks küsimusele „Milline on hetkeilm Stockholmis?“. Selle põhjuseks on see, et mudelite andmed olid piiratud koolituse ajaga.
#
# Vaatame allolevat näidet, mis illustreerib seda probleemi:
#
# Oletame, et tahame luua üliõpilaste andmebaasi, et saaksime neile soovitada sobivaid kursusi. Allpool on kaks üliõpilaste kirjeldust, mis sisaldavad väga sarnaseid andmeid.

# %%
student_1_description="Emily Johnson is a sophomore majoring in computer science at Duke University. She has a 3.7 GPA. Emily is an active member of the university's Chess Club and Debate Team. She hopes to pursue a career in software engineering after graduating."
 
student_2_description = "Michael Lee is a sophomore majoring in computer science at Stanford University. He has a 3.8 GPA. Michael is known for his programming skills and is an active member of the university's Robotics Club. He hopes to pursue a career in artificial intelligence after finishing his studies."

# %% [markdown]
# Me tahame seda saata LLM-ile, et andmeid töödelda. Seda saab hiljem meie rakenduses kasutada, et saata see API-le või salvestada andmebaasi.
#
# Loome kaks identset käsku, millega juhendame LLM-i, millist teavet me soovime:

# %% [markdown]
# Me tahame seda saata LLM-ile, et ta saaks analüüsida toote jaoks olulisi osi. Nii saame luua kaks identset juhist LLM-i suunamiseks:

# %%
prompt1 = f'''
Please extract the following information from the given text and return it as a JSON object:

name
major
school
grades
club

This is the body of text to extract the information from:
{student_1_description}
'''


prompt2 = f'''
Please extract the following information from the given text and return it as a JSON object:

name
major
school
grades
club

This is the body of text to extract the information from:
{student_2_description}
'''

# %% [markdown]
# Pärast nende kahe päringu loomist saadame need LLM-ile, kasutades `client.responses.create`. Me hoiame päringut muutujas `input` ja määrame rolli väärtuseks `user`. See on selleks, et imiteerida kasutaja sõnumi kirjutamist juturobotile.

# %%
import os
import json
from openai import OpenAI
from dotenv import load_dotenv
load_dotenv()

# The OpenAI client points at the Azure OpenAI (Microsoft Foundry) /openai/v1/ endpoint
client = OpenAI(
  api_key=os.environ['AZURE_OPENAI_API_KEY'],
  base_url=f"{os.environ['AZURE_OPENAI_ENDPOINT'].rstrip('/')}/openai/v1/",
  )

deployment=os.environ['AZURE_OPENAI_DEPLOYMENT']
# Out:
# Running cells with '/opt/homebrew/bin/python3' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# Nüüd saame saata mõlemad päringud LLM-ile ja uurida saadud vastust.

# %%
openai_response1 = client.responses.create(
 model=deployment,    
 input = [{'role': 'user', 'content': prompt1}],
 store=False,
)
openai_response1.output_text

# %%
openai_response2 = client.responses.create(
 model=deployment,    
 input = [{'role': 'user', 'content': prompt2}],
 store=False,
)
openai_response2.output_text

# %%
# Loading the response as a JSON object
json_response1 = json.loads(openai_response1.output_text)
json_response1

# %%
# Loading the response as a JSON object
json_response2 = json.loads(openai_response2.output_text)
json_response2

# %% [markdown]
# Kuigi promptid on samad ja kirjeldused sarnased, võime saada omaduse `Grades` erinevaid vorminguid.
#
# Kui käivitad ülaltoodud lahtri mitu korda, võib vorming olla kas `3.7` või `3.7 GPA`.
#
# See on sellepärast, et LLM võtab vastu struktureerimata andmeid kirjaliku prompti kujul ja tagastab samuti struktureerimata andmeid. Meil peab olema struktureeritud vorming, et teada, mida oodata andmete salvestamisel või kasutamisel.
#
# Funktsionaalse kutsumise abil saame tagada, et saame tagasi struktureeritud andmed. Funktsiooni kutsumise kasutamisel LLM tegelikult ei kutsu ega käivita mingeid funktsioone. Selle asemel loome struktuuri, mida LLM peab oma vastustes järgima. Seejärel kasutame neid struktureeritud vastuseid, et teada, millist funktsiooni meie rakendustes käivitada.

# %% [markdown]
# ![Funktsiooni kutsumise vooskeem](../../../../translated_images/et/Function-Flow.083875364af4f4bb.webp)

# %% [markdown]
# Saame seejärel võtta funktsioonilt tagastatud väärtuse ja saata selle tagasi LLM-ile. LLM vastab seejärel loomulikus keeles, et vastata kasutaja päringule.

# %% [markdown]
# ### Funktsiooni kutsumise kasutusjuhtumid
#
# **Väliste tööriistade kutsumine**
# Vestlusrobotid on suurepärased kasutajate küsimustele vastuste andmisel. Funktsiooni kutsumise abil saavad vestlusrobotid kasutada kasutajate sõnumeid teatud ülesannete täitmiseks. Näiteks võib õpilane paluda vestlusrobotil „Saada meil minu juhendajale, öeldes, et vajan selle ainega rohkem abi“. See võib teha funktsioonikõne `send_email(to: string, body: string)`
#
#
# **API või andmebaasi päringute loomine**
# Kasutajad saavad leida teavet loomulikus keeles, mis muundatakse vormindatud päringuks või API-päringuks. Näiteks võib õpetaja küsida: „Kes on need õpilased, kes lõpetasid viimase ülesande“, mis võiks kutsuda funktsiooni nimega `get_completed(student_name: string, assignment: int, current_status: string)`
#
#
# **Struktureeritud andmete loomine**
# Kasutajad võivad võtta tekstiploki või CSV ja kasutada LLM-i olulise teabe eraldamiseks sellest. Näiteks võib õpilane muuta Wikipedia artikli rahulepingute kohta tehisintellekti välkkaartide loomiseks. Seda saab teha, kasutades funktsiooni nimega `get_important_facts(agreement_name: string, date_signed: string, parties_involved: list)`

# %% [markdown]
# ## 2. Oma Esimese Funktsiooni Kutsumise Loomine
#
# Funktsiooni kutsumise loomise protsess hõlmab 3 peamist sammu:
# 1. Chat Completions API kutsumine oma funktsioonide loendi ja kasutajateatega
# 2. Mudeli vastuse lugemine toimingu sooritamiseks, st funktsiooni või API-kutsingu täitmine
# 3. Teine Chat Completions API kutsumine koos oma funktsiooni vastusega, et kasutada seda teavet kasutajale vastuse loomiseks.

# %% [markdown]
# ![Funktsiooni väljakutse voog](../../../../translated_images/et/LLM-Flow.3285ed8caf4796d7.webp)

# %% [markdown]
# ### Funktsioonikõne elemendid
#
# #### Kasutaja sisend
#
# Esimene samm on kasutajasõnumi loomine. Seda saab dünaamiliselt määrata, kasutades tekstisisendi väärtust, või võite siin määrata väärtuse. Kui see on teie esimene kord töötada Chat Completions API-ga, peame määratlema sõnumi `rolli` ja `sisu`.
#
# `roll` võib olla kas `system` (reeglite loomine), `assistant` (mudel) või `user` (lõppkasutaja). Funktsioonikõne korral määrame selle `user`-iks ja anname näitega küsimuse.

# %%
messages= [ {"role": "user", "content": "Find me a good course for a beginner student to learn Azure."} ]

# %% [markdown]
# ### Funktsioonide loomine.
#
# Järgmisena määratleme funktsiooni ja selle funktsiooni parameetrid. Kasutame siin ainult ühte funktsiooni nimega `search_courses`, kuid saate luua mitu funktsiooni.
#
# **Oluline**: Funktsioonid on LLM-i süsteemiteatesse kaasatud ja need kuuluvad teie saadaval olevate tokenite hulka.

# %%
# The Responses API uses a flat tool format: name/description/parameters at the top level
functions = [
   {
      "type":"function",
      "name":"search_courses",
      "description":"Retrieves courses from the search index based on the parameters provided",
      "parameters":{
         "type":"object",
         "properties":{
            "role":{
               "type":"string",
               "description":"The role of the learner (i.e. developer, data scientist, student, etc.)"
            },
            "product":{
               "type":"string",
               "description":"The product that the lesson is covering (i.e. Azure, Power BI, etc.)"
            },
            "level":{
               "type":"string",
               "description":"The level of experience the learner has prior to taking the course (i.e. beginner, intermediate, advanced)"
            }
         },
         "required":[
            "role"
         ]
      }
   }
]

# %% [markdown]
# **Määratlused**
#
# `name` - Funktsiooni nimi, mida soovime kutsuda.
#
# `description` - Kirjeldus, kuidas funktsioon töötab. Siin on oluline olla konkreetne ja selge.
#
# `parameters` - Loend väärtustest ja formaadist, mida soovite, et mudel vastuses toodaks.
#
#
# `type` - Andmetüüp, millesse omadused salvestatakse.
#
# `properties` - Loend spetsiifilistest väärtustest, mida mudel vastuse jaoks kasutab.
#
#
# `name` - Omaduse nimi, mida mudel vormindatud vastuses kasutab.
#
# `type` - Selle omaduse andmetüüp.
#
# `description` - Käesoleva omaduse kirjeldus.
#
#
# **Valikuline**
#
# `required` - Omadus, mis peab funktsiooni väljakutse lõpuleviimiseks olema olemas.

# %% [markdown]
# ### Funktsiooni väljakutse tegemine
# Pärast funktsiooni defineerimist tuleb see nüüd lisada Chat Completion API väljakutse juurde. Teeme seda, lisades päringule `functions`. Antud juhul `functions=functions`.
#
# On ka võimalus määrata `function_call` väärtuseks `auto`. See tähendab, et lubame LLM-il otsustada, millist funktsiooni kutsuda kasutaja sõnumi põhjal, mitte määrame selle ise.

# %%
response = client.responses.create(model=deployment, 
                                        input=messages,
                                        tools=functions, 
                                        tool_choice="auto",
                                        store=False) 

print(response.output)

# %% [markdown]
# Vaatame nüüd vastust ja uurime, kuidas see on vormindatud:
#
# {
#   "role": "assistant",
#   "function_call": {
#     "name": "search_courses",
#     "arguments": "{\n  \"role\": \"student\",\n  \"product\": \"Azure\",\n  \"level\": \"beginner\"\n}"
#   }
# }
#
# Näete, et funktsiooni nimi kutsutakse välja ja kasutaja sõnumi põhjal suutis LLM leida andmed, mis vastavad funktsiooni argumentidele.

# %% [markdown]
# ## 3. Funktsioonikõnede integreerimine rakendusse.
#
#
# Pärast LLM-i vormindatud vastuse testimist saame nüüd selle rakendusse integreerida.
#
# ### Voogude haldamine
#
# Selle rakendusse integreerimiseks võtame järgmised sammud:
#
# Esmalt teeme Open AI teenustele kõne ja salvestame sõnumi muutuja nimega `response_message`.

# %%
# Extract the function call items from the response output
tool_calls = [item for item in response.output if item.type == "function_call"]

# %% [markdown]
# Nüüd määratleme funktsiooni, mis kutsub Microsoft Learn API-d, et saada kursuste nimekiri:

# %%
import requests

def search_courses(role, product, level):
    url = "https://learn.microsoft.com/api/catalog/"
    params = {
        "role": role,
        "product": product,
        "level": level
    }
    response = requests.get(url, params=params)
    modules = response.json()["modules"]
    results = []
    for module in modules[:5]:
        title = module["title"]
        url = module["url"]
        results.append({"title": title, "url": url})
    return str(results)

# %% [markdown]
# Parima praktikana vaatame seejärel, kas mudel soovib kutsuda funktsiooni. Seejärel loome ühe saadaolevatest funktsioonidest ja sobitame selle kutsutava funktsiooniga.
# Seejärel võtame funktsiooni argumendid ja kaardistame need LLM-i argumentidele.
#
# Lõpuks lisame funktsioonikõne sõnumi ja väärtused, mis tagastati `search_courses` sõnumi poolt. See annab LLM-ile kogu vajaliku informatsiooni,
# et vastata kasutajale looduslikus keeles.

# %%
# Check if the model wants to call a function
if tool_calls:
    tool_call = tool_calls[0]
    print("Recommended Function call:")
    print(tool_call.name)
    print()

    # Call the function. 
    function_name = tool_call.name

    available_functions = {
            "search_courses": search_courses,
    }
    function_to_call = available_functions[function_name] 

    function_args = json.loads(tool_call.arguments)
    function_response = function_to_call(**function_args)

    print("Output of function call:")
    print(function_response)
    print(type(function_response))


    # Add the model's function call item(s) and our function result to the conversation.
    # The Responses API represents tool results as `function_call_output` items.
    messages.extend(response.output)  # adding the model's function_call item(s)
    messages.append( # adding function response to messages
        {
            "type": "function_call_output",
            "call_id": tool_call.call_id,
            "output": function_response,
        }
    )

# %% [markdown]
# Nüüd saadame värskendatud sõnumi LLM-ile, et saada loomuliku keele vastus API JSON-vormingus vastuse asemel.

# %%
print("Messages in next request:")
print(messages)
print()

second_response = client.responses.create(
    input=messages,
    model=deployment,
    tools=functions,
    tool_choice="auto",
    temperature=0,
    store=False,
        )  # get a new response from the model where it can see the function response


print(second_response.output_text)

# %% [markdown]
# ## Koodiväljakutse
#
# Suurepärane töö! Jätkates oma õppimist Azure Open AI funktsiooni väljakutsete kohta, võid ehitada: https://learn.microsoft.com/training/support/catalog-api-developer-reference?WT.mc_id=academic-105485-koreyst
#  - Rohkem funktsiooni parameetreid, mis võivad aidata õppijatel leida rohkem kursuseid. Saad saadavalolevaid API parameetreid vaadata siin:
#  - Loo teine funktsiooni kutsumine, mis võtab õppijalt rohkem informatsiooni, näiteks nende emakeele
#  - Loo veahaldus, kui funktsiooni kutsumine ja/või API kutsumine ei tagasta sobivaid kursuseid

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Lahtiütlus**:
# See dokument on tõlgitud kasutades AI tõlketeenust [Co-op Translator](https://github.com/Azure/co-op-translator). Kuigi me püüdleme täpsuse poole, palun pange tähele, et automatiseeritud tõlgetes võib esineda vigu või ebatäpsusi. Originaaldokument selle emakeeles tuleks pidada autoriteetseks allikaks. Olulise teabe puhul soovitatakse kasutada professionaalset inimtõlget. Me ei vastuta selle tõlkega seotud eksimustest või valesti mõistmistest.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
