# %% [markdown]
# ## Sissejuhatus
#
# See õppetund käsitleb:
# - Mis on funktsiooni kutsumine ja selle kasutusjuhtumid
# - Kuidas luua funktsiooni kutset, kasutades Azure OpenAI
# - Kuidas integreerida funktsiooni kutset rakendusse
#
# ## Õpieesmärgid
#
# Pärast selle õppetundi lõpetamist tead ja mõistad:
#
# - Funktsiooni kutsumise eesmärki
# - Funktsiooni kutse seadistamist, kasutades Azure Open AI teenust
# - Kujundada tõhusaid funktsiooni kutseid oma rakenduse kasutusjuhtumile

# %% [markdown]
# ## Funktsioonikõnede mõistmine
#
# Selle tunni jaoks soovime luua meie haridusettevõtte jaoks funktsiooni, mis võimaldab kasutajatel kasutada vestlusrobotit tehniliste kursuste leidmiseks. Soovitame kursuseid, mis sobivad nende oskustasemele, praegusele rollile ja huvipakkuvale tehnoloogiale.
#
# Selle lõpetamiseks kasutame kombinatsiooni:
#  - `Azure Open AI` kasutajale vestluskogemuse loomiseks
#  - `Microsoft Learn Catalog API`, et aidata kasutajatel leida kursuseid vastavalt kasutaja päringule
#  - `Funktsioonikõne` kasutamiseks kasutaja päringu edastamiseks funktsioonile API-päringu tegemiseks.
#
# Alustamiseks vaatame, miks me tahaksime üldse funktsioonikõnet kasutada:

# %% [markdown]
# ### Miks funktsioonikõnesid kasutada
#
# Kui olete selle kursuse mõnda teist peatükki läbinud, mõistate tõenäoliselt suurt keelemudelite (LLM-ide) kasutamise võimsust. Loodetavasti näete ka mõningaid nende piiranguid.
#
# Funktsioonikõne on Azure Open AI teenuse funktsioon, mis aitab ületada järgmisi piiranguid:
# 1) Vastuse vormingu järjepidevus
# 2) Võime kasutada vestluskontekstis rakenduse teistest allikatest pärit andmeid
#
# Enne funktsioonikõnet olid LLM-i vastused struktureerimata ja ebajärjekindlad. Arendajad pidid kirjutama keerukat valideerimiskoodi, et suuta käsitleda iga vastuse variatsiooni.
#
# Kasutajad ei saanud selliseid vastuseid nagu "Mis on hetkel ilm Stockholmis?". Sellepärast, et mudelite andmed olid piiratud koolituse ajaga.
#
# Vaatame allolevat näidet, mis illustreerib seda probleemi:
#
# Oletame, et tahame luua andmebaasi õpilaste andmetega, et saaksime neile sobivaid kursuseid soovitada. Allpool on kaks väga sarnast õpilaste kirjelduse näidet andmetes.

# %%
student_1_description="Emily Johnson is a sophomore majoring in computer science at Duke University. She has a 3.7 GPA. Emily is an active member of the university's Chess Club and Debate Team. She hopes to pursue a career in software engineering after graduating."
 
student_2_description = "Michael Lee is a sophomore majoring in computer science at Stanford University. He has a 3.8 GPA. Michael is known for his programming skills and is an active member of the university's Robotics Club. He hopes to pursue a career in artificial intelligence after finishing his studies."

# %% [markdown]
# Soovime seda saata LLM-ile, et andmeid töödelda. Seda saab hiljem meie rakenduses kasutada API-le saatmiseks või andmebaasi salvestamiseks.
#
# Loome kaks identsed prompti, kus juhendame LLM-i, mis teavet meid huvitab:

# %% [markdown]
# Soovime seda saata LLM-ile, et analüüsida meie toote jaoks olulisi osi. Nii saame luua kaks identselt käsklust LLM-i juhendamiseks:

# %%
prompt1 = f'''
Please extract the following information from the given text and return it as a JSON object:

name
major
school
grades
club

This is the body of text to extract the information from:
{student_1_description}
'''


prompt2 = f'''
Please extract the following information from the given text and return it as a JSON object:

name
major
school
grades
club

This is the body of text to extract the information from:
{student_2_description}
'''

# %% [markdown]
# Pärast nende kahe prompti loomist saadame need LLM-ile, kasutades `client.responses.create`.  Me salvestame prompti muutujasse `input` ja määrame rolli `user`. See on mõeldud kasutaja sõnumi matkimiseks, mis kirjutatakse vestlusrobotile.

# %%
import os
import json
from openai import OpenAI
from dotenv import load_dotenv
load_dotenv()

# The OpenAI client points at the Azure OpenAI (Microsoft Foundry) /openai/v1/ endpoint
client = OpenAI(
  api_key=os.environ['AZURE_OPENAI_API_KEY'],
  base_url=f"{os.environ['AZURE_OPENAI_ENDPOINT'].rstrip('/')}/openai/v1/",
  )

deployment=os.environ['AZURE_OPENAI_DEPLOYMENT']
# Out:
# Running cells with '/opt/homebrew/bin/python3' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# Nüüd saame saata mõlemad päringud LLM-ile ja uurida saadud vastust.

# %%
openai_response1 = client.responses.create(
 model=deployment,    
 input = [{'role': 'user', 'content': prompt1}],
 store=False,
)
openai_response1.output_text

# %%
openai_response2 = client.responses.create(
 model=deployment,    
 input = [{'role': 'user', 'content': prompt2}],
 store=False,
)
openai_response2.output_text

# %%
# Loading the response as a JSON object
json_response1 = json.loads(openai_response1.output_text)
json_response1

# %%
# Loading the response as a JSON object
json_response2 = json.loads(openai_response2.output_text)
json_response2

# %% [markdown]
# Kuigi promptid on samad ja kirjeldused sarnased, võime saada erinevates vormingutes `Grades` omaduse.
#
# Kui käivitada ülaltoodud plokk mitu korda, võib vorming olla kas `3.7` või `3.7 GPA`.
#
# See on sellepärast, et LLM võtab sisendiks kirjutatud promptis oleva struktuurita andmed ja tagastab samuti struktuurita andmed. Meil peab olema struktureeritud vorming, et teada, mida oodata, kui neid andmeid salvestame või kasutame.
#
# Funktsionaalse väljakutse kasutamisel saame tagada, et saame tagasi struktureeritud andmed. Funktsiooni väljakutse kasutamisel LLM tegelikult funktsioone ei kutsu ega käivita. Selle asemel loodame struktuuri, mida LLM peab oma vastustes järgima. Seejärel kasutame neid struktureeritud vastuseid teadmiseks, millist funktsiooni meie rakendustes käivitada.

# %% [markdown]
# ![Funktsiooni kutsumise vooskeem](../../../../translated_images/et/Function-Flow.083875364af4f4bb.webp)

# %% [markdown]
# Seejärel saame funktsioonist tagastatu võtta ja selle tagasi LLM-i saata. LLM vastab seejärel loomulikus keeles kasutaja päringule.

# %% [markdown]
# ### Funktsioonikõnede kasutamise juhtumid
#
# **Väliste tööriistade kutsumine**
# Vestlusrobotid on suurepärased kasutajate küsimustele vastuste andmisel. Funktsioonikõnede abil saavad vestlusrobotid kasutada kasutajatelt saadud sõnumeid teatud ülesannete täitmiseks. Näiteks võib õpilane paluda vestlusroboti "Saada minu õpetajale e-kiri, öeldes, et vajan selle aine osas rohkem abi". Seda saab teha funktsioonikõnega `send_email(to: string, body: string)`
#
#
# **API või andmebaasi päringute loomine**
# Kasutajad saavad leida infot loomulikus keeles, mis muudetakse vormindatud päringuks või API päringuks. Näiteks võib õpetaja küsida: "Kes on õpilased, kes lõpetasid viimase ülesande", mida võiks käsitleda funktsioon nimega `get_completed(student_name: string, assignment: int, current_status: string)`
#
#
# **Struktureeritud andmete loomine**
# Kasutajad saavad võtta tekstiploki või CSV-faili ja kasutada LLM-i, et sellest olulist teavet eraldada. Näiteks võib õpilane teisendada Vikipeedia artikli rahulepingute kohta AI-mälukaartide loomiseks. Seda saab teha funktsiooniga `get_important_facts(agreement_name: string, date_signed: string, parties_involved: list)`

# %% [markdown]
# ## 2. Esimese funktsiooni kõne loomine
#
# Funktsiooni kõne loomise protsess hõlmab 3 põhietappi:
# 1. Chat Completions API kutsumine oma funktsioonide nimekirja ja kasutaja sõnumiga
# 2. Mudeli vastuse lugemine toimingu teostamiseks, nt funktsiooni või API kõne täitmine
# 3. Teine kõne Chat Completions API-le oma funktsiooni vastusega, et kasutada seda teavet kasutajale vastuse loomisel.

# %% [markdown]
# ![Funktsiooni väljakutse voog](../../../../translated_images/et/LLM-Flow.3285ed8caf4796d7.webp)

# %% [markdown]
# ### Funktsiooni kutsumise elemendid
#
# #### Kasutaja sisend
#
# Esimene samm on luua kasutajasõnum. Seda saab dünaamiliselt määrata, võttes väärtuse tekstisisendist või võite siin väärtuse määrata. Kui kasutate Chat Completions API-d esimest korda, peame määratlema sõnumi `role` ja `content`.
#
# `role` võib olla kas `system` (reeslite loomine), `assistant` (mudel) või `user` (lõppkasutaja). Funktsiooni kutsumiseks määrame selle `user`-iks ja lisame näidisülesande.

# %%
messages= [ {"role": "user", "content": "Find me a good course for a beginner student to learn Azure."} ]

# %% [markdown]
# ### Funktsioonide loomine.
#
# Järgmisena määratleme funktsiooni ja selle funktsiooni parameetrid. Siin kasutame ainult ühte funktsiooni nimega `search_courses`, kuid võite luua mitu funktsiooni.
#
# **Oluline** : Funktsioonid on lisatud süsteemiteatele LLM-ile ja kuuluvad teie käsutuses olevate tokenite hulka.

# %%
# The Responses API uses a flat tool format: name/description/parameters at the top level
functions = [
   {
      "type":"function",
      "name":"search_courses",
      "description":"Retrieves courses from the search index based on the parameters provided",
      "parameters":{
         "type":"object",
         "properties":{
            "role":{
               "type":"string",
               "description":"The role of the learner (i.e. developer, data scientist, student, etc.)"
            },
            "product":{
               "type":"string",
               "description":"The product that the lesson is covering (i.e. Azure, Power BI, etc.)"
            },
            "level":{
               "type":"string",
               "description":"The level of experience the learner has prior to taking the course (i.e. beginner, intermediate, advanced)"
            }
         },
         "required":[
            "role"
         ]
      }
   }
]

# %% [markdown]
# **Määratlused**
#
# `name` - Funktsiooni nimi, mida soovime kutsuda.
#
# `description` - See on kirjeldus funktsiooni tööpõhimõttest. Siin on oluline olla täpne ja selge
#
# `parameters` - Loetelu väärtustest ja vormingust, mida soovite, et mudel oma vastuses toodaks
#
#
# `type` - Andmetüüp, milles omadusi hoitakse
#
# `properties` - Loetelu spetsiifilistest väärtustest, mida mudel oma vastuses kasutab
#
#
# `name` - omaduse nimi, mida mudel oma vormindatud vastuses kasutab
#
# `type` - Selle omaduse andmetüüp
#
# `description` - Sihtomaduse kirjeldus
#
#
# **Valikuline**
#
# `required` - vajalik omadus, et funktsioonikõne saaks lõpetatud

# %% [markdown]
# ### Funktsiooni kutsumine
# Pärast funktsiooni määratlemist peame selle nüüd lisama Chat Completion API kutsele. Teeme seda, lisades päringusse `functions`. Antud juhul `functions=functions`.
#
# Samuti on olemas võimalus seada `function_call` väärtuseks `auto`. See tähendab, et laseme LLM-il otsustada, millist funktsiooni tuleks kasutaja sõnumi põhjal kutsuda, selle asemel et ise määrata.

# %%
response = client.responses.create(model=deployment, 
                                        input=messages,
                                        tools=functions, 
                                        tool_choice="auto",
                                        store=False) 

print(response.output)

# %% [markdown]
# Vaatame nüüd vastust ja uurime, kuidas see on vormindatud:
#
# {
#   "role": "assistant",
#   "function_call": {
#     "name": "search_courses",
#     "arguments": "{\n  \"role\": \"student\",\n  \"product\": \"Azure\",\n  \"level\": \"beginner\"\n}"
#   }
# }
#
# Saate näha, et funktsiooni nimi kutsutakse välja ja kasutaja sõnumist suutis LLM leida andmed, mis sobivad funktsiooni argumentidega.

# %% [markdown]
# ## 3.Funktsioonikõnede integreerimine rakendusse.
#
#
# Pärast seda, kui oleme testinud LLM-i vormindatud vastust, saame nüüd selle integreerida rakendusse.
#
# ### Voogude haldamine
#
# Selle integreerimiseks meie rakendusse, võtame järgmised sammud:
#
# Esiteks, teeme kõne Open AI teenustele ja salvestame sõnumi muutujasse nimega `response_message`.

# %%
# Extract the function call items from the response output
tool_calls = [item for item in response.output if item.type == "function_call"]

# %% [markdown]
# Nüüd määratleme funktsiooni, mis kutsub Microsoft Learni API-d, et saada kursuste nimekiri:

# %%
import requests

def search_courses(role, product, level):
    url = "https://learn.microsoft.com/api/catalog/"
    params = {
        "role": role,
        "product": product,
        "level": level
    }
    response = requests.get(url, params=params)
    modules = response.json()["modules"]
    results = []
    for module in modules[:5]:
        title = module["title"]
        url = module["url"]
        results.append({"title": title, "url": url})
    return str(results)

# %% [markdown]
# Parima praktikana vaatame siis, kas mudel soovib funktsiooni kutsuda. Seejärel loome ühe olemasolevatest funktsioonidest ja seome selle kutsutava funktsiooniga.
# Seejärel võtame funktsiooni argumendid ja kaardistame need LLM-i argumentidega.
#
# Lõpuks lisame funktsiooni kutsumise sõnumi ja väärtused, mis tagastati `search_courses` sõnumi kaudu. See annab LLM-ile kogu vajaliku teabe,
# et vastata kasutajale loomulikus keeles.

# %%
# Check if the model wants to call a function
if tool_calls:
    tool_call = tool_calls[0]
    print("Recommended Function call:")
    print(tool_call.name)
    print()

    # Call the function. 
    function_name = tool_call.name

    available_functions = {
            "search_courses": search_courses,
    }
    function_to_call = available_functions[function_name] 

    function_args = json.loads(tool_call.arguments)
    function_response = function_to_call(**function_args)

    print("Output of function call:")
    print(function_response)
    print(type(function_response))


    # Add the model's function call item(s) and our function result to the conversation.
    # The Responses API represents tool results as `function_call_output` items.
    messages.extend(response.output)  # adding the model's function_call item(s)
    messages.append( # adding function response to messages
        {
            "type": "function_call_output",
            "call_id": tool_call.call_id,
            "output": function_response,
        }
    )

# %% [markdown]
# Nüüd saadame värskendatud sõnumi LLM-ile, et saaksime vastuseks loomuliku keele väljundi API JSON-vormingus vastuse asemel.

# %%
print("Messages in next request:")
print(messages)
print()

second_response = client.responses.create(
    input=messages,
    model=deployment,
    tools=functions,
    tool_choice="auto",
    store=False,
        )  # get a new response from the model where it can see the function response


print(second_response.output_text)

# %% [markdown]
# ## Koodi väljakutse
#
# Suurepärane töö! Selleks, et jätkata Azure Open AI funktsioonikõnede õppimist, võite luua: https://learn.microsoft.com/training/support/catalog-api-developer-reference?WT.mc_id=academic-105485-koreyst
#  - Rohkem funktsiooni parameetreid, mis võivad aidata õppijatel leida rohkem kursusi. Saate leida saadavalolevad API parameetrid siit:
#  - Looge teine funktsiooni kõne, mis võtab õppijalt rohkem teavet, näiteks nende emakeele
#  - Looge veakäsitlus, kui funktsiooni kõne ja/või API kõne ei tagasta sobivaid kursuseid

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Lahtiütlus**:
# See dokument on tõlgitud kasutades AI tõlketeenust [Co-op Translator](https://github.com/Azure/co-op-translator). Kuigi me püüdleme täpsuse poole, palun pange tähele, et automatiseeritud tõlgetes võib esineda vigu või ebatäpsusi. Originaaldokument selle emakeeles tuleks pidada autoriteetseks allikaks. Olulise teabe puhul soovitatakse kasutada professionaalset inimtõlget. Me ei vastuta selle tõlkega seotud eksimustest või valesti mõistmistest.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
