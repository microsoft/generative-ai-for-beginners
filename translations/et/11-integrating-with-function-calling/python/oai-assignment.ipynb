# %% [markdown]
# ## Sissejuhatus
#
# See õppetund käsitleb:
# - Mis on funktsiooni kutsumine ja selle kasutusjuhud
# - Kuidas luua funktsiooni kutset OpenAI abil
# - Kuidas integreerida funktsiooni kutset rakendusse
#
# ## Õpieesmärgid
#
# Pärast selle õppetunni lõpetamist tead ja mõistad:
#
# - Funktsiooni kutsumise eesmärki
# - Funktsiooni kutsumise seadistamist OpenAI teenuse abil
# - Kujundada tõhusaid funktsiooni kutsumisi vastavalt oma rakenduse kasutusjuhule

# %% [markdown]
# ## Funktsioonikõnede mõistmine
#
# Selle õppetunni jaoks soovime luua haridusettevõttele funktsiooni, mis võimaldab kasutajatel kasutada vestlusrobotit tehniliste kursuste leidmiseks. Soovitame kursusi, mis vastavad nende oskustasemele, praegusele ametikohale ja huvipakkuvale tehnoloogiale.
#
# Selle lõpuleviimiseks kasutame kombinatsiooni:
#  - `OpenAI` kasutajale vestluskogemuse loomiseks
#  - `Microsoft Learn Catalog API` kasutajate abistamiseks kursuste leidmisel vastavalt kasutaja päringule
#  - `Funktsioonikutsed`, et võtta kasutaja päring ja saata see funktsioonile API-päringu tegemiseks.
#
# Alustamiseks vaatame, miks me üldse tahaksime kasutada funktsioonikutsed:

# %% [markdown]
# ### Miks funktsioonikõne
#
# Kui olete selle kursuse mõne teise õppetükiga juba lõpetanud, mõistate ilmselt suurte keelemudelite (LLM-ide) kasutamise võimu. Loodetavasti näete ka mõningaid nende piiranguid.
#
# Funktsioonikõne on OpenAI teenuse funktsioon, mis on mõeldud järgmiste väljakutsetega tegelemiseks:
#
# Ebajärjekindel vastuse vormindamine:
# - Enne funktsioonikõnet olid suure keelemudeli vastused struktureerimata ja ebajärjekindlad. Arendajad pidid kirjutama keerulist valideerimiskoodi, et käsitleda iga väljundi variatsiooni.
#
# Piiratud integratsioon välise andmetega:
# - Selle funktsiooni eel oli keeruline kaasata rakenduse teistest osadest pärit andmeid vestluse konteksti.
#
# Standardiseerides vastuse vormingud ja võimaldades sujuvat integratsiooni väliste andmetega, lihtsustab funktsioonikõne arendust ja vähendab täiendava valideerimisloogika vajadust.
#
# Kasutajad ei saanud vastuseid, nagu "Milline on praegune ilm Stockholmis?". Seda seetõttu, et mudelite piiranguks oli andmete treeningaeg.
#
# Vaatame järgmist näidet, mis illustreerib seda probleemi:
#
# Oletame, et tahame luua õpilaste andmebaasi, et saaksime neile soovitada sobiva kursuse. Allpool on kaks üksteisega väga sarnase sisuga õpilaste kirjeldust.

# %%
student_1_description="Emily Johnson is a sophomore majoring in computer science at Duke University. She has a 3.7 GPA. Emily is an active member of the university's Chess Club and Debate Team. She hopes to pursue a career in software engineering after graduating."
 
student_2_description = "Michael Lee is a sophomore majoring in computer science at Stanford University. He has a 3.8 GPA. Michael is known for his programming skills and is an active member of the university's Robotics Club. He hopes to pursue a career in artificial intelligence after finishing his studies."

# %% [markdown]
# Soovime selle saata LLM-ile, et andmeid töödelda. Seda saab hiljem meie rakenduses kasutada selle API-le saatmiseks või andmebaasis salvestamiseks.
#
# Loome kaks identselt päringut, mille kaudu juhendame LLM-i sellest, millist teavet meid huvitab:

# %% [markdown]
# Me soovime selle saata LLM-ile, et analüüsida toote jaoks olulisi osi. Nii saame luua kaks identselt küsimust LLM-i juhendamiseks:

# %%
prompt1 = f'''
Please extract the following information from the given text and return it as a JSON object:

name
major
school
grades
club

This is the body of text to extract the information from:
{student_1_description}
'''


prompt2 = f'''
Please extract the following information from the given text and return it as a JSON object:

name
major
school
grades
club

This is the body of text to extract the information from:
{student_2_description}
'''

# %% [markdown]
# Pärast nende kahe prompti loomist saadame need LLM-ile, kasutades `client.responses.create`. Me salvestame prompti `input` muutujasse ja määrame rolli `user`. See on selleks, et jäljendada kasutaja sõnumi kirjutamist vestlusrobotile.

# %%
import os
import json
from openai import OpenAI
from dotenv import load_dotenv
load_dotenv()

client = OpenAI()

deployment="gpt-4o-mini"
# Out:
# Running cells with '/opt/homebrew/bin/python3' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# Nüüd saame saata mõlemad päringud LLM-ile ja uurida saadud vastust.

# %%
openai_response1 = client.responses.create(
 model=deployment,    
 input = [{'role': 'user', 'content': prompt1}],
 store=False,
)
openai_response1.output_text

# %%
openai_response2 = client.responses.create(
 model=deployment,    
 input = [{'role': 'user', 'content': prompt2}],
 store=False,
)
openai_response2.output_text

# %%
# Loading the response as a JSON object
json_response1 = json.loads(openai_response1.output_text)
json_response1

# %%
# Loading the response as a JSON object
json_response2 = json.loads(openai_response2.output_text)
json_response2

# %% [markdown]
# Kuigi promptid on samad ja kirjeldused sarnased, võime saada erinevaid `Grades` omaduse vorminguid.
#
# Kui käivitate ülaltoodud lahtri mitu korda, võib vorming olla kas `3.7` või `3.7 GPA`.
#
# See on tingitud sellest, et LLM võtab kirjutatud prompti kujul vastu struktureerimata andmeid ja tagastab samuti struktureerimata andmeid. Meil peab olema struktureeritud vorming, et teada, mida oodata, kui neid andmeid salvestada või kasutada.
#
# Funktsionaalse väljakutse kasutamisega saame tagada, et saame tagasi struktureeritud andmed. Funktsiooni kutsumise puhul ei kutsu LLM tegelikult ühtegi funktsiooni ega käivita seda. Selle asemel loome struktuuri, mida LLM peab oma vastustes järgima. Seejärel kasutame neid struktureeritud vastuseid, et teada, millist funktsiooni meie rakendustes käivitada.

# %% [markdown]
# ![Funktsiooni käivitamise vooskeem](../../../../translated_images/et/Function-Flow.083875364af4f4bb.webp)

# %% [markdown]
# Me võime seejärel võtta funktsioonilt tagastatud väärtuse ja saata selle tagasi LLM-ile. LLM vastab seejärel looduslikus keeles, vastamaks kasutaja päringule.

# %% [markdown]
# ### Funktsioonikõnede kasutamise juhtumid
#
# **Välistööriistade kutsumine**
# Vestlusrobotid on suurepärased vastamaks kasutajate küsimustele. Funktsioonikõnede abil saavad vestlusrobotid kasutada kasutajate sõnumeid teatud ülesannete täitmiseks. Näiteks võib õpilane paluda vestlusrobotil "Saada e-kiri minu juhendajale, öeldes, et mul on selle teema kohta vaja rohkem abi". See võib teha funktsioonikõne `send_email(to: string, body: string)`
#
#
# **API- või andmebaasipäringute loomine**
# Kasutajad saavad leida teavet loomuliku keele abil, mis teisendatakse vormingustatud päringuks või API päringuks. Näiteks võib õpetaja küsida "Kes on õpilased, kes lõpetasid viimase ülesande", mis võib kutsuda funktsiooni nimega `get_completed(student_name: string, assignment: int, current_status: string)`
#
#
# **Struktureeritud andmete loomine**
# Kasutajad võivad võtta tekstiploki või CSV-faili ja kasutada LLM-i sellelt olulise teabe väljavõtmiseks. Näiteks võib õpilane muuta Vikipeedia artikli rahulepingutest AI mälukaartide loomiseks. Seda saab teha funktsiooniga `get_important_facts(agreement_name: string, date_signed: string, parties_involved: list)`

# %% [markdown]
# ## 2. Oma Esimese Funktsiooni Kutsumise Loomine
#
# Funktsiooni kutsumise loomise protsess hõlmab 3 peamist sammu:
# 1. Kõne Chat Completions API-le, kasutades oma funktsioonide nimekirja ja kasutaja sõnumit
# 2. Loe mudeli vastust, et teostada tegevus, nt funktsiooni või API-kõne käivitamine
# 3. Tee uus kõne Chat Completions API-le koos oma funktsiooni vastusega, et kasutada seda teavet kasutajale vastuse loomiseks.

# %% [markdown]
# ![Funktsiooni väljakutse voo skeem](../../../../translated_images/et/LLM-Flow.3285ed8caf4796d7.webp)

# %% [markdown]
# ### Funktsiooni väljakutse elemendid
#
# #### Kasutaja sisend
#
# Esimene samm on luua kasutaja sõnum. Seda saab dünaamiliselt määrata tekstisisendi väärtuse põhjal või võite siin väärtuse määrata. Kui see on teie esimene kord töötada Chat Completions API-ga, peame määratlema sõnumi `role` ja `content`.
#
# `role` võib olla kas `system` (reeglite loomine), `assistant` (mudel) või `user` (lõppkasutaja). Funktsiooni väljakutse puhul määrame selle kui `user` ja toome näidisena küsimuse.

# %%
messages= [ {"role": "user", "content": "Find me a good course for a beginner student to learn Azure."} ]

# %% [markdown]
# ### Funktsioonide loomine.
#
# Järgmises osas määratleme funktsiooni ja selle funktsiooni parameetrid. Siin kasutame ainult üht funktsiooni nimega `search_courses`, kuid võid luua mitu funktsiooni.
#
# **Tähtis**: Funktsioonid lisatakse süsteemisõnumisse LLM-ile ning need arvestatakse sinu saadaolevate tokenite hulka.

# %%
# The Responses API uses a flat tool format: name/description/parameters at the top level
functions = [
   {
      "type":"function",
      "name":"search_courses",
      "description":"Retrieves courses from the search index based on the parameters provided",
      "parameters":{
         "type":"object",
         "properties":{
            "role":{
               "type":"string",
               "description":"The role of the learner (i.e. developer, data scientist, student, etc.)"
            },
            "product":{
               "type":"string",
               "description":"The product that the lesson is covering (i.e. Azure, Power BI, etc.)"
            },
            "level":{
               "type":"string",
               "description":"The level of experience the learner has prior to taking the course (i.e. beginner, intermediate, advanced)"
            }
         },
         "required":[
            "role"
         ]
      }
   }
]

# %% [markdown]
# **Määratlused**
#
# Funktsiooni määratlemise struktuur on mitmetasandiline, iga tasand oma omadustega. Siin on pesastatud struktuuri ülevaade:
#
# **Kõrgtasandi funktsiooni omadused:**
#
# `name` - Funktsiooni nimi, mida soovime kutsuda.
#
# `description` - See on kirjelduse, kuidas funktsioon töötab. Siin on oluline olla konkreetne ja selge
#
# `parameters` - Loetelu väärtustest ja vormingust, mida soovite, et mudel oma vastuses esitaks
#
# **Parameetrite objekti omadused:**
#
# `type` - Parameetrite objekti andmetüüp (tavaliselt "object")
#
# `properties` - Loetelu konkreetsetest väärtustest, mida mudel vastuse koostamiseks kasutab
#
# **Individuaalsete parameetrite omadused:**
#
# `name` - Implicit defineeritud omaduse võtme kaudu (nt "role", "product", "level")
#
# `type` - Selle konkreetse parameetri andmetüüp (nt "string", "number", "boolean")
#
# `description` - Konkreetse parameetri kirjeldus
#
# **Valikulised omadused:**
#
# `required` - Massiiv, mis loetleb, millised parameetrid on funktsiooni väljakutse lõpetamiseks kohustuslikud

# %% [markdown]
# ### Funktsiooni kutsumise tegemine
# Pärast funktsiooni defineerimist peame nüüd selle lisama Chat Completion API päringusse. Teeme seda, lisades `functions` päringusse. Antud juhul `functions=functions`.
#
# On ka võimalus seada `function_call` väärtuseks `auto`. See tähendab, et laseme LLM-il otsustada, millist funktsiooni tuleks kutsuda vastavalt kasutaja sõnumile, selle asemel et määrata see ise.

# %%
response = client.responses.create(model=deployment, 
                                        input=messages,
                                        tools=functions, 
                                        tool_choice="auto",
                                        store=False) 

print(response.output)

# %% [markdown]
# Vaatame nüüd vastust ja uurime, kuidas see on vormindatud:
#
# {
#   "role": "assistant",
#   "function_call": {
#     "name": "search_courses",
#     "arguments": "{\n  \"role\": \"student\",\n  \"product\": \"Azure\",\n  \"level\": \"beginner\"\n}"
#   }
# }
#
# Saate näha, et funktsiooni nimi kutsutakse ja kasutaja sõnumi põhjal suutis LLM leida andmed, mis sobivad funktsiooni argumentidega.

# %% [markdown]
# ## 3.Funktsioonikõnede integreerimine rakendusse.
#
#
# Pärast seda, kui oleme testinud LLM-i vormindatud vastust, saame selle nüüd rakendusse integreerida.
#
# ### Voogude haldamine
#
# Selle integreerimiseks meie rakendusse teeme järgmised sammud:
#
# Esiteks teeme kõne OpenAI teenustele ja salvestame sõnumi muutujasse nimega `response_message`.

# %%
# Extract the function call items from the response output
tool_calls = [item for item in response.output if item.type == "function_call"]

# %% [markdown]
# Nüüd määratleme funktsiooni, mis kutsub Microsoft Learn API-d, et saada kursuste nimekiri:

# %%
import requests

def search_courses(role, product, level):
    url = "https://learn.microsoft.com/api/catalog/"
    params = {
        "role": role,
        "product": product,
        "level": level
    }
    response = requests.get(url, params=params)
    modules = response.json()["modules"]
    results = []
    for module in modules[:5]:
        title = module["title"]
        url = module["url"]
        results.append({"title": title, "url": url})
    return str(results)

# %% [markdown]
# Parima tava kohaselt vaatame seejärel, kas mudel soovib funktsiooni kutsuda. Seejärel loome ühe saadaolevatest funktsioonidest ja sobitame selle kutsutava funktsiooniga.
# Seejärel võtame funktsiooni argumendid ja kaardistame need LLM-i argumentidega.
#
# Lõpuks lisame funktsioonikõne sõnumi ja väärtused, mis tagastati sõnumi `search_courses` kaudu. See annab LLM-ile kogu vajaliku info,
# et vastata kasutajale loomulikus keeles.

# %%
# Check if the model wants to call a function
if tool_calls:
    tool_call = tool_calls[0]
    print("Recommended Function call:")
    print(tool_call.name)
    print()

    # Call the function. 
    function_name = tool_call.name

    available_functions = {
            "search_courses": search_courses,
    }
    function_to_call = available_functions[function_name] 

    function_args = json.loads(tool_call.arguments)
    function_response = function_to_call(**function_args)

    print("Output of function call:")
    print(function_response)
    print(type(function_response))


    # Add the model's function call item(s) and our function result to the conversation.
    # The Responses API represents tool results as `function_call_output` items.
    messages.extend(response.output)  # adding the model's function_call item(s)
    messages.append( # adding function response to messages
        {
            "type": "function_call_output",
            "call_id": tool_call.call_id,
            "output": function_response,
        }
    )

# %% [markdown]
# Nüüd saadame värskendatud sõnumi LLM-ile, et saaksime loomulikus keeles vastuse API JSON-vormingus vastuse asemel.

# %%
print("Messages in next request:")
print(messages)
print()

second_response = client.responses.create(
    input=messages,
    model=deployment,
    tools=functions,
    tool_choice="auto",
    temperature=0,
    store=False,
        )  # get a new response from the model where it can see the function response


print(second_response.output_text)

# %% [markdown]
# ## Koodi väljakutse
#
# Suurepärane töö! Oma OpenAI funktsioonikõnede õppimise jätkamiseks võite luua: https://learn.microsoft.com/training/support/catalog-api-developer-reference?WT.mc_id=academic-105485-koreyst
#  - Funktsiooni rohkem parameetreid, mis võivad õppijatel aidata leida rohkem kursusi. Saate siin vaadata saadaolevaid API parameetreid:
#  - Looge teine funktsiooni kõne, mis võtab õppijalt rohkem teavet, näiteks nende emakeele
#  - Looge veakäsitlus, kui funktsiooni kõne ja/või API kõne ei tagasta sobivaid kursusi

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Lahtiütlus**:
# See dokument on tõlgitud kasutades AI tõlketeenust [Co-op Translator](https://github.com/Azure/co-op-translator). Kuigi me püüdleme täpsuse poole, palun pange tähele, et automatiseeritud tõlgetes võib esineda vigu või ebatäpsusi. Originaaldokument selle emakeeles tuleks pidada autoriteetseks allikaks. Olulise teabe puhul soovitatakse kasutada professionaalset inimtõlget. Me ei vastuta selle tõlkega seotud eksimustest või valesti mõistmistest.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
