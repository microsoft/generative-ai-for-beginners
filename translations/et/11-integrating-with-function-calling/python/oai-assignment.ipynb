# %% [markdown]
# ## Sissejuhatus
#
# See õppetund käsitleb:
# - Mis on funktsioonide kutsumine ja selle kasutusjuhud
# - Kuidas luua funktsioonikõnet OpenAI abil
# - Kuidas integreerida funktsioonikõne rakendusse
#
# ## Õpieesmärgid
#
# Selle õppetunni lõpetamisel tead ja mõistad:
#
# - Funktsioonide kutsumise eesmärki
# - Funktsioonikõne seadistamist OpenAI teenuse abil
# - Kuidas kujundada tõhusaid funktsioonikõnesid oma rakenduse vajaduste jaoks

# %% [markdown]
# ## Funktsioonikõnede mõistmine
#
# Selleks õppetükiks tahame ehitada meie haridus-ettevõttele funktsiooni, mis võimaldab kasutajatel kasutada vestlusrobotit tehniliste kursuste leidmiseks. Me soovitame kursuseid, mis sobivad nende oskuste taseme, praeguse rolli ja huvipakkuva tehnoloogiaga.
#
# Selle lõpetamiseks kasutame kombinatsiooni:
#  - `OpenAI`, et luua kasutajale vestluskogemus
#  - `Microsoft Learn Catalog API`, et aidata kasutajatel leida kursusi vastavalt kasutaja päringule
#  - `Function Calling`, et võtta kasutaja päring ja saata see funktsiooni, mis teeb API päringu.
#
# Alustamiseks vaatame, miks me üldse tahaksime kasutada funktsioonikõnet:

# %% [markdown]
# ### Miks funktsioonikõnede kasutamine
#
# Kui olete selle kursuse mõne muu õppetüki lõpetanud, siis mõistate tõenäoliselt suurte keelemodellide (LLM-ide) kasutamise jõudu. Loodetavasti näete ka mõningaid nende piiranguid.
#
# Funktsioonikõnede kasutamine on OpenAI teenuse funktsioon, mis on loodud järgnevate väljakutsete lahendamiseks:
#
# Ebajärjekindel vastuse vormindamine:
# - Enne funktsioonikõnesid olid suurte keelemodellide vastused struktureerimata ja ebajärjekindlad. Arendajad pidid kirjutama keerulist valideerimiskoodi, et käsitleda iga erinevust väljundis.
#
# Piiratud integratsioon välise andmetega:
# - Enne seda funktsiooni oli keeruline kaasata andmeid rakenduse teistest osadest vestluse konteksti.
#
# Standardiseerides vastuse vormingud ja võimaldades sujuva integratsiooni väliste andmetega, lihtsustab funktsioonikõnede kasutamine arendust ning vähendab vajadust täiendava valideerimisloogika järele.
#
# Kasutajad ei saanud näiteks vastuseid küsimustele nagu "Milline on hetkeilm Stockholmis?". Põhjus on selles, et mudelid olid piiratud andmete treenimise ajaga.
#
# Vaatame allpool toodud näidet, mis illustreerib seda probleemi:
#
# Oletame, et soovime luua õpilaste andmebaasi, et saaksime neile soovitada sobiva kursuse. Allpool on kaks kirjeldust õpilastest, kes on sisalduvate andmete poolest väga sarnased.

# %%
student_1_description="Emily Johnson is a sophomore majoring in computer science at Duke University. She has a 3.7 GPA. Emily is an active member of the university's Chess Club and Debate Team. She hopes to pursue a career in software engineering after graduating."
 
student_2_description = "Michael Lee is a sophomore majoring in computer science at Stanford University. He has a 3.8 GPA. Michael is known for his programming skills and is an active member of the university's Robotics Club. He hopes to pursue a career in artificial intelligence after finishing his studies."

# %% [markdown]
# Tahame seda saata LLM-ile, et andmeid töödelda. Seda saab hiljem meie rakenduses kasutada, et saata see API-le või salvestada andmebaasi.
#
# Loome kaks identselt küsimust, mille kaudu juhendame LLM-i, millist teavet me soovime:

# %% [markdown]
# Soovime seda saata LLM-ile, et analüüsida meie toote jaoks olulisi osi. Nii saame luua kaks identsed juhiseid andvat prompti LLM-ile:

# %%
prompt1 = f'''
Please extract the following information from the given text and return it as a JSON object:

name
major
school
grades
club

This is the body of text to extract the information from:
{student_1_description}
'''


prompt2 = f'''
Please extract the following information from the given text and return it as a JSON object:

name
major
school
grades
club

This is the body of text to extract the information from:
{student_2_description}
'''

# %% [markdown]
# Pärast nende kahe prompti loomist saadame need LLM-ile, kasutades `client.responses.create`. Me salvestame prompti muutujasse `input` ja määrame rolliks `user`. See on selleks, et jäljendada kasutaja sõnumi kirjutamist vestlusrobotile.

# %%
import os
import json
from openai import OpenAI
from dotenv import load_dotenv
load_dotenv()

client = OpenAI()

deployment="gpt-5-mini"
# Out:
# Running cells with '/opt/homebrew/bin/python3' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# Nüüd saame mõlemad päringud LLM-ile saata ja vastust uurida.

# %%
openai_response1 = client.responses.create(
 model=deployment,    
 input = [{'role': 'user', 'content': prompt1}],
 store=False,
)
openai_response1.output_text

# %%
openai_response2 = client.responses.create(
 model=deployment,    
 input = [{'role': 'user', 'content': prompt2}],
 store=False,
)
openai_response2.output_text

# %%
# Loading the response as a JSON object
json_response1 = json.loads(openai_response1.output_text)
json_response1

# %%
# Loading the response as a JSON object
json_response2 = json.loads(openai_response2.output_text)
json_response2

# %% [markdown]
# Kuigi käsud on samad ja kirjeldused sarnased, võime saada erinevaid vorminguid atribuudi `Grades` jaoks.
#
# Kui käivitad ülaltoodud lahtri mitu korda, võib vorming olla kas `3.7` või `3.7 GPA`.
#
# See on sellepärast, et LLM võtab sisendiks struktuurita andmeid kirjaliku käsu kujul ja tagastab samuti struktuurita andmeid. Me vajame struktureeritud vormingut, et teaksime, mida oodata andmete salvestamisel või kasutamisel.
#
# Funktsionaalse kutsumise kasutamisel saame veenduda, et saame tagasi struktureeritud andmeid. Funktsionaalse kutsumise puhul ei kutsu ega käivita LLM tegelikult ühtegi funktsiooni. Selle asemel loome LLM-ile vastamiseks struktuuri. Seejärel kasutame neid struktureeritud vastuseid selleks, et teada, millist funktsiooni meie rakendustes käivitada.

# %% [markdown]
# ![Funktsiooni kutsumise voo diagramm](../../../../translated_images/et/Function-Flow.083875364af4f4bb.webp)

# %% [markdown]
# Seejärel saame võetud tulemuse funktsioonist saata tagasi LLM-ile. LLM vastab seejärel looduslikus keeles, et kasutaja päringule vastata.

# %% [markdown]
# ### Funktsiooni väljakutsete kasutamise juhtumid
#
# **Väliste tööriistade kutsumine**
# Vestlusrobotid on suurepärased kasutajate küsimustele vastuste andmisel. Funktsioonide väljakutse kasutamise abil saavad vestlusrobotid kasutada kasutajate sõnumeid teatud ülesannete täitmiseks. Näiteks võib tudeng paluda vestlusrobotil "Saatke õpetajale e-kiri, et mul on selle ainega rohkem abi vaja". See võib teha funktsiooni väljakutse `send_email(to: string, body: string)`
#
#
# **API või andmebaasi päringute loomine**
# Kasutajad saavad otsida teavet loodussõnalisel viisil, mis teisendatakse vormindatud päringuks või API päringuks. Näiteks võib õpetaja küsida "Kes on õpilased, kes lõpetasid viimase ülesande", mis võib kutsuda välja funktsiooni nimega `get_completed(student_name: string, assignment: int, current_status: string)`
#
#
# **Struktureeritud andmete loomine**
# Kasutajad saavad võtta teksti ploki või CSV ja kasutada LLM-i selle olulisema teabe eraldamiseks. Näiteks võib tudeng teisendada Wikipedia artikli rahulepingute kohta, et luua tehisintellekti mälukaardid. Seda saab teha funktsiooni abil nimega `get_important_facts(agreement_name: string, date_signed: string, parties_involved: list)`

# %% [markdown]
# ## 2. Oma esimese funktsiooni kutsumise loomine
#
# Funktsioonikõne loomise protsess hõlmab 3 peamist sammu:
# 1. Chat Completions API kutsumine koos teie funktsioonide loendi ja kasutaja sõnumiga
# 2. Loe mudeli vastust, et sooritada tegevus ehk käivitada funktsioon või API-kõne
# 3. Tee teine kõne Chat Completions API-le koos sinu funktsiooni vastusega, et kasutada seda teavet kasutajale vastuse loomiseks.

# %% [markdown]
# ![Funktsiooni kõne voog](../../../../translated_images/et/LLM-Flow.3285ed8caf4796d7.webp)

# %% [markdown]
# ### Funktsiooni väljakutse elemendid
#
# #### Kasutaja sisend
#
# Esimene samm on luua kasutaja sõnum. Seda saab dünaamiliselt määrata, võttes teksti sisendi väärtuse, või võite siin määrata väärtuse. Kui kasutate Chat Completions API-d esimest korda, peame määratlema sõnumi `role` ja `content`.
#
# `role` võib olla `system` (reeglite loomine), `assistant` (mudel) või `user` (lõppkasutaja). Funktsiooni väljakutse korral määrame selle kui `user` ja näitame küsimust.

# %%
messages= [ {"role": "user", "content": "Find me a good course for a beginner student to learn Azure."} ]

# %% [markdown]
# ### Funktsioonide loomine.
#
# Järgmises sammus määratleme funktsiooni ja selle funktsiooni parameetrid. Siin kasutame ainult ühte funktsiooni nimega `search_courses`, kuid võite luua mitu funktsiooni.
#
# **Oluline** : Funktsioonid on kaasatud süsteemiteatesse LLM-ile ja need arvestatakse teie kasutuses olevate tokenite hulka.

# %%
# The Responses API uses a flat tool format: name/description/parameters at the top level
functions = [
   {
      "type":"function",
      "name":"search_courses",
      "description":"Retrieves courses from the search index based on the parameters provided",
      "parameters":{
         "type":"object",
         "properties":{
            "role":{
               "type":"string",
               "description":"The role of the learner (i.e. developer, data scientist, student, etc.)"
            },
            "product":{
               "type":"string",
               "description":"The product that the lesson is covering (i.e. Azure, Power BI, etc.)"
            },
            "level":{
               "type":"string",
               "description":"The level of experience the learner has prior to taking the course (i.e. beginner, intermediate, advanced)"
            }
         },
         "required":[
            "role"
         ]
      }
   }
]

# %% [markdown]
# **Määratlused**
#
# Funktsiooni definitsiooni struktuur koosneb mitmest tasemest, millest igaühel on omadused. Siin on pesastatud struktuuri ülevaade:
#
# **Kõrgema taseme funktsiooni omadused:**
#
# `name` - Funktsiooni nimi, mida soovime kutsuda.
#
# `description` - See on kirjeldus, kuidas funktsioon töötab. Siin on oluline olla konkreetne ja selge
#
# `parameters` - Loend väärtustest ja vormingust, mida soovite mudeli vastuses saada
#
# **Parameetrite objekti omadused:**
#
# `type` - Parameetrite objekti andmetüüp (tavaliselt "object")
#
# `properties` - Loetelu konkreetsetest väärtustest, mida mudel oma vastuses kasutab
#
# **Individuaalsete parameetrite omadused:**
#
# `name` - Implicit määratletud atribuudi võtme järgi (nt "role", "product", "level")
#
# `type` - Selle spetsiifilise parameetri andmetüüp (nt "string", "number", "boolean")
#
# `description` - Kirjeldus konkreetsest parameetrist
#
# **Valikulised omadused:**
#
# `required` - Massiiv, mis loetleb, millised parameetrid on funktsioonikutse lõpetamiseks vajalikud

# %% [markdown]
# ### Funktsiooni kutsumine
# Pärast funktsiooni määratlemist peame nüüd selle lisama Chat Completion API kutsesse. Seda teeme, lisades päringule `functions`. Antud juhul `functions=functions`.
#
# Samuti on võimalik seada `function_call` väärtuseks `auto`. See tähendab, et lubame LLM-il otsustada, milline funktsioon tuleks kutsuda, lähtudes kasutaja sõnumist, selle asemel et seda ise määrata.

# %%
response = client.responses.create(model=deployment, 
                                        input=messages,
                                        tools=functions, 
                                        tool_choice="auto",
                                        store=False) 

print(response.output)

# %% [markdown]
# Vaatame nüüd vastust ja näeme, kuidas see on vormindatud:
#
# {
#   "role": "assistant",
#   "function_call": {
#     "name": "search_courses",
#     "arguments": "{\n  \"role\": \"student\",\n  \"product\": \"Azure\",\n  \"level\": \"beginner\"\n}"
#   }
# }
#
# Näete, et funktsiooni nime kutsutakse ja kasutaja sõnumist leidis LLM andmed, mis sobivad funktsiooni argumentidega.

# %% [markdown]
# ## 3. Funktsioonikõnede integreerimine rakendusse.
#
#
# Pärast seda, kui oleme testinud LLM-i vormindatud vastust, saame selle nüüd rakendusse integreerida.
#
# ### Voogude haldamine
#
# Selle rakendusse integreerimiseks võtame järgmised sammud:
#
# Kõigepealt teeme kutse OpenAI teenustele ja salvestame sõnumi muutujasse nimega `response_message`.

# %%
# Extract the function call items from the response output
tool_calls = [item for item in response.output if item.type == "function_call"]

# %% [markdown]
# Nüüd määratleme funktsiooni, mis kutsub Microsoft Learn API välja, et saada kursuste nimekiri:

# %%
import requests

def search_courses(role, product, level):
    url = "https://learn.microsoft.com/api/catalog/"
    params = {
        "role": role,
        "product": product,
        "level": level
    }
    response = requests.get(url, params=params)
    modules = response.json()["modules"]
    results = []
    for module in modules[:5]:
        title = module["title"]
        url = module["url"]
        results.append({"title": title, "url": url})
    return str(results)

# %% [markdown]
# Hea tavana vaatame seejärel, kas mudel soovib funktsiooni kutsuda. Pärast seda loome ühe olemasolevatest funktsioonidest ja seome selle kutsutava funktsiooniga.
# Seejärel võtame funktsiooni argumendid ja kaardistame need LLM-i argumentidele.
#
# Lõpuks lisame funktsiooni kutsumise sõnumi ja väärtused, mis tagastati `search_courses` sõnumiga. See annab LLM-ile kogu vajaliku info
# kasutaja loomulikus keeles vastamiseks.

# %%
# Check if the model wants to call a function
if tool_calls:
    tool_call = tool_calls[0]
    print("Recommended Function call:")
    print(tool_call.name)
    print()

    # Call the function. 
    function_name = tool_call.name

    available_functions = {
            "search_courses": search_courses,
    }
    function_to_call = available_functions[function_name] 

    function_args = json.loads(tool_call.arguments)
    function_response = function_to_call(**function_args)

    print("Output of function call:")
    print(function_response)
    print(type(function_response))


    # Add the model's function call item(s) and our function result to the conversation.
    # The Responses API represents tool results as `function_call_output` items.
    messages.extend(response.output)  # adding the model's function_call item(s)
    messages.append( # adding function response to messages
        {
            "type": "function_call_output",
            "call_id": tool_call.call_id,
            "output": function_response,
        }
    )

# %% [markdown]
# Nüüd saadame uuendatud sõnumi LLM-ile, et saada algoritmilise JSON-vastuse asemel loomuliku keele vastus.

# %%
print("Messages in next request:")
print(messages)
print()

second_response = client.responses.create(
    input=messages,
    model=deployment,
    tools=functions,
    tool_choice="auto",
    store=False,
        )  # get a new response from the model where it can see the function response


print(second_response.output_text)

# %% [markdown]
# ## Koodi Väljakutse
#
# Väga hea töö! OpenAI funktsioonikõnede õppimise jätkamiseks võid ehitada: https://learn.microsoft.com/training/support/catalog-api-developer-reference?WT.mc_id=academic-105485-koreyst
#  - Veel funktsiooni parameetreid, mis võiksid aidata õppijatel leida rohkem kursusi. Saad kasutada olemasolevaid API parameetreid siit:
#  - Loo teine funktsiooni kõne, mis võtab õppijalt rohkem infot, näiteks nende emakeele
#  - Loo veahaldus juhuks, kui funktsiooni kõne ja/või API kõne ei tagasta sobivaid kursusi

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Lahtiütlus**:
# See dokument on tõlgitud kasutades AI tõlketeenust [Co-op Translator](https://github.com/Azure/co-op-translator). Kuigi me püüdleme täpsuse poole, palun pange tähele, et automatiseeritud tõlgetes võib esineda vigu või ebatäpsusi. Originaaldokument selle emakeeles tuleks pidada autoriteetseks allikaks. Olulise teabe puhul soovitatakse kasutada professionaalset inimtõlget. Me ei vastuta selle tõlkega seotud eksimustest või valesti mõistmistest.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
