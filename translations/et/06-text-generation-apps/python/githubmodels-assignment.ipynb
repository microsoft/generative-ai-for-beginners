# %% [markdown]
# # Ehita tekstigeneratsiooni rakendusi
#
# Selle õppekava jooksul oled näinud, et on olemas põhikontseptsioonid nagu promptid ja isegi terve distsipliin nimega „prompt engineering“. Paljud vahendid, millega saad suhelda, nagu ChatGPT, Office 365, Microsoft Power Platform ja teised, toetavad sind promptide kasutamisel eesmärgi saavutamiseks.
#
# Selleks, et lisada selline kogemus rakendusse, pead sa mõistma mõisteid nagu promptid, täiendused ja valima töötamiseks sobiva raamatu. Just seda sa selles peatükis õpid.
#
# ## Sissejuhatus
#
# Selles peatükis sa:
#
# - Õpid openai raamatukogu ja selle põhikontseptsioonide kohta.
# - Ehita tekstigeneratsiooni rakendus, kasutades openai raamatukogu.
# - Mõista, kuidas kasutada mõisteid nagu prompt, temperatuur ja tokenid tekstigeneratsiooni rakenduse ehitamiseks.
#
# ## Õpieesmärgid
#
# Selle õppetunni lõpus suudad sa:
#
# - Selgitada, mis on tekstigeneratsiooni rakendus.
# - Ehita tekstigeneratsiooni rakendus, kasutades openai raamatukogu.
# - Konfigureerida oma rakendust kasutama rohkem või vähem tokeneid ning muuta temperatuuri, et saada mitmekesisemat väljundit.
#
# ## Mis on tekstigeneratsiooni rakendus?
#
# Tavaliselt, kui ehitad rakenduse, on sellel mingi liides, nagu alljärgnev:
#
# - Käsupõhine. Konsoolirakendused on tüüpilised rakendused, kus sa trükid käsu ja see täidab tegevuse. Näiteks `git` on käsupõhine rakendus.
# - Kasutajaliides (UI). Mõnel rakendusel on graafilised kasutajaliidesed (GUI-d), kus sa klikid nuppudel, sisestad teksti, valid valikuid jms.
#
# ### Konsooli- ja UI-rakendused on piiratud
#
# Võrdle seda käsupõhise rakendusega, kus trükid käsu:
#
# - **See on piiratud.** Sa ei saa trükkida suvalist käsku, ainult neid, mida rakendus toetab.
# - **Keelepõhine.** Mõned rakendused toetavad mitut keelt, kuid vaikimisi on rakendus ehitatud kindla keele jaoks, isegi kui saad lisada rohkem keele tuge.
#
# ### Tekstigeneratsiooni rakenduste eelised
#
# Mis siis on tekstigeneratsiooni rakendus erinev?
#
# Tekstigeneratsiooni rakenduses on sul rohkem paindlikkust, sind ei piirata kindlate käskude ega kindla sisendkeelega. Selle asemel saad kasutada loomulikku keelt rakendusega suhtlemiseks. Teine eelis on see, et sa suhtled juba andmeallikaga, mis on koolitatud tohutu info korpuse peal, samas kui traditsiooniline rakendus võib olla piiratud selle andmebaasi sisuga.
#
# ### Mida ma saan tekstigeneratsiooni rakendusega ehitada?
#
# On palju asju, mida saad ehitada. Näiteks:
#
# - **Vestlusrobot (chatbot).** Vestlusrobot, mis vastab teemade kohta, nagu sinu ettevõte ja selle tooted, võiks olla hea valik.
# - **Abi.** Suured keelemudelid (LLM-id) on suurepärased tekstide kokkusurumisel, tekstist teadmiste võtmises, tekstide loomisel nagu CVd ja rohkem.
# - **Koodi assistent.** Sõltuvalt kasutatavast keelemudelist saad ehitada koodi assistendi, mis aitab sul kirjutada koodi. Näiteks võid kasutada tooteid nagu GitHub Copilot ja ChatGPT, et aidata koodi kirjutamisel.
#
# ## Kuidas alustada?
#
# Sa pead leidma viisi LLM-iga integreerimiseks, mis tavaliselt tähendab kahte lähenemist:
#
# - Kasuta API-t. Siin ehitad veebipäringuid oma promptiga ja saad tagasi genereeritud teksti.
# - Kasuta raamatukogu. Raamatukogud aitavad API kõnesid kapseldada ning teevad nende kasutamise lihtsamaks.
#
# ## Raamatukogud/SDK-d
#
# On mõned tuntud raamatukogud, millega LLM-idega töötada, näiteks:
#
# - **openai**, see raamatukogu teeb lihtsaks mudeliga ühenduse loomise ja promptide saatmise.
#
# Lisaks on olemas kõrgema taseme raamatukogud nagu:
#
# - **Langchain**. Langchain on tuntud ja toetab Pythonit.
# - **Semantic Kernel**. Semantic Kernel on Microsofti raamatukogu, mis toetab keeli C#, Python ja Java.
#
# ## Esimene rakendus Microsoft Foundry Models Playground ja Azure AI Inference SDK kasutades
#
# Vaatame, kuidas me saame oma esimese rakenduse ehitada, milliseid raamatukogusid vajame, kui palju on vajalik ja nii edasi.
#
# > **Märkus:** GitHub Models lõpetab juuli lõpus 2026. Allolevad sammud on uuendatud kasutama [Microsoft Foundry Models](https://ai.azure.com/catalog/models?WT.mc_id=academic-105485-koreyst), mis pakub sama „uurida, proovida mänguväljakul ja kutsuda API võtmega“ kogemust, mida GitHub Models pakkus, nüüd hostitud otse Microsoft Foundry portaalis. Eelistad töötada täielikult võrguühenduseta? Vaata [Foundry Local](https://foundrylocal.ai?WT.mc_id=academic-105485-koreyst) mudelite jooksutamiseks oma seadmes, pilveteenust ei ole vaja.
#
# ### Mis on Microsoft Foundry Models?
#
# Tere tulemast [Microsoft Foundry Models](https://ai.azure.com/catalog/models?WT.mc_id=academic-105485-koreyst)! Foundry mudelite kataloog annab sulle ühe koha, kus uurida ja proovida sadu tehisintellekti mudeleid - OpenAI, Meta, Mistral, Cohere, Microsoft ja teised - mis on majutatud Azure'is, kõik ligipääsetavad tasuta mänguväljaku kaudu ja kui kasutusele võtta, kutsutavad su lemmikkoodi IDE-st.
#
# ### Mida ma vajan?
#
# * Microsofti konto ja [Azure tellimus](https://aka.ms/azure/free?WT.mc_id=academic-105485-koreyst) (tasuta konto sobib)
# * [Microsoft Foundry projekt](https://ai.azure.com?WT.mc_id=academic-105485-koreyst)
#
# Alustagem!
#
# ### Leia mudel ja testi seda
#
# Mine aadressile [Microsoft Foundry Models kataloog](https://ai.azure.com/catalog/models?WT.mc_id=academic-105485-koreyst)
#
# ![Microsoft Foundry Models kataloog näidates mudelikaarte nagu Cohere, Meta llama, Mistral ja GPT mudelid](../../../../translated_images/et/GithubModelsMainScreen.62aed2c56e2bee64.webp)
#
# Vali mudel - näiteks OpenAI GPT-4o mini
#
# Siin näed mudelikaarti. Sa saad:
# * Lugeda mudeli kohta detaile readme, benchmarkide ja litsentsi sakkides
# * Rajada mudel oma Foundry projekti
# * Kui mudel on rajatud, siis suhelda mudeliga otse mänguväljakul
#
# ![Microsoft Foundry Models GPT-4o mudelikaart](../../../../translated_images/et/GithubModels-modelcard.c65ce4538e7bee92.webp)
#
# Ava **Playground**, et mudeliga suhelda, lisada süsteemi promptid ja muuta parameetrite detaile - ning saada kogu kood, mida vajad selle käivitamiseks kõikjal, Pythonis, JavaScriptis, C#-s ja REST'is.
#
# ![Microsoft Foundry Models Playground kogemus näidates koodi ja toetatud keeli](../../../../translated_images/et/GithubModels-plagroundcode.da2dea486f1ad5e0.webp)
#
#
# ### Kasutame mudelit oma IDE-s
#
# Kaks varianti:
# 1. **GitHub Codespaces** - sujuv integratsioon Codespacesiga
# 2. **VS Code (või mõni lemmik IDE)** - vajad **endpoint**i ja **API võtme** oma Foundry projektist
#
#
# Mõlema puhul leiad need väärtused oma Foundry projekti **Ülevaate** lehelt.
#
# ![Get Started ekraan näidates, kuidas pääseda juurde Codespaces või kasutada isikliku ligipääsu tokenit, et seadistada endale IDE](../../../../translated_images/et/GithubModels-getstarted.4821f6f3182fc666.webp)
#
# ### 1. Codespaces
#
# * Loo uus codespace (või kasuta olemasolevat)
# * VS Code avaneb sinu brauseris koos näidis märkmike komplektiga mitmes keeles, mida saad proovida
# * Käivita näidiskood: ```./githubmodels-app.py```.
#
# > Märkus: Codespacesis salvesta oma Foundry endpoint ja võti Codespacesi saladustena, et neid ei peaks lokaalselt seadistama.
#
# **Nüüd liigu allpool olevasse sektsiooni 'Teksti genereerimine', et jätkata seda ülesannet**
#
# ### 2. VS Code (või mõni lemmik IDE)
#
# Microsoft Foundry projektist on sul kogu info, mida vajad, et käivitada oma lemmik IDE-s. See näide näitab VS Code'i kasutamist.
#
# * Rajada vestlusmudel nagu `gpt-4o-mini` oma Foundry projektis
# * Kopeeri projekti **endpoint** ja **API võti** Ülevaate lehelt
# * Loo keskkonnamuutujad, kuhu need salvestada: `AZURE_INFERENCE_ENDPOINT` ja `AZURE_INFERENCE_CREDENTIAL` - näidised saadaval bash, powershelli ja Windowsi käsukäsu juures
# * Paigalda sõltuvused: ```pip install azure-ai-inference```
# * Kopeeri põhinäidiskood .py faili
# * Liigu kausta, kuhu kood on salvestatud, ja käivita fail: ```python filename.py```
#
# Ära unusta, et kasutades Azure AI Inference SDK-d, saad lihtsalt katsetada erinevate mudelitega, muutes koodi `model_name` väärtust.
#
# Järgmised mudelid on saadaval Microsoft Foundry Models kataloogis:
#
# * OpenAI: gpt-4o, gpt-4o-mini, gpt-4.1, gpt-4.1-mini, o3-mini, text-embedding-3-large, text-embedding-3-small
# * Meta: Meta-Llama-3.1-405B-Instruct, Meta-Llama-3.1-70B-Instruct, Meta-Llama-3.1-8B-Instruct, Llama-3.2-11B-Vision-Instruct, Llama-3.2-90B-Vision-Instruct, Llama-4-Scout-17B-16E-Instruct
# * Mistral AI: Mistral-large-2411, Mistral-small-2503, Codestral-2501, Ministral-3B
# * Microsoft: Phi-4, Phi-4-mini-instruct, Phi-4-multimodal-instruct, Phi-4-reasoning
# * Cohere: Cohere-command-r-plus-08-2024, Cohere-embed-v3-multilingual, Cohere-embed-v3-english
# * DeepSeek: DeepSeek-V3, DeepSeek-R1
#
#
#
# **Nüüd liigu allpool olevasse sektsiooni 'Teksti genereerimine', et jätkata seda ülesannet**
#
# ## Teksti genereerimine ChatCompletions abil
#
# Teksti genereerimiseks kasuta klassi `ChatCompletionsClient`.
# Failis `samples/python/azure_ai_inference/basic.py`, koodi vastuse osas uuenda kasutaja rolli, muutes content parameetri alljärgnevalt:
#
# ```python
#
# response = client.complete(
#     messages=[
#         {
#             "role": "system",
#             "content": "You are a helpful assistant.",
#         },
#         {
#             "role": "user",
#             "content": "Complete the following: Once upon a time there was a",
#         },
#     ],
#     model=model_name,
#     # Valikulised parameetrid
#     temperature=1.,
#     max_tokens=1000,
#     top_p=1.
# )
#
# ```
#
# Käivita uuendatud fail, et näha väljundit

# %% [markdown]
# ## Erinevat tüüpi promptid erinevate asjade jaoks
#
# Nüüd oled näinud, kuidas genereerida teksti prompti abil. Sul on isegi programm töös, mida saad muuta ja kohandada erinevat tüüpi teksti genereerimiseks.
#
# Prompte saab kasutada igasugusteks ülesanneteks. Näiteks:
#
# - **Teksti liiki genereerimine**. Näiteks võid genereerida luuletust, viktoriiniküsimusi jne.
# - **Info otsimine**. Prompte saab kasutada informatsiooni otsimiseks nagu näiteks „Mida tähendab CORS veebiarenduses?“.
# - **Koodi genereerimine**. Sa võid promtide abil genereerida koodi, näiteks arendada regulaaravaldisi e-kirjade valideerimiseks või miks mitte terve programmi genereerida, nagu veebirakendus?
#
# ## Harjutus: retseptigeneraator
#
# Kujutle, et sul on kodus koostisosad ja soovid midagi süüa teha. Selleks vajad retsepti. Retseptide leidmiseks võid kasutada otsingumootorit või saaksid kasutada LLM-i.
#
# Sa võiksid kirjutada prompti nii:
#
# > "Näita mulle 5 retsepti roale, milles on järgmised koostisosad: kana, kartulid ja porgandid. Iga retsepti puhul loetle kõik kasutatud koostisosad"
#
# Antud prompti põhjal võid saada vastuse, mis on sarnane:
#
# ```output
# 1. Roasted Chicken and Vegetables:
# Ingredients:
# - 4 chicken thighs
# - 2 potatoes, cut into cubes
# - 2 carrots, cut into cubes
# - 2 tablespoons olive oil
# - 2 cloves garlic, minced
# - 1 teaspoon dried thyme
# - 1 teaspoon dried oregano
# - Salt and pepper, to taste
#
# 2. Chicken and Potato Stew:
# Ingredients:
# - 2 tablespoons olive oil
# - 1 onion, diced
# - 2 cloves garlic, minced
# - 2 chicken breasts, cut into cubes
# - 2 potatoes, cut into cubes
# - 2 carrots, cut into cubes
# - 1 teaspoon dried oregano
# - 1 teaspoon dried thyme
# - 1 cup chicken broth
# - Salt and pepper, to taste
#
# 3. Chicken and Potato Bake:
# Ingredients:
# - 2 tablespoons olive oil
# - 2 chicken breasts, cut into cubes
# - 2 potatoes, cut into cubes
# - 2 carrots, cut into cubes
# - 1 onion, diced
# - 2 cloves garlic, minced
# - 1 teaspoon dried oregano
# - 1 teaspoon dried thyme
# - 1 cup chicken broth
# - Salt and pepper, to taste
#
# 4. Chicken and Potato Soup:
# Ingredients:
# - 2 tablespoons olive oil
# - 1 onion, diced
# - 2 cloves garlic, minced
# - 2 chicken breasts, cut into cubes
# - 2 potatoes, cut into cubes
# - 2 carrots, cut into cubes
# - 1 teaspoon dried oregano
# - 1 teaspoon dried thyme
# - 4 cups chicken broth
# - Salt and pepper, to taste
#
# 5. Chicken and Potato Hash:
# Ingredients:
# - 2 tablespoons olive oil
# - 2 chicken breasts, cut into cubes
# - 2 potatoes, cut into cubes
# - 2 carrots, cut into cubes
# - 1 onion, diced
# - 2 cloves garlic, minced
# - 1 teaspoon dried oregano
# ```
#
# See tulemus on suurepärane, ma tean, mida süüa teha. Praegu võiksid kasulikud täiustused olla:
#
# - Kõrvaldada koostisained, mida ma ei salli või millele olen allergiline.
# - Koostada ostunimekiri juhuks, kui mul ei ole kõiki koostisosi kodus.
#
# Eeltoodud juhtumite jaoks lisame täiendava prompti:
#
# > "Palun eemalda retseptidest küüslauk, kuna olen selle suhtes allergiline, ja asenda see millegagi muuga. Samuti palun koostada ostunimekiri retseptide jaoks, arvestades, et mul on juba kodus kana, kartulid ja porgandid."
#
# Nüüd on sul uus tulemus, nimelt:
#
# ```output
# 1. Roasted Chicken and Vegetables:
# Ingredients:
# - 4 chicken thighs
# - 2 potatoes, cut into cubes
# - 2 carrots, cut into cubes
# - 2 tablespoons olive oil
# - 1 teaspoon dried thyme
# - 1 teaspoon dried oregano
# - Salt and pepper, to taste
#
# 2. Chicken and Potato Stew:
# Ingredients:
# - 2 tablespoons olive oil
# - 1 onion, diced
# - 2 chicken breasts, cut into cubes
# - 2 potatoes, cut into cubes
# - 2 carrots, cut into cubes
# - 1 teaspoon dried oregano
# - 1 teaspoon dried thyme
# - 1 cup chicken broth
# - Salt and pepper, to taste
#
# 3. Chicken and Potato Bake:
# Ingredients:
# - 2 tablespoons olive oil
# - 2 chicken breasts, cut into cubes
# - 2 potatoes, cut into cubes
# - 2 carrots, cut into cubes
# - 1 onion, diced
# - 1 teaspoon dried oregano
# - 1 teaspoon dried thyme
# - 1 cup chicken broth
# - Salt and pepper, to taste
#
# 4. Chicken and Potato Soup:
# Ingredients:
# - 2 tablespoons olive oil
# - 1 onion, diced
# - 2 chicken breasts, cut into cubes
# - 2 potatoes, cut into cubes
# - 2 carrots, cut into cubes
# - 1 teaspoon dried oregano
# - 1 teaspoon dried thyme
# - 4 cups chicken broth
# - Salt and pepper, to taste
#
# 5. Chicken and Potato Hash:
# Ingredients:
# - 2 tablespoons olive oil
# - 2 chicken breasts, cut into cubes
# - 2 potatoes, cut into cubes
# - 2 carrots, cut into cubes
# - 1 onion, diced
# - 1 teaspoon dried oregano
#
# Shopping List:
# - Olive oil
# - Onion
# - Thyme
# - Oregano
# - Salt
# - Pepper
# ```
#
# Need on sinu viis retsepti, kus küüslauku pole mainitud, ja sul on ka ostunimekiri, arvestades, mida sul juba kodus on.

# %% [markdown]
# ## Harjutus - retseptigeneraatori loomine
#
# Nüüd, kui oleme stsenaariumi läbi mänginud, kirjutame koodi, mis vastab demonstreeritud stsenaariumile. Selleks toimige järgmiselt:
#
# 1. Kasutage lähtepunktina olemasolevat faili
# 1. Looge muutuja `prompt` ja muutke näidiskoodi alljärgmiselt:

# %%
import os
from azure.ai.inference import ChatCompletionsClient
from azure.ai.inference.models import SystemMessage, UserMessage
from azure.core.credentials import AzureKeyCredential

# Get these from your Microsoft Foundry project's "Overview" page
token = os.environ["AZURE_INFERENCE_CREDENTIAL"]
endpoint = os.environ["AZURE_INFERENCE_ENDPOINT"]

model_name = "gpt-4o-mini"

client = ChatCompletionsClient(
    endpoint=endpoint,
    credential=AzureKeyCredential(token),
)

prompt = "Show me 5 recipes for a dish with the following ingredients: chicken, potatoes, and carrots. Per recipe, list all the ingredients used"

response = client.complete(
    messages=[
        {
            "role": "system",
            "content": "You are a helpful assistant.",
        },
        {
            "role": "user",
            "content": prompt,
        },
    ],
    model=model_name,
    # Optional parameters
    temperature=1.,
    max_tokens=1000,
    top_p=1.    
)

print(response.choices[0].message.content)

# %% [markdown]
# Kui käivitate nüüd koodi, peaksite nägema sarnast väljundit:
#
# ```output
# ### Recipe 1: Classic Chicken Stew
# #### Ingredients:
# - 2 lbs chicken thighs or drumsticks, skinless
# - 4 cups chicken broth
# - 4 medium potatoes, peeled and diced
# - 4 large carrots, peeled and sliced
# - 1 large onion, chopped
# - 2 cloves garlic, minced
# - 2 celery stalks, sliced
# - 1 tsp dried thyme
# - 1 tsp dried rosemary
# - Salt and pepper to taste
# - 2 tbsp olive oil
# - 2 tbsp flour (optional, for thickening)
#
# ### Recipe 2: Chicken and Vegetable Roast
# #### Ingredients:
# - 4 chicken breasts or thighs
# - 4 medium potatoes, cut into wedges
# - 4 large carrots, cut into sticks
# - 1 large onion, cut into wedges
# - 3 cloves garlic, minced
# - 1/4 cup olive oil
# - 1 tsp paprika
# - 1 tsp dried oregano
# - Salt and pepper to taste
# - Juice of 1 lemon
# - Fresh parsley, chopped (for garnish)
# (continued ...)
# ```
#
# > MÄRKUS, teie LLM on mittedeterministlik, nii et teil võivad programmi käivitamisel iga kord tekkida erinevad tulemused.
#
# Suurepärane, vaatame, kuidas saame asju parandada. Asjade parandamiseks tahame veenduda, et kood oleks paindlik, nii et koostisosade ja retseptide arvu saaks parandada ja muuta.

# %% [markdown]
# 1. Muudame koodi järgmiselt:

# %%
import os
from azure.ai.inference import ChatCompletionsClient
from azure.ai.inference.models import SystemMessage, UserMessage
from azure.core.credentials import AzureKeyCredential

# Get these from your Microsoft Foundry project's "Overview" page
token = os.environ["AZURE_INFERENCE_CREDENTIAL"]
endpoint = os.environ["AZURE_INFERENCE_ENDPOINT"]

model_name = "gpt-4o-mini"

client = ChatCompletionsClient(
    endpoint=endpoint,
    credential=AzureKeyCredential(token),
)

no_recipes = input("No of recipes (for example, 5): ")

ingredients = input("List of ingredients (for example, chicken, potatoes, and carrots): ")

# interpolate the number of recipes into the prompt an ingredients
prompt = f"Show me {no_recipes} recipes for a dish with the following ingredients: {ingredients}. Per recipe, list all the ingredients used"

response = client.complete(
    messages=[
        {
            "role": "system",
            "content": "You are a helpful assistant.",
        },
        {
            "role": "user",
            "content": prompt,
        },
    ],
    model=model_name,
    # Optional parameters
    temperature=1.,
    max_tokens=1000,
    top_p=1.    
)

print(response.choices[0].message.content)

# %% [markdown]
# Koodi testimiseks võiks see välja näha näiteks nii:
#
# ```output
# No of recipes (for example, 5): 2
# List of ingredients (for example, chicken, potatoes, and carrots): milk, strawberries
#
# Sure! Here are two recipes featuring milk and strawberries:
#
# ### Recipe 1: Strawberry Milkshake
#
# #### Ingredients:
# - 1 cup milk
# - 1 cup strawberries, hulled and sliced
# - 2 tablespoons sugar (optional, to taste)
# - 1/2 teaspoon vanilla extract
# - 5-6 ice cubes
#
# #### Instructions:
# 1. Combine the milk, strawberries, sugar (if using), and vanilla extract in a blender.
# 2. Blend on high until smooth and creamy.
# 3. Add the ice cubes and blend again until the ice is fully crushed and the milkshake is frothy.
# 4. Pour into a glass and serve immediately.
#
# ### Recipe 2: Strawberry Panna Cotta
#
# #### Ingredients:
# - 1 cup milk
# - 1 cup strawberries, hulled and pureed
# - 1/4 cup sugar
# - 1 teaspoon vanilla extract
# - 1 envelope unflavored gelatin (about 2 1/2 teaspoons)
# - 2 tablespoons cold water
# - 1 cup heavy cream
#
# #### Instructions:
# 1. Sprinkle the gelatin over the cold water in a small bowl and let it stand for about 5-10 minutes to soften.
# 2. In a saucepan, combine the milk, heavy cream, and sugar. Cook over medium heat, stirring frequently until the sugar is dissolved and the mixture begins to simmer. Do not let it boil.
# 3. Remove the saucepan from the heat and stir in the softened gelatin until completely dissolved.
# 4. Stir in the vanilla extract and allow the mixture to cool slightly.
# 5. Divide the mixture evenly into serving cups or molds and refrigerate for at least 4 hours or until set.
# 6. To prepare the strawberry puree, blend the strawberries until smooth.
# 7. Once the panna cotta is set, spoon the strawberry puree over the top of each panna cotta.
# 8. Serve chilled.
#
# Enjoy these delightful recipes!
# ```
#
# ### Paranda, lisades filtri ja ostunimekirja
#
# Meil on nüüd töötab rakendus, mis suudab koostada retsepte ja on paindlik, kuna tugineb kasutaja sisendile – nii retseptide arvu kui kasutatud koostisosade osas.
#
# Seda edasiarendades soovime lisada järgmist:
#
# - **Filtreeri välja koostisosad**. Soovime võimalust välja filtreerida koostisosi, mida me ei armasta või mille suhtes meil on allergia. Selleks muudatuseks võime redigeerida olemasolevat prompti ja lisada selle lõppu filtritingimuse nii:
#
#     ```python
#     filter = input("Filter (for example, vegetarian, vegan, or gluten-free: ")
#
#     prompt = f"Show me {no_recipes} recipes for a dish with the following ingredients: {ingredients}. Per recipe, list all the ingredients used, no {filter}"
#     ```
#
#     Ülal lisame prompti lõppu `{filter}` ning võtmme ka kasutajalt filtriväärtuse.
#
#     Näidis sisend programmi käivitamisel võib nüüd välja näha nii:
#
#     ```output
#     No of recipes (for example, 5): 2
#     List of ingredients (for example, chicken, potatoes, and carrots): onion, milk
#     Filter (for example, vegetarian, vegan, or gluten-free: no milk
#     Certainly! Here are two recipes using onion but omitting milk:
#
#     ### Recipe 1: Caramelized Onions
#
#     #### Ingredients:
#     - 4 large onions, thinly sliced
#     - 2 tablespoons olive oil
#     - 1 tablespoon butter
#     - 1 teaspoon salt
#     - 1 teaspoon sugar (optional)
#     - 1 tablespoon balsamic vinegar (optional)
#
#     #### Instructions:
#     1. Heat the olive oil and butter in a large skillet over medium heat until the butter is melted.
#     2. Add the onions and stir to coat them with the oil and butter mixture.
#     3. Add salt (and sugar if using) to the onions.
#     4. Cook the onions, stirring occasionally, for about 45 minutes to an hour until they are golden brown and caramelized.
#     5. If using, add balsamic vinegar during the last 5 minutes of cooking.
#     6. Remove from heat and serve as a topping for burgers, steak, or as a side dish.
#
#     ### Recipe 2: French Onion Soup
#
#     #### Ingredients:
#     - 4 large onions, thinly sliced
#     - 3 tablespoons unsalted butter
#     - 2 cloves garlic, minced
#     - 1 teaspoon sugar
#     - 1 teaspoon salt
#     - 1/4 cup dry white wine (optional)
#     - 4 cups beef broth
#     - 4 cups chicken broth
#     - 1 bay leaf
#     - 1 teaspoon fresh thyme, chopped (or 1/2 teaspoon dried thyme)
#     - 1 baguette, sliced
#     - 2 cups Gruyère cheese, grated
#
#     #### Instructions:
#     1. Melt the butter in a large pot over medium heat.
#     2. Add the onions, garlic, sugar, and salt, and cook, stirring frequently, until the onions are deeply caramelized (about 30-35 minutes).
#     3. If using, add the white wine and cook until it evaporates, about 3-5 minutes.
#     4. Add the beef and chicken broths, bay leaf, and thyme. Bring to a simmer and cook for another 30 minutes. Remove the bay leaf.
#     5. Preheat the oven to 400°F (200°C).
#     6. Place the baguette slices on a baking sheet and toast them in the preheated oven until golden brown, about 5 minutes.
#     7. Ladle the soup into oven-safe bowls and place a slice of toasted baguette on top of each bowl.
#     8. Sprinkle the grated Gruyère cheese generously over the baguette slices.
#     9. Place the bowls under the broiler until the cheese is melted and bubbly, about 3-5 minutes.
#     10. Serve hot.
#
#     Enjoy your delicious onion dishes!
#     ```
#
# - **Loo ostunimekiri**. Soovime koostada ostunimekirja, võttes arvesse, mis meil kodus juba olemas on.
#
#     Selle funktsionaalsuse jaoks võiks proovida lahendada kõik ühe promptiga või jagada see kaheks promptiks. Proovime seda viimast lähenemist. Siin soovitame lisada teise prompti, kuid selleks peame esimese prompti tulemuse lisama teise prompti kontekstiks.
#
#     Leia koodist koht, kus trükitakse esmase prompti tulemus ja lisa sinna järgnev kood:
#
#     ```python
#     old_prompt_result = response.choices[0].message.content
#     prompt = "Produce a shopping list for the generated recipes and please don't include ingredients that I already have."
#
#     new_prompt = f"{old_prompt_result} {prompt}"
#
#     response = client.complete(
#         messages=[
#             {
#                 "role": "system",
#                 "content": "You are a helpful assistant.",
#             },
#             {
#                 "role": "user",
#                 "content": new_prompt,
#             },
#         ],
#         model=model_name,
#         # Valikulised parameetrid
#         temperature=1.,
#         max_tokens=1200,
#         top_p=1.
#     )
#
#     # prindi vastus
#     print("Shopping list:")
#     print(response.choices[0].message.content)
#     ```
#
#
#     Pane tähele järgmist:
#
#     - Koostame uue prompti lisades esimese prompti tulemuse uuele promptile:
#
#         ```python
#         new_prompt = f"{old_prompt_result} {prompt}"
#         messages = [{"role": "user", "content": new_prompt}]
#         ```
#
#     - Teeme uue päringu, arvestades siiski ka, et esimese prompti puhul palusime 1200 tokenit (`max_tokens`). **Sõna tokenite pikkusest**. Peaksime kaaluma, kui palju tokeneid on vajalikke soovitud teksti genereerimiseks. Tokenid maksavad, seega tuleks võimalusel olla tokenite kasutamisel säästlik. Näiteks, kas saame kirjutada prompti nii, et kasutame vähem tokeneid?
#
#         ```python
#         response = client.complete(
#             messages=[
#                 {
#                     "role": "system",
#                     "content": "You are a helpful assistant.",
#                 },
#                 {
#                     "role": "user",
#                     "content": new_prompt,
#                 },
#             ],
#             model=model_name,
#             # Valikulised parameetrid
#             temperature=1.,
#             max_tokens=1200,
#             top_p=1.
#         )
#         ```
#
#         Selle koodi käivitades saame nüüd järgmise väljundi:
#
#         ```output
#         No of recipes (for example, 5): 1
#         List of ingredients (for example, chicken, potatoes, and carrots): strawberry, milk
#         Filter (for example, vegetarian, vegan, or gluten-free): nuts
#
#         Certainly! Here's a simple and delicious recipe for a strawberry milkshake using strawberry and milk as primary ingredients:
#
#         ### Strawberry Milkshake
#
#         #### Ingredients:
#         - 1 cup fresh strawberries, hulled
#         - 1 cup cold milk
#         - 1 tablespoon honey or sugar (optional, to taste)
#         - 1/2 teaspoon vanilla extract (optional)
#         - 3-4 ice cubes
#
#         #### Instructions:
#         1. Wash and hull the strawberries, then slice them in half.
#         2. In a blender, combine the strawberries, cold milk, honey or sugar (if using), vanilla extract (if using), and ice cubes.
#         3. Blend until smooth and frothy.
#         4. Pour the milkshake into a glass.
#         5. Serve immediately and enjoy your refreshing strawberry milkshake!
#
#         This recipe is nut-free and makes for a delightful and quick treat!
#         Shopping list:
#         Sure! Here’s the shopping list for the Strawberry Milkshake recipe based on the ingredients provided. Please adjust based on what you already have at home:
#
#         ### Shopping List:
#         - Fresh strawberries (1 cup)
#         - Milk (1 cup)
#
#         Optional:
#         - Honey or sugar (1 tablespoon)
#         - Vanilla extract (1/2 teaspoon)
#         - Ice cubes (3-4)
#
#         Feel free to omit the optional ingredients if you prefer or if you already have them on hand. Enjoy your delicious strawberry milkshake!
#         ```
#
# - **Temperatuuri katsetamine**. Temperatuur on asi, millest pole seni räägitud, kuid see on oluline meie programmi käitumise mõistmiseks. Mida kõrgem on temperatuur, seda juhuslikum on väljund. Mida madalam on temperatuur, seda etteaimatavam on väljund. Mõtle, kas soovid oma väljundis varieeruvust või mitte.
#
#    Temperatuuri muutmiseks võid kasutada `temperature` parameetrit. Näiteks, kui soovid kasutada temperatuuri väärtusega 0.5, teed nii:
#
# ```python
#     response = client.complete(
#         messages=[
#             {
#                 "role": "system",
#                 "content": "You are a helpful assistant.",
#             },
#             {
#                 "role": "user",
#                 "content": new_prompt,
#             },
#         ],
#         model=model_name,
#         # Valikulised parameetrid
#         temperature=0.5,
#         max_tokens=1200,
#         top_p=1.
#     )
# ```
#
#    > Märkus: mida lähemal 1.0, seda varieeruvam on väljund.
#
#
# ## Ülesanne
#
# Selle ülesande puhul võid valida, mida ehitad.
#
# Siin on mõned soovitused:
#
# - Viimistle retseptigeneraatori rakendust veelgi. Katseta temperatuuri väärtusi ja prompte, et näha, mida välja tuleb.
# - Ehita "õppemängukaaslane". See rakendus peaks suutma vastata küsimustele teema kohta, näiteks Python. Võid kasutada mõtteid nagu "Mis on mingi teema Pythoni kohta?", või prompt, mis ütleb "näita mulle koodi mingil teemal" jne.
# - Ajaloo bot, too ajalugu ellu, käsu botil mängida kindlat ajaloolist tegelast ja esita talle küsimusi selle elu ja aja kohta.
#
# ## Lahendus
#
# ### Õppemängukaaslane
#
# - "Sa oled Python keele ekspert
#
#     Paku algajale Python õppetundi järgmises vormingus:
#
#     Vorming:
#     - kontseptsioonid:
#     - lühike õppetunni selgitus:
#     - harjutus koodiga koos lahendustega"
#
# Ülal on alustuseks prompt, vaata, kuidas saad seda kasutada ja oma äranägemise järgi muuta.
#
# ### Ajaloo bot
#
# Siin on mõned promptid, mida võid kasutada:
#
# - "Sa oled Abe Lincoln, räägi endast 3 lauses ja kasuta grammatikat ja sõnu, mida Abe oleks kasutanud"
# - "Sa oled Abe Lincoln, vasta kasutades grammatikat ja sõnu, mida Abe oleks kasutanud:
#
#    Räägi oma suurimatest saavutustest 300 sõnaga:"
#
# ## Teadmiste kontroll
#
# Mida teeb temperatuurikontseptsioon?
#
# 1. See kontrollib, kui juhuslik väljund on.
# 1. See kontrollib, kui pikk vastus on.
# 1. See kontrollib, kui palju tokeneid kasutatakse.
#
# V: 1
#
# Kuidas on hea hoida saladusi nagu API võtmed?
#
# 1. Koodis.
# 1. Failis.
# 1. Keskkonnamuutujates.
#
# V: 3, sest keskkonnamuutujad ei ole koodis salvestatud ja neid saab koodist laadida.

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Lahtiütlus**:
# See dokument on tõlgitud kasutades AI tõlketeenust [Co-op Translator](https://github.com/Azure/co-op-translator). Kuigi me püüdleme täpsuse poole, palun pange tähele, et automatiseeritud tõlgetes võib esineda vigu või ebatäpsusi. Originaaldokument selle emakeeles tuleks pidada autoriteetseks allikaks. Olulise teabe puhul soovitatakse kasutada professionaalset inimtõlget. Me ei vastuta selle tõlkega seotud eksimustest või valesti mõistmistest.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
