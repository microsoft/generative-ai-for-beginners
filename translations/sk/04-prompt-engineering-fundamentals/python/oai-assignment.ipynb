# %% [markdown]
# Nasledujúci notebook bol automaticky vygenerovaný pomocou GitHub Copilot Chat a je určený iba na počiatočné nastavenie

# %% [markdown]
# # Úvod do návrhu promptov
# Návrh promptov je proces navrhovania a optimalizácie promptov pre úlohy spracovania prirodzeného jazyka. Zahŕňa výber správnych promptov, ladenie ich parametrov a vyhodnocovanie ich výkonu. Návrh promptov je kľúčový pre dosiahnutie vysokej presnosti a efektívnosti v modeloch NLP. V tejto sekcii preskúmame základy návrhu promptov pomocou modelov OpenAI pre prieskum.

# %% [markdown]
# ### Cvičenie 1: Tokenizácia
# Preskúmajte tokenizáciu pomocou tiktoken, open-source rýchleho tokenizéra od OpenAI
# Viac príkladov nájdete v [OpenAI Cookbook](https://github.com/openai/openai-cookbook/blob/main/examples/How_to_count_tokens_with_tiktoken.ipynb?WT.mc_id=academic-105485-koreyst).

# %%
# EXERCISE:
# 1. Run the exercise as is first
# 2. Change the text to any prompt input you want to use & re-run to see tokens

import tiktoken

# Define the prompt you want tokenized
text = f"""
Jupiter is the fifth planet from the Sun and the \
largest in the Solar System. It is a gas giant with \
a mass one-thousandth that of the Sun, but two-and-a-half \
times that of all the other planets in the Solar System combined. \
Jupiter is one of the brightest objects visible to the naked eye \
in the night sky, and has been known to ancient civilizations since \
before recorded history. It is named after the Roman god Jupiter.[19] \
When viewed from Earth, Jupiter can be bright enough for its reflected \
light to cast visible shadows,[20] and is on average the third-brightest \
natural object in the night sky after the Moon and Venus.
"""

# Set the model you want encoding for
encoding = tiktoken.encoding_for_model("gpt-4o")

# Encode the text - gives you the tokens in integer form
tokens = encoding.encode(text)
print(tokens);

# Decode the integers to see what the text versions look like
[encoding.decode_single_token_bytes(token) for token in tokens]

# %% [markdown]
# ### Cvičenie 2: Overenie nastavenia kľúča OpenAI API
#
# Spustite nasledujúci kód, aby ste overili, či je váš OpenAI endpoint správne nastavený. Kód iba skúša jednoduchý základný prompt a overuje dokončenie. Vstup `oh say can you see` by mal byť dokončený niečo ako `by the dawn's early light..`

# %%
# Uses the OpenAI client with the Responses API.
# See https://platform.openai.com/docs/api-reference/responses

import os
from openai import OpenAI
from dotenv import load_dotenv
load_dotenv()

client = OpenAI()

deployment="gpt-5-mini"

def get_completion(prompt):
    response = client.responses.create(
        model=deployment,
        input=prompt,
        max_output_tokens=1024,
        store=False,
    )
    return response.output_text

## ---------- Call the helper method

### 1. Set primary content or prompt text
text = f"""
oh say can you see
"""

### 2. Use that in the prompt template below
prompt = f"""
```{text}```
"""

## 3. Run the prompt
response = get_completion(prompt)
print(response)

# %% [markdown]
# ### Cvičenie 3: Vymysleniny
# Preskúmajte, čo sa stane, keď požiadate LLM, aby vrátil dokončenia pre výzvu na tému, ktorá nemusí existovať, alebo o témach, o ktorých nemusí vedieť, pretože neboli súčasťou jeho predtrénovanej dátovej množiny (novšie). Pozrite sa, ako sa odpoveď zmení, ak vyskúšate inú výzvu alebo iný model.

# %%
## Set the text for simple prompt or primary content
## Prompt shows a template format with text in it - add cues, commands etc if needed
## Run the completion 
text = f"""
generate a lesson plan on the Martian War of 2076.
"""

prompt = f"""
```{text}```
"""

response = get_completion(prompt)
print(response)

# %% [markdown]
# ### Cvičenie 4: Na základe inštrukcií
# Použite premennú „text“ na nastavenie hlavného obsahu
# a premennú „prompt“ na poskytnutie inštrukcie súvisiacej s týmto hlavným obsahom.
#
# Tu žiadame model, aby zhrnul text pre druháka

# %%
# Test Example
# https://platform.openai.com/playground/p/default-summarize

## Example text
text = f"""
Jupiter is the fifth planet from the Sun and the \
largest in the Solar System. It is a gas giant with \
a mass one-thousandth that of the Sun, but two-and-a-half \
times that of all the other planets in the Solar System combined. \
Jupiter is one of the brightest objects visible to the naked eye \
in the night sky, and has been known to ancient civilizations since \
before recorded history. It is named after the Roman god Jupiter.[19] \
When viewed from Earth, Jupiter can be bright enough for its reflected \
light to cast visible shadows,[20] and is on average the third-brightest \
natural object in the night sky after the Moon and Venus.
"""

## Set the prompt
prompt = f"""
Summarize content you are provided with for a second-grade student.
```{text}```
"""

## Run the prompt
response = get_completion(prompt)
print(response)

# %% [markdown]
# ### Cvičenie 5: Komplexný prompt
# Skúste požiadavku, ktorá obsahuje správy systému, používateľa a asistenta
# Systém nastavuje kontext asistenta
# Správy používateľa a asistenta poskytujú kontext viackolovej konverzácie
#
# Venujte pozornosť, ako je v systémovom kontexte nastavená osobnosť asistenta na "sarkastickú".
# Skúste použiť inú osobnosť v kontexte. Alebo skúste inú sériu vstupných/výstupných správ

# %%
response = client.responses.create(
    model=deployment,
    input=[
        {"role": "system", "content": "You are a sarcastic assistant."},
        {"role": "user", "content": "Who won the world series in 2020?"},
        {"role": "assistant", "content": "Who do you think won? The Los Angeles Dodgers of course."},
        {"role": "user", "content": "Where was it played?"}
    ],
    store=False,
)
print(response.output_text)

# %% [markdown]
# ### Cvičenie: Preskúmajte svoju intuíciu
# Vyššie uvedené príklady vám dávajú vzory, ktoré môžete použiť na vytváranie nových podnetov (jednoduché, zložité, inštrukcie atď.) - skúste vytvoriť ďalšie cvičenia na preskúmanie niektorých ďalších nápadov, o ktorých sme hovorili, ako sú príklady, náznaky a ďalšie.

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Vyhlásenie o zodpovednosti**:
# Tento dokument bol preložený pomocou AI prekladateľskej služby [Co-op Translator](https://github.com/Azure/co-op-translator). Hoci sa snažíme o presnosť, vezmite prosím na vedomie, že automatické preklady môžu obsahovať chyby alebo nepresnosti. Pôvodný dokument v jeho natívnom jazyku by mal byť považovaný za autoritatívny zdroj. Pre kritické informácie sa odporúča profesionálny ľudský preklad. Nie sme zodpovední za žiadne nedorozumenia alebo nesprávne interpretácie vyplývajúce z použitia tohto prekladu.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
