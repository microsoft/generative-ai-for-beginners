# %% [markdown]
# # 建立文字生成應用程式
#
# 到目前為止，你在這個課程中已經看過像是提示詞（prompts）等核心概念，甚至有一整門學科叫做「提示詞工程」。許多你可以互動的工具，例如 ChatGPT、Office 365、Microsoft Power Platform 等，皆支援你使用提示詞來完成某些事情。
#
# 若你想在應用程式中加入這樣的體驗，你需要了解提示詞、完成結果等概念，並選擇一個合適的函式庫來使用。這正是你將在本章學到的內容。
#
# ## 介紹
#
# 本章你將學到：
#
# - 了解 openai 函式庫及其核心概念。
# - 使用 openai 建立文字生成應用程式。
# - 瞭解如何使用提示詞、溫度（temperature）和 Token 等概念來建構文字生成應用程式。
#
# ## 學習目標
#
# 本課程結束時，你將能夠：
#
# - 解釋什麼是文字生成應用程式。
# - 使用 openai 建構文字生成應用程式。
# - 配置應用程式以使用更多或更少的 Token，並調整溫度參數，以產生多樣化的輸出。
#
# ## 什麼是文字生成應用程式？
#
# 通常當你建立一個應用程式時，它會有某種介面，如下所示：
#
# - 基於命令的介面。控制台應用程式是典型的命令行應用，你輸入命令後它會執行任務。例如，`git` 就是一個基於命令的應用。
# - 使用圖形使用者介面（UI）。有些應用程式有圖形化介面，讓你點擊按鈕、輸入文字、選擇選項等。
#
# ### 控制台和 UI 應用程式的限制
#
# 與基於命令的應用相比，你需要輸入命令：
#
# - <strong>它受限</strong>。你不能隨意輸入任何命令，只能使用應用程式支援的命令。
# - <strong>語言特定</strong>。有些應用程式支援多種語言，但預設是為特定語言設計，即使你可以新增更多語言支援。
#
# ### 文字生成應用程式的優點
#
# 那麼，文字生成應用程式有何不同？
#
# 在文字生成應用程式中，你有更多的彈性，不受限於一組指令或特定輸入語言。相反地，你可以使用自然語言與應用程式互動。另一個優點是，你直接與經過大量文本資料訓練的資料來源互動，而傳統應用程式可能只侷限於資料庫中的內容。
#
# ### 文字生成應用程式可以做什麼？
#
# 你可以建立很多不同的應用，例如：
#
# - <strong>聊天機器人</strong>。能回答有關主題問題的聊天機器人，例如公司及產品相關問題，非常適合。
# - <strong>助手</strong>。大型語言模型（LLM）非常擅長總結文字、提取文本洞察、生成文字如履歷等。
# - <strong>程式碼助手</strong>。依據你使用的語言模型，可以建立幫助你寫程式碼的助手。例如，你可以使用 GitHub Copilot 或 ChatGPT 來協助寫程式碼。
#
# ## 如何開始？
#
# 你需要找到與大型語言模型（LLM）整合的方法，通常有以下兩種方式：
#
# - 使用 API。這裡你會組構網路請求並帶入提示詞，取得生成的文字回應。
# - 使用函式庫。函式庫封裝 API 調用，使使用更加簡便。
#
# ## 函式庫/SDK
#
# 有幾個知名的函式庫可用於操作大型語言模型，如：
#
# - **openai** ：此函式庫讓你輕鬆連接到模型並傳送提示詞。
#
# 另外還有較高層的函式庫，例如：
#
# - **Langchain**。Langchain 相當知名，支援 Python。
# - **Semantic Kernel**。Semantic Kernel 是微軟推出的函式庫，支援 C#、Python 和 Java。
#
# ## 使用 Microsoft Foundry Models Playground 與 Azure AI Inference SDK 建立第一個應用程式
#
# 讓我們看看如何建立第一個應用程式，需要哪些函式庫，流程和需求為何。
#
# > **注意：** GitHub Models 將於 2026 年 7 月底退役。以下步驟已更新，改為使用 [Microsoft Foundry Models](https://ai.azure.com/catalog/models?WT.mc_id=academic-105485-koreyst)，它提供與 GitHub Models 相同的「探索、在 Playground 試用、並使用 API 金鑰呼叫」體驗，現在直接托管在 Microsoft Foundry 入口網站中。如果你偏好完全離線作業，請參考 [Foundry Local](https://foundrylocal.ai?WT.mc_id=academic-105485-koreyst)，可在自己的設備上執行模型，不需雲端訂閱。
#
# ### 什麼是 Microsoft Foundry Models？
#
# 歡迎來到 [Microsoft Foundry Models](https://ai.azure.com/catalog/models?WT.mc_id=academic-105485-koreyst)！Foundry 模型目錄為你提供一個單一平台，可探索並試用數百個 AI 模型，這些模型來自 OpenAI、Meta、Mistral、Cohere、Microsoft 等，並托管於 Azure。你可免費使用 Playground，一旦部署完畢，也可從你最喜愛的程式碼 IDE 中呼叫。
#
# ### 我需要什麼？
#
# * 一組微軟帳戶和一個 [Azure 訂閱](https://aka.ms/azure/free?WT.mc_id=academic-105485-koreyst)（免費帳戶即可）
# * 一個 [Microsoft Foundry 專案](https://ai.azure.com?WT.mc_id=academic-105485-koreyst)
#
# 開始動手吧！
#
# ### 找到模型並測試
#
# 前往 [Microsoft Foundry Models 目錄](https://ai.azure.com/catalog/models?WT.mc_id=academic-105485-koreyst)
#
# ![Microsoft Foundry Models 目錄展示多個模型說明卡，如 Cohere、Meta llama、Mistral 和 GPT 模型](../../../../translated_images/zh-TW/GithubModelsMainScreen.62aed2c56e2bee64.webp)
#
# 選擇一個模型，例如 OpenAI GPT-4o mini
#
# 在這裡你會看到模型說明卡。你可以：
# * 閱讀模型在自述檔、基準測試和授權標籤中的詳細資訊
# * 將模型部署到你的 Foundry 專案
# * 部署後可直接在 Playground 與模型互動
#
# ![Microsoft Foundry Models GPT-4o 模型說明卡](../../../../translated_images/zh-TW/GithubModels-modelcard.c65ce4538e7bee92.webp)
#
# 開啟 **Playground** 與模型互動，新增系統提示詞並更改參數細節 — 同時獲得足夠的程式碼範例，可在任何地方使用 Python、JavaScript、C# 與 REST 執行。
#
# ![Microsoft Foundry Models Playground 操作介面與程式碼與語言顯示](../../../../translated_images/zh-TW/GithubModels-plagroundcode.da2dea486f1ad5e0.webp)
#
#
# ### 在自己喜愛的 IDE 中使用模型
#
# 有兩個選擇：
# 1. **GitHub Codespaces** — 與 Codespaces 無縫整合
# 2. **VS Code（或任何喜愛的 IDE）** — 你需要在 Foundry 專案中取得 **endpoint** 與 **API key**
#
#
# 不論哪種方式，這些數值都可在 Foundry 專案的 **Overview** 頁面找到。
#
# ![入門畫面展示如何存取 Codespaces 或使用個人存取權杖設置你的 IDE](../../../../translated_images/zh-TW/GithubModels-getstarted.4821f6f3182fc666.webp)
#
# ### 1. Codespaces
#
# * 建立一個新的 codespace（或使用現有的）
# * VS Code 將在瀏覽器中開啟，並提供多語言的範例筆記本可試用
# * 執行範例 ```./githubmodels-app.py```
#
# > 注意：在 Codespaces 中，將你的 Foundry 端點和金鑰保存為 Codespaces 秘密，這樣就不用在本機端設定。
#
# **現在接著往下移動到「生成文字」章節繼續本作業**
#
# ### 2. VS Code（或任何喜愛的 IDE）
#
# 在你的 Microsoft Foundry 專案中，你擁有所有需要的資訊來在你喜愛的 IDE 中執行。本範例將示範 VS Code
#
# * 在 Foundry 專案中部署聊天模型，例如 `gpt-4o-mini`
# * 從 Overview 頁面複製項目 **endpoint** 及 **API key**
# * 建立環境變數以存放它們：`AZURE_INFERENCE_ENDPOINT` 與 `AZURE_INFERENCE_CREDENTIAL` — 範例支援 bash、powershell 和 windows 命令提示字元
# * 安裝相依套件：```pip install azure-ai-inference```
# * 將基本範例程式碼複製到 .py 檔案
# * 轉至程式碼所在目錄並執行檔案：```python filename.py```
#
# 不要忘了，利用 Azure AI 推論 SDK，你可以透過修改程式中 `model_name` 的值，輕鬆嘗試不同的模型。
#
# 以下模型可在 Microsoft Foundry Models 目錄中找到：
#
# * OpenAI: gpt-4o, gpt-4o-mini, gpt-4.1, gpt-4.1-mini, o3-mini, text-embedding-3-large, text-embedding-3-small
# * Meta: Meta-Llama-3.1-405B-Instruct, Meta-Llama-3.1-70B-Instruct, Meta-Llama-3.1-8B-Instruct, Llama-3.2-11B-Vision-Instruct, Llama-3.2-90B-Vision-Instruct, Llama-4-Scout-17B-16E-Instruct
# * Mistral AI: Mistral-large-2411, Mistral-small-2503, Codestral-2501, Ministral-3B
# * Microsoft: Phi-4, Phi-4-mini-instruct, Phi-4-multimodal-instruct, Phi-4-reasoning
# * Cohere: Cohere-command-r-plus-08-2024, Cohere-embed-v3-multilingual, Cohere-embed-v3-english
# * DeepSeek: DeepSeek-V3, DeepSeek-R1
#
#
#
# **現在接著往下移動到「生成文字」章節繼續本作業**
#
# ## 使用 ChatCompletions 生成文字
#
# 生成文字的方法是使用 `ChatCompletionsClient` 類別。
# 在 `samples/python/azure_ai_inference/basic.py` 的回應程式碼區段，更新 user 角色的 content 參數內容為以下：
#
# ```python
#
# response = client.complete(
#     messages=[
#         {
#             "role": "system",
#             "content": "You are a helpful assistant.",
#         },
#         {
#             "role": "user",
#             "content": "Complete the following: Once upon a time there was a",
#         },
#     ],
#     model=model_name,
#     # 可選參數
#     temperature=1.,
#     max_tokens=1000,
#     top_p=1.
# )
#
# ```
#
# 執行更新後的檔案以查看輸出結果

# %% [markdown]
# ## 不同類型的提示詞，適用於不同任務
#
# 現在你已經了解如何使用提示詞生成文本。你甚至有一個正在運行的程式，可以修改並生成不同類型的文本。
#
# 提示詞可以用於各種任務。例如：
#
# - <strong>生成某種類型的文本</strong>。例如，你可以生成詩歌、測驗題目等。
# - <strong>查詢資訊</strong>。你可以使用提示尋找資訊，像是例子中的「CORS 在網頁開發中是什麼意思？」。
# - <strong>生成程式碼</strong>。你可以用提示詞生成程式碼，例如開發驗證電子郵件的正則表達式，或者直接生成一個完整的程式，像是網頁應用程式？
#
# ## 練習：食譜生成器
#
# 想像你家裡有食材，想做點菜，這時候你需要食譜。找食譜的方法可以是使用搜尋引擎，或者你也可以用大型語言模型（LLM）來幫助。
#
# 你可以寫出這樣的提示詞：
#
# > 「給我 5 道包含以下食材的料理食譜：雞肉、馬鈴薯和紅蘿蔔。請列出每道食譜中所使用的所有食材」
#
# 根據以上提示詞，你可能會得到類似的回應：
#
# ```output
# 1. Roasted Chicken and Vegetables:
# Ingredients:
# - 4 chicken thighs
# - 2 potatoes, cut into cubes
# - 2 carrots, cut into cubes
# - 2 tablespoons olive oil
# - 2 cloves garlic, minced
# - 1 teaspoon dried thyme
# - 1 teaspoon dried oregano
# - Salt and pepper, to taste
#
# 2. Chicken and Potato Stew:
# Ingredients:
# - 2 tablespoons olive oil
# - 1 onion, diced
# - 2 cloves garlic, minced
# - 2 chicken breasts, cut into cubes
# - 2 potatoes, cut into cubes
# - 2 carrots, cut into cubes
# - 1 teaspoon dried oregano
# - 1 teaspoon dried thyme
# - 1 cup chicken broth
# - Salt and pepper, to taste
#
# 3. Chicken and Potato Bake:
# Ingredients:
# - 2 tablespoons olive oil
# - 2 chicken breasts, cut into cubes
# - 2 potatoes, cut into cubes
# - 2 carrots, cut into cubes
# - 1 onion, diced
# - 2 cloves garlic, minced
# - 1 teaspoon dried oregano
# - 1 teaspoon dried thyme
# - 1 cup chicken broth
# - Salt and pepper, to taste
#
# 4. Chicken and Potato Soup:
# Ingredients:
# - 2 tablespoons olive oil
# - 1 onion, diced
# - 2 cloves garlic, minced
# - 2 chicken breasts, cut into cubes
# - 2 potatoes, cut into cubes
# - 2 carrots, cut into cubes
# - 1 teaspoon dried oregano
# - 1 teaspoon dried thyme
# - 4 cups chicken broth
# - Salt and pepper, to taste
#
# 5. Chicken and Potato Hash:
# Ingredients:
# - 2 tablespoons olive oil
# - 2 chicken breasts, cut into cubes
# - 2 potatoes, cut into cubes
# - 2 carrots, cut into cubes
# - 1 onion, diced
# - 2 cloves garlic, minced
# - 1 teaspoon dried oregano
# ```
#
# 這個結果很棒，我知道要做什麼了。目前，可能有幾個實用的改進：
#
# - 過濾掉我不喜歡或過敏的食材。
# - 產生購物清單，假設我家裡不全都有這些食材。
#
# 針對上述情況，我們加入額外的提示詞：
#
# > 「請移除含有大蒜的食譜，因為我過敏，可用其他食材替代。並請根據我已有雞肉、馬鈴薯和紅蘿蔔，產生購物清單。」
#
# 現在你會得到新的結果：
#
# ```output
# 1. Roasted Chicken and Vegetables:
# Ingredients:
# - 4 chicken thighs
# - 2 potatoes, cut into cubes
# - 2 carrots, cut into cubes
# - 2 tablespoons olive oil
# - 1 teaspoon dried thyme
# - 1 teaspoon dried oregano
# - Salt and pepper, to taste
#
# 2. Chicken and Potato Stew:
# Ingredients:
# - 2 tablespoons olive oil
# - 1 onion, diced
# - 2 chicken breasts, cut into cubes
# - 2 potatoes, cut into cubes
# - 2 carrots, cut into cubes
# - 1 teaspoon dried oregano
# - 1 teaspoon dried thyme
# - 1 cup chicken broth
# - Salt and pepper, to taste
#
# 3. Chicken and Potato Bake:
# Ingredients:
# - 2 tablespoons olive oil
# - 2 chicken breasts, cut into cubes
# - 2 potatoes, cut into cubes
# - 2 carrots, cut into cubes
# - 1 onion, diced
# - 1 teaspoon dried oregano
# - 1 teaspoon dried thyme
# - 1 cup chicken broth
# - Salt and pepper, to taste
#
# 4. Chicken and Potato Soup:
# Ingredients:
# - 2 tablespoons olive oil
# - 1 onion, diced
# - 2 chicken breasts, cut into cubes
# - 2 potatoes, cut into cubes
# - 2 carrots, cut into cubes
# - 1 teaspoon dried oregano
# - 1 teaspoon dried thyme
# - 4 cups chicken broth
# - Salt and pepper, to taste
#
# 5. Chicken and Potato Hash:
# Ingredients:
# - 2 tablespoons olive oil
# - 2 chicken breasts, cut into cubes
# - 2 potatoes, cut into cubes
# - 2 carrots, cut into cubes
# - 1 onion, diced
# - 1 teaspoon dried oregano
#
# Shopping List:
# - Olive oil
# - Onion
# - Thyme
# - Oregano
# - Salt
# - Pepper
# ```
#
# 這是你的五道食譜，都沒有大蒜，而且還有依照你已有的食材產生的購物清單。

# %% [markdown]
# ## 練習 - 建立一個食譜產生器
#
# 現在我們已經模擬了一個情境，讓我們撰寫程式碼以符合示範的情境。為此，請依照以下步驟：
#
# 1. 使用現有的檔案作為起點
# 1. 建立一個 `prompt` 變數，並將範例程式碼修改如下：

# %%
import os
from azure.ai.inference import ChatCompletionsClient
from azure.ai.inference.models import SystemMessage, UserMessage
from azure.core.credentials import AzureKeyCredential

# Get these from your Microsoft Foundry project's "Overview" page
token = os.environ["AZURE_INFERENCE_CREDENTIAL"]
endpoint = os.environ["AZURE_INFERENCE_ENDPOINT"]

model_name = "gpt-4o-mini"

client = ChatCompletionsClient(
    endpoint=endpoint,
    credential=AzureKeyCredential(token),
)

prompt = "Show me 5 recipes for a dish with the following ingredients: chicken, potatoes, and carrots. Per recipe, list all the ingredients used"

response = client.complete(
    messages=[
        {
            "role": "system",
            "content": "You are a helpful assistant.",
        },
        {
            "role": "user",
            "content": prompt,
        },
    ],
    model=model_name,
    # Optional parameters
    temperature=1.,
    max_tokens=1000,
    top_p=1.    
)

print(response.choices[0].message.content)

# %% [markdown]
# 如果你現在執行這段程式碼，你應該會看到類似以下的輸出：
#
# ```output
# ### Recipe 1: Classic Chicken Stew
# #### Ingredients:
# - 2 lbs chicken thighs or drumsticks, skinless
# - 4 cups chicken broth
# - 4 medium potatoes, peeled and diced
# - 4 large carrots, peeled and sliced
# - 1 large onion, chopped
# - 2 cloves garlic, minced
# - 2 celery stalks, sliced
# - 1 tsp dried thyme
# - 1 tsp dried rosemary
# - Salt and pepper to taste
# - 2 tbsp olive oil
# - 2 tbsp flour (optional, for thickening)
#
# ### Recipe 2: Chicken and Vegetable Roast
# #### Ingredients:
# - 4 chicken breasts or thighs
# - 4 medium potatoes, cut into wedges
# - 4 large carrots, cut into sticks
# - 1 large onion, cut into wedges
# - 3 cloves garlic, minced
# - 1/4 cup olive oil
# - 1 tsp paprika
# - 1 tsp dried oregano
# - Salt and pepper to taste
# - Juice of 1 lemon
# - Fresh parsley, chopped (for garnish)
# (continued ...)
# ```
#
# > 注意，你的 LLM 是非決定性的，所以每次執行程式時可能會得到不同的結果。
#
# 很好，讓我們來看看如何改進。為了改進，我們希望確保程式碼具有彈性，這樣配料和食譜的數量才能被改良和更改。

# %% [markdown]
# 1. 我們來按照以下方式更改程式碼：

# %%
import os
from azure.ai.inference import ChatCompletionsClient
from azure.ai.inference.models import SystemMessage, UserMessage
from azure.core.credentials import AzureKeyCredential

# Get these from your Microsoft Foundry project's "Overview" page
token = os.environ["AZURE_INFERENCE_CREDENTIAL"]
endpoint = os.environ["AZURE_INFERENCE_ENDPOINT"]

model_name = "gpt-4o-mini"

client = ChatCompletionsClient(
    endpoint=endpoint,
    credential=AzureKeyCredential(token),
)

no_recipes = input("No of recipes (for example, 5): ")

ingredients = input("List of ingredients (for example, chicken, potatoes, and carrots): ")

# interpolate the number of recipes into the prompt an ingredients
prompt = f"Show me {no_recipes} recipes for a dish with the following ingredients: {ingredients}. Per recipe, list all the ingredients used"

response = client.complete(
    messages=[
        {
            "role": "system",
            "content": "You are a helpful assistant.",
        },
        {
            "role": "user",
            "content": prompt,
        },
    ],
    model=model_name,
    # Optional parameters
    temperature=1.,
    max_tokens=1000,
    top_p=1.    
)

print(response.choices[0].message.content)

# %% [markdown]
# 進行程式碼測試運行，可以看起來像這樣：
#
# ```output
# No of recipes (for example, 5): 2
# List of ingredients (for example, chicken, potatoes, and carrots): milk, strawberries
#
# Sure! Here are two recipes featuring milk and strawberries:
#
# ### Recipe 1: Strawberry Milkshake
#
# #### Ingredients:
# - 1 cup milk
# - 1 cup strawberries, hulled and sliced
# - 2 tablespoons sugar (optional, to taste)
# - 1/2 teaspoon vanilla extract
# - 5-6 ice cubes
#
# #### Instructions:
# 1. Combine the milk, strawberries, sugar (if using), and vanilla extract in a blender.
# 2. Blend on high until smooth and creamy.
# 3. Add the ice cubes and blend again until the ice is fully crushed and the milkshake is frothy.
# 4. Pour into a glass and serve immediately.
#
# ### Recipe 2: Strawberry Panna Cotta
#
# #### Ingredients:
# - 1 cup milk
# - 1 cup strawberries, hulled and pureed
# - 1/4 cup sugar
# - 1 teaspoon vanilla extract
# - 1 envelope unflavored gelatin (about 2 1/2 teaspoons)
# - 2 tablespoons cold water
# - 1 cup heavy cream
#
# #### Instructions:
# 1. Sprinkle the gelatin over the cold water in a small bowl and let it stand for about 5-10 minutes to soften.
# 2. In a saucepan, combine the milk, heavy cream, and sugar. Cook over medium heat, stirring frequently until the sugar is dissolved and the mixture begins to simmer. Do not let it boil.
# 3. Remove the saucepan from the heat and stir in the softened gelatin until completely dissolved.
# 4. Stir in the vanilla extract and allow the mixture to cool slightly.
# 5. Divide the mixture evenly into serving cups or molds and refrigerate for at least 4 hours or until set.
# 6. To prepare the strawberry puree, blend the strawberries until smooth.
# 7. Once the panna cotta is set, spoon the strawberry puree over the top of each panna cotta.
# 8. Serve chilled.
#
# Enjoy these delightful recipes!
# ```
#
# ### 透過加入篩選器和購物清單來改進
#
# 我們現在有一個可運作的應用程式，可以產生食譜，而且相當彈性，因為它依賴使用者的輸入，包括食譜數量以及使用的食材。
#
# 為了進一步改進它，我們希望新增以下功能：
#
# - <strong>篩選掉不想要的食材</strong>。我們希望能夠篩選掉我們不喜歡或過敏的食材。為了實現這個改動，我們可以修改現有的提示語，在它末尾加入一個篩選條件，如下所示：
#
#     ```python
#     filter = input("Filter (for example, vegetarian, vegan, or gluten-free: ")
#
#     prompt = f"Show me {no_recipes} recipes for a dish with the following ingredients: {ingredients}. Per recipe, list all the ingredients used, no {filter}"
#     ```
#
#     上述程式碼中，我們在提示語句末尾添加了 `{filter}`，同時也從使用者處取得篩選條件的值。
#
#     執行程式的示例輸入現在可以像這樣：
#
#     ```output
#     No of recipes (for example, 5): 2
#     List of ingredients (for example, chicken, potatoes, and carrots): onion, milk
#     Filter (for example, vegetarian, vegan, or gluten-free: no milk
#     Certainly! Here are two recipes using onion but omitting milk:
#
#     ### Recipe 1: Caramelized Onions
#
#     #### Ingredients:
#     - 4 large onions, thinly sliced
#     - 2 tablespoons olive oil
#     - 1 tablespoon butter
#     - 1 teaspoon salt
#     - 1 teaspoon sugar (optional)
#     - 1 tablespoon balsamic vinegar (optional)
#
#     #### Instructions:
#     1. Heat the olive oil and butter in a large skillet over medium heat until the butter is melted.
#     2. Add the onions and stir to coat them with the oil and butter mixture.
#     3. Add salt (and sugar if using) to the onions.
#     4. Cook the onions, stirring occasionally, for about 45 minutes to an hour until they are golden brown and caramelized.
#     5. If using, add balsamic vinegar during the last 5 minutes of cooking.
#     6. Remove from heat and serve as a topping for burgers, steak, or as a side dish.
#
#     ### Recipe 2: French Onion Soup
#
#     #### Ingredients:
#     - 4 large onions, thinly sliced
#     - 3 tablespoons unsalted butter
#     - 2 cloves garlic, minced
#     - 1 teaspoon sugar
#     - 1 teaspoon salt
#     - 1/4 cup dry white wine (optional)
#     - 4 cups beef broth
#     - 4 cups chicken broth
#     - 1 bay leaf
#     - 1 teaspoon fresh thyme, chopped (or 1/2 teaspoon dried thyme)
#     - 1 baguette, sliced
#     - 2 cups Gruyère cheese, grated
#
#     #### Instructions:
#     1. Melt the butter in a large pot over medium heat.
#     2. Add the onions, garlic, sugar, and salt, and cook, stirring frequently, until the onions are deeply caramelized (about 30-35 minutes).
#     3. If using, add the white wine and cook until it evaporates, about 3-5 minutes.
#     4. Add the beef and chicken broths, bay leaf, and thyme. Bring to a simmer and cook for another 30 minutes. Remove the bay leaf.
#     5. Preheat the oven to 400°F (200°C).
#     6. Place the baguette slices on a baking sheet and toast them in the preheated oven until golden brown, about 5 minutes.
#     7. Ladle the soup into oven-safe bowls and place a slice of toasted baguette on top of each bowl.
#     8. Sprinkle the grated Gruyère cheese generously over the baguette slices.
#     9. Place the bowls under the broiler until the cheese is melted and bubbly, about 3-5 minutes.
#     10. Serve hot.
#
#     Enjoy your delicious onion dishes!
#     ```
#
# - <strong>產生購物清單</strong>。我們希望根據家裡已有的食材，產生一份購物清單。
#
#     對於這個功能，我們可以嘗試在同一個提示語裡解決所有問題，或者拆成兩個提示語。這裡我們嘗試後者做法。這裡建議新增一個提示語，但為了使它有效，我們需要將前一個提示語的結果作為後一個提示語的上下文。
#
#     找出程式碼中印出第一個提示結果的部分，並在下面新增如下程式碼：
#
#     ```python
#     old_prompt_result = response.choices[0].message.content
#     prompt = "Produce a shopping list for the generated recipes and please don't include ingredients that I already have."
#
#     new_prompt = f"{old_prompt_result} {prompt}"
#
#     response = client.complete(
#         messages=[
#             {
#                 "role": "system",
#                 "content": "You are a helpful assistant.",
#             },
#             {
#                 "role": "user",
#                 "content": new_prompt,
#             },
#         ],
#         model=model_name,
#         # 選擇性參數
#         temperature=1.,
#         max_tokens=1200,
#         top_p=1.
#     )
#
#     # 列印回應
#     print("Shopping list:")
#     print(response.choices[0].message.content)
#     ```
#
#
#     注意以下幾點：
#
#     - 我們是透過將第一個提示的結果附加到新提示裡，來組合出新的提示語：
#
#         ```python
#         new_prompt = f"{old_prompt_result} {prompt}"
#         messages = [{"role": "user", "content": new_prompt}]
#         ```
#
#     - 我們發出一個新的請求，並考慮到第一次呼叫時的 token 數量，這次設定 `max_tokens` 為 1200。**關於 token 長度的說明**。我們應該考慮生成文字所需的 token 數。Token 使用會產生費用，因此盡可能經濟使用 token。舉例來說，我們能不能重新措辭提示語，減少 token 使用？
#
#         ```python
#         response = client.complete(
#             messages=[
#                 {
#                     "role": "system",
#                     "content": "You are a helpful assistant.",
#                 },
#                 {
#                     "role": "user",
#                     "content": new_prompt,
#                 },
#             ],
#             model=model_name,
#             # 可選參數
#             temperature=1.,
#             max_tokens=1200,
#             top_p=1.
#         )
#         ```
#
#         以此程式碼運行的結果，我們可得到如下輸出：
#
#         ```output
#         No of recipes (for example, 5): 1
#         List of ingredients (for example, chicken, potatoes, and carrots): strawberry, milk
#         Filter (for example, vegetarian, vegan, or gluten-free): nuts
#
#         Certainly! Here's a simple and delicious recipe for a strawberry milkshake using strawberry and milk as primary ingredients:
#
#         ### Strawberry Milkshake
#
#         #### Ingredients:
#         - 1 cup fresh strawberries, hulled
#         - 1 cup cold milk
#         - 1 tablespoon honey or sugar (optional, to taste)
#         - 1/2 teaspoon vanilla extract (optional)
#         - 3-4 ice cubes
#
#         #### Instructions:
#         1. Wash and hull the strawberries, then slice them in half.
#         2. In a blender, combine the strawberries, cold milk, honey or sugar (if using), vanilla extract (if using), and ice cubes.
#         3. Blend until smooth and frothy.
#         4. Pour the milkshake into a glass.
#         5. Serve immediately and enjoy your refreshing strawberry milkshake!
#
#         This recipe is nut-free and makes for a delightful and quick treat!
#         Shopping list:
#         Sure! Here’s the shopping list for the Strawberry Milkshake recipe based on the ingredients provided. Please adjust based on what you already have at home:
#
#         ### Shopping List:
#         - Fresh strawberries (1 cup)
#         - Milk (1 cup)
#
#         Optional:
#         - Honey or sugar (1 tablespoon)
#         - Vanilla extract (1/2 teaspoon)
#         - Ice cubes (3-4)
#
#         Feel free to omit the optional ingredients if you prefer or if you already have them on hand. Enjoy your delicious strawberry milkshake!
#         ```
#
# - **實驗調整 temperature 參數**。temperature 是一個到目前為止未提及，但對程式表現很重要的設定。temperature 值越高，輸出結果越隨機；反之，temperature 越低，輸出就越可預測。請考慮你是否想要輸出的多樣性。
#
#    若要調整 temperature，你可以使用 `temperature` 參數。例如，如果想使用 0.5 的 temperature，程式碼如下：
#
# ```python
#     response = client.complete(
#         messages=[
#             {
#                 "role": "system",
#                 "content": "You are a helpful assistant.",
#             },
#             {
#                 "role": "user",
#                 "content": new_prompt,
#             },
#         ],
#         model=model_name,
#         # 可選參數
#         temperature=0.5,
#         max_tokens=1200,
#         top_p=1.
#     )
# ```
#
#    > 注意，越接近 1.0，輸出就越多變化。
#
#
# ## 作業
#
# 在此作業中，你可以自由決定想要建置什麼。
#
# 以下是一些建議：
#
# - 進一步調整食譜產生器應用程式。嘗試 temperature 的不同數值，以及更換提示語，看看你能設計出什麼功能。
# - 建立一個「學習夥伴」。這個應用程式能夠針對主題，例如 Python，回答相關問題。你可以設計類似「Python 的某個主題是什麼？」或「請給我某個主題的程式碼」的提示語。
# - 歷史機器人，讓歷史活起來，指示機器人扮演某個歷史人物，並詢問其生平與時代背景。
#
# ## 解答
#
# ### 學習夥伴
#
# - 「你是 Python 語言專家
#
#     請建議適合初學者的 Python 課程，格式如下：
#
#     格式：
#     - 概念：
#     - 課程簡要說明：
#     - 程式碼練習與解答」
#
# 上述是一個起始提示語，看看你如何使用並調整，做出自己喜歡的版本。
#
# ### 歷史機器人
#
# 以下是你可以試用的一些提示語：
#
# - 「你是亞伯‧林肯，請用三句話介紹自己，並用林肯當時會用的文法及措辭回答」
# - 「你是亞伯‧林肯，請用林肯會用的文法及措辭回答：
#
#    請告訴我你最偉大的成就，用 300 字回答：」
#
# ## 知識檢測
#
# temperature 參數是做什麼用的？
#
# 1. 它控制輸出的隨機程度。
# 1. 它控制回應的大小。
# 1. 它控制使用了多少 tokens。
#
# 答案：1
#
# 儲存像 API key 這類機密的好方法是什麼？
#
# 1. 直接寫在程式碼裡。
# 1. 寫在檔案裡。
# 1. 使用環境變數。
#
# 答案：3，因為環境變數不會存在程式碼裡，但可以從程式碼讀取。

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **免責聲明**：
# 此文件已使用 AI 翻譯服務 [Co-op Translator](https://github.com/Azure/co-op-translator) 進行翻譯。雖然我們努力追求準確性，但請注意自動翻譯可能包含錯誤或不準確之處。原始文件的母語版本應視為權威來源。對於關鍵資訊，建議採用專業人工翻譯。我們不對因使用此翻譯所產生的任何誤解或誤譯承擔責任。
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
