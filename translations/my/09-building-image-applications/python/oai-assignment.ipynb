# %% [markdown]
# # ပုံထုတ်လုပ်ရေးအက်ပ်လီကေးရှင်း တည်ဆောက်ခြင်း
#
# LLM တွေဟာ စာသားထုတ်လုပ်ခြင်းအတွက်သာမက ပိုပြီးအကျိုးရှိပါတယ်။ စာသားဖော်ပြချက်တွေကနေ ပုံတွေကိုပါ ထုတ်လုပ်နိုင်ပါတယ်။ ပုံတွေကို modality အနေနဲ့ အသုံးပြုနိုင်တာဟာ MedTech, အိမ်ဆောက်လုပ်ရေး, ခရီးသွားလုပ်ငန်း, ဂိမ်းဖန်တီးမှုနဲ့ အခြားနယ်ပယ်တွေမှာ အလွန်အသုံးဝင်ပါတယ်။ ဒီအခန်းမှာတော့ အလွန်လူကြိုက်များတဲ့ ပုံထုတ်လုပ်ရေးမော်ဒယ်နှစ်ခုဖြစ်တဲ့ DALL-E နဲ့ Midjourney ကို လေ့လာသွားမှာပါ။
#
# ## မိတ်ဆက်
#
# ဒီသင်ခန်းစာမှာ လေ့လာရမယ့်အကြောင်းအရာတွေကတော့ -
#
# - ပုံထုတ်လုပ်ခြင်းနဲ့ ဘာကြောင့် အသုံးဝင်သလဲ။
# - DALL-E နဲ့ Midjourney ဆိုတာ ဘာလဲ၊ ဘယ်လိုအလုပ်လုပ်သလဲ။
# - ပုံထုတ်လုပ်ရေးအက်ပ်တစ်ခုကို ဘယ်လိုတည်ဆောက်မလဲ။
#
# ## သင်ယူရမယ့်ရည်ရွယ်ချက်များ
#
# ဒီသင်ခန်းစာပြီးဆုံးပြီးရင် -
#
# - ပုံထုတ်လုပ်ရေးအက်ပ်တစ်ခု တည်ဆောက်နိုင်မယ်။
# - မိမိအက်ပ်အတွက် meta prompts နဲ့ အနားသတ်နိုင်မယ်။
# - DALL-E နဲ့ Midjourney ကို အသုံးပြုနိုင်မယ်။
#
# ## ဘာကြောင့် ပုံထုတ်လုပ်ရေးအက်ပ် တည်ဆောက်သင့်သလဲ?
#
# ပုံထုတ်လုပ်ရေးအက်ပ်တွေက Generative AI ရဲ့စွမ်းရည်တွေကို စမ်းသပ်ဖို့အတွက် အရမ်းကောင်းတဲ့နည်းလမ်းတစ်ခုပါ။ ဥပမာ -
#
# - **ပုံတည်းဖြတ်ခြင်းနဲ့ ပုံဖန်တီးခြင်း**။ အသုံးအများဆုံးအတွက် ပုံတည်းဖြတ်ခြင်း၊ ပုံဖန်တီးခြင်းအတွက် အသုံးပြုနိုင်ပါတယ်။
#
# - **နယ်ပယ်အမျိုးမျိုးမှာ အသုံးချနိုင်ခြင်း**။ Medtech, ခရီးသွားလုပ်ငန်း, ဂိမ်းဖန်တီးမှုနဲ့ အခြားနယ်ပယ်တွေမှာ အသုံးပြုနိုင်ပါတယ်။
#
# ## အခြေအနေ - Edu4All
#
# ဒီသင်ခန်းစာမှာ Edu4All ဆိုတဲ့ startup နဲ့ ဆက်လက်အလုပ်လုပ်သွားမှာပါ။ ကျောင်းသားတွေက သူတို့ရဲ့ စာမေးပွဲအတွက် ပုံတွေဖန်တီးမှာဖြစ်ပြီး ဘယ်လိုပုံဖန်တီးမလဲဆိုတာ သူတို့ပဲဆုံးဖြတ်နိုင်ပါတယ်။ ဥပမာ သူတို့ရဲ့ပုံပြင်အတွက် ပုံဆွဲခြင်း၊ ဇာတ်ကောင်အသစ်ဖန်တီးခြင်း၊ ကိုယ်ပိုင်စိတ်ကူးတွေကို မြင်သာအောင်ဖန်တီးခြင်း စသဖြင့်။
#
# ဥပမာ ကျောင်းသားတွေက အတန်းထဲမှာ အထင်ကရအဆောက်အအုံတွေကို လေ့လာနေတဲ့အခါ ဖန်တီးနိုင်တဲ့ပုံက -
#
# ![Edu4All startup, class on monuments, Eifel Tower](../../../../translated_images/startup.94d6b79cc4bb3f5afbf6e2ddfcf309aa5d1e256b5f30cc41d252024eaa9cc5dc.my.png)
#
# prompt တစ်ခုက
#
# > "Dog next to Eiffel Tower in early morning sunlight"
#
# ## DALL-E နဲ့ Midjourney ဆိုတာဘာလဲ?
#
# [DALL-E](https://openai.com/dall-e-2?WT.mc_id=academic-105485-koreyst) နဲ့ [Midjourney](https://www.midjourney.com/?WT.mc_id=academic-105485-koreyst) ဟာ လူကြိုက်အများဆုံး ပုံထုတ်လုပ်ရေးမော်ဒယ်နှစ်ခုဖြစ်ပြီး prompt တွေသုံးပြီး ပုံထုတ်လုပ်နိုင်ပါတယ်။
#
# ### DALL-E
#
# DALL-E က စာသားဖော်ပြချက်တွေကနေ ပုံထုတ်လုပ်နိုင်တဲ့ Generative AI မော်ဒယ်တစ်ခုပါ။
#
# > [DALL-E ဟာ CLIP နဲ့ diffused attention ဆိုတဲ့ မော်ဒယ်နှစ်ခုပေါင်းစပ်ထားတာပါ](https://towardsdatascience.com/openais-dall-e-and-clip-101-a-brief-introduction-3a4367280d4e?WT.mc_id=academic-105485-koreyst)။
#
# - **CLIP** က ပုံနဲ့စာသားတွေကနေ embedding တွေ (ဒေတာကို ဂဏန်းနဲ့ဖော်ပြထားတဲ့အရာ) ထုတ်လုပ်တဲ့မော်ဒယ်ပါ။
#
# - **Diffused attention** က embedding တွေကနေ ပုံထုတ်လုပ်တဲ့မော်ဒယ်ပါ။ DALL-E ကို ပုံနဲ့စာသား dataset တွေသုံးပြီး သင်ကြားထားပါတယ်။ စာသားဖော်ပြချက်တွေကနေ ပုံထုတ်လုပ်နိုင်ပါတယ်။ ဥပမာ DALL-E ကို "တစ်ကောင်က ဦးထုပ်တပ်ထားတဲ့ကြောင်"၊ "မိုဟော့ခေါင်းပုံစံရှိတဲ့ခွေး" စသဖြင့် ပုံထုတ်လုပ်နိုင်ပါတယ်။
#
# ### Midjourney
#
# Midjourney က DALL-E နဲ့ တူတဲ့နည်းလမ်းနဲ့ အလုပ်လုပ်ပါတယ်။ စာသား prompt တွေသုံးပြီး ပုံထုတ်လုပ်နိုင်ပါတယ်။ ဥပမာ “တစ်ကောင်က ဦးထုပ်တပ်ထားတဲ့ကြောင်”၊ “မိုဟော့ခေါင်းပုံစံရှိတဲ့ခွေး” စသဖြင့် prompt တွေသုံးနိုင်ပါတယ်။
#
# ![Image generated by Midjourney, mechanical pigeon](https://upload.wikimedia.org/wikipedia/commons/thumb/8/8c/Rupert_Breheny_mechanical_dove_eca144e7-476d-4976-821d-a49c408e4f36.png/440px-Rupert_Breheny_mechanical_dove_eca144e7-476d-4976-821d-a49c408e4f36.png?WT.mc_id=academic-105485-koreyst)
#
# *Wikipedia မှပုံ၊ Midjourney နဲ့ထုတ်လုပ်ထားတဲ့ပုံ*
#
# ## DALL-E နဲ့ Midjourney ဘယ်လိုအလုပ်လုပ်သလဲ
#
# ပထမဆုံး [DALL-E](https://arxiv.org/pdf/2102.12092.pdf?WT.mc_id=academic-105485-koreyst) ကို ကြည့်ပါ။ DALL-E ဟာ transformer architecture ကိုအခြေခံထားတဲ့ Generative AI မော်ဒယ်တစ်ခုဖြစ်ပြီး *autoregressive transformer* ပါဝင်ပါတယ်။
#
# *Autoregressive transformer* ဆိုတာ မော်ဒယ်က စာသားဖော်ပြချက်ကနေ ပုံထုတ်လုပ်တဲ့နည်းလမ်းကို သတ်မှတ်ပေးတာပါ။ တစ်ပစ်ဆင့်ချင်းစီ ပုံထုတ်လုပ်ပြီး ထုတ်လုပ်ထားတဲ့ပစ်တွေကို နောက်ထပ်ပစ်ထုတ်လုပ်ဖို့ အသုံးပြုပါတယ်။ Neural network layer အများကြီးကို ဖြတ်သွားပြီး ပုံတစ်ပုံလုံး ပြီးစီးအောင်လုပ်ပါတယ်။
#
# ဒီနည်းလမ်းနဲ့ DALL-E က ပုံထုတ်လုပ်တဲ့ attributes, objects, characteristics စသဖြင့် ထိန်းချုပ်နိုင်ပါတယ်။ ဒါပေမယ့် DALL-E 2 နဲ့ 3 တွေက ထုတ်လုပ်တဲ့ပုံကို ပိုမိုထိန်းချုပ်နိုင်ပါတယ်။

# %% [markdown]
# ## သင့်ရဲ့ ပထမဆုံး ပုံထုတ်လုပ်ရေး အက်ပ်လီကေးရှင်း တည်ဆောက်ခြင်း
#
# ပုံထုတ်လုပ်ရေး အက်ပ်တစ်ခု တည်ဆောက်ဖို့ ဘာတွေလိုအပ်မလဲ? အောက်ပါ လိုက်ဘရရီတွေ လိုအပ်ပါတယ်-
#
# - **python-dotenv** ကို သုံးဖို့ အထူးအကြံပြုပါတယ်။ ဒီလိုက်ဘရရီက သင့်ရဲ့ လျှို့ဝှက်ချက်တွေကို *.env* ဖိုင်ထဲမှာ ကုဒ်နဲ့ခွဲထားနိုင်အောင် ကူညီပေးပါတယ်။
# - **openai** ကို သုံးပြီး OpenAI API နဲ့ ဆက်သွယ်ဖို့ လိုအပ်ပါတယ်။
# - **pillow** ကို Python မှာ ပုံတွေနဲ့ အလုပ်လုပ်ဖို့ သုံးပါတယ်။
# - **requests** ကို HTTP request တွေ ပို့ဖို့ ကူညီပေးပါတယ်။
#
# 1. *.env* ဆိုတဲ့ ဖိုင်တစ်ခုကို အောက်ပါအတိုင်း ဖန်တီးပါ-
#
#     ```text
#     OPENAI_API_KEY='<add your OpenAI key here>'
#     ```

# %% [markdown]
# 1. အထက်ပါလိုက်ဘရရီတွေကို *requirements.txt* ဆိုတဲ့ဖိုင်ထဲမှာ ဒီလိုစုစည်းပါ။
#
#     ```text
#     python-dotenv
#     openai
#     pillow
#     requests
#     ```
#
# 1. နောက်တစ်ဆင့်၊ virtual environment တစ်ခုဖန်တီးပြီး လိုအပ်တဲ့လိုက်ဘရရီတွေကို install လုပ်ပါ။

# %%
# create virtual env
! python3 -m venv venv
# activate environment
! source venv/bin/activate
# install libraries
# pip install -r requirements.txt, if using a requirements.txt file 
! pip install python-dotenv openai pillow requests

# %% [markdown]
# > [!NOTE]
# > Windows အတွက် သင့် virtual environment ကို ဖန်တီးပြီး အသုံးပြုရန် အောက်ပါ command များကို သုံးပါ။
#
#     ```bash
#     python3 -m venv venv
#     venv\Scripts\activate.bat
#     ```
#
# 1. *app.py* ဆိုတဲ့ ဖိုင်ထဲမှာ အောက်ပါ code ကို ထည့်ပါ။
#
#     ```python
#     import openai
#     import os
#     import requests
#     from PIL import Image
#     import dotenv
#
#     # import dotenv
#     dotenv.load_dotenv()
#
#     # Create OpenAI object
#     client = OpenAI()
#
#
#     try:
#         # Create an image by using the image generation API
#         generation_response = client.images.generate(
#             model="dall-e-3",
#             prompt='Bunny on horse, holding a lollipop, on a foggy meadow where it grows daffodils',    # Enter your prompt text here
#             size='1024x1024',
#             n=1
#         )
#         # Set the directory for the stored image
#         image_dir = os.path.join(os.curdir, 'images')
#
#         # If the directory doesn't exist, create it
#         if not os.path.isdir(image_dir):
#             os.mkdir(image_dir)
#
#         # Initialize the image path (note the filetype should be png)
#         image_path = os.path.join(image_dir, 'generated-image.png')
#
#         # Retrieve the generated image
#         print(generation_response)
#
#         image_url = generation_response.data[0].url # extract image URL from response
#         generated_image = requests.get(image_url).content  # download the image
#         with open(image_path, "wb") as image_file:
#             image_file.write(generated_image)
#
#         # Display the image in the default image viewer
#         image = Image.open(image_path)
#         image.show()
#
#     # catch exceptions
#     except client.error.InvalidRequestError as err:
#         print(err)
#
#     ```
#
# ဒီ code ကို ရှင်းပြပါမယ်-
#
# - အရင်ဆုံး လိုအပ်တဲ့ library တွေကို import လုပ်ပါတယ်။ OpenAI library, dotenv library, requests library နဲ့ Pillow library တို့ပါဝင်ပါတယ်။
#
#     ```python
#     import openai
#     import os
#     import requests
#     from PIL import Image
#     import dotenv
#     ```
#
# - ထို့နောက် object ကို ဖန်တီးပြီး သင့် ``.env`` ထဲက API key ကို ယူပါမယ်။
#
#     ```python
#         # Create OpenAI object
#         client = OpenAI()
#     ```
#
# - နောက်တစ်ခုက ပုံကို generate လုပ်တာပါ-
#
#     ```python
#     # Create an image by using the image generation API
#     generation_response = client.images.generate(
#         model="dall-e-3",
#         prompt='Bunny on horse, holding a lollipop, on a foggy meadow where it grows daffodils',    # Enter your prompt text here
#         size='1024x1024',
#         n=1
#     )
#     ```
#
#     အထက်ပါ code က generate လုပ်ထားတဲ့ ပုံရဲ့ URL ပါဝင်တဲ့ JSON object တစ်ခုကို ပြန်ပေးပါမယ်။ ဒီ URL ကို သုံးပြီး ပုံကို download လုပ်ပြီး ဖိုင်အဖြစ် သိမ်းနိုင်ပါတယ်။
#
# - နောက်ဆုံးမှာ ပုံကို ဖွင့်ပြီး ပုံကြည့်တဲ့ default viewer နဲ့ ပြပါမယ်-
#
#     ```python
#     image = Image.open(image_path)
#     image.show()
#     ```
#
# ### ပုံကို generate လုပ်တဲ့အကြောင်း ပိုမိုအသေးစိတ်
#
# ပုံကို generate လုပ်တဲ့ code ကို ပိုမိုအသေးစိတ်ကြည့်ကြမယ်-
#
# ```python
# generation_response = client.images.generate(
#         model="dall-e-3",
#         prompt='Bunny on horse, holding a lollipop, on a foggy meadow where it grows daffodils',    # Enter your prompt text here
#         size='1024x1024',
#         n=1
#     )
# ```
#
# - **prompt** ဆိုတာက ပုံကို generate လုပ်ဖို့ အသုံးပြုတဲ့ စာသား prompt ပါ။ ဒီနေရာမှာ "Bunny on horse, holding a lollipop, on a foggy meadow where it grows daffodils" ဆိုတဲ့ prompt ကို သုံးထားပါတယ်။
# - **size** ဆိုတာက generate လုပ်မယ့် ပုံရဲ့ အရွယ်အစားပါ။ ဒီနေရာမှာ 1024x1024 pixels အရွယ်အစားနဲ့ ပုံကို generate လုပ်ပါတယ်။
# - **n** ဆိုတာက generate လုပ်မယ့် ပုံအရေအတွက်ပါ။ ဒီနေရာမှာ ပုံ ၂ ပုံ generate လုပ်ပါတယ်။
#
# ပုံနဲ့ ပတ်သက်ပြီး လုပ်နိုင်တဲ့ အခြားအရာတွေကို နောက်အပိုင်းမှာ ဆက်လေ့လာပါမယ်။
#
# ## ပုံ generate လုပ်ခြင်းရဲ့ ထပ်မံနိုင်စွမ်းများ
#
# Python နဲ့ အနည်းငယ်သာ code ရိုက်ရုံနဲ့ ပုံတစ်ပုံ generate လုပ်နိုင်တာကို မြင်ခဲ့ပြီးပါပြီ။ ဒါပေမယ့် ပုံနဲ့ ပတ်သက်ပြီး လုပ်နိုင်တဲ့ အခြားအရာတွေရှိပါတယ်။
#
# သင်လုပ်နိုင်တာတွေကတော့-
#
# - **တည်းဖြတ်နိုင်ခြင်း**။ ရှိပြီးသားပုံတစ်ပုံ၊ mask တစ်ခုနဲ့ prompt တစ်ခုကို ပေးပြီး ပုံကို ပြင်နိုင်ပါတယ်။ ဥပမာ- ပုံတစ်ပုံထဲမှာ တစ်စိတ်တစ်ပိုင်းကို တိုးထည့်ချင်ရင် mask နဲ့ ပြောင်းလဲချင်တဲ့နေရာကို သတ်မှတ်ပြီး prompt နဲ့ ဘာလုပ်ချင်တယ်ဆိုတာ ရေးပေးရပါမယ်။ ဥပမာ- ကြွက်ပုံမှာ ဦးထုပ်တစ်လုံး ထပ်ထည့်ချင်ရင် ပုံ၊ mask (ပြောင်းချင်တဲ့နေရာ) နဲ့ ဘာထည့်ချင်တယ်ဆိုတဲ့ prompt ကို ပေးရပါမယ်။
#
#     ```python
#     response = openai.images.edit(
#       image=open("base_image.png", "rb"),
#       mask=open("mask.png", "rb"),
#       prompt="An image of a rabbit with a hat on its head.",
#       n=1,
#       size="1024x1024"
#     )
#     image_url = response.data[0].url
#     ```
#
#     မူလပုံမှာ ကြွက်ပဲပါမယ်၊ နောက်ဆုံးပုံမှာတော့ ကြွက်အပေါ် ဦးထုပ်ပါလာပါမယ်။
#
# - **ပုံအမျိုးမျိုးဖန်တီးခြင်း**။ ရှိပြီးသားပုံတစ်ပုံကို အမျိုးမျိုးပြောင်းလဲပေးဖို့ တောင်းနိုင်ပါတယ်။ Variation တစ်ခုဖန်တီးဖို့ ပုံတစ်ပုံနဲ့ prompt တစ်ခုကို ပေးပြီး အောက်ပါ code လို ရေးနိုင်ပါတယ်-
#
#     ```python
#     response = openai.images.create_variation(
#       image=open("bunny-lollipop.png", "rb"),
#       n=1,
#       size="1024x1024"
#     )
#     image_url = response.data[0].url
#     ```

# %% [markdown]
# ---
#
# **သတိပြုရန်**:
# ဤစာရွက်စာတမ်းကို AI ဘာသာပြန်ဝန်ဆောင်မှု [Co-op Translator](https://github.com/Azure/co-op-translator) ကို အသုံးပြု၍ ဘာသာပြန်ထားပါသည်။ ကျွန်ုပ်တို့သည် တိကျမှန်ကန်မှုအတွက် ကြိုးစားနေသော်လည်း၊ အလိုအလျောက် ဘာသာပြန်ချက်များတွင် အမှားများ သို့မဟုတ် မမှန်ကန်မှုများ ပါဝင်နိုင်သည်ကို သတိပြုပါ။ မူရင်းဘာသာဖြင့် ရေးသားထားသော စာရွက်စာတမ်းကိုသာ အာဏာတရားရှိသော ရင်းမြစ်အဖြစ် ယူဆသင့်ပါသည်။ အရေးကြီးသော အချက်အလက်များအတွက် လူ့ဘာသာပြန်ပညာရှင်များ၏ ဝန်ဆောင်မှုကို အသုံးပြုရန် အကြံပြုပါသည်။ ဤဘာသာပြန်ချက်ကို အသုံးပြုခြင်းမှ ဖြစ်ပေါ်လာနိုင်သော နားလည်မှုမှားခြင်းများ သို့မဟုတ် အနားလည်အမှားများအတွက် ကျွန်ုပ်တို့သည် တာဝန်ယူမည်မဟုတ်ပါ။
