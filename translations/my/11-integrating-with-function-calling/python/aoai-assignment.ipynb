# %% [markdown]
# ## နိဒါန်း
#
# ဒီသင်ခန်းစာမှာ အောက်ပါအကြောင်းအရာတွေကို ဖော်ပြပေးမှာပါ-
# - Function calling ဆိုတာဘာလဲ၊ အသုံးချမှုများ
# - Azure OpenAI ကိုသုံးပြီး Function call ကို ဘယ်လိုဖန်တီးရမလဲ
# - Application မှာ Function call ထည့်သွင်းအသုံးပြုနည်း
#
# ## သင်ယူရမည့်ရည်မှန်းချက်များ
#
# ဒီသင်ခန်းစာပြီးရင် သင်လုပ်နိုင်မှာနဲ့နားလည်မှာတွေက-
#
# - Function calling ကို အသုံးပြုရသည့်ရည်ရွယ်ချက်
# - Azure Open AI Service ကိုသုံးပြီး Function Call ချိန်ညှိခြင်း
# - သင့် Application ၏ အသုံးပြုမှုအတွက် ထိရောက်သော Function call များဒီဇိုင်းဆွဲနည်း

# %% [markdown]
# ## ဖန်ရှင်ခေါ်ဆိုမှုများကိုနားလည်ခြင်း
#
# ဤသင်ခန်းစာအတွက် ကျွန်ုပ်တို့သည် ကျောင်းသားများကို နည်းပညာသင်တန်းများရှာဖွေရန် ဆက်သွယ်မေးမြန်းနိုင်သော chatbot တစ်ခု အသုံးပြုခွင့်ပြုသော လုပ်ဆောင်ချက်တစ်ခု ဖန်တီးလိုပါသည်။ ကျွန်ုပ်တို့သည် သူတို့၏ ကျွမ်းကျင်မှုအဆင့်၊ လက်ရှိတာဝန်နှင့် နည်းပညာစိတ်ဝင်စားမှုအတိုင်း သင်တန်းများကို အကြံပြုမည်ဖြစ်သည်။
#
# ဤကို ပြီးမြောက်စေရန် အောက်တွင်ဖေါ်ပြသော ပေါင်းစပ်အသုံးပြုမှုများကို အသုံးပြုမည်။
#  - အသုံးပြုသူအတွက် စကားပြောအတွေ့အကြုံ တည်ဆောက်ရန် `Azure Open AI`
#  - အသုံးပြုသူ၏ မေးခွန်းအပေါ် အခြေခံ၍ သင်တန်းများ ရှာဖွေရန် `Microsoft Learn Catalog API`
#  - အသုံးပြုသူ၏ မေးခွန်းကို ယူ၍ API မေးမြန်းမှု ပြုလုပ်ရန် ဖန်ရှင်သို့ပို့ရန် `Function Calling`
#
# စတင်ရန် မိမိတို့ ဈေးတင် function calling ကို အသုံးပြုလိုသည့် အကြောင်းရင်းများကို ကြည့်ကြရအောင်။

# %% [markdown]
# ### Function Calling ဘာကြောင့်အသုံးပြုသလဲ
#
# ဒီသင်ခန်းစာကိုပြီးစီးထားရင်တော့ သင်ဟာကြီးမားတဲ့ဘာသာစကားမော်ဒယ်များ (LLMs) ကိုသုံးခြင်း၏အစွမ်းအထင်းကိုနားလည်နေလိမ့်မယ်။ တခြားဘက်မှာတော့ ၎င်းတို့၏ကန့်သတ်ချက်များကိုလည်းမြင်နိုင်ပါတယ်လို့ မျှော်လင့်ပါတယ်။
#
# Function Calling သည် Azure Open AI Service မှ ထုတ်ပေးသော လက္ခဏာတစ်ခုဖြစ်ပြီး နောက်ပါတဲ့ ကန့်သတ်ချက်များကိုကျော်လွှားရန်ဖြစ်သည် -
# 1) တိတိကျကျတုံ့ပြန်မှုပုံစံ
# 2) ဆက်စပ်ထားသောအက်ပလီကေးရှင်းမှ အချက်အလက်များကို စကားပြောအခြေအနေတွင် သုံးနိုင်မှု
#
# Function calling မရှိမီ၊ LLM မှ တုံ့ပြန်ချက်များမှာ အစိတ်အပိုင်းမတိကျပြီး မညီမျှခြင်းများရှိခဲ့သည်။ ဖန်တီးသူများသည် တုံ့ပြန်ချက်ရဲတစ်မျိုးမျိုးကို ကိုင်တွယ်နိုင်ရန် ဘာသာရပ်ခက်ခဲသော အတည်ပြုကုဒ်များရေးဆွဲရန်လိုအပ်ခဲ့သည်။
#
# အသုံးပြုသူများသည် "စတော့(့)့လ်ဟိုးမ်တွင် လက်ရှိမိုးလေဝသဘယ်လောက်ရှိလဲ?" ဆိုတဲ့ မေးခွန်းများကို မရရှိနိုင်ခဲ့ကြပါဘူး။ အကြောင်းမှာ မော်ဒယ်များဟာ လေ့ကျင့်ထားတဲ့အပေါ်အချိန်ကန့်သတ်ချက်ရှိတာပါ။
#
# ဒီပြဿနာကိုရှင်းပြပုံရအောင် အောက်ပါဥပမာကိုကြည့်ကြရအောင် -
#
# ကျောင်းသားဒေတာ ဘေ့စ်ကို ဖန်တီးရန်နှင့် သင့်တော်သောသင်တန်းများကို အကြံပြုရန်လိုချင်တယ်ဆိုပါစို့။ အောက်မှာ ကျောင်းသားနှစ်ဦး၊ သူတို့၏အချက်အလက်များရဲ့ အရာတူညီချက်များပါဝင်တဲ့ ဖော်ပြချက်နှစ်ခုရှိပါတယ်။

# %%
student_1_description="Emily Johnson is a sophomore majoring in computer science at Duke University. She has a 3.7 GPA. Emily is an active member of the university's Chess Club and Debate Team. She hopes to pursue a career in software engineering after graduating."
 
student_2_description = "Michael Lee is a sophomore majoring in computer science at Stanford University. He has a 3.8 GPA. Michael is known for his programming skills and is an active member of the university's Robotics Club. He hopes to pursue a career in artificial intelligence after finishing his studies."

# %% [markdown]
# ဒီကို ဒေတာအား ပေါ်ဆိုင်မှု ပြုလုပ်ရန် LLM သို့ ပို့လိုပါသည်။ နောက်တစ်ကြိမ်တွင် ဤကို ကျွန်ုပ်တို့၏ အက်ပ်လီကေးရှင်းတွင် API သို့ ပို့ရန် သို့မဟုတ် ဒေတာဘေ့စ်တွင် သိမ်းဆည်းရန် အသုံးပြုနိုင်ပါသည်။
#
# ကျွန်ုပ်တို့ LLM ကို စိတ်ဝင်စားသော အချက်အလက်အကြောင်း ဘာကို ညွှန်ကြားရန် သဘောတူညီသော prompt နှစ်ခု တူညီစွာ ဖန်တီးကြပါစို့။

# %% [markdown]
# ကျွန်ုပ်တို့၏ထုတ်ကုန်အတွက် အရေးကြီးသော အစိတ်အပိုင်းများကို စိတ်ကြိုက်ခွဲခြမ်းစိတ်ဖြာရန် ဒီအချက်များကို LLM သို့ ပို့လိုသည်။ ထို့ကြောင့် LLM ကိုညွှန်ကြားရန် တူညီသော prompt နှစ်ခုကို ဖန်တီးနိုင်ပါမည်။

# %%
prompt1 = f'''
Please extract the following information from the given text and return it as a JSON object:

name
major
school
grades
club

This is the body of text to extract the information from:
{student_1_description}
'''


prompt2 = f'''
Please extract the following information from the given text and return it as a JSON object:

name
major
school
grades
club

This is the body of text to extract the information from:
{student_2_description}
'''

# %% [markdown]
# ဤဘာသာပြန်ဆိုချက်နှစ်ခုကို ဖန်တီးပြီးနောက် `client.responses.create` ကိုအသုံးပြုကာ LLM သို့ ပို့ပါမည်။ ကျွန်ုပ်တို့သည် prompt ကို `input` အဆင့်တွင်သိမ်းဆည်းပြီး role ကို `user` သတ်မှတ်သည်။ ၎င်းမှာ chatbot သို့ အသုံးပြုသူမှစာပို့သည့်မက်ဆေ့ခ်ျကို ကိုက်ညီစေဖို့ဖြစ်သည်။

# %%
import os
import json
from openai import OpenAI
from dotenv import load_dotenv
load_dotenv()

# The OpenAI client points at the Azure OpenAI (Microsoft Foundry) /openai/v1/ endpoint
client = OpenAI(
  api_key=os.environ['AZURE_OPENAI_API_KEY'],
  base_url=f"{os.environ['AZURE_OPENAI_ENDPOINT'].rstrip('/')}/openai/v1/",
  )

deployment=os.environ['AZURE_OPENAI_DEPLOYMENT']
# Out:
# Running cells with '/opt/homebrew/bin/python3' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ယခုအခါ ကျွန်ုပ်တို့သည် LLM သို့ စကားဝိုင်းနှစ်ခုစလုံးကို ပို့လို့ရပြီး၊ ရရှိသော တုံ့ပြန်မှုကို စစ်ဆေးနိုင်ပါပြီ။

# %%
openai_response1 = client.responses.create(
 model=deployment,    
 input = [{'role': 'user', 'content': prompt1}],
 store=False,
)
openai_response1.output_text

# %%
openai_response2 = client.responses.create(
 model=deployment,    
 input = [{'role': 'user', 'content': prompt2}],
 store=False,
)
openai_response2.output_text

# %%
# Loading the response as a JSON object
json_response1 = json.loads(openai_response1.output_text)
json_response1

# %%
# Loading the response as a JSON object
json_response2 = json.loads(openai_response2.output_text)
json_response2

# %% [markdown]
# တူညီသော prompt များနှင့် ဖော်ပြချက်များသည် ဆင်တူဖြစ်သော်လည်း `Grades` ပိုင်ဆိုင်မှု၏ ဖော်မတ်များကြားကွဲပြားမှုများ ရရှိနိုင်သည်။
#
# အထက်ပါ cell ကို မကြာခဏပြန်ရိုက်မည်ဆိုပါက ဖော်မတ်သည် `3.7` သို့မဟုတ် `3.7 GPA` ဖြစ်နိုင်သည်။
#
# ၎င်းမှာ LLM သည် ရေးသားထားသော prompt နေရာမှ စာရင်းပုံစံမရှိသော ဒေတာကို ယူပြီး ထိုမူမတည်သော ဒေတာကိုပြန်လည်ပေးပို့ခြင်းကြောင့် ဖြစ်ပါသည်။ ဒေတာသိုလှောင်ခြင်း သို့မဟုတ် အသုံးပြုရာတွင် မည်သည်ကိုမျှ မျှော်လင့်နိုင်ရန် ဖော်မတ်စနစ်ရှိရန် လိုအပ်ပါသည်။
#
# function calling ကိုအသုံးပြုခြင်းဖြင့် ဖော်မတ်စနစ်ရှိသော ဒေတာပြန်လည်ရရှိရေး သေချာစေနိုင်သည်။ function calling အသုံးပြုသည့်အခါ LLM သည် function မဖြစ်စေ မခေါ်ရန်။ တကယ် function မည်သည့်အားဖြင့် မပြေးခိုင်းပါ။ ၎င်း၏ဖြေကြားချက်များအတွက် လိုက်နာသင့်သော ဖွဲ့စည်းမှုပုံစံဖြစ်စေရန် ဖန်တီးသည်။ ထိုဖွဲ့စည်းမှုပုံစံဖြေကြားချက်များကို အသုံးပြု၍ application များ၌ မည်သူ့ကို function ပြေးရန်ကို သိရှိ တာဖြစ်သည်။

# %% [markdown]
# ![လုပ်ဆောင်ချက်ခေါ်ယူမှု လည်ပတ်မှုဇယား](../../../../translated_images/my/Function-Flow.083875364af4f4bb.webp)

# %% [markdown]
# နှင့် အဆိုပါ function မှ ပြန်လာသည့် အရာကို ယူပြီး အဲဒီကို LLM ထံ ပြန်ပို့နိုင်ပါတယ်။ LLM သည် သဘာဝဘာသာဖြင့် တုံ့ပြန်ကာ အသုံးပြုသူ၏ မေးခွန်းကို ဖြေကြားပါလိမ့်မည်။

# %% [markdown]
# ### Function calls အသုံးပြုခြင်းအတွက် အကောင်အထည်ဖော်မှုများ
#
# **ပြင်ပကိရိယာများကို ခေါ်ရန်**
# Chatbot များသည် အသုံးပြုသူများရဲ့ မေးခွန်းများအတွက် အဖြေများပေးရာတွင် အလွန်စွမ်းဆောင်နိုင်သည်။ Function calling ကို အသုံးပြုခြင်းဖြင့် chatbot များသည် အသုံးပြုသူများရဲ့ သတင်းဆောင်များကို အသုံးပြု၍ အချို့သောတာဝန်များကို ပြီးစီးနိုင်သည်။ ဥပမာ- ကျောင်းသားတစ်ဦးသည် chatbot ကို "ဒီဘာသာရပ်နဲ့ ပို၍အကူအညီလိုတယ်ဆိုပြီး ဆရာအတွက် အီးမေးလ်ပို့ပေးပါ" ဟုပြောနိုင်သည်။ သို့ဖြစ်လျှင် `send_email(to: string, body: string)` ဆိုတဲ့ function ကို ခေါ်နိုင်သည်။
#
#
# **API သို့မဟုတ် ဒေတာဘေ့(စ်)မေးခွန်းများ ဖန်တီးခြင်း**
# အသုံးပြုသူများသည် သဘာဝဘာသာစကားအသုံးပြုပြီး အချက်အလက်များကို ရှာဖွေနိုင်ပြီး၊ ၎င်းသည် ဖော်မတ်ထားသော မေးခွန်း သို့မဟုတ် API မှတဆင့် တင်ပြပါသည်။ ဥပမာ- ဆရာတစ်ဦးသည် "နောက်ဆုံးတာဝန်ကိုပြီးမြောက်ခဲ့သော ကျောင်းသားများ ဘယ်သူတွေလဲ" ဟုပြောဆိုပြီး `get_completed(student_name: string, assignment: int, current_status: string)` ဆိုတဲ့ function ကို ခေါ်နိုင်သည်။
#
#
# **ဖွဲ့စည်းတည်ဆောက်ထားသော ဒေတာဖန်တီးခြင်း**
# အသုံးပြုသူများသည် စာပိုဒ်တစ်ပိုင်း သို့မဟုတ် CSV မှ ထူးခြားသော အချက်အလက်များကို LLM အသုံးပြု၍ ထုတ်ယူနိုင်သည်။ ဥပမာ- ကျောင်းသားတစ်ဦးသည် ငြိမ်းချမ်းရေးစာချုပ်များအား ဖော်ပြထားသော Wikipedia ဆောင်းပါးကို AI flash cards အသစ်များဖန်တီးရန် ပြောင်းနိုင်သည်။ ၎င်းကိစ္စကို `get_important_facts(agreement_name: string, date_signed: string, parties_involved: list)` ဆိုသော function ဖြင့် ပြုလုပ်နိုင်သည်။

# %% [markdown]
# ## 2. သင့်ပထမဆုံး Function Call ကို ဖန်တီးခြင်း
#
# Function call တစ်ခုဖန်တီးခြင်းဖြစ်စဉ်တွင် အခြေခံ အဆင့် ၃ ချက်ပါဝင်သည်-
# ၁။ သင့် function များစာရင်းနှင့် အသုံးပြုသူမက်ဆေ့ခ်ျဖြင့် Chat Completions API ကို ခေါ်ဆိုခြင်း
# ၂။ ဖန်တီးထားသော function သို့မဟုတ် API ကို တည်ထောင်ရန် အရေးယူရန် မော်ဒယ်၏ တုံ့ပြန်မှုကို ဖတ်ရှုခြင်း
# ၃။ သင့် function မှ ပြန်လာသော တုံ့ပြန်မှုဖြင့် အသုံးပြုသူအား တုံ့ပြန်ချက်တစ်ခု ဖန်တီးရန် Chat Completions API ကို ထပ်မံခေါ်ဆိုခြင်း

# %% [markdown]
# ![လုပ်ဆောင်ချက်ခေါ်ဆိုမှု၏ခုန်လှုပ်မှု](../../../../translated_images/my/LLM-Flow.3285ed8caf4796d7.webp)

# %% [markdown]
# ### ဖန်ပါတ်ခေါ်မှု၏ အစိတ်အပိုင်းများ
#
# #### အသုံးပြုသူ၏ ထည့်သွင်းချက်
#
# ပထမဆုံးခြေလှမ်းမှာ အသုံးပြုသူဆီမှစာတိုများ ဖန်တီးခြင်း ဖြစ်သည်။ ၎င်းကို စာသားထည့်သွင်းမှုတန်ဖိုးကို တန်ဆာခံယူ၍ ချိန်ညှိနိုင်သလို ဒီမှာတန်ဖိုးတစ်ခု သတ်မှတ်ပေးလို့ရပါသည်။ ၎င်းသည် Chat Completions API နှင့် ပထမဆုံးအကြိမ်အဖြစ် လုပ်ကိုင်ခြင်းဖြစ်ပါက `role` နှင့် `content` ကို သတ်မှတ်ရန် လိုအပ်ပါသည်။
#
# `role` သည် `system` (စည်းကမ်းများ ဖန်တီးခြင်း), `assistant` (မော်ဒယ်), သို့မဟုတ် `user` (အဆုံးသတ် အသုံးပြုသူ) တို့ ဖြစ်နိုင်သည်။ ဖန်ပါတ်ခေါ်မှုအတွက် `user` ဟု သတ်မှတ်ပြီး မေးခွန်းနမူနာတစ်ခု ပေးသွင်းမည်ဖြစ်သည်။

# %%
messages= [ {"role": "user", "content": "Find me a good course for a beginner student to learn Azure."} ]

# %% [markdown]
# ### လုပ်ဆောင်ချက်များ ဖန်တီးခြင်း။
#
# နောက်တစ်ခု အနေဖြင့် သတ်မှတ်ချက်လည်းဖြစ်ပြီး လုပ်ဆောင်ချက်တစ်ခုနှင့် ၎င်းလုပ်ဆောင်ချက်၏ ပါရာမီတာများကို သတ်မှတ်ပါမည်။ ဒီမှာ `search_courses` ဆိုတဲ့ လုပ်ဆောင်ချက်တစ်ခုကို သုံးမယ့်အတွက် သုံးစွဲနိုင်သည့် လုပ်ဆောင်ချက်များ အများကြီး ဖန်တီးနိုင်ပါတယ်။
#
# **အရေးကြီးချက်** : လုပ်ဆောင်ချက်များကို LLM ကိုပေးပို့သော တင်စားချက်စာသားတွင် ထည့်သွင်းပြီး သင်ထည့်သွင်းနိုင်သော ရရှိနိုင်သော token အရေအတွက်အတွင်း ပါဝင်သည်။

# %%
# The Responses API uses a flat tool format: name/description/parameters at the top level
functions = [
   {
      "type":"function",
      "name":"search_courses",
      "description":"Retrieves courses from the search index based on the parameters provided",
      "parameters":{
         "type":"object",
         "properties":{
            "role":{
               "type":"string",
               "description":"The role of the learner (i.e. developer, data scientist, student, etc.)"
            },
            "product":{
               "type":"string",
               "description":"The product that the lesson is covering (i.e. Azure, Power BI, etc.)"
            },
            "level":{
               "type":"string",
               "description":"The level of experience the learner has prior to taking the course (i.e. beginner, intermediate, advanced)"
            }
         },
         "required":[
            "role"
         ]
      }
   }
]

# %% [markdown]
# **အဓိပ္ပာယ်ဖော်ခြင်းများ**
#
# `name` - လူကြိုက်ဆုံးဖိတ်ခေါ်လိုသော ဖန်ခေါ်ခြင်း၏နာမည်။
#
# `description` - ဤသည်မှာ ဖန်ခေါ်မှုသည် မည်သို့ အလုပ်လုပ်သည်ကို ဖော်ပြချက်ဖြစ်သည်။ ဤနေရာ၌ တိကျရှင်းလင်းမှုရှိရမည်။
#
# `parameters` - မော်ဒယ်မှ တုံ့ပြန်မှုတွင် ထုတ်ပေးလိုသော တန်ဖိုးများနှင့် ဖော်မက်အမျိုးအစားစာရင်း
#
#
# `type` - ကိုင်တွယ်မည့် ပိုင်ဆိုင်မှုများ၏ ဒေတာအမျိုးအစား
#
# `properties` - မော်ဒယ်သည် တုံ့ပြန်ရာတွင် အသုံးပြုမည့် သတ်မှတ်တန်ဖိုးများစာရင်း
#
#
# `name` - မော်ဒယ်၏ ဖော်မက်လုပ်ထားသော တုံ့ပြန်မှုတွင် အသုံးပြုမည့် ပိုင်ဆိုင်မှုအမည်
#
# `type` - ဤပိုင်ဆိုင်မှု၏ ဒေတာအမျိုးအစား
#
# `description` - သတ်မှတ်ပိုင်ဆိုင်မှု၏ ဖော်ပြချက်
#
#
# **ရွေးချယ်စရာ**
#
# `required` - ဖန်ခေါ်မှု ပြီးစီးရန် လိုအပ်သော ပိုင်ဆိုင်မှု

# %% [markdown]
# ### အလုပ်လုပ်မှုခေါ်ချက်လုပ်ခြင်း
# အလုပ်လုပ်မှုတစ်ခုကို သတ်မှတ်ပြီးနောက်၊ အခုမှာ ကျွန်ုပ်တို့သည် Chat Completion API ကို ခေါ်သည့်အခါ ထိုအလုပ်လုပ်မှုကို ထည့်သွင်းရန်လိုအပ်သည်။ ကျွန်ုပ်တို့သည် `functions` ကို request ထဲသို့ ထည့်ခြင်းဖြင့် ဒီအလုပ်ကို ပြုလုပ်သည်။ ဒီအခြေအနေမှာ `functions=functions` ဖြစ်ပါသည်။
#
# ထို့အပြင် `function_call` ကို `auto` အဖြစ်သတ်မှတ်ရန်ရွေးချယ်စရာလည်းရှိသည်။ ၎င်းသည် ကျွန်ုပ်တို့ကိုယ်တိုင် သတ်မှတ်ခြင်းမပြုဘဲ အသုံးပြုသူ၏ မက်ဆေ့ချ်အရ LLM က မည်သည့် function ကိုခေါ်သင့်သည်ကို ဆုံးဖြတ်စေသည်ဟု အဓိပ္ပာယ်ရသည်။

# %%
response = client.responses.create(model=deployment, 
                                        input=messages,
                                        tools=functions, 
                                        tool_choice="auto",
                                        store=False) 

print(response.output)

# %% [markdown]
# ယခုအခါ တုံ့ပြန်မှုကိုကြည့်ပြီး ၎င်းအတိုင်း ဖော်ညွှန်းပုံကို ကြည့်ကြရအောင်။
#
# {
#   "role": "assistant",
#   "function_call": {
#     "name": "search_courses",
#     "arguments": "{\n  \"role\": \"student\",\n  \"product\": \"Azure\",\n  \"level\": \"beginner\"\n}"
#   }
# }
#
# သင်မြင်နိုင်တာက function နာမည်ကိုခေါ်ပြီး၊ အသုံးပြုသူ၏မက်ဆေ့ချ်မှ LLM သည် function ၏ arguments ကို ဖြေရှင်းဖို့သင့်တော်တဲ့ဒေတာကိုရှာတွေ့ခဲ့တာဖြစ်ပါတယ်။

# %% [markdown]
# ## ၃။ အက်ပလီကေးရှင်းထဲတွင် ဖန်စ်ရှင်ခေါ်ဆိုမှုများ ပေါင်းစပ်ခြင်း။
#
#
# LLM မှ ဖန်းတီးထားသော ပြန်လည်ဖြေကြားချက်ကို စမ်းသပ်ပြီးပါက၊ ယခုအချိန်တွင် ဤကို အက်ပလီကေးရှင်းတစ်ခုထဲသို့ ပေါင်းစပ်နိုင်ပါပြီ။
#
# ### လှိုင်းကို စီမံခန့်ခွဲခြင်း
#
# ဤကို ကျွန်ုပ်တို့၏ အက်ပလီကေးရှင်းထဲသို့ ပေါင်းစပ်ရန်အတွက် အောက်ပါအဆင့်များကို လုပ်ဆောင်ကြရအောင်။
#
# ပထမဦးဆုံး၊ Open AI ဝန်ဆောင်မှုများကို ခေါ်ယူ၍ မက်ဆေ့ခ်ျကို `response_message` ဟု အမည်ပေးထားသော မတူညီသောအချက်အလက်တွင် သိမ်းဆည်းလိုက်ပါစို့။

# %%
# Extract the function call items from the response output
tool_calls = [item for item in response.output if item.type == "function_call"]

# %% [markdown]
# ယခုတွင် သင်ယူမည့် Microsoft Learn API ကို ခေါ်ယူ၍ ကိုးစီများစာရင်းကို ရယူမည့် function ကို သတ်မှတ်ပါမည်-

# %%
import requests

def search_courses(role, product, level):
    url = "https://learn.microsoft.com/api/catalog/"
    params = {
        "role": role,
        "product": product,
        "level": level
    }
    response = requests.get(url, params=params)
    modules = response.json()["modules"]
    results = []
    for module in modules[:5]:
        title = module["title"]
        url = module["url"]
        results.append({"title": title, "url": url})
    return str(results)

# %% [markdown]
# အကောင်းဆုံး လေ့ကျင့်မှုအဖြစ် မော်ဒယ်သည် function တစ်ခုကို ခေါ်လိုပါက ကြည့်ရှုမည်ဖြစ်သည်။ ၎င်းထုတ်ပြန်ပြီးနောက် ရနိုင်သော function များထဲမှ တစ်ခုကို ဖန်တီးပြီး ခေါ်လိုသော function နှင့် ကိုက်ညီစေရမည်။
# ပြီးလျှင် function ၏ arguments များကို ယူပြီး LLM မှလာသော arguments များနှင့် ကိုက်ညီစေရမည်။
#
# နောက်ဆုံးတွင် function ခေါ်ဆိုချက် message နှင့် `search_courses` message မှ ပြန်လာသော တန်ဖိုးများကို ပေါင်းထည့်ပေးမည်ဖြစ်သည်။ ၎င်းအတိုင်း LLM သည် သဘာဝဘာသာဖြင့် အသုံးပြုသူအား ဖြေကြားနိုင်ရန် လိုအပ်သော အချက်အလက်များအားလုံး ရရှိပါသည်။
# အသုံးပြုသူအား သဘာဝ ဘာသာဖြင့် တုံ့ပြန်နိုင်မည်။

# %%
# Check if the model wants to call a function
if tool_calls:
    tool_call = tool_calls[0]
    print("Recommended Function call:")
    print(tool_call.name)
    print()

    # Call the function. 
    function_name = tool_call.name

    available_functions = {
            "search_courses": search_courses,
    }
    function_to_call = available_functions[function_name] 

    function_args = json.loads(tool_call.arguments)
    function_response = function_to_call(**function_args)

    print("Output of function call:")
    print(function_response)
    print(type(function_response))


    # Add the model's function call item(s) and our function result to the conversation.
    # The Responses API represents tool results as `function_call_output` items.
    messages.extend(response.output)  # adding the model's function_call item(s)
    messages.append( # adding function response to messages
        {
            "type": "function_call_output",
            "call_id": tool_call.call_id,
            "output": function_response,
        }
    )

# %% [markdown]
# ယခုမှာ ကျွန်ုပ်တို့သည် အပ်ဒိတ်လုပ်ပြီးသော သတင်းสารကို LLM သို့ ပို့မည်ဖြစ်ပြီး ထိုကဲ့သို့နည်းဖြင့် API JSON ဖော်မတ်ဖြင့်ဖြစ်သော ပြန်လည်ဖြေကြားချက်မဟုတ်ဘဲ သဘာဝဘာသာစကားဖြင့် ပြန်လည်ဖြေကြားချက်တောင်းခံနိုင်ပါသည်။

# %%
print("Messages in next request:")
print(messages)
print()

second_response = client.responses.create(
    input=messages,
    model=deployment,
    tools=functions,
    tool_choice="auto",
    store=False,
        )  # get a new response from the model where it can see the function response


print(second_response.output_text)

# %% [markdown]
# ## ကုဒ် စိန်ခေါ်မှု
#
# ကောင်းစွာလုပ်ဆောင်ထားပါသည်! Azure Open AI Function Calling ကို စဉ်ဆက်ပြီး သင်ယူနိင်ရန်အတွက် သင်တန်းတစ်ခုကိုတည်ဆောက်နိုင်သည်။ https://learn.microsoft.com/training/support/catalog-api-developer-reference?WT.mc_id=academic-105485-koreyst
#  - သင်ယူသူများကို သင်တန်းများပိုမို ရှာဖွေရာတွင် ကူညီနိုင်မည့် function ၏ ပိုမိုသော parameters များ။ အသုံးပြုနိုင်သော API parameters များကို ဒီနေရာမှာ ရှာဖွေနိုင်သည်။
#  - သင်ယူသူ၏ မိခင်ဘာသာစကားကိုပါ ထည့်သွင်းသုံးစွဲမည့် နောက်ထပ် function call တစ်ခုကို ဖန်တီးရန်
#  - function call သို့မဟုတ် API call မှ သင့်တော်သော သင်တန်း မပြန်လိုက်သောအခါ ဂျာနယ်ကိစ္စများကို ကိုင်တွယ်ရန် error handling ဖန်တီးရန်

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **ပြောကြားချက်**
# ဤစာတမ်းကို AI ဘာသာပြန်ဝန်ဆောင်မှု [Co-op Translator](https://github.com/Azure/co-op-translator) အသုံးပြု၍ ဘာသာပြန်ထားပါသည်။ ကျွန်ုပ်တို့သည် တိကျမှန်ကန်မှုအတွက် ကြိုးပမ်းနေသော်လည်း၊ စက်ကိရိယာဘာသာပြန်ခြင်းများတွင် အမှားများ သို့မဟုတ် မှားယွင်းချက်များ ပါဝင်နိုင်ကြောင်း သတိပြုပါရန် လိုအပ်ပါသည်။ မူလစာတမ်းကို မူရင်းဘာသာဖြင့်သာ ယုံကြည်စိတ်ချရသော အချက်အလက်အဖြစ် သတ်မှတ်သင့်သည်။ အရေးကြီးသည့် သတင်းအချက်အလက်များအတွက် ပရော်ဖက်ရှင်နယ် လူသားဘာသာပြန်သူဝန်ဆောင်မှုကို အကြံပြုပါသည်။ ဤဘာသာပြန်ချက်ကို အသုံးပြုခြင်းမှ ဖြစ်ပေါ်လာသော နားလည်မှုကွာခြားမှုများ သို့မဟုတ် မမှန်ကန်သော အသုံးပြုမှုများအတွက် ကျွန်ုပ်တို့ တာဝန်မခံပါ။
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
