# %% [markdown]
# # Kurkite tekstų generavimo programas
#
# Iki šiol šioje mokymo programoje matėte, kad yra pagrindinės sąvokos, tokios kaip užklausos ir net visa disciplina, vadinama „užklausų inžinerija“. Daugelis įrankių, su kuriais galite bendrauti, pavyzdžiui, ChatGPT, Office 365, Microsoft Power Platform ir kiti, remiasi užklausomis, kad pasiektumėte norimą rezultatą.
#
# Kad galėtumėte pridėti tokį patyrimą prie programėlės, turite suprasti tokias sąvokas kaip užklausos, atsakymai ir pasirinkti biblioteką darbui. Būtent to ir išmoksite šiame skyriuje.
#
# ## Įvadas
#
# Šiame skyriuje jūs:
#
# - Sužinosite apie openai biblioteką ir jos pagrindines sąvokas.
# - Sukursite tekstų generavimo programėlę naudodami openai.
# - Suprasite, kaip naudoti tokias sąvokas kaip užklausa, temperatūra ir žetonai, kuriant tekstų generavimo programėlę.
#
# ## Mokymosi tikslai
#
# Pabaigoje šios pamokos galėsite:
#
# - Paaiškinti, kas yra tekstų generavimo programėlė.
# - Sukurti tekstų generavimo programėlę naudojant openai.
# - Sukonfigūruoti programėlę naudoti daugiau arba mažiau žetonų ir taip pat keisti temperatūrą, kad gautumėte įvairų rezultatą.
#
# ## Kas yra tekstų generavimo programėlė?
#
# Paprastai, kai kuriate programėlę, ji turi tam tikrą sąsają, pavyzdžiui, tokią:
#
# - Komandų pagrindu. Konsolinės programėlės yra tokios, kuriose įvedate komandą ir ji atlieka užduotį. Pavyzdžiui, `git` yra komandų pagrindu veikianti programa.
# - Vartotojo sąsaja (UI). Kai kurios programėlės turi grafines vartotojo sąsajas (GUI), kuriose spustelėjate mygtukus, įvedate tekstą, pasirenkate parinktis ir kt.
#
# ### Konsolinės ir vartotojo sąsajos programėlės yra ribotos
#
# Palyginkite su komandine programa, kurioje įvedate komandą:
#
# - **Ji yra ribota**. Negalite įvesti bet kokios komandos, tik tos, kurias palaiko programa.
# - **Kalbiškai specifinė**. Kai kurios programos palaiko daug kalbų, tačiau pagal nutylėjimą jos sukurtos konkrečiai kalbai, nors galite pridėti papildomų kalbų palaikymą.
#
# ### Tekstų generavimo programėlių privalumai
#
# Tai kaip skiriasi tekstų generavimo programėlė?
#
# Tekstų generavimo programėlėje turite daugiau lankstumo, nesate apriboti tam tikrų komandų rinkiniu ar konkrečia įvesties kalba. Vietoje to galite naudoti natūralią kalbą bendrauti su programa. Kitas privalumas yra tas, kad jūs jau bendraujate su duomenų šaltiniu, kuris buvo apmokytas milžinišku informacijos korpusu, tuo tarpu tradicinės programos gali būti ribotos pagal duomenų bazės turinį.
#
# ### Ką galima sukurti su tekstų generavimo programėle?
#
# Galite sukurti daugybę dalykų. Pavyzdžiui:
#
# - **Pokalbių robotą**. Pokalbių robotas, atsakantis į klausimus apie temas, pvz., jūsų įmonę ir jos produktus, galėtų būti tinkamas pasirinkimas.
# - **Pagalbą**. Dideli kalbos modeliai (LLM) puikiai apibendrina tekstą, gauna įžvalgas iš teksto, gamina tekstą, pvz., gyvenimo aprašymus ir kt.
# - **Kodo asistentą**. Priklausomai nuo naudojamo kalbos modelio, galite sukurti kodo asistentą, kuris padeda rašyti kodą. Pavyzdžiui, galite naudotis tokiais produktais kaip GitHub Copilot ir ChatGPT, kurie padeda rašyti kodą.
#
# ## Kaip pradėti?
#
# Jums reikia rasti būdą integruotis su dideliu kalbos modeliu (LLM), o tai paprastai reiškia šiuos du būdus:
#
# - Naudoti API. Čia jums reikia sukurti žiniatinklio užklausas su savo užklausa ir gauti sugeneruotą tekstą atgal.
# - Naudoti biblioteką. Bibliotekos supaprastina API kvietimus ir padaro juos lengviau naudojamus.
#
# ## Bibliotekos / SDK
#
# Yra keletas gerai žinomų bibliotekų darbui su LLM, pavyzdžiui:
#
# - **openai**, ši biblioteka leidžia lengvai prisijungti prie jūsų modelio ir siųsti užklausas.
#
# Yra ir aukštesnio lygio bibliotekų, pavyzdžiui:
#
# - **Langchain**. Langchain yra gerai žinoma ir palaiko Python.
# - **Semantic Kernel**. Semantic Kernel yra Microsoft biblioteka, palaikanti C#, Python ir Java kalbas.
#
# ## Pirmoji programa naudojant Microsoft Foundry Models Playground ir Azure AI Inference SDK
#
# Pažiūrėkime, kaip galime sukurti mūsų pirmą programėlę, kokių bibliotekų reikia, kiek tai užtruks ir panašiai.
#
# > **Pastaba:** GitHub Models bus nutrauktas 2026 metų liepos pabaigoje. Žemiau pateikti žingsniai atnaujinti naudojant [Microsoft Foundry Models](https://ai.azure.com/catalog/models?WT.mc_id=academic-105485-koreyst), kuris siūlo tokią pačią patirtį „ištirti, išbandyti žaidimų aikštelėje ir iškviesti API raktu“, kaip siūlė GitHub Models, dabar tiesiogiai talpinamą Microsoft Foundry portale. Norite dirbti visiškai neprisijungę? Žiūrėkite [Foundry Local](https://foundrylocal.ai?WT.mc_id=academic-105485-koreyst) ir paleiskite modelius savo įrenginyje be debesijos prenumeratos.
#
# ### Kas yra Microsoft Foundry Models?
#
# Sveiki atvykę į [Microsoft Foundry Models](https://ai.azure.com/catalog/models?WT.mc_id=academic-105485-koreyst)! Foundry modelių katalogas suteikia vieną vietą ištirti ir išbandyti šimtus dirbtinio intelekto modelių – iš OpenAI, Meta, Mistral, Cohere, Microsoft ir kt. – talpinamų Azure, visi pasiekiami per nemokamą žaidimų aikštelę ir, kartą įdiegiant, prieinami per jūsų mėgstamą kodo IDE.
#
# ### Ko reikia?
#
# * Microsoft paskyra ir [Azure prenumerata](https://aka.ms/azure/free?WT.mc_id=academic-105485-koreyst) (nemokama paskyra tinka)
# * [Microsoft Foundry projektas](https://ai.azure.com?WT.mc_id=academic-105485-koreyst)
#
# Pradėkime!
#
# ### Raskite modelį ir jį išbandykite
#
# Eikite į [Microsoft Foundry Models katalogą](https://ai.azure.com/catalog/models?WT.mc_id=academic-105485-koreyst)
#
# ![Microsoft Foundry Models katalogas rodantis modelių kortelių sąrašą, tokius kaip Cohere, Meta llama, Mistral ir GPT modeliai](../../../../translated_images/lt/GithubModelsMainScreen.62aed2c56e2bee64.webp)
#
# Pasirinkite modelį – pavyzdžiui, OpenAI GPT-4o mini
#
# Čia matysite modelio kortelę. Galite:
# * Skaityti informaciją apie modelį skiltyse readme, benchmarkai ir licencijos
# * Įdiegti modelį į savo Foundry projektą
# * Įdiegus, bendrauti su modeliu tiesiogiai žaidimų aikštelėje
#
# ![Microsoft Foundry Models GPT-4o modelio kortelė](../../../../translated_images/lt/GithubModels-modelcard.c65ce4538e7bee92.webp)
#
# Atidarykite **Playground** (žaidimų aikštelę), kad bendrautumėte su modeliu, pridėtumėte sistemos užklausas ir keistumėte parametrų detales – taip pat gaukite visą reikiamą kodą, kad tai galėtumėte paleisti bet kur, naudojant Python, JavaScript, C# ar REST.
#
# ![Microsoft Foundry Models žaidimų aikštelės patirtis su rodomu kodu ir kalbomis](../../../../translated_images/lt/GithubModels-plagroundcode.da2dea486f1ad5e0.webp)
#
#
# ### Naudokime modelį savo IDE
#
# Yra dvi galimybės:
# 1. **GitHub Codespaces** – sklandi integracija su Codespaces
# 2. **VS Code (arba bet kuri mėgstama IDE)** – jums reikės **pabaigos taško** ir **API rakto** iš jūsų Foundry projekto
#
#
# Bet kuriuo atveju šias reikšmes rasite savo Foundry projekto **Apžvalgos** puslapyje.
#
# ![Pradžios ekranas, rodantis kaip pasiekti Codespaces arba naudoti asmeninį prieigos raktą, kad nustatytumėte savo IDE](../../../../translated_images/lt/GithubModels-getstarted.4821f6f3182fc666.webp)
#
# ### 1. Codespaces
#
# * Sukurkite naują codespacą (arba naudokite esamą)
# * VS Code atsidarys naršyklėje su keliomis pavyzdinėmis užrašų knygelėmis skirtingomis kalbomis, kurias galite išbandyti
# * Paleiskite pavyzdinį failą ```./githubmodels-app.py```.
#
# > Pastaba: Codespaces išsaugokite savo Foundry pabaigos tašką ir raktą kaip Codespaces paslaptis, kad nereikėtų jų nustatinėti lokaliai.
#
# **Dabar tęskite užduotį žemiau skiltyje „Generate Text“**
#
# ### 2. VS Code (arba bet kuri mėgstama IDE)
#
# Iš savo Microsoft Foundry projekto turite visą reikalingą informaciją, kad galėtumėte paleisti IDE. Šis pavyzdys parodys VS Code.
#
# * Įdiekite pokalbių modelį, pvz., `gpt-4o-mini`, savo Foundry projekte
# * Nukopijuokite projekto **pabaigos tašką** ir **API raktą** iš Apžvalgos puslapio
# * Sukurkite aplinkos kintamuosius jiems saugoti: `AZURE_INFERENCE_ENDPOINT` ir `AZURE_INFERENCE_CREDENTIAL` – pavyzdžiai bash, powershell ir Windows komandų eilutėje
# * Įdiekite priklausomybes: ```pip install azure-ai-inference```
# * Nukopijuokite pagrindinį pavyzdinį kodą į .py failą
# * Eikite į vietą, kur išsaugojote kodą, ir paleiskite failą: ```python filename.py```
#
# Nepamirškite, naudodami Azure AI Inference SDK galite lengvai eksperimentuoti su skirtingais modeliais keisdami kodo eilutėje `model_name` reikšmę.
#
# Šie modeliai yra prieinami Microsoft Foundry Models kataloge:
#
# * OpenAI: gpt-4o, gpt-4o-mini, gpt-4.1, gpt-4.1-mini, o3-mini, text-embedding-3-large, text-embedding-3-small
# * Meta: Meta-Llama-3.1-405B-Instruct, Meta-Llama-3.1-70B-Instruct, Meta-Llama-3.1-8B-Instruct, Llama-3.2-11B-Vision-Instruct, Llama-3.2-90B-Vision-Instruct, Llama-4-Scout-17B-16E-Instruct
# * Mistral AI: Mistral-large-2411, Mistral-small-2503, Codestral-2501, Ministral-3B
# * Microsoft: Phi-4, Phi-4-mini-instruct, Phi-4-multimodal-instruct, Phi-4-reasoning
# * Cohere: Cohere-command-r-plus-08-2024, Cohere-embed-v3-multilingual, Cohere-embed-v3-english
# * DeepSeek: DeepSeek-V3, DeepSeek-R1
#
#
#
# **Dabar tęskite užduotį žemiau skiltyje „Generate Text“**
#
# ## Teksto generavimas su ChatCompletions
#
# Tekstą generuoti galite naudodami klasę `ChatCompletionsClient`.
# Faile `samples/python/azure_ai_inference/basic.py`, atsako kodo dalyje atnaujinkite vartotojo rolę, pakeisdami parametrą content taip:
#
# ```python
#
# response = client.complete(
#     messages=[
#         {
#             "role": "system",
#             "content": "You are a helpful assistant.",
#         },
#         {
#             "role": "user",
#             "content": "Complete the following: Once upon a time there was a",
#         },
#     ],
#     model=model_name,
#     # Pasirenkami parametrai
#     temperature=1.,
#     max_tokens=1000,
#     top_p=1.
# )
#
# ```
#
# Paleiskite atnaujintą failą ir pažiūrėkite rezultatą

# %% [markdown]
# ## Skirtingų tipų užklausos, skirtingiems dalykams
#
# Dabar jau matėte, kaip generuoti tekstą naudojant užklausą. Jūs netgi turite programą, kuri veikia ir kurią galite keisti bei modifikuoti, kad sukurtumėte skirtingų tipų tekstą.
#
# Užklausos gali būti naudojamos įvairiems užduotims. Pavyzdžiui:
#
# - **Sugeneruoti tam tikro tipo tekstą**. Pavyzdžiui, galite sugeneruoti eilėraštį, viktorinos klausimus ir pan.
# - **Ieškoti informacijos**. Galite naudoti užklausas ieškant informacijos, pavyzdžiui, tokios kaip „Ką reiškia CORS interneto kūrime?“.
# - **Generuoti kodą**. Galite naudoti užklausas kodui generuoti, pavyzdžiui, rašant reguliarią išraišką elektroninio pašto validavimui ar kodėl gi ne sugeneruoti visą programą, pavyzdžiui, žiniatinklio programėlę?
#
# ## Užduotis: receptų generatorius
#
# Įsivaizduokite, kad namuose turite ingredientų ir norite ką nors pagaminti. Tam jums reikalingas receptas. Vienas būdas rasti receptus – naudotis paieškos sistema, o galite pasinaudoti ir LLM.
#
# Galite parašyti užklausą taip:
#
# > „Pateikite 5 receptus patiekalui su šiais ingredientais: vištiena, bulvės ir morkos. Kiekvienam receptui išvardinkite visus naudotus ingredientus.“
#
# Remiantis aukščiau pateikta užklausa, galite gauti panašų atsakymą:
#
# ```output
# 1. Roasted Chicken and Vegetables:
# Ingredients:
# - 4 chicken thighs
# - 2 potatoes, cut into cubes
# - 2 carrots, cut into cubes
# - 2 tablespoons olive oil
# - 2 cloves garlic, minced
# - 1 teaspoon dried thyme
# - 1 teaspoon dried oregano
# - Salt and pepper, to taste
#
# 2. Chicken and Potato Stew:
# Ingredients:
# - 2 tablespoons olive oil
# - 1 onion, diced
# - 2 cloves garlic, minced
# - 2 chicken breasts, cut into cubes
# - 2 potatoes, cut into cubes
# - 2 carrots, cut into cubes
# - 1 teaspoon dried oregano
# - 1 teaspoon dried thyme
# - 1 cup chicken broth
# - Salt and pepper, to taste
#
# 3. Chicken and Potato Bake:
# Ingredients:
# - 2 tablespoons olive oil
# - 2 chicken breasts, cut into cubes
# - 2 potatoes, cut into cubes
# - 2 carrots, cut into cubes
# - 1 onion, diced
# - 2 cloves garlic, minced
# - 1 teaspoon dried oregano
# - 1 teaspoon dried thyme
# - 1 cup chicken broth
# - Salt and pepper, to taste
#
# 4. Chicken and Potato Soup:
# Ingredients:
# - 2 tablespoons olive oil
# - 1 onion, diced
# - 2 cloves garlic, minced
# - 2 chicken breasts, cut into cubes
# - 2 potatoes, cut into cubes
# - 2 carrots, cut into cubes
# - 1 teaspoon dried oregano
# - 1 teaspoon dried thyme
# - 4 cups chicken broth
# - Salt and pepper, to taste
#
# 5. Chicken and Potato Hash:
# Ingredients:
# - 2 tablespoons olive oil
# - 2 chicken breasts, cut into cubes
# - 2 potatoes, cut into cubes
# - 2 carrots, cut into cubes
# - 1 onion, diced
# - 2 cloves garlic, minced
# - 1 teaspoon dried oregano
# ```
#
# Šis rezultatas puikus, aš žinau, ką gaminti. Šiuo metu naudingos galėtų būti tokios patobulinimai:
#
# - Išfiltruoti ingredientus, kurių nemėgstu arba kuriems esu alergiškas.
# - Paruošti pirkinių sąrašą tuo atveju, jei namuose neturiu visų ingredientų.
#
# Tokiems atvejams pridėkime papildomą užklausą:
#
# > „Prašau pašalinti receptus, kuriuose yra česnako, nes esu alergiškas, ir pakeisti jį kažkuo kitu. Taip pat, prašau paruošti pirkinių sąrašą šiems receptams, atsižvelgiant į tai, kad namuose jau turiu vištienos, bulvių ir morkų.“
#
# Dabar turite naują rezultatą, būtent:
#
# ```output
# 1. Roasted Chicken and Vegetables:
# Ingredients:
# - 4 chicken thighs
# - 2 potatoes, cut into cubes
# - 2 carrots, cut into cubes
# - 2 tablespoons olive oil
# - 1 teaspoon dried thyme
# - 1 teaspoon dried oregano
# - Salt and pepper, to taste
#
# 2. Chicken and Potato Stew:
# Ingredients:
# - 2 tablespoons olive oil
# - 1 onion, diced
# - 2 chicken breasts, cut into cubes
# - 2 potatoes, cut into cubes
# - 2 carrots, cut into cubes
# - 1 teaspoon dried oregano
# - 1 teaspoon dried thyme
# - 1 cup chicken broth
# - Salt and pepper, to taste
#
# 3. Chicken and Potato Bake:
# Ingredients:
# - 2 tablespoons olive oil
# - 2 chicken breasts, cut into cubes
# - 2 potatoes, cut into cubes
# - 2 carrots, cut into cubes
# - 1 onion, diced
# - 1 teaspoon dried oregano
# - 1 teaspoon dried thyme
# - 1 cup chicken broth
# - Salt and pepper, to taste
#
# 4. Chicken and Potato Soup:
# Ingredients:
# - 2 tablespoons olive oil
# - 1 onion, diced
# - 2 chicken breasts, cut into cubes
# - 2 potatoes, cut into cubes
# - 2 carrots, cut into cubes
# - 1 teaspoon dried oregano
# - 1 teaspoon dried thyme
# - 4 cups chicken broth
# - Salt and pepper, to taste
#
# 5. Chicken and Potato Hash:
# Ingredients:
# - 2 tablespoons olive oil
# - 2 chicken breasts, cut into cubes
# - 2 potatoes, cut into cubes
# - 2 carrots, cut into cubes
# - 1 onion, diced
# - 1 teaspoon dried oregano
#
# Shopping List:
# - Olive oil
# - Onion
# - Thyme
# - Oregano
# - Salt
# - Pepper
# ```
#
# Tai jūsų penki receptai, kuriuose nėra česnako, ir taip pat turite pirkinių sąrašą, atsižvelgiant į tai, ką jau turite namuose.

# %% [markdown]
# ## Užduotis - sukurkite receptų generatorių
#
# Dabar, kai pavaizdavome scenarijų, parašykime kodą, atitinkantį parodytą scenarijų. Tam atlikite šiuos veiksmus:
#
# 1. Panaudokite esamą failą kaip pradinį tašką
# 1. Sukurkite kintamąjį `prompt` ir pakeiskite pavyzdinį kodą taip, kaip nurodyta žemiau:

# %%
import os
from azure.ai.inference import ChatCompletionsClient
from azure.ai.inference.models import SystemMessage, UserMessage
from azure.core.credentials import AzureKeyCredential

# Get these from your Microsoft Foundry project's "Overview" page
token = os.environ["AZURE_INFERENCE_CREDENTIAL"]
endpoint = os.environ["AZURE_INFERENCE_ENDPOINT"]

model_name = "gpt-4o-mini"

client = ChatCompletionsClient(
    endpoint=endpoint,
    credential=AzureKeyCredential(token),
)

prompt = "Show me 5 recipes for a dish with the following ingredients: chicken, potatoes, and carrots. Per recipe, list all the ingredients used"

response = client.complete(
    messages=[
        {
            "role": "system",
            "content": "You are a helpful assistant.",
        },
        {
            "role": "user",
            "content": prompt,
        },
    ],
    model=model_name,
    # Optional parameters
    temperature=1.,
    max_tokens=1000,
    top_p=1.    
)

print(response.choices[0].message.content)

# %% [markdown]
# Jei dabar paleisite kodą, turėtumėte matyti panašų išvestį:
#
# ```output
# ### Recipe 1: Classic Chicken Stew
# #### Ingredients:
# - 2 lbs chicken thighs or drumsticks, skinless
# - 4 cups chicken broth
# - 4 medium potatoes, peeled and diced
# - 4 large carrots, peeled and sliced
# - 1 large onion, chopped
# - 2 cloves garlic, minced
# - 2 celery stalks, sliced
# - 1 tsp dried thyme
# - 1 tsp dried rosemary
# - Salt and pepper to taste
# - 2 tbsp olive oil
# - 2 tbsp flour (optional, for thickening)
#
# ### Recipe 2: Chicken and Vegetable Roast
# #### Ingredients:
# - 4 chicken breasts or thighs
# - 4 medium potatoes, cut into wedges
# - 4 large carrots, cut into sticks
# - 1 large onion, cut into wedges
# - 3 cloves garlic, minced
# - 1/4 cup olive oil
# - 1 tsp paprika
# - 1 tsp dried oregano
# - Salt and pepper to taste
# - Juice of 1 lemon
# - Fresh parsley, chopped (for garnish)
# (continued ...)
# ```
#
# > PASTABA, jūsų LLM yra nedeterministinis, todėl kiekvieną kartą paleidus programą galite gauti skirtingus rezultatus.
#
# Puiku, pažiūrėkime, kaip galime patobulinti dalykus. Norėdami pagerinti situaciją, norime įsitikinti, kad kodas yra lankstus, kad ingredientus ir receptų skaičių būtų galima patobulinti ir pakeisti.

# %% [markdown]
# 1. Pakeiskime kodą taip:

# %%
import os
from azure.ai.inference import ChatCompletionsClient
from azure.ai.inference.models import SystemMessage, UserMessage
from azure.core.credentials import AzureKeyCredential

# Get these from your Microsoft Foundry project's "Overview" page
token = os.environ["AZURE_INFERENCE_CREDENTIAL"]
endpoint = os.environ["AZURE_INFERENCE_ENDPOINT"]

model_name = "gpt-4o-mini"

client = ChatCompletionsClient(
    endpoint=endpoint,
    credential=AzureKeyCredential(token),
)

no_recipes = input("No of recipes (for example, 5): ")

ingredients = input("List of ingredients (for example, chicken, potatoes, and carrots): ")

# interpolate the number of recipes into the prompt an ingredients
prompt = f"Show me {no_recipes} recipes for a dish with the following ingredients: {ingredients}. Per recipe, list all the ingredients used"

response = client.complete(
    messages=[
        {
            "role": "system",
            "content": "You are a helpful assistant.",
        },
        {
            "role": "user",
            "content": prompt,
        },
    ],
    model=model_name,
    # Optional parameters
    temperature=1.,
    max_tokens=1000,
    top_p=1.    
)

print(response.choices[0].message.content)

# %% [markdown]
# Kodo išbandymas galėtų atrodyti štai taip:
#
# ```output
# No of recipes (for example, 5): 2
# List of ingredients (for example, chicken, potatoes, and carrots): milk, strawberries
#
# Sure! Here are two recipes featuring milk and strawberries:
#
# ### Recipe 1: Strawberry Milkshake
#
# #### Ingredients:
# - 1 cup milk
# - 1 cup strawberries, hulled and sliced
# - 2 tablespoons sugar (optional, to taste)
# - 1/2 teaspoon vanilla extract
# - 5-6 ice cubes
#
# #### Instructions:
# 1. Combine the milk, strawberries, sugar (if using), and vanilla extract in a blender.
# 2. Blend on high until smooth and creamy.
# 3. Add the ice cubes and blend again until the ice is fully crushed and the milkshake is frothy.
# 4. Pour into a glass and serve immediately.
#
# ### Recipe 2: Strawberry Panna Cotta
#
# #### Ingredients:
# - 1 cup milk
# - 1 cup strawberries, hulled and pureed
# - 1/4 cup sugar
# - 1 teaspoon vanilla extract
# - 1 envelope unflavored gelatin (about 2 1/2 teaspoons)
# - 2 tablespoons cold water
# - 1 cup heavy cream
#
# #### Instructions:
# 1. Sprinkle the gelatin over the cold water in a small bowl and let it stand for about 5-10 minutes to soften.
# 2. In a saucepan, combine the milk, heavy cream, and sugar. Cook over medium heat, stirring frequently until the sugar is dissolved and the mixture begins to simmer. Do not let it boil.
# 3. Remove the saucepan from the heat and stir in the softened gelatin until completely dissolved.
# 4. Stir in the vanilla extract and allow the mixture to cool slightly.
# 5. Divide the mixture evenly into serving cups or molds and refrigerate for at least 4 hours or until set.
# 6. To prepare the strawberry puree, blend the strawberries until smooth.
# 7. Once the panna cotta is set, spoon the strawberry puree over the top of each panna cotta.
# 8. Serve chilled.
#
# Enjoy these delightful recipes!
# ```
#
# ### Pagerinkite pridėdami filtrą ir pirkinių sąrašą
#
# Dabar turime veikiančią programėlę, galinčią generuoti receptus, kuri yra lanksti, nes priklauso nuo naudotojo įvesties — tiek receptų skaičiaus, tiek naudojamų ingredientų.
#
# Norėdami ją dar pagerinti, norime pridėti šiuos dalykus:
#
# - **Filtruoti ingredientus**. Norime galėti filtruoti ingredientus, kurių nemėgstame arba esame jiems alergiški. Norėdami įgyvendinti šią funkciją, galime redaguoti esamą užklausą ir pabaigoje pridėti filtro sąlygą taip:
#
#     ```python
#     filter = input("Filter (for example, vegetarian, vegan, or gluten-free: ")
#
#     prompt = f"Show me {no_recipes} recipes for a dish with the following ingredients: {ingredients}. Per recipe, list all the ingredients used, no {filter}"
#     ```
#
#     Viršuje prie užklausos pabaigos pridedame `{filter}` ir taip pat gauname filtro reikšmę iš naudotojo.
#
#     Pavyzdinė programos vykdymo įvestis dabar galėtų atrodyti taip:
#
#     ```output
#     No of recipes (for example, 5): 2
#     List of ingredients (for example, chicken, potatoes, and carrots): onion, milk
#     Filter (for example, vegetarian, vegan, or gluten-free: no milk
#     Certainly! Here are two recipes using onion but omitting milk:
#
#     ### Recipe 1: Caramelized Onions
#
#     #### Ingredients:
#     - 4 large onions, thinly sliced
#     - 2 tablespoons olive oil
#     - 1 tablespoon butter
#     - 1 teaspoon salt
#     - 1 teaspoon sugar (optional)
#     - 1 tablespoon balsamic vinegar (optional)
#
#     #### Instructions:
#     1. Heat the olive oil and butter in a large skillet over medium heat until the butter is melted.
#     2. Add the onions and stir to coat them with the oil and butter mixture.
#     3. Add salt (and sugar if using) to the onions.
#     4. Cook the onions, stirring occasionally, for about 45 minutes to an hour until they are golden brown and caramelized.
#     5. If using, add balsamic vinegar during the last 5 minutes of cooking.
#     6. Remove from heat and serve as a topping for burgers, steak, or as a side dish.
#
#     ### Recipe 2: French Onion Soup
#
#     #### Ingredients:
#     - 4 large onions, thinly sliced
#     - 3 tablespoons unsalted butter
#     - 2 cloves garlic, minced
#     - 1 teaspoon sugar
#     - 1 teaspoon salt
#     - 1/4 cup dry white wine (optional)
#     - 4 cups beef broth
#     - 4 cups chicken broth
#     - 1 bay leaf
#     - 1 teaspoon fresh thyme, chopped (or 1/2 teaspoon dried thyme)
#     - 1 baguette, sliced
#     - 2 cups Gruyère cheese, grated
#
#     #### Instructions:
#     1. Melt the butter in a large pot over medium heat.
#     2. Add the onions, garlic, sugar, and salt, and cook, stirring frequently, until the onions are deeply caramelized (about 30-35 minutes).
#     3. If using, add the white wine and cook until it evaporates, about 3-5 minutes.
#     4. Add the beef and chicken broths, bay leaf, and thyme. Bring to a simmer and cook for another 30 minutes. Remove the bay leaf.
#     5. Preheat the oven to 400°F (200°C).
#     6. Place the baguette slices on a baking sheet and toast them in the preheated oven until golden brown, about 5 minutes.
#     7. Ladle the soup into oven-safe bowls and place a slice of toasted baguette on top of each bowl.
#     8. Sprinkle the grated Gruyère cheese generously over the baguette slices.
#     9. Place the bowls under the broiler until the cheese is melted and bubbly, about 3-5 minutes.
#     10. Serve hot.
#
#     Enjoy your delicious onion dishes!
#     ```
#
# - **Sukurti pirkinių sąrašą**. Norime sukurti pirkinių sąrašą, atsižvelgdami į tai, ką jau turime namuose.
#
#     Šiai funkcijai galėtume pabandyti viską išspręsti vienoje užklausoje arba galėtume padalinti į dvi užklausas. Pabandykime antrąjį būdą. Čia siūlome pridėti papildomą užklausą, tačiau tam, kad tai veiktų, turime pridėti pirmosios užklausos rezultatą kaip kontekstą antrajai užklausai.
#
#     Suraskite kodo dalį, kur spaudžiamas pirmosios užklausos rezultatas, ir po juo pridėkite šį kodą:
#
#     ```python
#     old_prompt_result = response.choices[0].message.content
#     prompt = "Produce a shopping list for the generated recipes and please don't include ingredients that I already have."
#
#     new_prompt = f"{old_prompt_result} {prompt}"
#
#     response = client.complete(
#         messages=[
#             {
#                 "role": "system",
#                 "content": "You are a helpful assistant.",
#             },
#             {
#                 "role": "user",
#                 "content": new_prompt,
#             },
#         ],
#         model=model_name,
#         # Neprivalomi parametrai
#         temperature=1.,
#         max_tokens=1200,
#         top_p=1.
#     )
#
#     # atspausdinti atsakymą
#     print("Shopping list:")
#     print(response.choices[0].message.content)
#     ```
#
#
#     Atkreipkite dėmesį į tai:
#
#     - Mes kuriame naują užklausą, pridėdami pirmosios užklausos rezultatą prie naujos užklausos:
#
#         ```python
#         new_prompt = f"{old_prompt_result} {prompt}"
#         messages = [{"role": "user", "content": new_prompt}]
#         ```
#
#     - Darome naują užklausą, bet taip pat atsižvelgiame į pirmojoje užklausoje prašytų tokenų skaičių, todėl šį kartą `max_tokens` nustatome 1200. **Žodis apie tokenų ilgį**. Turėtume apgalvoti, kiek tokenų reikia sugeneruoti norimą tekstą. Tokenai kainuoja pinigus, todėl kur įmanoma, turėtume stengtis taupyti tokenų skaičių. Pavyzdžiui, ar galime užklausą suformuluoti taip, kad naudotume mažiau tokenų?
#
#         ```python
#         response = client.complete(
#             messages=[
#                 {
#                     "role": "system",
#                     "content": "You are a helpful assistant.",
#                 },
#                 {
#                     "role": "user",
#                     "content": new_prompt,
#                 },
#             ],
#             model=model_name,
#             # Pasirenkami parametrai
#             temperature=1.,
#             max_tokens=1200,
#             top_p=1.
#         )
#         ```
#
#         Išbandžius šį kodą, gauname tokį rezultatą:
#
#         ```output
#         No of recipes (for example, 5): 1
#         List of ingredients (for example, chicken, potatoes, and carrots): strawberry, milk
#         Filter (for example, vegetarian, vegan, or gluten-free): nuts
#
#         Certainly! Here's a simple and delicious recipe for a strawberry milkshake using strawberry and milk as primary ingredients:
#
#         ### Strawberry Milkshake
#
#         #### Ingredients:
#         - 1 cup fresh strawberries, hulled
#         - 1 cup cold milk
#         - 1 tablespoon honey or sugar (optional, to taste)
#         - 1/2 teaspoon vanilla extract (optional)
#         - 3-4 ice cubes
#
#         #### Instructions:
#         1. Wash and hull the strawberries, then slice them in half.
#         2. In a blender, combine the strawberries, cold milk, honey or sugar (if using), vanilla extract (if using), and ice cubes.
#         3. Blend until smooth and frothy.
#         4. Pour the milkshake into a glass.
#         5. Serve immediately and enjoy your refreshing strawberry milkshake!
#
#         This recipe is nut-free and makes for a delightful and quick treat!
#         Shopping list:
#         Sure! Here’s the shopping list for the Strawberry Milkshake recipe based on the ingredients provided. Please adjust based on what you already have at home:
#
#         ### Shopping List:
#         - Fresh strawberries (1 cup)
#         - Milk (1 cup)
#
#         Optional:
#         - Honey or sugar (1 tablespoon)
#         - Vanilla extract (1/2 teaspoon)
#         - Ice cubes (3-4)
#
#         Feel free to omit the optional ingredients if you prefer or if you already have them on hand. Enjoy your delicious strawberry milkshake!
#         ```
#
# - **Eksperimentavimas su temperature**. Temperatūra yra kontekstas, kurio iki šiol nepaminėjome, bet jis svarbus tam, kaip mūsų programa veikia. Kuo aukštesnė temperatūros reikšmė, tuo atsitiktinesnis išvestis. Atvirkščiai, kuo žemesnė temperatūra, tuo labiau prognozuojama išvestis. Pagalvokite, ar norite turėti įvairiavimą savo išvestyje, ar ne.
#
#    Norėdami pakeisti temperatūrą, galite naudoti `temperature` parametrą. Pavyzdžiui, jeigu norite naudoti 0.5 temperatūrą, tai darytumėte taip:
#
# ```python
#     response = client.complete(
#         messages=[
#             {
#                 "role": "system",
#                 "content": "You are a helpful assistant.",
#             },
#             {
#                 "role": "user",
#                 "content": new_prompt,
#             },
#         ],
#         model=model_name,
#         # Neprivalomi parametrai
#         temperature=0.5,
#         max_tokens=1200,
#         top_p=1.
#     )
# ```
#
#    > Pastaba, kuo arčiau 1.0, tuo įvairesnė išvestis.
#
#
# ## Priskyrimas
#
# Šiam priskyrimui galite pasirinkti, ką sukurti.
#
# Štai keletas pasiūlymų:
#
# - Tobulinkite receptų generatorės programėlę. Eksperimentuokite su temperatūros reikšmėmis ir užklausomis, pažiūrėkite, ką galite sukurti.
# - Sukurkite „studijų draugą“. Ši programėlė turėtų gebėti atsakyti į klausimus apie tam tikrą temą, pvz., Python; galėtumėte turėti užklausas, pavyzdžiui, „Kas yra tam tikra tema Python?“ arba užklausą „Parodyk man kodą tam tikrai temai“ ir pan.
# - Istorijos botą, kuris prikelia istoriją gyvybei; paprašykite boto vaidinti tam tikrą istorinę asmenybę ir užduokite klausimus apie jos gyvenimą ir laikus.
#
# ## Sprendimas
#
# ### Studijų draugas
#
# - „Tu esi Python kalbos ekspertas
#
#     Pasiūlyk pradedančiųjų pamoką Python šiuo formatu:
#
#     Format:
#     - sąvokos:
#     - pamokos trumpas paaiškinimas:
#     - užduotis su kodu ir sprendimais“
#
# Aukščiau pateikta pradinė užklausa, pažiūrėkite, kaip ją galite naudoti ir pakeisti pagal savo skonį.
#
# ### Istorijos botas
#
# Štai kelios užklausos, kurias galite naudoti:
#
# - „Tu esi Abas Linkolnas, papasakok man apie save 3 sakiniais ir atsakyk taip, kaip tai darytų Lincolnas su jo gramatika ir žodynu“
# - „Tu esi Abas Linkolnas, atsakyk taip, kaip tai darytų Lincolnas su jo gramatika ir žodynu:
#
#    Papasakok apie savo didžiausius pasiekimus, 300 žodžių:“
#
# ## Žinių patikrinimas
#
# Ką veikia temperatūros sąvoka?
#
# 1. Ji reguliuoja, kiek atsitiktinė bus išvestis.
# 1. Ji reguliuoja, kiek didelis bus atsakymas.
# 1. Ji reguliuoja, kiek tokenų bus panaudota.
#
# A: 1
#
# Koks yra geras būdas saugoti slaptus duomenis, pvz., API raktus?
#
# 1. Kode.
# 1. Faile.
# 1. Aplinkos kintamuosiuose.
#
# A: 3, nes aplinkos kintamieji nėra saugomi kode ir gali būti užkrauti iš kodo.

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Atsakomybės apribojimas**:
# Šis dokumentas buvo išverstas naudojant dirbtinio intelekto vertimo paslaugą [Co-op Translator](https://github.com/Azure/co-op-translator). Nors siekiame tikslumo, prašome atkreipti dėmesį, kad automatiniai vertimai gali turėti klaidų ar netikslumų. Originalus dokumentas jo gimtąja kalba laikomas autoritetingu šaltiniu. Svarbiai informacijai rekomenduojama naudoti profesionalų žmogiškąjį vertimą. Mes neatsakome už jokius nesusipratimus ar neteisingą interpretaciją, kilusią naudojantis šiuo vertimu.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
