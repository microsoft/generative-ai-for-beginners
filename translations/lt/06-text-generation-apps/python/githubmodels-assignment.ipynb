# %% [markdown]
# # Kurkite teksto generavimo programas
#
# Iki šiol matėte šiame mokymo plane, kad yra pagrindinės sąvokos, tokios kaip užklausos (prompts), ir net visa disciplina, vadinama „užklausų inžinerija“. Daugelis įrankių, su kuriais galite bendrauti, pvz., ChatGPT, Office 365, Microsoft Power Platform ir kt., remiasi užklausomis, kad pasiektumėte norimą rezultatą.
#
# Kad galėtumėte pridėti tokią patirtį prie programos, turite suprasti sąvokas, tokias kaip užklausos, atsakymai (completions), ir pasirinkti biblioteka darbui su jomis. Būtent to išmoksite šiame skyriuje.
#
# ## Įvadas
#
# Šiame skyriuje jūs:
#
# - Sužinosite apie openai biblioteką ir jos pagrindines sąvokas.
# - Sukursite teksto generavimo programą naudodami openai.
# - Suprasite, kaip naudoti tokius konceptus kaip užklausa, temperatūra ir tokenai kuriant teksto generavimo programą.
#
# ## Mokymosi tikslai
#
# Pamokos pabaigoje jūs sugebėsite:
#
# - Paaiškinti, kas yra teksto generavimo programa.
# - Sukurti teksto generavimo programą naudojant openai.
# - Konfigūruoti programą naudoti daugiau ar mažiau tokenų bei keisti temperatūrą, kad gautumėte įvairų rezultatą.
#
# ## Kas yra teksto generavimo programa?
#
# Įprastai kuriant programą ji turi tam tikrą sąsają, pavyzdžiui:
#
# - Komandų pagrindu. Konsolinės programos yra tipinės programos, kuriose įvedate komandą ir ji atlieka užduotį. Pavyzdžiui, `git` yra komandų pagrindu veikianti programa.
# - Vartotojo sąsaja (UI). Kai kurios programos turi grafines vartotojo sąsajas (GUI), kur spustelėjate mygtukus, įvedate tekstą, pasirenkate parinktis ir pan.
#
# ### Konsolės ir UI programos yra ribotos
#
# Palyginkite tai su komandine programa, kurioje įvedate komandą:
#
# - **Ji yra ribota**. Negalite tiesiog įvesti bet kokios komandos, tik tas, kurias programa palaiko.
# - **Kalbai specifinė**. Kai kurios programos palaiko daug kalbų, tačiau pagal numatytąją reikšmę programa kuriama konkrečiai kalbai, nors galite pridėti ir daugiau kalbų palaikymo.
#
# ### Teksto generavimo programų privalumai
#
# Taigi kuo skiriasi teksto generavimo programa?
#
# Teksto generavimo programoje turite daugiau lankstumo, nesate apriboti komandomis ar konkrečia įvesties kalba. Vietoj to, galite naudoti natūralią kalbą, kad bendrautumėte su programa. Kitas privalumas yra tas, kad jūs jau bendraujate su duomenų šaltiniu, kuris buvo apmokytas dideliu informacijos korpusu, kai tradicinė programa gali būti ribota tuo, kas yra duomenų bazėje.
#
# ### Ką galiu sukurti su teksto generavimo programa?
#
# Galite sukurti daugybę dalykų. Pavyzdžiui:
#
# - **Pokalbių robotą**. Pokalbių robotas, atsakantis į klausimus apie temas, pvz., jūsų įmone ir jos produktus, būtų puikus pasirinkimas.
# - **Pagalbininką**. Dideli kalbos modeliai (LLM) puikiai tinka tekstų santraukų kūrimui, įžvalgoms iš tekstų gavimui, tokio turinio kaip gyvenimo aprašymai kūrimui ir pan.
# - **Kodo asistentą**. Priklausomai nuo kalbos modelio, kurį naudositės, galite sukurti kodo asistentą, kuris padės rašyti kodą. Pavyzdžiui, galite naudoti produktus kaip GitHub Copilot bei ChatGPT, kad padėtų rašyti kodą.
#
# ## Kaip pradėti?
#
# Reikia rasti būdą integruotis su LLM, kuris dažniausiai apima šiuos du būdus:
#
# - Naudoti API. Čia sudarote interneto užklausas su savo užklausa ir gaunate sugeneruotą tekstą atgal.
# - Naudoti biblioteką. Bibliotekos padeda apjungti API kvietimus ir palengvina jų naudojimą.
#
# ## Bibliotekos/SDK
#
# Yra kelios gerai žinomos bibliotekos darbui su LLM, pvz.:
#
# - **openai**, ši biblioteka palengvina prisijungimą prie modelio ir užklausų siuntimą.
#
# Yra ir bibliotekų, veikiančių aukštesniame lygyje, pvz.:
#
# - **Langchain**. Langchain yra gerai žinoma ir palaiko Python.
# - **Semantic Kernel**. Semantic Kernel yra Microsoft biblioteka, palaikanti kalbas C#, Python ir Java.
#
# ## Pirmoji programa naudojant Microsoft Foundry Models Playground ir Azure AI Inference SDK
#
# Pažiūrėkime, kaip galime sukurti savo pirmąją programą, kokių bibliotekų reikia, kiek jų reikia ir panašiai.
#
# > **Pastaba:** GitHub Models bus nutraukta 2026 metų liepos pabaigoje. Žemiau pateikti veiksmai atnaujinti naudoti [Microsoft Foundry Models](https://ai.azure.com/catalog/models?WT.mc_id=academic-105485-koreyst), kurie siūlo tą patį „ištirti, išbandyti žaidimų aikštelėje ir kvietimą su API raktu“ patirtį, kaip ir GitHub Models, dabar tiesiogiai talpinamą Microsoft Foundry portale. Norite dirbti visiškai neprisijungę? Peržiūrėkite [Foundry Local](https://foundrylocal.ai?WT.mc_id=academic-105485-koreyst), kad galėtumėte vykdyti modelius savo įrenginyje be debesijos prenumeratos.
#
# ### Kas yra Microsoft Foundry Models?
#
# Sveiki atvykę į [Microsoft Foundry Models](https://ai.azure.com/catalog/models?WT.mc_id=academic-105485-koreyst)! Foundry modelių katalogas suteikia vieną vietą ištirti ir išbandyti šimtus AI modelių – iš OpenAI, Meta, Mistral, Cohere, Microsoft ir kitų – talpinamus „Azure“, visus prieinamus per nemokamą žaidimų aikštelę ir, kai paskelbti, kviečiamus iš jūsų mėgstamos kodo IDE.
#
# ### Ką reikia?
#
# * Microsoft paskyra ir [Azure prenumerata](https://aka.ms/azure/free?WT.mc_id=academic-105485-koreyst) (nemokama paskyra tinka)
# * [Microsoft Foundry projektas](https://ai.azure.com?WT.mc_id=academic-105485-koreyst)
#
# Pradėkime!
#
# ### Raskite modelį ir išbandykite jį
#
# Eikite į [Microsoft Foundry Models katalogą](https://ai.azure.com/catalog/models?WT.mc_id=academic-105485-koreyst)
#
# ![Microsoft Foundry Models katalogas, rodantis modelių korteles, tokias kaip Cohere, Meta llama, Mistral ir GPT modeliai](../../../../translated_images/lt/GithubModelsMainScreen.62aed2c56e2bee64.webp)
#
# Pasirinkite modelį – pavyzdžiui, OpenAI GPT-4o mini
#
# Čia matysite modelio kortelę. Galite:
# * Perskaityti informaciją apie modelį skaitymo, etalonų ir licencijos skirtukuose
# * Diegti modelį į savo Foundry projektą
# * Paskyrus, bendrauti su modeliu tiesiogiai žaidimų aikštelėje
#
# ![Microsoft Foundry Models GPT-4o modelio kortelė](../../../../translated_images/lt/GithubModels-modelcard.c65ce4538e7bee92.webp)
#
# Atidarykite **Playground** sąsają, kad bendrautumėte su modeliu, pridėtumėte sistemines užklausas ir keistumėte parametrus – taip pat gaukite visą reikalingą kodą, kad galėtumėte vykdyti tai bet kur, naudojant Python, JavaScript, C# ir REST.
#
# ![Microsoft Foundry Models žaidimų aikštelės patirtis su rodoma kodu ir kalbomis](../../../../translated_images/lt/GithubModels-plagroundcode.da2dea486f1ad5e0.webp)
#
#
# ### Naudokime modelį savo IDE
#
# Yra du variantai:
# 1. **GitHub Codespaces** – sklandi integracija su Codespaces
# 2. **VS Code (arba bet kuri mėgstama IDE)** – jums reikės **galo taško** ir **API rakto** iš savo Foundry projekto
#
#
# Bet kuriuo atveju, šias reikšmes rasite savo Foundry projekto **Apžvalgos** puslapyje.
#
# ![Pradžios ekranas, rodantis, kaip pasiekti Codespaces arba naudoti asmeninį prieigos raktą savo IDE nustatymui](../../../../translated_images/lt/GithubModels-getstarted.4821f6f3182fc666.webp)
#
# ### 1. Codespaces
#
# * Sukurkite naują codespace (arba naudokite esamą)
# * VS Code atsidarys naršyklėje su kelių kalbų pavyzdiniais užrašais, kuriuos galite išbandyti
# * Vykdykite pavyzdį ```./githubmodels-app.py```.
#
# > Pastaba: Codespaces išsaugokite savo Foundry endpoint ir raktą kaip Codespaces paslėptą informaciją, kad nereikėtų jų nustatyti lokaliai.
#
# **Dabar pereikite į toliau esantį 'Generate Text' skyrių, kad tęstumėte užduotį**
#
# ### 2. VS Code (arba bet kuri mėgstama IDE)
#
# Iš savo Microsoft Foundry projekto turite visą informaciją, reikalingą paleisti mėgstamoje IDE. Šiame pavyzdyje bus parodyta VS Code.
#
# * Įdiekite pokalbių modelį savo Foundry projekte. Šios pamokos temperatūros pavyzdžiai naudoja **Llama** modelį, pvz., `Llama-3.3-70B-Instruct`, kadangi loginiai modeliai, tokie kaip `gpt-5-mini`, nepalaiko `temperature`/`top_p`.
# * Nukopijuokite projekto **endpoint** ir **API raktą** iš Apžvalgos puslapio
# * Sukurkite aplinkos kintamuosius jiems saugoti: `AZURE_INFERENCE_ENDPOINT` ir `AZURE_INFERENCE_CREDENTIAL` – pavyzdžiai yra bash, powershell ir Windows komandų lange
# * Įdiekite priklausomybes: ```pip install azure-ai-inference```
# * Nukopijuokite pagrindinį pavyzdinį kodą į .py failą
# * Eikite į vietą, kur išsaugojote kodą, ir paleiskite failą: ```python filename.py```
#
# Nepamirškite, naudodami Azure AI Inference SDK, galite lengvai eksperimentuoti su skirtingais modeliais keisdami `model_name` reikšmę kode.
#
# Toliau pateikti modeliai yra prieinami Microsoft Foundry Models kataloge:
#
# * OpenAI: gpt-4o, gpt-5-mini, gpt-4.1, gpt-4.1-mini, o3-mini, text-embedding-3-large, text-embedding-3-small
# * Meta: Meta-Llama-3.1-405B-Instruct, Meta-Llama-3.1-70B-Instruct, Meta-Llama-3.1-8B-Instruct, Llama-3.2-11B-Vision-Instruct, Llama-3.2-90B-Vision-Instruct, Llama-4-Scout-17B-16E-Instruct
# * Mistral AI: Mistral-large-2411, Mistral-small-2503, Codestral-2501, Ministral-3B
# * Microsoft: Phi-4, Phi-4-mini-instruct, Phi-4-multimodal-instruct, Phi-4-reasoning
# * Cohere: Cohere-command-r-plus-08-2024, Cohere-embed-v3-multilingual, Cohere-embed-v3-english
# * DeepSeek: DeepSeek-V3, DeepSeek-R1
#
#
#
# **Dabar pereikite į toliau esantį 'Generate Text' skyrių, kad tęstumėte užduotį**
#
# ## Teksto generavimas su ChatCompletions
#
# Teksto generavimui naudojama klasė `ChatCompletionsClient`.
# Faile `samples/python/azure_ai_inference/basic.py`, atsakymo kodo skiltyje atnaujinkite vartotojo rolės kodą, pakeisdami content parametrą žemiau pateiktu būdu:
#
# ```python
#
# response = client.complete(
#     messages=[
#         {
#             "role": "system",
#             "content": "You are a helpful assistant.",
#         },
#         {
#             "role": "user",
#             "content": "Complete the following: Once upon a time there was a",
#         },
#     ],
#     model=model_name,
#     # Pasirenkami parametrai
#     temperature=1.,
#     max_tokens=1000,
#     top_p=1.
# )
#
# ```
#
# Paleiskite atnaujintą failą, kad pamatytumėte rezultatą

# %% [markdown]
# ## Skirtingų tipų užklausos, skirtingiems dalykams
#
# Dabar jau matėte, kaip generuoti tekstą naudojant užklausą. Jūs netgi turite veikiantį programą, kurią galite modifikuoti ir keisti, kad generuotumėte skirtingų tipų tekstą.
#
# Užklausos gali būti naudojamos įvairiems uždaviniams. Pavyzdžiui:
#
# - **Generuoti tam tikro tipo tekstą**. Pavyzdžiui, galite generuoti eilėraštį, klausimus viktorinai ir pan.
# - **Ieškoti informacijos**. Užklausas galite naudoti informacijai ieškoti, pavyzdžiui, kaip šiame pavyzdyje: „Ką CORS reiškia žiniatinklio kūrime?“
# - **Generuoti kodą**. Užklausas galite naudoti kodui generuoti, pavyzdžiui, kurdami reguliariąją išraišką el. pašto adresų tikrinimui arba kodėl gi nevisą programą, pavyzdžiui, interneto programą?
#
# ## Užduotis: receptų generatorius
#
# Įsivaizduokite, kad turite ingredientų namuose ir norite ką nors pagaminti. Tam reikia recepto. Receptų galite ieškoti naudodami paieškos sistemą arba galėtumėte naudoti LLM.
#
# Galėtumėte parašyti tokią užklausą:
#
# > „Parodykite man 5 receptus patiekalui su šiomis sudedamosiomis dalimis: vištiena, bulvės ir morkos. Kiekvienam receptui surašykite visas naudojamas sudedamąsias dalis“
#
# Atsižvelgiant į aukščiau nurodytą užklausą, galite gauti panašų atsakymą:
#
# ```output
# 1. Roasted Chicken and Vegetables:
# Ingredients:
# - 4 chicken thighs
# - 2 potatoes, cut into cubes
# - 2 carrots, cut into cubes
# - 2 tablespoons olive oil
# - 2 cloves garlic, minced
# - 1 teaspoon dried thyme
# - 1 teaspoon dried oregano
# - Salt and pepper, to taste
#
# 2. Chicken and Potato Stew:
# Ingredients:
# - 2 tablespoons olive oil
# - 1 onion, diced
# - 2 cloves garlic, minced
# - 2 chicken breasts, cut into cubes
# - 2 potatoes, cut into cubes
# - 2 carrots, cut into cubes
# - 1 teaspoon dried oregano
# - 1 teaspoon dried thyme
# - 1 cup chicken broth
# - Salt and pepper, to taste
#
# 3. Chicken and Potato Bake:
# Ingredients:
# - 2 tablespoons olive oil
# - 2 chicken breasts, cut into cubes
# - 2 potatoes, cut into cubes
# - 2 carrots, cut into cubes
# - 1 onion, diced
# - 2 cloves garlic, minced
# - 1 teaspoon dried oregano
# - 1 teaspoon dried thyme
# - 1 cup chicken broth
# - Salt and pepper, to taste
#
# 4. Chicken and Potato Soup:
# Ingredients:
# - 2 tablespoons olive oil
# - 1 onion, diced
# - 2 cloves garlic, minced
# - 2 chicken breasts, cut into cubes
# - 2 potatoes, cut into cubes
# - 2 carrots, cut into cubes
# - 1 teaspoon dried oregano
# - 1 teaspoon dried thyme
# - 4 cups chicken broth
# - Salt and pepper, to taste
#
# 5. Chicken and Potato Hash:
# Ingredients:
# - 2 tablespoons olive oil
# - 2 chicken breasts, cut into cubes
# - 2 potatoes, cut into cubes
# - 2 carrots, cut into cubes
# - 1 onion, diced
# - 2 cloves garlic, minced
# - 1 teaspoon dried oregano
# ```
#
# Šis rezultatas yra puikus, dabar žinau, ką gaminti. Šiuo atveju būtų naudinga patobulinimų:
#
# - Pašalinti ingredientus, kurių nemėgstu arba kuriems esu alergiškas.
# - Paruošti pirkinių sąrašą, jei namuose neturiu visų ingredientų.
#
# Tokiais atvejais pridėkime papildomą užklausą:
#
# > „Prašau pašalinti receptus su česnaku, nes esu alergiškas, ir pakeisti jį kažkuo kitu. Taip pat, prašau paruošti pirkinių sąrašą pagal receptus, atsižvelgiant, kad namuose jau turiu vištienos, bulvių ir morkų.“
#
# Dabar turite naują rezultatą, būtent:
#
# ```output
# 1. Roasted Chicken and Vegetables:
# Ingredients:
# - 4 chicken thighs
# - 2 potatoes, cut into cubes
# - 2 carrots, cut into cubes
# - 2 tablespoons olive oil
# - 1 teaspoon dried thyme
# - 1 teaspoon dried oregano
# - Salt and pepper, to taste
#
# 2. Chicken and Potato Stew:
# Ingredients:
# - 2 tablespoons olive oil
# - 1 onion, diced
# - 2 chicken breasts, cut into cubes
# - 2 potatoes, cut into cubes
# - 2 carrots, cut into cubes
# - 1 teaspoon dried oregano
# - 1 teaspoon dried thyme
# - 1 cup chicken broth
# - Salt and pepper, to taste
#
# 3. Chicken and Potato Bake:
# Ingredients:
# - 2 tablespoons olive oil
# - 2 chicken breasts, cut into cubes
# - 2 potatoes, cut into cubes
# - 2 carrots, cut into cubes
# - 1 onion, diced
# - 1 teaspoon dried oregano
# - 1 teaspoon dried thyme
# - 1 cup chicken broth
# - Salt and pepper, to taste
#
# 4. Chicken and Potato Soup:
# Ingredients:
# - 2 tablespoons olive oil
# - 1 onion, diced
# - 2 chicken breasts, cut into cubes
# - 2 potatoes, cut into cubes
# - 2 carrots, cut into cubes
# - 1 teaspoon dried oregano
# - 1 teaspoon dried thyme
# - 4 cups chicken broth
# - Salt and pepper, to taste
#
# 5. Chicken and Potato Hash:
# Ingredients:
# - 2 tablespoons olive oil
# - 2 chicken breasts, cut into cubes
# - 2 potatoes, cut into cubes
# - 2 carrots, cut into cubes
# - 1 onion, diced
# - 1 teaspoon dried oregano
#
# Shopping List:
# - Olive oil
# - Onion
# - Thyme
# - Oregano
# - Salt
# - Pepper
# ```
#
# Tai jūsų penki receptai, kuriuose nėra minėtas česnakas, ir taip pat turite pirkinių sąrašą, atsižvelgiant į tai, ką jau turite namuose.

# %% [markdown]
# ## Pratybos - sukurkite receptų generatorių
#
# Dabar, kai suvaidinome scenarijų, parašykime kodą, atitinkantį parodytą scenarijų. Norėdami tai padaryti, atlikite šiuos veiksmus:
#
# 1. Naudokite esamą failą kaip pradinį tašką
# 1. Sukurkite `prompt` kintamąjį ir pakeiskite pavyzdinį kodą taip, kaip nurodyta žemiau:

# %%
import os
from azure.ai.inference import ChatCompletionsClient
from azure.ai.inference.models import SystemMessage, UserMessage
from azure.core.credentials import AzureKeyCredential

# Get these from your Microsoft Foundry project's "Overview" page
token = os.environ["AZURE_INFERENCE_CREDENTIAL"]
endpoint = os.environ["AZURE_INFERENCE_ENDPOINT"]

# temperature/top_p need a non-reasoning model (gpt-5 rejects them), so use a Llama model here.
model_name = os.environ.get("AZURE_INFERENCE_CHAT_MODEL", "Llama-3.3-70B-Instruct")

client = ChatCompletionsClient(
    endpoint=endpoint,
    credential=AzureKeyCredential(token),
)

prompt = "Show me 5 recipes for a dish with the following ingredients: chicken, potatoes, and carrots. Per recipe, list all the ingredients used"

response = client.complete(
    messages=[
        {
            "role": "system",
            "content": "You are a helpful assistant.",
        },
        {
            "role": "user",
            "content": prompt,
        },
    ],
    model=model_name,
    # Optional parameters
    temperature=1.,
    max_tokens=1000,
    top_p=1.    
)

print(response.choices[0].message.content)

# %% [markdown]
# Jei dabar paleisite kodą, turėtumėte pamatyti panašų rezultatą:
#
# ```output
# ### Recipe 1: Classic Chicken Stew
# #### Ingredients:
# - 2 lbs chicken thighs or drumsticks, skinless
# - 4 cups chicken broth
# - 4 medium potatoes, peeled and diced
# - 4 large carrots, peeled and sliced
# - 1 large onion, chopped
# - 2 cloves garlic, minced
# - 2 celery stalks, sliced
# - 1 tsp dried thyme
# - 1 tsp dried rosemary
# - Salt and pepper to taste
# - 2 tbsp olive oil
# - 2 tbsp flour (optional, for thickening)
#
# ### Recipe 2: Chicken and Vegetable Roast
# #### Ingredients:
# - 4 chicken breasts or thighs
# - 4 medium potatoes, cut into wedges
# - 4 large carrots, cut into sticks
# - 1 large onion, cut into wedges
# - 3 cloves garlic, minced
# - 1/4 cup olive oil
# - 1 tsp paprika
# - 1 tsp dried oregano
# - Salt and pepper to taste
# - Juice of 1 lemon
# - Fresh parsley, chopped (for garnish)
# (continued ...)
# ```
#
# > PASTABA, jūsų LLM yra nedeterministinis, todėl kiekvieną kartą paleidus programą galite gauti skirtingus rezultatus.
#
# Puiku, pažiūrėkime, kaip galime pagerinti situaciją. Norėdami pagerinti situaciją, norime užtikrinti, kad kodas būtų lankstus, kad ingredientai ir receptų skaičius galėtų būti tobulinami ir keičiami.

# %% [markdown]
# 1. Pakeiskime kodą taip:

# %%
import os
from azure.ai.inference import ChatCompletionsClient
from azure.ai.inference.models import SystemMessage, UserMessage
from azure.core.credentials import AzureKeyCredential

# Get these from your Microsoft Foundry project's "Overview" page
token = os.environ["AZURE_INFERENCE_CREDENTIAL"]
endpoint = os.environ["AZURE_INFERENCE_ENDPOINT"]

# temperature/top_p need a non-reasoning model (gpt-5 rejects them), so use a Llama model here.
model_name = os.environ.get("AZURE_INFERENCE_CHAT_MODEL", "Llama-3.3-70B-Instruct")

client = ChatCompletionsClient(
    endpoint=endpoint,
    credential=AzureKeyCredential(token),
)

no_recipes = input("No of recipes (for example, 5): ")

ingredients = input("List of ingredients (for example, chicken, potatoes, and carrots): ")

# interpolate the number of recipes into the prompt an ingredients
prompt = f"Show me {no_recipes} recipes for a dish with the following ingredients: {ingredients}. Per recipe, list all the ingredients used"

response = client.complete(
    messages=[
        {
            "role": "system",
            "content": "You are a helpful assistant.",
        },
        {
            "role": "user",
            "content": prompt,
        },
    ],
    model=model_name,
    # Optional parameters
    temperature=1.,
    max_tokens=1000,
    top_p=1.    
)

print(response.choices[0].message.content)

# %% [markdown]
# Kodo bandomasis paleidimas galėtų atrodyti taip:
#
# ```output
# No of recipes (for example, 5): 2
# List of ingredients (for example, chicken, potatoes, and carrots): milk, strawberries
#
# Sure! Here are two recipes featuring milk and strawberries:
#
# ### Recipe 1: Strawberry Milkshake
#
# #### Ingredients:
# - 1 cup milk
# - 1 cup strawberries, hulled and sliced
# - 2 tablespoons sugar (optional, to taste)
# - 1/2 teaspoon vanilla extract
# - 5-6 ice cubes
#
# #### Instructions:
# 1. Combine the milk, strawberries, sugar (if using), and vanilla extract in a blender.
# 2. Blend on high until smooth and creamy.
# 3. Add the ice cubes and blend again until the ice is fully crushed and the milkshake is frothy.
# 4. Pour into a glass and serve immediately.
#
# ### Recipe 2: Strawberry Panna Cotta
#
# #### Ingredients:
# - 1 cup milk
# - 1 cup strawberries, hulled and pureed
# - 1/4 cup sugar
# - 1 teaspoon vanilla extract
# - 1 envelope unflavored gelatin (about 2 1/2 teaspoons)
# - 2 tablespoons cold water
# - 1 cup heavy cream
#
# #### Instructions:
# 1. Sprinkle the gelatin over the cold water in a small bowl and let it stand for about 5-10 minutes to soften.
# 2. In a saucepan, combine the milk, heavy cream, and sugar. Cook over medium heat, stirring frequently until the sugar is dissolved and the mixture begins to simmer. Do not let it boil.
# 3. Remove the saucepan from the heat and stir in the softened gelatin until completely dissolved.
# 4. Stir in the vanilla extract and allow the mixture to cool slightly.
# 5. Divide the mixture evenly into serving cups or molds and refrigerate for at least 4 hours or until set.
# 6. To prepare the strawberry puree, blend the strawberries until smooth.
# 7. Once the panna cotta is set, spoon the strawberry puree over the top of each panna cotta.
# 8. Serve chilled.
#
# Enjoy these delightful recipes!
# ```
#
# ### Patobulinkite pridėdami filtrą ir pirkinių sąrašą
#
# Dabar turime veikiančią programėlę, kuri sukuria receptus ir yra lanksti, nes remiasi vartotojo įvestimis – tiek receptų skaičiumi, tiek naudojamais ingredientais.
#
# Kad ją dar labiau patobulintume, norime pridėti šiuos dalykus:
#
# - **Filtruoti ingredientus**. Norime galėti filtruoti ingredientus, kurie mums nepatinka arba esame jiems alergiški. Kad tai padarytume, galime redaguoti esamą užklausą ir pridėti filtro sąlygą jos pabaigoje taip:
#
#     ```python
#     filter = input("Filter (for example, vegetarian, vegan, or gluten-free: ")
#
#     prompt = f"Show me {no_recipes} recipes for a dish with the following ingredients: {ingredients}. Per recipe, list all the ingredients used, no {filter}"
#     ```
#
# Viršuje pridedame `{filter}` prie užklausos pabaigos ir taip pat gauname filtro reikšmę iš vartotojo.
#
# Programa dabar gali būti paleista su tokiu įvedimu:
#
#     ```output
#     No of recipes (for example, 5): 2
#     List of ingredients (for example, chicken, potatoes, and carrots): onion, milk
#     Filter (for example, vegetarian, vegan, or gluten-free: no milk
#     Certainly! Here are two recipes using onion but omitting milk:
#
#     ### Recipe 1: Caramelized Onions
#
#     #### Ingredients:
#     - 4 large onions, thinly sliced
#     - 2 tablespoons olive oil
#     - 1 tablespoon butter
#     - 1 teaspoon salt
#     - 1 teaspoon sugar (optional)
#     - 1 tablespoon balsamic vinegar (optional)
#
#     #### Instructions:
#     1. Heat the olive oil and butter in a large skillet over medium heat until the butter is melted.
#     2. Add the onions and stir to coat them with the oil and butter mixture.
#     3. Add salt (and sugar if using) to the onions.
#     4. Cook the onions, stirring occasionally, for about 45 minutes to an hour until they are golden brown and caramelized.
#     5. If using, add balsamic vinegar during the last 5 minutes of cooking.
#     6. Remove from heat and serve as a topping for burgers, steak, or as a side dish.
#
#     ### Recipe 2: French Onion Soup
#
#     #### Ingredients:
#     - 4 large onions, thinly sliced
#     - 3 tablespoons unsalted butter
#     - 2 cloves garlic, minced
#     - 1 teaspoon sugar
#     - 1 teaspoon salt
#     - 1/4 cup dry white wine (optional)
#     - 4 cups beef broth
#     - 4 cups chicken broth
#     - 1 bay leaf
#     - 1 teaspoon fresh thyme, chopped (or 1/2 teaspoon dried thyme)
#     - 1 baguette, sliced
#     - 2 cups Gruyère cheese, grated
#
#     #### Instructions:
#     1. Melt the butter in a large pot over medium heat.
#     2. Add the onions, garlic, sugar, and salt, and cook, stirring frequently, until the onions are deeply caramelized (about 30-35 minutes).
#     3. If using, add the white wine and cook until it evaporates, about 3-5 minutes.
#     4. Add the beef and chicken broths, bay leaf, and thyme. Bring to a simmer and cook for another 30 minutes. Remove the bay leaf.
#     5. Preheat the oven to 400°F (200°C).
#     6. Place the baguette slices on a baking sheet and toast them in the preheated oven until golden brown, about 5 minutes.
#     7. Ladle the soup into oven-safe bowls and place a slice of toasted baguette on top of each bowl.
#     8. Sprinkle the grated Gruyère cheese generously over the baguette slices.
#     9. Place the bowls under the broiler until the cheese is melted and bubbly, about 3-5 minutes.
#     10. Serve hot.
#
#     Enjoy your delicious onion dishes!
#     ```
#
# - **Sukurti pirkinių sąrašą**. Norime sukurti pirkinių sąrašą, atsižvelgiant į tai, ką jau turime namuose.
#
# Tam galime pabandyti išspręsti viską viena užklausa arba padalinti į dvi užklausas. Išbandykime antrąjį variantą. Čia siūlome pridėti papildomą užklausą, bet kad tai veiktų, turime pridėti pirmos užklausos rezultatą kaip kontekstą antrajai užklausai.
#
# Suraskite kodo dalį, kuri atspausdina pirmos užklausos rezultatą, ir po ja pridėkite šį kodą:
#
#     ```python
#     old_prompt_result = response.choices[0].message.content
#     prompt = "Produce a shopping list for the generated recipes and please don't include ingredients that I already have."
#
#     new_prompt = f"{old_prompt_result} {prompt}"
#
#     response = client.complete(
#         messages=[
#             {
#                 "role": "system",
#                 "content": "You are a helpful assistant.",
#             },
#             {
#                 "role": "user",
#                 "content": new_prompt,
#             },
#         ],
#         model=model_name,
#         # Pasirinktiniai parametrai
#         temperature=1.,
#         max_tokens=1200,
#         top_p=1.
#     )
#
#     # atspausdinti atsakymą
#     print("Shopping list:")
#     print(response.choices[0].message.content)
#     ```
#
#
# Atkreipkite dėmesį į šiuos dalykus:
#
# - Kuriame naują užklausą, pridėdami pirmos užklausos rezultatą prie naujos užklausos:
#
#         ```python
#         new_prompt = f"{old_prompt_result} {prompt}"
#         messages = [{"role": "user", "content": new_prompt}]
#         ```
#
# - Vykdome naują užklausą, tačiau atsižvelgiame į pirmoje užklausoje prašytų žetonų skaičių, tad šįkart nustatome `max_tokens` kaip 1200. **Žodžiai apie žetonų ilgį**. Turime apsvarstyti, kiek žetonų reikia sugeneruoti norimą tekstą. Žetonai kainuoja pinigus, todėl kur įmanoma, turėtume stengtis naudoti žetonus taupiai. Pavyzdžiui, ar galime formuluoti užklausą taip, kad naudotume mažiau žetonų?
#
#         ```python
#         response = client.complete(
#             messages=[
#                 {
#                     "role": "system",
#                     "content": "You are a helpful assistant.",
#                 },
#                 {
#                     "role": "user",
#                     "content": new_prompt,
#                 },
#             ],
#             model=model_name,
#             # Pasirenkami parametrai
#             temperature=1.,
#             max_tokens=1200,
#             top_p=1.
#         )
#         ```
#
# Pabandę šį kodą, gauname tokį rezultatą:
#
#         ```output
#         No of recipes (for example, 5): 1
#         List of ingredients (for example, chicken, potatoes, and carrots): strawberry, milk
#         Filter (for example, vegetarian, vegan, or gluten-free): nuts
#
#         Certainly! Here's a simple and delicious recipe for a strawberry milkshake using strawberry and milk as primary ingredients:
#
#         ### Strawberry Milkshake
#
#         #### Ingredients:
#         - 1 cup fresh strawberries, hulled
#         - 1 cup cold milk
#         - 1 tablespoon honey or sugar (optional, to taste)
#         - 1/2 teaspoon vanilla extract (optional)
#         - 3-4 ice cubes
#
#         #### Instructions:
#         1. Wash and hull the strawberries, then slice them in half.
#         2. In a blender, combine the strawberries, cold milk, honey or sugar (if using), vanilla extract (if using), and ice cubes.
#         3. Blend until smooth and frothy.
#         4. Pour the milkshake into a glass.
#         5. Serve immediately and enjoy your refreshing strawberry milkshake!
#
#         This recipe is nut-free and makes for a delightful and quick treat!
#         Shopping list:
#         Sure! Here’s the shopping list for the Strawberry Milkshake recipe based on the ingredients provided. Please adjust based on what you already have at home:
#
#         ### Shopping List:
#         - Fresh strawberries (1 cup)
#         - Milk (1 cup)
#
#         Optional:
#         - Honey or sugar (1 tablespoon)
#         - Vanilla extract (1/2 teaspoon)
#         - Ice cubes (3-4)
#
#         Feel free to omit the optional ingredients if you prefer or if you already have them on hand. Enjoy your delicious strawberry milkshake!
#         ```
#
# - **Eksperimentavimas su temperatūra**. Temperatūra yra tai, apie ką dar nekalbėjome, bet tai svarbus aspektas, kaip veikia mūsų programa. Kuo aukštesnė temperatūra, tuo atsakymai tampa labiau atsitiktiniai. Priešingai, kuo žemesnė temperatūra, tuo atsakymai labiau nuspėjami. Pagalvokite, ar norite daugiau įvairovės savo atsakyme, ar ne.
#
# Temperatūros keitimui galite naudoti parametrą `temperature`. Pavyzdžiui, jei norite naudoti temperatūrą 0.5, darytumėte taip:
#
# ```python
#     response = client.complete(
#         messages=[
#             {
#                 "role": "system",
#                 "content": "You are a helpful assistant.",
#             },
#             {
#                 "role": "user",
#                 "content": new_prompt,
#             },
#         ],
#         model=model_name,
#         # Pasirenkami parametrai
#         temperature=0.5,
#         max_tokens=1200,
#         top_p=1.
#     )
# ```
#
# > Pastaba: kuo arčiau 1.0, tuo įvairesnis rezultatas.
#
#
# ## Užduotis
#
# Šioje užduotyje galite rinktis, ką kurti.
#
# Štai keli pasiūlymai:
#
# - Patobulinkite receptų generatoriaus programą. Eksperimentuokite su temperatūros reikšmėmis ir užklausomis ir pažiūrėkite, ką sukursite.
# - Sukurkite „studijų draugą“. Ši programa turėtų gebėti atsakyti į klausimus apie temą, pvz., Python, galėtumėte turėti užklausas, kaip „Kas yra tam tikra tema Python?“ arba „PARODYK kodą apie tam tikrą temą“ ir pan.
# - Istorijos robotas, leiskite istorijai gyventi, nurodykite robotui vaidinti tam tikrą istorinį veikėją ir užduokite klausimus apie jo gyvenimą ir laikmetį.
#
# ## Sprendimas
#
# ### Studijų draugas
#
# - „Jūs esate Python kalbos ekspertas
#
# Pasiūlykite pradedančiųjų pamoką Python šia forma:
#
# Forma:
# - sąvokos:
# - trumpas pamokos paaiškinimas:
# - kodų užduotis su sprendimais“
#
# Aukščiau pateikta pradinė užklausa, pažiūrėkite, kaip ją naudoti ir pritaikyti pagal savo poreikius.
#
# ### Istorijos robotas
#
# Štai keletas užklausų, kurias galite naudoti:
#
# - „Jūs esate Abe Linkolnas, papasakokite apie save trimis sakiniais ir atsakykite naudodami gramatiką bei žodžius, kuriuos naudotų Abe“
# - „Jūs esate Abe Linkolnas, atsakykite naudodami gramatiką bei žodžius, kuriuos naudotų Abe:
#
# Papasakokite apie savo didžiausius pasiekimus, 300 žodžių ilgio:"
#
# ## Žinių patikrinimas
#
# Kas tai yra temperatūros sąvoka?
#
# 1. Ji valdo, kiek atsitiktinis yra rezultatas.
# 1. Ji valdo, koks didelis yra atsakymas.
# 1. Ji valdo, kiek žetonų naudojama.
#
# A: 1
#
# Kaip geriausia saugoti paslaptis, tokias kaip API raktai?
#
# 1. Kode.
# 1. Faile.
# 1. Aplinkos kintamuosiuose.
#
# A: 3, nes aplinkos kintamieji nėra saugomi kode ir gali būti įkelti iš kodo.

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Atsakomybės apribojimas**:
# Šis dokumentas buvo išverstas naudojant dirbtinio intelekto vertimo paslaugą [Co-op Translator](https://github.com/Azure/co-op-translator). Nors siekiame tikslumo, prašome atkreipti dėmesį, kad automatiniai vertimai gali turėti klaidų ar netikslumų. Originalus dokumentas jo gimtąja kalba laikomas autoritetingu šaltiniu. Svarbiai informacijai rekomenduojama naudoti profesionalų žmogiškąjį vertimą. Mes neatsakome už jokius nesusipratimus ar neteisingą interpretaciją, kilusią naudojantis šiuo vertimu.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
