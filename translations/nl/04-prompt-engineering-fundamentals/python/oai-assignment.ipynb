# %% [markdown]
# Het volgende notitieboek is automatisch gegenereerd door GitHub Copilot Chat en is alleen bedoeld voor de initiële setup

# %% [markdown]
# # Introductie tot Prompt Engineering
# Prompt engineering is het proces van het ontwerpen en optimaliseren van prompts voor taken in natuurlijke taalverwerking. Het omvat het selecteren van de juiste prompts, het afstemmen van hun parameters, en het evalueren van hun prestaties. Prompt engineering is cruciaal voor het bereiken van hoge nauwkeurigheid en efficiëntie in NLP-modellen. In deze sectie verkennen we de basisprincipes van prompt engineering met behulp van de OpenAI-modellen voor verkenning.

# %% [markdown]
# ### Oefening 1: Tokenisatie
# Verken Tokenisatie met behulp van tiktoken, een open-source snelle tokenizer van OpenAI
# Zie [OpenAI Cookbook](https://github.com/openai/openai-cookbook/blob/main/examples/How_to_count_tokens_with_tiktoken.ipynb?WT.mc_id=academic-105485-koreyst) voor meer voorbeelden.

# %%
# EXERCISE:
# 1. Run the exercise as is first
# 2. Change the text to any prompt input you want to use & re-run to see tokens

import tiktoken

# Define the prompt you want tokenized
text = f"""
Jupiter is the fifth planet from the Sun and the \
largest in the Solar System. It is a gas giant with \
a mass one-thousandth that of the Sun, but two-and-a-half \
times that of all the other planets in the Solar System combined. \
Jupiter is one of the brightest objects visible to the naked eye \
in the night sky, and has been known to ancient civilizations since \
before recorded history. It is named after the Roman god Jupiter.[19] \
When viewed from Earth, Jupiter can be bright enough for its reflected \
light to cast visible shadows,[20] and is on average the third-brightest \
natural object in the night sky after the Moon and Venus.
"""

# Set the model you want encoding for
encoding = tiktoken.encoding_for_model("gpt-4o")

# Encode the text - gives you the tokens in integer form
tokens = encoding.encode(text)
print(tokens);

# Decode the integers to see what the text versions look like
[encoding.decode_single_token_bytes(token) for token in tokens]

# %% [markdown]
# ### Oefening 2: Valideer OpenAI API-sleutelconfiguratie
#
# Voer de onderstaande code uit om te controleren of je OpenAI-eindpunt correct is ingesteld. De code probeert gewoon een eenvoudige basisprompt en valideert de voltooiing. De invoer `oh say can you see` zou moeten worden voltooid met iets als `by the dawn's early light..`

# %%
# Uses the OpenAI client with the Responses API.
# See https://platform.openai.com/docs/api-reference/responses

import os
from openai import OpenAI
from dotenv import load_dotenv
load_dotenv()

client = OpenAI()

deployment="gpt-4o-mini"

def get_completion(prompt):
    response = client.responses.create(
        model=deployment,
        input=prompt,
        temperature=0, # this is the degree of randomness of the model's output
        max_output_tokens=1024,
        store=False,
    )
    return response.output_text

## ---------- Call the helper method

### 1. Set primary content or prompt text
text = f"""
oh say can you see
"""

### 2. Use that in the prompt template below
prompt = f"""
```{text}```
"""

## 3. Run the prompt
response = get_completion(prompt)
print(response)

# %% [markdown]
# ### Oefening 3: Verzinsels
# Ontdek wat er gebeurt wanneer je het LLM vraagt om aanvullingen terug te geven voor een prompt over een onderwerp dat mogelijk niet bestaat, of over onderwerpen waar het misschien niets van weet omdat ze buiten de vooraf getrainde dataset vallen (recente onderwerpen). Kijk hoe het antwoord verandert als je een andere prompt of een ander model probeert.

# %%
## Set the text for simple prompt or primary content
## Prompt shows a template format with text in it - add cues, commands etc if needed
## Run the completion 
text = f"""
generate a lesson plan on the Martian War of 2076.
"""

prompt = f"""
```{text}```
"""

response = get_completion(prompt)
print(response)

# %% [markdown]
# ### Oefening 4: Instructie Gebaseerd
# Gebruik de variabele "text" om de primaire inhoud in te stellen
# en de variabele "prompt" om een instructie te geven die met die primaire inhoud te maken heeft.
#
# Hier vragen we het model om de tekst samen te vatten voor een leerling van groep 4

# %%
# Test Example
# https://platform.openai.com/playground/p/default-summarize

## Example text
text = f"""
Jupiter is the fifth planet from the Sun and the \
largest in the Solar System. It is a gas giant with \
a mass one-thousandth that of the Sun, but two-and-a-half \
times that of all the other planets in the Solar System combined. \
Jupiter is one of the brightest objects visible to the naked eye \
in the night sky, and has been known to ancient civilizations since \
before recorded history. It is named after the Roman god Jupiter.[19] \
When viewed from Earth, Jupiter can be bright enough for its reflected \
light to cast visible shadows,[20] and is on average the third-brightest \
natural object in the night sky after the Moon and Venus.
"""

## Set the prompt
prompt = f"""
Summarize content you are provided with for a second-grade student.
```{text}```
"""

## Run the prompt
response = get_completion(prompt)
print(response)

# %% [markdown]
# ### Oefening 5: Complexe prompt
# Probeer een verzoek dat systeem-, gebruiker- en assistentberichten bevat
# Het systeem stelt de context van de assistent in
# Gebruiker- en assistentberichten bieden context voor een gesprek met meerdere beurten
#
# Let op hoe de persoonlijkheid van de assistent wordt ingesteld op "sarcastisch" in de systeemcontext.
# Probeer een andere persoonlijkheidscontext te gebruiken. Of probeer een andere reeks input-/outputberichten

# %%
response = client.responses.create(
    model=deployment,
    input=[
        {"role": "system", "content": "You are a sarcastic assistant."},
        {"role": "user", "content": "Who won the world series in 2020?"},
        {"role": "assistant", "content": "Who do you think won? The Los Angeles Dodgers of course."},
        {"role": "user", "content": "Where was it played?"}
    ],
    store=False,
)
print(response.output_text)

# %% [markdown]
# ### Oefening: Verken je intuïtie
# De bovenstaande voorbeelden geven je patronen die je kunt gebruiken om nieuwe opdrachten te maken (eenvoudig, complex, instructie, enz.) - probeer andere oefeningen te maken om enkele van de andere ideeën die we hebben besproken te verkennen, zoals voorbeelden, aanwijzingen en meer.

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Disclaimer**:
# Dit document is vertaald met behulp van de AI vertaaldienst [Co-op Translator](https://github.com/Azure/co-op-translator). Hoewel we streven naar nauwkeurigheid, dient u er rekening mee te houden dat geautomatiseerde vertalingen fouten of onnauwkeurigheden kunnen bevatten. Het originele document in de oorspronkelijke taal moet worden beschouwd als de gezaghebbende bron. Voor kritieke informatie wordt professionele menselijke vertaling aanbevolen. Wij zijn niet aansprakelijk voor eventuele misverstanden of verkeerde interpretaties die voortvloeien uit het gebruik van deze vertaling.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
