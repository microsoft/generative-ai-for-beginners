# %% [markdown]
# تم إنشاء دفتر الملاحظات التالي تلقائيًا بواسطة GitHub Copilot Chat وهو مخصص للإعداد الأولي فقط

# %% [markdown]
# # مقدمة في هندسة المطالبات
# هندسة المطالبات هي عملية تصميم وتحسين المطالبات لمهام معالجة اللغة الطبيعية. وتشمل اختيار المطالبات المناسبة، وضبط معلماتها، وتقييم أدائها. تعتبر هندسة المطالبات حاسمة لتحقيق دقة وكفاءة عالية في نماذج معالجة اللغة الطبيعية. في هذا القسم، سوف نستعرض أساسيات هندسة المطالبات باستخدام نماذج OpenAI للاكتشاف.

# %% [markdown]
# ### التمرين 1: التجزئة
# استكشف التجزئة باستخدام tiktoken، أداة تجزئة سريعة مفتوحة المصدر من OpenAI
# انظر [OpenAI Cookbook](https://github.com/openai/openai-cookbook/blob/main/examples/How_to_count_tokens_with_tiktoken.ipynb?WT.mc_id=academic-105485-koreyst) لمزيد من الأمثلة.

# %%
# EXERCISE:
# 1. Run the exercise as is first
# 2. Change the text to any prompt input you want to use & re-run to see tokens

import tiktoken

# Define the prompt you want tokenized
text = f"""
Jupiter is the fifth planet from the Sun and the \
largest in the Solar System. It is a gas giant with \
a mass one-thousandth that of the Sun, but two-and-a-half \
times that of all the other planets in the Solar System combined. \
Jupiter is one of the brightest objects visible to the naked eye \
in the night sky, and has been known to ancient civilizations since \
before recorded history. It is named after the Roman god Jupiter.[19] \
When viewed from Earth, Jupiter can be bright enough for its reflected \
light to cast visible shadows,[20] and is on average the third-brightest \
natural object in the night sky after the Moon and Venus.
"""

# Set the model you want encoding for
encoding = tiktoken.encoding_for_model("gpt-4o")

# Encode the text - gives you the tokens in integer form
tokens = encoding.encode(text)
print(tokens);

# Decode the integers to see what the text versions look like
[encoding.decode_single_token_bytes(token) for token in tokens]

# %% [markdown]
# ### التمرين 2: التحقق من إعداد مفتاح واجهة برمجة تطبيقات OpenAI
#
# قم بتشغيل الكود أدناه للتحقق من أن نقطة النهاية الخاصة بـ OpenAI تم إعدادها بشكل صحيح. يحاول الكود ببساطة طلبًا أساسيًا بسيطًا ويتحقق من التكملة. يجب أن يُكمل الإدخال `oh say can you see` على غرار `by the dawn's early light..`

# %%
# Uses the OpenAI client with the Responses API.
# See https://platform.openai.com/docs/api-reference/responses

import os
from openai import OpenAI
from dotenv import load_dotenv
load_dotenv()

client = OpenAI()

deployment="gpt-5-mini"

def get_completion(prompt):
    response = client.responses.create(
        model=deployment,
        input=prompt,
        max_output_tokens=1024,
        store=False,
    )
    return response.output_text

## ---------- Call the helper method

### 1. Set primary content or prompt text
text = f"""
oh say can you see
"""

### 2. Use that in the prompt template below
prompt = f"""
```{text}```
"""

## 3. Run the prompt
response = get_completion(prompt)
print(response)

# %% [markdown]
# ### التمرين 3: الاختلاقات
# استكشف ما يحدث عندما تطلب من نموذج اللغة الكبير إعطاء تكملات لموجه حول موضوع قد لا يكون موجودًا، أو حول مواضيع قد لا يعرفها لأنه خارج مجموعة البيانات التي تم تدريبه عليها مسبقًا (الأكثر حداثة). راقب كيف يتغير الرد إذا جربت موجه مختلف، أو نموذجًا مختلفًا.

# %%
## Set the text for simple prompt or primary content
## Prompt shows a template format with text in it - add cues, commands etc if needed
## Run the completion 
text = f"""
generate a lesson plan on the Martian War of 2076.
"""

prompt = f"""
```{text}```
"""

response = get_completion(prompt)
print(response)

# %% [markdown]
# ### التمرين 4: بناءً على التعليمات
# استخدم متغير "text" لتعيين المحتوى الأساسي
# ومتغير "prompt" لتقديم تعليمات تتعلق بذلك المحتوى الأساسي.
#
# هنا نطلب من النموذج تلخيص النص لطالب في الصف الثاني

# %%
# Test Example
# https://platform.openai.com/playground/p/default-summarize

## Example text
text = f"""
Jupiter is the fifth planet from the Sun and the \
largest in the Solar System. It is a gas giant with \
a mass one-thousandth that of the Sun, but two-and-a-half \
times that of all the other planets in the Solar System combined. \
Jupiter is one of the brightest objects visible to the naked eye \
in the night sky, and has been known to ancient civilizations since \
before recorded history. It is named after the Roman god Jupiter.[19] \
When viewed from Earth, Jupiter can be bright enough for its reflected \
light to cast visible shadows,[20] and is on average the third-brightest \
natural object in the night sky after the Moon and Venus.
"""

## Set the prompt
prompt = f"""
Summarize content you are provided with for a second-grade student.
```{text}```
"""

## Run the prompt
response = get_completion(prompt)
print(response)

# %% [markdown]
# ### التمرين 5: طلب معقد
# جرب طلبًا يحتوي على رسائل من النظام، المستخدم والمساعد
# يحدد النظام سياق المساعد
# رسائل المستخدم والمساعد توفر سياق محادثة متعددة الجولات
#
# لاحظ كيف تم تعيين شخصية المساعد إلى "ساخر" في سياق النظام.
# جرب استخدام شخصية مختلفة في السياق. أو جرب سلسلة مختلفة من رسائل الإدخال/الإخراج

# %%
response = client.responses.create(
    model=deployment,
    input=[
        {"role": "system", "content": "You are a sarcastic assistant."},
        {"role": "user", "content": "Who won the world series in 2020?"},
        {"role": "assistant", "content": "Who do you think won? The Los Angeles Dodgers of course."},
        {"role": "user", "content": "Where was it played?"}
    ],
    store=False,
)
print(response.output_text)

# %% [markdown]
# ### تمرين: استكشف حدسك
# الأمثلة السابقة تمنحك أنماطًا يمكنك استخدامها لإنشاء مطالبات جديدة (بسيطة، معقدة، تعليمات، إلخ) - جرّب إنشاء تمارين أخرى لاستكشاف بعض الأفكار الأخرى التي تحدثنا عنها مثل الأمثلة، والإشارات، والمزيد.

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **تنويه**:
# تمت ترجمة هذا المستند باستخدام خدمة الترجمة بالذكاء الاصطناعي [Co-op Translator](https://github.com/Azure/co-op-translator). بينما نسعى للدقة، يرجى العلم أن الترجمات الآلية قد تحتوي على أخطاء أو عدم دقة. يجب اعتبار المستند الأصلي بلغته الأصلية المصدر الرسمي والمعتمد. للمعلومات الهامة، يُنصح بالاستعانة بترجمة بشرية محترفة. نحن غير مسؤولين عن أي سوء فهم أو تفسير ناتج عن استخدام هذه الترجمة.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
