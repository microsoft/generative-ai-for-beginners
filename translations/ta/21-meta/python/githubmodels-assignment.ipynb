# %% [markdown]
# # மெட்டா குடும்ப மாதிரிகளுடன் கட்டிடம் செய்வது
#
# ## அறிமுகம்
#
# இந்த பாடம் கையாளும் বিষয়ங்கள்:
#
# - இரண்டு முக்கிய மெட்டா குடும்ப மாதிரிகளை ஆராய்தல் - லாமா 3.1 மற்றும் லாமா 3.2
# - ஒவ்வொரு மாதிரிக்கும் பயன்பாட்டு வழிகள் மற்றும் சூழ்நிலைகளை புரிந்துகொள்வது
# - ஒவ்வொரு மாதிரியின் தனித்துவ அம்சங்களை காட்டும் குறியீடு உதாரணம்
#
#
# ## மெட்டா குடும்ப மாதிரிகள்
#
# இந்த பாடத்தில், நாம் மெட்டா குடும்பத்தின் அல்லது "லாமா ரீட்" இல் இருந்து 2 மாதிரிகளை ஆராயப்போகிறோம் - லாமா 3.1 மற்றும் லாமா 3.2
#
# இந்த மாதிரிகள் பல வகைகளில் கிடைக்கின்றன மற்றும் [Microsoft Foundry Models பட்டியலில்](https://ai.azure.com/catalog/models?WT.mc_id=academic-105485-koreyst) கிடைக்கின்றன.
#
# > **குறிப்பு:** GitHub Models ஜூலை 2026இன் முடிவில் பயன்பாட்டிலிருந்து வெளியேறும். AI மாதிரிகளுடன் உருவாக்க Microsoft Foundry Models பயன்பாட்டைப்பற்றி மேலும் விவரங்கள் [இங்கே](https://learn.microsoft.com/azure/ai-foundry/model-inference/overview?WT.mc_id=academic-105485-koreyst).
#
# மாதிரி வகைகள்:
# - லாமா 3.1 - 70B இன்பக்ட்ரக்ட்
# - லாமா 3.1 - 405B இன்பக்ட்ரக்ட்
# - லாமா 3.2 - 11B விட்ஷன் இன்பக்ட்ரக்ட்
# - லாமா 3.2 - 90B விட்ஷன் இன்பக்ட்ரக்ட்
#
# *குறிப்பு: லாமா 3 Microsoft Foundry Models இல் கிடைக்கிறது, ஆனால் இந்த பாடத்தில் அதைப் பற்றிப் பேசப்பட மாட்டாது*

# %% [markdown]
# ## ல்லாமா 3.1
#
# 405 பில்லியன் அளவுகோல்கள் கொண்ட, ல்லாமா 3.1 திறந்த மூல LLM வகைபடுத்தலில் பொருந்துகிறது.
#
# இந்த பதிப்பு முந்தைய வெளியீடு ல்லாமா 3 ஐ மேம்படுத்தும் வகையில்:
#
# - பெரிய உள்ளடைவு சாளரம் - 128k டோக்கன்கள் مقابل 8k டோக்கன்கள்
# - பெரிய அதிகபட்ச வெளியீடு டோக்கன்கள் - 4096 مقابل 2048
# - சிறந்த பன்மொழி ஆதரவு - பயிற்சி டோக்கன்கள் அதிகரித்து
#
# இவை ல்லாமா 3.1-ஐ ஜென் ஏஐ பயன்பாடுகள் உருவாக்கும்போது கூடுதல் சிக்கலான பயன்பாடுகள் கையாள உதவுகின்றன:
# - சொந்த செயல்பாட்டு அழைப்பு - LLM வேலைபாடுக்கு வெளியே உள்ள வெளிப்பார்வை கருவிகள் மற்றும் செயல்பாடுகளை அழைக்கும் திறன்
# - சிறந்த RAG செயல்திறன் - அதிக உள்ளடைவு சாளரத்தினால்
# - செயற்கை தரவு உருவாக்கம் - நுட்ப சூழலைப் போன்ற பணிகளுக்காக பயனுள்ள தரவை உருவாக்கும் திறன்

# %% [markdown]
# ### நாட்டிய செயல்பாடு அழைப்பு
#
# Llama 3.1 செயல்பாடுகள் அல்லது கருவி அழைப்புகளை செய்வதில் அதிக செயல்திறன் அடைவதற்காக நன்கு வடிவமைக்கப்பட்டது. அதற்கு இரண்டு உட்புகுத்தப்பட்ட கருவிகள் உள்ளன, அவை பயனரிடமிருந்து வரும் குறிக்கோளின் அடிப்படையில் எந்த கருவி பயன்படுத்தப்பட வேண்டும் என்பதை மாதிரியாக அடையாளம் காண முடியும். இந்த கருவிகள்:
#
# - **Brave Search** - வானிலை போன்ற புதுப்பிக்கப்பட்ட தகவல்களை வலை தேடல் மூலம் பெற பயன்படும்
# - **Wolfram Alpha** - மேலும் சிக்கலான கணித கணக்கீடுகளுக்கு பயன்படுத்தப்படுகிறது, எனவே உங்கள் சொந்த செயல்பாடுகளை எழுத வேண்டியதில்லை.
#
# நீங்கள் LLM அழைக்கக்கூடிய உங்கள் சொந்த தனிப்பயன் கருவிகளையும் உருவாக்கலாம்.
#
# கீழே உள்ள குறியீடு உதாரணத்தில்:
#
# - கிடைக்கும் கருவிகள் (brave_search, wolfram_alpha) அமைப்பு குறிக்கோளில் வரையறுக்கப்பட்டுள்ளன.
# - ஒரு நகரத்தின் வானிலையைப் பற்றி கேட்கும் பயனர் குறிக்கோளை அனுப்பவும்.
# - LLM Brave Search கருவியை அழைக்கும் பழக்கவழக்கு `<|python_tag|>brave_search.call(query="Stockholm weather")` போன்றதாக இருக்கும்
#
# *கவனிக்கவும்: இந்த உதாரணம் கருவி அழைப்பை மட்டுமே செய்கிறது, முடிவுகளை பெற விரும்பினால், Brave API பக்கத்தில் இலவச கணக்கை உருவாக்கி செயல்பாட்டை வரையறுக்க வேண்டும்`

# %%
# %pip install azure-core
# %pip install azure-ai-inference

# %%
import os
from azure.ai.inference import ChatCompletionsClient
from azure.ai.inference.models import AssistantMessage, SystemMessage, UserMessage
from azure.core.credentials import AzureKeyCredential

# Get these from your Microsoft Foundry project's "Overview" page
token = os.environ["AZURE_INFERENCE_CREDENTIAL"]
endpoint = os.environ["AZURE_INFERENCE_ENDPOINT"]
model_name = "Meta-Llama-3.1-405B-Instruct"

client = ChatCompletionsClient(
    endpoint=endpoint,
    credential=AzureKeyCredential(token),
)


tool_prompt=f"""
<|begin_of_text|><|start_header_id|>system<|end_header_id|>

Environment: ipython
Tools: brave_search, wolfram_alpha
Cutting Knowledge Date: December 2023
Today Date: 23 July 2024

You are a helpful assistant<|eot_id|>
"""

messages = [
    SystemMessage(content=tool_prompt),
    UserMessage(content="What is the weather in Stockholm?"),

]

response = client.complete(messages=messages, model=model_name)

print(response.choices[0].message.content)

# %% [markdown]
# ### ல்லாமா 3.2
#
# ல்லாமா 3.1 ஒரு LLM என்றாலும், அதற்குள் உள்ள ஒரு குறைபாடு மைக்ஸ்மீடியா திறன் ஆகும். அதாவது, படங்கள் போன்ற பலவகை உள்ளீடுகளை பயன்படுத்தி பதிலளிக்கக் கூடியதையாகக் காணப்படும் திறன். இந்த திறன் ல்லாமா 3.2 இன் முக்கிய அம்சங்களில் ஒன்றாகும். இந்த அம்சங்களில் அடக்கம்:
#
# - மைக்ஸ்மீடியா - உரை மற்றும் பட உத்திகளைய இரண்டையும் மதிப்பீடு செய்யும் திறன்
# - சிறிய முதல் நடுத்தர அளவுகள் (11B மற்றும் 90B) - இது நெகிழ்வான உபயோகப்படுத்தல் விருப்பங்களை வழங்குகிறது,
# - உரை மட்டுமே உள்ள அளவுகள் (1B மற்றும் 3B) - இது மாடலை எட்ஜ் / மொபைல் சாதனங்களில் பயன்படுத்தும் வசதியையும் குறைந்த குறுகியதுவையும் வழங்குகிறது
#
# மைக்ஸ்மீடியா ஆதரவு திறன் திறந்த மூல மாடல்களின் உலகில் ஒரு பெரிய முன்னேற்றத்தை குறிக்கிறது. கீழே உள்ள கோடு உதாரணம் ல்லாமா 3.2 90B இலிருந்து படத்தையும் உரைக்கும் ஒருங்கிணைத்துப் படத்தைப் பகுப்பாய்வு செய்யக் கொடுக்கிறது.
#
# ### ல்லாமா 3.2 உடன் மைக்ஸ்மீடியா ஆதரவு

# %%
# %pip install azure-core
# %pip install azure-ai-inference

# %%
import os
from azure.ai.inference import ChatCompletionsClient
from azure.ai.inference.models import (
    SystemMessage,
    UserMessage,
    TextContentItem,
    ImageContentItem,
    ImageUrl,
    ImageDetailLevel,
)
from azure.core.credentials import AzureKeyCredential

# Get these from your Microsoft Foundry project's "Overview" page
token = os.environ["AZURE_INFERENCE_CREDENTIAL"]
endpoint = os.environ["AZURE_INFERENCE_ENDPOINT"]
model_name = "Llama-3.2-90B-Vision-Instruct"


client = ChatCompletionsClient(
    endpoint=endpoint,
    credential=AzureKeyCredential(token),
)

response = client.complete(
    messages=[
        SystemMessage(
            content="You are a helpful assistant that describes images in details."
        ),
        UserMessage(
            content=[
                TextContentItem(text="What's in this image?"),
                ImageContentItem(
                    image_url=ImageUrl.load(
                        image_file="sample.jpg",
                        image_format="jpg",
                        detail=ImageDetailLevel.LOW)
                ),
            ],
        ),
    ],
    model=model_name,
)

print(response.choices[0].message.content)

# %% [markdown]
# ## கற்றல் இங்குதான் நிற்காது, பயணத்தை தொடருங்கள்
#
# இந்த பாடத்தை முடித்த பிறகு, உங்கள் சுழற்சி செயற்கை நுண்ணறிவு அறிவை இன்னும் மேம்படுத்த எங்கள் [சுழற்சி செயற்கை நுண்ணறிவு கற்றல் தொகுப்பு](https://aka.ms/genai-collection?WT.mc_id=academic-105485-koreyst) ஐ காணவும்!

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **மறுப்பு**:
# இந்த ஆவணம் AI மொழிபெயர்ப்பு சேவை [Co-op Translator](https://github.com/Azure/co-op-translator) பயன்படுத்தி மொழிபெயர்க்கப்பட்டுள்ளது. நாங்கள் துல்லியத்திற்காக முயற்சி செய்துள்ளோம், ஆனால் தானாக செய்யப்படும் மொழிபெயர்ப்புகளில் பிழைகள் அல்லது தவறுகள் இருக்கலாம் என்பதை கவனத்தில் கொள்ளவும். அசல் ஆவணம் அதன் தாய்மொழியில் அதிகாரப்பூர்வ ஆதாரமாக கருதப்பட வேண்டும். முக்கியமான தகவல்களுக்கு, தொழில்நுட்பமான மனித மொழிபெயர்ப்பு பரிந்துரைக்கப்படுகிறது. இந்த மொழிபெயர்ப்பைப் பயன்படுத்துவதால் ஏற்படும் எந்த தவறான புரிதல்கள் அல்லது தவறான விளக்கத்திற்கும் நாங்கள் பொறுப்பில்வில்லை.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
