# %% [markdown]
# # படங்களை உருவாக்கும் பயன்பாட்டை உருவாக்குதல்
#
# LLMs (Large Language Models) மூலம் உரை உருவாக்கத்தைத் தாண்டி பலவற்றை செய்ய முடியும். உரை விவரணங்களிலிருந்து படங்களை உருவாக்கவும் கூட முடியும். படங்களை உருவாக்கும் திறன் மருத்துவ தொழில்நுட்பம், கட்டிடக்கலை, சுற்றுலா, விளையாட்டு மேம்பாடு போன்ற பல துறைகளில் மிகவும் பயனுள்ளதாக இருக்கும். இந்த அத்தியாயத்தில், மிகவும் பிரபலமான இரண்டு பட உருவாக்க மாடல்கள், DALL-E மற்றும் Midjourney பற்றி பார்ப்போம்.
#
# ## அறிமுகம்
#
# இந்த பாடத்தில் நாம் கற்கப்போகிறவை:
#
# - பட உருவாக்கம் மற்றும் அதன் பயன்கள்.
# - DALL-E மற்றும் Midjourney என்றால் என்ன, அவை எப்படி செயல்படுகின்றன.
# - ஒரு பட உருவாக்க பயன்பாட்டை எப்படி உருவாக்குவது.
#
# ## கற்றல் இலக்குகள்
#
# இந்த பாடத்தை முடித்த பிறகு, நீங்கள்:
#
# - ஒரு பட உருவாக்க பயன்பாட்டை உருவாக்க முடியும்.
# - உங்கள் பயன்பாட்டிற்கான எல்லைகளை meta prompts மூலம் வரையறுக்க முடியும்.
# - DALL-E மற்றும் Midjourney உடன் வேலை செய்ய முடியும்.
#
# ## ஏன் ஒரு பட உருவாக்க பயன்பாட்டை உருவாக்க வேண்டும்?
#
# பட உருவாக்க பயன்பாடுகள் Generative AI இன் திறன்களை ஆராய ஒரு சிறந்த வழியாகும். அவை பலவகையான பயன்பாடுகளுக்கு உதவக்கூடியவை, உதாரணமாக:
#
# - **படத் திருத்தம் மற்றும் ஒருங்கிணைப்பு**: பல்வேறு பயன்பாடுகளுக்காக படங்களை உருவாக்க முடியும், உதாரணமாக படத் திருத்தம் மற்றும் பட ஒருங்கிணைப்பு.
#
# - **பல துறைகளில் பயன்பாடு**: மருத்துவ தொழில்நுட்பம், சுற்றுலா, விளையாட்டு மேம்பாடு போன்ற பல துறைகளில் படங்களை உருவாக்க பயன்படுத்தலாம்.
#
# ## சூழல்: Edu4All
#
# இந்த பாடத்தின் ஒரு பகுதியாக, நாம் Edu4All என்ற நமது ஸ்டார்ட்அப்புடன் தொடர்ந்து வேலை செய்வோம். மாணவர்கள் தங்கள் மதிப்பீடுகளுக்காக படங்களை உருவாக்குவார்கள். எந்த வகையான படங்களை உருவாக்குவது என்பது அவர்களது விருப்பம். உதாரணமாக, அவர்கள் தங்களது கற்பனைக்கதைக்கான விளக்கப்படங்களை உருவாக்கலாம் அல்லது தங்கள் கதைக்கான புதிய கதாபாத்திரத்தை உருவாக்கலாம் அல்லது தங்கள் கருத்துகளை காட்சிப்படுத்த உதவலாம்.
#
# Edu4All மாணவர்கள், உதாரணமாக, நினைவுச்சின்னங்கள் பற்றிய வகுப்பில் வேலை செய்தால், அவர்கள் உருவாக்கக்கூடிய சில படங்கள் இங்கே:
#
# ![Edu4All ஸ்டார்ட்அப், நினைவுச்சின்னங்கள் பற்றிய வகுப்பு, ஐஃபல் கோபுரம்](../../../../translated_images/startup.94d6b79cc4bb3f5afbf6e2ddfcf309aa5d1e256b5f30cc41d252024eaa9cc5dc.ta.png)
#
# இதைப் போன்ற ஒரு prompt பயன்படுத்தி:
#
# > "காலை நேர சூரிய ஒளியில் ஐஃபல் கோபுரம் அருகே நாய்"
#
# ## DALL-E மற்றும் Midjourney என்றால் என்ன?
#
# [DALL-E](https://openai.com/dall-e-2?WT.mc_id=academic-105485-koreyst) மற்றும் [Midjourney](https://www.midjourney.com/?WT.mc_id=academic-105485-koreyst) ஆகியவை மிகவும் பிரபலமான பட உருவாக்க மாடல்கள். இவை prompt களை பயன்படுத்தி படங்களை உருவாக்க அனுமதிக்கின்றன.
#
# ### DALL-E
#
# முதலில் DALL-E பற்றி பார்ப்போம். இது ஒரு Generative AI மாடல், இது உரை விவரணங்களிலிருந்து படங்களை உருவாக்குகிறது.
#
# > [DALL-E என்பது இரண்டு மாடல்களின் இணைப்பு, CLIP மற்றும் diffused attention](https://towardsdatascience.com/openais-dall-e-and-clip-101-a-brief-introduction-3a4367280d4e?WT.mc_id=academic-105485-koreyst).
#
# - **CLIP** என்பது படங்கள் மற்றும் உரைகளிலிருந்து எண்களால் பிரதிபலிக்கப்படும் embeddings உருவாக்கும் மாடல்.
#
# - **Diffused attention** என்பது embeddings இல் இருந்து படங்களை உருவாக்கும் மாடல். DALL-E படங்கள் மற்றும் உரைகளின் தரவுத்தொகுப்பில் பயிற்சியளிக்கப்பட்டது, மேலும் உரை விவரணங்களிலிருந்து படங்களை உருவாக்க பயன்படுத்தப்படுகிறது. உதாரணமாக, DALL-E ஒரு தொப்பியில் பூனை அல்லது மோகாக் கொண்ட நாயின் படங்களை உருவாக்க முடியும்.
#
# ### Midjourney
#
# Midjourney DALL-E போலவே செயல்படுகிறது. இது உரை prompt களை பயன்படுத்தி படங்களை உருவாக்குகிறது. Midjourney மூலம் “ஒரு தொப்பியில் பூனை” அல்லது “மோகாக் கொண்ட நாய்” போன்ற prompt களை பயன்படுத்தி படங்களை உருவாக்கலாம்.
#
# ![Midjourney மூலம் உருவாக்கப்பட்ட படம், இயந்திர புறா](https://upload.wikimedia.org/wikipedia/commons/thumb/8/8c/Rupert_Breheny_mechanical_dove_eca144e7-476d-4976-821d-a49c408e4f36.png/440px-Rupert_Breheny_mechanical_dove_eca144e7-476d-4976-821d-a49c408e4f36.png?WT.mc_id=academic-105485-koreyst)
#
# *படத்தின் உரிமை: விக்கிப்பீடியா, Midjourney மூலம் உருவாக்கப்பட்ட படம்*
#
# ## DALL-E மற்றும் Midjourney எப்படி செயல்படுகின்றன?
#
# முதலில், [DALL-E](https://arxiv.org/pdf/2102.12092.pdf?WT.mc_id=academic-105485-koreyst). DALL-E என்பது *ஆட்டோரிகிரசிவ் டிரான்ஸ்ஃபார்மர்* கொண்ட டிரான்ஸ்ஃபார்மர் கட்டமைப்பை அடிப்படையாகக் கொண்ட Generative AI மாடல்.
#
# *ஆட்டோரிகிரசிவ் டிரான்ஸ்ஃபார்மர்* என்பது ஒரு மாடல் உரை விவரணங்களிலிருந்து படங்களை உருவாக்கும் முறையை வரையறுக்கிறது. இது ஒரு பிக்சலை ஒரே நேரத்தில் உருவாக்கி, பின்னர் உருவாக்கப்பட்ட பிக்சல்களை அடுத்த பிக்சலை உருவாக்க பயன்படுத்துகிறது. இது நரம்பியல் வலையமைப்பின் பல அடுக்குகள் வழியாக செல்கிறது, படத்தை முழுமையாக உருவாக்கும் வரை.
#
# இந்த செயல்முறையின் மூலம், DALL-E உருவாக்கும் படங்களில் பண்புகள், பொருட்கள், குணாதிசயங்கள் மற்றும் பலவற்றை கட்டுப்படுத்துகிறது. ஆனால், DALL-E 2 மற்றும் 3 உருவாக்கப்படும் படத்தின் மீது மேலும் அதிக கட்டுப்பாட்டை வழங்குகின்றன.

# %% [markdown]
# ## உங்கள் முதல் பட உருவாக்க பயன்பாட்டை உருவாக்குதல்
#
# பட உருவாக்க பயன்பாட்டை உருவாக்க என்ன தேவை? உங்களுக்கு பின்வரும் நூலகங்கள் தேவை:
#
# - **python-dotenv**, உங்கள் ரகசியங்களை *.env* கோப்பில் இருந்து விலக்கி வைக்க இந்த நூலகத்தை பயன்படுத்த பரிந்துரைக்கப்படுகிறது.
# - **openai**, OpenAI API உடன் தொடர்பு கொள்ள இந்த நூலகத்தை நீங்கள் பயன்படுத்துவீர்கள்.
# - **pillow**, Python-இல் படங்களுடன் வேலை செய்ய.
# - **requests**, HTTP கோரிக்கைகளை செய்ய உதவ.
#
# 1. பின்வரும் உள்ளடக்கத்துடன் *.env* என்ற கோப்பை உருவாக்கவும்:
#
#     ```text
#     OPENAI_API_KEY='<add your OpenAI key here>'
#     ```

# %% [markdown]
# 1. மேலே உள்ள நூலகங்களை *requirements.txt* என்ற கோப்பில் சேகரிக்கவும், இதைப் போல:
#
#     ```text
#     python-dotenv
#     openai
#     pillow
#     requests
#     ```
#
#
# 1. அதன் பிறகு, ஒரு மெய்நிகர் சூழலை உருவாக்கி நூலகங்களை நிறுவவும்:

# %%
# create virtual env
! python3 -m venv venv
# activate environment
! source venv/bin/activate
# install libraries
# pip install -r requirements.txt, if using a requirements.txt file 
! pip install python-dotenv openai pillow requests

# %% [markdown]
# > [!NOTE]
# > Windows-ல், உங்கள் மெய்நிகர் சூழலை உருவாக்க மற்றும் செயல்படுத்த கீழ்க்காணும் கட்டளைகளை பயன்படுத்தவும்:
#
#     ```bash
#     python3 -m venv venv
#     venv\Scripts\activate.bat
#     ```
#
# 1. *app.py* என்ற கோப்பில் கீழ்க்காணும் குறியீட்டை சேர்க்கவும்:
#
#     ```python
#     import openai
#     import os
#     import requests
#     from PIL import Image
#     import dotenv
#
#     # import dotenv
#     dotenv.load_dotenv()
#
#     # Create OpenAI object
#     client = OpenAI()
#
#
#     try:
#         # Create an image by using the image generation API
#         generation_response = client.images.generate(
#             model="dall-e-3",
#             prompt='Bunny on horse, holding a lollipop, on a foggy meadow where it grows daffodils',    # Enter your prompt text here
#             size='1024x1024',
#             n=1
#         )
#         # Set the directory for the stored image
#         image_dir = os.path.join(os.curdir, 'images')
#
#         # If the directory doesn't exist, create it
#         if not os.path.isdir(image_dir):
#             os.mkdir(image_dir)
#
#         # Initialize the image path (note the filetype should be png)
#         image_path = os.path.join(image_dir, 'generated-image.png')
#
#         # Retrieve the generated image
#         print(generation_response)
#
#         image_url = generation_response.data[0].url # extract image URL from response
#         generated_image = requests.get(image_url).content  # download the image
#         with open(image_path, "wb") as image_file:
#             image_file.write(generated_image)
#
#         # Display the image in the default image viewer
#         image = Image.open(image_path)
#         image.show()
#
#     # catch exceptions
#     except client.error.InvalidRequestError as err:
#         print(err)
#
#     ```
#
# இந்த குறியீட்டை விளக்குவோம்:
#
# - முதலில், OpenAI நூலகம், dotenv நூலகம், requests நூலகம் மற்றும் Pillow நூலகம் போன்ற தேவையான நூலகங்களை இறக்குமதி செய்கிறோம்.
#
#     ```python
#     import openai
#     import os
#     import requests
#     from PIL import Image
#     import dotenv
#     ```
#
# - அதன் பிறகு, ``.env``-இல் இருந்து API விசையை பெறும் பொருளை உருவாக்குகிறோம்.
#
#     ```python
#         # Create OpenAI object
#         client = OpenAI()
#     ```
#
# - அடுத்ததாக, படத்தை உருவாக்குகிறோம்:
#
#     ```python
#     # Create an image by using the image generation API
#     generation_response = client.images.generate(
#         model="dall-e-3",
#         prompt='Bunny on horse, holding a lollipop, on a foggy meadow where it grows daffodils',    # Enter your prompt text here
#         size='1024x1024',
#         n=1
#     )
#     ```
#
#     மேலே உள்ள குறியீடு உருவாக்கப்பட்ட படத்தின் URL-ஐ கொண்ட JSON பொருளை பதிலளிக்கிறது. இந்த URL-ஐ பயன்படுத்தி படத்தை பதிவிறக்கம் செய்து ஒரு கோப்பில் சேமிக்கலாம்.
#
# - கடைசியாக, படத்தை திறந்து, வழக்கமான பட பார்வையாளரை பயன்படுத்தி அதை காண்பிக்கிறோம்:
#
#     ```python
#     image = Image.open(image_path)
#     image.show()
#     ```
#
# ### படத்தை உருவாக்குவதற்கான கூடுதல் விவரங்கள்
#
# படத்தை உருவாக்கும் குறியீட்டை மேலும் விரிவாகப் பார்ப்போம்:
#
# ```python
# generation_response = client.images.generate(
#         model="dall-e-3",
#         prompt='Bunny on horse, holding a lollipop, on a foggy meadow where it grows daffodils',    # Enter your prompt text here
#         size='1024x1024',
#         n=1
#     )
# ```
#
# - **prompt**, இது படத்தை உருவாக்க பயன்படுத்தப்படும் உரை உத்தேசம். இங்கு, "மூடுபனியான புல்வெளியில், குதிரை மீது ஒரு லாலிபாப் பிடித்துக் கொண்டிருக்கும் முயல், புல்வெளியில் மஞ்சள் பூக்கள் வளர்கின்றன" என்ற உத்தேசத்தை பயன்படுத்துகிறோம்.
# - **size**, இது உருவாக்கப்படும் படத்தின் அளவு. இங்கு, 1024x1024 பிக்சல்கள் அளவிலான படத்தை உருவாக்குகிறோம்.
# - **n**, இது உருவாக்கப்படும் படங்களின் எண்ணிக்கை. இங்கு, இரண்டு படங்களை உருவாக்குகிறோம்.
#
# படங்களுடன் மேலும் செய்யக்கூடிய விஷயங்களை அடுத்த பகுதியில் காண்போம்.
#
# ## பட உருவாக்கத்தின் கூடுதல் திறன்கள்
#
# Python-ல் சில வரிகளைக் கொண்டு படத்தை உருவாக்கிய விதத்தை இதுவரை பார்த்தீர்கள். ஆனால், படங்களுடன் மேலும் செய்யக்கூடிய விஷயங்கள் உள்ளன.
#
# நீங்கள் இதையும் செய்யலாம்:
#
# - **திருத்தங்களைச் செய்யவும்**. ஏற்கனவே உள்ள ஒரு படத்தை, ஒரு மாஸ்க் மற்றும் ஒரு உத்தேசத்தை வழங்குவதன் மூலம், ஒரு படத்தை மாற்றலாம். உதாரணமாக, ஒரு படத்தின் ஒரு பகுதியை மாற்றி அதில் ஏதாவது சேர்க்கலாம். முயல் படத்தை கற்பனை செய்யுங்கள், முயலுக்கு ஒரு தொப்பி சேர்க்கலாம். அதைச் செய்ய, படத்தை, மாஸ்க் (மாற்றம் செய்ய வேண்டிய பகுதியை அடையாளம் காண) மற்றும் உரை உத்தேசத்தை வழங்க வேண்டும்.
#
#     ```python
#     response = openai.images.edit(
#       image=open("base_image.png", "rb"),
#       mask=open("mask.png", "rb"),
#       prompt="An image of a rabbit with a hat on its head.",
#       n=1,
#       size="1024x1024"
#     )
#     image_url = response.data[0].url
#     ```
#
#     அடிப்படை படம் முயலை மட்டுமே கொண்டிருக்கும், ஆனால் இறுதி படம் முயலின் மீது தொப்பி இருக்கும்.
#
# - **மாறுபாடுகளை உருவாக்கவும்**. கருத்து என்னவென்றால், நீங்கள் ஏற்கனவே உள்ள ஒரு படத்தை எடுத்து, அதற்கான மாறுபாடுகளை உருவாக்க வேண்டும். மாறுபாடுகளை உருவாக்க, நீங்கள் ஒரு படத்தை மற்றும் உரை உத்தேசத்தை வழங்கி, கீழ்க்காணும் குறியீட்டை பயன்படுத்தலாம்:
#
#     ```python
#     response = openai.images.create_variation(
#       image=open("bunny-lollipop.png", "rb"),
#       n=1,
#       size="1024x1024"
#     )
#     image_url = response.data[0].url
#     ```

# %% [markdown]
# ---
#
# **குறிப்பு**:
# இந்த ஆவணம் [Co-op Translator](https://github.com/Azure/co-op-translator) என்ற AI மொழிபெயர்ப்பு சேவையைப் பயன்படுத்தி மொழிபெயர்க்கப்பட்டுள்ளது. நாங்கள் துல்லியத்திற்காக முயற்சிக்கிறோம், ஆனால் தானியங்கி மொழிபெயர்ப்புகளில் பிழைகள் அல்லது தவறான தகவல்கள் இருக்கக்கூடும் என்பதை தயவுசெய்து கவனத்தில் கொள்ளுங்கள். அதன் தாய்மொழியில் உள்ள மூல ஆவணம் அதிகாரப்பூர்வ ஆதாரமாக கருதப்பட வேண்டும். முக்கியமான தகவல்களுக்கு, தொழில்முறை மனித மொழிபெயர்ப்பு பரிந்துரைக்கப்படுகிறது. இந்த மொழிபெயர்ப்பைப் பயன்படுத்துவதால் ஏற்படும் எந்த தவறான புரிதல்கள் அல்லது தவறான விளக்கங்களுக்கு நாங்கள் பொறுப்பல்ல.
