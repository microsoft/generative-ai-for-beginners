# %% [markdown]
# ## அறிமுகம்
#
# இந்த பாடம் கவர இருக்கும்:
# - செயல்பாட்டு அறிமுறை என்ன மற்றும் அதன் பயன்பாடுகள்
# - Azure OpenAI பயன்படுத்தி செயல்பாட்டு அறிமுறையை உருவாக்குவது எப்படி
# - செயல்பாட்டு அறிமுறையை ஒரு செயலியில் ஒருங்கிணைக்கும் முறை
#
# ## கற்றல் குறிக்கோள்கள்
#
# இந்த பாடத்தை முடித்தபின் நீங்கள் எப்படி என்பதை அறிந்து கொள்ளவோ புரிந்து கொள்வதோ செய்ய முடியும்:
#
# - செயல்பாட்டு அறிமுறையை பயன்படுத்துவதன் நோக்கம்
# - Azure Open AI சேவையை பயன்படுத்தி செயல்பாட்டு அறிமுறையை அமைத்தல்
# - உங்கள் செயலியின் பயன்பாட்டிற்கான பயன் படுத்தக்கூடிய செயல்பாட்டு அறிமுறைகளை வடிவமைத்தல்

# %% [markdown]
# ## செயல்பாட்டு அழைப்புகளை புரிந்துகொள்ளுதல்
#
# இந்த படிப்பிற்கு, நாங்கள் எங்கள் கல்வி தொடக்க நிறுவனத்திற்கான ஒரு அம்சத்தை உருவாக்க விரும்புகிறோம், இது பயனர்களுக்கு தொழில்நுட்ப பாடநெறிகளை கண்டுபிடிக்க ஹெல்ப்டாக் மூலம் உதவும். அவர்கள் திறன் நிலை, தற்போதைய பணி மற்றும் விருப்ப தொழில்நுட்பத்தை பொருத்து பாடநெறிகளை பரிந்துரைக்கிறோம்.
#
# இதனை முடிக்க, நாங்கள் பின்வருவனவற்றை இணைத்து பயன்படுத்துவோம்:
#  - பயனருக்கு ஒரு உரையாடல் அனுபவத்தை உருவாக்க `Azure Open AI`
#  - பயனர்களின் கோரிக்கையை அடிப்படையாகக் கொண்டு பாடநெறிகளை கண்டுபிடிக்க `Microsoft Learn Catalog API`
#  - பயனரின் விசாரணையை எடுத்துக் கொண்டு ஒரு API கோரிக்கை செய்ய `Function Calling`
#
# துவங்க, முதலில் நாம் ஏன் செயல்பாட்டு அழைப்புகளை பயன்படுத்த வேண்டும் என்பதைக் காண்போம்:

# %% [markdown]
# ### செயல்பாடு அழைப்பது ஏன்
#
# நீங்கள் இந்த பாடத்தில் ஏதேனும் மற்ற பாடத்தை முடித்திருந்தால், பன்மொழி மொழி மாதிரிகள் (LLMs) பயன்படுத்துவதின் சக்தியை நீங்கள் புரிந்திருக்க வாய்ப்புள்ளது. அதேபோல் அவற்றின் சில கட்டுப்பாடுகளையும் நீங்கள் காண முடியும் என நம்புகிறோம்.
#
# செயல்பாடு அழைப்பது Azure Open AI சேவையின் ஒரு அம்சமாகும், கீழ்க்காணும் கட்டுப்பாடுகளைத் தாண்ட விட:
# 1) ஒரே மாதிரியான பதில் வடிவம்
# 2) உரையாடல் சூழலில் பயன்பாட்டின் பிற மூலங்களிலிருந்து தரவைப் பயன்படுத்தும் திறன்
#
# செயல்பாடு அழைப்புக்கு முன்பு, LLM இன் பதில்கள் அமைப்பற்றதும் ஒரே மாதிரியும் இல்லை.  கூற்றியர்கள் ஒவ்வொரு பதிலின் மாறுபாட்டையும் கையாளும் திறன் கொள்வதற்காக சிக்கலான சரிபார்ப்பு குறியீட்டை எழுத வேண்டியிருந்தது.
#
# பயனாளிகள் "ஷ்டாகோல்மில் தற்போதைய வானிலை என்ன?" போன்ற கேள்விகளுக்கு பதில்கள் பெற முடியவில்லை. இதன் காரணம் மாதிரிகள் பயிற்சி பெற்று வந்த தரவின் காலத்துடன் மட்டுப்படுத்தப்பட்டிருந்தது.
#
# இந்த சிக்கலை வெளிப்படுத்தும் கீழ்காணும் எடுத்துக்காட்டைக் காண்போம்:
#
# மாணவர் தரவுக்கான ஒரு தரவுத்தளத்தை உருவாக்க விரும்புகிறோமென கூறுங்கள், அதனால் அவர்களுக்கு சரியான பாடத்திட்டத்தை பரிந்துரைக்கலாம். கீழே உள்ள இரண்டு மாணவர்கள் பற்றிய விவரங்கள் தரவு வல்லுநர்களின் கணக்கில் மிகவும் இணையாக இருக்கின்றன.

# %%
student_1_description="Emily Johnson is a sophomore majoring in computer science at Duke University. She has a 3.7 GPA. Emily is an active member of the university's Chess Club and Debate Team. She hopes to pursue a career in software engineering after graduating."
 
student_2_description = "Michael Lee is a sophomore majoring in computer science at Stanford University. He has a 3.8 GPA. Michael is known for his programming skills and is an active member of the university's Robotics Club. He hopes to pursue a career in artificial intelligence after finishing his studies."

# %% [markdown]
# நாம் இந்தத் தரவுகளை ப解析க்க LLMக்கு அனுப்ப விரும்புவோம். இதனை பின்பு நமது பயன்பாட்டில் APIக்கு அனுப்ப அல்லது தரவுத்தளத்தில் சேமிக்க பயன்படுத்தலாம்.
#
# நாம் ஈடுபடுவதற்கான தகவல்களை LLMக்கு சொல்வதற்கான இரண்டு ஒரே மாதிரியான கோரிக்கைகளை உருவாக்குவோம்:

# %% [markdown]
# இந்தப் பகுதியை எங்கள் தயாரிப்புக்கு முக்கியமானவை என LLM க்கு அனுப்ப விரும்புகிறோம். அதனால் LLM ஐ வழிநடத்த இரண்டு ஒரேபோன்ற உத்தேசங்களை உருவாக்க முடியும்:

# %%
prompt1 = f'''
Please extract the following information from the given text and return it as a JSON object:

name
major
school
grades
club

This is the body of text to extract the information from:
{student_1_description}
'''


prompt2 = f'''
Please extract the following information from the given text and return it as a JSON object:

name
major
school
grades
club

This is the body of text to extract the information from:
{student_2_description}
'''

# %% [markdown]
# இந்த இரண்டு உந்துதல்கள் உருவாக்கப்பட்ட பிறகு, `client.responses.create` பயன்படுத்தி அவற்றை LLM க்கு அனுப்புவோம்.  நாங்கள் உந்துதலை `input` மாறியில் சேமித்து, பங்கினை `user` என்று ஒதுக்குகிறோம். இது ஒரு பயனரிடமிருந்து ஒரு செய்தி chatbotக்கு எழுதியதைப் போல செயல் படுத்துகிறது.

# %%
import os
import json
from openai import OpenAI
from dotenv import load_dotenv
load_dotenv()

# The OpenAI client points at the Azure OpenAI (Microsoft Foundry) /openai/v1/ endpoint
client = OpenAI(
  api_key=os.environ['AZURE_OPENAI_API_KEY'],
  base_url=f"{os.environ['AZURE_OPENAI_ENDPOINT'].rstrip('/')}/openai/v1/",
  )

deployment=os.environ['AZURE_OPENAI_DEPLOYMENT']
# Out:
# Running cells with '/opt/homebrew/bin/python3' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# இப்போது நாங்கள் இரு வேண்டுகோள்களையும் LLMக்கு அனுப்பி நாம் பெறும் பதிலை பரிசோதிக்கலாம்.

# %%
openai_response1 = client.responses.create(
 model=deployment,    
 input = [{'role': 'user', 'content': prompt1}],
 store=False,
)
openai_response1.output_text

# %%
openai_response2 = client.responses.create(
 model=deployment,    
 input = [{'role': 'user', 'content': prompt2}],
 store=False,
)
openai_response2.output_text

# %%
# Loading the response as a JSON object
json_response1 = json.loads(openai_response1.output_text)
json_response1

# %%
# Loading the response as a JSON object
json_response2 = json.loads(openai_response2.output_text)
json_response2

# %% [markdown]
# ஒன்றோன்று இருந்தாலும் மற்றும் விளக்கங்கள் ஒத்ததாக இருந்தாலும், நாம் `Grades` பண்புக்கான வெவ்வேறு வடிவமைப்புகளைப் பெறலாம்.
#
# மேல் உள்ள செல்செய்யும் செயலியை பலமுறை இயக்கினால், வடிவமைப்பு `3.7` அல்லது `3.7 GPA` ஆக இருக்கலாம்.
#
# இது காரணம் LLM கட்டாயப்படுத்தப்படாத தரவுகளை எழுத்துப் பிராம்ட் வடிவில் எடுத்துக்கொண்டு, கட்டாயப்படுத்தப்படாத தரவுகளையே திரும்ப அளிக்கிறது. நாம் கட்டமைக்கப்பட்ட வடிவமைப்பைக் கொண்டிருக்க வேண்டும், அப்போது நாம் இந்த தரவை சேமிப்பதற்கும் அல்லது பயன்படுத்துவதற்கும் என்ன எதிர்பார்க்க வேண்டும் என்று தெரியும்.
#
# செயல்பாட்டு அழைப்பைப் பயன்படுத்துவதன் மூலம், கட்டமைக்கப்பட்ட தரவைத் திரும்ப பெறுவதை நிச்சயப்படுத்த முடியும். செயல்பாட்டு அழைப்பைப் பயன்படுத்தும்போது, LLM உண்மையில் எந்த செயல்பாடுகளையும் அழைக்கவோ இயக்கவோ செய்யாது. பதில்கள் அளிக்க LLM பின்பற்ற ஒரு கட்டமைப்பை நாம் உருவாக்குகிறோம். பின்னர் அக்கட்டமைக்கப்பட்ட பதில்களைப் பயன்படுத்தி எதை இயக்க வேண்டும் என்பதை நமது பயன்பாடுகளில் தெரியும்.

# %% [markdown]
# ![ஊர்முக அழைப்பு ஓட்காட்சி வரைபடம்](../../../../translated_images/ta/Function-Flow.083875364af4f4bb.webp)

# %% [markdown]
# பிறகு, நாங்கள் செயல்பாட்டிலிருந்து திரும்பியவற்றை எடுத்துக்கொண்டு இதை LLMக்கு திருப்பி அனுப்ப முடியும். அதன் பின்னர் LLM, பயனரின் கேள்விக்கு இயல்பான மொழியில் பதிலளிக்கும்.

# %% [markdown]
# ### செயல்பாட்டு அழைப்புகளைப் பயன்படுத்தும் பயன்பாடுகள்
#
# **வெளிப்புற கருவிகளை அழைக்கல்**
# чат்பாட்கள் பயனர்களின் கேள்விகளுக்கு பதிலளிப்பதில் சிறந்தவை. செயல்பாட்டு அழைப்பைப் பயன்படுத்துவதன் மூலம், чат்பாட்கள் பயனர்களின் செய்திகளைப் பயன்படுத்தி சில பணிகளை முடிக்கலாம். உதாரணமாக, ஒரு மாணவர் чат்பாட்டிடம் “எனது ஆசிரியருக்கு இ-மெயில் அனுப்பவும், நான் இந்த பாடத்தில் மேலும் உதவியளிக்கவேண்டும் என்று சொல்லவும்” என்று கேட்கலாம். இதன் மூலம் `send_email(to: string, body: string)` என்ற செயல்பாட்டை அழைக்கலாம்
#
#
# **API அல்லது தரவுத்தள கேள்விகள் உருவாக்குதல்**
# பயனர்கள் இயற்கை மொழியைக் கொண்டு தகவல்களைப் பெறலாம், அவை வடிவமைக்கப்பட்ட கேள்வி அல்லது API கோரிக்கையாக மாறும். உதாரணமாக, ஒரு ஆசிரியர் “ஓராவது மாணவர்கள் கடைசித் திட்டத்தை முடித்தவர்கள் யார்” என்று கேட்கலாம், இது `get_completed(student_name: string, assignment: int, current_status: string)` என்ற செயல்பாட்டை அழைக்கலாம்
#
#
# **உருவாக்கும் கட்டமைக்கப்பட்ட தரவு**
# பயனர்கள் ஒரு உரை தொகுதி அல்லது CSV போன்றவற்றிலிருந்து முக்கிய தகவல்களை LLM-ஐப் பயன்படுத்தி எடுக்க முடியும். உதாரணமாக, ஒரு மாணவர் சமாதான ஒப்பந்தங்களைப் பற்றிய விக்கிப்பீடியா கட்டுரையை AI ஃபிளாஷ் கார்டுகள் ஆக மாற்றலாம். இது `get_important_facts(agreement_name: string, date_signed: string, parties_involved: list)` என்ற செயல்பாட்டைப் பயன்படுத்தி செய்யலாம்

# %% [markdown]
# ## 2. உங்கள் முதல் செயல்பாட்டு அழைப்பை உருவாக்குதல்
#
# ஒரு செயல்பாட்டு அழைப்பை உருவாக்கும் செயல்முறை 3 முக்கிய படிகளைக் கொண்டுள்ளது:
# 1. உங்கள் செயல்பாடுகளின் பட்டியலுடன் மற்றும் ஒரு பயனர் செய்தியுடன் Chat Completions API-வை அழைத்தல்
# 2. செயல்படுத்த ஒரு செயல்பாடு அல்லது API அழைப்பை இயக்க மாடலின் பதிலை வாசித்தல்
# 3. பயனருக்கு பதிலை உருவாக்க அந்த தகவலை பயன்படுத்த உங்கள் செயல்பாட்டின் பதிலுடன் Chat Completions API-வுக்கு மற்றொரு அழைப்பை செய்வது.

# %% [markdown]
# ![ஒரு செயல்பாட்டுக் கோரிக்கையின் ஓட்டம்](../../../../translated_images/ta/LLM-Flow.3285ed8caf4796d7.webp)

# %% [markdown]
# ### ஒரு செயல்பாடு அழைப்பின் கூறுகள்
#
# #### பயன்பாட்டாளர் உள்ளீடு
#
# முதல் படி ஒரு பயனர் செய்தியை உருவாக்குவது. இது ஒரு உரை உள்ளீட்டின் மதிப்பைப் பெற்று தானாகவே ஒதுக்கலாம் அல்லது நீங்கள் இங்கே ஒரு மதிப்பை ஒதுக்கலாம். நீங்கள் Chat Completions API உடன் முதன்முறை வேலை செய்வதாக இருந்தால், செய்தியின் `role` மற்றும் `content` ஐ வரையறுக்க வேண்டும்.
#
# `role` என்பது `system` (கொள்கைகளை உருவாக்குவது), `assistant` (மாதிரி) அல்லது `user` (இறுதி பயனர்) ஆக இருக்க முடியும். செயல்பாடு அழைப்பிற்கு, இதை `user` என்ற வகையில் மற்றும் ஒரு எடுத்துக்காட்டு கேள்வியாக ஒதுக்குவோம்.

# %%
messages= [ {"role": "user", "content": "Find me a good course for a beginner student to learn Azure."} ]

# %% [markdown]
# ### செயல்பாடுகளை உருவாக்குதல்.
#
# அடுத்து நாம் ஒரு செயல்பாடை மற்றும் அதன் பரிமாணங்களை வரையறுப்போம். இங்கு `search_courses` என்ற ஒரு செயல்பாடு மட்டுமே பயன்படுத்துகிறோம், ஆனால் நீங்கள் பல செயல்பாடுகளை உருவாக்கலாம்.
#
# **முக்கியம்** : செயல்பாடுகள் LLM-க்கு அனுப்பப்படும் கணினி செய்தியில் சேர்க்கப்படுகின்றன மற்றும் உங்களுக்கு கிடைக்கும் டோக்கன்களின் அளவிலும் சேர்க்கப்படும்.

# %%
# The Responses API uses a flat tool format: name/description/parameters at the top level
functions = [
   {
      "type":"function",
      "name":"search_courses",
      "description":"Retrieves courses from the search index based on the parameters provided",
      "parameters":{
         "type":"object",
         "properties":{
            "role":{
               "type":"string",
               "description":"The role of the learner (i.e. developer, data scientist, student, etc.)"
            },
            "product":{
               "type":"string",
               "description":"The product that the lesson is covering (i.e. Azure, Power BI, etc.)"
            },
            "level":{
               "type":"string",
               "description":"The level of experience the learner has prior to taking the course (i.e. beginner, intermediate, advanced)"
            }
         },
         "required":[
            "role"
         ]
      }
   }
]

# %% [markdown]
# **வரையறைகள்**
#
# `name` - நாம் அழைக்க விரும்பும் செயல்பாட்டின் பெயர்.
#
# `description` - செயல்பாடு எவ்வாறு செயல்படுகிறது என்பதை விளக்கும் விவரம். இங்கு தெளிவாகவும் சரியாகவும் இருக்க வேண்டும்
#
# `parameters` - மாடல் தன் பதிலில் உற்பத்தி செய்ய விரும்பும் மதிப்புகளும் வடிவமைப்பும் கொண்ட பட்டியல்
#
#
# `type` - பண்புகளின் தரவுத்தரவு வகை
#
# `properties` - மாடல் தன் பதிலில் பயன்படுத்தும் குறிப்பிட்ட மதிப்புகளின் பட்டியல்
#
#
# `name` - மாடல் தன் வடிவமைக்கப்பட்ட பதிலில் பயன்படுத்தும் பண்பின் பெயர்
#
# `type` - இந்த பண்பின் தரவுத்தரவு வகை
#
# `description` - குறிப்பிட்ட பண்பின் விளக்கம்
#
#
# **விருப்பமானவை**
#
# `required` - செயல்பாட்டு அழைப்பை நிறைவேற்றுவதற்கு தேவையான பண்பு

# %% [markdown]
# ### செயல்பாடு அழைப்பு செய்யல்
# ஒரு செயல்பாட்டை வரையறுக்கக்குப்பின், அதை Chat Completion API ஐ அழைப்பில் சேர்க்க வேண்டும். இதற்கு, கோரிக்கையில் `functions` ஐச் சேர்க்கிறோம். இதில், `functions=functions` ஆக இருக்கும்.
#
# `function_call` ஐ `auto` என்று அமைப்பதும் ஒரு விருப்பம் உள்ளது. இதன் அர்த்தம், பயனர் செய்தியை அடிப்படையாகக் கொண்டு எந்த செயல்பாடு அழைக்கப்பட வேண்டும் என்பதை நாங்களே தீர்மானிப்பதற்குப் பதிலாக LLM தீர்மானிக்க விடுவோம் எனும் பொருள்.

# %%
response = client.responses.create(model=deployment, 
                                        input=messages,
                                        tools=functions, 
                                        tool_choice="auto",
                                        store=False) 

print(response.output)

# %% [markdown]
# இப்போது பதிலைக் காண்போம் மற்றும் அது எப்படி வடிவமைக்கப்பட்டிருக்கிறது என்பதை பார்ப்போம்:
#
# {
#   "role": "assistant",
#   "function_call": {
#     "name": "search_courses",
#     "arguments": "{\n  \"role\": \"student\",\n  \"product\": \"Azure\",\n  \"level\": \"beginner\"\n}"
#   }
# }
#
# செயலியின் பெயர் அழைக்கப்பட்டது என்பதைப் பார்க்க முடியும் மற்றும் பயனர் செய்தியிலிருந்து, LLM செயலியின் arguments-க்கு பொருந்தும் தரவை கண்டுபிடிக்க முடிந்தது.

# %% [markdown]
# ## 3. செயலியில் செயல்பாடு அழைப்புகளை இணைத்தல்.
#
#
# LLM-இன் வடிவமைக்கப்பட்ட பதிலை நாம் சோதித்த பிறகு, இப்போது அதை ஒரு செயலியில் இணைக்கலாம்.
#
# ### தொலைபயணத்தை இயக்குதல்
#
# இதனை எங்கள் செயலியில் இணைக்க, கீழ்காணும் படிகளை எடுத்துக்கொள்வோம்:
#
# முதலில், Open AI சேவைகளை அழைத்து 'response_message' என்ற மாறியில் செய்தியை சேமிக்கலாம்.

# %%
# Extract the function call items from the response output
tool_calls = [item for item in response.output if item.type == "function_call"]

# %% [markdown]
# இப்போது நாம் Microsoft Learn API-யை அழைத்து பாடங்களின் பட்டியலை பெறும் செயல்பாட்டை வரையறுக்கப் போகிறோம்:

# %%
import requests

def search_courses(role, product, level):
    url = "https://learn.microsoft.com/api/catalog/"
    params = {
        "role": role,
        "product": product,
        "level": level
    }
    response = requests.get(url, params=params)
    modules = response.json()["modules"]
    results = []
    for module in modules[:5]:
        title = module["title"]
        url = module["url"]
        results.append({"title": title, "url": url})
    return str(results)

# %% [markdown]
# சிறந்த நடைமுறையாக, பின்னர் மாதிரி ஒரு செயல்பாட்டை அழைக்க விரும்புகிறதா என்று நாம் பார்க்க போகிறோம். அதன் பிறகு, குறியிடப்பட்ட செயல்பாட்டை உருவாக்கி அழைக்கப்பட்ட செயல்பாட்டுடன் பொருந்தச் செய்வோம்.
# அதன்பின், செயல்பாட்டின் அமைப்புகளை எடுத்து அவற்றை LLM-இன் அமைப்புகளுடன் மையமாக்குவோம்.
#
# இறுதியில், செயல்பாட்டை அழைக்கும் செய்தியை மற்றும் `search_courses` செய்தியால் திருப்பிய பெறுமதிகளை இணைக்கிறோம். இது LLM-க்கு
# இயல்புநிலை மொழியை பயன்படுத்தி பயனருக்கு பதிலளிக்க தேவையான அனைத்து தகவல்களையும் வழங்குகிறது.

# %%
# Check if the model wants to call a function
if tool_calls:
    tool_call = tool_calls[0]
    print("Recommended Function call:")
    print(tool_call.name)
    print()

    # Call the function. 
    function_name = tool_call.name

    available_functions = {
            "search_courses": search_courses,
    }
    function_to_call = available_functions[function_name] 

    function_args = json.loads(tool_call.arguments)
    function_response = function_to_call(**function_args)

    print("Output of function call:")
    print(function_response)
    print(type(function_response))


    # Add the model's function call item(s) and our function result to the conversation.
    # The Responses API represents tool results as `function_call_output` items.
    messages.extend(response.output)  # adding the model's function_call item(s)
    messages.append( # adding function response to messages
        {
            "type": "function_call_output",
            "call_id": tool_call.call_id,
            "output": function_response,
        }
    )

# %% [markdown]
# இப்போது நாம் புதுப்பிக்கப்பட்ட செய்தியை LLM க்கு அனுப்புவோம், அதனால் API JSON வடிவிலான பதிலின் பதிலுக்கு பதிலாக இயற்கை மொழி பதிலை பெறலாம்.

# %%
print("Messages in next request:")
print(messages)
print()

second_response = client.responses.create(
    input=messages,
    model=deployment,
    tools=functions,
    tool_choice="auto",
    temperature=0,
    store=False,
        )  # get a new response from the model where it can see the function response


print(second_response.output_text)

# %% [markdown]
# ## குறியீட்டு சேவல்
#
# அருமை! Azure Open AI செயல்பாட்டு அழைப்பைப் பற்றிய உங்கள் கற்றலைத் தொடர https://learn.microsoft.com/training/support/catalog-api-developer-reference?WT.mc_id=academic-105485-koreyst என்ற வலைப் பக்கத்தை நீங்கள் உருவாக்கலாம்
#  - கற்றுக்கொள்ளுபவர்களுக்கு அதிக பாடங்களைத் தேட உதவும் செயல்பாட்டின் கூடுதல் அளவுருக்கள். கிடைக்கும் API அளவுருக்களை இங்கே காணலாம்:
#  - கற்றுக் கொள்வவரின் தாய்மொழி போன்ற கூடுதல் தகவல்களைப் பெறும் மற்றொரு செயல்பாட்டு அழைப்பான ஒன்றை உருவாக்கவும்
#  - செயல்பாட்டு அழைப்பு மற்றும்/அல்லது API அழைப்பு எந்த பொருத்தமான பாடங்களையும் வழங்காவிட்டால் பிழை கையாளுதலை உருவாக்கவும்

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **மறுப்பு**:
# இந்த ஆவணம் AI மொழிபெயர்ப்பு சேவை [Co-op Translator](https://github.com/Azure/co-op-translator) பயன்படுத்தி மொழிபெயர்க்கப்பட்டுள்ளது. நாங்கள் துல்லியத்திற்காக முயற்சி செய்துள்ளோம், ஆனால் தானாக செய்யப்படும் மொழிபெயர்ப்புகளில் பிழைகள் அல்லது தவறுகள் இருக்கலாம் என்பதை கவனத்தில் கொள்ளவும். அசல் ஆவணம் அதன் தாய்மொழியில் அதிகாரப்பூர்வ ஆதாரமாக கருதப்பட வேண்டும். முக்கியமான தகவல்களுக்கு, தொழில்நுட்பமான மனித மொழிபெயர்ப்பு பரிந்துரைக்கப்படுகிறது. இந்த மொழிபெயர்ப்பைப் பயன்படுத்துவதால் ஏற்படும் எந்த தவறான புரிதல்கள் அல்லது தவறான விளக்கத்திற்கும் நாங்கள் பொறுப்பில்வில்லை.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
