# %% [markdown]
# ## அறிமுகம்
#
# இந்த பாடத்தில் நீங்கள் கற்று கொள்ளப்போகிறது:
# - פונקי ஏற்றும் என்ன மற்றும் அதன் பயன்பாடுகள்
# - OpenAI ஐ பயன்படுத்தி ஒரு פונקי கேட்டல் உருவாக்குவது எப்படி
# - פונקי கேட்டலை பயன்பாட்டிற்கு எப்படி இணைக்கலாம்
#
# ## கற்றல் இலக்குகள்
#
# இந்த பாடத்தை முடித்துவிட்டபின் நீங்கள் எப்படி செய்வது மற்றும் புரிந்துகொள்ளப்படும்:
#
# - פונקי கேட்டலை பயன்படுத்தும் நோக்கம்
# - OpenAI சேவையை பயன்படுத்தி פונקי கேட்டலை அமைத்தல்
# - உங்கள் பயன்பாட்டிற்கான פונקי கேட்டல்களை திறமையாக வடிவமைத்தல்

# %% [markdown]
# ## செயல்பாடு கால் செய்துகொள்ளும் புரிதல்
#
# இந்த பாடத்திற்காக, நாங்கள் எங்கள் கல்வி தொடக்கம் நிறுவனத்திற்கு ஒரு அம்சத்தை உருவாக்க விரும்புகிறோம், அது பயனர்களுக்கு தொழில்நுட்ப பாடங்களை கண்டுபிடிக்க ஒரு சாட்பாட்டை பயன்படுத்த அனுமதிக்கும். நாங்கள் அவர்களின் திறன் நிலை, தற்போதைய பணி மற்றும் ஆர்வமான தொழில்நுட்பத்தை பொருத்த பாடங்களை பரிந்துரைக்கப்போவது.
#
# இதை முடிக்க, நாங்கள் கலவையாக பயன்படுத்தப்போவது:
#  - பயனருக்கு ஒரு உரையாடல் அனுபவத்தை உருவாக்க `OpenAI`
#  - பயனரின் கோரிக்கையின் அடிப்படையில் பாடங்களைக் கண்டுபிடிக்க `Microsoft Learn Catalog API`
#  - பயனர் கேள்வியை எடுத்துக் கொண்டு அதனை API கோரிக்கைக்காக ஒரு செயல்பாட்டிற்கு அனுப்ப `Function Calling`
#
# துவங்க, முதலில் நாங்கள் ஏன் செயல்பாடு கால் செய்ய விரும்புவோமோ அதை பார்ப்போம்:

# %% [markdown]
# ### ஏன் செயல்பாட்டு அழைப்பு
#
# நீங்கள் இந்த பாடநெறியில் ஏதேனும் மற்ற பாடம் முடித்து இருந்தால், பெரிய மொழி மாதிரிகள் (LLMs) பயன்படுத்தும் சக்தியை நீங்கள் பொதுவாக புரிந்துகொண்டிருக்கலாம். அதேபோல் அவற்றின் சில வரம்புகளையும் நீங்கள் காண முடியும் என்று நம்புகிறேன்.
#
# செயல்பாட்டு அழைப்பு OpenAI சேவையின் ஒரு அம்சமாகும், இது கீழ்க்காணும் சவாப்புத்தல்களை தீர்க்க வடிவமைக்கப்பட்டுள்ளது:
#
# ஒற்றை மாதிரி பதிலின் வடிவமைப்பு இல்லாமை:
# - செயல்பாட்டு அழைப்புக்கு முன், பெரிய மொழி மாதிரியிலிருந்து பெறும் பதில்கள் அமைப்பு இல்லாதவையாகவும் பொதுவாக மாறுபடும் வகையிலும் இருந்தன. வடிவமைப்பாளர் ஒவ்வொரு பதிலின் மாறுபாட்டிற்கும் சிக்கலான சரிபார்ப்பு கோ드를 எழுத வேண்டியது ஏற்பட்டது.
#
# வெளிப்புற தரவுடன் குறைந்த இணைப்பு:
# - இந்த அம்சத்திற்கு முன்பு, ஒரு செயலியில் உள்ள பிற பகுதிகளிலிருந்தும் தரவை உரையாடல் சூழலில் சேர்ப்பது கடினமாக இருந்தது.
#
# பதில்களின் வடிவங்களை ஒத்திசைத்து வெளிப்புற தரவுடன் தானாக இணைக்கும்படி செயல்பாட்டு அழைப்பு மேம்படுத்தல் எளிமையாக்கி கூடுதல் சரிபார்ப்பு குறியீடு தேவையை குறைத்தது.
#
# பயனர்கள் "ஸ்டாக்ஹோல்மில் தற்போதைய வானிலை என்ன?" போன்ற கேள்விகளுக்கு பதில் பெற முடியவில்லை. காரணம், மாதிரிகள் பயிற்சி பெற்ற தரவு நேரத்திற்கு மட்டுமே வரம்பு ஏற்பட்டது.
#
# இந்த பிரச்சனையை விளக்கும் கீழ்காணும் உதாரணத்தைப் பார்க்கலாம்:
#
# மாணவர் தரவுத்தளத்தை உருவாக்கி அவர்களுக்கு சரியான பாடத்திட்டத்தை பரிந்துரைக்கலாம் என்று நினைக்கிறோம் என வைத்துக்கொள்வோம். கீழே உள்ள இரு மாணவர்களின் விவரங்கள் உள்ளடக்கிய தரவைப் பார்த்தால் அவை மிகவும் ஒத்ததாக உள்ளன.

# %%
student_1_description="Emily Johnson is a sophomore majoring in computer science at Duke University. She has a 3.7 GPA. Emily is an active member of the university's Chess Club and Debate Team. She hopes to pursue a career in software engineering after graduating."
 
student_2_description = "Michael Lee is a sophomore majoring in computer science at Stanford University. He has a 3.8 GPA. Michael is known for his programming skills and is an active member of the university's Robotics Club. He hopes to pursue a career in artificial intelligence after finishing his studies."

# %% [markdown]
# நாங்கள் இந்த தகவலை பகுப்பாய்வு செய்ய LLMக்கு அனுப்ப விரும்புகிறோம். இதைப் பயன்படுத்தி பின்னர் எங்கள் செயலியில் ஒரு APIக்கு அனுப்ப அல்லது தரவுத்தளத்தில் சேமிக்கலாம்.
#
# நாம் கவனம் செலுத்தும் தகவலை LLMக்கு அறிவிக்க இரண்டு அதே மாதிரியான கேள்விகள் உருவாக்குவோம்:

# %% [markdown]
# எங்கள் தயாரிப்புக்கு முக்கியமான பகுதிகளை பகுப்பாய்வு செய்ய ஒரு LLM-க்கு இதைப் பதிவேற்ற விரும்புகிறோம். ஆகவே LLM-ஐ வழிநடத்த இரண்டு அடிப்படையான ப்ராம்ட்களை உருவாக்கலாம்:

# %%
prompt1 = f'''
Please extract the following information from the given text and return it as a JSON object:

name
major
school
grades
club

This is the body of text to extract the information from:
{student_1_description}
'''


prompt2 = f'''
Please extract the following information from the given text and return it as a JSON object:

name
major
school
grades
club

This is the body of text to extract the information from:
{student_2_description}
'''

# %% [markdown]
# இந்த இரண்டு பரிந்துரைகளையும் உருவாக்கிய பிறகு, அவற்றை `client.responses.create` பயன்படுத்தி LLM-க்காக அனுப்புவோம்.  நாம் பரிந்துரையை `input` மாறிலியில் சேமித்து, பங்கு `user` என ஒதுக்குகிறோம். இது ஒரு பயனரின் செய்தி ஒரு சாட்பாட்டுக்கு எழுதப்பட்டிருக்கிறதை ஏற்றுக்கொள்ளும் விதமாகும்.

# %%
import os
import json
from openai import OpenAI
from dotenv import load_dotenv
load_dotenv()

client = OpenAI()

deployment="gpt-5-mini"
# Out:
# Running cells with '/opt/homebrew/bin/python3' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# இப்போது நாம் இரு கோரிக்கைகளையும் LLM க்கு அனுப்பி, கிடைக்கும் பதிலை பரிசீலிக்கலாம்.

# %%
openai_response1 = client.responses.create(
 model=deployment,    
 input = [{'role': 'user', 'content': prompt1}],
 store=False,
)
openai_response1.output_text

# %%
openai_response2 = client.responses.create(
 model=deployment,    
 input = [{'role': 'user', 'content': prompt2}],
 store=False,
)
openai_response2.output_text

# %%
# Loading the response as a JSON object
json_response1 = json.loads(openai_response1.output_text)
json_response1

# %%
# Loading the response as a JSON object
json_response2 = json.loads(openai_response2.output_text)
json_response2

# %% [markdown]
# ஏனெனில், கேள்விகள் ஒரே மாதிரி இருந்தாலும் மற்றும் விளக்கங்கள் ஒத்தவையாக இருந்தாலும், `Grades` பண்புக் கொள்ளப்பட்ட வெவ்வேறு வடிவங்களைப் பெறலாம்.
#
# மேலேயுள்ள செலலை பலமுறை இயக்கினால், வடிவம் `3.7` அல்லது `3.7 GPA` இருக்கலாம்.
#
# இதன் காரணம் LLM எழுதப்பட்ட கேள்வியின் வடிவில் அமைந்தமற்ற தரவை எடுத்துக் கொண்டு, அமைந்தமற்ற தரவே திருப்பி அளிக்கும். எனவே, தரவை சேமிப்பதற்கும் பயன்படுத்துவதற்கும் நாம் எதிர்பார்க்கும் அமைந்த வடிவம் தேவை.
#
# செயல்பாட்டு அழைக்கும் முறையைப் பயன்படுத்தினால், சரியான அமைந்த தரவை பெறுவோம் என்பதை உறுதி செய்யலாம். செயல்பாட்டு அழைப்பை பயன்படுத்தும் போது, LLM உண்மையில் எந்த செயல்பாடுகளையும் அழைக்காது அல்லது இயக்கு மாட்டாது. பதிலளிப்பிற்காக LLM பின்பற்ற ஒரு அமைப்பைப் நாம் உருவாக்குகிறோம். அப்படியான அமைந்த பதில்களைக் கொண்டு, எது செயல்பாட்டை இயக்கு வேண்டும் என்பதை நம் பயன்பாடுகளில் அறிவோம்.

# %% [markdown]
# ![செயல்பாடு அழைப்பு ஓட்ட நோக்கு](../../../../translated_images/ta/Function-Flow.083875364af4f4bb.webp)

# %% [markdown]
# பின்னர் நாம் செயல்பாட்டிலிருந்து திரும்பியுள்ளது எடுக்கலாம் மற்றும் இதை LLMக்கு திருப்பி அனுப்பலாம். அதன் பிறகு LLM இயற்கை மொழியைப் பயன்படுத்தி பயனரின் கேள்விக்கு பதிலளிக்கும்.

# %% [markdown]
# ### செயல்பாட்டு அழைப்புகளை பயன்படுத்துவதற்கான பயன்பாட்டுக் குறிப்புகள்
#
# **வெளிப்புற கருவிகளை அழைத்தல்**
# பயனாளர்களிடமிருந்து கேள்விகளுக்கு பதிலளிப்பதில் சாட்போட்கள் சிறந்தவையாக இருக்கின்றன. செயல்பாட்டு அழைப்பை பயன்படுத்தி, சாட்போட்கள் பயனாளர்களிடமிருந்து பெறும் செய்திகளை பயன்படுத்தி குறிப்பிட்ட பணிகளை நிறைவேற்ற முடியும். உதாரணமாக, ஒரு மாணவர் சாட்போட்டிடம் "இந்தப் பாடத்தில் எனக்கு மேலும் உதவி தேவை என்றும் எனது ஆசிரியருக்கு மின்னஞ்சல் அனுப்பு" என்று கேட்கலாம். இது `send_email(to: string, body: string)` என்ற செயல்பாட்டை அழைக்கலாம்
#
#
# **API அல்லது தரவுத்தள கேள்விகளை உருவாக்குதல்**
# பயனாளர்கள் இயல்பான மொழியைப் பயன்படுத்தி தகவல்களை கண்டுபிடிக்கலாம், இது வடிவமைக்கப்பட்ட கேள்வி அல்லது API கோரிக்கையாக மாற்றப்படும். உதாரணமாக, ஒரு ஆசிரியர் "கடைசி கட்டளை நிறைவேற்றிய மாணவர்கள் யார்?" என்று கேட்கலாம், இது `get_completed(student_name: string, assignment: int, current_status: string)` என்ற செயல்பாட்டை அழைக்கலாம்
#
#
# **கட்டமைக்கப்பட்ட தரவு உருவாக்குதல்**
# பயனாளர்கள் ஒரு உரை தொகுப்பு அல்லது CSV ஐ எடுத்து அதிலிருந்து முக்கியமான தகவல்களை LLM மூலம் எடுக்கலாம். உதாரணமாக, ஒரு மாணவர் சமாதான ஒப்பந்தங்கள் பற்றிய விக்கிப்பீடியா கட்டுரையை மாற்றி AI ஃபிளாஷ் கார்ட்களை உருவாக்கலாம். இது `get_important_facts(agreement_name: string, date_signed: string, parties_involved: list)` என்ற செயல்பாட்டை பயன்படுத்தி செய்யப்படும்

# %% [markdown]
# ## 2. உங்கள் முதல் செயல்பாட்டு அழைப்பை உருவாக்குதல்
#
# செயல்பாட்டு அழைப்பை உருவாக்கும் செயல்முறை மூன்று முக்கிய படிகள் கொண்டது:
# 1. உங்கள் செயல்பாடுகளின் பட்டியல் மற்றும் ஒரு பயனர் செய்தியுடன் Chat Completions API-யை அழைக்குதல்
# 2. செயல்பாடு அல்லது API அழைப்பை இயக்க செயல்முறையை மேற்கொள்ள மாதிரியின் பதிலை வாசித்தல்
# 3. பயனருக்கு பதில் உருவாக்க அந்த தகவலை பயன்படுத்த உங்கள் செயல்பாட்டிலிருந்து வரும் பதிலுடன் மீண்டும் Chat Completions API-யை அழைக்குதல்.

# %% [markdown]
# ![ஒரு செயல்பாட்டுக்கான அழைப்பு தோற்றம்](../../../../translated_images/ta/LLM-Flow.3285ed8caf4796d7.webp)

# %% [markdown]
# ### ஒரு செயல்பாட்டு அழைப்பின் கூறுகள்
#
# #### பயனர் உள்ளீடு
#
# முதலாம் படியாக, பயனர் செய்தியை உருவாக்க வேண்டும். இது உரை உள்ளீட்டின் மதிப்பை எடுத்துக்கொண்டு இயங்குதளம் மூலம் ஒதுக்கப்படலாம் அல்லது நீங்கள் இங்கே ஒரு மதிப்பை ஒதுக்கலாம். இது Chat Completions API உடன் உங்கள் முதன்மை முறையாக இருந்தால், செய்தியின் `role` மற்றும் `content` ஐ வரையறுக்க வேண்டும்.
#
# `role` என்பது `system` (கானூன்களை உருவாக்குதல்), `assistant` (மாதிரி) அல்லது `user` (இறுதி பயன்பாட்டாளர்) ஆகியவற்றுள் எதுவோ இருக்கலாம். செயல்பாட்டு அழைப்புக்காக, நாங்கள் இதை `user` ஆக ஒதுக்கி ஒரு உதாரணக் கேள்வியை கொடுக்க உள்ளோம்.

# %%
messages= [ {"role": "user", "content": "Find me a good course for a beginner student to learn Azure."} ]

# %% [markdown]
# ### செயல்பாடுகளை உருவாக்குதல்.
#
# அடுத்ததாக நாம் ஒரு செயல்பாட்டையும் அந்த செயல்பாட்டின் அளவுருக்களையும் வரையறுக்கவுள்ளோம். இங்கே `search_courses` என்ற ஒரு செயல்பாட்டை மட்டுமே பயன்படுத்தப்போகிறோம் ஆனால் நீங்கள் பல செயல்பாடுகளை உருவாக்கலாம்.
#
# **முக்கியம்** : செயல்பாடுகள் LLM க்கான சிஸ்டம் செய்தியில் சேர்க்கப்பட்டிருக்கும் மற்றும் அவை உங்கள் கிடைக்கும் டோக்கன்களின் அளவில் சேர்க்கப்படும்.

# %%
# The Responses API uses a flat tool format: name/description/parameters at the top level
functions = [
   {
      "type":"function",
      "name":"search_courses",
      "description":"Retrieves courses from the search index based on the parameters provided",
      "parameters":{
         "type":"object",
         "properties":{
            "role":{
               "type":"string",
               "description":"The role of the learner (i.e. developer, data scientist, student, etc.)"
            },
            "product":{
               "type":"string",
               "description":"The product that the lesson is covering (i.e. Azure, Power BI, etc.)"
            },
            "level":{
               "type":"string",
               "description":"The level of experience the learner has prior to taking the course (i.e. beginner, intermediate, advanced)"
            }
         },
         "required":[
            "role"
         ]
      }
   }
]

# %% [markdown]
# **விவரக்குறிப்புகள்**
#
# செயல்பாட்டு வரையறை அமைப்பில் பல நிலைகள் உள்ளன, ஒவ்வொரு நிலைக்கும் தன் சொந்த பண்புகள் உள்ளன. এখানে ஈர்க்கப்பட்ட அமைப்பின் விரிவாக்கம்:
#
# **மேல் நிலை செயல்பாட்டு பண்புகள்:**
#
# `name` - நாம் அழைக்க விரும்பும் செயல்பாட்டின் பெயர்.
#
# `description` - செயல்பாடு எவ்வாறு செயல்படுகிறது என்பது பற்றிய விளக்கம். இங்கு தெளிவாகவும் சிறப்பாகவும் இருக்க வேண்டும்
#
# `parameters` - மாடல் தன்னுடைய பதிலில் உருவாக்க நிலைகளைப் பெற விரும்பும் மதிப்புகளின் பட்டியல் மற்றும் வடிவமைப்பு
#
# **அளவை பொருள் பண்புகள்:**
#
# `type` - அளவை பொருளின் தரவு வகை (பொதுவாக "object")
#
# `properties` - மாடல் தன் பதிலுக்கான பயன்படுத்தும் குறிப்பிட்ட மதிப்புகளின் பட்டியல்
#
# **தனிச்சென்ற அளவை பண்புகள்:**
#
# `name` - பண்புக் குறி மூலம் மறைமுகமாக வரையறுக்கப்பட்டது (உதா., "role", "product", "level")
#
# `type` - இந்த குறிப்பிட்ட அளவையின் தரவு வகை (உதா., "string", "number", "boolean")
#
# `description` - குறிப்பிட்ட அளவையின் விளக்கம்
#
# **விரும்பத்தக்க பண்புகள்:**
#
# `required` - செயல்பாடு அழைக்க முடிக்க தேவையான அளவைகள் பட்டியலிடப்பட்டுள்ளது

# %% [markdown]
# ### செயல்பாட்டு அழைப்பை செய்வது
# ஒரு செயல்பாட்டை வரையறுத்த பிறகு, அதை Chat Completion API க்கு அழைப்பில் சேர்க்க வேண்டும். இதன்படி கோரிக்கைக்கு `functions` ஐ சேர்க்கிறோம். இவ்வாறாக `functions=functions` ஆகும்.
#
# `function_call` ஐ `auto` ஆக அமைக்க விருப்பம் પણ உள்ளது. இதன் பொருள், பயனர் செய்தியின் அடிப்படையில் எந்த செயல்பாடு அழைக்கப்பட வேண்டும் என்பதை நாமே அமைப்பதற்குப் பதிலாக LLM தீர்மானிக்க விடுவோம் என்பது தான்.

# %%
response = client.responses.create(model=deployment, 
                                        input=messages,
                                        tools=functions, 
                                        tool_choice="auto",
                                        store=False) 

print(response.output)

# %% [markdown]
# இப்போது பதிலை பார்ப்போம் மற்றும் அது எவ்வாறு வடிவமைக்கப்பட்டுள்ளது என்பதை பார்ப்போம்:
#
# {
#   "role": "assistant",
#   "function_call": {
#     "name": "search_courses",
#     "arguments": "{\n  \"role\": \"student\",\n  \"product\": \"Azure\",\n  \"level\": \"beginner\"\n}"
#   }
# }
#
# நீங்கள் பார்க்க முடியும், செயல்பாட்டின் பெயர் அழைக்கப்பட்டுள்ளது மற்றும் பயனர் செய்தியிலிருந்து, LLM செயல்பாட்டின் argumentsக்கு ஏற்ப தரவை கண்டுபிடிக்க முடிந்தது.

# %% [markdown]
# ## 3.ஒரு செயலியில் செயல்பாட்டு அழைப்புகளை ஒருங்கிணைத்தல்.
#
#
# LLM இருந்து வரையறுக்கப்பட்ட பதிலை நாம் சோதித்து பார்த்தபோது, இப்போது இதை ஒரு செயலியில் ஒருங்கிணைக்கலாம்.
#
# ### பாய்ச்சலை நிர்வகித்தல்
#
# இதை நமது செயலியில் ஒருங்கிணைக்க, கீழ்கண்ட படிகளை பின்பற்றுவோம்:
#
# முதலில், OpenAI சேவைகளை அழைத்து, செய்தியை `response_message` என்ற மாறியில் சேமிக்கவோம்.

# %%
# Extract the function call items from the response output
tool_calls = [item for item in response.output if item.type == "function_call"]

# %% [markdown]
# இப்போது நாம் Microsoft Learn API ஐ அழைத்து படிப்புகளின் பட்டியலை பெறும் செயல்பாட்டை வரையறுக்கப் போகிறோம்:

# %%
import requests

def search_courses(role, product, level):
    url = "https://learn.microsoft.com/api/catalog/"
    params = {
        "role": role,
        "product": product,
        "level": level
    }
    response = requests.get(url, params=params)
    modules = response.json()["modules"]
    results = []
    for module in modules[:5]:
        title = module["title"]
        url = module["url"]
        results.append({"title": title, "url": url})
    return str(results)

# %% [markdown]
# சிறந்த பழக்கவழக்கமாக, பின்னர் மாதிரி ஒரு செயல்பாட்டை அழைக்க விரும்புகிறதா என்று பார்க்கப்போகிறோம். அதன் பிறகு, கிடைக்கும் செயல்பாடுகளில் ஒன்றை உருவாக்கி அந்த அழைக்கப்படும் செயல்பாட்டிற்கு பொருந்துமாறு பொருந்த வைக்கப்போகிறோம்.
# பின்னர், செயல்பாட்டின் arguments-ஐ எடுத்துக்கொண்டு அவற்றை LLM இன் arguments-க்கு பொருந்த வைக்கப்போகிறோம்.
#
# இறுதியாக, `search_courses` செய்தியால் திரும்பிய மதிப்புகளையும் செயல்பாடு அழைப்புச் செய்தியையும் இணைக்கப்போகிறோம். இது LLM-க்கு பயனருக்கு இயல்பான மொழியில் பதில் அளிக்க தேவையான அனைத்து தகவல்களை வழங்குகிறது.

# %%
# Check if the model wants to call a function
if tool_calls:
    tool_call = tool_calls[0]
    print("Recommended Function call:")
    print(tool_call.name)
    print()

    # Call the function. 
    function_name = tool_call.name

    available_functions = {
            "search_courses": search_courses,
    }
    function_to_call = available_functions[function_name] 

    function_args = json.loads(tool_call.arguments)
    function_response = function_to_call(**function_args)

    print("Output of function call:")
    print(function_response)
    print(type(function_response))


    # Add the model's function call item(s) and our function result to the conversation.
    # The Responses API represents tool results as `function_call_output` items.
    messages.extend(response.output)  # adding the model's function_call item(s)
    messages.append( # adding function response to messages
        {
            "type": "function_call_output",
            "call_id": tool_call.call_id,
            "output": function_response,
        }
    )

# %% [markdown]
# இப்போது நாங்கள் புதுப்பிக்கப்பட்ட செய்தியை LLM க்கு அனுப்பப் போகிறோம், afin API JSON வடிவமைக்கப்பட்ட பதிலுக்கு பதிலாக இயற்கை மொழி பதிலை பெற.

# %%
print("Messages in next request:")
print(messages)
print()

second_response = client.responses.create(
    input=messages,
    model=deployment,
    tools=functions,
    tool_choice="auto",
    store=False,
        )  # get a new response from the model where it can see the function response


print(second_response.output_text)

# %% [markdown]
# ## குறியீட்டு சவால்
#
# சிறந்த வேலை! OpenAI Function Calling கற்றலினை தொடர https://learn.microsoft.com/training/support/catalog-api-developer-reference?WT.mc_id=academic-105485-koreyst என்ற இணையத்தளத்தில் உள்ளவற்றைப் பயன்படுத்தி நீங்கள் உருவாக்கலாம்:
#  - பயனாளிகளுக்குத் தேர்ந்தெடுக்க மேலும் பாடங்களை காண உதவும் செயல்பாட்டின் கூடுதல் அளவுருக்கள். கிடைக்கும் API அளவுருக்களை இங்கே காணலாம்:
#  - பயனர் மொழி போன்ற கூடுதல் தகவல்களை எடுத்துக்கொள்ள ஒரு வேறு செயல்பாட்டுக் கோரலை உருவாக்கவும்
#  - செயல்பாட்டுக் கோரல் மற்றும்/அல்லது API கோரல் எந்ததொரு பொருத்தமான பாடங்களையும் திருப்பாமையைக் கண்டறிந்து பிழை கையாளல் செய்யவும்

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **மறுப்பு**:
# இந்த ஆவணம் AI மொழிபெயர்ப்பு சேவை [Co-op Translator](https://github.com/Azure/co-op-translator) பயன்படுத்தி மொழிபெயர்க்கப்பட்டுள்ளது. நாங்கள் துல்லியத்திற்காக முயற்சி செய்துள்ளோம், ஆனால் தானாக செய்யப்படும் மொழிபெயர்ப்புகளில் பிழைகள் அல்லது தவறுகள் இருக்கலாம் என்பதை கவனத்தில் கொள்ளவும். அசல் ஆவணம் அதன் தாய்மொழியில் அதிகாரப்பூர்வ ஆதாரமாக கருதப்பட வேண்டும். முக்கியமான தகவல்களுக்கு, தொழில்நுட்பமான மனித மொழிபெயர்ப்பு பரிந்துரைக்கப்படுகிறது. இந்த மொழிபெயர்ப்பைப் பயன்படுத்துவதால் ஏற்படும் எந்த தவறான புரிதல்கள் அல்லது தவறான விளக்கத்திற்கும் நாங்கள் பொறுப்பில்வில்லை.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
