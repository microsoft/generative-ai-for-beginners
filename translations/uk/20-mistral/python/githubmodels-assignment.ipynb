# %% [markdown]
# # Робота з моделями Mistral
#
# ## Вступ
#
# У цьому уроці буде розглянуто:
# - Ознайомлення з різними моделями Mistral
# - Розуміння варіантів використання та сценаріїв для кожної моделі
# - Приклади коду, що демонструють унікальні особливості кожної моделі.

# %% [markdown]
# ## Моделі Mistral
#
# У цьому уроці ми розглянемо 3 різні моделі Mistral:
# **Mistral Large**, **Mistral Small** та **Mistral Nemo**.
#
# Кожна з цих моделей доступна безкоштовно на [Microsoft Foundry Models](https://ai.azure.com/catalog/models?WT.mc_id=academic-105485-koreyst). Код у цій блокноті використовуватиме ці моделі для виконання коду.
#
# > **Примітка:** GitHub Models припиняє роботу наприкінці липня 2026 року. Ось більше деталей щодо використання [Microsoft Foundry Models](https://learn.microsoft.com/en-us/azure/ai-foundry/model-inference/overview?WT.mc_id=academic-105485-koreyst) для прототипування з AI-моделями.

# %% [markdown]
# ## Mistral Large 2 (2407)
# Mistral Large 2 наразі є флагманською моделлю від Mistral та призначена для корпоративного використання.
#
# Ця модель є покращенням оригінальної Mistral Large, пропонуючи:
# -  Більше вікно контексту — 128k проти 32k
# -  Кращу продуктивність у математичних та кодувальних завданнях — 76,9% середньої точності проти 60,4%
# -  Підвищену багатомовну продуктивність — мови включають: англійську, французьку, німецьку, іспанську, італійську, португальську, нідерландську, російську, китайську, японську, корейську, арабську та хінді.
#
# Завдяки цим характеристикам Mistral Large відмінно підходить для:
# - *Розширеного генерації з пошуком (Retrieval Augmented Generation, RAG)* — завдяки більшому вікну контексту
# - *Виклику функцій* — ця модель має вбудований виклик функцій, що дозволяє інтегруватися з зовнішніми інструментами та API. Ці виклики можуть виконуватись як паралельно, так і послідовно один за одним.
# - *Генерації коду* — ця модель відмінно справляється з генерацією Python, Java, TypeScript та C++.

# %% [markdown]
# ### Приклад RAG з використанням Mistral Large 2

# %% [markdown]
# У цьому прикладі ми використовуємо Mistral Large 2 для запуску патерну RAG над текстовим документом. Запитання написане корейською мовою і стосується діяльності автора до університету.
#
# Для створення вбудованих представлень текстового документа та запитання використовується модель Cohere Embeddings. Для цього прикладу використовується пакет faiss Python як векторне сховище.
#
# Запит, надісланий до моделі Mistral, включає як запитання, так і отримані фрагменти, схожі на запитання. Модель тоді надає відповідь природною мовою.

# %%
pip install faiss-cpu
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
import numpy as np
import faiss
import os

from azure.ai.inference import ChatCompletionsClient
from azure.ai.inference.models import SystemMessage, UserMessage
from azure.core.credentials import AzureKeyCredential
from azure.ai.inference import EmbeddingsClient

# Get these from your Microsoft Foundry project's "Overview" page
endpoint = os.environ["AZURE_INFERENCE_ENDPOINT"]
model_name = "Mistral-large"
token = os.environ["AZURE_INFERENCE_CREDENTIAL"]

client = ChatCompletionsClient(
    endpoint=endpoint,
    credential=AzureKeyCredential(token),
)

response = requests.get('https://raw.githubusercontent.com/run-llama/llama_index/main/docs/docs/examples/data/paul_graham/paul_graham_essay.txt')
text = response.text

chunk_size = 2048
chunks = [text[i:i + chunk_size] for i in range(0, len(text), chunk_size)]
len(chunks)

embed_model_name = "cohere-embed-v3-multilingual" 

embed_client = EmbeddingsClient(
        endpoint=endpoint,
        credential=AzureKeyCredential(token)
)

embed_response = embed_client.embed(
    input=chunks,
    model=embed_model_name
)



text_embeddings = []
for item in embed_response.data:
    length = len(item.embedding)
    text_embeddings.append(item.embedding)
text_embeddings = np.array(text_embeddings)


d = text_embeddings.shape[1]
index = faiss.IndexFlatL2(d)
index.add(text_embeddings)

question = "저자가 대학에 오기 전에 주로 했던 두 가지 일은 무엇이었나요?？"

question_embedding = embed_client.embed(
    input=[question],
    model=embed_model_name
)

question_embeddings = np.array(question_embedding.data[0].embedding)


D, I = index.search(question_embeddings.reshape(1, -1), k=2) # distance, index
retrieved_chunks = [chunks[i] for i in I.tolist()[0]]

prompt = f"""
Context information is below.
---------------------
{retrieved_chunks}
---------------------
Given the context information and not prior knowledge, answer the query.
Query: {question}
Answer:
"""


chat_response = client.complete(
    messages=[
        SystemMessage(content="You are a helpful assistant."),
        UserMessage(content=prompt),
    ],
    temperature=1.0,
    top_p=1.0,
    max_tokens=1000,
    model=model_name
)

print(chat_response.choices[0].message.content)
# Out:
# The author primarily engaged in two activities before college: writing and programming. In terms of writing, they wrote short stories, albeit not very good ones, with minimal plot and characters expressing strong feelings. For programming, they started writing programs on the IBM 1401 used for data processing during their 9th grade, at the age of 13 or 14. They used an early version of Fortran and typed programs on punch cards, later loading them into the card reader to run the program.

# %% [markdown]
# ## Mistral Small
# Mistral Small — це ще одна модель у сімействі моделей Mistral у категорії premier/enterprise. Як випливає з назви, ця модель є маленькою мовною моделлю (SLM). Переваги використання Mistral Small полягають у тому, що вона:
# - Економія коштів порівняно з Mistral LLM, такими як Mistral Large і NeMo — зниження вартості на 80%
# - Низька затримка — швидша відповідь у порівнянні з LLM від Mistral
# - Гнучкість — може бути розгорнута в різних середовищах із меншими обмеженнями на необхідні ресурси.
#
#
# Mistral Small чудово підходить для:
# - Завдань на основі тексту, таких як узагальнення, аналіз настроїв і переклад.
# - Застосунків, де часто надходять запити завдяки її економічності
# - Завдань з низькою затримкою, пов’язаних із кодом, таких як рев’ю та пропозиції щодо коду

# %% [markdown]
# ## Порівняння Mistral Small і Mistral Large
#
# Щоб показати різницю в затримці між Mistral Small і Large, запустіть наведені нижче блоки.
#
# Ви маєте побачити різницю у часі відповіді від 3 до 5 секунд. Також зверніть увагу на довжину та стиль відповіді на однаковий запит.

# %%
import os 
endpoint = os.environ["AZURE_INFERENCE_ENDPOINT"]
model_name = "Mistral-small"
token = os.environ["AZURE_INFERENCE_CREDENTIAL"]

client = ChatCompletionsClient(
    endpoint=endpoint,
    credential=AzureKeyCredential(token),
)

response = client.complete(
    messages=[
        SystemMessage(content="You are a helpful coding assistant."),
        UserMessage(content="Can you write a Python function to the fizz buzz test?"),
    ],
    temperature=1.0,
    top_p=1.0,
    max_tokens=1000,
    model=model_name
)

print(response.choices[0].message.content)

# %%
import os
from azure.ai.inference import ChatCompletionsClient
from azure.ai.inference.models import SystemMessage, UserMessage
from azure.core.credentials import AzureKeyCredential

endpoint = os.environ["AZURE_INFERENCE_ENDPOINT"]
model_name = "Mistral-large"
token = os.environ["AZURE_INFERENCE_CREDENTIAL"]

client = ChatCompletionsClient(
    endpoint=endpoint,
    credential=AzureKeyCredential(token),
)

response = client.complete(
    messages=[
        SystemMessage(content="You are a helpful coding assistant."),
        UserMessage(content="Can you write a Python function to the fizz buzz test?"),
    ],
    temperature=1.0,
    top_p=1.0,
    max_tokens=1000,
    model=model_name
)

print(response.choices[0].message.content)

# %% [markdown]
# ## Mistral NeMo
#
# Порівняно з іншими двома моделями, обговореними в цьому уроці, Mistral NeMo є єдиною безкоштовною моделлю з ліцензією Apache2.
#
# Її розглядають як оновлення до попередньої відкритої моделі LLM від Mistral, Mistral 7B.
#
# Деякі інші особливості моделі NeMo:
#
# - *Більш ефективна токенізація:* Ця модель використовує токенізатор Tekken замість більш поширеного tiktoken. Це дозволяє покращити продуктивність для більшої кількості мов та коду.
#
# - *Додаткове налаштування (finetuning):* Базова модель доступна для донавчання. Це забезпечує більшу гнучкість для випадків використання, де може знадобитися донавчання.
#
# - *Рідний виклик функцій (Native Function Calling)* - Як і Mistral Large, ця модель була навчена на виклики функцій. Це робить її унікальною, оскільки вона одна з перших відкритих моделей, що це підтримує.

# %% [markdown]
# ## Mistral NeMo
#
# Порівняно з іншими двома моделями, розглянутими в цьому уроці, Mistral NeMo — єдина безкоштовна модель з ліцензією Apache2.
#
# Вона вважається оновленням попередньої відкритої моделі від Mistral, Mistral 7B.
#
# Деякі інші особливості моделі NeMo:
#
# - *Більш ефективна токенізація:* Ця модель використовує токенізатор Tekken замість більш поширеного tiktoken. Це забезпечує кращу продуктивність для більшої кількості мов та коду.
#
# - *Фінетюнінг:* Базова модель доступна для фінетюнінгу. Це дає змогу більшої гнучкості у випадках, коли потрібен фінетюнінг.
#
# - *Нативний виклик функцій* — Як і Mistral Large, ця модель була навчена на викликах функцій. Це робить її унікальною як одну з перших відкритих моделей, які це підтримують.

# %% [markdown]
# ### Порівняння токенізаторів
#
# У цьому прикладі ми розглянемо, як Mistral NeMo справляється з токенізацією в порівнянні з Mistral Large.
#
# Обидва приклади використовують однаковий запит, але ви повинні помітити, що NeMo повертає менше токенів порівняно з Mistral Large.

# %%
pip install mistral-common
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 63.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 19.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 16.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 797.0/797.0 kB 15.1 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import needed packages:
from mistral_common.protocol.instruct.messages import (
    UserMessage,
)
from mistral_common.protocol.instruct.request import ChatCompletionRequest
from mistral_common.protocol.instruct.tool_calls import (
    Function,
    Tool,
)
from mistral_common.tokens.tokenizers.mistral import MistralTokenizer

# Load Mistral tokenizer

model_name = "open-mistral-nemo	"

tokenizer = MistralTokenizer.from_model(model_name)

# Tokenize a list of messages
tokenized = tokenizer.encode_chat_completion(
    ChatCompletionRequest(
        tools=[
            Tool(
                function=Function(
                    name="get_current_weather",
                    description="Get the current weather",
                    parameters={
                        "type": "object",
                        "properties": {
                            "location": {
                                "type": "string",
                                "description": "The city and state, e.g. San Francisco, CA",
                            },
                            "format": {
                                "type": "string",
                                "enum": ["celsius", "fahrenheit"],
                                "description": "The temperature unit to use. Infer this from the users location.",
                            },
                        },
                        "required": ["location", "format"],
                    },
                )
            )
        ],
        messages=[
            UserMessage(content="What's the weather like today in Paris"),
        ],
        model=model_name,
    )
)
tokens, text = tokenized.tokens, tokenized.text

# Count the number of tokens
print(len(tokens))
# Out:
# 128

# %%
# Import needed packages:
from mistral_common.protocol.instruct.messages import (
    UserMessage,
)
from mistral_common.protocol.instruct.request import ChatCompletionRequest
from mistral_common.protocol.instruct.tool_calls import (
    Function,
    Tool,
)
from mistral_common.tokens.tokenizers.mistral import MistralTokenizer

# Load Mistral tokenizer

model_name = "mistral-large-latest"

tokenizer = MistralTokenizer.from_model(model_name)

# Tokenize a list of messages
tokenized = tokenizer.encode_chat_completion(
    ChatCompletionRequest(
        tools=[
            Tool(
                function=Function(
                    name="get_current_weather",
                    description="Get the current weather",
                    parameters={
                        "type": "object",
                        "properties": {
                            "location": {
                                "type": "string",
                                "description": "The city and state, e.g. San Francisco, CA",
                            },
                            "format": {
                                "type": "string",
                                "enum": ["celsius", "fahrenheit"],
                                "description": "The temperature unit to use. Infer this from the users location.",
                            },
                        },
                        "required": ["location", "format"],
                    },
                )
            )
        ],
        messages=[
            UserMessage(content="What's the weather like today in Paris"),
        ],
        model=model_name,
    )
)
tokens, text = tokenized.tokens, tokenized.text

# Count the number of tokens
print(len(tokens))
# Out:
# 135

# %% [markdown]
# ## Навчання на цьому не завершується, продовжуйте подорож
#
# Після завершення цього уроку перегляньте нашу [колекцію навчання з генеративного ШІ](https://aka.ms/genai-collection?WT.mc_id=academic-105485-koreyst), щоб продовжити підвищувати свої знання про генеративний ШІ!

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Відмова від відповідальності**:
# Цей документ було перекладено за допомогою сервісу штучного інтелекту для перекладу [Co-op Translator](https://github.com/Azure/co-op-translator). Хоча ми прагнемо до точності, будь ласка, майте на увазі, що автоматичні переклади можуть містити помилки або неточності. Оригінальний документ рідною мовою слід вважати авторитетним джерелом. Для критично важливої інформації рекомендується професійний людський переклад. Ми не несемо відповідальності за будь-які непорозуміння або неправильні тлумачення, що виникли внаслідок використання цього перекладу.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
