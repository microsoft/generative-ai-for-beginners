# %% [markdown]
# ಕೆಳಗಿನ ನೋಟ್‌ಬುಕ್ GitHub Copilot Chat ಮೂಲಕ ಸ್ವಯಂಚಾಲಿತವಾಗಿ ರಚಿತವಾಗಿದ್ದು, ಪ್ರಾಥಮಿಕ ವ್ಯವಸ್ಥಾಪನೆಗಾಗಿ ಮಾತ್ರ ಉದ್ದೇಶಿಸಲಾಗಿದೆ

# %% [markdown]
# # ಸೂಚನೆ ಇಂಜಿನಿಯರಿಂಗ್ ಪರಿಚಯ
# ಸೂಚನೆ ಇಂಜಿನಿಯರಿಂಗ್ ಎಂಬುದು ಸ್ವಭಾವಿಕ ಭಾಷಾ ಪ್ರಕ್ರಿಯೆ ಕುರಿತ ಕಾರ್ಯಗಳಿಗೆ ಸೂಚನೆಗಳನ್ನು ವಿನ್ಯಾಸಗೊಳಿಸುವುದು ಮತ್ತು ಸುಧಾರಿಸುವ ಪ್ರಕ್ರಿಯೆಯಾಗಿದ್ದು, ಸರಿಯಾದ ಸೂಚನೆಗಳನ್ನು ಆಯ್ಕೆ ಮಾಡುವುದು, ಅವುಗಳ ಪರಿಮಾಣಗಳನ್ನು ಹೊಂದಾಣಿಕೆಗೊಳಿಸುವುದು ಮತ್ತು ಅವುಗಳ ಕಾರ್ಯಕ್ಷಮತೆಯನ್ನು ಮೌಲ್ಯಮಾಪನ ಮಾಡುವುದು ಜೊತೆಗೆ ಇರುತ್ತದೆ. ಸೂಚನೆ ಇಂಜಿನಿಯರಿಂಗ್ NLP ಮಾದರಿಗಳಲ್ಲಿ ಉನ್ನತ ಸರಿಯಾದತೆ ಮತ್ತು ಪರಿಣಾಮಕಾರಿತೆಯನ್ನು ಸಾಧಿಸಲು ಅತ್ಯಂತ ಪ್ರಮುಖವಾಗಿದೆ. ಈ ವಿಭಾಗದಲ್ಲಿ, ಎಕ್ಸ್ಪ್ಲೊೋಷನ್ ಗೆ OpenAI ಮಾದರಿಗಳನ್ನು ಉಪಯೋಗಿಸಿ ಸೂಚನೆ ಇಂಜಿನಿಯರಿಂಗ್ ಮೂಲಭೂತ ವಿಷಯಗಳನ್ನು ಪರಿಶೀಲಿಸುವೆವು.

# %% [markdown]
# ### ಅಭ್ಯಾಸ 1: ಟೋಕನೈಸೇಶನ್
# tiktoken ಬಳಸಿ ಟೋಕನೈಸೇಶನ್ ಅನ್ನು ಅನ್ವೇಷಿಸಿ, OpenAI ಯಿಂದ ಓಪನ್-ಸೋರ್ಸ್ ವೇಗದ ಟೋಕನೈಸರ್
# ಇನ್ನಷ್ಟು ಉದಾಹರಣೆಗಳಿಗೆ [OpenAI ಕುಕ್‌ಬುಕ್](https://github.com/openai/openai-cookbook/blob/main/examples/How_to_count_tokens_with_tiktoken.ipynb?WT.mc_id=academic-105485-koreyst) ನೋಡಿ.

# %%
# EXERCISE:
# 1. Run the exercise as is first
# 2. Change the text to any prompt input you want to use & re-run to see tokens

import tiktoken

# Define the prompt you want tokenized
text = f"""
Jupiter is the fifth planet from the Sun and the \
largest in the Solar System. It is a gas giant with \
a mass one-thousandth that of the Sun, but two-and-a-half \
times that of all the other planets in the Solar System combined. \
Jupiter is one of the brightest objects visible to the naked eye \
in the night sky, and has been known to ancient civilizations since \
before recorded history. It is named after the Roman god Jupiter.[19] \
When viewed from Earth, Jupiter can be bright enough for its reflected \
light to cast visible shadows,[20] and is on average the third-brightest \
natural object in the night sky after the Moon and Venus.
"""

# Set the model you want encoding for
encoding = tiktoken.encoding_for_model("gpt-4o")

# Encode the text - gives you the tokens in integer form
tokens = encoding.encode(text)
print(tokens);

# Decode the integers to see what the text versions look like
[encoding.decode_single_token_bytes(token) for token in tokens]

# %% [markdown]
# ### ವ್ಯಾಯಾಮ 2: OpenAI API ಕಿ ಸೆಟಪ್ ಪರಿಶೀಲಿಸಿ
#
# ನಿಮ್ಮ OpenAI ಸಂಪರ್ಕವು ಸರಿಯಾಗಿ ಸೆಟ್‌ಅಪ್ ಆಗಿದ್ದು ಎಂದು ಪರಿಶೀಲಿಸಲು ಕೆಳಗಿನ ಕೋಡ್ ಅನ್ನು ರನ್ ಮಾಡಿ. ಕೋಡ್ ಸರಳ ಮೂಲ ಪ್ರಾಂಪ್ಟ್ ಅನ್ನು ಪ್ರಯತ್ನಿಸಿ ಪೂರ್ಣಗೊಳಿಸುವಿಕೆಯನ್ನು ಮಾನ್ಯಗೊಳಿಸುತ್ತದೆ. ಇನ್‌ಪುಟ್ `oh say can you see` ಆಗಿದ್ದು `by the dawn's early light..` ಎಂಬ ರೀತಿಯಲ್ಲಿ ಪೂರ್ಣಗೊಳ್ಳಬೇಕು.

# %%
# Uses the OpenAI client against the Azure OpenAI (Microsoft Foundry) v1 endpoint
# with the Responses API. See https://aka.ms/openai/start

import os
from openai import OpenAI
from dotenv import load_dotenv
load_dotenv()

client = OpenAI(
  api_key=os.environ['AZURE_OPENAI_API_KEY'],
  base_url=f"{os.environ['AZURE_OPENAI_ENDPOINT'].rstrip('/')}/openai/v1/",
  )

deployment=os.environ['AZURE_OPENAI_DEPLOYMENT']

def get_completion(prompt):
    response = client.responses.create(
        model=deployment,
        input=prompt,
        temperature=0, # this is the degree of randomness of the model's output
        max_output_tokens=1024,
        store=False,
    )
    return response.output_text

## ---------- Call the helper method

### 1. Set primary content or prompt text
text = f"""
oh say can you see
"""

### 2. Use that in the prompt template below
prompt = f"""
```{text}```
"""

## 3. Run the prompt
response = get_completion(prompt)
print(response)

# %% [markdown]
# ### ವ್ಯಾಯಾಮ 3: ಕಲ್ಪನೆಗಳು
# ಲ್ಲಂಗೆ ಅಸ್ತಿತ್ವದಲ್ಲಿರದ ಅಥವಾ ಅದರ ಪೂರ್ವ-ಪ್ರಶಿಕ್ಷಿತ ಡೇಟಾಸೆಟ್ (ಇತ್ತೀಚಿನ) ಹೊರಗೆಯಾದ ವಿಷಯಗಳ ಬಗ್ಗೆ ಪೂರ್ಣಗೊಳಿಸುವಿಕೆಗಳಿಗೆ ಕೇಳುವಾಗ ಏನು ಸಂಭವಿಸುತ್ತದೆ ಎಂದು ಅನ್ವೇಷಿಸಿ. ನೀವು ವಿಭಿನ್ನ ಪ್ರಾಂಪ್ಟ್ ಅಥವಾ ವಿಭಿನ್ನ ಮಾದರಿಯನ್ನು ಪ್ರಯತ್ನಿಸಿದಾಗ ಪ್ರತಿಕ್ರಿಯೆ ಬದಲಾಗುವುದು ಹೇಗೆ ಎಂಬುದನ್ನು ನೋಡಿ.

# %%
## Set the text for simple prompt or primary content
## Prompt shows a template format with text in it - add cues, commands etc if needed
## Run the completion 
text = f"""
generate a lesson plan on the Martian War of 2076.
"""

prompt = f"""
```{text}```
"""

response = get_completion(prompt)
print(response)

# %% [markdown]
# ### ಅಭ್ಯಾಸ 4: ಸೂಚನೆ ಆಧಾರಿತ
# ಪ್ರಾಥಮಿಕ ವಿಷಯವನ್ನು ಸೆಟ್ ಮಾಡಲು "text" variable ಬಳಸಿ
# ಮತ್ತು ಆ ಪ್ರಾಥಮಿಕ ವಿಷಯಕ್ಕೆ ಸಂಬಂಧಿಸಿದಂತೆ ಸೂಚನೆ ನೀಡಲು "prompt" variable ಬಳಸಿ.
#
# ಇಲ್ಲಿ ನಾವು ಮಾದರಿಯನ್ನು ಎರಡನೇ ತರಗತಿಯ ವಿದ್ಯಾರ್ಥಿಗಾಗಿ ಪಠ್ಯವನ್ನು ಸಂಕ್ಷಿಪ್ತಗೊಳಿಸಲು ಕೇಳುತ್ತಿದ್ದೇವೆ

# %%
# Test Example
# https://platform.openai.com/playground/p/default-summarize

## Example text
text = f"""
Jupiter is the fifth planet from the Sun and the \
largest in the Solar System. It is a gas giant with \
a mass one-thousandth that of the Sun, but two-and-a-half \
times that of all the other planets in the Solar System combined. \
Jupiter is one of the brightest objects visible to the naked eye \
in the night sky, and has been known to ancient civilizations since \
before recorded history. It is named after the Roman god Jupiter.[19] \
When viewed from Earth, Jupiter can be bright enough for its reflected \
light to cast visible shadows,[20] and is on average the third-brightest \
natural object in the night sky after the Moon and Venus.
"""

## Set the prompt
prompt = f"""
Summarize content you are provided with for a second-grade student.
```{text}```
"""

## Run the prompt
response = get_completion(prompt)
print(response)

# %% [markdown]
# ### ವ್ಯಾಯಾಮ 5: ಸಂಕೀರ್ಣ ಪ್ರಾಂಪ್ಟ್
# ಸಿಸ್ಟಮ್, ಬಳಕೆದಾರ ಮತ್ತು ಸಹಾಯಕ ಸಂದೇಶಗಳಿರುವ ವಿನಂತಿಯನ್ನು ಪ್ರಯತ್ನಿಸಿ
# ಸಿಸ್ಟಮ್ ಸಹಾಯಕ ಸಾಂದರ್ಭಿಕವನ್ನು ಹೊಂದಿಸುತ್ತದೆ
# ಬಳಕೆದಾರ ಮತ್ತು ಸಹಾಯಕ ಸಂದೇಶಗಳು ಬಹು-ತಲುಪಿದ ಸಂಭಾಷಣೆ ಸಾಂದರ್ಭಿಕವನ್ನು ಒದಗಿಸುತ್ತವೆ
#
# ಸಹಾಯಕರ ವ್ಯಕ್ತಿತ್ವವನ್ನು ಸಿಸ್ಟಮ್ ಸಾಂದರ್ಭಿಕದಲ್ಲಿ "ವ್ಯಂಗ್ಯಾತ್ಮಕ" ಎಂದು ಹೇಗೆ ಹೊಂದಿಸಲಾಗುತ್ತದೆ ಎಂದು ಗಮನಿಸಿ.
# ವಿಭಿನ್ನ ವ್ಯಕ್ತಿತ್ವ ಸಾಂದರ್ಭಿಕವನ್ನು ಪ್ರಯತ್ನಿಸಿ. ಅಥವಾ ಇನ್ಪುಟ್/ಔಟ್‌ಪುಟ್ ಸಂದೇಶಗಳ ವಿಭಿನ್ನ ಸರಣಿಯನ್ನು ಪ್ರಯತ್ನಿಸಿ

# %%
response = client.responses.create(
    model=deployment,
    input=[
        {"role": "system", "content": "You are a sarcastic assistant."},
        {"role": "user", "content": "Who won the world series in 2020?"},
        {"role": "assistant", "content": "Who do you think won? The Los Angeles Dodgers of course."},
        {"role": "user", "content": "Where was it played?"}
    ],
    store=False,
)
print(response.output_text)

# %% [markdown]
# ### ವ್ಯಾಯಾಮ: ನಿಮ್ಮ ಸಾಮಾಜಿಕ ಬುದ್ಧಿಮತ್ತೆಯನ್ನು ಅನ್ವೇಷಿಸಿ
# ಮೇಲಿನ ಉದಾಹರಣೆಗಳು ನಿಮಗೆ ಹೊಸ ಪ್ರಾಂಪ್ಟ್ಗಳನ್ನು (ಸರಳ, ಸಂಕೀರ್ಣ, ನಿರ್ದೇಶನ ಇತ್ಯಾದಿ) ರಚಿಸಲು ಬಳಕೆ ಮಾಡಬಹುದಾದ ಮಾದರಿಗಳನ್ನು ನೀಡುತ್ತವೆ - ಉದಾಹರಣೆಗಳು, ಸೂಚನೆಗಳು ಮತ್ತು ಇನ್ನಷ್ಟು ಬಗ್ಗೆ ನಾವು ಚರ್ಚಿಸಿದ ಕೆಲವು ಇತರ ಆಲೋಚನೆಗಳನ್ನು ಅನ್ವೇಷಿಸಲು ಇತರ ವ್ಯಾಯಾಮಗಳನ್ನು ರಚಿಸುವ ಪ್ರಯತ್ನಿಸಿ.

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **ಅಸ್ವೀಕಾರ**:
# ಈ ದಸ್ತಾವೇಜು AI ಅನುವಾದ ಸೇವೆ [Co-op Translator](https://github.com/Azure/co-op-translator) ಬಳಸಿ ಅನುವಾದಿಸಲಾಗಿದೆ. ನಾವು ನಿಖರತೆಯನ್ನು ಸಾಧಿಸಲು ಪ್ರಯತ್ನಿಸುತ್ತಿದ್ದರೂ, ದಯವಿಟ್ಟು ಗಮನಿಸಿ, ಸ್ವಯಂಚಾಲಿತ ಅನುವಾದಗಳಲ್ಲಿ ದೋಷಗಳು ಅಥವಾ ಅಸಡ್ಡೆಗಳು ಇರಬಹುದು. ಮೂಲ ಭಾಷೆಯಲ್ಲಿರುವ ಮೂಲ ದಸ್ತಾವೇಜು ಪ್ರಾಮಾಣಿಕ ಮೂಲವೆಂದು ಪರಿಗಣಿಸಬೇಕು. ಪ್ರಮುಖ ಮಾಹಿತಿಗಾಗಿ, ವೃತ್ತಿಪರ ಮಾನವ ಅನುವಾದವನ್ನು ಶಿಫಾರಸು ಮಾಡಲಾಗುತ್ತದೆ. ಈ ಅನುವಾದವನ್ನು ಬಳಸುವ ಮೂಲಕ ಉಂಟಾಗುವ ಯಾವುದೇ ತಪ್ಪು ಅರ್ಥಗಳ ಅಥವಾ ತಪ್ಪು ವ್ಯಾಖ್ಯಾನಗಳ ಬಗ್ಗೆ ನಾವು ಹೊಣೆಗಾರರಲ್ಲ.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
