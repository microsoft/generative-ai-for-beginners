# %% [markdown]
# Следната тетрадка беше автоматично генерирана от GitHub Copilot Chat и е предназначена само за първоначална настройка

# %% [markdown]
# # Въведение в проектирането на подканите
# Проектирането на подканите е процес на създаване и оптимизиране на подканите за задачи за обработка на естествен език. Той включва избора на правилните подканите, настройването на техните параметри и оценяването на тяхната ефективност. Проектирането на подканите е от съществено значение за постигане на висока точност и ефективност при модели за обработка на естествен език. В този раздел ще разгледаме основите на проектирането на подканите, използвайки моделите на OpenAI за изследване.

# %% [markdown]
# ### Упражнение 1: Токенизация
# Изследвайте Токенизацията, използвайки tiktoken, бърз токенизатор с отворен код от OpenAI
# Вижте [OpenAI Cookbook](https://github.com/openai/openai-cookbook/blob/main/examples/How_to_count_tokens_with_tiktoken.ipynb?WT.mc_id=academic-105485-koreyst) за повече примери.

# %%
# EXERCISE:
# 1. Run the exercise as is first
# 2. Change the text to any prompt input you want to use & re-run to see tokens

import tiktoken

# Define the prompt you want tokenized
text = f"""
Jupiter is the fifth planet from the Sun and the \
largest in the Solar System. It is a gas giant with \
a mass one-thousandth that of the Sun, but two-and-a-half \
times that of all the other planets in the Solar System combined. \
Jupiter is one of the brightest objects visible to the naked eye \
in the night sky, and has been known to ancient civilizations since \
before recorded history. It is named after the Roman god Jupiter.[19] \
When viewed from Earth, Jupiter can be bright enough for its reflected \
light to cast visible shadows,[20] and is on average the third-brightest \
natural object in the night sky after the Moon and Venus.
"""

# Set the model you want encoding for
encoding = tiktoken.encoding_for_model("gpt-4o")

# Encode the text - gives you the tokens in integer form
tokens = encoding.encode(text)
print(tokens);

# Decode the integers to see what the text versions look like
[encoding.decode_single_token_bytes(token) for token in tokens]

# %% [markdown]
# ### Упражнение 2: Потвърдете настройката на OpenAI API ключ
#
# Стартирайте кода по-долу, за да проверите дали вашата OpenAI крайна точка е настроена правилно. Кодът просто опитва проста основна заявка и валидира получения резултат. Входът `oh say can you see` трябва да бъде завършен с нещо от рода на `by the dawn's early light..`

# %%
# Uses the OpenAI client against the Azure OpenAI (Microsoft Foundry) v1 endpoint
# with the Responses API. See https://aka.ms/openai/start

import os
from openai import OpenAI
from dotenv import load_dotenv
load_dotenv()

client = OpenAI(
  api_key=os.environ['AZURE_OPENAI_API_KEY'],
  base_url=f"{os.environ['AZURE_OPENAI_ENDPOINT'].rstrip('/')}/openai/v1/",
  )

deployment=os.environ['AZURE_OPENAI_DEPLOYMENT']

def get_completion(prompt):
    response = client.responses.create(
        model=deployment,
        input=prompt,
        max_output_tokens=1024,
        store=False,
    )
    return response.output_text

## ---------- Call the helper method

### 1. Set primary content or prompt text
text = f"""
oh say can you see
"""

### 2. Use that in the prompt template below
prompt = f"""
```{text}```
"""

## 3. Run the prompt
response = get_completion(prompt)
print(response)

# %% [markdown]
# ### Упражнение 3: Измислици
# Изследвайте какво се случва, когато помолите LLM да върне допълнения за подсказка по тема, която може да не съществува, или по теми, за които може да не знае, тъй като са извън предварително обучаващия му набор от данни (по-нови). Вижте как се променя отговорът, ако опитате различна подсказка или различен модел.

# %%
## Set the text for simple prompt or primary content
## Prompt shows a template format with text in it - add cues, commands etc if needed
## Run the completion 
text = f"""
generate a lesson plan on the Martian War of 2076.
"""

prompt = f"""
```{text}```
"""

response = get_completion(prompt)
print(response)

# %% [markdown]
# ### Упражнение 4: Базирано на инструкции
# Използвайте променливата "text", за да зададете основното съдържание
# и променливата "prompt", за да предоставите инструкция, свързана с това основно съдържание.
#
# Тук молим модела да обобщи текста за ученик във втори клас

# %%
# Test Example
# https://platform.openai.com/playground/p/default-summarize

## Example text
text = f"""
Jupiter is the fifth planet from the Sun and the \
largest in the Solar System. It is a gas giant with \
a mass one-thousandth that of the Sun, but two-and-a-half \
times that of all the other planets in the Solar System combined. \
Jupiter is one of the brightest objects visible to the naked eye \
in the night sky, and has been known to ancient civilizations since \
before recorded history. It is named after the Roman god Jupiter.[19] \
When viewed from Earth, Jupiter can be bright enough for its reflected \
light to cast visible shadows,[20] and is on average the third-brightest \
natural object in the night sky after the Moon and Venus.
"""

## Set the prompt
prompt = f"""
Summarize content you are provided with for a second-grade student.
```{text}```
"""

## Run the prompt
response = get_completion(prompt)
print(response)

# %% [markdown]
# ### Упражнение 5: Комплексна заявка
# Опитайте заявка, която включва системни, потребителски и съобщения от асистента
# Системата задава контекста на асистента
# Потребителските и асистентските съобщения предоставят контекст за многократен диалог
#
# Обърнете внимание как личността на асистента е зададена като "саркастична" в системния контекст.
# Опитайте да използвате различна контекстна личност. Или опитайте различна серия от входни/изходни съобщения

# %%
response = client.responses.create(
    model=deployment,
    input=[
        {"role": "system", "content": "You are a sarcastic assistant."},
        {"role": "user", "content": "Who won the world series in 2020?"},
        {"role": "assistant", "content": "Who do you think won? The Los Angeles Dodgers of course."},
        {"role": "user", "content": "Where was it played?"}
    ],
    store=False,
)
print(response.output_text)

# %% [markdown]
# ### Упражнение: Изследвайте своята интуиция
# Горните примери ви предоставят шаблони, които можете да използвате, за да създавате нови запитвания (прости, сложни, инструкции и т.н.) - опитайте да създадете други упражнения, за да изследвате някои от другите идеи, за които сме говорили, като примери, подсказки и още.

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Отказ от отговорност**:
# Този документ е преведен с помощта на AI преводачески услуга [Co-op Translator](https://github.com/Azure/co-op-translator). Въпреки че се стремим към точност, моля имайте предвид, че автоматизираните преводи могат да съдържат грешки или неточности. Оригиналният документ на неговия роден език трябва да се счита за авторитетен източник. За критична информация се препоръчва професионален човешки превод. Ние не носим отговорност за каквито и да е недоразумения или неправилни тълкувания, произтичащи от използването на този превод.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
