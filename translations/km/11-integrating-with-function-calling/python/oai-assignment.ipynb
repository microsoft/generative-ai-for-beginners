# %% [markdown]
# ## Introduction
#
# មេរៀននេះនឹងគ្របដណ្តប់៖
# - ផលប្រយោជន៍នៃការហៅមុខងារ និងករណីការប្រើប្រាស់របស់វា
# - របៀបបង្កើតការហៅមុខងារ ប្រើប្រាស់ OpenAI
# - របៀបបញ្ចូលការហៅមុខងារចូលក្នុងកម្មវិធីមួយ
#
# ## Learning Goals
#
# បន្ទាប់ពីបញ្ចប់មេរៀននេះ អ្នកនឹងដឹង និងយល់ដឹងអំពី៖
#
# - វិធីប្រើប្រាស់ការហៅមុខងារ
# - ការតំឡើងការហៅមុខងារ ប្រើប្រាស់សេវាកម្ម OpenAI
# - រចនាបែបការហៅមុខងារដែលមានប្រសិទ្ធភាពសម្រាប់ករណីការប្រើប្រាស់កម្មវិធីរបស់អ្នក

# %% [markdown]
# ## ការយល់ដឹងអំពីការហៅមុខងារ
#
# សម្រាប់មេរៀននេះ យើងចង់បង្កើតមុខងារសម្រាប់ស្តាតអាប់អមហិរញ្ញវត្ថុការអប់រំនេះ ដែលអនុញ្ញាតឲ្យអ្នកប្រើប្រាស់ប្រើប្រាស់ប៉ុស្តិ៍សន្ទនាដើម្បីស្វែងរកវគ្គបច្ចេកទេស។ យើងនឹងផ្ដល់អនុសាសន៍វគ្គសិក្សាដែលសមរម្យនឹងកម្រិតជំនាញ តួនាទីបច្ចុប្បន្ន និងបច្ចេកវិទ្យាដែលព្រមចិត្ត។
#
# ដើម្បីបញ្ចប់បន្តិចនេះ យើងនឹងប្រើប្រាស់ការរួមបញ្ចូល:
#  - `OpenAI` ដើម្បីបង្កើតបទពិសោធន៍សន្ទនា​សម្រាប់អ្នកប្រើប្រាស់
#  - `Microsoft Learn Catalog API` ដើម្បីជួយអ្នកប្រើស្វែងរកវគ្គការសិក្សាដោយផ្អែកលើការសំណើរបស់អ្នកប្រើ
#  - `Function Calling` ដើម្បីយកសំណួររបស់អ្នកប្រើ និងផ្ញើទៅមុខងារមួយដើម្បីធ្វើសំណើ API។
#
# ដើម្បីចាប់ផ្តើម អ្នកត្រូវមើលថា ហេតុអ្វីបានជាយើងចង់ប្រើការហៅមុខងារនៅដំបូង៖
#
# print("សារ​នៅក្នុងសំណើបន្ទាប់:")
# print(messages)
# print()
#
# second_response = client.chat.completions.create(
#     messages=messages,
#     model=deployment,
#     function_call="auto",
#     functions=functions,
#     temperature=0
#         )  # ទទួលបានចម្លើយថ្មីពី GPT ដែលអាចឃើញការឆ្លើយតបពីមុខងារ
#
#
# print(second_response.choices[0].message)

# %% [markdown]
# ### ហេតុអ្វីបានជា Function Calling
#
# បើអ្នកបានបញ្ចប់មេរៀនណាមួយផ្សេងទៀតនៅក្នុងវគ្គនេះ អ្នកប្រហែលជាធ្លាប់យល់ពីកម្លាំងនៃការប្រើប្រាស់ម៉ូឌែលភាសាធំនៅ (LLMs)។ សង្ឃឹមថាអ្នកក៏អាចមើលឃើញកំលាំងខ្សោយខ្លះៗរបស់ពួកម៉ូដែលទាំងនោះផងដែរ។
#
# Function Calling គឺជាមុខងារមួយនៃសេវាអ្នកផ្តល់ដោយ OpenAI ដែលរចនាឡើងដើម្បីដោះស្រាយបញ្ហាក្រោមខាងក្រោម៖
#
# ការរៀបចំអត្ថបទអត្រាប្រាលពីគ្នា៖
# - មុនពេលប្រើ function calling ព្យាយាមមួយពីម៉ូឌែលភាសាធំបានផ្តល់ចម្លើយមិនមានរចនាសម្ព័ន្ធ និងមិនដូចគ្នាទេ។ អ្នកអភិវឌ្ឍន៍ត្រូវតែសរសេរកូដផ្ទៀងផ្ទាត់ស្មុគស្មាញដើម្បីដោះស្រាយការប្រែប្រួលនៃចំណុចចេញ។
#
# ការចូលរួមខ្សោយជាមួយទិន្នន័យខាងក្រៅ៖
# - មុននឹងមានមុខងារនេះ វាយ៉ាងហោចណាស់ក្នុងការចូលរួមទិន្នន័យពីផ្នែកផ្សេងៗនៃកម្មវិធីទៅក្នុងបរិបទកិច្ចសន្ទនា។
#
# ដោយសារតែការមានរចនាបទការឆ្លើយតបស្ដង់ដារ និងអនុញ្ញាតឱ្យបញ្ចូលទិន្នន័យខាងក្រៅបានយ៉ាងរលូន, function calling ធ្វើអោយការអភិវឌ្ឍន៍កាន់តែងាយស្រួល និងកាត់បន្ថយការត្រូវការកូដផ្ទៀងផ្ទាត់បន្ថែម។
#
# អ្នកប្រើមិនអាចទទួលបានចម្លើយដូចជា "អាកាសធាតុបច្ចុប្បន្ននៅ Stockholm ជានរណា?" ទេ។ នេះគឺដោយសារម៉ូឌែលមានការកំណត់លើពេលវេលាដែលទិន្នន័យត្រូវបានបណ្តុះបណ្តាល។
#
# មកមើលឧទាហរណ៍ខាងក្រោមដែលបង្ហាញពីបញ្ហានេះ៖
#
# សន្មត់ថាយើងចង់បង្កើតមូលដ្ឋានទិន្នន័យសិស្ស ដើម្បីយើងអាចផ្ដល់ដល់ពួកគេច្បាប់វគ្គសិក្សាដែលត្រូវបានត្រឹមត្រូវ។ ខាងក្រោមនេះយើងមានការពិពណ៌នាពីសិស្សពីរនាក់ដែលមានទិន្នន័យស្រដៀងគ្នាជាច្រើន។

# %%
student_1_description="Emily Johnson is a sophomore majoring in computer science at Duke University. She has a 3.7 GPA. Emily is an active member of the university's Chess Club and Debate Team. She hopes to pursue a career in software engineering after graduating."
 
student_2_description = "Michael Lee is a sophomore majoring in computer science at Stanford University. He has a 3.8 GPA. Michael is known for his programming skills and is an active member of the university's Robotics Club. He hopes to pursue a career in artificial intelligence after finishing his studies."

# %% [markdown]
# យើងចង់ផ្ញើររឿងនេះទៅ LLM ដើម្បីបកស្រាយទិន្នន័យ។ វាអាចត្រូវបានប្រើនៅក្រោយនេះក្នុងកម្មវិធីរបស់យើង ដើម្បីផ្ញើទៅ API ឬផ្ទុកវាទុកនៅក្នុងមូលដ្ឋានទិន្នន័យ។
#
# មកបង្កើតសំណើពីរដូចគ្នា ដែលយើងផ្តល់ការណែនាំដល់ LLM ថាតើព័ត៌មានណាដែលយើងចាប់អារម្មណ៍៖

# %% [markdown]
# យើងចង់ផ្ញើនេះទៅកាន់ LLM ដើម្បីបំបែកផ្នែកដែលសំខាន់ចំពោះផលិតផលរបស់យើង។ ដូច្នេះយើងអាចបង្កើតការបញ្ចូលបញ្ហាមួយចំនួនដូចគ្នាពីរដើម្បីណែនាំ LLM៖

# %%
prompt1 = f'''
Please extract the following information from the given text and return it as a JSON object:

name
major
school
grades
club

This is the body of text to extract the information from:
{student_1_description}
'''


prompt2 = f'''
Please extract the following information from the given text and return it as a JSON object:

name
major
school
grades
club

This is the body of text to extract the information from:
{student_2_description}
'''

# %% [markdown]
# បន្ទាប់ពីបង្កើតសំណួរទាំងពីរនេះ រួចយើងនឹងផ្ញើវាទៅកាន់ LLM ដោយប្រើ `openai.ChatCompletion`។ យើងរក្សាទុកសំណួរនៅក្នុងអថេរ `messages` ហើយផ្ដល់តួនាទីជា `user`។ វាត្រូវបានធ្វើឡើងដើម្បីគំនូសនូវសារមួយពីអ្នកប្រើដែលកំពុងសរសេរទៅកាន់ chatbot។

# %%
import os
import json
from openai import OpenAI
from dotenv import load_dotenv
load_dotenv()

client = OpenAI()

deployment="gpt-3.5-turbo"
# Out:
# Running cells with '/opt/homebrew/bin/python3' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ឥឡូវនេះយើងអាចផ្ញើសំណើទាំងពីរទៅកាន់ LLM ហើយពិនិត្យមើលចម្លើយដែលយើងទទួលបាន។

# %%
openai_response1 = client.chat.completions.create(
 model=deployment,    
 messages = [{'role': 'user', 'content': prompt1}]
)
openai_response1.choices[0].message.content

# %%
openai_response2 = client.chat.completions.create(
 model=deployment,    
 messages = [{'role': 'user', 'content': prompt2}]
)
openai_response2.choices[0].message.content

# %%
# Loading the response as a JSON object
json_response1 = json.loads(openai_response1.choices[0].message.content)
json_response1

# %%
# Loading the response as a JSON object
json_response2 = json.loads(openai_response2.choices[0].message.content )
json_response2

# %% [markdown]
# បើទោះបីជាការបញ្ចូលសំណួរនិងការពិពណ៌នាដូចគ្នាក៏ដោយ យើងអាចទទួលបានទ្រង់ទ្រាយផ្សេងៗនៃគុណលក្ខណៈ `Grades` ។
#
# បើអ្នករត់កំណត់បន្ទាត់ខាងលើជាអនុಕ್ರಮច្រើនដង ទ្រង់ទ្រាយអាចមានជា `3.7` ឬ `3.7 GPA` ។
#
# នេះគឺព្រោះ LLM ថែមទាំងទទួលទិន្នន័យដែលមិនមានរចនាសម្ព័ន្ធនៅក្នុងទម្រង់នៃសំណួរដែលបានសរសេរ ហើយត្រឡប់មកតែម្តងទិន្នន័យដែលមិនមានរចនាសម្ព័ន្ធផងដែរ។ យើងត្រូវការទ្រង់ទ្រាយដែលមានរចនាសម្ព័ន្ធ ដូច្នេះយើងអាចដឹងថាត្រូវរំពឹងអ្វីពេលផ្ទុកឬប្រើទិន្នន័យនេះ។
#
# ដោយប្រើការហៅអនុគមន៍ យើងអាចធានាថាយើងទទួលបានទិន្នន័យដែលមានរចនាសម្ព័ន្ធត្រឡប់មកវិញ។ ពេលប្រើការហៅអនុគមន៍ LLM មិនមែនពិតជាហៅឬដំណើរការអនុគមន៍ណាមួយឡើយ។ ថ្នាក់វិស្វករយើងបង្កើតរចនាសម្ព័ន្ធសម្រាប់ឲ្យ LLM ធ្វើតាមសម្រាប់ចម្លើយរបស់វា។ បន្ទាប់មកយើងប្រើចម្លើយដែលមានរចនាសម្ព័ន្ធនោះដើម្បីដឹងថាតើត្រូវដំណើរការ function ណាមួយនៅក្នុងកម្មវិធីរបស់យើង។

# %% [markdown]
# ![ចរាចរណ៍ហៅមុខងារ](../../../../translated_images/km/Function-Flow.083875364af4f4bb.webp)

# %% [markdown]
# បន្ទាប់មកយើងអាចយកអ្វីដែលត្រឡប់មកពីមុខងារនិងផ្ញើវាទៅវិញទៅកាន់ LLM ។ LLM នឹងឆ្លើយតបដោយប្រើភាសាធម្មជាតិ ដើម្បីឆ្លើយសំណួររបស់អ្នកប្រើ។

# %% [markdown]
# ### ប្រើ​ករណី​សម្រាប់ការហៅមុខងារ
#
# **ការហៅឧបករណ៍ខាងក្រៅ**
# អ្នកនិយាយជជែកមានភាពអស្ចារ្យក្នុងការផ្តល់ចម្លើយទៅសំណួរពីអ្នកប្រើ។ ដោយប្រើការហៅមុខងារ អ្នកនិយាយជជែកអាចប្រើសារពីអ្នកប្រើដើម្បីបញ្ចប់ភារកិច្ចជាក់លាក់មួយចំនួន។ ឧទាហរណ៍ សិស្សអាចសុំឲ្យអ្នកនិយាយជជែក "ផ្ញើអ៊ីមែលទៅគ្រូបង្រៀនរបស់ខ្ញុំថាខ្ញុំត្រូវការជំនួយបន្ថែមជាមួយមុខវិជ្ជានេះ"។ នេះអាចធ្វើការហៅមុខងារ `send_email(to: string, body: string)`
#
# **បង្កើតសំណួរប្រព័ន្ធ API ឬមូលដ្ឋានទិន្នន័យ**
# អ្នកប្រើអាចស្វែងរកព័ត៌មានដោយប្រើភាសា​ធម្មជាតិដែលត្រូវបានបំលែងទៅជាសំណួរដែលមានរចនាសម្ព័ន្ធ ឬសំណើ API។ ឧទាហរណ៍នេះអាចជាគ្រូបង្រៀនដែលស្នើសុំ "នរណាខ្លះជានិស្សិតដែលបានបញ្ចប់ភារកិច្ចចុងក្រោយ" ដែលអាចហៅមុខងារដោយឈ្មោះ `get_completed(student_name: string, assignment: int, current_status: string)`
#
# **បង្កើតទិន្នន័យដែលមានរចនាសម្ព័ន្ធ**
# អ្នកប្រើអាចយកសំណុំអត្ថបទ ឬ CSV មួយហើយប្រើ LLM ដើម្បីដកព័ត៌មានសំខាន់ៗចេញពីវា។ ឧទាហរណ៍ សិស្សអាចបម្លែងអត្ថបទវិគីភីឌានេះអំពីកិច្ចព្រមព្រៀងសន្តិភាព ដើម្បីបង្កើតកាតបង្ហាញ AI ។ នេះអាចធ្វើបានដោយប្រើមុខងារ `get_important_facts(agreement_name: string, date_signed: string, parties_involved: list)`

# %% [markdown]
# ## 2. បង្កើតការហៅមុខងារដំបូងរបស់អ្នក
#
# ដំណើរការបង្កើតការហៅមុខងាររួមមានជំហានមូលដ្ឋាន 3 ៖
# 1. ហៅ API Chat Completions ជាមួយបញ្ជីមុខងាររបស់អ្នក និងសាររបស់អ្នកប្រើ
# 2. អានការឆ្លើយតបរបស់ម៉ូឌែលដើម្បីអនុវត្តន៍សកម្មភាព ឧទាហរណ៍ ដំណើរមុខងារ ឬហៅ API
# 3. ធ្វើការហៅម្តងទៀតទៅ API Chat Completions ជាមួយពត៌មានពីមុខងាររបស់អ្នក ដើម្បីប្រើប្រាស់ពត៌មាននោះក្នុងការបង្កើតការឆ្លើយតបទៅអ្នកប្រើ។

# %% [markdown]
# ![សៀលនៃការហៅមុខងារ](../../../../translated_images/km/LLM-Flow.3285ed8caf4796d7.webp)

# %% [markdown]
# ### ធាតុទាំងឡាយនៃការហៅមុខងារ
#
# #### ការបញ្ចូលរបស់អ្នកប្រើប្រាស់
#
# ជំហ៊ានដំបូងគឺការបង្កើតសាររបស់អ្នកប្រើប្រាស់។ វាអាចត្រូវបានបញ្ជូនតម្លៃដោយស្វ័យប្រវត្តិដោយយកតម្លៃនៃការបញ្ចូលអត្ថបទ ឬអ្នកអាចបញ្ជូនតម្លៃនៅទីនេះ។ ប្រសិនបើនេះជាលើកដំបូងអ្នកធ្វើការជាមួយ Chat Completions API យើងត្រូវកំណត់ `role` និង `content` នៃសារ។
#
# `role` អាចជាទាំង `system` (បង្កើតច្បាប់), `assistant` (ម៉ូដែល) ឬ `user` (អ្នកប្រើប្រាស់ចុងក្រោយ)។ សម្រាប់ការហៅមុខងារ យើងនឹងកំណត់វាជា `user` និងសំណួរឧទាហរណ៍មួយ។

# %%
messages= [ {"role": "user", "content": "Find me a good course for a beginner student to learn Azure."} ]

# %% [markdown]
# ### ការបង្កើតមុខងារ។
#
# បន្ទាប់មកយើងនឹងកំណត់មុខងារមួយ និងប៉ារ៉ាម៉ែត្រនៃមុខងារនោះ។ យើងនឹងប្រើមុខងារតែមួយនៅទីនេះដែលហៅថា `search_courses` ប៉ុន្តែអ្នកអាចបង្កើតមុខងារច្រើនបាន។
#
# **សំខាន់** : មុខងារត្រូវបានបញ្ចូលក្នុងសារ​ប្រព័ន្ធទៅកាន់ LLM ហើយនឹងត្រូវបានរាប់បញ្ចូលក្នុងចំនួនតូកែនដែលអ្នកមានស្រាប់។

# %%
functions = [
   {
      "name":"search_courses",
      "description":"Retrieves courses from the search index based on the parameters provided",
      "parameters":{
         "type":"object",
         "properties":{
            "role":{
               "type":"string",
               "description":"The role of the learner (i.e. developer, data scientist, student, etc.)"
            },
            "product":{
               "type":"string",
               "description":"The product that the lesson is covering (i.e. Azure, Power BI, etc.)"
            },
            "level":{
               "type":"string",
               "description":"The level of experience the learner has prior to taking the course (i.e. beginner, intermediate, advanced)"
            }
         },
         "required":[
            "role"
         ]
      }
   }
]

# %% [markdown]
# **និយមន័យ**
#
# រចនាសម្ព័ន្ធការកំណត់សិទ្ធិមុខងារមានជាន់ច្រើន សម្រាប់មុខងារនីមួយៗ មានលក្ខណៈផ្ទាល់ខ្លួន។ ខាងក្រោមនេះជា​ចំណែកនៃរចនាសម្ព័ន្ធបណ្ដល់គ្នា៖
#
# **លក្ខណៈផ្ទាល់ខ្លួនលំដាប់លើសម្រាប់មុខងារ៖**
#
# `name` - ឈ្មោះនៃមុខងារ ដែលយើងចង់ឱ្យហៅ។
#
# `description` - នេះជាពណ៌នាអំពីរបៀបដែលមុខងារនេះដំណើរការ។ នៅទីនេះវាសំខាន់ក្នុងការជាក់លាក់និងច្បាស់លាស់។
#
# `parameters` - បញ្ជីតម្លៃនិងទ្រង់ទ្រាយដែលអ្នកចង់ឱ្យម៉ូដែលផលិតក្នុងចម្លើយរបស់វា។
#
# **លក្ខណៈផ្ទាល់ខ្លួនវត្ថុ Parameters៖**
#
# `type` - ប្រភេទទិន្នន័យនៃវត្ថុ parameters (សម្រាប់ភាគច្រើនគឺ "object")
#
# `properties` - បញ្ជីតម្លៃជាក់លាក់ដែលម៉ូដែលនឹងប្រើសម្រាប់ចម្លើយរបស់វា។
#
# **លក្ខណៈផ្ទាល់ខ្លួនគ្រឿងបញ្ជាក់ផ្ទាល់ខ្លួន៖**
#
# `name` - កំណត់ដោយផ្ទាល់តាមគន្លងលក្ខណៈ (ឧ. "role", "product", "level")
#
# `type` - ប្រភេទទិន្នន័យនៃគ្រឿងបញ្ជាក់នេះជាក់លាក់ (ឧ. "string", "number", "boolean")
#
# `description` - ពណ៌នាអំពីគ្រឿងបញ្ជាក់ជាក់លាក់នេះ។
#
# **លក្ខណៈជាជម្រើស៖**
#
# `required` - តារាងត់បញ្ជីគ្រឿងបញ្ជាក់ណាខ្លះដែលត្រូវការសម្រាប់ហៅមុខងារឱ្យបានបញ្ចប់។

# %% [markdown]
# ### ការហៅមុខងារ
# បន្ទាប់ពីកំណត់មុខងារ រួច ឥឡូវនេះយើងត្រូវបញ្ចូលវាទៅក្នុងការហៅ API ការបញ្ចប់ជជែក។ យើងធ្វើនេះដោយបន្ថែម `functions` ទៅកាន់សំណើ។ ក្នុងករណីនេះ `functions=functions`។
#
# មានជម្រើសមួយទៀតដើម្បីកំណត់ `function_call` ទៅជា `auto`។ នេះមានន័យថាយើងនឹងអនុញ្ញាតឲ្យ LLM សម្រេចថាតើមុខងារណាដែលគួរត្រូវបានហៅ dựa trên សារ​អ្នកប្រើប្រាស់ ជាជំនួសការផ្ដល់តួនាទីដោយខ្លួនឯង។

# %%
response = client.chat.completions.create(model=deployment, 
                                        messages=messages,
                                        functions=functions, 
                                        function_call="auto") 

print(response.choices[0].message)

# %% [markdown]
# ឥឡូវនេះយើងចង់មើលការឆ្លើយតបនោះ ហើយសូមមើលពីរបៀបដែលវាត្រូវបានរៀបចំបង្ហាញ៖
#
# {
#   "role": "assistant",
#   "function_call": {
#     "name": "search_courses",
#     "arguments": "{\n  \"role\": \"student\",\n  \"product\": \"Azure\",\n  \"level\": \"beginner\"\n}"
#   }
# }
#
# អ្នកអាចឃើញថា ឈ្មោះមុខងារត្រូវបានហៅ ហើយពីសាររបស់អ្នកប្រើប្រាស់ LLM អាចរកឃើញទិន្នន័យដើម្បីផ្គូផ្គងជាមួយអនុវត្តន៍នៃមុខងារ។

# %% [markdown]
# ## 3.ការរួមបញ្ចូលការហៅមុខងារចូលទៅក្នុងកម្មវិធី។
#
#
# បន្ទាប់ពីយើងបានសាកល្បងចម្លើយដែលបានរៀបចំពី LLM រួចហើយ ឥឡូវនេះយើងអាចបញ្ចូលវាទៅក្នុងកម្មវិធីមួយ។
#
# ### ការគ្រប់គ្រងលំនាំ
#
# ដើម្បីបញ្ចូលវាទៅក្នុងកម្មវិធីរបស់យើង តោះយើងធ្វើជំហានដូចខាងក្រោម៖
#
# ជំហានដំបូង តោះជំពូកហៅទៅសេវាកម្ម OpenAI ហើយរក្សាសារ​នោះ ក្នុងអថេរ​ដែលមានឈ្មោះថា `response_message`។

# %%
response_message = response.choices[0].message

# %% [markdown]
# ឥឡូវនេះយើងនឹងកំណត់អនុគមន៍ដែលនឹងហៅ API Microsoft Learn ដើម្បីទទួលបានបញ្ជីវគ្គសិក្សា៖

# %%
import requests

def search_courses(role, product, level):
    url = "https://learn.microsoft.com/api/catalog/"
    params = {
        "role": role,
        "product": product,
        "level": level
    }
    response = requests.get(url, params=params)
    modules = response.json()["modules"]
    results = []
    for module in modules[:5]:
        title = module["title"]
        url = module["url"]
        results.append({"title": title, "url": url})
    return str(results)

# %% [markdown]
# ជាការអនុវត្តដ៏ល្អបំផុត យើងនឹងពិនិត្យមើលថា ម៉ូដែលចង់ហៅមុខងារមួយទេ ដោយបន្ទាប់ពីនោះ យើងនឹងបង្កើតមុខងារមួយដែលមានស្រាប់ ហើយផ្គូផ្គងវានឹងមុខងារដែលត្រូវបានហៅ។
# បន្ទាប់មក យើងនឹងយកអាគុយម៉ង់ទាំងអស់នៃមុខងារនោះ ហើយផ្គូផ្គងវាទៅកាន់អាគុយម៉ង់ពី LLM។
#
# ចុងក្រោយ យើងនឹងបន្ថែមសារហៅមុខងារ និងតម្លៃដែលត្រូវបានត្រឡប់មកវិញដោយសារណ៍ `search_courses`។ វានេះផ្តល់ឲ្យ LLM នូវព័ត៌មានទាំងអស់ដែលវាត្រូវការ ដើម្បីឆ្លើយតបនឹងអ្នកប្រើប្រាស់ជាភាសាប្រពៃណី។

# %%
# Check if the model wants to call a function
if response_message.function_call.name:
    print("Recommended Function call:")
    print(response_message.function_call.name)
    print()

    # Call the function. 
    function_name = response_message.function_call.name

    available_functions = {
            "search_courses": search_courses,
    }
    function_to_call = available_functions[function_name] 

    function_args = json.loads(response_message.function_call.arguments)
    function_response = function_to_call(**function_args)

    print("Output of function call:")
    print(function_response)
    print(type(function_response))


    # Add the assistant response and function response to the messages
    messages.append( # adding assistant response to messages
        {
            "role": response_message.role,
            "function_call": {
                "name": function_name,
                "arguments": response_message.function_call.arguments,
            },
            "content": None
        }
    )
    messages.append( # adding function response to messages
        {
            "role": "function",
            "name": function_name,
            "content":function_response,
        }
    )

# %% [markdown]
# ឥឡូវនេះយើងនឹងផ្ញើសារដែលបានបន្ទាន់សម័យទៅកាន់ LLM ដើម្បីយើងអាចទទួលបានចម្លើយជាភាសាប្រពៃណីជំនួសការឆ្លើយតបជារចនាសម្ព័ន្ធ JSON API។

# %%
print("Messages in next request:")
print(messages)
print()

second_response = client.chat.completions.create(
    messages=messages,
    model=deployment,
    function_call="auto",
    functions=functions,
    temperature=0
        )  # get a new response from GPT where it can see the function response


print(second_response.choices[0].message)

# %% [markdown]
# ## Code Challenge
#
# ការងារល្អ! ដើម្បីបន្តការសិក្សារបស់អ្នកអំពីការហៅមុខងារ OpenAI អ្នកអាចសាងសង់: https://learn.microsoft.com/training/support/catalog-api-developer-reference?WT.mc_id=academic-105485-koreyst
#  - ពារម៉ែត្រផ្សេងទៀតនៃមុខងារដែលអាចជួយអ្នកសិក្សាស្វែងរកវគ្គបណ្តុះបណ្តាលបន្ថែម។ អ្នកអាចស្វែងរកពារម៉ែត្រ API ដែលមាននៅទីនេះ:
#  - បង្កើតការហៅមុខងារផ្សេងទៀតដែលយកព័ត៌មានបន្ថែមពីអ្នកសិក្សាដូចជาทាសែមូលដ្ឋានរបស់ពួកគេ
#  - បង្កើតការដោះស្រាយកំហុស នៅពេលដែលការហៅមុខងារ និង/ឬការហៅ API មិនតបត្រឡប់វគ្គសិក្សាដែលសមស្របណាមួយមកវិញ

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **ការបដិសេធ**៖
# ឯកសារនេះត្រូវបានបកប្រែដោយប្រើសេវាកម្មបកប្រែ AI [Co-op Translator](https://github.com/Azure/co-op-translator)។ ខណៈពេលដែលយើងខំប្រឹងប្រែងសម្រាប់ភាពត្រឹមត្រូវ សូមយកចិត្តទុកដាក់ថាការបកប្រែដោយស្វ័យប្រវត្តិអាចមានកំហុស ឬភាពមិនច្បាស់លាស់ខ្លះ។ ឯកសារដើមនៅក្នុងភាសាមាតុភាសាគួរត្រូវបានគេរក្សាទុកជាឯកសារមូលដ្ឋានដែលមានអំណាច។ សម្រាប់ព័ត៌មានចាំបាច់ សូមផ្តល់អនុសាសន៍អោយប្រើការបកប្រែដោយមនុស្សវិជ្ជាជីវៈ។ យើងមិនទទួលខុសត្រូវចំពោះការយល់ច្រឡំ ឬការបកប្រែខុសណាមួយដែលកើតមានពីការប្រើប្រាស់ការបកប្រែនេះឡើយ។
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
