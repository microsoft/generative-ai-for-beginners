# %% [markdown]
# # ផ្នែកទី 7៖ ការបង្កើតកម្មវិធីជជែក
# ## ការចាប់ផ្តើមរហ័សជាមួយ OpenAI API
#
# កំណត់ត្រានេះត្រូវបានបំលែងពី [ឃ្លាំងគំរូ Azure OpenAI](https://github.com/Azure/azure-openai-samples?WT.mc_id=academic-105485-koreyst) ដែលមានកំណត់ត្រាដែលចូលដំណើរការ [Azure OpenAI](notebook-azure-openai.ipynb) សេវាកម្ម។
#
# Python OpenAI API សម្រុកជាមួយម៉ូដែល Azure OpenAI ផងដែរ ជាមួយការផ្លាស់ប្ដូរតិចតួច។ សូមរៀនបន្ថែមអំពីភាពខុសគ្នានៅទីនេះ៖ [របៀបផ្លាស់ប្ដូររវាង OpenAI និង Azure OpenAI endpoints ជាមួយ Python](https://learn.microsoft.com/azure/ai-services/openai/how-to/switching-endpoints?WT.mc_id=academic-109527-jasmineg)

# %% [markdown]
# # គណនា​សង្ខេ​ប
# "ម៉ូដែលភាសាធំ​ជាអនុគមន៍​ដែលបត់បញ្ជូន​អក្សរទៅជាអក្សរ។ បើមានខ្សែក្រវ៉ាត់​អក្សរបញ្ចូលមួយ ម៉ូដែលភាសាធំ​នឹងព្យាយាមទាយអក្សរដែលនឹងមកបន្ទាប់"(1)។ សៀវភៅកំណត់ត្រា "quickstart" នេះនឹងណែនាំអ្នកប្រើអំពីគំនិត LLM នៅកម្រិតខ្ពស់ តម្រូវការបញ្ចូលការដំឡើងកញ្ចប់សំខាន់សម្រាប់ចាប់ផ្តើមជាមួយ AML ការណែនាំទាបៗអំពីការរចនាបង្ហាញ និងឧទាហរណ៍ខ្លីៗជាច្រើននៃករណីប្រើប្រាស់ផ្សេងៗ។

# %% [markdown]
# ## សេវាកម្មមេរៀន
#
# [ទិដ្ឋភាពទូទៅ](#overview)
# [របៀបប្រើប្រាស់សេវាកម្ម OpenAI](#how-to-use-openai-service)
# [1. បង្កើតសេវាកម្ម OpenAI របស់អ្នក](#1.-creating-your-openai-service)
# [2. ការដំឡើង](#2.-installation)
# [3. គ្រឿងបញ្ជាក់](#3.-credentials)
#
# [ករណីប្រើប្រាស់](#use-cases)
# [1. សង្ខេបទំរៀប](#1.-summarize-text)
# [2. ចាត់ថ្នាក់អត្ថបទ](#2.-classify-text)
# [3. បង្កើតឈ្មោះផលិតផលថ្មី](#3.-generate-new-product-names)
# [4. បង្វឹកកថាខណ្ឌដើម្បីចាត់ថ្នាក់](#4.fine-tune-a-classifier)
#
# [យោង](#references)

# %% [markdown]
# ### សាងសង់សំណើរដំបូងរបស់អ្នក
# ការអនុវត្តខ្លីនេះនឹងផ្តល់ការណែនាំមូលដ្ឋានសម្រាប់ដាក់សំណើរទៅម៉ូដែល OpenAI សម្រាប់បេសកកម្មសាមញ្ញ "សង្ខេប".
#
#
# **ជំហាន**:
# 1. ដំឡើងបណ្ណាល័យ OpenAI នៅក្នុងបរិស្ថាន python របស់អ្នក
# 2. ផ្ទុកបណ្ណាល័យជំនួយស្តង់ដារនិងកំណត់សេវាសុវត្ថិភាព OpenAI ធម្មតារបស់អ្នកសម្រាប់សេវាកម្ម OpenAI ដែលអ្នកបានបង្កើត
# 3. ជ្រើសម៉ូដែលសម្រាប់បេសកកម្មរបស់អ្នក
# 4. បង្កើតសំណើសាមញ្ញសម្រាប់ម៉ូដែល
# 5. ដាក់សំណើរបស់អ្នកទៅ API ម៉ូដែល!

# %% [markdown]
# ### 1. ដំឡើង OpenAI

# %%
# %pip install openai python-dotenv

# %% [markdown]
# ### 2. អញ្ចឹញបណ្ណាល័យជំនួយ និង បង្កើតអត្តសញ្ញាណ

# %%
import os
from openai import OpenAI
from dotenv import load_dotenv

load_dotenv()

API_KEY = os.getenv("OPENAI_API_KEY","")
assert API_KEY, "ERROR: OpenAI Key is missing"

client = OpenAI(
    api_key=API_KEY
    )

# %% [markdown]
# ### 3. ការស្វែងរកម៉ូដែលត្រឹមត្រូវ
# ម៉ូដែលដូចជា GPT-4o និង GPT-4o mini អាចយល់និងបង្កើតភាសាតាមធម្មជាតិបាន ហើយអាចប្រើបានលើវេទិកា OpenAI ជាមួយនឹងកម្រិតថាមពល និងល្បឿនខុសៗគ្នា ដែលសមរម្យសម្រាប់ភារកិច្ចខុសៗគ្នា។

# %%
# Select a general purpose chat model
model = "gpt-4o-mini"

# %% [markdown]
# ## 4. ការរចនាពាក្យបញ្ជា
#
# "មន្តសាស្ត្ររបស់ម៉ូដែលភាសាធំបំផុតគឺដោយខួរក្បាលត្រូវបានបណ្តុះបណ្តាលដើម្បីបន្សល់កំហុសការព្យាករណ៍នេះជាបន្ទាប់ទៅលើអត្ថបទច្រើនយ៉ាងដូច្នោះ ម៉ូដែលនោះនឹងសិក្សាដឹងពីគំនិតដែលមានប្រយោជន៍សម្រាប់ការព្យាករណ៍ទាំងនេះ។ ឧទាហរណ៍ ពួកវាសិក្សាដឹងពីគំនិតដូចជា"(1):
#
# * វិធីសាស្រ្តអក្សរសំដី
# * វិធីការងារផ្នែកវេយ្យាករណ៍
# * វិធីបម្លែងប្រយោគ
# * វិធីឆ្លើយសំណួរ
# * វិធីបន្តិចបន្តួចនៃការនិយាយ
# * វិធីសរសេរជាភាសាច្រើន
# * វិធីកូដ
# * ជាដើម។
#
# #### របៀបគ្រប់គ្រងម៉ូដែលភាសាធំបំផុត
# "ក្នុងចំណោមបញ្ចូលទាំងអស់ទៅម៉ូដែលភាសាធំបំផុត ពាក្យបញ្ជាអត្ថបទគឺជាអ្វីដែលមានឥទ្ឋិពលខ្លាំងជាងគេ(1)។
#
# ម៉ូដែលភាសាធំបំផុតអាចត្រូវបានបញ្ចេញជាការបង្ហាញចេញដោយវិធីខ្លះៗ៖
#
# សេចក្តីណែនាំ: ប្រាប់ម៉ូដែលពីអ្វីដែលអ្នកចង់បាន
# ការបញ្ចប់: បញ្ជូនម៉ូដែលបញ្ចប់ចំណុចដើមដែលអ្នកចង់បាន
# ការបង្ហាញ: បង្ហាញម៉ូដែលអ្វីដែលអ្នកចង់បាន ជាមួយ:
# ឧទាហរណ៍បន្ថែមមួយចំនួនក្នុងពាក្យបញ្ជា
# ឧទាហរណ៍រាប់​រយឬ​ពាន់​លើក​ក្នុងឯកសារបណ្តុះបណ្តាល fine-tuning"
#
#
#
# #### មានមូលដ្ឋានមួយចំនួនបីសម្រាប់បង្កើតពាក្យបញ្ជា:
#
# **បង្ហាញហើយប្រាប់**។ ធ្វើឱ្យច្បាស់ថាអ្នកចង់បានអ្វី តាមរយៈសេចក្តីណែនាំ ឧទាហរណ៍ ឬការរួមបញ្ចូលទាំងពីរនេះ។ ប្រសិនបើអ្នកចង់ឱ្យម៉ូដែលបញ្ជីវត្ថុជាអក្សរតម្រៀប ឬចាត់ថ្នាក់អត្ថបទដោយអារម្មណ៍ បង្ហាញវាថានេះជាអ្វីដែលអ្នកចង់បាន។
#
# **ផ្តល់ទិន្នន័យមានគុណភាព**។ ប្រសិនបើអ្នកកំពុងព្យាយាមបង្កើតឧទាហរណ៍ឬឱ្យម៉ូដែលអនុវត្តបទលំនាំ ត្រូវប្រាកដថាមានឧទាហរណ៍គ្រប់គ្រាន់។ សូមពិនិត្យឲ្យបានមើលឧទាហរណ៍របស់អ្នកម្តងទៀត — ម៉ូដែលភាគច្រើនមានឆ្លាតបំផុតគ្រប់គ្រាន់ក្នុងការមើលឃើញកំហុសអក្ខរកម្មព្រោះសាមញ្ញ និងផ្ដល់ការឆ្លើយតបដល់អ្នក ប៉ុន្តែវាអាចសង្ស័យថានេះគឺជាការត្រូវបានគេដេីម្បីហើយវាអាចប៉ះពាល់ទៅនឹងការឆ្លើយតបបាន។
#
# **ពិនិត្យការកំណត់របស់អ្នក។** ការកំណត់សីតុណ្ហភាព និង top_p គ្រប់គ្រងមុខងារម៉ូដែលក្នុងការចេញឆ្លើយតបយ៉ាងច្បាស់លាស់ ឬចៃដន្យ។ ប្រសិនបើអ្នកស្នើសុំឲ្យវាឆ្លើយតបដែលមានចម្លើយត្រឹមតែចំរូងតែមួយ អ្នកគួរតែដាក់ការកំណត់ទាំងនេះទាប។ ប្រសិនបើអ្នកកំពុងស្វែងរកឆ្លើយតបជាច្រើនរាង អ្នកប្រហែលជាចង់កំណត់ឲ្យខ្ពស់ឡើង។ កំហុសលេខមួយដែលមនុស្សធ្វើជាមួយការកំណត់ទាំងនេះគឺផ្អែកលើការយល់ថា វាជាការគ្រប់គ្រង "ភាពឆ្លាត" ឬ "ភាពច្នៃប្រឌិត"។
#
#
# ប្រភព៖ https://learn.microsoft.com/azure/ai-services/openai/overview

# %% [markdown]
# ### 5. ស្នើសុំ!

# %%
# Create your first prompt
text_prompt = "Should oxford commas always be used?"

response = client.responses.create(
  model=model,
  input = [{"role":"system", "content":"You are a helpful assistant."},
               {"role":"user","content":text_prompt},],
  store=False,)

response.output_text

# %% [markdown]
# ### ហៅម្ដងទៀត ដូចម្ដេចបានលទ្ធផលប្រៀបធៀបទៅ?

# %%
response = client.responses.create(
  model=model,
  input = [{"role":"system", "content":"You are a helpful assistant."},
               {"role":"user","content":text_prompt},],
  store=False,)

response.output_text

# %% [markdown]
# ## សង្ខេបអត្ថបទ
# #### បញ្ហានៃការប្រឈម
# សង្ខេបអត្ថបទដោយបញ្ចូល 'tl;dr:' នៅចុងផ្នែកអត្ថបទមួយ។ សង្កេតពីរបៀបដែលម៉ូឌែលយល់ពីរបៀបអនុវត្តការងារច្រើនដោយគ្មានការណែនាំបន្ថែម។ អ្នកអាចសាកល្បងជាមួយការណែនាំដែលពិពណ៌នាបានច្រើនជាង tl;dr ដើម្បីផ្លាស់ប្ដូរប្រតិបត្តិការរបស់ម៉ូឌែលនិងប្ដូររបៀបសង្ខេបដែលអ្នកទទួលបាន(3)។
#
# ការងារថ្មីៗបានបង្ហាញពីការកើនឡើងយ៉ាងច្រើនលើការងារ NLP ជាច្រើននិងសន្ទស្សន៍ដោយការបណ្តុះបណ្តាលជាមុនលើអត្ថបទធម្មតាស្រុកធំមួយបន្ទាប់មកត្រូវបំពេញការបណ្តុះបណ្តាលលើការងារពិសេសមួយ។ ខណៈដែលវិធីសាស្រ្តនេះជាទូទៅមិនរាប់បញ្ចូលកាសាងសង់ខ្លួនចូលលើការងារ ព្រោះវាត្រូវការដំណើរការបណ្តុះបណ្តាលលើឯកសារពិសេសដែលមានពហុពាន់ឬបណ្ដារប្រាំពាន់គំរូ។ ផ្ទុយទៅវិញ មនុស្សភាគច្រើនអាចអនុវត្តការងារភាសាថ្មីពីគំរូតិចៗឬពីការណែនាំសាមញ្ញ - រឿងដែលប្រព័ន្ធ NLP បច្ចុប្បន្ននៅតែមានការលំបាកយ៉ាងខ្លាំងក្នុងការធ្វើ។ នៅទីនេះយើងបង្ហាញថាការពង្រឹងម៉ូឌែលភាសាដោយចំណាយធំធេងធ្វើឱ្យប្រសើរឡើងយ៉ាងច្រើនសមត្ថភាពអនុវត្តការងារដោយគ្មានការណែនាំជាច្រើនលើឧទាហរណ៍តិចៗ ដល់ចំណុចមួយដែលអាចប្រកួតប្រជែងទាំងទៅវិញទៅមកជាមួយវិធីសាស្រ្តបណ្តុះបណ្តាលល្អបំផុតជាសៀវភៅមុន។
#
#
#
# Tl;dr

# %% [markdown]
# # លំហាត់សម្រាប់ករណីប្រើប្រាស់ជាច្រើន
# 1. សរុបអត្ថបទ
# 2. ចាត់ថ្នាក់អត្ថបទ
# 3. បង្កើតឈ្មោះផលិតផលថ្មី

# %%
prompt = "Recent work has demonstrated substantial gains on many NLP tasks and benchmarks by pre-training on a large corpus of text followed by fine-tuning on a specific task. While typically task-agnostic in architecture, this method still requires task-specific fine-tuning datasets of thousands or tens of thousands of examples. By contrast, humans can generally perform a new language task from only a few examples or from simple instructions - something that current NLP systems still largely struggle to do. Here we show that scaling up language models greatly improves task-agnostic, few-shot performance, sometimes even reaching competitiveness with prior state-of-the-art fine-tuning approaches.\n\nTl;dr"

# %%
#Setting a few additional, typical parameters during API Call

response = client.responses.create(
  model=model,
  input = [{"role":"system", "content":"You are a helpful assistant."},
               {"role":"user","content":prompt},],
  store=False,)

response.output_text

# %% [markdown]
# ## ចាត់ថ្នាក់អត្ថបទ
# #### សំណួរ
# ចាត់ថ្នាក់ទំនិញទៅក្នុងចំណាត់ថ្នាក់ដែលបានផ្ដល់នៅពេលព្យាករណ៍។ ក្នុងឧទាហរណ៍ខាងក្រោម យើងផ្ដល់ទាំងចំណាត់ថ្នាក់ និងអត្ថបទសម្រាប់ចាត់ថ្នាក់ក្នុងការជំហាន (*playground_reference).
#
# សំណួរអតិថិជន៖ សួស្តី គន្លឹះមួយនៃក្តារចុចលើកុំព្យូទ័រយន្តខ្ញុំទើបតែខូចថ្មីៗនេះ ហើយខ្ញុំត្រូវការជំនួស:
#
# ចំណាត់ថ្នាក់ដែលបានចាត់:

# %%
prompt = "Classify the following inquiry into one of the following: categories: [Pricing, Hardware Support, Software Support]\n\ninquiry: Hello, one of the keys on my laptop keyboard broke recently and I'll need a replacement:\n\nClassified category:"
print(prompt)

# %%
#Setting a few additional, typical parameters during API Call

response = client.responses.create(
  model=model,
  input = [{"role":"system", "content":"You are a helpful assistant."},
               {"role":"user","content":prompt},],
  store=False,)

response.output_text

# %% [markdown]
# ## បង្កើតឈ្មោះផលិតផលថ្មី
# #### សម្រឡះ
# បង្កើតឈ្មោះផលិតផលពីពាក្យគំរូ។ នៅទីនេះ យើងបញ្ចូលព័ត៌មានអំពីផលិតផលដែលយើងនឹងបង្កើតឈ្មោះសម្រាប់ក្នុងការផ្តល់ព័ត៌មាន។ យើងក៏ផ្តល់ឧទាហរណ៍ស្រដៀងគ្នាមួយដើម្បីបង្ហាញលំនាំដែលយើងចង់ទទួលបាន។ យើងក៏បានកំណត់តម្លៃសីតុណ្ហភាពខ្ពស់ដើម្បីបង្កើនភាពចៃដន្យ និងឆ្លើយតបថ្មីៗជាងមុន។
#
# ការពិពណ៌នាផលិតផល៖ ម៉ាស៊ីនធ្វើកាកដំណក់ទឹកដោះគោនៅផ្ទះ
# ពាក្យគ្រាប់ទីណា៖ លឿន, មានសុខភាពល្អ, កាត់បន្ថយទំហំ។
# ឈ្មោះផលិតផល៖ HomeShaker, Fit Shaker, QuickShake, Shake Maker
#
# ការពិពណ៌នាផលិតផល៖ ស្បែកជើងមួយគូដែលអាចសម្របខ្លួនបានជាមួយទំហំព្រះជើងគ្រប់ប្រភេទ។
# ពាក្យគ្រាប់ទីណា៖ អាចសម្របខ្លួន, សមភាព, omni-fit។

# %%
prompt = "Product description: A home milkshake maker\nSeed words: fast, healthy, compact.\nProduct names: HomeShaker, Fit Shaker, QuickShake, Shake Maker\n\nProduct description: A pair of shoes that can fit any foot size.\nSeed words: adaptable, fit, omni-fit."

print(prompt)

# %%
#Setting a few additional, typical parameters during API Call

response = client.responses.create(
  model=model,
  input = [{"role":"system", "content":"You are a helpful assistant."},
               {"role":"user","content":prompt}],
  store=False,)

response.output_text

# %% [markdown]
# # ឯកសារយោង
# - [Openai Cookbook](https://github.com/openai/openai-cookbook?WT.mc_id=academic-105485-koreyst)
# - [Microsoft Foundry portal](https://ai.azure.com?WT.mc_id=academic-105485-koreyst)
# - [ប្រសិនបើអនុវត្តការលក្ខណៈល្អបំផុតសម្រាប់ការកែប្រែម៉ូដែល GPT ដើម្បីចាត់ថ្នាក់អត្ថបទ](https://platform.openai.com/docs/guides/fine-tuning?WT.mc_id=academic-105485-koreyst)

# %% [markdown]
# # សម្រាប់ជំនួយបន្ថែម
# [OpenAI Commercialization Team](AzureOpenAITeam@microsoft.com)

# %% [markdown]
# # អ្នកចូលរួម
# * Louis Li

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **ការបដិសេធ**:
# ឯកសារនេះត្រូវបានបម្លែងភាសា ដោយប្រើសេវាបម្លែងភាសា AI [Co-op Translator](https://github.com/Azure/co-op-translator)។ ទោះយើងខ្ញុំមានក្តីប្រាថ្នាឱ្យបានច្បាស់លាស់ តែសូមយល់ដឹងថាការបម្លែងដោយស្វ័យប្រវត្តិក៏អាចមានកំហុសឬភាពមិនត្រឹមត្រូវ។ ឯកសារដើមជាភាសាទីតាំងគួរត្រូវបានគេប្រើជាប្រភពច្បាស់លាស់។ សម្រាប់ព័ត៌មានសំខាន់ៗ សូមណែនាំឱ្យប្រើប្រាស់ការប្រែដោយមនុស្សជំនាញ។ យើងខ្ញុំមិនទទួលខុសត្រូវចំពោះការយល់ច្រឡំ ឬការបកស្រាយខុសបន្ទាប់ពីការប្រើប្រាស់ការបម្លែងនេះនោះទេ។
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
