# %% [markdown]
# # ជំពូក 7៖ ការបង្កើតកម្មវិធីជជែក
# ## ការចាប់ផ្តើមយ៉ាងរហ័សសម្រាប់ OpenAI API
#
# សៀវភៅកំណត់ត្រានេះត្រូវបានបម្លែងពី [ធនាគារឧទាហរណ៍ Azure OpenAI](https://github.com/Azure/azure-openai-samples?WT.mc_id=academic-105485-koreyst) ដែលរួមមានសៀវភៅកំណត់ត្រាដែលចូលទៅរកសេវាកម្ម [Azure OpenAI](notebook-azure-openai.ipynb)។
#
# Python OpenAI API បង្កើតការងារជាមួយម៉ូដែល Azure OpenAI ផងដែរ ជាមួយកំណែប្រែបន្តិច។ អាចរៀនបន្ថែមពីភាពខុសគ្នានៅទីនេះ៖ [របៀបប្តូរពី OpenAI ទៅ Azure OpenAI endpoints ជាមួយ Python](https://learn.microsoft.com/azure/ai-foundry/openai/how-to/switching-endpoints?WT.mc_id=academic-109527-jasmineg)

# %% [markdown]
# # ទិដ្ឋភាពទូទៅ
# "ម៉ូដែលភាសាធំៗ គឺជាអនុគមន៍ដែលផ្គូផ្គងអត្ថបទទៅអត្ថបទ។ នៅពេលបានខ្សែអត្ថបទបញ្ចូលមួយ ម៉ូដែលភាសាធំគឺព្យាយាមទាយអត្ថបទដែលនឹងមកបន្ទាប់"(1)។ សៀវភៅកំណត់ត្រា "ចាប់ផ្តើមរហ័ស" នេះនឹងណែនាំអ្នកប្រើអំពីអំពីគំនិត LLM ដំណាក់កម្រិតខ្ពស់ តម្រូវការពញ្ញាកម្មសំខាន់សម្រាប់ចាប់ផ្តើមជាមួយ AML ការណែនាំទន់នៃការរចនាការហៅ និងឧទាហរណ៍ខ្លីៗជាច្រើននៃការប្រើប្រាស់ផ្សេងៗគ្នា។

# %% [markdown]
# ## ទំព័ររបស់មាតិកា
#
# [ទិដ្ឋភាពទូទៅ](#overview)
# [របៀបប្រើសេវាកម្ម OpenAI](#how-to-use-openai-service)
# [1. បង្កើតសេវាកម្ម OpenAI របស់អ្នក](#1.-creating-your-openai-service)
# [2. ការដំឡើង](#2.-installation)
# [3. ព័ត៌មានសម្គាល់](#3.-credentials)
#
# [ករណីប្រើប្រាស់](#use-cases)
# [1. សង្ខេបអត្ថបទ](#1.-summarize-text)
# [2. ចាត់ថ្នាក់អត្ថបទ](#2.-classify-text)
# [3. បង្កើតឈ្មោះផលិតផលថ្មី](#3.-generate-new-product-names)
# [4. បង្វឹកចំណាត់ថ្នាក់](#4.fine-tune-a-classifier)
#
# [យោង](#references)

# %% [markdown]
# ### បង្កើតជំពូកដំបូងរបស់អ្នក
# វិចារណាការណ៍ខ្លីនេះនឹងផ្តល់ជំនួយមូលដ្ឋានសម្រាប់ការដាក់ជំពូកទៅម៉ូដែល OpenAI សម្រាប់ភារកិច្ចសាមញ្ញ "ការសង្ខេប"។
#
#
# **ជំហាន**៖
# 1. ដំឡើងបណ្ណាល័យ OpenAI ក្នុងបរិស្ថាន python របស់អ្នក
# 2. រំលំរួមបណ្ណាល័យជំនួយស្ដង់ដារហើយកំណត់លិខិតសម្ងាត់ OpenAI ជាធម្មតារបស់អ្នកសម្រាប់សេវាកម្ម OpenAI ដែលអ្នកបានបង្កើត
# 3. ជ្រើសរើសម៉ូដែលសម្រាប់ភារកិច្ចរបស់អ្នក
# 4. បង្កើតជំពូកសាមញ្ញសម្រាប់ម៉ូដែល
# 5. ស្នើសុំការអនុវត្តទៅ API ម៉ូដែល!

# %% [markdown]
# ### 1. ដំឡើង OpenAI

# %%
# %pip install openai python-dotenv

# %% [markdown]
# ### 2. នាំចូលបណ្ណាល័យជំនួយ និងបង្កើតការផ្អែកលើគណនី

# %%
import os
from openai import OpenAI
from dotenv import load_dotenv

load_dotenv()

API_KEY = os.getenv("OPENAI_API_KEY","")
assert API_KEY, "ERROR: OpenAI Key is missing"

client = OpenAI(
    api_key=API_KEY
    )

# %% [markdown]
# ### 3. ការស្វែងរកម៉ូដែលដែលត្រឹមត្រូវ
# ម៉ូដែលដូចជា GPT-4o និង GPT-4o mini អាចយល់ និងបង្កើតភាសាជាទ្រព្យសម្បត្តិធម្មតា ហើយអាចប្រើបានលើវេទិកា OpenAI ជាមួយនឹងកម្រិតថាមពល និងល្បឿនផ្សេងៗដែលសមនឹងភារកិច្ចផ្សេងៗ។

# %%
# Select a general purpose chat model
model = "gpt-5-mini"

# %% [markdown]
# ## 4. ការរចនាការណែនាំ
#
# "តន្ត្រីអាថ៌កំបាំងនៃគំរូភាសាធំគឺដោយការបណ្តុះបណ្តាលដើម្បីបន្ថយកំហុសនៃការព្យាករណ៍នេះលើចំណុចអត្ថបទច្រើនគ្រប់គ្រាន់ គំរូទាំងនេះនឹងរៀនគំនិតដែលមានប្រយោជន៍សម្រាប់ការព្យាករណ៍ទាំងនេះ។ ឧទាហរណ៍ ពួកវារៀនគំនិតដូចជា"(1):
#
# * របៀបសំភ្លេងពាក្យត្រឹមត្រូវ
# * របៀបប្រើវេយ្យាករណ៍
# * របៀបផ្លាស់ប្តូរពាក្យ
# * របៀបឆ្លើយសំនួរ
# * របៀបនិយាយជជែក
# * របៀបសរសេរជាភាសាច្រើន
# * របៀបកូដកម្ម
# * និងផ្សេងៗទៀត
#
# #### របៀបត្រួតគំរូភាសាធំ
# "ក្នុងចំណោមការបញ្ចូលទាំងអស់ទៅកាន់គំរូភាសាធំ អត្ថបទណែនាំគឺជារឿងដែលមានឥទ្ធិពលខ្លាំងបំផុត(1)។
#
# គំរូភាសាធំអាចត្រូវបានណែនាំឲ្យផលិតលទ្ធផលដោយវិធីខ្លះៗ៖
#
# ការណែនាំ៖ ប្រាប់គំរូថាអ្នកចង់បានអ្វី
# ការសម្រេច៖ បញ្ចូលគំរូឲ្យបញ្ចប់ចំណុចដំបូងនៃអ្វីដែលអ្នកចង់បាន
# ការបង្ហាញ៖ បង្ហាញគំរូអ្វីដែលអ្នកចង់បាន ជាមួយទាំង៖
# ឧទាហរណ៍ពីរបីក្នុងការណែនាំ
# ឧទាហរណ៍រាប់រយឬពាន់ក្នុងសំណុំទិន្នន័យបណ្តុះបណ្តាលជាសំខាន់"
#
#
#
# #### មានបទប្បញ្ញត្តិមូលដ្ឋានបីរបស់ការបង្កើតការណែនាំ៖
#
# **បង្ហាញ និងប្រាប់**។ ធ្វើឲ្យច្បាស់ថាអ្នកចង់បានអ្វី តាមរយៈការណែនាំ ឧទាហរណ៍ ឬការភ្ជាប់រវាងពីរនេះ។ ប្រសិនបើអ្នកចង់ឲ្យគំរូតម្រៀបបញ្ជីមុខម្ហូបជាក្រមអក្សរឬចាត់ថ្នាក់បន្ទាត់តាមអារម្មណ៍ បង្ហាញវាថា នេះជាអ្វីដែលអ្នកចង់បាន។
#
# **ផ្តល់ទិន្នន័យគុណភាព**។ ប្រសិនបើអ្នកកំពុងព្យាយាមបង្កើតមុខងារចាត់ថ្នាក់ ឬឲ្យគំរូអនុវត្តតាមគំរូមួយ ចូរត្រូវមានឧទាហរណ៍គ្រប់គ្រាន់។ ត្រូវពិនិត្យឲ្យបានយ៉ាងម៉ត់ចត់ពីឧទាហរណ៍របស់អ្នក—គំរូភាគច្រើនវាស់ចេះគិតបានក្រោមកម្រិតរាល់កំហុសសំភ្លេងសាមញ្ញនិងឲ្យចម្លើយ មួយទៀត វាអាចនឹកស្មារតីថានេះជាការដាក់ចិត្តផ្លូវចិត្តហើយវាអាចមានផលប៉ះពាល់ដល់ចម្លើយ។
#
# **ពិនិត្យការកំណត់របស់អ្នក។** កម្រិតសីតុណ្ហភាព និង top_p គ្រប់គ្រងពីរបៀបដែលគំរូមានញាណក្នុងការចេញចម្លើយ។ ប្រសិនបើអ្នកស្នើសុំចម្លើយដែលមានតែចម្លើយត្រឹមតែ១តែប៉ុណ្ណោះ អ្នកគួរត្រូវកំណត់តម្លៃទាំងនេះឲ្យទាប។ ប្រសិនបើអ្នកចង់បានចម្លើយចម្រុះ ក៏អាចកំណត់កម្រិតខ្ពស់ជាងនេះ។ កំហុសលេខមួយដែលមនុស្សភាគច្រើនធ្វើជាមួយការកំណត់ទាំងនេះគឺចាត់ទុកថាវាជាការគ្រប់គ្រង "ភាពឆ្លាត" ឬ "ភាពច្នៃប្រឌិត"។
#
#
# ប្រភព៖ https://learn.microsoft.com/azure/ai-foundry/openai/overview

# %% [markdown]
# ### 5. ដាក់ស្នើ!

# %%
# Create your first prompt
text_prompt = "Should oxford commas always be used?"

response = client.responses.create(
  model=model,
  input = [{"role":"system", "content":"You are a helpful assistant."},
               {"role":"user","content":text_prompt},],
  store=False,)

response.output_text

# %% [markdown]
# ### ព្យាយាមហៅម្ដងទៀត ដូចម្ដេចដែលលទ្ធផលបានប្រៀបធៀប?

# %%
response = client.responses.create(
  model=model,
  input = [{"role":"system", "content":"You are a helpful assistant."},
               {"role":"user","content":text_prompt},],
  store=False,)

response.output_text

# %% [markdown]
# ## សង្ខេបអត្ថបទ
# #### ប្រឈមក្រោយ
# សង្ខេបអត្ថបទដោយបន្ថែម 'tl;dr:' នៅចុងអត្ថបទមួយ។ សម្គាល់ថាគំរូយល់ពីរបៀបអនុវត្តភារកិច្ចជាច្រើនដោយមិនបាច់មានការណែនាំបន្ថែមណា។ អ្នកអាចសាកល្បងប្រើការបញ្ជាបណ្តាលដែលពិពណ៌នាបន្ថែមជាង tl;dr ដើម្បីផ្លាស់ប្តូរចរិតគំរូ និងប្តូរសង្ខេបដែលអ្នកទទួលបាន(3)។
#
# ការងារថ្មីៗបានបង្ហាញពីការកើនឡើងយ៉ាងច្រើនលើភារកិច្ចនិងការវាស់វែង NLP ជាច្រើនដោយការបណ្តុះបណ្តាលជាមុនលើអត្ថបទដែលមានច្រើនបន្ទាត់ ហើយបន្ទាប់មកជាការបង្រៀនលម្អិតលើភារកិច្ឆតិជាក់លាក់មួយ។ ទោះបីបែបផែនរាងកាយជាទូទៅមិនត្រូវបានប្ដូរតាមភារកិច្ចក៏ដោយ វាវិធីនេះនៅតែមើលវាចាំបាច់ការបង្រៀនលម្អិតផ្អែកលើតុំបញ្ញត្តិភារកិច្ចជាមួយគំរូជាអ្នករាប់ពាន់ឬអតីតនៃគំរូរបស់អ្នកឧទាហរណ៍។ ក្នុងនិរូបផ្សេង Humans ប្រហែលជាអាចអនុវត្តភារកិច្ចភាសាថ្មីមួយដោយមានតែគំរូតិចតួចឬពីការណែនាំសាមញ្ញៗ - បាតឯកសារព័ត៌មានបានប្រព្រឹត្តិយ៉ាងខ្លាំងនៅក្នុងប្រព័ន្ធ NLP សព្វថ្ងៃ ទំនងថាអាចធ្វើការយ៉ាងល្អក្នុងភារកិច្ចពិសេសណាមួយបាន។ នៅទីនេះ យើងបង្ហាញថាការពង្រីកទំហំគំរូភាសាជួយសម្រួលការអនុវត្តភារកិច្ចដោយមិនចាំបាច់បានច្រើន ក៏ប៉ុន្តែការអនុវត្ត បន្តបន្ទាប់ខ្លះមិនសូវខ្វះខាត ជាមួយនឹងវិធីសាស្ត្រការបង្រៀនលម្អិតលើភារកិច្ឆតិកន្លងមក។
#
#
#
# Tl;dr

# %% [markdown]
# # ការប្រលងសម្រាប់ករណីប្រើប្រាស់ច្រើន
# 1.សង្ខេបអត្ថបទ
# 2.ចាត់ថ្នាក់អត្ថបទ
# 3.បង្កើតឈ្មោះផលិតផលថ្មី

# %%
prompt = "Recent work has demonstrated substantial gains on many NLP tasks and benchmarks by pre-training on a large corpus of text followed by fine-tuning on a specific task. While typically task-agnostic in architecture, this method still requires task-specific fine-tuning datasets of thousands or tens of thousands of examples. By contrast, humans can generally perform a new language task from only a few examples or from simple instructions - something that current NLP systems still largely struggle to do. Here we show that scaling up language models greatly improves task-agnostic, few-shot performance, sometimes even reaching competitiveness with prior state-of-the-art fine-tuning approaches.\n\nTl;dr"

# %%
#Setting a few additional, typical parameters during API Call

response = client.responses.create(
  model=model,
  input = [{"role":"system", "content":"You are a helpful assistant."},
               {"role":"user","content":prompt},],
  store=False,)

response.output_text

# %% [markdown]
# ##ចំណាត់ថ្នាក់អត្ថបទ
# #### សម្រួល
# ចំណាត់ថ្នាក់ទំនិញទៅកាន់ប្រភេទដែលបានផ្ដល់នៅពេលដំណើរការ។ ក្នុងឧទាហរណ៍ខាងក្រោម យើងផ្ដល់ទាំងប្រភេទនិងអត្ថបទសម្រាប់ចំណាត់ថ្នាក់ក្នុងការបង្ហាញ(*playground_reference)។
#
# សំណួរពីអតិថិជន: សួស្តី ប៊ូតុងមួយនៅលើក្តារចុចកុំព្យូទ័រយ៉ាងខ្ញុំបានខូចថ្មីៗនេះហើយខ្ញុំនឹងត្រូវការប្រែប្រួលមួយ៖
#
# ប្រភេទដែលចំណាត់ថ្នាក់:

# %%
prompt = "Classify the following inquiry into one of the following: categories: [Pricing, Hardware Support, Software Support]\n\ninquiry: Hello, one of the keys on my laptop keyboard broke recently and I'll need a replacement:\n\nClassified category:"
print(prompt)

# %%
#Setting a few additional, typical parameters during API Call

response = client.responses.create(
  model=model,
  input = [{"role":"system", "content":"You are a helpful assistant."},
               {"role":"user","content":prompt},],
  store=False,)

response.output_text

# %% [markdown]
# ## បង្កើតឈ្មោះផលិតផលថ្មី
# #### 챌린지
# បង្កើតឈ្មោះផលិតផលពីពាក្យឧទាហរណ៍។ នៅទីនេះយើងរួមបញ្ចូលព័ត៌មានអំពីផលិតផលដែលយើងនឹងបង្កើតឈ្មោះសម្រាប់ក្នុងល្បែងស្នើ។ យើងក៏បានផ្តល់ឧទាហរណ៍ដូចគ្នាមួយដើម្បីបង្ហាញលំនាំដែលយើងចង់ទទួលបាន។ យើងក៏បានកំណត់តម្លៃសីតុណ្ហភាពខ្ពស់ដើម្បីបង្កើនភាពចៃដន្យនិងការឆ្លើយតបបរិច្ឆេទបន្ថែម។
#
# ការពិពណ៌នាផលិតផល៖ ឧបករណ៍ធ្វើមួលទឹកដោះគោនៅផ្ទះ
# ពាក្យគំរូ៖ រហ័ស, សុខភាពល្អ, តូចតាង។
# ឈ្មោះផលិតផល៖ HomeShaker, Fit Shaker, QuickShake, Shake Maker
#
# ការពិពណ៌នាផលិតផល៖ ស្បែកជើងមួយគូដែលអាចសមនឹងទំហំជើងណាមួយ។
# ពាក្យគំរូ៖ អាចត្រូវគ្នា, សមនឹង, អូម្នី-សមនឹង។

# %%
prompt = "Product description: A home milkshake maker\nSeed words: fast, healthy, compact.\nProduct names: HomeShaker, Fit Shaker, QuickShake, Shake Maker\n\nProduct description: A pair of shoes that can fit any foot size.\nSeed words: adaptable, fit, omni-fit."

print(prompt)

# %%
#Setting a few additional, typical parameters during API Call

response = client.responses.create(
  model=model,
  input = [{"role":"system", "content":"You are a helpful assistant."},
               {"role":"user","content":prompt}],
  store=False,)

response.output_text

# %% [markdown]
# # ឯកសារយោង
# - [Openai Cookbook](https://github.com/openai/openai-cookbook?WT.mc_id=academic-105485-koreyst)
# - [Microsoft Foundry portal](https://ai.azure.com?WT.mc_id=academic-105485-koreyst)
# - [Best practices for fine-tuning GPT models to classify text](https://platform.openai.com/docs/guides/fine-tuning?WT.mc_id=academic-105485-koreyst)

# %% [markdown]
# # សម្រាប់ជំនួយបន្ថែម
# [ក្រុមពាណិជ្ជកម្ម OpenAI](AzureOpenAITeam@microsoft.com)

# %% [markdown]
# # អ្នកចូលរួម
# * Louis Li

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **ការបដិសេធ**:
# ឯកសារនេះត្រូវបានបម្លែងភាសា ដោយប្រើសេវាបម្លែងភាសា AI [Co-op Translator](https://github.com/Azure/co-op-translator)។ ទោះយើងខ្ញុំមានក្តីប្រាថ្នាឱ្យបានច្បាស់លាស់ តែសូមយល់ដឹងថាការបម្លែងដោយស្វ័យប្រវត្តិក៏អាចមានកំហុសឬភាពមិនត្រឹមត្រូវ។ ឯកសារដើមជាភាសាទីតាំងគួរត្រូវបានគេប្រើជាប្រភពច្បាស់លាស់។ សម្រាប់ព័ត៌មានសំខាន់ៗ សូមណែនាំឱ្យប្រើប្រាស់ការប្រែដោយមនុស្សជំនាញ។ យើងខ្ញុំមិនទទួលខុសត្រូវចំពោះការយល់ច្រឡំ ឬការបកស្រាយខុសបន្ទាប់ពីការប្រើប្រាស់ការបម្លែងនេះនោះទេ។
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
