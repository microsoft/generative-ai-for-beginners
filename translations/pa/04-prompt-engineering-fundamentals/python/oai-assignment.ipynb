# %% [markdown]
# ਹੇਠਾਂ ਦਿੱਤੀ ਨੋਟਬੁੱਕ ਆਟੋਮੈਟਿਕ ਤੌਰ 'ਤੇ ਗਿੱਟਹਬ ਕੋਪਾਇਲਟ ਚੈਟ ਵੱਲੋਂ ਬਣਾਈ ਗਈ ਸੀ ਅਤੇ ਕੇਵਲ ਮੁੱਢਲੇ ਸੈਟਅਪ ਲਈ ਹੈ

# %% [markdown]
# # ਪ੍ਰੌਂਪਟ ਇੰਜੀਨੀਅਰਿੰਗ ਦਾ ਪਰਿਚਯ
# ਪ੍ਰੌਂਪਟ ਇੰਜੀਨੀਅਰਿੰਗ ਕੁਦਰਤੀ ਭਾਸ਼ਾ ਪ੍ਰਕਿਰਿਆ ਕਰਨ ਦੇ ਕੰਮਾਂ ਲਈ ਪ੍ਰੌਂਪਟਾਂ ਨੂੰ ਡਿਜ਼ਾਈਨ ਅਤੇ ਅਪਟਿਮਾਈਜ਼ ਕਰਨ ਦੀ ਪ੍ਰਕਿਰਿਆ ਹੈ। ਇਸ ਵਿੱਚ ਸਹੀ ਪ੍ਰੌਂਪਟਾਂ ਦੀ ਚੋਣ ਕਰਨਾ, ਉਨ੍ਹਾਂ ਦੇ ਪੈਰਾਮੀਟਰਾਂ ਨੂੰ ਸੁਧਾਰਨਾ ਅਤੇ ਉਨ੍ਹਾਂ ਦੀ ਕਾਰਕਿਰਦਗੀ ਦਾ ਮੁਲਾਂਕਣ ਕਰਨਾ ਸ਼ਾਮਲ ਹੈ। NLP ਮਾਡਲਾਂ ਵਿੱਚ ਉੱਚ ਸਹੀਤਾ ਅਤੇ ਕੰਮ ਕਰਨ ਦੀ ਸਮਰੱਥਾ ਪ੍ਰਾਪਤ ਕਰਨ ਲਈ ਪ੍ਰੌਂਪਟ ਇੰਜੀਨੀਅਰਿੰਗ ਬਹੁਤ ਮਹੱਤਵਪੂਰਨ ਹੈ। ਇਸ ਹਿੱਸੇ ਵਿੱਚ, ਅਸੀਂ ਖੋਜ ਲਈ OpenAI ਮਾਡਲਾਂ ਦੀ ਵਰਤੋਂ ਕਰਕੇ ਪ੍ਰੌਂਪਟ ਇੰਜੀਨੀਅਰਿੰਗ ਦੇ ਬੁਨਿਆਦੀ ਤੱਤਾਂ ਦੀ ਜਾਂਚ ਕਰਾਂਗੇ।

# %% [markdown]
# ### ਵਰਕਆਉਟ 1: ਟੋਕਨਾਈਜੇਸ਼ਨ
# tiktoken ਦੀ ਵਰਤੋਂ ਕਰਕੇ ਟੋਕਨਾਈਜੇਸ਼ਨ ਦੀ ਖੋਜ ਕਰੋ, ਜੋ OpenAI ਤੋਂ ਇੱਕ ਓਪਨ-ਸੋਰਸ ਤੇਜ਼ ਟੋਕਨਾਈਜ਼ਰ ਹੈ
# ਹੋਰ ਉਦਾਹਰਣਾਂ ਲਈ [OpenAI Cookbook](https://github.com/openai/openai-cookbook/blob/main/examples/How_to_count_tokens_with_tiktoken.ipynb?WT.mc_id=academic-105485-koreyst) ਵੇਖੋ।

# %%
# EXERCISE:
# 1. Run the exercise as is first
# 2. Change the text to any prompt input you want to use & re-run to see tokens

import tiktoken

# Define the prompt you want tokenized
text = f"""
Jupiter is the fifth planet from the Sun and the \
largest in the Solar System. It is a gas giant with \
a mass one-thousandth that of the Sun, but two-and-a-half \
times that of all the other planets in the Solar System combined. \
Jupiter is one of the brightest objects visible to the naked eye \
in the night sky, and has been known to ancient civilizations since \
before recorded history. It is named after the Roman god Jupiter.[19] \
When viewed from Earth, Jupiter can be bright enough for its reflected \
light to cast visible shadows,[20] and is on average the third-brightest \
natural object in the night sky after the Moon and Venus.
"""

# Set the model you want encoding for
encoding = tiktoken.encoding_for_model("gpt-4o")

# Encode the text - gives you the tokens in integer form
tokens = encoding.encode(text)
print(tokens);

# Decode the integers to see what the text versions look like
[encoding.decode_single_token_bytes(token) for token in tokens]

# %% [markdown]
# ### ਐਕਸਰਸਾਈਜ਼ 2: OpenAI API ਕੀ ਸੈਟਅਪ ਦੀ ਪੁਸ਼ਟੀ ਕਰੋ
#
# ਹੇਠਾਂ ਦਿੱਤਾ ਕੋਡ ਚਲਾਓ ਤਾਂ ਜੋ ਇਹ ਪੁੱਛਿਆ ਜਾ ਸਕੇ ਕਿ ਤੁਹਾਡਾ OpenAI ਐਂਡਪੌਇੰਟ ਠੀਕ ਤਰ੍ਹਾਂ ਸੈੱਟ ਹੈ ਜਾਂ ਨਹੀਂ। ਕੋਡ ਸਿਰਫ ਇੱਕ ਸਧਾਰਣ ਬੇਸਿਕ ਪ੍ਰਾਂਪਟ ਦੀ ਕੋਸ਼ਿਸ਼ ਕਰਦਾ ਹੈ ਅਤੇ ਪੂਰਨਤਾ ਦੀ ਪੁਸ਼ਟੀ ਕਰਦਾ ਹੈ। ਇਨਪੁੱਟ `oh say can you see` ਦੇ ਆਧਾਰ 'ਤੇ ਜਵਾਬ `by the dawn's early light..` ਵਰਗਾ ਹੋਣਾ ਚਾਹੀਦਾ ਹੈ।

# %%
# Uses the OpenAI client with the Responses API.
# See https://platform.openai.com/docs/api-reference/responses

import os
from openai import OpenAI
from dotenv import load_dotenv
load_dotenv()

client = OpenAI()

deployment="gpt-5-mini"

def get_completion(prompt):
    response = client.responses.create(
        model=deployment,
        input=prompt,
        max_output_tokens=1024,
        store=False,
    )
    return response.output_text

## ---------- Call the helper method

### 1. Set primary content or prompt text
text = f"""
oh say can you see
"""

### 2. Use that in the prompt template below
prompt = f"""
```{text}```
"""

## 3. Run the prompt
response = get_completion(prompt)
print(response)

# %% [markdown]
# ### ਵਰਜ਼ਿਸ 3: ਨਿਰਮਾਣ
# ਦੇਖੋ ਕਿ ਕੀ ਹੁੰਦਾ ਹੈ ਜਦੋਂ ਤੁਸੀਂ LLM ਨੂੰ ਕਿਸੇ ਐਸੇ ਵਿਸ਼ੇ ਦੇ ਬਾਰੇ ਪੂਛਦੇ ਹੋ ਜਿਸਦਾ ਹੋ ਸਕਦਾ ਹੈ ਮੌਜੂਦ ਨਾ ਹੋਵੇ, ਜਾਂ ਉਹ ਵਿਸ਼ੇ ਜਿਨ੍ਹਾਂ ਬਾਰੇ ਹੋ ਸਕਦਾ ਹੈ ਇਹ ਨਹੀਂ ਜਾਣਦਾ ਕਿਉਂਕਿ ਉਹ ਇਸਦੇ ਪ੍ਰੀ-ਟਰੇਨਡ ਡੇਟਾਸੈਟ (ਹਾਲੀਆ) ਦੇ ਬਾਹਰ ਸਨ। ਵੇਖੋ ਕਿ ਜੇ ਤੁਸੀਂ ਵੱਖਰਾ ਪ੍ਰਾਂਪਟ ਜਾਂ ਵੱਖਰਾ ਮਾਡਲ ਦੀ ਕੋਸ਼ਿਸ਼ ਕਰੋ ਤਾਂ ਜਵਾਬ ਕਿਵੇਂ ਬਦਲਦਾ ਹੈ।

# %%
## Set the text for simple prompt or primary content
## Prompt shows a template format with text in it - add cues, commands etc if needed
## Run the completion 
text = f"""
generate a lesson plan on the Martian War of 2076.
"""

prompt = f"""
```{text}```
"""

response = get_completion(prompt)
print(response)

# %% [markdown]
# ### ਵਰਕਆਉਟ 4: ਨਿਰਦੇਸ਼ ਅਧਾਰਿਤ
# ਪ੍ਰਾਇਮਰੀ ਸਮੱਗਰੀ ਸੈੱਟ ਕਰਨ ਲਈ "text" ਵੇਰੀਏਬਲ ਦੀ ਵਰਤੋਂ ਕਰੋ
# ਅਤੇ ਉਸ ਪ੍ਰਾਇਮਰੀ ਸਮੱਗਰੀ ਨਾਲ ਸੰਬੰਧਤ ਨਿਰਦੇਸ਼ ਦੇਣ ਲਈ "prompt" ਵੇਰੀਏਬਲ ਦੀ ਵਰਤੋਂ ਕਰੋ।
#
# ਇੱਥੇ ਅਸੀਂ ਮਾਡਲ ਨੂੰ ਦੂਜੇ ਦਰਜੇ ਦੇ ਵਿਦਿਆਰਥੀ ਲਈ ਟੈਕਸਟ ਦਾ ਸੰਗ੍ਰਹਿ ਕਰਨ ਲਈ ਕਹਿੰਦੇ ਹਾਂ

# %%
# Test Example
# https://platform.openai.com/playground/p/default-summarize

## Example text
text = f"""
Jupiter is the fifth planet from the Sun and the \
largest in the Solar System. It is a gas giant with \
a mass one-thousandth that of the Sun, but two-and-a-half \
times that of all the other planets in the Solar System combined. \
Jupiter is one of the brightest objects visible to the naked eye \
in the night sky, and has been known to ancient civilizations since \
before recorded history. It is named after the Roman god Jupiter.[19] \
When viewed from Earth, Jupiter can be bright enough for its reflected \
light to cast visible shadows,[20] and is on average the third-brightest \
natural object in the night sky after the Moon and Venus.
"""

## Set the prompt
prompt = f"""
Summarize content you are provided with for a second-grade student.
```{text}```
"""

## Run the prompt
response = get_completion(prompt)
print(response)

# %% [markdown]
# ### ਅਭਿਆਸ 5: ਜਟਿਲ ਪ੍ਰਾਂਪਟ
# ਇੱਕ ਅਜਿਹਾ ਬੇਨਤੀ ਕਰੋ ਜਿਸ ਵਿੱਚ ਸਿਸਟਮ, ਯੂਜ਼ਰ ਅਤੇ ਸਹਾਇਕ ਸਨੇਹੇ ਹੋਣ
# ਸਿਸਟਮ ਸਹਾਇਕ ਸੰਦਰਭ ਸੈੱਟ ਕਰਦਾ ਹੈ
# ਯੂਜ਼ਰ ਅਤੇ ਸਹਾਇਕ ਦੇ ਸਨੇਹੇ ਬਹੁ-ਮੁੜਕ ਪ੍ਰਵਚਨ ਸੰਦਰਭ ਪ੍ਰਦਾਨ ਕਰਦੇ ਹਨ
#
# ਧਿਆਨ ਦਿਓ ਕਿ ਸਹਾਇਕ ਦੀ ਸ਼ਖਸੀਅਤ ਸਿਸਟਮ ਸੰਦਰਭ ਵਿੱਚ "ਵੈਰੋਧੀ" ਵਜੋਂ ਸੈੱਟ ਕੀਤੀ ਗਈ ਹੈ।
# ਕੋਈ ਵੱਖਰੀ ਸ਼ਖਸੀਅਤ ਸੰਦਰਭ ਜਾਂ ਵੱਖਰੀ ਇਨਪੁਟ/ਆਉਟਪੁਟ ਸਨੇਹਾ ਲੜੀ ਅਜ਼ਮਾਉ।

# %%
response = client.responses.create(
    model=deployment,
    input=[
        {"role": "system", "content": "You are a sarcastic assistant."},
        {"role": "user", "content": "Who won the world series in 2020?"},
        {"role": "assistant", "content": "Who do you think won? The Los Angeles Dodgers of course."},
        {"role": "user", "content": "Where was it played?"}
    ],
    store=False,
)
print(response.output_text)

# %% [markdown]
# ### ਕਸਰਤ: ਆਪਣੀ ਅੰਦਰੂਨੀ ਸੋਚ ਦਾ ਪਤਾ ਲਗਾਓ
# ਉੱਪਰ ਦਿੱਤੇ ਉਦਾਹਰਨ ਤੁਹਾਨੂੰ ਪੈਟਰਨ ਦਿੰਦੇ ਹਨ ਜਿਨ੍ਹਾਂ ਦਾ ਇਸਤੇਮਾਲ ਕਰਕੇ ਤੁਸੀਂ ਨਵੇਂ ਪ੍ਰਾਂਪਟ (ਸਧਾਰਣ, ਜਟਿਲ, ਹਦਾਇਤ ਆਦਿ) ਬਣਾ ਸਕਦੇ ਹੋ - ਹੋਰ ਕੁਝ ਅਭਿਆਸ ਬਣਾਉਣ ਦੀ ਕੋਸ਼ਿਸ਼ ਕਰੋ ਤਾਂ ਜੋ ਅਸੀਂ ਗੱਲ ਕੀਤੀਆਂ ਹੋਈਆਂ ਹੋਰ ਵਿਚਾਰਾਂ ਜਿਵੇਂ ਕਿ ਉਦਾਹਰਨਾਂ, ਸੰਕੇਤ ਅਤੇ ਹੋਰ ਦੀ ਜਾਂਚ ਕਰ ਸਕੀਏ।

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **ਅਸਵੀਕਾਰੋਪਣ**:
# ਇਸ ਦਸਤਾਵੇਜ਼ ਦਾ ਅਨੁਵਾਦ ਏਆਈ ਅਨੁਵਾਦ ਸੇਵਾ [Co-op Translator](https://github.com/Azure/co-op-translator) ਦੀ ਵਰਤੋਂ ਕਰਕੇ ਕੀਤਾ ਗਿਆ ਹੈ। ਜਦੋਂ ਕਿ ਅਸੀਂ ਸਹੀਤਾਵਾਂ ਲਈ ਯਤਨਸ਼ੀਲ ਹਾਂ, ਕਿਰਪਾ ਕਰਕੇ ਧਿਆਨ ਰੱਖੋ ਕਿ ਸਵੈਚਾਲਿਤ ਅਨੁਵਾਦਾਂ ਵਿੱਚ ਗਲਤੀਆਂ ਜਾਂ ਅਸਮੱਤਿਆਵਾਂ ਹੋ ਸਕਦੀਆਂ ਹਨ। ਮੂਲ ਦਸਤਾਵੇਜ਼ ਆਪਣੀ ਮੂਲ ਭਾਸ਼ਾ ਵਿੱਚ ਅਧਿਕਾਰਕ ਸਰੋਤ ਮੰਨਿਆ ਜਾਣਾ ਚਾਹੀਦਾ ਹੈ। ਜਰੂਰੀ ਜਾਣਕਾਰੀ ਲਈ, ਪੇਸ਼ੇਵਰ ਮਨੁੱਖੀ ਅਨੁਵਾਦ ਦੀ ਸਿਫ਼ਾਰਸ਼ ਕੀਤੀ ਜਾਂਦੀ ਹੈ। ਅਸੀਂ ਇਸ ਅਨੁਵਾਦ ਦੇ ਉਪਯੋਗ ਤੋਂ ਪੈਦਾ ਹੋਣ ਵਾਲੀਆਂ ਕਿਸੇ ਵੀ ਗਲਤਫਹਿਮੀਆਂ ਜਾਂ ਗਲਤ ਵਿਆਖਿਆਵਾਂ ਲਈ ਜਵਾਬਦੇਹ ਨਹੀਂ ਹਾਂ।
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
