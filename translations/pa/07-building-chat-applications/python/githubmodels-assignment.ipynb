# %% [markdown]
# # ਚੈਪਟਰ 7: ਚੈਟ ਐਪਲੀਕੇਸ਼ਨਾਂ ਦੀ ਬਣਤਰ
# ## ਮਾਈਕਰੋਸਾਫਟ ਫਾਊਂਡਰੀ ਮਾਡਲਸ API ਕ੍ਵిక్‌ਸਟਾਰਟ
#
# ਇਹ ਨੋਟਬੁੱਕ [Azure OpenAI Samples Repository](https://github.com/Azure/azure-openai-samples?WT.mc_id=academic-105485-koreyst) ਤੋਂ ਅਨੁਕੂਲਿਤ ਕੀਤੀ ਗਈ ਹੈ ਜਿਸ ਵਿੱਚ ਨੋਟਬੁੱਕ ਸ਼ਾਮਲ ਹਨ ਜੋ [Azure OpenAI](notebook-azure-openai.ipynb) ਸੇਵਾਵਾਂ ਤੱਕ ਪਹੁੰਚਦੇ ਹਨ।
#
# > **ਨੋਟ:** GitHub ਮਾਡਲਸ 2026 ਦੇ ਜੁਲਾਈ ਦੇ ਅੰਤ ਵਿੱਚ ਵਿਸ਼੍ਰਾਮ ਲੈ ਰਹੇ ਹਨ। ਇਹ ਨੋਟਬੁੱਕ ਹੁਣ [Microsoft Foundry Models](https://ai.azure.com/catalog/models?WT.mc_id=academic-105485-koreyst) ਨੂੰ ਧਿਆਨ ਵਿੱਚ ਰੱਖਦਾ ਹੈ, ਜੋ ਇਕੋ ਫ੍ਰੀ-ਟ੍ਰਾਈ ਮਾਡਲ ਕੈਟਾਲਾਗ ਅਤੇ Azure AI ਇਨਫਰੈਂਸ SDK ਅਨੁਭਵ ਪੇਸ਼ ਕਰਦਾ ਹੈ।

# %% [markdown]
# # ਸੰਖੇਪ ਜਾਣਕਾਰੀ
# "ਵੱਡੇ ਭਾਸ਼ਾ ਮਾਡਲਾਂ ਉਹ ਫੰਕਸ਼ਨ ਹਨ ਜੋ ਲਿਖਤ ਨੂੰ ਲਿਖਤ ਵਿੱਚ ਮੈਪ ਕਰਦੇ ਹਨ। ਦਿੱਤੇ ਗਏ ਇਨਪੁੱਟ ਲਿਖਤ ਸਤਰ ਦੇ ਆਧਾਰ 'ਤੇ, ਵੱਡਾ ਭਾਸ਼ਾ ਮਾਡਲ ਅਗਲੇ ਆਉਣ ਵਾਲੇ ਲਿਖਤ ਦੀ ਭਵਿੱਖਬਾਣੀ ਕਰਨ ਦੀ ਕੋਸ਼ਿਸ਼ ਕਰਦਾ ਹੈ"(1)। ਇਹ "ਕਵਿਕਸਟਾਰਟ" ਨੋਟਬੁੱਕ ਉਪਭੋਗਤਾਵਾਂ ਨੂੰ ਉੱਚ-ਪੱਧਰੀ LLM ਧਾਰਣਾਵਾਂ ਨਾਲ ਜਾਣੂ ਕਰਵਾਏਗਾ, AML ਨਾਲ ਸ਼ੁਰੂ ਕਰਨ ਲਈ ਮੂਲ ਪੈਕੇਜ ਦੀਆਂ ਲੋੜਾਂ, ਪ੍ਰੰਪਟ ਡਿਜ਼ਾਈਨ ਵਿੱਚ ਹੌਲੀ ਹੌਲੀ ਪਹਿਚਾਣ, ਅਤੇ ਵੱਖ-ਵੱਖ ਉਪਯੋਗ ਦੇ ਮਾਮਲਿਆਂ ਦੇ ਕਈ ਛੋਟੇ ਉਦਾਹਰਣ ਦਿੱਤੇ ਜਾਣਗੇ।

# %% [markdown]
# ## ਮੈਜ਼ਬਾਨ ਸੰਗ੍ਰਹਿ
#
# [ਸਾਡੇ ਬਾਰੇ](#overview)
# [OpenAI ਸੇਵਾ ਕਿਵੇਂ ਵਰਤੋਂ](#how-to-use-openai-service)
# [1. ਆਪਣੀ OpenAI ਸੇਵਾ ਬਣਾਉਣਾ](#1.-creating-your-openai-service)
# [2. ਇੰਸਟਾਲੇਸ਼ਨ](#2.-installation)
# [3. ਪ੍ਰਮਾਣ ਪੱਤਰ](#3.-credentials)
#
# [ਵਰਤੋਂ ਦੇ ਕੇਸ](#use-cases)
# [1. ਪਾਠ ਸਾਰांश](#1.-summarize-text)
# [2. ਪਾਠ ਵਰਗੀਕਰਨ](#2.-classify-text)
# [3. ਨਵੇਂ ਉਤਪਾਦ ਨਾਮ ਤਿਆਰ ਕਰੋ](#3.-generate-new-product-names)
# [4. ਇੱਕ ਵਰਗੀਕਰਨ ਕਲਾਸ ਦਾ ਸੁਧਾਰ](#4.fine-tune-a-classifier)
#
# [ਹਵਾਲੇ](#references)

# %% [markdown]
# ### ਆਪਣੀ ਪਹਿਲੀ ਪ੍ਰਾਮਪਟ ਬਣਾਓ
# ਇਹ ਛੋਟੀ ਕਸਰਤ ਮਾਈਕਰੋਸਾਫਟ ਫਾਉਂਡਰੀ ਮਾਡਲਾਂ ਵਿੱਚ ਇੱਕ ਸਰਲ ਕੰਮ "ਸੰਖੇਪ ਬਣਾਉਣਾ" ਲਈ ਪ੍ਰਾਮਪਟ ਸਬਮਿਟ ਕਰਨ ਵਾਸਤੇ ਇੱਕ ਬੁਨਿਆਦੀ ਜਾਣੂ ਬਹਾਲ ਕਰੇਗੀ।
#
#
# **ਕਦਮ**:
# 1. ਆਪਣੀ ਪਾਇਥਨ ਵਾਤਾਵਰਨ ਵਿੱਚ `azure-ai-inference` ਲਾਇਬ੍ਰੇਰੀ ਇੰਸਟਾਲ ਕਰੋ, ਜੇ ਤੁਹਾਡੇ ਕੋਲ ਇਹ ਪਹਿਲਾਂ ਨਹੀਂ ਹੈ।
# 2. ਮਿਆਰੀ ਸਹਾਇਕ ਲਾਇਬ੍ਰੇਰੀਆਂ ਲੋਡ ਕਰੋ ਅਤੇ ਆਪਣਾ ਮਾਈਕਰੋਸਾਫਟ ਫਾਉਂਡਰੀ ਮਾਡਲਾਂ ਦੇ ਕ੍ਰੈਡੈਂਸ਼ਲ ਸੈੱਟ ਕਰੋ।
# 3. ਆਪਣੇ ਕੰਮ ਲਈ ਇੱਕ ਮਾਡਲ ਚੁਣੋ
# 4. ਮਾਡਲ ਲਈ ਇੱਕ ਸਰਲ ਪ੍ਰਾਮਪਟ ਬਣਾਓ
# 5. ਆਪਣੀ ਬੇਨਤੀ ਮਾਡਲ API ਨੂੰ ਸੌਂਪੋ!

# %% [markdown]
# ### 1. `azure-ai-inference` ਇੰਸਟਾਲ ਕਰੋ

# %%
# %pip install azure-ai-inference

# %% [markdown]
# ### 2. ਸਹਾਇਕ ਲਾਇਬ੍ਰੇਰੀਆਂ ਨੂੰ ਆਯਾਤ ਕਰੋ ਅਤੇ ਪ੍ਰਮਾਣ ਪੱਤਰ ਬਣਾਓ

# %%
import os
from azure.ai.inference import ChatCompletionsClient
from azure.ai.inference.models import SystemMessage, UserMessage
from azure.core.credentials import AzureKeyCredential

# Get these from your Microsoft Foundry project's "Overview" page
token = os.environ["AZURE_INFERENCE_CREDENTIAL"]
endpoint = os.environ["AZURE_INFERENCE_ENDPOINT"]

client = ChatCompletionsClient(
    endpoint=endpoint,
    credential=AzureKeyCredential(token),
)

# %% [markdown]
# ### 3. ਸਹੀ ਮਾਡਲ ਲੱਭਣਾ
# GPT-4o ਅਤੇ GPT-4o ਮਿਨੀ ਵਰਗੇ ਮਾਡਲ ਕੁਦਰਤੀ ਭਾਸ਼ਾ ਨੂੰ ਸਮਝ ਅਤੇ ਬਣਾਉਣ ਵਿੱਚ ਸਮਰੱਥ ਹਨ, ਅਤੇ ਇਹ ਮਾਈਕ੍ਰੋਸਾਫਟ ਫਾਊਂਡਰੀ ਮਾਡਲਜ਼ ਕੈਟਾਲੌਗ ਵਿੱਚ ਮੇਟਾ, ਮਿਸਟਰਲ, ਕੋਹੀਰ ਅਤੇ ਮਾਈਕ੍ਰੋਸਾਫਟ ਦੇ ਮਾਡਲਾਂ ਦੇ ਨਾਲ ਉਪਲਬਧ ਹਨ।

# %%
# Select a general purpose chat model
model_name = "gpt-4o-mini"

# %% [markdown]
# ## 4. ਪ੍ਰਾਂਪਟ ਡਿਜ਼ਾਈਨ
#
# "ਵੇਖਣਯੋਗ ਭਾਸ਼ਾ ਮਾਡਲਾਂ ਦਾ ਜਾਦੂ ਇਹ ਹੈ ਕਿ ਜਦੋਂ ਇਹਨਾ ਨੂੰ ਵੱਡੀ ਮਾਤਰਾ ਵਿੱਚ ਟੈਕਸਟ 'ਤੇ ਅੰਦਰੂਨੀ ਭਵਿੱਖਬਾਣੀ ਦੀ ਗਲਤੀ ਨੂੰ ਘਟਾਉਣ ਲਈ ਸਿਖਾਇਆ ਜਾਂਦਾ ਹੈ, ਤਾਂ ਮਾਡਲ ਅੰਤੀ ਵਿੱਚ ਉਹ ਧਾਰਨਾਵਾਂ ਸਿੱਖ ਲੈਂਦੇ ਹਨ ਜੋ ਇਹ ਭਵਿੱਖਬਾਣੀ ਲਈ ਲਾਭਦਾਇਕ ਹੁੰਦੀਆਂ ਹਨ। ਉਦਾਹਰਣ ਲਈ, ਇਹ ਧਾਰਨਾਵਾਂ ਸਿੱਖਦੇ ਹਨ, ਜਿਵੇਂ ਕਿ"(1):
#
# * ਸ਼ਬਦਾਂ ਨੂੰ ਕਿਵੇਂ ਸਹੀ ਲਿਖਣਾ ਹੈ
# * ਵਿਆਕਰਣ ਕਿਵੇਂ ਕੰਮ ਕਰਦਾ ਹੈ
# * ਕਿਵੇਂ ਪੈਰਾਫਰੇਜ਼ ਕਰਨਾ ਹੈ
# * ਸਵਾਲਾਂ ਦੇ ਜਵਾਬ ਕਿਵੇਂ ਦੇਣੇ ਹਨ
# * ਗੱਲਬਾਤ ਕਿਵੇਂ ਕਰਨੀ ਹੈ
# * ਕਈ ਭਾਸ਼ਾਵਾਂ ਵਿੱਚ ਲਿਖਣਾ ਕਿਵੇਂ ਹੈ
# * ਕੋਡ ਕਿਵੇਂ ਲਿਖਣਾ ਹੈ
# * ਆਦਿ।
#
# #### ਵੱਡੇ ਭਾਸ਼ਾ ਮਾਡਲ ਨੂੰ ਕਿਵੇਂ ਸੰਭਾਲਣਾ ਹੈ
# "ਵੱਡੇ ਭਾਸ਼ਾ ਮਾਡਲ ਲਈ ਸਾਰੇ ਇਨਪੁੱਟ ਵਿੱਚੋਂ ਸਭ ਤੋਂ ਪ੍ਰਭਾਵਸ਼ਾਲੀ ਕਾਫੀਹਦਾ ਟੈਕਸਟ ਪ੍ਰਾਂਪਟ ਹੁੰਦਾ ਹੈ(1).
#
# ਵੱਡੇ ਭਾਸ਼ਾ ਮਾਡਲ ਨੂੰ ਕੁਝ ਤਰੀਕਿਆਂ ਨਾਲ ਆਉਟਪੁੱਟ ਉਤਪੱਨ ਕਰਨ ਲਈ ਪ੍ਰਾਂਪਟ ਕੀਤਾ ਜਾ ਸਕਦਾ ਹੈ:
#
# ਹਦਾਇਤ: ਮਾਡਲ ਨੂੰ ਦੱਸੋ ਕਿ ਤੁਸੀਂ ਕੀ ਚਾਹੁੰਦੇ ਹੋ
# ਪੂਰੀ ਕਰਨਾ: ਮਾਡਲ ਨੂੰ ਪ੍ਰੇਰਿਤ ਕਰੋ ਕਿ ਉਹ ਤੁਸੀਂ ਜੋ ਚਾਹੁੰਦੇ ਹੋ ਉਸਦੀ ਸ਼ੁਰੂਆਤ ਪੂਰੀ ਕਰੇ
# ਪ੍ਰਦਰਸ਼ਨ: ਮਾਡਲ ਨੂੰ ਦਿਖਾਓ ਕਿ ਤੁਸੀਂ ਕੀ ਚਾਹੁੰਦੇ ਹੋ, ਜਾਂ ਤਾਂ:
# ਪ੍ਰਾਂਪਟ ਵਿੱਚ ਕੁਝ ਉਦਾਹਰਣਾਂ
# ਫਾਈਨ-ਟਿਊਨਿੰਗ ਟ੍ਰੇਨਿੰਗ ਡੇਟਾਸੈੱਟ ਵਿੱਚ ਸੈਂਕੜੇ ਜਾਂ ਹਜ਼ਾਰਾਂ ਉਦਾਹਰਣਾਂ"
#
#
#
# #### ਪ੍ਰਾਂਪਟ ਬਣਾਉਣ ਲਈ ਤਿੰਨ ਬੁਨਿਆਦੀ ਹਦਾਇਤਾਂ ਹਨ:
#
# **ਦਿਖਾਓ ਅਤੇ ਦਸੋ**। ਇਹ ਸਪਸ਼ਟ ਕਰੋ ਕਿ ਤੁਸੀਂ ਕੀ ਚਾਹੁੰਦੇ ਹੋ, ਜਾਂ ਤਾਂ ਹਦਾਇਤਾਂ, ਉਦਾਹਰਣਾਂ ਰਾਹੀਂ, ਜਾਂ ਦੋਹਾਂ ਦੇ ਮਿਲਾਪ ਨਾਲ। ਜੇ ਤੁਸੀਂ ਮਾਡਲ ਨੂੰ ਆਈਟਮਾਂ ਦੀ ਸੂਚੀ ਨੂੰ ਵਰਣਮਾਲਾ ਕ੍ਰਮ ਵਿੱਚ ਰੰਗ ਕਰਨਾ ਜਾਂ ਪੈਰਾਗ੍ਰਾਫ ਨੂੰ ਭਾਵਨਾ ਅਨੁਸਾਰ ਵੰਡਣਾ ਚਾਹੁੰਦੇ ਹੋ, ਤਾਂ ਉਹੀ ਦਿਖਾਓ ਕਿ ਤੁਸੀਂ ਇਹੀ ਚਾਹੁੰਦੇ ਹੋ।
#
# **ਗੁਣਵੱਤਾ ਵਾਲਾ ਡੇਟਾ ਪ੍ਰਦਾਨ ਕਰੋ**। ਜੇ ਤੁਸੀਂ ਇੱਕ ਵਰਗੀਕਰਨਕਾਰ ਬਣਾਉਣ ਦੀ ਕੋਸ਼ਿਸ਼ ਕਰ ਰਹੇ ਹੋ ਜਾਂ ਮਾਡਲ ਨੂੰ ਕਿਸੇ ਪੈਟਰਨ ਦੀ ਪਾਲਣਾ ਕਰਵਾਉਣਾ ਚਾਹੁੰਦੇ ਹੋ, ਤਾਂ ਯਕੀਨੀ ਬਣਾਓ ਕਿ ਪਰਯਾਪਤ ਉਦਾਹਰਣ ਹਨ। ਆਪਣੇ ਉਦਾਹਰਣਾਂ ਨੂੰ ਪੜ੍ਹ ਕੇ ਚੈੱਕ ਕਰੋ — ਮਾਡਲ ਆਮ ਤੌਰ 'ਤੇ ਆਮ ਸਪੈਲਿੰਗ ਗਲਤੀਆਂ ਨੂੰ ਸਮਝ ਸਕਦਾ ਹੈ ਅਤੇ ਤੁਹਾਡੇ ਲਈ ਜਵਾਬ ਦਿੰਦਾ ਹੈ, ਪਰ ਇਸ ਨੂੰ ਸ਼ਾਇਦ ਲੱਗ ਸਕਦਾ ਹੈ ਕਿ ਇਹ ਜਾਣਬੂਝ ਕੇ ਕੀਤਾ ਗਿਆ ਹੈ ਅਤੇ ਇਹ ਜਵਾਬ ਨੂੰ ਪ੍ਰਭਾਵਿਤ ਕਰ ਸਕਦਾ ਹੈ।
#
# **ਆਪਣੇ ਸੈਟਿੰਗਾਂ ਦੀ ਜਾਂਚ ਕਰੋ।** ਟੈਮਪਰਚਰ ਅਤੇ ਟੌਪ_p ਸੈਟਿੰਗ ਮਾਡਲ ਨੂੰ ਜਵਾਬ ਬਣਾਉਣ ਵਿੱਚ ਕਿੰਨਾ ਨਿਰਧਾਰਤ ਹੋਣਾ ਹੈ ਇਸਦਾ ਨਿਯੰਤਰਣ ਕਰਦੀਆਂ ਹਨ। ਜੇ ਤੁਸੀਂ ਉਹ ਜਵਾਬ ਚਾਹੁੰਦੇ ਹੋ ਜਿਸ ਵਿੱਚ ਸਿਰਫ ਇੱਕ ਸਹੀ ਉੱਤਰ ਹੋਵੇ, ਤਾਂ ਤੁਸੀਂ ਇਹ ਸੈਟਿੰਗਾਂ ਘੱਟ ਕਰਨੀ ਚਾਹੀਦੀ ਹੈ। ਜੇ ਤੁਸੀਂ ਵੱਖ-ਵੱਖ ਜਵਾਬ ਚਾਹੁੰਦੇ ਹੋ, ਤਾਂ ਤੁਸੀਂ ਉਨ੍ਹਾਂ ਨੂੰ ਵੱਧ ਕਰ ਸਕਦੇ ਹੋ। ਲੋਕਾਂ ਦੀ ਇੱਕ ਮੁੱਖ ਗਲਤੀ ਇਹ ਹੈ ਕਿ ਉਹ ਇਹ ਸੈਟਿੰਗਾਂ "ਚਤੁਰਾਈ" ਜਾਂ "ਰਚਨਾਤਮਕਤਾ" ਦੇ ਨਿਯੰਤਰਣ ਸਮਝ ਲੈਂਦੇ ਹਨ।
#
#
# ਸਰੋਤ: https://learn.microsoft.com/azure/ai-services/openai/overview

# %% [markdown]
# ### 5. ਸੌਂਪੋ!

# %%
# Create your first prompt
text_prompt = "Should oxford commas always be used?"

response = client.complete(
  model=model_name,
  messages = [{"role":"system", "content":"You are a helpful assistant."},
               {"role":"user","content":text_prompt},])

response.choices[0].message.content

# %% [markdown]
# ### ਉਹੀ ਕਾਲ ਦੁਹਰਾਉ, ਨਤੀਜੇ ਕਿਵੇਂ ਤੁਲਨਾ ਕਰਦੇ ਹਨ?

# %%
response = client.complete(
  model=model_name,
  messages = [{"role":"system", "content":"You are a helpful assistant."},
               {"role":"user","content":text_prompt},])

response.choices[0].message.content

# %% [markdown]
# ## ਲੇਖ ਦਾ ਸਾਰ
# #### ਚੁਣੌਤੀ
# ਲੇਖ ਨੂੰ ਸੰਖੇਪ ਵਿੱਚ ਕਮਾਉਣ ਲਈ ਲੇਖ ਦੇ ਅੰਤ ਵਿੱਚ ਇੱਕ 'tl;dr:' ਜੋੜੋ। ਧਿਆਨ ਦਿਓ ਕਿ ਮਾਡਲ ਕਿਸ ਤਰ੍ਹਾਂ ਬਿਨਾਂ ਕਿਸੇ ਵਾਧੂ ਹਦਾਇਤਾਂ ਦੇ ਕਈ ਕਾਰਜਾਂ ਨੂੰ ਸਮਝਦਾ ਹੈ। ਤੁਸੀਂ ਮਾਡਲ ਦੀ ਵਰਤੋਂ ਨੂੰ ਬਦਲਣ ਅਤੇ ਪ੍ਰਾਪਤ ਕੀਤੀ ਸੰਖੇਪ ਰਚਨਾ ਨੂੰ ਵੱਖਰਾ ਕਰਨ ਲਈ tl;dr ਤੋਂ ਵਧੇਰੇ ਵਰਣਨਾਤਮਕ ਪ੍ਰੰਪਟਾਂ ਨਾਲ ਪ੍ਰਯੋਗ ਕਰ ਸਕਦੇ ਹੋ(3)।
#
# ਹਾਲੀਆ ਕੰਮ ਨੇ ਵੱਡੇ ਪਾਠ ਸੰਗ੍ਰਹਿ 'ਤੇ ਪ੍ਰੀ-ਟ੍ਰੇਨਿੰਗ ਕਰਨ ਅਤੇ ਫਿਰ ਕਿਸੇ ਖਾਸ ਕੰਮ ਲਈ ਫਾਈਨ-ਟਿਊਨਿੰਗ ਕਰਨ ਨਾਲ ਕਈ NLP ਕੰਮਾਂ ਅਤੇ ਮਿਆਰੀਆਂ 'ਤੇ ਵੱਡੇ ਫਾਇਦੇ ਦਰਸਾਏ ਹਨ। ਜਦਕਿ ਆਮ ਤੌਰ 'ਤੇ ਇਹ ਤਰੀਕਾ ਕੰਮ-ਅਗਨੌਸਟਿਕ ਆਰਕੀਟੈਕਚਰ ਵਿੱਚ ਹੁੰਦਾ ਹੈ, ਇਹ ਤਰੀਕਾ ਫਿਰ ਵੀ ਹਜਾਰਾਂ ਜਾਂ ਦਸ ਹਜ਼ਾਰਾਂ ਉਦਾਹਰਨਾਂ ਦੇ ਕੰਮ-ਖਾਸ ਫਾਈਨ-ਟਿਊਨਿੰਗ ਡੇਟਾਸੈੱਟ ਦੀ ਲੋੜ ਰੱਖਦਾ ਹੈ। ਉਸ ਦੇ ਮੁਕਾਬਲੇ, ਮਨੁੱਖ ਆਮ ਤੌਰ 'ਤੇ ਸਿਰਫ ਕੁਝ ਉਦਾਹਰਨਾਂ ਜਾਂ ਸਧਾਰਨ ਹੁਕਮਾਂ ਤੋਂ ਇੱਕ ਨਵਾਂ ਭਾਸ਼ਾ ਕੰਮ ਕਰ ਸਕਦੇ ਹਨ – ਜੋ ਕਿ ਮੌਜੂਦਾ NLP ਸਿਸਟਮ ਆਮ ਤੌਰ 'ਤੇ ਅਜੇ ਵੀ ਬੜੀ ਮੁਸ਼ਕਲ ਨਾਲ ਕਰਦੇ ਹਨ। ਇੱਥੇ ਅਸੀਂ ਦਿਖਾਉਂਦੇ ਹਾਂ ਕਿ ਭਾਸ਼ਾ ਮਾਡਲਾਂ ਦਾ ਵੱਧ ਰਿਹਾ ਆਕਾਰ ਬਿਨਾਂ ਕਿਸੇ ਖਾਸ ਕੰਮ ਦੀ ਪ੍ਰੀ-ਟ੍ਰੇਨਿੰਗ ਦੇ, ਕੁਝ ਉਦਾਹਰਨਾਂ 'ਤੇ ਕੰਮ ਕਰਨ ਦੀ ਸਮਰੱਥਾ ਨੂੰ ਬਹੁਤ ਵਧਾਉਂਦਾ ਹੈ, ਕਈ ਵਾਰੀ ਇਹ ਪਹਿਲਾਂ ਦੇ ਸਰਵੋਤਮ ਫਾਈਨ-ਟਿਊਨਿੰਗ ਤਰੀਕਿਆਂ ਦੇ ਮੁਕਾਬਲੇ ਵਿੱਚ ਭੀ ਪ੍ਰਤੀਸਪਰਧੀ ਹੋ ਜਾਂਦਾ ਹੈ।
#
#
#
# ਟੀਪ; ਡੀ.ਆਰ.

# %% [markdown]
# # ਕਈ ਵਰਤੋਂ ਦੇ ਮਾਮਲਿਆਂ ਲਈ ਅਭਿਆਸ
# 1. ਲਿਖਤ ਦਾ ਸਾਰ ਸੰਗ੍ਰਹਿ ਕਰੋ
# 2. ਲਿਖਤ ਨੂੰ ਵਰਗੀਕ੍ਰਿਤ ਕਰੋ
# 3. ਨਵੇਂ ਉਤਪਾਦ ਨਾਮ ਬਣਾਓ

# %%
prompt = "Recent work has demonstrated substantial gains on many NLP tasks and benchmarks by pre-training on a large corpus of text followed by fine-tuning on a specific task. While typically task-agnostic in architecture, this method still requires task-specific fine-tuning datasets of thousands or tens of thousands of examples. By contrast, humans can generally perform a new language task from only a few examples or from simple instructions - something that current NLP systems still largely struggle to do. Here we show that scaling up language models greatly improves task-agnostic, few-shot performance, sometimes even reaching competitiveness with prior state-of-the-art fine-tuning approaches.\n\nTl;dr"

# %%
#Setting a few additional, typical parameters during API Call

response = client.complete(
  model=model_name,
  messages = [{"role":"system", "content":"You are a helpful assistant."},
               {"role":"user","content":prompt},])

response.choices[0].message.content

# %% [markdown]
# ## ਲੇਖ ਨੂੰ ਵਰਗੀਕ੍ਰਿਤ ਕਰੋ
# #### ਚੁਣੌਤੀ
# ਆਈਟਮਾਂ ਨੂੰ ਉਸ ਸਮੇਂ ਦਿੱਤੀਆਂ ਗਈਆਂ ਸ਼੍ਰੇਣੀਆਂ ਵਿੱਚ ਵਰਗੀਕ੍ਰਿਤ ਕਰੋ ਜਦੋਂ ਇੰਫਰੈਂਸ ਕੀਤਾ ਜਾ ਰਿਹਾ ਹੈ। ਹੇਠਾਂ ਦਿੱਤੇ ਉਦਾਹਰਨ ਵਿੱਚ, ਅਸੀਂ ਦੋਹਾਂ ਸ਼੍ਰੇਣੀਆਂ ਅਤੇ ਵਰਗੀਕ੍ਰਿਤ ਕਰਨ ਲਈ ਟੈਕਸਟ ਪ੍ਰਾਪਟ ਵਿੱਚ ਪ੍ਰਦਾਨ ਕਰਦੇ ਹਾਂ(*playground_reference)।
#
# ਗ੍ਰਾਹਕ ਪੁੱਛਗਿੱਛ: ਸਤ ਸ੍ਰੀ ਅਕਾਲ, ਮੇਰੇ ਲੈਪਟਾਪ ਦੀਪਰ ਕੁੰਜੀ ਹਾਲ ਹੀ ਵਿੱਚ ਟੁੱਟ ਗਈ ਹੈ ਅਤੇ ਮੈਨੂੰ ਇਸਦਾ ਬਦਲੀ ਚਾਹੀਦੀ ਹੈ:
#
# ਵਰਗੀਕ੍ਰਿਤ ਸ਼੍ਰੇਣੀ:

# %%
prompt = "Classify the following inquiry into one of the following: categories: [Pricing, Hardware Support, Software Support]\n\ninquiry: Hello, one of the keys on my laptop keyboard broke recently and I'll need a replacement:\n\nClassified category:"
print(prompt)

# %%
#Setting a few additional, typical parameters during API Call

response = client.complete(
  model=model_name,
  messages = [{"role":"system", "content":"You are a helpful assistant."},
               {"role":"user","content":prompt},])

response.choices[0].message.content

# %% [markdown]
# ## ਨਵੇਂ ਉਤਪਾਦ ਨਾਮ ਬਣਾਓ
# #### ਚੁਣੌਤੀ
# ਉਦਾਹਰਨ ਸ਼ਬਦਾਂ ਤੋਂ ਉਤਪਾਦ ਨਾਮ ਬਣਾਓ। ਇੱਥੇ ਅਸੀਂ ਪ੍ਰੋਮਪਟ ਵਿੱਚ ਉਸ ਉਤਪਾਦ ਬਾਰੇ ਜਾਣਕਾਰੀ ਸ਼ਾਮਲ ਕਰਦੇ ਹਾਂ ਜਿਸ ਲਈ ਅਸੀਂ ਨਾਮ ਬਣਾਉਣ ਜਾ ਰਹੇ ਹਾਂ। ਅਸੀਂ ਉਦਾਹਰਨ ਵੀ ਦਿੰਦੇ ਹਾਂ ਤਾਂ ਜੋ ਅਸੀਂ ਜਿਹੜਾ ਨਮੂਨਾ ਲੈਣਾ ਚਾਹੁੰਦੇ ਹਾਂ ਉਹ ਸਪਸ਼ਟ ਹੋ ਜਾਵੇ। ਅਸੀਂ ਤਾਪਮਾਨ ਦਾ ਮੁੱਲ ਉੱਚਾ ਰੱਖਿਆ ਹੈ ਤਾਂ ਜੋ ਬੇਤਰਤੀਬੀ ਅਤੇ ਵਧੇਰੇ ਨਵੀਨਤਮ ਜਵਾਬ ਮਿਲ ਸਕਣ।
#
# ਉਤਪਾਦ ਵੇਰਵਾ: ਇਕ ਘਰੇਲੂ ਮਿਲਕਸ਼ੇਕ ਮਸ਼ੀਨ
# ਬੀਜ ਸ਼ਬਦ: ਤੇਜ਼, ਸਿਹਤਮੰਦ, ਕੰਪੈਕਟ।
# ਉਤਪਾਦ ਨਾਮ: HomeShaker, Fit Shaker, QuickShake, Shake Maker
#
# ਉਤਪਾਦ ਵੇਰਵਾ: ਇੱਕ ਜੁੜਾ ਜੁੱਤਾ ਜੋ ਕਿਸੇ ਵੀ ਪੈਰ ਦੇ ਆਕਾਰ ਵਿੱਚ ਫਿੱਟ ਹੋ ਸਕਦਾ ਹੈ।
# ਬੀਜ ਸ਼ਬਦ: ਅਨੁਕੂਲ, ਫਿੱਟ, ਓਮਨੀ-ਫਿੱਟ।

# %%
prompt = "Product description: A home milkshake maker\nSeed words: fast, healthy, compact.\nProduct names: HomeShaker, Fit Shaker, QuickShake, Shake Maker\n\nProduct description: A pair of shoes that can fit any foot size.\nSeed words: adaptable, fit, omni-fit."

print(prompt)

# %%
#Setting a few additional, typical parameters during API Call

response = client.complete(
  model=model_name,
  messages = [{"role":"system", "content":"You are a helpful assistant."},
               {"role":"user","content":prompt}])

response.choices[0].message.content

# %% [markdown]
# # ਸਰੋਤ
# - [Openai Cookbook](https://github.com/openai/openai-cookbook?WT.mc_id=academic-105485-koreyst)
# - [Microsoft Foundry portal](https://ai.azure.com?WT.mc_id=academic-105485-koreyst)
# - [ਪਾਠ ਨੂੰ ਵਰਗੀਕ੍ਰਿਤ ਕਰਨ ਲਈ GPT ਮਾਡਲਾਂ ਨੂੰ ਫਾਈਨ-ਟਿਊਨਿੰਗ ਕਰਨ ਦੀਆਂ ਸਭ ਤੋਂ ਵਧੀਆ ਪ੍ਰਥਾਵਾਂ](https://platform.openai.com/docs/guides/fine-tuning?WT.mc_id=academic-105485-koreyst)

# %% [markdown]
# # ਹੋਰ ਮਦਦ ਲਈ
# [OpenAI Commercialization Team](AzureOpenAITeam@microsoft.com)

# %% [markdown]
# # ਯੋਗਦਾਤਾ
# * [Chew-Yean Yam](https://www.linkedin.com/in/cyyam/)

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **ਅਸਵੀਕਾਰੋਪਣ**:
# ਇਸ ਦਸਤਾਵੇਜ਼ ਦਾ ਅਨੁਵਾਦ ਏਆਈ ਅਨੁਵਾਦ ਸੇਵਾ [Co-op Translator](https://github.com/Azure/co-op-translator) ਦੀ ਵਰਤੋਂ ਕਰਕੇ ਕੀਤਾ ਗਿਆ ਹੈ। ਜਦੋਂ ਕਿ ਅਸੀਂ ਸਹੀਤਾਵਾਂ ਲਈ ਯਤਨਸ਼ੀਲ ਹਾਂ, ਕਿਰਪਾ ਕਰਕੇ ਧਿਆਨ ਰੱਖੋ ਕਿ ਸਵੈਚਾਲਿਤ ਅਨੁਵਾਦਾਂ ਵਿੱਚ ਗਲਤੀਆਂ ਜਾਂ ਅਸਮੱਤਿਆਵਾਂ ਹੋ ਸਕਦੀਆਂ ਹਨ। ਮੂਲ ਦਸਤਾਵੇਜ਼ ਆਪਣੀ ਮੂਲ ਭਾਸ਼ਾ ਵਿੱਚ ਅਧਿਕਾਰਕ ਸਰੋਤ ਮੰਨਿਆ ਜਾਣਾ ਚਾਹੀਦਾ ਹੈ। ਜਰੂਰੀ ਜਾਣਕਾਰੀ ਲਈ, ਪੇਸ਼ੇਵਰ ਮਨੁੱਖੀ ਅਨੁਵਾਦ ਦੀ ਸਿਫ਼ਾਰਸ਼ ਕੀਤੀ ਜਾਂਦੀ ਹੈ। ਅਸੀਂ ਇਸ ਅਨੁਵਾਦ ਦੇ ਉਪਯੋਗ ਤੋਂ ਪੈਦਾ ਹੋਣ ਵਾਲੀਆਂ ਕਿਸੇ ਵੀ ਗਲਤਫਹਿਮੀਆਂ ਜਾਂ ਗਲਤ ਵਿਆਖਿਆਵਾਂ ਲਈ ਜਵਾਬਦੇਹ ਨਹੀਂ ਹਾਂ।
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
