# %% [markdown]
# # ਅਧਿਆਇ 7: ਚੈਟ ਐਪਲੀਕੇਸ਼ਨਾਂ ਦਾ ਨਿਰਮਾਣ
# ## ਮਾਈਕਰੋਸੌਫਟ ਫਾਉਂਡਰੀ ਮਾਡਲਜ਼ API ਕੁਇਕਸਟਾਰਟ
#
# ਇਹ ਨੋਟਬੁੱਕ [Azure OpenAI Samples Repository](https://github.com/Azure/azure-openai-samples?WT.mc_id=academic-105485-koreyst) ਤੋਂ ਅਨੁਕੂਲਿਤ ਹੈ ਜਿਸ ਵਿੱਚ ਨਾੈਟਬੁੱਕ ਸ਼ਾਮਲ ਹਨ ਜੋ [Azure OpenAI](notebook-azure-openai.ipynb) ਸੇਵਾਵਾਂ ਤੱਕ ਪਹੁੰਚਦੇ ਹਨ।
#
# > **ਨੋਟ:** GitHub ਮਾਡਲਜ਼ ਜੁਲਾਈ 2026 ਦੇ ਅੰਤ ਵਿਚ ਸੰਨਾਸ ਕਰ ਰਹੇ ਹਨ। ਇਹ ਨੋਟਬੁੱਕ ਹੁਣ [Microsoft Foundry Models](https://ai.azure.com/catalog/models?WT.mc_id=academic-105485-koreyst) ਨੂੰ ਨਿਸ਼ਾਨਾ ਬਣਾਉਂਦਾ ਹੈ, ਜੋ ਉਹੋ ਜਿਹਾ ਮੁਫ਼ਤ ਟ੍ਰਾਈ ਕਰਨ ਵਾਲਾ ਮਾਡਲ ਕੈਟਾਲੌਗ ਅਤੇ Azure AI Inference SDK ਅਨੁਭਵ ਪ੍ਰਦਾਨ ਕਰਦਾ ਹੈ।

# %% [markdown]
# # ਓਵਰਵਿਊ
# "ਵੱਡੇ ਭਾਸ਼ਾ ਮਾਡਲ ਫੰਕਸ਼ਨਾਂ ਹਨ ਜੋ ਟੈਕਸਟ ਨੂੰ ਟੈਕਸਟ ਨਾਲ ਜੋੜਦੇ ਹਨ। ਦਿੱਤੇ ਗਏ ਇਨਪੁਟ ਟੈਕਸਟ ਸਟਰਿੰਗ ਦੇ ਅਧਾਰ 'ਤੇ, ਇੱਕ ਵੱਡਾ ਭਾਸ਼ਾ ਮਾਡਲ ਅਗਲਾ ਆਉਣ ਵਾਲਾ ਟੈਕਸਟ ਅਨੁਮਾਨਿਤ ਕਰਨ ਦੀ ਕੋਸ਼ਿਸ਼ ਕਰਦਾ ਹੈ"(1)। ਇਹ "ਕੁਇਕਸਟਾਰਟ" ਨੋਟਬੁੱਕ ਉਪਭੋਗਤਾਵਾਂ ਨੂੰ ਉੱਚ-ਸਤਰ ਦੇ LLM ਸਰੂਪਾਂ, AML ਨਾਲ ਸ਼ੁਰੂਆਤ ਲਈ ਮੁੱਖ ਪੈਕੇਜ ਲੋੜਾਂ, ਪ੍ਰਭਾਵਿਤ ਡਿਜ਼ਾਈਨ ਲਈ ਇਕ ਨਰਮ ਜਾਣ-ਪਛਾਣ, ਅਤੇ ਵੱਖ-ਵੱਖ ਵਰਤੋਂ ਦੇ ਕੇਸਾਂ ਦੇ ਕਈ ਛੋਟੇ ਉਦਾਹਰਣਾਂ ਨਾਲ ਜਾਣੂ ਕਰਵਾਏਗੀ।

# %% [markdown]
# ## ਵਿਸ਼ਯ ਸੂਚੀ
#
# [ਸਮਰੀਖਿਆ](#overview)
# [OpenAI ਸੇਵਾ ਦਾ ਵਰਤੋਂ ਕਿਵੇਂ ਕਰੀਏ](#how-to-use-openai-service)
# [1. ਆਪਣੀ OpenAI ਸੇਵਾ ਬਣਾਉਣਾ](#1.-creating-your-openai-service)
# [2. ਇੰਸਟਾਲੇਸ਼ਨ](#2.-installation)
# [3. ਪ੍ਰਮਾਣ ਪੱਤਰ](#3.-credentials)
#
# [ਵਰਤੋਂ ਦੇ ਕੇਸ](#use-cases)
# [1. ਟੈਕਸਟ ਦਾ ਸਾਰ](#1.-summarize-text)
# [2. ਟੈਕਸਟ ਦਾ ਵਰਗੀਕਰਨ](#2.-classify-text)
# [3. ਨਵੇਂ ਉਤਪਾਦ ਦੇ ਨਾਮ ਬਣਾਉਣਾ](#3.-generate-new-product-names)
# [4. ਇੱਕ ਵਰਗੀਕਰਤਾ ਨੂੰ ਬਿਹਤਰ ਬਣਾਉਣਾ](#4.fine-tune-a-classifier)
#
# [ਹਵਾਲੇ](#references)

# %% [markdown]
# ### ਆਪਣਾ ਪਹਿਲਾ ਪ੍ਰਾਂਪਟ ਬਣਾਓ
# ਇਹ ਛੋਟਾ ਅਭਿਆਸ ਮਾਇਕਰੋਸਾਫਟ ਫਾਊਂਡਰੀ ਮਾਡਲਸ ਵਿੱਚ ਇਕ ਸਾਦਾ ਕੰਮ "ਸੰਖੇਪ" ਲਈ ਮਾਡਲ ਨੂੰ ਪ੍ਰਾਂਪਟ ਸੱਬਮਿਟ ਕਰਨ ਦੀ ਬੁਨਿਆਦੀ ਜਾਣਕਾਰੀ ਦੇਵੇਗਾ।
#
#
# **ਕਦਮ**:
# 1. ਜੇ ਤੁਸੀਂ ਨਹੀਂ ਕੀਤਾ ਤਾਂ ਆਪਣੇ ਪਾਇਥਨ ਵਾਤਾਵਰਨ ਵਿੱਚ `azure-ai-inference` ਲਾਇਬ੍ਰੇਰੀ ਇੰਸਟਾਲ ਕਰੋ।
# 2. ਮਿਆਰੀ ਮਦਦਗਾਰ ਲਾਇਬ੍ਰੇਰੀਆਂ ਲੋਡ ਕਰੋ ਅਤੇ ਆਪਣੇ ਮਾਇਕਰੋਸਾਫਟ ਫਾਊਂਡਰੀ ਮਾਡਲਸ ਸਨਦਾਂ ਸੈੱਟ ਕਰੋ।
# 3. ਆਪਣੇ ਕੰਮ ਲਈ ਇੱਕ ਮਾਡਲ ਚੁਣੋ
# 4. ਮਾਡਲ ਲਈ ਇੱਕ ਸਧਾਰਣ ਪ੍ਰਾਂਪਟ ਬਣਾਓ
# 5. ਆਪਣੇ ਬੇਨਤੀ ਨੂੰ ਮਾਡਲ API ਨੂੰ ਸੌਂਪੋ!

# %% [markdown]
# ### 1. `azure-ai-inference` ਨੂੰ ਇੰਸਟਾਲ ਕਰੋ

# %%
# %pip install azure-ai-inference

# %% [markdown]
# ### 2. ਸਹਾਇਕ ਲਾਇਬ੍ਰੇਰੀਆਂ ਦੀ ਆਯਾਤ ਕਰੋ ਅਤੇ ਪ੍ਰਮਾਣ ਪੱਤਰ ਬਣਾਓ

# %%
import os
from azure.ai.inference import ChatCompletionsClient
from azure.ai.inference.models import SystemMessage, UserMessage
from azure.core.credentials import AzureKeyCredential

# Get these from your Microsoft Foundry project's "Overview" page
token = os.environ["AZURE_INFERENCE_CREDENTIAL"]
endpoint = os.environ["AZURE_INFERENCE_ENDPOINT"]

client = ChatCompletionsClient(
    endpoint=endpoint,
    credential=AzureKeyCredential(token),
)

# %% [markdown]
# ### 3. ਸਹੀ ਮਾਡਲ ਲੱਭਣਾ
# GPT-4o ਅਤੇ GPT-4o ਮਿਨੀ ਵਰਗੇ ਮਾਡਲ ਕੁਦਰਤੀ ਭਾਸ਼ਾ ਨੂੰ ਸਮਝ ਸਕਦੇ ਹਨ ਅਤੇ ਬਣਾਉਂਦੇ ਹਨ, ਅਤੇ ਮਾਈਕਰੋਸਾਫਟ ਫੌਂਡਰੀ ਮਾਡਲ ਕੈਟਲੌਗ ਵਿੱਚ ਮੈਟਾ, ਮਿਸਟਰਲ, ਕੋਹੀਰ ਅਤੇ ਮਾਈਕਰੋਸਾਫਟ ਤੋਂ ਮਾਡਲਾਂ ਦੇ ਨਾਲ ਉਪਲਬਧ ਹਨ।

# %%
# Select a general purpose chat model
model_name = "gpt-5-mini"

# %% [markdown]
# ## 4. ਪ੍ਰਾਂਪਟ ਡਿਜ਼ਾਈਨ
#
# "ਵੱਡੇ ਭਾਸ਼ਾਈ ਮਾਡਲਾਂ ਦੀ ਜਾਦੂਗਰੀ ਇਹ ਹੈ ਕਿ ਵੱਡੀ ਮਾਤਰਾ ਵਿੱਚ ਟੈਕਸਟ 'ਤੇ ਇਸ ਭਵਿੱਖਬਾਣੀ ਗਲਤੀ ਨੂੰ ਘਟਾਉਣ ਲਈ ਸਿਖਲਾਈ ਦੇਣ ਨਾਲ, ਮਾਡਲ ਉਹਨਾਂ ਭਵਿੱਖਬਾਣੀਆਂ ਲਈ ਲਾਭਦਾਇਕ ਸੰਕਲਪ ਸਿੱਖ ਲੈਂਦੇ ਹਨ। ਉਦਾਹਰਣ ਲਈ, ਇਹ ਉਹ ਸਿੱਖਦੇ ਹਨ ਜੋ ਕੰਸੈਪਟ ਹਨ"(1):
#
# * ਕਿਵੇਂ ਸਪੈਲ ਕਰਨਾ ਹੈ
# * ਕਿਵੇਂ ਵਿਆਕਰਣ ਕੰਮ ਕਰਦਾ ਹੈ
# * ਕਿਵੇਂ ਪਰਾਫਰੇਜ਼ ਕਰਨਾ ਹੈ
# * ਕਿਵੇਂ ਪ੍ਰਸ਼ਨਾਂ ਦੇ ਜਵਾਬ ਦੇਣੇ ਹਨ
# * ਕਿਵੇਂ ਗੱਲਬਾਤ ਬਰਕਰਾਰ ਰੱਖਣੀ ਹੈ
# * ਕਈ ਭਾਸ਼ਾਵਾਂ ਵਿੱਚ ਕਿਵੇਂ ਲਿਖਣਾ ਹੈ
# * ਕਿਵੇਂ ਕੋਡ ਕਰਨਾ ਹੈ
# * ਆਦਿ।
#
# #### ਵੱਡੇ ਭਾਸ਼ਾਈ ਮਾਡਲ ਨੂੰ ਕਿਵੇਂ ਕਾਬੂ ਕੀਤਾ ਜਾਏ
# "ਵੱਡੇ ਭਾਸ਼ਾਈ ਮਾਡਲ ਨੂੰ ਦਿੱਤੇ ਗਏ ਸਾਰੇ ਇਨਪੁੱਟਾਂ ਵਿੱਚੋਂ, ਸਭ ਤੋਂ ਪ੍ਰਭਾਵਸ਼ালী ਟੈਕਸਟ ਪ੍ਰਾਂਪਟ ਹੁੰਦਾ ਹੈ(1).
#
# ਵੱਡੇ ਭਾਸ਼ਾਈ ਮਾਡਲਾਂ ਨੂੰ ਕੁਝ ਤਰੀਕਿਆਂ ਨਾਲ ਆਊਟਪੁੱਟ ਦੇਣ ਲਈ ਪ੍ਰਾਂਪਟ ਕੀਤਾ ਜਾ ਸਕਦਾ ਹੈ:
#
# ਦਿਸ਼ਾ-ਨਿਰਦੇਸ਼: ਮਾਡਲ ਨੂੰ ਦੱਸੋ ਕਿ ਤੁਸੀਂ ਕੀ ਚਾਹੁੰਦੇ ਹੋ
# ਪੂਰੀਕਰਨ: ਮਾਡਲ ਨੂੰ ਪ੍ਰੇਰਿਤ ਕਰੋ ਕਿ ਉਹ ਜਿਸ ਚੀਜ ਦੀ ਸ਼ੁਰੂਆਤ ਤੁਸੀਂ ਚਾਹੁੰਦੇ ਹੋ ਉਹ ਪੂਰੀ ਕਰੇ
# ਪ੍ਰਦਰਸ਼ਨ: ਮਾਡਲ ਨੂੰ ਦਿਖਾਓ ਕਿ ਤੁਸੀਂ ਕੀ ਚਾਹੁੰਦੇ ਹੋ, ਜਾਂ ਤਾਂ:
# ਪ੍ਰਾਂਪਟ ਵਿੱਚ ਕੁਝ ਉਦਾਹਰਣਾਂ
# ਇੱਕ ਫਾਈਨ-ਟਿਊਨਿੰਗ ਟਰੇਨਿੰਗ ਡੇਟਾਸੇਟ ਵਿੱਚ ਸੈਂਕੜੇ ਜਾਂ ਹਜ਼ਾਰਾਂ ਉਦਾਹਰਣਾਂ"
#
#
#
# #### ਪ੍ਰਾਂਪਟ ਬਣਾਉਣ ਲਈ ਤਿੰਨ ਮੁੱਢਲੇ ਨਿਯਮ ਹਨ:
#
# **ਦਿਖਾਓ ਅਤੇ ਦੱਸੋ**। ਇਹ ਸਾਫ਼ ਕਰੋ ਕਿ ਤੁਸੀਂ ਕੀ ਚਾਹੁੰਦੇ ਹੋ, ਚਾਹੇ ਉਹ ਦਿਸ਼ਾ-ਨਿਰਦੇਸ਼ਾਂ, ਉਦਾਹਰਣਾਂ ਕੇ ਦੁਆਰਾ ਹੋਵੇ ਜਾਂ ਦੋਹਾਂ ਦੇ ਮਿਲਾਪ ਨਾਲ। ਜੇ ਤੁਸੀਂ ਮਾਡਲ ਨੂੰ ਕਿਸੇ ਚੀਜ਼ ਦੀ ਸੂਚੀ ਨੂੰ ਵਰਣਮਾਲਾ ਕ੍ਰਮ ਵਿੱਚ ਰੈਂਕ ਕਰਵਾਉਣਾ ਜਾਂ ਇੱਕ ਪੈਰਾ ਨੂੰ ਭਾਵਨਾਤਮਕਤਾ ਦੇ ਅਧਾਰ 'ਤੇ ਵਰਗੀਕ੍ਰਿਤ ਕਰਵਾਉਣਾ ਚਾਹੁੰਦੇ ਹੋ, ਤਾਂ ਇਸ ਨੂੰ ਵਿਖਾਓ ਕਿ ਇਹੀ ਤੁਸੀਂ ਚਾਹੁੰਦੇ ਹੋ।
#
# **ਗੁਣਵੱਤਾ ਵਾਲਾ ਡੇਟਾ ਮੁਹੱਈਆ ਕਰੋ**। ਜੇ ਤੁਸੀਂ ਕਿਸੇ ਵਰਗੀਕਰਤਾ ਨੂੰ ਬਣਾਉਣ ਦੀ ਕੋਸ਼ਿਸ਼ ਕਰ ਰਹੇ ਹੋ ਜਾਂ ਮਾਡਲ ਨੂੰ ਕਿਸੇ ਨਕਸ਼ੇ ਦਾ ਪਾਲਣ ਕਰਨ ਲਈ ਕਹਿ ਰਹੇ ਹੋ, ਤਾਂ ਯਕੀਨੀ ਬਣਾਓ ਕਿ ਕਾਫੀ ਉਦਾਹਰਣਾਂ ਹਨ। ਆਪਣੇ ਉਦਾਹਰਣਾਂ ਦੀ ਪ੍ਰੂਫਰੀਡਿੰਗ ਕਰੋ — ਮਾਡਲ ਆਮ ਤੌਰ 'ਤੇ ਉਹਨਾਂ ਬੁਨਿਆਦੀ ਸਪੈਲਿੰਗ ਗਲਤੀਆਂ ਨੂੰ ਵੇਖ ਕੇ ਜਵਾਬ ਦੇਣ ਲਈ ਕਾਫੀ ਸਮਝਦਾਰ ਹੁੰਦਾ ਹੈ, ਪਰ ਇਹ ਵੀ ਧਾਰਣਾ ਕਰ ਸਕਦਾ ਹੈ ਕਿ ਇਹ ਜਾਣ-ਬੁਧਕੇ ਹੈ ਅਤੇ ਇਸ ਨਾਲ ਜਵਾਬ ਪ੍ਰਭਾਵਿਤ ਹੋ ਸਕਦਾ ਹੈ।
#
# **ਆਪਣੀਆਂ ਸੈਟਿੰਗਜ਼ ਦੀ ਜਾਂਚ ਕਰੋ।** ਟੈਮਪਰੇਚਰ ਅਤੇ ਟਾਪ_ਪੀ ਸੈਟਿੰਗਜ਼ ਨਿਰਧਾਰਿਤ ਕਰਦੀਆਂ ਹਨ ਕਿ ਮਾਡਲ ਜਵਾਬ ਦੇਣ ਵਿੱਚ ਕਿੰਨਾ ਡਿਟਰਮਿਨਿਸਟਿਕ ਹੈ। ਜੇ ਤੁਸੀਂ ਉਸੇ ਸਹੀ ਜਵਾਬ ਲਈ ਪੁੱਛ ਰਹੇ ਹੋ, ਤਾਂ ਤੁਸੀਂ ਇਹਨਾਂ ਨੂੰ ਘੱਟ ਰੱਖਣਾ ਚਾਹੁੰਦੇ ਹੋ। ਜੇ ਤੁਸੀਂ ਵੱਖ-ਵੱਖ ਪ੍ਰਤੀਕਿਰਿਆਵਾਂ ਲਈ ਲੱਭ ਰਹੇ ਹੋ, ਤਾਂ ਤੁਸੀਂ ਇਹਨਾਂ ਨੂੰ ਵਧੀਆ ਰੱਖਣਾ ਚਾਹੁੰਦੇ ਹੋ। ਲੋਕਾਂ ਦੀ ਸਭ ਤੋਂ ਵੱਡੀ ਗਲਤੀ ਇਹ ਸਮਝਣਾ ਹੈ ਕਿ ਇਹ ਸੈਟਿੰਗਜ਼ "ਸਿਆਣਪ" ਜਾਂ "ਰਚਨਾਤਮਕਤਾ" ਨੂੰ ਕੰਟਰੋਲ ਕਰਦੀਆਂ ਹਨ।
#
#
# ਸਰੋਤ: https://learn.microsoft.com/azure/ai-foundry/openai/overview

# %% [markdown]
# ### 5. ਜਮ੍ਹਾਂ ਕਰੋ!

# %%
# Create your first prompt
text_prompt = "Should oxford commas always be used?"

response = client.complete(
  model=model_name,
  messages = [{"role":"system", "content":"You are a helpful assistant."},
               {"role":"user","content":text_prompt},])

response.choices[0].message.content

# %% [markdown]
# ### ਇਕੋ ਕਾਲ ਨੂੰ ਦੁਹਰਾਓ, ਨਤੀਜੇ ਕਿਵੇਂ ਤੁਲਨਾ ਕਰਦੇ ਹਨ?

# %%
response = client.complete(
  model=model_name,
  messages = [{"role":"system", "content":"You are a helpful assistant."},
               {"role":"user","content":text_prompt},])

response.choices[0].message.content

# %% [markdown]
# ## ਟੈਕਸਟ ਦਾ ਸਾਰ
# #### ਚੁਣੌਤੀ
# ਟੈਕਸਟ ਪੈਸੇਜ ਦੇ ਅਖੀਰ ਵਿੱਚ 'tl;dr:' ਜੋੜ ਕੇ ਟੈਕਸਟ ਦਾ ਸਾਰ ਦਿੱਤਾ ਜਾਵੇ। ਧਿਆਨ ਦਿਓ ਕਿ ਮਾਡਲ ਕਿਵੇਂ ਬਿਨਾਂ ਵਾਧੂ ਹੁਕਮਾਂ ਦੇ ਕਈ ਕੰਮ ਕਰਨ ਦੀ ਸਮਝ ਰੱਖਦਾ ਹੈ। ਤੁਸੀਂ ਮਾਡਲ ਦੇ ਵਤੀਰੇ ਨੂੰ ਬਦਲਣ ਅਤੇ ਪ੍ਰਾਪਤ ਸਭਾਵਾਂ ਦਾ ਨਿੱਜੀਕਰਨ ਕਰਨ ਲਈ tl;dr ਤੋਂ ਵੱਧ ਵਰਣਨਾਤਮਕ ਪ੍ਰੰਪਟਸ ਨਾਲ ਪ੍ਰਯੋਗ ਕਰ ਸਕਦੇ ਹੋ(3)।
#
# ਹਾਲੀਆ ਕੰਮ ਵਿੱਚ ਇੱਕ ਵੱਡੇ ਪਾਠ ਕੋਰਪਸ 'ਤੇ ਪ੍ਰੀ-ਟ੍ਰੇਨਿੰਗ ਅਤੇ ਫਿਰ ਕਿਸੇ ਵਿਸ਼ੇਸ਼ ਕੰਮ 'ਤੇ ਫਾਈਨ-ਟਿਊਨਿੰਗ ਰਾਹੀਂ ਬਹੁਤ ਸਾਰੇ NLP ਕੰਮਾਂ ਅਤੇ ਬੈਂਚਮਾਰਕਾਂ 'ਤੇ ਵੱਡੀ ਤਰੱਕੀ ਦਰਸਾਈ ਗਈ ਹੈ। ਜੇਕਰچہ ਆਮ ਤੌਰ 'ਤੇ ਇਹ ਤਰੀਕਾ ਆਰਕੀਟੈਕਚਰ ਵਿੱਚ ਟਾਸਕ-ਐਗਨੋਸਟਿਕ ਹੁੰਦਾ ਹੈ, ਫਿਰ ਵੀ ਇਸ ਤਰੀਕੇ ਨੂੰ ਹਜ਼ਾਰਾਂ ਜਾਂ ਦਸ ਹਜ਼ਾਰਾਂ ਉਦਾਹਰਣਾਂ ਵਾਲੇ ਟਾਸਕ-ਵਿਸ਼ੇਸ਼ ਫਾਈਨ-ਟਿਊਨਿੰਗ ਡੇਟਾ ਸੈੱਟ ਦੀ ਲੋੜ ਹੁੰਦੀ ਹੈ। ਇਸ ਦੇ ਬਰਕਸ, ਮਨੁੱਖ ਆਮ ਤੌਰ 'ਤੇ ਕੁਝ ਉਦਾਹਰਣਾਂ ਜਾਂ ਸਧਾਰਨ ਹੁਕਮਾਂ ਤੋਂ ਹੀ ਨਵਾਂ ਭਾਸ਼ਾਈ ਕੰਮ ਕਰ ਸਕਦਾ ਹੈ - ਜੋ ਕਿ ਮੌਜੂਦਾ NLP ਪ੍ਰਣਾਲੀਆਂ ਅਜੇ ਵੀ ਅਕਸਰ ਨਹੀਂ ਕਰ ਪਾ ਰਹੀਆਂ। ਇੱਥੇ ਅਸੀਂ ਦਰਸਾਉਂਦੇ ਹਾਂ ਕਿ ਭਾਸ਼ਾ ਮਾਡਲਾਂ ਦਾ ਪੈਮਾਨਾ ਵਧਾਉਣਾ ਟਾਸਕ-ਐਗਨੋਸਟਿਕ, ਥੋੜੇ-ਸ਼ਾਟ ਪ੍ਰਦਰਸ਼ਨ ਨੂੰ ਬਹੁਤ ਸੁਧਾਰਦਾ ਹੈ, ਕਈ ਵਾਰ ਪਹਿਲਾਂ ਦੇ ਸਿੱਟੇਦਾਰ ਫਾਈਨ-ਟਿਊਨਿੰਗ ਤਰੀਕਿਆਂ ਨਾਲ ਮੁਕਾਬਲਾ ਵੀ ਕਰ ਲੈਂਦਾ ਹੈ।
#
#
#
# Tl;dr

# %% [markdown]
# # ਕਈ ਵਰਤੋਂਮਾਮਲਿਆਂ ਲਈ ਅਭਿਆਸ
# 1. ਟੈਕਸਟ ਦਾ ਸੰਖੇਪ
# 2. ਟੈਕਸਟ ਦੀ ਵਰਗੀਕਰਨ
# 3. ਨਵੇਂ ਉਤਪਾਦ ਨਾਮ ਤਿਆਰ ਕਰੋ

# %%
prompt = "Recent work has demonstrated substantial gains on many NLP tasks and benchmarks by pre-training on a large corpus of text followed by fine-tuning on a specific task. While typically task-agnostic in architecture, this method still requires task-specific fine-tuning datasets of thousands or tens of thousands of examples. By contrast, humans can generally perform a new language task from only a few examples or from simple instructions - something that current NLP systems still largely struggle to do. Here we show that scaling up language models greatly improves task-agnostic, few-shot performance, sometimes even reaching competitiveness with prior state-of-the-art fine-tuning approaches.\n\nTl;dr"

# %%
#Setting a few additional, typical parameters during API Call

response = client.complete(
  model=model_name,
  messages = [{"role":"system", "content":"You are a helpful assistant."},
               {"role":"user","content":prompt},])

response.choices[0].message.content

# %% [markdown]
# ## ਲਿਖਤ ਨੂੰ ਵਰਗੀਕਰਣ ਕਰੋ
# #### ਚੁਣੌਤੀ
# ਚੀਜ਼ਾਂ ਨੂੰ ਉਨ੍ਹਾਂ ਵਰਗੀਕਰਨ ਵਿੱਚ ਵੰਡੋ ਜੋ ਅਨੁਮਾਨ ਸਮੇਂ ਦਿੱਤੀਆਂ ਗਈਆਂ ਹਨ। ਹੇਠਾਂ ਦਿੱਤੇ ਉਦਾਹਰਨ ਵਿੱਚ, ਅਸੀਂ ਦੋਹਾਂ ਵਰਗੀਕਰਨ ਅਤੇ ਲਿਖਤ ਜੋ ਵਰਗੀਕਰਣ ਲਈ ਹੈ, ਪ੍ਰਾਂਪਟ ਵਿੱਚ ਪ੍ਰਦਾਨ ਕਰਦੇ ਹਾਂ(*playground_reference).
#
# ਗਾਹਕ ਪੁੱਛਗਿੱਛ: ਹੈਲੋ, ਮੇਰੇ ਲੈਪਟਾਪ ਦੇ ਕੀਬੋਰਡ 'ਤੇੋਂ ਇੱਕ ਕੁੰਜੀ ਹਾਲ ਹੀ ਵਿੱਚ ਟੁੱਟ ਗਈ ਹੈ ਅਤੇ ਮੈਨੂੰ ਇੱਕ ਬਦਲੀ ਦੀ ਲੋੜ ਹੈ:
#
# ਵਰਗੀਕਰਦ ਵਰਗੀਕਰਨ:

# %%
prompt = "Classify the following inquiry into one of the following: categories: [Pricing, Hardware Support, Software Support]\n\ninquiry: Hello, one of the keys on my laptop keyboard broke recently and I'll need a replacement:\n\nClassified category:"
print(prompt)

# %%
#Setting a few additional, typical parameters during API Call

response = client.complete(
  model=model_name,
  messages = [{"role":"system", "content":"You are a helpful assistant."},
               {"role":"user","content":prompt},])

response.choices[0].message.content

# %% [markdown]
# ## ਨਵੇਂ ਉਤਪਾਦ ਨਾਮ ਤਿਆਰ ਕਰੋ
# #### ਚੈਲੈਂਜ
# ਉਦਾਹਰਨ ਸ਼ਬਦਾਂ ਤੋਂ ਉਤਪਾਦ ਨਾਮ ਬਣਾਉ। ਇੱਥੇ ਅਸੀਂ ਪ੍ਰੋੰਪਟ ਵਿੱਚ ਉਸ ਉਤਪਾਦ ਬਾਰੇ ਜਾਣਕਾਰੀ ਸ਼ਾਮਲ ਕਰਦੇ ਹਾਂ ਜਿਸ ਲਈ ਅਸੀਂ ਨਾਮ ਬਣਾਉਣ ਜਾ ਰਹੇ ਹਾਂ। ਅਸੀਂ ਇੱਕ ਸਮਾਨ ਉਦਾਹਰਨ ਵੀ ਦਿੰਦੇ ਹਾਂ ਤਾਂ ਜੋ ਉਹ ਪੈਟਰਨ ਸੋਝੀ ਸਕੀਏ ਜੋ ਅਸੀਂ ਪ੍ਰਾਪਤ ਕਰਨਾ ਚਾਹੁੰਦੇ ਹਾਂ। ਅਸੀਂ ਤਾਪਮਾਨ ਦੀ ਕੀਮਤ ਵੱਧ ਰੱਖੀ ਹੈ ਤਾਂ ਜੋ ਅਚਾਨਕਤਾ ਵਧੇ ਅਤੇ ਜ਼ਿਆਦਾ ਨਵਾਂਪਨ ਵਾਲੇ ਜਵਾਬ ਮਿਲਣ।
#
# ਉਤਪਾਦ ਵਰਣਨ: ਇਕ ਘਰੇਲੂ ਮਿਲਕਸ਼ੇਕ ਮਸ਼ੀਨ
# ਸਿੱਖਿਆ ਸ਼ਬਦ: ਤੇਜ਼, ਸਿਹਤਮੰਦ, ਸਮੇਤ
# ਉਤਪਾਦ ਨਾਮ: HomeShaker, Fit Shaker, QuickShake, Shake Maker
#
# ਉਤਪਾਦ ਵਰਣਨ: ਜੁੱਤੀ ਦਾ ਜੋੜ ਜੋ ਕਿਸੇ ਵੀ ਪੈਰ ਦਾ ਆਕਾਰ ਫਿੱਟ ਕਰ ਸਕੇ।
# ਸਿੱਖਿਆ ਸ਼ਬਦ: ਅਨੁਕੂਲ, ਫਿੱਟ, ਓਮਨੀ-ਫਿੱਟ।

# %%
prompt = "Product description: A home milkshake maker\nSeed words: fast, healthy, compact.\nProduct names: HomeShaker, Fit Shaker, QuickShake, Shake Maker\n\nProduct description: A pair of shoes that can fit any foot size.\nSeed words: adaptable, fit, omni-fit."

print(prompt)

# %%
#Setting a few additional, typical parameters during API Call

response = client.complete(
  model=model_name,
  messages = [{"role":"system", "content":"You are a helpful assistant."},
               {"role":"user","content":prompt}])

response.choices[0].message.content

# %% [markdown]
# # ਹਵਾਲੇ
# - [Openai CookBook](https://github.com/openai/openai-cookbook?WT.mc_id=academic-105485-koreyst)
# - [Microsoft Foundry ਪੋਰਟਲ](https://ai.azure.com?WT.mc_id=academic-105485-koreyst)
# - [ਪਾਠ ਕਲਾਸੀਫਾਈ ਕਰਨ ਲਈ GPT ਮਾਡਲਾਂ ਨੂੰ ਫਾਈਨ-ਟਿਊਨ ਕਰਨ ਲਈ ਸਭ ਤੋਂ ਵਧੀਆ ਅਮਲ](https://platform.openai.com/docs/guides/fine-tuning?WT.mc_id=academic-105485-koreyst)

# %% [markdown]
# # ਹੋਰ ਮਦਦ ਲਈ
# [OpenAI Commercialization Team](AzureOpenAITeam@microsoft.com)

# %% [markdown]
# # ਯੋਗਦਾਨਕਾਰ
# * [Chew-Yean Yam](https://www.linkedin.com/in/cyyam/)

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **ਅਸਵੀਕਾਰੋਪਣ**:
# ਇਸ ਦਸਤਾਵੇਜ਼ ਦਾ ਅਨੁਵਾਦ ਏਆਈ ਅਨੁਵਾਦ ਸੇਵਾ [Co-op Translator](https://github.com/Azure/co-op-translator) ਦੀ ਵਰਤੋਂ ਕਰਕੇ ਕੀਤਾ ਗਿਆ ਹੈ। ਜਦੋਂ ਕਿ ਅਸੀਂ ਸਹੀਤਾਵਾਂ ਲਈ ਯਤਨਸ਼ੀਲ ਹਾਂ, ਕਿਰਪਾ ਕਰਕੇ ਧਿਆਨ ਰੱਖੋ ਕਿ ਸਵੈਚਾਲਿਤ ਅਨੁਵਾਦਾਂ ਵਿੱਚ ਗਲਤੀਆਂ ਜਾਂ ਅਸਮੱਤਿਆਵਾਂ ਹੋ ਸਕਦੀਆਂ ਹਨ। ਮੂਲ ਦਸਤਾਵੇਜ਼ ਆਪਣੀ ਮੂਲ ਭਾਸ਼ਾ ਵਿੱਚ ਅਧਿਕਾਰਕ ਸਰੋਤ ਮੰਨਿਆ ਜਾਣਾ ਚਾਹੀਦਾ ਹੈ। ਜਰੂਰੀ ਜਾਣਕਾਰੀ ਲਈ, ਪੇਸ਼ੇਵਰ ਮਨੁੱਖੀ ਅਨੁਵਾਦ ਦੀ ਸਿਫ਼ਾਰਸ਼ ਕੀਤੀ ਜਾਂਦੀ ਹੈ। ਅਸੀਂ ਇਸ ਅਨੁਵਾਦ ਦੇ ਉਪਯੋਗ ਤੋਂ ਪੈਦਾ ਹੋਣ ਵਾਲੀਆਂ ਕਿਸੇ ਵੀ ਗਲਤਫਹਿਮੀਆਂ ਜਾਂ ਗਲਤ ਵਿਆਖਿਆਵਾਂ ਲਈ ਜਵਾਬਦੇਹ ਨਹੀਂ ਹਾਂ।
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
