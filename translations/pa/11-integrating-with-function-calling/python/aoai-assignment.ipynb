# %% [markdown]
# ## ਪਰਿਚਯ
#
# ਇਸ ਪਾਠ ਵਿੱਚ ਕਵਰ ਕੀਤਾ ਜਾਵੇਗਾ:
# - ਫੰਕਸ਼ਨ ਕਾਲ ਕੀ ਹੈ ਅਤੇ ਇਸ ਦੇ ਉਪਯੋਗ ਮਾਮਲੇ
# - Azure OpenAI ਦੀ ਵਰਤੋਂ ਕਰਕੇ ਫੰਕਸ਼ਨ ਕਾਲ ਕਿਵੇਂ ਬਣਾਈਏ
# - ਫੰਕਸ਼ਨ ਕਾਲ ਨੂੰ ਕਿਸੇ ਐਪਲਿਕੇਸ਼ਨ ਵਿੱਚ ਕਿਵੇਂ ਇੰਟਿਗ੍ਰੇਟ ਕੀਤਾ ਜਾਵੇ
#
# ## ਸਿੱਖਣ ਦੇ ਲੱਛਣ
#
# ਇਸ ਪਾਠ ਨੂੰ مکمل ਕਰਨ ਤੋਂ ਬਾਅਦ ਤੁਸੀਂ ਜਾਣੋਗੇ ਕਿ ਕਿਵੇਂ ਅਤੇ ਸਮਝੋਗੇ:
#
# - ਫੰਕਸ਼ਨ ਕਾਲ ਦੀ ਵਰਤੋਂ ਕਰਨ ਦਾ ਉਦੇਸ਼
# - Azure Open AI ਸੇਵਾ ਦੀ ਵਰਤੋਂ ਕਰਕੇ ਫੰਕਸ਼ਨ ਕਾਲ ਸੈੱਟਅਪ ਕਰੋ
# - ਤੁਹਾਡੇ ਐਪਲਿਕੇਸ਼ਨ ਦੇ ਉਪਯੋਗ ਮਾਮਲੇ ਲਈ ਪ੍ਰਭਾਵਸ਼ਾਲੀ ਫੰਕਸ਼ਨ ਕਾਲਾਂ ਡਿਜ਼ਾਇਨ ਕਰੋ

# %% [markdown]
# ## ਫੰਕਸ਼ਨ ਕਾਲ ਨੂੰ ਸਮਝਣਾ
#
# ਇਸ ਪਾਠ ਲਈ, ਅਸੀਂ ਆਪਣੇ ਸਿੱਖਿਆ ਸਟਾਰਟਅੱਪ ਲਈ ਇੱਕ ਫੀਚਰ ਬਣਾਉਣਾ ਚਾਹੁੰਦੇ ਹਾਂ ਜੋ ਵਰਤੋਂਕਾਰਾਂ ਨੂੰ ਚੈਟਬੋਟ ਦੀ ਵਰਤੋਂ ਕਰਕੇ ਤਕਨੀਕੀ ਕੋਰਸ ਲੱਭਣ ਦੀ ਸਹੂਲਤ ਦਿੰਦਾ ਹੈ। ਅਸੀਂ ਉਹਨਾਂ ਦੇ ਹੁਨਰ ਦੇ ਅਨੁਕੂਲ, ਮੌਜੂਦਾ ਭੂਮਿਕਾ ਅਤੇ ਰੁਚੀ ਦੀ ਤਕਨੀਕ ਦੇ ਅਧਾਰ 'ਤੇ ਕੋਰਸ ਸਿਫਾਰਸ਼ ਕਰਾਂਗੇ।
#
# ਇਸ ਨੂੰ ਪੂਰਾ ਕਰਨ ਲਈ ਅਸੀਂ ਇਹਨਾਂ ਦਾ ਸੰਗਮ ਵਰਤਾਂਗੇ:
#  - `Azure Open AI` ਵਰਤੋਂਕਾਰ ਲਈ ਚੈਟ ਅਨੁਭਵ ਬਣਾਉਣ ਲਈ
#  - `Microsoft Learn Catalog API` ਵਰਤੋਂਕਾਰਾਂ ਦੀ ਬੇਨਤੀ ਅਨੁਸਾਰ ਕੋਰਸ ਲੱਭਣ ਵਿੱਚ ਮਦਦ ਲਈ
#  - `Function Calling` ਵਰਤੋਂਕਾਰ ਦੀ ਪ੍ਰਸ਼ਨ ਨੂੰ ਲੈ ਕੇ ਉਸਨੂੰ API ਬੇਨਤੀ ਕਰਨ ਲਈ ਫੰਕਸ਼ਨ ਨੂੰ ਭੇਜਣ ਲਈ.
#
# ਸ਼ੁਰੂ ਕਰਨ ਲਈ, ਆਓ ਦੇਖੀਏ ਕਿ ਅਸੀਂ ਪਹਿਲਾਂ ਫੰਕਸ਼ਨ ਕਾਲਿੰਗ ਕਿਉਂ ਵਰਤਣਾ ਚਾਹੁੰਦੇ ਹਾਂ:

# %% [markdown]
# ### ਫੰਕਸ਼ਨ ਕਾਲਿੰਗ ਕਿਉਂ
#
# ਜੇਕਰ ਤੁਸੀਂ ਇਸ ਕੋਰਸ ਵਿੱਚ ਕਿਸੇ ਹੋਰ ਪਾਠ ਨੂੰ ਪੂਰਾ ਕੀਤਾ ਹੈ, ਤਾਂ ਤੁਹਾਨੂੰ ਵੱਡੀਆਂ ਭਾਸ਼ਾ ਮਾਡਲਾਂ (LLMs) ਦੀ ਵਰਤੋਂ ਦੀ ਤਾਕਤ ਸਮਝ ਆ ਗਈ ਹੋਵੇਗੀ। ਉਮੀਦ ਹੈ ਕਿ ਤੁਸੀਂ ਇਹਨਾਂ ਦੀਆਂ ਕੁਝ ਸੀਮਾਵਾਂ ਨੂੰ ਵੀ ਦੇਖ ਸਕਦੇ ਹੋ।
#
# ਫੰਕਸ਼ਨ ਕਾਲਿੰਗ Azure Open AI ਸੇਵਾ ਦੀ ਇੱਕ ਵਿਸ਼ੇਸ਼ਤਾ ਹੈ ਜੋ ਹੇਠਾਂ ਦਿੱਤੀਆਂ ਸੀਮਾਵਾਂ ਨੂੰ ਪਾਰ ਕਰਨ ਲਈ ਹੈ:
# 1) ਲਗਾਤਾਰ ਜਵਾਬ ਫਾਰਮੈਟ
# 2) ਚੈਟ ਸੰਦਰਭ ਵਿੱਚ ਐਪਲੀਕੇਸ਼ਨ ਦੇ ਹੋਰ ਸਰੋਤਾਂ ਤੋਂ ਡਾਟਾ ਦੀ ਵਰਤੋਂ ਕਰਨ ਦੀ ਸਮਰੱਥਾ
#
# ਫੰਕਸ਼ਨ ਕਾਲਿੰਗ ਤੋਂ ਪਹਿਲਾਂ, ਇੱਕ LLM ਤੋਂ ਮਿਲਦੇ ਜਵਾਬ ਬੇਢੰਗੇ ਤੇ ਅਸੰਘਟਿਤ ਹੁੰਦੇ ਸਨ। ਡਿਵੈਲਪਰਨਾਂ ਨੂੰ ਹਰ ਇੱਕ ਜਵਾਬ ਦੇ ਬਦਲ ਨੂੰ ਸੰਭਾਲਣ ਲਈ ਜਟਿਲ ਵੈਧਤਾ ਕੋਡ ਲਿਖਣ ਦੀ ਲੋੜ ਹੁੰਦੀ ਸੀ।
#
# ਯੂਜ਼ਰਾਂ ਨੂੰ ਇਸ ਤਰ੍ਹਾਂ ਦੇ ਜਵਾਬ ਨਹੀਂ ਮਿੱਲ ਸਕਦੇ ਸਨ ਜਿਵੇਂ "ਸਟਾਕਹੋਮ ਵਿੱਚ ਮੌਜੂਦਾ ਮੌਸਮ ਕੀ ਹੈ?"। ਇਹ ਇਸ ਲਈ ਕਿ ਮਾਡਲ ਸਿਰਫ ਉਹਨਾਂ ਸਮਿਆਂ ਤੱਕ ਹੀ ਸੀਮਿਤ ਸੀ ਜਦੋਂ ਡਾਟਾ ਦੀ ਤਿਆਰੀ ਕੀਤੀ ਗਈ ਸੀ।
#
# ਆਓ ਹੇਠਾਂ ਦਿੱਤੇ ਉਦਾਹਰਨ ਨੂੰ ਵੇਖੀਏ ਜੋ ਇਸ ਸਮੱਸਿਆ ਨੂੰ ਦਰਸਾਉਂਦਾ ਹੈ:
#
# ਮਾਨ ਲੋ ਕਿ ਅਸੀਂ ਵਿਦਿਆਰਥੀ ਡਾਟਾਬੇਸ ਬਣਾਉਣਾ ਚਾਹੁੰਦੇ ਹਾਂ ਤਾਂ ਜੋ ਅਸੀਂ ਉਨ੍ਹਾਂ ਨੂੰ ਸਹੀ ਕੋਰਸ ਸੁਝਾ ਸਕੀਏ। ਹੇਠਾਂ ਦੋ ਵਿਦਿਆਰਥੀਆਂ ਦੇ ਵੇਰਵੇ ਹਨ ਜੋ ਆਪਣੇ ਡਾਟਾ ਵਿੱਚ ਬਹੁਤ ਮਿਲਦੇ-ਜੁਲਦੇ ਹਨ।

# %%
student_1_description="Emily Johnson is a sophomore majoring in computer science at Duke University. She has a 3.7 GPA. Emily is an active member of the university's Chess Club and Debate Team. She hopes to pursue a career in software engineering after graduating."
 
student_2_description = "Michael Lee is a sophomore majoring in computer science at Stanford University. He has a 3.8 GPA. Michael is known for his programming skills and is an active member of the university's Robotics Club. He hopes to pursue a career in artificial intelligence after finishing his studies."

# %% [markdown]
# ਅਸੀਂ ਇਸਨੂੰ ਇੱਕ LLM ਨੂੰ ਡਾਟਾ ਨੂੰ ਪਾਰਸ ਕਰਨ ਲਈ ਭੇਜਣਾ ਚਾਹੁੰਦੇ ਹਾਂ। ਇਸਨੂੰ ਬਾਅਦ ਵਿੱਚ ਸਾਡੇ ਐਪਲੀਕੇਸ਼ਨ ਵਿੱਚ ਵਰਤਿਆ ਜਾ ਸਕਦਾ ਹੈ ਤਾਂ ਜੋ ਇਸਨੂੰ ਕਿਸੇ API ਨੂੰ ਭੇਜਿਆ ਜਾ ਸਕੇ ਜਾਂ ਡਾਟਾਬੇਸ ਵਿੱਚ ਸਟੋਰ ਕੀਤਾ ਜਾ ਸਕੇ।
#
# ਆਓ ਦੋ ਇੱਕਸਾਰ ਪ੍ਰੰਪਟ ਬਣਾਈਏ ਜਿਸ ਵਿੱਚ ਅਸੀਂ LLM ਨੂੰ ਦੱਸਦੇ ਹਾਂ ਕਿ ਅਸੀਂ ਕਿਸ ਜਾਣਕਾਰੀ ਵਿੱਚ ਰੁਚੀ ਰੱਖਦੇ ਹਾਂ:

# %% [markdown]
# ਅਸੀਂ ਇਸਨੂੰ ਇੱਕ LLM ਨੂੰ ਭੇਜਣਾ ਚਾਹੁੰਦੇ ਹਾਂ ਤਾਂ ਜੋ ਉਹ ਸਾਡੇ ਉਤਪਾਦ ਲਈ ਮਹੱਤਵਪੂਰਨ ਹਿੱਸਿਆਂ ਨੂੰ ਵਿਸ਼ਲੇਸ਼ਣ ਕਰ ਸਕੇ। ਤਾਂ ਜੋ ਅਸੀਂ LLM ਨੂੰ ਦਿਸ਼ਾ-ਨਿਰਦੇਸ਼ ਦੇਣ ਲਈ ਦੋ ਇੱਕੋ ਜਿਹੇ ਪ੍ਰਾਰੰਭਿਕ ਵਾਕ ਬਣਾਉਣ ਸਕੀਏ:

# %%
prompt1 = f'''
Please extract the following information from the given text and return it as a JSON object:

name
major
school
grades
club

This is the body of text to extract the information from:
{student_1_description}
'''


prompt2 = f'''
Please extract the following information from the given text and return it as a JSON object:

name
major
school
grades
club

This is the body of text to extract the information from:
{student_2_description}
'''

# %% [markdown]
# ਇਹ ਦੋ ਪ੍ਰਾਂਪਟ ਬਣਾਉਣ ਤੋਂ ਬਾਅਦ, ਅਸੀਂ ਉਹਨਾਂ ਨੂੰ LLM ਨੂੰ `client.responses.create` ਦੀ ਵਰਤੋਂ ਕਰਕੇ ਭੇਜਾਂਗੇ। ਅਸੀਂ ਪ੍ਰਾਂਪਟ ਨੂੰ `input` ਵੈਰੀਏਬਲ ਵਿੱਚ ਸਟੋਰ ਕਰਦੇ ਹਾਂ ਅਤੇ ਰੋਲ ਨੂੰ `user` ਨਿਰਧਾਰਤ ਕਰਦੇ ਹਾਂ। ਇਹ ਇਸ ਲਈ ਹੈ ਕਿ ਯੂਜ਼ਰ ਵੱਲੋਂ ਚੈਟਬੋਟ ਨੂੰ ਭੇਜੇ ਜਾਣ ਵਾਲੇ ਸੁਨੇਹੇ ਦੀ ਨਕਲ ਕੀਤੀ ਜਾਵੇ।

# %%
import os
import json
from openai import OpenAI
from dotenv import load_dotenv
load_dotenv()

# The OpenAI client points at the Azure OpenAI (Microsoft Foundry) /openai/v1/ endpoint
client = OpenAI(
  api_key=os.environ['AZURE_OPENAI_API_KEY'],
  base_url=f"{os.environ['AZURE_OPENAI_ENDPOINT'].rstrip('/')}/openai/v1/",
  )

deployment=os.environ['AZURE_OPENAI_DEPLOYMENT']
# Out:
# Running cells with '/opt/homebrew/bin/python3' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ਹੁਣ ਅਸੀਂ ਦੋਹਾਂ ਬੇਨਤੀਆਂ ਨੂੰ LLM ਨੂੰ ਭੇਜ ਸਕਦੇ ਹਾਂ ਅਤੇ ਪ੍ਰਾਪਤ ਜਵਾਬ ਦੀ ਜਾਂਚ ਕਰ ਸਕਦੇ ਹਾਂ।

# %%
openai_response1 = client.responses.create(
 model=deployment,    
 input = [{'role': 'user', 'content': prompt1}],
 store=False,
)
openai_response1.output_text

# %%
openai_response2 = client.responses.create(
 model=deployment,    
 input = [{'role': 'user', 'content': prompt2}],
 store=False,
)
openai_response2.output_text

# %%
# Loading the response as a JSON object
json_response1 = json.loads(openai_response1.output_text)
json_response1

# %%
# Loading the response as a JSON object
json_response2 = json.loads(openai_response2.output_text)
json_response2

# %% [markdown]
# ਹਾਲਾਂਕਿ ਪ੍ਰਾਂਪਟ ਇੱਕੋ ਜਿਹੇ ਹਨ ਅਤੇ ਵਰਣਨ ਸਮਾਨ ਹਨ, ਅਸੀਂ `Grades` ਪ੍ਰਾਪਰਟੀ ਦੇ ਵੱਖ-ਵੱਖ ਫਾਰਮੈਟ ਪ੍ਰਾਪਤ ਕਰ ਸਕਦੇ ਹਾਂ।
#
# ਜੇ ਤੁਸੀਂ ਉਪਰੋਕਤ ਸੈੱਲ ਨੂੰ ਕਈ ਵਾਰੀ ਚਲਾਉਂਦੇ ਹੋ, ਤਾਂ ਫਾਰਮੈਟ `3.7` ਜਾਂ `3.7 GPA` ਹੋ ਸਕਦਾ ਹੈ।
#
# ਇਹ ਇਸ ਲਈ ਹੈ ਕਿ LLM ਲਿਖੇ ਹੋਏ ਪ੍ਰਾਂਪਟ ਦੇ ਰੂਪ ਵਿੱਚ ਅਸੰਰਚਿਤ ਡੇਟਾ ਲੈਂਦਾ ਹੈ ਅਤੇ ਅਸੰਰਚਿਤ ਡੇਟਾ ਹੀ ਵਾਪਸ ਕਰਦਾ ਹੈ। ਸਾਨੂੰ ਇੱਕ ਸੰਰਚਿਤ ਫਾਰਮੈਟ ਦੀ ਲੋੜ ਹੈ ਤਾਂ ਜੋ ਸਾਨੂੰ ਪਤਾ ਹੋਵੇ ਕਿ ਇਸ ਡੇਟਾ ਨੂੰ ਸਟੋਰ ਕਰਨ ਜਾਂ ਵਰਤਣ ਸਮੇਂ ਕੀ ਉਮੀਦ ਕਰਨੀ ਹੈ।
#
# ਫੰਕਸ਼ਨਲ ਕਾਲਿੰਗ ਦੀ ਵਰਤੋਂ ਕਰਕੇ, ਅਸੀਂ ਇਸ ਗੱਲ ਨੂੰ ਯਕੀਨੀ ਬਣਾ ਸਕਦੇ ਹਾਂ ਕਿ ਸਾਨੂੰ ਸੰਰਚਿਤ ਡੇਟਾ ਵਾਪਸ ਮਿਲੇ। ਫੰਕਸ਼ਨ ਕਾਲਿੰਗ ਦੀ ਵਰਤੋਂ ਦੌਰਾਨ, LLM ਅਸਲ ਵਿੱਚ ਕੋਈ ਫੰਕਸ਼ਨ ਨਹੀਂ ਕਾਲ ਕਰਦਾ ਜਾਂ ਚਲਾਉਂਦਾ। ਇਸਦੀ ਬਜਾਏ, ਅਸੀਂ LLM ਲਈ ਉਸਦੀ ਜਵਾਬਦਿਹੀ ਲਈ ਇੱਕ ਸੰਰਚਨਾ ਬਣਾਉਂਦੇ ਹਾਂ। ਫਿਰ ਅਸੀਂ ਉਹਨਾਂ ਸੰਰਚਿਤ ਜਵਾਬਾਂ ਦੀ ਵਰਤੋਂ ਕਰਕੇ ਇਹ ਜਾਣਦੇ ਹਾਂ ਕਿ ਸਾਡੇ ਐਪਲੀਕੇਸ਼ਨਾਂ ਵਿੱਚ ਕਿਹੜਾ ਫੰਕਸ਼ਨ ਚਲਾਉਣਾ ਹੈ।

# %% [markdown]
# ![ਫੰਕਸ਼ਨ ਕਾਲਿੰਗ ਫਲੋ ਡਾਇਗ੍ਰਾਮ](../../../../translated_images/pa/Function-Flow.083875364af4f4bb.webp)

# %% [markdown]
# ਅਸੀਂ ਫਿਰ ਫੰਕਸ਼ਨ ਤੋਂ ਮਿਲਣ ਵਾਲੇ ਨਤੀਜੇ ਨੂੰ ਲੈ ਕੇ ਇਸਨੂੰ LLM ਨੂੰ ਵਾਪਸ ਭੇਜ ਸਕਦੇ ਹਾਂ। LLM ਫਿਰ ਕੁਦਰਤੀ ਭਾਸ਼ਾ ਦੀ ਵਰਤੋਂ ਕਰਕੇ ਉਪਭੋਗਤਾ ਦੇ ਸਵਾਲ ਦਾ ਜਵਾਬ ਦੇਵੇਗਾ।

# %% [markdown]
# ### ਫੰਕਸ਼ਨ ਕਾਲਾਂ ਦੀ ਵਰਤੋਂ ਲਈ ਉਪਯੋਗ ਕੇਸ
#
# **ਬਾਹਰੀ ਸੰਦ ਕਾਲ ਕਰਨਾ**
# ਚੈਟਬੌਟ ਉਪਭੋਗਤਾਵਾਂ ਦੇ ਸਵਾਲਾਂ ਦੇ ਜਵਾਬ ਦੇਣ ਵਿੱਚ ਮਹਾਨ ਹਨ। ਫੰਕਸ਼ਨ ਕਾਲਿੰਗ ਦੀ ਵਰਤੋਂ ਕਰਕੇ, ਚੈਟਬੌਟ ਉਪਭੋਗਤਾਵਾਂ ਦੇ ਸੁਨੇਹਿਆਂ ਨੂੰ ਕੁਝ ਕਾਰਜ ਪੂਰੇ ਕਰਨ ਲਈ ਵਰਤ ਸਕਦੇ ਹਨ। ਉਦਾਹਰਨ ਵਜੋਂ, ਇੱਕ ਵਿਦਿਆਰਥੀ ਚੈਟਬੌਟ ਨੂੰ ਕਹਿ ਸਕਦਾ ਹੈ "ਮੇਰੇ ਅਧਿਆਪਕ ਨੂੰ ਈਮੇਲ ਭੇਜੋ ਕਿ ਮੈਨੂੰ ਇਸ ਵਿਸ਼ੇ ਨਾਲ ਵਧੇਰੇ ਮਦਦ ਦੀ ਲੋੜ ਹੈ"। ਇਹ `send_email(to: string, body: string)` ਨਾਮਕ ਫੰਕਸ਼ਨ ਦੀ ਕਾਲ ਕਰ ਸਕਦਾ ਹੈ।
#
#
# **API ਜਾਂ ਡੇਟਾਬੇਸ ਕਵੇਰੀ ਬਣਾਉਣਾ**
# ਉਪਭੋਗਤਾ ਕੁਦਰਤੀ ਭਾਸ਼ਾ ਦੀ ਵਰਤੋਂ ਕਰਕੇ ਜਾਣਕਾਰੀ ਲੱਭ ਸਕਦੇ ਹਨ ਜੋ ਇੱਕ ਫਾਰਮੈਟਡ ਕਵੇਰੀ ਜਾਂ API ਬੇਨਤੀ ਵਿੱਚ ਬਦਲ ਜਾਏਗੀ। ਇਸਦਾ ਇੱਕ ਉਦਾਹਰਨ ਇੱਕ ਅਧਿਆਪਕ ਹੋ ਸਕਦਾ ਹੈ ਜੋ ਪੂੱਛਦਾ ਹੈ "ਆਖਰੀ ਅਸਾਈਨਮੈਂਟ ਕੌਣ-ਕੌਣ ਮੁਕੰਮਲ ਕਰ ਚੁੱਕੇ ਹਨ" ਜਿਸ ਨਾਲ `get_completed(student_name: string, assignment: int, current_status: string)` ਨਾਮਕ ਫੰਕਸ਼ਨ ਕਾਲ ਹੋ ਸਕਦਾ ਹੈ।
#
#
# **ਸੰਰਚਿਤ ਡੇਟਾ ਤਿਆਰ ਕਰਨਾ**
# ਉਪਭੋਗਤਾ ਇੱਕ ਟੈਕਸਟ ਜਾਂ CSV ਬਲਾਕ ਲੈ ਕੇ LLM ਦੀ ਵਰਤੋਂ ਕਰਕੇ ਮਹੱਤਵਪੂਰਨ ਜਾਣਕਾਰੀ ਨਿਕਾਲ ਸਕਦੇ ਹਨ। ਉਦਾਹਰਨ ਵਜੋਂ, ਇੱਕ ਵਿਦਿਆਰਥੀ ਅਮਨ ਸੰਝੌਤਿਆਂ ਬਾਰੇ ਵਿਕੀਪੀਡੀਆ ਲੇਖ ਨੂੰ AI ਫਲੈਸ਼ ਕਾਰਡ ਬਣਾਉਣ ਲਈ ਬਦਲ ਸਕਦਾ ਹੈ। ਇਹ `get_important_facts(agreement_name: string, date_signed: string, parties_involved: list)` ਨਾਮਕ ਫੰਕਸ਼ਨ ਦੀ ਵਰਤੋਂ ਨਾਲ ਕੀਤਾ ਜਾ ਸਕਦਾ ਹੈ।

# %% [markdown]
# ## 2. ਤੁਹਾਡੇ ਪਹਿਲੇ ਫੰਕਸ਼ਨ ਕਾਲ ਬਣਾਉਣਾ
#
# ਫੰਕਸ਼ਨ ਕਾਲ ਬਣਾਉਣ ਦੀ ਪ੍ਰਕਿਰਿਆ ਵਿੱਚ 3 ਮੁੱਖ ਕਦਮ ਸ਼ਾਮਲ ਹਨ:
# 1. ਆਪਣੇ ਫੰਕਸ਼ਨਾਂ ਦੀ ਸੂਚੀ ਅਤੇ ਇੱਕ ਯੂਜ਼ਰ ਸੁਨੇਹਾ ਦੇ ਨਾਲ ਚੈਟ ਕੰਪਲੀਸ਼ਨ API ਨੂੰ ਕਾਲ ਕਰਨਾ
# 2. ਮਾਡਲ ਦੇ ਜਵਾਬ ਨੂੰ ਪੜ੍ਹਨਾ ਤਾਂ ਜੋ ਕੋਈ ਕਾਰਵਾਈ ਕੀਤੀ ਜਾਵੇ ਜਿਵੇਂ ਕਿ ਫੰਕਸ਼ਨ ਜਾਂ API ਕਾਲ ਚਲਾਈ ਜਾਵੇ
# 3. ਆਪਣੇ ਫੰਕਸ਼ਨ ਤੋਂ ਜਵਾਬ ਲੈ ਕੇ ਚੈਟ ਕੰਪਲੀਸ਼ਨ API ਨੂੰ ਦੁਬਾਰਾ ਕਾਲ ਕਰਨਾ taaki ਇਸ ਜਾਣਕਾਰੀ ਨੂੰ ਵਰਤ ਕੇ ਯੂਜ਼ਰ ਲਈ ਜਵਾਬ ਬਣਾਇਆ ਜਾ ਸਕੇ।

# %% [markdown]
# ![ਫੰਕਸ਼ਨ ਕਾਲ ਦਾ ਪ੍ਰਵਾਹ](../../../../translated_images/pa/LLM-Flow.3285ed8caf4796d7.webp)

# %% [markdown]
# ### ਫੰਕਸ਼ਨ ਕਾਲ ਦੇ ਤੱਤ
#
# #### ਯੂਜ਼ਰ ਇਨਪੁਟ
#
# ਪਹਿਲਾ ਕਦਮ ਇੱਕ ਯੂਜ਼ਰ ਸੁਨੇਹਾ ਬਣਾਉਣਾ ਹੈ। ਇਹ ਡਾਇਨਾਮਿਕ ਤਰੀਕੇ ਨਾਲ ਇੱਕ ਟੈਕਸਟ ਇਨਪੁਟ ਦੀ ਵੈਲੀਉ ਲੈ ਕੇ ਅਸਾਈਨ ਕੀਤਾ ਜਾ ਸਕਦਾ ਹੈ ਜਾਂ ਤੁਸੀਂ ਇੱਥੇ ਇੱਕ ਵੈਲੀਉ ਅਸਾਈਨ ਕਰ ਸਕਦੇ ਹੋ। ਜੇ ਇਹ ਤੁਹਾਡਾ ਪਹਿਲਾ ਵਾਰ ਹੈ ਜੋ ਤੁਸੀਂ Chat Completions API ਨਾਲ ਕੰਮ ਕਰ ਰਹੇ ਹੋ, ਤਾਂ ਸਾਨੂੰ ਸੁਨੇਹੇ ਦੀ `role` ਅਤੇ `content` ਪਰਿਭਾਸ਼ਿਤ ਕਰਨੀਆਂ ਚਾਹੀਦੀਆਂ ਹਨ।
#
# `role` ਜਾਂ ਤਾਂ `system` (ਨਿਯਮ ਬਣਾਉਣਾ), `assistant` (ਮਾਡਲ) ਜਾਂ `user` (ਅੰਤ-ਯੂਜ਼ਰ) ਹੋ ਸਕਦੀ ਹੈ। ਫੰਕਸ਼ਨ ਕਾਲਿੰਗ ਲਈ, ਅਸੀਂ ਇਸਨੂੰ `user` ਦੇ ਤੌਰ 'ਤੇ ਅਸਾਈਨ ਕਰਾਂਗੇ ਅਤੇ ਇੱਕ ਉਦਾਹਰਨ ਸਵਾਲ ਦਿਆਂਗੇ।

# %%
messages= [ {"role": "user", "content": "Find me a good course for a beginner student to learn Azure."} ]

# %% [markdown]
# ### ਫੰਕਸ਼ਨਾਂ ਦੀ ਬਣਾਉਣਾ।
#
# ਅਗਲੇ ਅਸੀਂ ਇੱਕ ਫੰਕਸ਼ਨ ਅਤੇ ਉਸ ਫੰਕਸ਼ਨ ਦੇ ਪੈਰਾਮੀਟਰ ਨਿਰਧਾਰਤ ਕਰਾਂਗੇ। ਅਸੀਂ ਇੱਥੇ ਸਿਰਫ਼ ਇੱਕ ਫੰਕਸ਼ਨ `search_courses` ਵਰਤਾਂਗੇ ਪਰ ਤੁਸੀਂ ਕਈ ਫੰਕਸ਼ਨਾਂ ਬਣਾ ਸਕਦੇ ਹੋ।
#
# **ਮਹੱਤਵਪੂਰਨ** : ਫੰਕਸ਼ਨਾਂ ਨੂੰ LLM ਲਈ ਸਿਸਟਮ ਸੁਨੇਹੇ ਵਿੱਚ ਸ਼ਾਮਲ ਕੀਤਾ ਜਾਂਦਾ ਹੈ ਅਤੇ ਇਹ ਤੁਹਾਡੇ ਕੋਲ ਉਪਲਬਧ ਟੋਕਨ ਦੀ ਗਿਣਤੀ ਵਿੱਚ ਸ਼ਾਮਲ ਹੋਵੇਗਾ।

# %%
# The Responses API uses a flat tool format: name/description/parameters at the top level
functions = [
   {
      "type":"function",
      "name":"search_courses",
      "description":"Retrieves courses from the search index based on the parameters provided",
      "parameters":{
         "type":"object",
         "properties":{
            "role":{
               "type":"string",
               "description":"The role of the learner (i.e. developer, data scientist, student, etc.)"
            },
            "product":{
               "type":"string",
               "description":"The product that the lesson is covering (i.e. Azure, Power BI, etc.)"
            },
            "level":{
               "type":"string",
               "description":"The level of experience the learner has prior to taking the course (i.e. beginner, intermediate, advanced)"
            }
         },
         "required":[
            "role"
         ]
      }
   }
]

# %% [markdown]
# **ਪਰਿਭਾਸ਼ਾਵਾਂ**
#
# `name` - ਉਸ ਫੰਕਸ਼ਨ ਦਾ ਨਾਮ ਜਿਸਨੂੰ ਅਸੀਂ ਕਾਲ ਕਰਵਾਉਣਾ ਚਾਹੁੰਦੇ ਹਾਂ।
#
# `description` - ਇਹ ਉਹ ਵੇਰਵਾ ਹੈ ਕਿ ਫੰਕਸ਼ਨ ਕਿਵੇਂ ਕੰਮ ਕਰਦਾ ਹੈ। ਇਥੇ ਵਿਸ਼ੇਸ਼ ਅਤੇ ਸਪਸ਼ਟ ਹੋਣਾ ਜਰੂਰੀ ਹੈ
#
# `parameters` - ਉਹ ਮੁੱਲਾਂ ਅਤੇ ਫਾਰਮੈਟ ਦੀ ਸੂਚੀ ਜੋ ਤੁਸੀਂ ਮਾਡਲ ਤੋਂ ਆਪਣੇ ਜਵਾਬ ਵਿੱਚ ਚਾਹੁੰਦੇ ਹੋ
#
#
# `type` -  ਉਹ ਡੇਟਾ ਟਾਈਪ ਜਿਸ ਵਿੱਚ ਪ੍ਰਾਪਰਟੀਜ਼ ਸਟੋਰ ਕੀਤੀਆਂ ਜਾਣਗੀਆਂ
#
# `properties` - ਉਹ ਖਾਸ ਮੁੱਲਾਂ ਦੀ ਸੂਚੀ ਜੋ ਮਾਡਲ ਆਪਣੇ ਜਵਾਬ ਲਈ ਵਰਤੇਗਾ
#
#
# `name` - ਉਹ ਪ੍ਰਾਪਰਟੀ ਦਾ ਨਾਮ ਜੋ ਮਾਡਲ ਆਪਣੇ ਫਾਰਮੈਟਡ ਜਵਾਬ ਵਿੱਚ ਵਰਤੇਗਾ
#
# `type` - ਇਸ ਪ੍ਰਾਪਰਟੀ ਦਾ ਡੇਟਾ ਟਾਈਪ
#
# `description` - ਖਾਸ ਪ੍ਰਾਪਰਟੀ ਦਾ ਵੇਰਵਾ
#
#
# **ਵਿਕਲਪਿਕ**
#
# `required` - ਫੰਕਸ਼ਨ ਕਾਲ ਪੂਰੀ ਹੋਣ ਲਈ ਲਾਜ਼ਮੀ ਪ੍ਰਾਪਰਟੀ

# %% [markdown]
# ### ਫੰਕਸ਼ਨ ਕਾਲ ਬਣਾਉਣਾ
# ਇੱਕ ਫੰਕਸ਼ਨ ਨੂੰ ਪਰਿਭਾਸ਼ਿਤ ਕਰਨ ਤੋਂ ਬਾਅਦ, ਹੁਣ ਸਾਨੂੰ ਇਸ ਨੂੰ ਚੈਟ ਕਮਪਲੀਸ਼ਨ API ਨੂੰ ਕਾਲ ਵਿੱਚ ਸ਼ਾਮਿਲ ਕਰਨ ਦੀ ਲੋੜ ਹੈ। ਅਸੀਂ ਇਹ ਬੇਨਤੀ ਵਿੱਚ `functions` ਸ਼ਾਮਿਲ ਕਰਕੇ ਕਰਦੇ ਹਾਂ। ਇਸ ਮਾਮਲੇ ਵਿੱਚ `functions=functions`।
#
# ਇੱਕ ਵਿਕਲਪ ਵੀ ਹੈ ਜਿਸ ਵਿੱਚ `function_call` ਨੂੰ `auto` ਤੇ ਸੈਟ ਕੀਤਾ ਜਾ ਸਕਦਾ ਹੈ। ਇਸਦਾ ਅਰਥ ਹੈ ਕਿ ਅਸੀਂ ਸਵੈ-ਤਹਿਧਾਰਿਤ ਤੌਰ 'ਤੇ ਨਹੀਂ, ਸਗੋਂ ਵਰਤੋਂਕਾਰ ਦੇ ਸੁਨੇਹੇ ਦੇ ਆਧਾਰ 'ਤੇ ਕਿਹੜਾ ਫੰਕਸ਼ਨ ਕਾਲ ਕਰਨਾ ਚਾਹੀਦਾ ਹੈ, ਇਹ ਫੈਸਲਾ LLM ਕਰੇਗਾ।

# %%
response = client.responses.create(model=deployment, 
                                        input=messages,
                                        tools=functions, 
                                        tool_choice="auto",
                                        store=False) 

print(response.output)

# %% [markdown]
# ਹੁਣ ਆਓ ਜਵਾਬ ਨੂੰ ਵੇਖੀਏ ਅਤੇ ਦੇਖੀਏ ਕਿ ਇਹ ਕਿਵੇਂ ਫਾਰਮੈਟ ਕੀਤਾ ਗਿਆ ਹੈ:
#
# {
#   "role": "assistant",
#   "function_call": {
#     "name": "search_courses",
#     "arguments": "{\n  \"role\": \"student\",\n  \"product\": \"Azure\",\n  \"level\": \"beginner\"\n}"
#   }
# }
#
# ਤੁਸੀਂ ਦੇਖ ਸਕਦੇ ਹੋ ਕਿ ਫੰਕਸ਼ਨ ਦਾ ਨਾਮ ਕਾਲ ਕੀਤਾ ਗਿਆ ਹੈ ਅਤੇ ਯੂਜ਼ਰ ਮੈਸੇਜ ਵਿੱਚੋਂ, LLM ਸਮਰਥ ਹੋਇਆ ਕਿ ਫੰਕਸ਼ਨ ਦੇ ਆਰਗੁਮੈਂਟਸ ਨੂੰ ਫਿੱਟ ਕਰਨ ਲਈ ਡੇਟਾ ਲੱਭ ਸਕਿਆ।

# %% [markdown]
# ## 3.ਐਪਲੀਕੇਸ਼ਨ ਵਿੱਚ ਫੰਕਸ਼ਨ ਕਾਲਾਂ ਨੂੰ ਏਕੀਕ੍ਰਿਤ ਕਰਨਾ।
#
#
# ਜਦੋਂ ਅਸੀਂ LLM ਵੱਲੋਂ ਫਾਰਮੈਟ ਕੀਤਾ ਗਿਆ ਜਵਾਬ ਟੈਸਟ ਕਰ ਲਿਆ ਹੈ, ਹੁਣ ਅਸੀਂ ਇਸਨੂੰ ਇੱਕ ਐਪਲੀਕੇਸ਼ਨ ਵਿੱਚ ਏਕੀਕ੍ਰਿਤ ਕਰ ਸਕਦੇ ਹਾਂ।
#
# ### ਫਲੋ ਨੂੰ ਸੰਭਾਲਣਾ
#
# ਇਸਨੂੰ ਆਪਣੇ ਐਪਲੀਕੇਸ਼ਨ ਵਿੱਚ ਏਕੀਕ੍ਰਿਤ ਕਰਨ ਲਈ, ਆਓ ਹੇਠ ਲਿਖੇ ਕਦਮਾਂ ਨੂੰ ਲਏਂ:
#
# ਸਭ ਤੋਂ ਪਹਿਲਾਂ, ਆਓ Open AI ਸੇਵਾਵਾਂ ਨੂੰ ਕਾਲ ਕਰੀਏ ਅਤੇ ਸੁਨੇਹਾ `response_message` ਨਾਮਕ ਚਰ ਵਿੱਚ ਸੰਗ੍ਰਹਿਤ ਕਰੀਏ।

# %%
# Extract the function call items from the response output
tool_calls = [item for item in response.output if item.type == "function_call"]

# %% [markdown]
# ਹੁਣ ਅਸੀਂ ਉਹ ਫੰਕਸ਼ਨ ਪਰਿਭਾਸ਼ਿਤ ਕਰਾਂਗੇ ਜੋ ਮਾਈਕ੍ਰੋਸੌਫਟ ਲਰਨ API ਨੂੰ ਕਾਲ ਕਰੇਗਾ ਤਾਂ ਜੋ ਕੋਰਸਾਂ ਦੀ ਇੱਕ ਸੂਚੀ ਪ੍ਰਾਪਤ ਕੀਤੀ ਜਾ ਸਕੇ:

# %%
import requests

def search_courses(role, product, level):
    url = "https://learn.microsoft.com/api/catalog/"
    params = {
        "role": role,
        "product": product,
        "level": level
    }
    response = requests.get(url, params=params)
    modules = response.json()["modules"]
    results = []
    for module in modules[:5]:
        title = module["title"]
        url = module["url"]
        results.append({"title": title, "url": url})
    return str(results)

# %% [markdown]
# ਇੱਕ ਵਧੀਆ ਅਭਿਆਸ ਵਜੋਂ, ਅਸੀਂ ਫਿਰ ਵੇਖਾਂਗੇ ਕਿ ਮਾਡਲ ਕਿਸੇ ਫੰਕਸ਼ਨ ਨੂੰ ਕਾਲ ਕਰਨਾ ਚਾਹੁੰਦਾ ਹੈ ਕਿ ਨਹੀਂ। ਉਸ ਤੋਂ ਬਾਅਦ, ਅਸੀਂ ਉਪਲਬਧ ਫੰਕਸ਼ਨਾਂ ਵਿੱਚੋਂ ਇੱਕ ਬਣਾਵਾਂਗੇ ਅਤੇ ਇਸਨੂੰ ਕਾਲ ਕੀਤੇ ਜਾ ਰਹੇ ਫੰਕਸ਼ਨ ਨਾਲ ਮਿਲਾਵਾਂਗੇ।
# ਫਿਰ ਅਸੀਂ ਫੰਕਸ਼ਨ ਦੇ ਆਰਗੁਮੈਂਟਸ ਲੈਕੇ LLM ਦੇ ਆਰਗੁਮੈਂਟਸ ਨਾਲ ਮੇਲ ਕਰਾਂਗੇ।
#
# ਆਖਰੀ ਵਿੱਚ, ਅਸੀਂ ਫੰਕਸ਼ਨ ਕਾਲ ਮੈਸੇਜ ਨੂੰ ਅਟੈਚ ਕਰਾਂਗੇ ਅਤੇ ਉਹ ਵੈਲਯੂਜ਼ ਜੋ `search_courses` ਮੈਸੇਜ ਦੁਆਰਾ ਵਾਪਸ ਕੀਤੇ ਗਏ ਸਨ। ਇਹ LLM ਨੂੰ ਸਾਰਾ ਜਾਣਕਾਰੀ ਦਿੰਦਾ ਹੈ ਜੋ ਇਸਨੂੰ
# ਵਰਤੋਂਕਾਰ ਨੂੰ ਕੁਦਰਤੀ ਭਾਸ਼ਾ ਵਿੱਚ ਜਵਾਬ ਦੇਣ ਲਈ ਚਾਹੀਦੀ ਹੈ।

# %%
# Check if the model wants to call a function
if tool_calls:
    tool_call = tool_calls[0]
    print("Recommended Function call:")
    print(tool_call.name)
    print()

    # Call the function. 
    function_name = tool_call.name

    available_functions = {
            "search_courses": search_courses,
    }
    function_to_call = available_functions[function_name] 

    function_args = json.loads(tool_call.arguments)
    function_response = function_to_call(**function_args)

    print("Output of function call:")
    print(function_response)
    print(type(function_response))


    # Add the model's function call item(s) and our function result to the conversation.
    # The Responses API represents tool results as `function_call_output` items.
    messages.extend(response.output)  # adding the model's function_call item(s)
    messages.append( # adding function response to messages
        {
            "type": "function_call_output",
            "call_id": tool_call.call_id,
            "output": function_response,
        }
    )

# %% [markdown]
# ਹੁਣ ਅਸੀਂ ਅਪਡੇਟ ਕੀਤਾ ਸੁਨੇਹਾ LLM ਨੂੰ ਭੇਜਾਂਗੇ ਤਾਂ ਜੋ ਅਸੀਂ API JSON ਫਾਰਮੈਟ ਵਿੱਚ ਜਵਾਬ ਦੀ ਬਜਾਏ ਇੱਕ ਕੁਦਰਤੀ ਭਾਸ਼ਾ ਵਿੱਚ ਜਵਾਬ ਪ੍ਰਾਪਤ ਕਰ ਸਕੀਏ।

# %%
print("Messages in next request:")
print(messages)
print()

second_response = client.responses.create(
    input=messages,
    model=deployment,
    tools=functions,
    tool_choice="auto",
    store=False,
        )  # get a new response from the model where it can see the function response


print(second_response.output_text)

# %% [markdown]
# ## ਕੋਡ ਚੈਲेंज
#
# ਵਧੀਆ ਕੰਮ! ਆਪਣੇ Azure Open AI Function Calling ਦੀ ਸਿੱਖਿਆ ਜਾਰੀ ਰੱਖਣ ਲਈ ਤੁਸੀਂ ਬਣਾ ਸਕਦੇ ਹੋ: https://learn.microsoft.com/training/support/catalog-api-developer-reference?WT.mc_id=academic-105485-koreyst
#  - ਫੰਕਸ਼ਨ ਦੇ ਹੋਰ ਪੈਰਾਮੀਟਰ ਜੋ ਸਿੱਖਣ ਵਾਲਿਆਂ ਨੂੰ ਹੋਰ ਕੋਰਸ ਲੱਭਣ ਵਿੱਚ ਮਦਦ ਕਰ ਸਕਦੇ ਹਨ। ਤੁਸੀਂ ਉਪਲਬਧ API ਪੈਰਾਮੀਟਰ ਇੱਥੇ ਲੱਭ ਸਕਦੇ ਹੋ:
#  - ਇੱਕ ਹੋਰ ਫੰਕਸ਼ਨ ਕਾਲ ਬਣਾਓ ਜੋ ਸਿੱਖਣ ਵਾਲੇ ਤੋਂ ਹੋਰ ਜਾਣਕਾਰੀ ਲੈਂਦੀ ਹੈ ਜਿਵੇਂ ਕਿ ਉਹਨਾਂ ਦੀ ਮੂਲ ਭਾਸ਼ਾ
#  - ਜਦੋਂ ਫੰਕਸ਼ਨ ਕਾਲ ਅਤੇ/ਜਾਂ API ਕਾਲ ਕੋਈ ਉਚਿਤ ਕੋਰਸ ਵਾਪਸ ਨਹੀਂ ਕਰਦੀ ਤਾਂ ਐਰਰ ਹੈਂਡਲਿੰਗ ਬਣਾਓ

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **ਅਸਵੀਕਾਰੋਪਣ**:
# ਇਸ ਦਸਤਾਵੇਜ਼ ਦਾ ਅਨੁਵਾਦ ਏਆਈ ਅਨੁਵਾਦ ਸੇਵਾ [Co-op Translator](https://github.com/Azure/co-op-translator) ਦੀ ਵਰਤੋਂ ਕਰਕੇ ਕੀਤਾ ਗਿਆ ਹੈ। ਜਦੋਂ ਕਿ ਅਸੀਂ ਸਹੀਤਾਵਾਂ ਲਈ ਯਤਨਸ਼ੀਲ ਹਾਂ, ਕਿਰਪਾ ਕਰਕੇ ਧਿਆਨ ਰੱਖੋ ਕਿ ਸਵੈਚਾਲਿਤ ਅਨੁਵਾਦਾਂ ਵਿੱਚ ਗਲਤੀਆਂ ਜਾਂ ਅਸਮੱਤਿਆਵਾਂ ਹੋ ਸਕਦੀਆਂ ਹਨ। ਮੂਲ ਦਸਤਾਵੇਜ਼ ਆਪਣੀ ਮੂਲ ਭਾਸ਼ਾ ਵਿੱਚ ਅਧਿਕਾਰਕ ਸਰੋਤ ਮੰਨਿਆ ਜਾਣਾ ਚਾਹੀਦਾ ਹੈ। ਜਰੂਰੀ ਜਾਣਕਾਰੀ ਲਈ, ਪੇਸ਼ੇਵਰ ਮਨੁੱਖੀ ਅਨੁਵਾਦ ਦੀ ਸਿਫ਼ਾਰਸ਼ ਕੀਤੀ ਜਾਂਦੀ ਹੈ। ਅਸੀਂ ਇਸ ਅਨੁਵਾਦ ਦੇ ਉਪਯੋਗ ਤੋਂ ਪੈਦਾ ਹੋਣ ਵਾਲੀਆਂ ਕਿਸੇ ਵੀ ਗਲਤਫਹਿਮੀਆਂ ਜਾਂ ਗਲਤ ਵਿਆਖਿਆਵਾਂ ਲਈ ਜਵਾਬਦੇਹ ਨਹੀਂ ਹਾਂ।
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
