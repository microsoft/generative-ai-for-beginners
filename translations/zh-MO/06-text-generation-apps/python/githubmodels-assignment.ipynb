# %% [markdown]
# # 建立文本生成應用程式
#
# 你到目前為止已經透過這個課程了解到一些核心概念，例如 prompts（提示詞）甚至有一整門學科稱為「提示詞工程 (prompt engineering)」。你可以與許多工具互動，例如 ChatGPT、Office 365、Microsoft Power Platform 等，它們都支援你使用提示詞達成某些任務。
#
# 若你想要在應用程式中加入這樣的體驗，你需要理解提示詞、完成項（completions）等概念，並選擇一個函式庫來操作。這正是你在本章節將學習的內容。
#
# ## 簡介
#
# 在本章節，你將會：
#
# - 了解 openai 函式庫及其核心概念。
# - 使用 openai 建立一個文本生成應用程式。
# - 理解如何利用提示詞 (prompt)、溫度 (temperature) 和 token 等概念來建置文本生成應用程式。
#
# ## 學習目標
#
# 在本課程結束時，你將能：
#
# - 解釋什麼是文本生成應用程式。
# - 使用 openai 建立文本生成應用程式。
# - 配置你的應用程式使用更多或更少的 token，並且調整溫度，產生多樣化的輸出。
#
# ## 什麼是文本生成應用程式？
#
# 通常當你建立一個應用程式時，它會有某種介面，如以下類型：
#
# - 命令式。主控台應用程式是典型你可以輸入命令並執行任務的應用程式。例如，`git` 就是一個命令式應用程式。
# - 使用者介面 (UI)。有些應用程式有圖形化使用者介面 (GUI)，你可以點擊按鈕、輸入文字、選擇選項等等。
#
# ### 主控台和使用者介面應用程式的限制
#
# 與你輸入命令的命令式應用程式比較：
#
# - <strong>受限</strong>。你不能隨意輸入任意命令，只能輸入應用程式支援的命令。
# - <strong>語言特定</strong>。有些應用程式支援多種語言，但預設是建置於特定語言，即使你可以加入更多語言支援。
#
# ### 文本生成應用程式的好處
#
# 那麼文本生成應用程式有什麼不同呢？
#
# 在文本生成應用程式中，你有更多的彈性，你不受限於特定的指令或輸入語言。相反地，你可以使用自然語言與應用程式互動。另一個好處是，你已經在與一個經過大量資料訓練的資料來源互動，而傳統應用程式可能受到資料庫內容的限制。
#
# ### 我可以用文本生成應用程式做什麼？
#
# 你可以建立很多不同的應用程式。例如：
#
# - <strong>聊天機械人</strong>。聊天機械人可以回答關於特定主題的問題，例如你的公司及其產品，非常合適。
# - <strong>助手</strong>。大型語言模型擅長摘要文字、從文本獲取洞見、產生像履歷等文件。
# - <strong>程式碼助手</strong>。根據你使用的語言模型，你可以建立一個協助編寫程式碼的助手。例如，你可以使用 GitHub Copilot 或 ChatGPT 來幫助寫程式碼。
#
# ## 如何開始？
#
# 你需要找到一個方式與大型語言模型（LLM）整合，通常有以下兩種方法：
#
# - 使用 API。這裡你會構造帶有提示詞的網路請求，然後取得生成的文本回應。
# - 使用函式庫。函式庫幫助封裝 API 呼叫，讓你更簡單使用。
#
# ## 函式庫/軟體開發套件
#
# 有一些知名的函式庫用於操作大型語言模型，例如：
#
# - **openai**，此函式庫使連接模型和發送提示詞變得簡單。
#
# 也有運作在更高層次的函式庫，比如：
#
# - **Langchain**。Langchain 是知名且支援 Python 的函式庫。
# - **Semantic Kernel**。Semantic Kernel 是由微軟開發的函式庫，支援 C#、Python 和 Java 三種語言。
#
# ## 使用 Microsoft Foundry Models Playground 和 Azure AI Inference SDK 建立第一個應用程式
#
# 讓我們看看如何建立第一個應用程式，需要哪些函式庫、所需程度等等。
#
# > **注意：** GitHub Models 於 2026 年 7 月底結束服務。以下步驟已更新為使用 [Microsoft Foundry Models](https://ai.azure.com/catalog/models?WT.mc_id=academic-105485-koreyst)，它提供跟 GitHub Models 相同的「瀏覽、在遊樂場中試玩，並用 API 金鑰呼叫」體驗，並且現在直接在 Microsoft Foundry 入口網站中託管。你若偏好完全離線作業？請參考 [Foundry Local](https://foundrylocal.ai?WT.mc_id=academic-105485-koreyst)，可在自己的設備上執行模型，無需雲端訂閱。
#
# ### 什麼是 Microsoft Foundry Models？
#
# 歡迎使用 [Microsoft Foundry Models](https://ai.azure.com/catalog/models?WT.mc_id=academic-105485-koreyst)！Foundry 模型目錄提供一個單一入口，讓你探索和試用數百個 AI 模型，包含 OpenAI、Meta、Mistral、Cohere、Microsoft 等，全部託管在 Azure 上。你可以透過免費的遊樂場存取這些模型，部署後還可以從你喜愛的程式碼 IDE 呼叫。
#
# ### 我需要什麼？
#
# * 微軟帳號及一個 [Azure 訂閱](https://aka.ms/azure/free?WT.mc_id=academic-105485-koreyst)（免費帳號即可）
# * 一個 [Microsoft Foundry 專案](https://ai.azure.com?WT.mc_id=academic-105485-koreyst)
#
# 我們開始吧！
#
# ### 尋找模型並測試
#
# 前往 [Microsoft Foundry Models 目錄](https://ai.azure.com/catalog/models?WT.mc_id=academic-105485-koreyst)
#
# ![Microsoft Foundry Models 目錄，顯示多個模型卡，如 Cohere、Meta llama、Mistral 和 GPT 模型](../../../../translated_images/zh-MO/GithubModelsMainScreen.62aed2c56e2bee64.webp)
#
# 選擇一個模型，例如 OpenAI GPT-4o mini
#
# 此處你會看到模型資訊卡。你可以：
# * 閱讀模型的說明文件、基準測試結果及授權標籤
# * 部署模型至你的 Foundry 專案
# * 部署完成後，可直接在遊樂場中與模型互動
#
# ![Microsoft Foundry Models GPT-4o 模型卡](../../../../translated_images/zh-MO/GithubModels-modelcard.c65ce4538e7bee92.webp)
#
# 開啟 **Playground** 與模型互動，新增系統提示詞並調整參數細節，還能取得以 Python、JavaScript、C# 和 REST 所需的完整程式碼。
#
# ![Microsoft Foundry Models Playground 體驗，顯示程式碼和語言選項](../../../../translated_images/zh-MO/GithubModels-plagroundcode.da2dea486f1ad5e0.webp)
#
#
# ### 在自己的 IDE 中使用模型
#
# 有兩個選項：
# 1. **GitHub Codespaces** - 無縫整合 Codespaces
# 2. **VS Code（或任何喜歡的 IDE）** - 你需要從 Foundry 專案取得 **端點 (endpoint)** 和 **API 金鑰**
#
#
# 無論哪種方式，你都可以在 Foundry 專案的 <strong>概覽</strong> 頁面找到這些值。
#
# ![入門畫面展示如何存取 Codespaces 或使用個人存取權杖設置自己的 IDE](../../../../translated_images/zh-MO/GithubModels-getstarted.4821f6f3182fc666.webp)
#
# ### 1. Codespaces
#
# * 建立新的 codespace（或使用現有的）
# * VS Code 將會在你的瀏覽器中開啟，附帶多語言範例筆記本讓你嘗試
# * 執行範例程式 ```./githubmodels-app.py```
#
# > 注意：在 codespaces 中，請將 Foundry 端點和金鑰儲存為 Codespaces 秘密，這樣就不必在本機設置它們。
#
# **請接著移至下方「生成文本」章節繼續本作業**
#
# ### 2. VS Code（或任何喜歡的 IDE）
#
# 從你的 Microsoft Foundry 專案中，你已有足夠資訊在你喜歡的 IDE 中執行。以下示範 VS Code。
#
# * 在你的 Foundry 專案中部署一個聊天模型，如 `gpt-4o-mini`
# * 從概覽頁面複製專案的 <strong>端點</strong> 和 **API 金鑰**
# * 建立環境變數以儲存它們：`AZURE_INFERENCE_ENDPOINT` 和 `AZURE_INFERENCE_CREDENTIAL`，並有 bash、powershell 及 windows 命令提示字元範例
# * 安裝相依套件：```pip install azure-ai-inference```
# * 將基本範例程式碼複製到 .py 檔案
# * 導航至保存程式碼的位置並執行檔案：```python filename.py```
#
# 不要忘記，使用 Azure AI Inference SDK 可以輕鬆透過修改程式碼中 `model_name` 的值來測試不同模型。
#
# 以下模型可在 Microsoft Foundry Models 目錄找到：
#
# * OpenAI：gpt-4o、gpt-4o-mini、gpt-4.1、gpt-4.1-mini、o3-mini、text-embedding-3-large、text-embedding-3-small
# * Meta：Meta-Llama-3.1-405B-Instruct、Meta-Llama-3.1-70B-Instruct、Meta-Llama-3.1-8B-Instruct、Llama-3.2-11B-Vision-Instruct、Llama-3.2-90B-Vision-Instruct、Llama-4-Scout-17B-16E-Instruct
# * Mistral AI：Mistral-large-2411、Mistral-small-2503、Codestral-2501、Ministral-3B
# * Microsoft：Phi-4、Phi-4-mini-instruct、Phi-4-multimodal-instruct、Phi-4-reasoning
# * Cohere：Cohere-command-r-plus-08-2024、Cohere-embed-v3-multilingual、Cohere-embed-v3-english
# * DeepSeek：DeepSeek-V3、DeepSeek-R1
#
#
#
# **請接著移至下方「生成文本」章節繼續本作業**
#
# ## 使用 ChatCompletions 生成文本
#
# 生成文本的方法是使用 `ChatCompletionsClient` 類別。
# 在 `samples/python/azure_ai_inference/basic.py` 中的回應程式碼部分，將 user 角色的 content 參數更新為以下內容：
#
# ```python
#
# response = client.complete(
#     messages=[
#         {
#             "role": "system",
#             "content": "You are a helpful assistant.",
#         },
#         {
#             "role": "user",
#             "content": "Complete the following: Once upon a time there was a",
#         },
#     ],
#     model=model_name,
#     # 可選參數
#     temperature=1.,
#     max_tokens=1000,
#     top_p=1.
# )
#
# ```
#
# 執行更新後的檔案以查看輸出

# %% [markdown]
# ## 不同類型的提示，適用於不同的事情
#
# 現在你已經了解了如何使用提示來生成文字。你甚至有一個正在運行的程式，能夠修改和更改以生成不同類型的文字。
#
# 提示可以用於各種任務。例如：
#
# - <strong>生成一種文字類型</strong>。例如，你可以生成詩歌、問答題目等。
# - <strong>查詢資訊</strong>。你可以使用提示來查詢資訊，例如以下範例「在網頁開發中，CORS是什麼意思？」。
# - <strong>生成程式碼</strong>。你可以使用提示來生成程式碼，例如開發用於驗證電郵的正則表示式，或者生成整個程式，如網頁應用程式？
#
# ## 練習：食譜生成器
#
# 想像你在家有一些食材，想做些料理。為此，你需要一個食譜。尋找食譜的方法包括使用搜尋引擎，或者使用大型語言模型（LLM）。
#
# 你可以這樣寫一個提示：
#
# > 「請展示用以下食材製作的五個食譜：雞肉、馬鈴薯和紅蘿蔔。請列出每個食譜所使用的所有食材」
#
# 根據以上提示，你可能會得到類似的回應：
#
# ```output
# 1. Roasted Chicken and Vegetables:
# Ingredients:
# - 4 chicken thighs
# - 2 potatoes, cut into cubes
# - 2 carrots, cut into cubes
# - 2 tablespoons olive oil
# - 2 cloves garlic, minced
# - 1 teaspoon dried thyme
# - 1 teaspoon dried oregano
# - Salt and pepper, to taste
#
# 2. Chicken and Potato Stew:
# Ingredients:
# - 2 tablespoons olive oil
# - 1 onion, diced
# - 2 cloves garlic, minced
# - 2 chicken breasts, cut into cubes
# - 2 potatoes, cut into cubes
# - 2 carrots, cut into cubes
# - 1 teaspoon dried oregano
# - 1 teaspoon dried thyme
# - 1 cup chicken broth
# - Salt and pepper, to taste
#
# 3. Chicken and Potato Bake:
# Ingredients:
# - 2 tablespoons olive oil
# - 2 chicken breasts, cut into cubes
# - 2 potatoes, cut into cubes
# - 2 carrots, cut into cubes
# - 1 onion, diced
# - 2 cloves garlic, minced
# - 1 teaspoon dried oregano
# - 1 teaspoon dried thyme
# - 1 cup chicken broth
# - Salt and pepper, to taste
#
# 4. Chicken and Potato Soup:
# Ingredients:
# - 2 tablespoons olive oil
# - 1 onion, diced
# - 2 cloves garlic, minced
# - 2 chicken breasts, cut into cubes
# - 2 potatoes, cut into cubes
# - 2 carrots, cut into cubes
# - 1 teaspoon dried oregano
# - 1 teaspoon dried thyme
# - 4 cups chicken broth
# - Salt and pepper, to taste
#
# 5. Chicken and Potato Hash:
# Ingredients:
# - 2 tablespoons olive oil
# - 2 chicken breasts, cut into cubes
# - 2 potatoes, cut into cubes
# - 2 carrots, cut into cubes
# - 1 onion, diced
# - 2 cloves garlic, minced
# - 1 teaspoon dried oregano
# ```
#
# 這個結果很棒，我知道該煮甚麼了。目前，可能有用的改進包括：
#
# - 篩選出我不喜歡或過敏的食材。
# - 產生購物清單，以防我家中沒有所有食材。
#
# 對於以上情況，我們加上另一個提示：
#
# > 「請移除含有大蒜的食譜，因為我過敏，並用其他食材代替。另外，請根據我已經有雞肉、馬鈴薯和紅蘿蔔，製作購物清單。」
#
# 現在你會得到一個新的結果：
#
# ```output
# 1. Roasted Chicken and Vegetables:
# Ingredients:
# - 4 chicken thighs
# - 2 potatoes, cut into cubes
# - 2 carrots, cut into cubes
# - 2 tablespoons olive oil
# - 1 teaspoon dried thyme
# - 1 teaspoon dried oregano
# - Salt and pepper, to taste
#
# 2. Chicken and Potato Stew:
# Ingredients:
# - 2 tablespoons olive oil
# - 1 onion, diced
# - 2 chicken breasts, cut into cubes
# - 2 potatoes, cut into cubes
# - 2 carrots, cut into cubes
# - 1 teaspoon dried oregano
# - 1 teaspoon dried thyme
# - 1 cup chicken broth
# - Salt and pepper, to taste
#
# 3. Chicken and Potato Bake:
# Ingredients:
# - 2 tablespoons olive oil
# - 2 chicken breasts, cut into cubes
# - 2 potatoes, cut into cubes
# - 2 carrots, cut into cubes
# - 1 onion, diced
# - 1 teaspoon dried oregano
# - 1 teaspoon dried thyme
# - 1 cup chicken broth
# - Salt and pepper, to taste
#
# 4. Chicken and Potato Soup:
# Ingredients:
# - 2 tablespoons olive oil
# - 1 onion, diced
# - 2 chicken breasts, cut into cubes
# - 2 potatoes, cut into cubes
# - 2 carrots, cut into cubes
# - 1 teaspoon dried oregano
# - 1 teaspoon dried thyme
# - 4 cups chicken broth
# - Salt and pepper, to taste
#
# 5. Chicken and Potato Hash:
# Ingredients:
# - 2 tablespoons olive oil
# - 2 chicken breasts, cut into cubes
# - 2 potatoes, cut into cubes
# - 2 carrots, cut into cubes
# - 1 onion, diced
# - 1 teaspoon dried oregano
#
# Shopping List:
# - Olive oil
# - Onion
# - Thyme
# - Oregano
# - Salt
# - Pepper
# ```
#
# 這就是你的五款食譜，沒有提及大蒜，也有考慮你已有食材的購物清單。

# %% [markdown]
# ## 練習 - 建立食譜生成器
#
# 現在我們已經模擬了一個場景，讓我們編寫代碼以符合示範的場景。為此，請按照以下步驟操作：
#
# 1. 使用現有檔案作為起點
# 1. 建立一個 `prompt` 變量並將範例程式碼更改如下：

# %%
import os
from azure.ai.inference import ChatCompletionsClient
from azure.ai.inference.models import SystemMessage, UserMessage
from azure.core.credentials import AzureKeyCredential

# Get these from your Microsoft Foundry project's "Overview" page
token = os.environ["AZURE_INFERENCE_CREDENTIAL"]
endpoint = os.environ["AZURE_INFERENCE_ENDPOINT"]

model_name = "gpt-4o-mini"

client = ChatCompletionsClient(
    endpoint=endpoint,
    credential=AzureKeyCredential(token),
)

prompt = "Show me 5 recipes for a dish with the following ingredients: chicken, potatoes, and carrots. Per recipe, list all the ingredients used"

response = client.complete(
    messages=[
        {
            "role": "system",
            "content": "You are a helpful assistant.",
        },
        {
            "role": "user",
            "content": prompt,
        },
    ],
    model=model_name,
    # Optional parameters
    temperature=1.,
    max_tokens=1000,
    top_p=1.    
)

print(response.choices[0].message.content)

# %% [markdown]
# 如果你現在執行程式碼，你應該會看到類似的輸出：
#
# ```output
# ### Recipe 1: Classic Chicken Stew
# #### Ingredients:
# - 2 lbs chicken thighs or drumsticks, skinless
# - 4 cups chicken broth
# - 4 medium potatoes, peeled and diced
# - 4 large carrots, peeled and sliced
# - 1 large onion, chopped
# - 2 cloves garlic, minced
# - 2 celery stalks, sliced
# - 1 tsp dried thyme
# - 1 tsp dried rosemary
# - Salt and pepper to taste
# - 2 tbsp olive oil
# - 2 tbsp flour (optional, for thickening)
#
# ### Recipe 2: Chicken and Vegetable Roast
# #### Ingredients:
# - 4 chicken breasts or thighs
# - 4 medium potatoes, cut into wedges
# - 4 large carrots, cut into sticks
# - 1 large onion, cut into wedges
# - 3 cloves garlic, minced
# - 1/4 cup olive oil
# - 1 tsp paprika
# - 1 tsp dried oregano
# - Salt and pepper to taste
# - Juice of 1 lemon
# - Fresh parsley, chopped (for garnish)
# (continued ...)
# ```
#
# > 注意，你的大型語言模型是非確定性的，所以每次執行程式時可能會得到不同的結果。
#
# 很好，讓我們看看如何改善。為了改善，我們要確保程式碼具有彈性，這樣配料和配方數量就可以被改進和更改。

# %% [markdown]
# 1. 我哋一齊咁改呢段代碼：

# %%
import os
from azure.ai.inference import ChatCompletionsClient
from azure.ai.inference.models import SystemMessage, UserMessage
from azure.core.credentials import AzureKeyCredential

# Get these from your Microsoft Foundry project's "Overview" page
token = os.environ["AZURE_INFERENCE_CREDENTIAL"]
endpoint = os.environ["AZURE_INFERENCE_ENDPOINT"]

model_name = "gpt-4o-mini"

client = ChatCompletionsClient(
    endpoint=endpoint,
    credential=AzureKeyCredential(token),
)

no_recipes = input("No of recipes (for example, 5): ")

ingredients = input("List of ingredients (for example, chicken, potatoes, and carrots): ")

# interpolate the number of recipes into the prompt an ingredients
prompt = f"Show me {no_recipes} recipes for a dish with the following ingredients: {ingredients}. Per recipe, list all the ingredients used"

response = client.complete(
    messages=[
        {
            "role": "system",
            "content": "You are a helpful assistant.",
        },
        {
            "role": "user",
            "content": prompt,
        },
    ],
    model=model_name,
    # Optional parameters
    temperature=1.,
    max_tokens=1000,
    top_p=1.    
)

print(response.choices[0].message.content)

# %% [markdown]
# 試跑一下代碼，可能看起來像這樣：
#
# ```output
# No of recipes (for example, 5): 2
# List of ingredients (for example, chicken, potatoes, and carrots): milk, strawberries
#
# Sure! Here are two recipes featuring milk and strawberries:
#
# ### Recipe 1: Strawberry Milkshake
#
# #### Ingredients:
# - 1 cup milk
# - 1 cup strawberries, hulled and sliced
# - 2 tablespoons sugar (optional, to taste)
# - 1/2 teaspoon vanilla extract
# - 5-6 ice cubes
#
# #### Instructions:
# 1. Combine the milk, strawberries, sugar (if using), and vanilla extract in a blender.
# 2. Blend on high until smooth and creamy.
# 3. Add the ice cubes and blend again until the ice is fully crushed and the milkshake is frothy.
# 4. Pour into a glass and serve immediately.
#
# ### Recipe 2: Strawberry Panna Cotta
#
# #### Ingredients:
# - 1 cup milk
# - 1 cup strawberries, hulled and pureed
# - 1/4 cup sugar
# - 1 teaspoon vanilla extract
# - 1 envelope unflavored gelatin (about 2 1/2 teaspoons)
# - 2 tablespoons cold water
# - 1 cup heavy cream
#
# #### Instructions:
# 1. Sprinkle the gelatin over the cold water in a small bowl and let it stand for about 5-10 minutes to soften.
# 2. In a saucepan, combine the milk, heavy cream, and sugar. Cook over medium heat, stirring frequently until the sugar is dissolved and the mixture begins to simmer. Do not let it boil.
# 3. Remove the saucepan from the heat and stir in the softened gelatin until completely dissolved.
# 4. Stir in the vanilla extract and allow the mixture to cool slightly.
# 5. Divide the mixture evenly into serving cups or molds and refrigerate for at least 4 hours or until set.
# 6. To prepare the strawberry puree, blend the strawberries until smooth.
# 7. Once the panna cotta is set, spoon the strawberry puree over the top of each panna cotta.
# 8. Serve chilled.
#
# Enjoy these delightful recipes!
# ```
#
# ### 透過添加過濾器和購物清單來改進
#
# 我們現在有了一個能夠生成食譜的可用應用程式，而且它相當靈活，因為它依賴用戶的輸入，無論是食譜數量還是所用的配料。
#
# 為了進一步改進它，我們想添加以下功能：
#
# - <strong>過濾配料</strong>。我們希望能夠過濾掉不喜歡或過敏的配料。為了實現這個更改，我們可以編輯現有的提示詞，並在其末尾添加過濾條件，如下所示：
#
#     ```python
#     filter = input("Filter (for example, vegetarian, vegan, or gluten-free: ")
#
#     prompt = f"Show me {no_recipes} recipes for a dish with the following ingredients: {ingredients}. Per recipe, list all the ingredients used, no {filter}"
#     ```
#
#     上面，我們在提示詞末尾加入 `{filter}`，同時我們也從用戶處取得過濾值。
#
#     執行程式的一個輸入範例如下：
#
#     ```output
#     No of recipes (for example, 5): 2
#     List of ingredients (for example, chicken, potatoes, and carrots): onion, milk
#     Filter (for example, vegetarian, vegan, or gluten-free: no milk
#     Certainly! Here are two recipes using onion but omitting milk:
#
#     ### Recipe 1: Caramelized Onions
#
#     #### Ingredients:
#     - 4 large onions, thinly sliced
#     - 2 tablespoons olive oil
#     - 1 tablespoon butter
#     - 1 teaspoon salt
#     - 1 teaspoon sugar (optional)
#     - 1 tablespoon balsamic vinegar (optional)
#
#     #### Instructions:
#     1. Heat the olive oil and butter in a large skillet over medium heat until the butter is melted.
#     2. Add the onions and stir to coat them with the oil and butter mixture.
#     3. Add salt (and sugar if using) to the onions.
#     4. Cook the onions, stirring occasionally, for about 45 minutes to an hour until they are golden brown and caramelized.
#     5. If using, add balsamic vinegar during the last 5 minutes of cooking.
#     6. Remove from heat and serve as a topping for burgers, steak, or as a side dish.
#
#     ### Recipe 2: French Onion Soup
#
#     #### Ingredients:
#     - 4 large onions, thinly sliced
#     - 3 tablespoons unsalted butter
#     - 2 cloves garlic, minced
#     - 1 teaspoon sugar
#     - 1 teaspoon salt
#     - 1/4 cup dry white wine (optional)
#     - 4 cups beef broth
#     - 4 cups chicken broth
#     - 1 bay leaf
#     - 1 teaspoon fresh thyme, chopped (or 1/2 teaspoon dried thyme)
#     - 1 baguette, sliced
#     - 2 cups Gruyère cheese, grated
#
#     #### Instructions:
#     1. Melt the butter in a large pot over medium heat.
#     2. Add the onions, garlic, sugar, and salt, and cook, stirring frequently, until the onions are deeply caramelized (about 30-35 minutes).
#     3. If using, add the white wine and cook until it evaporates, about 3-5 minutes.
#     4. Add the beef and chicken broths, bay leaf, and thyme. Bring to a simmer and cook for another 30 minutes. Remove the bay leaf.
#     5. Preheat the oven to 400°F (200°C).
#     6. Place the baguette slices on a baking sheet and toast them in the preheated oven until golden brown, about 5 minutes.
#     7. Ladle the soup into oven-safe bowls and place a slice of toasted baguette on top of each bowl.
#     8. Sprinkle the grated Gruyère cheese generously over the baguette slices.
#     9. Place the bowls under the broiler until the cheese is melted and bubbly, about 3-5 minutes.
#     10. Serve hot.
#
#     Enjoy your delicious onion dishes!
#     ```
#
# - <strong>生成購物清單</strong>。我們希望能基於家中已有的食材生成購物清單。
#
#     對於此功能，我們可以嘗試用一個提示詞解決所有問題，或者將其拆分成兩個提示詞。讓我們嘗試後者。在此我們建議添加一個額外的提示詞，但為了使其運作，我們需要將前一個提示詞的結果作為上下文傳給後一個提示詞。
#
#     找到代碼中打印第一個提示詞結果的部分，並在其下方加上以下代碼：
#
#     ```python
#     old_prompt_result = response.choices[0].message.content
#     prompt = "Produce a shopping list for the generated recipes and please don't include ingredients that I already have."
#
#     new_prompt = f"{old_prompt_result} {prompt}"
#
#     response = client.complete(
#         messages=[
#             {
#                 "role": "system",
#                 "content": "You are a helpful assistant.",
#             },
#             {
#                 "role": "user",
#                 "content": new_prompt,
#             },
#         ],
#         model=model_name,
#         # 可選參數
#         temperature=1.,
#         max_tokens=1200,
#         top_p=1.
#     )
#
#     # 列印回應
#     print("Shopping list:")
#     print(response.choices[0].message.content)
#     ```
#
#
#     注意以下事項：
#
#     - 我們通過將第一個提示詞的結果添加到新提示詞中，來構造新的提示詞：
#
#         ```python
#         new_prompt = f"{old_prompt_result} {prompt}"
#         messages = [{"role": "user", "content": new_prompt}]
#         ```
#
#     - 我們發出新的請求，但也考慮到第一次提示詞要求的令牌數量，所以這次設定 `max_tokens` 為 1200。<strong>關於令牌長度的一句話</strong>。我們應該考慮產生我們想要文字所需的令牌數。令牌使用會產生成本，所以在可能的情況下，我們應該盡量節約令牌使用。例如，我們能否調整提示詞以使用更少的令牌？
#
#         ```python
#         response = client.complete(
#             messages=[
#                 {
#                     "role": "system",
#                     "content": "You are a helpful assistant.",
#                 },
#                 {
#                     "role": "user",
#                     "content": new_prompt,
#                 },
#             ],
#             model=model_name,
#             # 可選參數
#             temperature=1.,
#             max_tokens=1200,
#             top_p=1.
#         )
#         ```
#
#         執行這段代碼後，我們將得到以下輸出：
#
#         ```output
#         No of recipes (for example, 5): 1
#         List of ingredients (for example, chicken, potatoes, and carrots): strawberry, milk
#         Filter (for example, vegetarian, vegan, or gluten-free): nuts
#
#         Certainly! Here's a simple and delicious recipe for a strawberry milkshake using strawberry and milk as primary ingredients:
#
#         ### Strawberry Milkshake
#
#         #### Ingredients:
#         - 1 cup fresh strawberries, hulled
#         - 1 cup cold milk
#         - 1 tablespoon honey or sugar (optional, to taste)
#         - 1/2 teaspoon vanilla extract (optional)
#         - 3-4 ice cubes
#
#         #### Instructions:
#         1. Wash and hull the strawberries, then slice them in half.
#         2. In a blender, combine the strawberries, cold milk, honey or sugar (if using), vanilla extract (if using), and ice cubes.
#         3. Blend until smooth and frothy.
#         4. Pour the milkshake into a glass.
#         5. Serve immediately and enjoy your refreshing strawberry milkshake!
#
#         This recipe is nut-free and makes for a delightful and quick treat!
#         Shopping list:
#         Sure! Here’s the shopping list for the Strawberry Milkshake recipe based on the ingredients provided. Please adjust based on what you already have at home:
#
#         ### Shopping List:
#         - Fresh strawberries (1 cup)
#         - Milk (1 cup)
#
#         Optional:
#         - Honey or sugar (1 tablespoon)
#         - Vanilla extract (1/2 teaspoon)
#         - Ice cubes (3-4)
#
#         Feel free to omit the optional ingredients if you prefer or if you already have them on hand. Enjoy your delicious strawberry milkshake!
#         ```
#
# - **嘗試調整 temperature 參數**。temperature 是我們迄今未提及，但對程式表現很重要的參數。temperature 值越高，輸出越隨機；相反越低，輸出越可預測。請考慮你想要輸出結果的變化程度。
#
#    若要更改 temperature，可以使用 `temperature` 參數。例如，若想使用 temperature 0.5，你可以這樣設定：
#
# ```python
#     response = client.complete(
#         messages=[
#             {
#                 "role": "system",
#                 "content": "You are a helpful assistant.",
#             },
#             {
#                 "role": "user",
#                 "content": new_prompt,
#             },
#         ],
#         model=model_name,
#         # 可選參數
#         temperature=0.5,
#         max_tokens=1200,
#         top_p=1.
#     )
# ```
#
#    > 注意，越接近 1.0，輸出越多變。
#
#
# ## 作業
#
# 這次的作業，你可以自行選擇開發什麼。
#
# 以下是一些建議：
#
# - 微調食譜生成器應用程式，進一步改進它。調整 temperature 值和提示詞，看看你能產生什麼結果。
# - 建立一個“學習夥伴”。這個應用可以回答與某個主題相關的問題，例如 Python。你可以設計像「什麼是 Python 中的某個主題？」的提示詞，或者設計請它展示某主題的範例代碼等。
# - 歷史機器人，讓歷史栩栩如生，指示機器人扮演某位歷史人物，並向它提問有關那段人生與時代的問題。
#
# ## 解決方案
#
# ### 學習夥伴
#
# - “你是 Python 語言專家
#
#     建議一個 Python 初學者課程，格式如下：
#
#     格式：
#     - 概念：
#     - 課程的簡要說明：
#     - 含解答的程式碼練習”
#
# 上面是一個起始提示詞，看看你怎麼使用並調整它以符合你的喜好。
#
# ### 歷史機器人
#
# 這裡有一些你可以使用的提示詞：
#
# - “你是亞伯·林肯，請用 3 句話介紹你自己，並使用亞伯當時會用的語法和詞彙回答”
# - “你是亞伯·林肯，請使用亞伯當時會用的語法和詞彙回答：
#
#    告訴我你最大的成就，字數約 300 字：“
#
# ## 知識檢測
#
# temperature 參數的作用是什麼？
#
# 1. 它控制輸出的隨機程度。
# 1. 它控制回應的長度。
# 1. 它控制使用的令牌數量。
#
# 答案：1
#
# 儲存 API 金鑰這類機密資料的好方法是什麼？
#
# 1. 直接寫在代碼裡。
# 1. 儲存於檔案。
# 1. 使用環境變量。
#
# 答案：3，因為環境變量不會被儲存在代碼中，可以從代碼中載入。

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **免責聲明**：
# 本文件使用 AI 翻譯服務 [Co-op Translator](https://github.com/Azure/co-op-translator) 進行翻譯。雖然我們力求準確，但請注意，自動翻譯可能包含錯誤或不準確之處。原始文件的母語版本應被視為權威來源。對於重要資訊，建議尋求專業人工翻譯。我們不對因使用本翻譯而引起的任何誤解或曲解承擔責任。
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
