# %% [markdown]
# तलको नोटबुक GitHub Copilot Chat द्वारा स्वचालित रूपमा सिर्जना गरिएको हो र यो केवल प्रारम्भिक सेटअपका लागि मात्र हो

# %% [markdown]
# # प्रॉम्प्ट इन्जिनियरिङ परिचय
# प्रॉम्प्ट इन्जिनियरिङ भनेको प्राकृतिक भाषा प्रशोधन कार्यहरूको लागि प्रॉम्प्टहरू डिजाइन र अनुकूलन गर्ने प्रक्रिया हो। यसले सही प्रॉम्प्टहरू चयन गर्ने, तिनीहरूको प्यारामिटरहरू ट्यून गर्ने, र तिनीहरूको प्रदर्शन मूल्याङ्कन गर्ने समावेश गर्दछ। उच्च शुद्धता र कार्यक्षमता प्राप्त गर्न प्रॉम्प्ट इन्जिनियरिङ NLP मोडेलहरूमा अत्यन्त महत्वपूर्ण छ। यस खण्डमा, हामी अन्वेषणका लागि OpenAI मोडेलहरूको प्रयोग गरी प्रॉम्प्ट इन्जिनियरिङका आधारहरू अन्वेषण गर्नेछौं।

# %% [markdown]
# ### अभ्यास १: टोकनाइजेशन
# OpenAI बाट ओपन-सोर्स छिटो टोकनाइजर tiktoken प्रयोग गरेर टोकनाइजेशन अन्वेषण गर्नुहोस्
# थप उदाहरणहरूको लागि [OpenAI Cookbook](https://github.com/openai/openai-cookbook/blob/main/examples/How_to_count_tokens_with_tiktoken.ipynb?WT.mc_id=academic-105485-koreyst) हेर्नुहोस्।

# %%
# EXERCISE:
# 1. Run the exercise as is first
# 2. Change the text to any prompt input you want to use & re-run to see tokens

import tiktoken

# Define the prompt you want tokenized
text = f"""
Jupiter is the fifth planet from the Sun and the \
largest in the Solar System. It is a gas giant with \
a mass one-thousandth that of the Sun, but two-and-a-half \
times that of all the other planets in the Solar System combined. \
Jupiter is one of the brightest objects visible to the naked eye \
in the night sky, and has been known to ancient civilizations since \
before recorded history. It is named after the Roman god Jupiter.[19] \
When viewed from Earth, Jupiter can be bright enough for its reflected \
light to cast visible shadows,[20] and is on average the third-brightest \
natural object in the night sky after the Moon and Venus.
"""

# Set the model you want encoding for
encoding = tiktoken.encoding_for_model("gpt-4o")

# Encode the text - gives you the tokens in integer form
tokens = encoding.encode(text)
print(tokens);

# Decode the integers to see what the text versions look like
[encoding.decode_single_token_bytes(token) for token in tokens]

# %% [markdown]
# ### अभ्यास २: OpenAI API कुञ्जी सेटअपको प्रमाणीकरण गर्नुहोस्
#
# तलको कोड चलाउनुहोस् ताकि तपाईंको OpenAI एन्डपोइन्ट सही तरिकाले सेटअप गरिएको छ वा छैन भनि जाँच गर्न सकियोस्। कोडले केवल एउटा साधारण आधारभूत प्रॉम्प्ट प्रयास गर्दछ र समापनलाई प्रमाणीकरण गर्दछ। इनपुट `oh say can you see` लाई `by the dawn's early light..` जस्तै समाप्त हुनु पर्छ।

# %%
# Uses the OpenAI client with the Responses API.
# See https://platform.openai.com/docs/api-reference/responses

import os
from openai import OpenAI
from dotenv import load_dotenv
load_dotenv()

client = OpenAI()

deployment="gpt-5-mini"

def get_completion(prompt):
    response = client.responses.create(
        model=deployment,
        input=prompt,
        max_output_tokens=1024,
        store=False,
    )
    return response.output_text

## ---------- Call the helper method

### 1. Set primary content or prompt text
text = f"""
oh say can you see
"""

### 2. Use that in the prompt template below
prompt = f"""
```{text}```
"""

## 3. Run the prompt
response = get_completion(prompt)
print(response)

# %% [markdown]
# ### अभ्यास ३: अभियांत्रणहरू
# जब तपाईं LLM लाई यस्तो विषयको बारेमा पूर्ति हरु फर्काउन भन्नुहुन्छ जुन अस्तित्वमा नहुन सक्छ, वा ती विषयहरूको बारेमा जुन यो पूर्व-प्रशिक्षित डाटासेट बाहिर हुन सक्छ (भर्खरको), तब के हुन्छ अन्वेषण गर्नुहोस्। यदि तपाईंले फरक प्राँप्ट वा फरक मोडल प्रयास गर्नुहुन्छ भने प्रतिक्रियामा कसरी परिवर्तन हुन्छ हेर्नुहोस्।

# %%
## Set the text for simple prompt or primary content
## Prompt shows a template format with text in it - add cues, commands etc if needed
## Run the completion 
text = f"""
generate a lesson plan on the Martian War of 2076.
"""

prompt = f"""
```{text}```
"""

response = get_completion(prompt)
print(response)

# %% [markdown]
# ### अभ्यास ४: निर्देशन आधारित
# प्राथमिक सामग्री सेट गर्न "text" चल प्रयोग गर्नुहोस्
# र त्यस प्राथमिक सामग्रीसँग सम्बन्धित निर्देशन दिन "prompt" चल प्रयोग गर्नुहोस्।
#
# यहाँ हामी मोडेललाई दोस्रो कक्षाका विद्यार्थीका लागि पाठ संक्षेप गर्न सोध्छौं

# %%
# Test Example
# https://platform.openai.com/playground/p/default-summarize

## Example text
text = f"""
Jupiter is the fifth planet from the Sun and the \
largest in the Solar System. It is a gas giant with \
a mass one-thousandth that of the Sun, but two-and-a-half \
times that of all the other planets in the Solar System combined. \
Jupiter is one of the brightest objects visible to the naked eye \
in the night sky, and has been known to ancient civilizations since \
before recorded history. It is named after the Roman god Jupiter.[19] \
When viewed from Earth, Jupiter can be bright enough for its reflected \
light to cast visible shadows,[20] and is on average the third-brightest \
natural object in the night sky after the Moon and Venus.
"""

## Set the prompt
prompt = f"""
Summarize content you are provided with for a second-grade student.
```{text}```
"""

## Run the prompt
response = get_completion(prompt)
print(response)

# %% [markdown]
# ### अभ्यास ५: जटिल प्रॉम्प्ट
# प्रणाली, प्रयोगकर्ता र सहायक सन्देशहरू भएका अनुरोध प्रयास गर्नुहोस्
# प्रणालीले सहायकको सन्दर्भ सेट गर्छ
# प्रयोगकर्ता र सहायक सन्देशहरूले बहु-चरण वार्तालाप सन्दर्भ प्रदान गर्छन्
#
# कसरी सहायकको व्यक्तित्व प्रणाली सन्दर्भमा "व्यंग्यात्मक" सेट गरिएको छ नोट गर्नुहोस्।
# भिन्न व्यक्तित्व सन्दर्भ प्रयोग गर्ने प्रयास गर्नुहोस्। वा इनपुट/आउटपुट सन्देशहरूको फरक श्रृंखला प्रयास गर्नुहोस्

# %%
response = client.responses.create(
    model=deployment,
    input=[
        {"role": "system", "content": "You are a sarcastic assistant."},
        {"role": "user", "content": "Who won the world series in 2020?"},
        {"role": "assistant", "content": "Who do you think won? The Los Angeles Dodgers of course."},
        {"role": "user", "content": "Where was it played?"}
    ],
    store=False,
)
print(response.output_text)

# %% [markdown]
# ### अभ्यास: आफ्नो अन्तर्ज्ञान अन्वेषण गर्नुहोस्
# माथिका उदाहरणहरूले तपाईंलाई नयाँ प्रम्पटहरू (सरल, जटिल, निर्देशन आदि) सिर्जना गर्न प्रयोग गर्न सकिने ढाँचाहरू दिन्छन् - हामीले छलफल गरेका केही अन्य विचारहरू जस्तै उदाहरणहरू, संकेतहरू र थप अन्वेषण गर्न अन्य अभ्यासहरू सिर्जना गर्न प्रयास गर्नुहोस्।

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **अस्वीकरण**:
# यो दस्तावेज़ AI अनुवाद सेवा [Co-op Translator](https://github.com/Azure/co-op-translator) प्रयोग गरेर अनुवाद गरिएको हो। हामी सही हुन प्रयास गर्छौं, तर कृपया जानकार हुनुस् कि स्वचालित अनुवादमा त्रुटिहरू वा अशुद्धताहरू हुन सक्छन्। मूल दस्तावेज़ यसको मूल भाषामा आधिकारिक स्रोत मानिनुपर्छ। महत्वपूर्ण जानकारीका लागि व्यावसायिक मानव अनुवाद सिफारिस गरिन्छ। यस अनुवादको प्रयोगबाट उत्पन्न कुनै पनि गलत बुझाइ वा त्रुटिको लागि हामी जिम्मेवार छैनौं।
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
