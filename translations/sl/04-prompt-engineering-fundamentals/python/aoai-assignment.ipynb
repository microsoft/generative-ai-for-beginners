# %% [markdown]
# Naslednji zvezek je bil samodejno ustvarjen z GitHub Copilot Chat in je namenjen le začetni nastavitvi

# %% [markdown]
# # Uvod v inženiring pozivov
# Inženiring pozivov je proces oblikovanja in optimizacije pozivov za naloge obdelave naravnega jezika. Vključuje izbiro pravih pozivov, prilagajanje njihovih parametrov in ocenjevanje njihove uspešnosti. Inženiring pozivov je ključen za dosego visoke natančnosti in učinkovitosti modelov NLP. V tem razdelku bomo raziskali osnove inženiringa pozivov z uporabo modelov OpenAI za raziskovanje.

# %% [markdown]
# ### Vaja 1: Tokenizacija
# Raziskujte tokenizacijo z uporabo tiktoken, odprtokodnega hitrega tokenizatorja iz OpenAI
# Oglejte si [OpenAI Cookbook](https://github.com/openai/openai-cookbook/blob/main/examples/How_to_count_tokens_with_tiktoken.ipynb?WT.mc_id=academic-105485-koreyst) za več primerov.

# %%
# EXERCISE:
# 1. Run the exercise as is first
# 2. Change the text to any prompt input you want to use & re-run to see tokens

import tiktoken

# Define the prompt you want tokenized
text = f"""
Jupiter is the fifth planet from the Sun and the \
largest in the Solar System. It is a gas giant with \
a mass one-thousandth that of the Sun, but two-and-a-half \
times that of all the other planets in the Solar System combined. \
Jupiter is one of the brightest objects visible to the naked eye \
in the night sky, and has been known to ancient civilizations since \
before recorded history. It is named after the Roman god Jupiter.[19] \
When viewed from Earth, Jupiter can be bright enough for its reflected \
light to cast visible shadows,[20] and is on average the third-brightest \
natural object in the night sky after the Moon and Venus.
"""

# Set the model you want encoding for
encoding = tiktoken.encoding_for_model("gpt-4o")

# Encode the text - gives you the tokens in integer form
tokens = encoding.encode(text)
print(tokens);

# Decode the integers to see what the text versions look like
[encoding.decode_single_token_bytes(token) for token in tokens]

# %% [markdown]
# ### Vaja 2: Preveri nastavitev ključa OpenAI API
#
# Zaženi spodnjo kodo, da preveriš, ali je tvoja OpenAI točka končnega dostopa pravilno nastavljena. Koda izvede enostaven osnovni poziv in preveri dokončanje. Vhod `oh say can you see` bi moral biti dokončan v slogu `by the dawn's early light..`

# %%
# Uses the OpenAI client against the Azure OpenAI (Microsoft Foundry) v1 endpoint
# with the Responses API. See https://aka.ms/openai/start

import os
from openai import OpenAI
from dotenv import load_dotenv
load_dotenv()

client = OpenAI(
  api_key=os.environ['AZURE_OPENAI_API_KEY'],
  base_url=f"{os.environ['AZURE_OPENAI_ENDPOINT'].rstrip('/')}/openai/v1/",
  )

deployment=os.environ['AZURE_OPENAI_DEPLOYMENT']

def get_completion(prompt):
    response = client.responses.create(
        model=deployment,
        input=prompt,
        max_output_tokens=1024,
        store=False,
    )
    return response.output_text

## ---------- Call the helper method

### 1. Set primary content or prompt text
text = f"""
oh say can you see
"""

### 2. Use that in the prompt template below
prompt = f"""
```{text}```
"""

## 3. Run the prompt
response = get_completion(prompt)
print(response)

# %% [markdown]
# ### Vaja 3: Izmišljotine
# Raziščite, kaj se zgodi, ko LLM zaprosite, naj vrne dopolnitve za poziv o temi, ki morda ne obstaja, ali o temah, ki jih morda ne pozna, ker so izven njegovega predhodno usposobljenega nabora podatkov (novejše). Oglejte si, kako se odziv spremeni, če poskusite z drugačnim pozivom ali z drugim modelom.

# %%
## Set the text for simple prompt or primary content
## Prompt shows a template format with text in it - add cues, commands etc if needed
## Run the completion 
text = f"""
generate a lesson plan on the Martian War of 2076.
"""

prompt = f"""
```{text}```
"""

response = get_completion(prompt)
print(response)

# %% [markdown]
# ### Vaja 4: Na osnovi navodil
# Uporabite spremenljivko "text" za nastavitev primarne vsebine
# in spremenljivko "prompt" za podajanje navodila, povezanega s to primarno vsebino.
#
# Tukaj model prosimo, naj povzame besedilo za učenca drugega razreda

# %%
# Test Example
# https://platform.openai.com/playground/p/default-summarize

## Example text
text = f"""
Jupiter is the fifth planet from the Sun and the \
largest in the Solar System. It is a gas giant with \
a mass one-thousandth that of the Sun, but two-and-a-half \
times that of all the other planets in the Solar System combined. \
Jupiter is one of the brightest objects visible to the naked eye \
in the night sky, and has been known to ancient civilizations since \
before recorded history. It is named after the Roman god Jupiter.[19] \
When viewed from Earth, Jupiter can be bright enough for its reflected \
light to cast visible shadows,[20] and is on average the third-brightest \
natural object in the night sky after the Moon and Venus.
"""

## Set the prompt
prompt = f"""
Summarize content you are provided with for a second-grade student.
```{text}```
"""

## Run the prompt
response = get_completion(prompt)
print(response)

# %% [markdown]
# ### Naloga 5: Kompleksen poziv
# Poskusi zahtevo, ki vsebuje sporočila sistema, uporabnika in pomočnika
# Sistem nastavi kontekst pomočnika
# Sporočila uporabnika in pomočnika zagotavljajo kontekst večkrožnega pogovora
#
# Opazuj, kako je osebnost pomočnika nastavljena na "sarkastična" v kontekstu sistema.
# Poskusi uporabiti drugačen osebnostni kontekst. Ali pa poskusi drugačen niz vhodnih/izhodnih sporočil

# %%
response = client.responses.create(
    model=deployment,
    input=[
        {"role": "system", "content": "You are a sarcastic assistant."},
        {"role": "user", "content": "Who won the world series in 2020?"},
        {"role": "assistant", "content": "Who do you think won? The Los Angeles Dodgers of course."},
        {"role": "user", "content": "Where was it played?"}
    ],
    store=False,
)
print(response.output_text)

# %% [markdown]
# ### Vaja: Raziskujte svojo intuicijo
# Zgornji primeri vam dajejo vzorce, ki jih lahko uporabite za ustvarjanje novih pozivov (enostavnih, zapletenih, navodil itd.) - poskusite ustvariti druge vaje za raziskovanje nekaterih drugih idej, o katerih smo govorili, kot so primeri, namigi in več.

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Omejitev odgovornosti**:
# Ta dokument je bil preveden z uporabo AI prevajalske storitve [Co-op Translator](https://github.com/Azure/co-op-translator). Čeprav si prizadevamo za natančnost, vas prosimo, da upoštevate, da avtomatizirani prevodi lahko vsebujejo napake ali netočnosti. Izvirni dokument v njegovem izvirnem jeziku je treba obravnavati kot avtoritativni vir. Za kritične informacije je priporočljiv strokovni človeški prevod. Ne odgovarjamo za morebitna nesporazume ali napačne interpretacije, ki izhajajo iz uporabe tega prevoda.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
